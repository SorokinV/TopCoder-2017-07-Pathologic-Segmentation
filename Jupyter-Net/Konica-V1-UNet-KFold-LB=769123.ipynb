# %%
##
## UNet 
##
## Взята идея по описанию из https://github.com/pietz/unet-keras
##
##
## 2017-07-28
##   Добавлены flip+rotation LB=760393
##
##
##
##
##

# %%
import sys,os,datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import fbeta_score
import sklearn.metrics as skm
from __future__ import print_function

# %%
print(np.__version__);
print(pd.__version__);
# Out:
# 1.13.1
# 0.19.2

# %%
import  cv2 as cv
cv.__version__
# Out:
# '3.2.0'

# %%
#from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.models import Sequential, save_model, load_model, Input, Model
from keras.layers import Convolution2D, MaxPooling2D, Convolution1D, MaxPooling1D, UpSampling2D, ZeroPadding2D
from keras.layers import Conv2D, Concatenate, Reshape
from keras.layers import Activation, Dropout, Flatten, Dense, Permute
from keras.layers.normalization import BatchNormalization
import keras.optimizers
from keras.callbacks import EarlyStopping,ReduceLROnPlateau,ModelCheckpoint
import keras.backend as K
# Out:
# Using TensorFlow backend.

# %%
keras.__version__
# Out:
# '2.0.6'

# %%
#---------------------------------------------------------------------

# %%
# !ls -la ..
#!ls -la ../Data
#!ls -la ../Data/training
# Out:
# total 25
# drwxrwxrwx 1 boba boba 4096 июл 26 11:10 .
# drwxrwxrwx 1 boba boba    0 июл 25 09:21 ..
# drwxrwxrwx 1 boba boba 4096 июл 25 09:23 Data
# drwxrwxrwx 1 boba boba    0 июл 25 09:22 Data-Arch
# drwxrwxrwx 1 boba boba    0 июл 25 09:26 Data-Keras
# drwxrwxrwx 1 boba boba 4096 июл 28 21:36 .git
# -rwxrwxrwx 2 boba boba  130 июл  9 12:02 .gitignore
# drwxrwxrwx 1 boba boba    0 июл 26 10:11 .ipynb_checkpoints
# drwxrwxrwx 1 boba boba    0 июл 28 21:36 Jupyter
# drwxrwxrwx 1 boba boba 4096 июл 29 11:29 Jupyter-Net
# drwxrwxrwx 1 boba boba 4096 июл 28 19:26 Result
# drwxrwxrwx 1 boba boba 4096 июл 28 21:35 Temp
# drwxrwxrwx 1 boba boba    0 июл 27 07:53 Work

# %%
dirData = '../Data'
dirTemp = '../Temp'
dirWork = '../Work'

dirTest  = os.path.join(dirData,'testing','images')
dirTrain = os.path.join(dirData,'training','images')
dirMask  = os.path.join(dirData,'training','truth')

# %%
listTrain = os.listdir(dirTrain)
listMask  = os.listdir(dirMask)
listTest  = os.listdir(dirTest)
listTrain = [xx for xx in listTrain if os.path.splitext(xx)[1]=='.tif']
listMask  = [xx for xx in listMask  if os.path.splitext(xx)[1]=='.png']
listTest  = [xx for xx in listTest  if os.path.splitext(xx)[1]=='.tif']
print(len(listTrain),len(listMask),len(listTest))
print(listTrain[:5],'\n',listMask[:5],'\n',listTest[:5])
# Out:
# 168 168 162
# ['i105404.tif', 'i117557.tif', 'i124017.tif', 'i130790.tif', 'i137857.tif']
#  ['i105404_mask.png', 'i117557_mask.png', 'i124017_mask.png', 'i130790_mask.png', 'i137857_mask.png']
#  ['i105047.tif', 'i116596.tif', 'i137649.tif', 'i140176.tif', 'i142099.tif']

# %%
if 0 :
    for xx in listTrain[:5] :
        img = cv.imread(os.path.join(dirTrain,xx),-1)
        xxm = os.path.splitext(xx)[0]+"_mask.png"
        msk = cv.imread(os.path.join(dirMask,xxm),-1)
        plt.subplot(121); plt.imshow(img); plt.subplot(122); plt.imshow(msk,'gray'); plt.show()
    plt.close()

# %%
msk.shape, img.shape, img.min(), img.max(), msk.max(), #img[6:10,6:10], msk[6:10,6:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-051c9d5448bc> in <module>()
# ----> 1 msk.shape, img.shape, img.min(), img.max(), msk.max(), #img[6:10,6:10], msk[6:10,6:10]
#
# NameError: name 'msk' is not defined

# %%
flagGray = False
Gauss    = 5
Median   = 5
if flagGray :
    trX, trY, trX0, trY0 = [], [], np.zeros((512,512,1)), np.zeros((512,512,1))
else :
    trX, trY, trX0, trY0 = [], [], np.zeros((512,512,3)), np.zeros((512,512,1))

for xx in listTrain :
    img = cv.imread(os.path.join(dirTrain,xx),-1)
    if 1 and (Gauss or Median): 
        for cc in range(img.shape[2]) : 
            if Gauss  : img[:,:,cc] = cv.GaussianBlur(img[:,:,cc],(Gauss,Gauss),0);
            if Median : img[:,:,cc] = cv.medianBlur  (img[:,:,cc],Median);
    xxm = os.path.splitext(xx)[0]+"_mask.png"
    msk = cv.imread(os.path.join(dirMask,xxm),-1)
    #print(img.mean(),msk.mean())
    if flagGray :
        img = cv.cvtColor(img,cv.COLOR_RGB2GRAY);
        trX0[6:506,6:506,0] = img[:,:]/255.0
        trY0[6:506,6:506,0] = msk[:,:]/255.0
    else :
        trX0[6:506,6:506,:] = img[:,:,:]/255.0
        trY0[6:506,6:506,0] = msk[:,:]/255.0
        trY0[trY0>=0.5] = 1.0
    trX.append(trX0.copy())
    trY.append(trY0.copy())
    #print(trX0.mean(),trY0.mean(),trX1[-1].mean(),trY1[-1].mean())

#print([trY[xx].mean() for xx in range(10)])
trX = np.array(trX)
trY = np.array(trY)

# аугментация
trXX, trYY = trX.copy(), trY.copy()

# flipping
for f in range(-1,2) :
    trXXX, trYYY = trX.copy(), trY.copy()
    for p in range(trXXX.shape[0]) :
        trXXX[p], trYYY[p,:,:,0] = cv.flip(trXXX[p],f), cv.flip(trYYY[p,:,:,0],f)
    trXX = np.vstack([trXX,trXXX])
    trYY = np.vstack([trYY,trYYY])
    print('flip :',f,trXX.shape,trYY.shape)
    
# rotate +-90

# rotate +90
trXXX, trYYY = trX.copy(), trY.copy()
for p in range(trX.shape[0]) :
    for i in range(trX.shape[1]) :
        for j in range(trX.shape[2]) :
            trXXX[p,i,j,:] = trX[p,j,trX.shape[1]-i-1]
            trYYY[p,i,j,:] = trY[p,j,trY.shape[1]-i-1]
trXX = np.vstack([trXX,trXXX])
trYY = np.vstack([trYY,trYYY])
print('rotate +90:',trXX.shape,trYY.shape)

# rotate -90
trXXX, trYYY = trX.copy(), trY.copy()
for p in range(trX.shape[0]) :
    for i in range(trX.shape[1]) :
        for j in range(trX.shape[2]) :
            trXXX[p,i,j,:] = trX[p,trX.shape[2]-j-1,i]
            trYYY[p,i,j,:] = trY[p,trY.shape[2]-j-1,i]
trXX = np.vstack([trXX,trXXX])
trYY = np.vstack([trYY,trYYY])
print('rotate -90:',trXX.shape,trYY.shape)
    
trX, trY = trXX.copy(), trYY.copy()
del trXX,trXXX,trYY,trYYY

# Считаем среднее по каналам и вычитаем из изображений
meanX = (trX[:,6:-6,6:-6,:].mean(axis=(1,2))).mean(axis=0)
stdX  = (trX[:,6:-6,6:-6,:].mean(axis=(1,2))).std(axis=0)
for cc in range(meanX.shape[0]) : 
    trX[:,6:-6,6:-6,cc] -= meanX[cc]    
print("mean={} std={}".format(meanX,stdX))
    
trX.shape, trX.min(), trX.max(), trY.shape, trY.min(), trY.max()
#[trY[xx].mean() for xx in range(10)]
# Out:
# flip : -1 (336, 512, 512, 3) (336, 512, 512, 1)
# flip : 0 (504, 512, 512, 3) (504, 512, 512, 1)
# flip : 1 (672, 512, 512, 3) (672, 512, 512, 1)
# rotate +90: (840, 512, 512, 3) (840, 512, 512, 1)
# rotate -90: (1008, 512, 512, 3) (1008, 512, 512, 1)
# mean=[ 0.6473997   0.48950165  0.70839568] std=[ 0.06249822  0.09179847  0.08778627]
# ((1008, 512, 512, 3),
#  -0.62212117329585415,
#  0.48696893986925888,
#  (1008, 512, 512, 1),
#  0.0,
#  1.0)

# %%
for xx in range(5) :
    img = trX[xx]
    xxm = trY[xx]
    plt.subplot(121); plt.imshow(img); plt.subplot(122); plt.imshow(xxm[:,:,0],'gray'); plt.show()
plt.close()

# %%
#
# model UNET
#
#    https://github.com/pietz/unet-keras
#
#

def level_block(m, dim, depth, acti, dropout=0.25, batch=True):
    if depth > 0:
        
        x = m
        if batch : x = BatchNormalization()(x)
        n = Conv2D(dim, (3, 3), activation=acti, padding='same')(x) #(m)
        n = Conv2D(dim, (3, 3), activation=acti, padding='same')(n)
        if dropout : n = Dropout(dropout)(n) ## add
        m = MaxPooling2D((2, 2))(n)
        m = level_block(m, 2*dim, depth-1, acti, dropout=dropout, batch=batch)
        m = UpSampling2D((2, 2))(m)
        m = Conv2D(dim, (2, 2), activation=acti, padding='same')(m)
        if dropout : m = Dropout(dropout)(m) ## add
        m = Concatenate(axis=3)([n, m])
    m = Conv2D(dim, (3, 3), activation=acti, padding='same')(m)
    return Conv2D(dim, (3, 3), activation=acti, padding='same')(m)

def UNet(img_shape, n_out=2, dim=32, depth=5, acti='relu', flatten=False, dropout=0.25, batch=True):
    i = Input(shape=img_shape)
    ## ???? i = ZeroPadding2D((6,6),data_format="channels_last")
    o = level_block(i, dim, depth, acti, dropout=dropout, batch=batch)
    o = Conv2D(n_out, (1, 1), name='prediction')(o)
    if flatten:
        o = Reshape(n_out, img_shape[0] * img_shape[1])(o)
        o = Permute((2, 1))(o)
    #o = Activation('relu')(o)
    if batch : o = BatchNormalization()(o)  ######
    o = Activation('sigmoid')(o)
    return Model(inputs=i, outputs=o)

# %%
model10 = UNet((512,512,3),depth=5,n_out=1, dropout=0.05)
model10.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 512, 512, 3)   0
# ____________________________________________________________________________________________________
# batch_normalization_1 (BatchNorm (None, 512, 512, 3)   12          input_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_1 (Conv2D)                (None, 512, 512, 32)  896         batch_normalization_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_2 (Conv2D)                (None, 512, 512, 32)  9248        conv2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 512, 512, 32)  0           conv2d_2[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)   (None, 256, 256, 32)  0           dropout_1[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_2 (BatchNorm (None, 256, 256, 32)  128         max_pooling2d_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_3 (Conv2D)                (None, 256, 256, 64)  18496       batch_normalization_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_4 (Conv2D)                (None, 256, 256, 64)  36928       conv2d_3[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)              (None, 256, 256, 64)  0           conv2d_4[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)   (None, 128, 128, 64)  0           dropout_2[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_3 (BatchNorm (None, 128, 128, 64)  256         max_pooling2d_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_5 (Conv2D)                (None, 128, 128, 128) 73856       batch_normalization_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_6 (Conv2D)                (None, 128, 128, 128) 147584      conv2d_5[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)              (None, 128, 128, 128) 0           conv2d_6[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)   (None, 64, 64, 128)   0           dropout_3[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_4 (BatchNorm (None, 64, 64, 128)   512         max_pooling2d_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_7 (Conv2D)                (None, 64, 64, 256)   295168      batch_normalization_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_8 (Conv2D)                (None, 64, 64, 256)   590080      conv2d_7[0][0]
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)              (None, 64, 64, 256)   0           conv2d_8[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)   (None, 32, 32, 256)   0           dropout_4[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_5 (BatchNorm (None, 32, 32, 256)   1024        max_pooling2d_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_9 (Conv2D)                (None, 32, 32, 512)   1180160     batch_normalization_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_10 (Conv2D)               (None, 32, 32, 512)   2359808     conv2d_9[0][0]
# ____________________________________________________________________________________________________
# dropout_5 (Dropout)              (None, 32, 32, 512)   0           conv2d_10[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)   (None, 16, 16, 512)   0           dropout_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_11 (Conv2D)               (None, 16, 16, 1024)  4719616     max_pooling2d_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_12 (Conv2D)               (None, 16, 16, 1024)  9438208     conv2d_11[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)   (None, 32, 32, 1024)  0           conv2d_12[0][0]
# ____________________________________________________________________________________________________
# conv2d_13 (Conv2D)               (None, 32, 32, 512)   2097664     up_sampling2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_6 (Dropout)              (None, 32, 32, 512)   0           conv2d_13[0][0]
# ____________________________________________________________________________________________________
# concatenate_1 (Concatenate)      (None, 32, 32, 1024)  0           dropout_5[0][0]
#                                                                    dropout_6[0][0]
# ____________________________________________________________________________________________________
# conv2d_14 (Conv2D)               (None, 32, 32, 512)   4719104     concatenate_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_15 (Conv2D)               (None, 32, 32, 512)   2359808     conv2d_14[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)   (None, 64, 64, 512)   0           conv2d_15[0][0]
# ____________________________________________________________________________________________________
# conv2d_16 (Conv2D)               (None, 64, 64, 256)   524544      up_sampling2d_2[0][0]
# ____________________________________________________________________________________________________
# dropout_7 (Dropout)              (None, 64, 64, 256)   0           conv2d_16[0][0]
# ____________________________________________________________________________________________________
# concatenate_2 (Concatenate)      (None, 64, 64, 512)   0           dropout_4[0][0]
#                                                                    dropout_7[0][0]
# ____________________________________________________________________________________________________
# conv2d_17 (Conv2D)               (None, 64, 64, 256)   1179904     concatenate_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_18 (Conv2D)               (None, 64, 64, 256)   590080      conv2d_17[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)   (None, 128, 128, 256) 0           conv2d_18[0][0]
# ____________________________________________________________________________________________________
# conv2d_19 (Conv2D)               (None, 128, 128, 128) 131200      up_sampling2d_3[0][0]
# ____________________________________________________________________________________________________
# dropout_8 (Dropout)              (None, 128, 128, 128) 0           conv2d_19[0][0]
# ____________________________________________________________________________________________________
# concatenate_3 (Concatenate)      (None, 128, 128, 256) 0           dropout_3[0][0]
#                                                                    dropout_8[0][0]
# ____________________________________________________________________________________________________
# conv2d_20 (Conv2D)               (None, 128, 128, 128) 295040      concatenate_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_21 (Conv2D)               (None, 128, 128, 128) 147584      conv2d_20[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)   (None, 256, 256, 128) 0           conv2d_21[0][0]
# ____________________________________________________________________________________________________
# conv2d_22 (Conv2D)               (None, 256, 256, 64)  32832       up_sampling2d_4[0][0]
# ____________________________________________________________________________________________________
# dropout_9 (Dropout)              (None, 256, 256, 64)  0           conv2d_22[0][0]
# ____________________________________________________________________________________________________
# concatenate_4 (Concatenate)      (None, 256, 256, 128) 0           dropout_2[0][0]
#                                                                    dropout_9[0][0]
# ____________________________________________________________________________________________________
# conv2d_23 (Conv2D)               (None, 256, 256, 64)  73792       concatenate_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_24 (Conv2D)               (None, 256, 256, 64)  36928       conv2d_23[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)   (None, 512, 512, 64)  0           conv2d_24[0][0]
# ____________________________________________________________________________________________________
# conv2d_25 (Conv2D)               (None, 512, 512, 32)  8224        up_sampling2d_5[0][0]
# ____________________________________________________________________________________________________
# dropout_10 (Dropout)             (None, 512, 512, 32)  0           conv2d_25[0][0]
# ____________________________________________________________________________________________________
# concatenate_5 (Concatenate)      (None, 512, 512, 64)  0           dropout_1[0][0]
#                                                                    dropout_10[0][0]
# ____________________________________________________________________________________________________
# conv2d_26 (Conv2D)               (None, 512, 512, 32)  18464       concatenate_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_27 (Conv2D)               (None, 512, 512, 32)  9248        conv2d_26[0][0]
# ____________________________________________________________________________________________________
# prediction (Conv2D)              (None, 512, 512, 1)   33          conv2d_27[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_6 (BatchNorm (None, 512, 512, 1)   4           prediction[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 512, 512, 1)   0           batch_normalization_6[0][0]
# ====================================================================================================
# Total params: 31,096,433
# Trainable params: 31,095,465
# Non-trainable params: 968
# ____________________________________________________________________________________________________

# %%
def dice (truth,pred) :
    g, s = K.sum(truth), K.sum(pred)
    x    = K.sum((truth*pred))
    return((1.0 if K.sum(g+s)==0.0 else 2.0*x/(g+s+K.epsilon())))

def f1 (truth,pred) :
    TP = K.sum(truth*pred)
    TN = K.sum((1.0-truth)*(1.0-pred))
    FP = K.sum(truth*(1.0-pred))
    FN = K.sum((1.0-truth)*pred)

    
    P  = 1.0 if K.sum(TP+FP)==0.0 else TP/(TP+FP)
    R  = 0.0 if K.sum(TP+FN)==0.0 else TP/(TP+FN) 

    F1 = 0.0 if K.sum(P+R)  ==0.0 else 2.0*P*R/(P+R)

    return(F1)

def f1dice (truth,pred) :
    return ((dice(truth,pred)+f1(truth,pred))/2.0)
    
def lossdice (truth,pred) :
    return(1.0 - dice(truth,pred))

def lossfd (truth,pred) :
    return(1.0 - f1dice(truth,pred))

# %%
def buildModel (input_shape) :
    model = UNet(input_shape,depth=5,n_out=1,dropout=0.05,batch=False)
    
    sgd = keras.optimizers.SGD(lr=0.01, momentum=0.9, nesterov=True)
    #model.compile(loss='mean_absolute_error',  #'binary_crossentropy',
    model.compile(loss=lossdice, #'mean_absolute_error',  #'binary_crossentropy',
                  optimizer=sgd, #sgd, #"adam", #'rmsprop',
                  metrics=[dice,'binary_accuracy']) #['binary_accuracy']) #[fbeta_pred]) #['accuracy',fbeta_pred]) #['accuracy'])
    return(model)

# %%
K.clear_session()
model10 = buildModel((trX.shape[1],trX.shape[2],trX.shape[3]))
model10.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 512, 512, 3)   0
# ____________________________________________________________________________________________________
# conv2d_1 (Conv2D)                (None, 512, 512, 32)  896         input_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_2 (Conv2D)                (None, 512, 512, 32)  9248        conv2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 512, 512, 32)  0           conv2d_2[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)   (None, 256, 256, 32)  0           dropout_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_3 (Conv2D)                (None, 256, 256, 64)  18496       max_pooling2d_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_4 (Conv2D)                (None, 256, 256, 64)  36928       conv2d_3[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)              (None, 256, 256, 64)  0           conv2d_4[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)   (None, 128, 128, 64)  0           dropout_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_5 (Conv2D)                (None, 128, 128, 128) 73856       max_pooling2d_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_6 (Conv2D)                (None, 128, 128, 128) 147584      conv2d_5[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)              (None, 128, 128, 128) 0           conv2d_6[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)   (None, 64, 64, 128)   0           dropout_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_7 (Conv2D)                (None, 64, 64, 256)   295168      max_pooling2d_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_8 (Conv2D)                (None, 64, 64, 256)   590080      conv2d_7[0][0]
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)              (None, 64, 64, 256)   0           conv2d_8[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)   (None, 32, 32, 256)   0           dropout_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_9 (Conv2D)                (None, 32, 32, 512)   1180160     max_pooling2d_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_10 (Conv2D)               (None, 32, 32, 512)   2359808     conv2d_9[0][0]
# ____________________________________________________________________________________________________
# dropout_5 (Dropout)              (None, 32, 32, 512)   0           conv2d_10[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)   (None, 16, 16, 512)   0           dropout_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_11 (Conv2D)               (None, 16, 16, 1024)  4719616     max_pooling2d_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_12 (Conv2D)               (None, 16, 16, 1024)  9438208     conv2d_11[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)   (None, 32, 32, 1024)  0           conv2d_12[0][0]
# ____________________________________________________________________________________________________
# conv2d_13 (Conv2D)               (None, 32, 32, 512)   2097664     up_sampling2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_6 (Dropout)              (None, 32, 32, 512)   0           conv2d_13[0][0]
# ____________________________________________________________________________________________________
# concatenate_1 (Concatenate)      (None, 32, 32, 1024)  0           dropout_5[0][0]
#                                                                    dropout_6[0][0]
# ____________________________________________________________________________________________________
# conv2d_14 (Conv2D)               (None, 32, 32, 512)   4719104     concatenate_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_15 (Conv2D)               (None, 32, 32, 512)   2359808     conv2d_14[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)   (None, 64, 64, 512)   0           conv2d_15[0][0]
# ____________________________________________________________________________________________________
# conv2d_16 (Conv2D)               (None, 64, 64, 256)   524544      up_sampling2d_2[0][0]
# ____________________________________________________________________________________________________
# dropout_7 (Dropout)              (None, 64, 64, 256)   0           conv2d_16[0][0]
# ____________________________________________________________________________________________________
# concatenate_2 (Concatenate)      (None, 64, 64, 512)   0           dropout_4[0][0]
#                                                                    dropout_7[0][0]
# ____________________________________________________________________________________________________
# conv2d_17 (Conv2D)               (None, 64, 64, 256)   1179904     concatenate_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_18 (Conv2D)               (None, 64, 64, 256)   590080      conv2d_17[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)   (None, 128, 128, 256) 0           conv2d_18[0][0]
# ____________________________________________________________________________________________________
# conv2d_19 (Conv2D)               (None, 128, 128, 128) 131200      up_sampling2d_3[0][0]
# ____________________________________________________________________________________________________
# dropout_8 (Dropout)              (None, 128, 128, 128) 0           conv2d_19[0][0]
# ____________________________________________________________________________________________________
# concatenate_3 (Concatenate)      (None, 128, 128, 256) 0           dropout_3[0][0]
#                                                                    dropout_8[0][0]
# ____________________________________________________________________________________________________
# conv2d_20 (Conv2D)               (None, 128, 128, 128) 295040      concatenate_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_21 (Conv2D)               (None, 128, 128, 128) 147584      conv2d_20[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)   (None, 256, 256, 128) 0           conv2d_21[0][0]
# ____________________________________________________________________________________________________
# conv2d_22 (Conv2D)               (None, 256, 256, 64)  32832       up_sampling2d_4[0][0]
# ____________________________________________________________________________________________________
# dropout_9 (Dropout)              (None, 256, 256, 64)  0           conv2d_22[0][0]
# ____________________________________________________________________________________________________
# concatenate_4 (Concatenate)      (None, 256, 256, 128) 0           dropout_2[0][0]
#                                                                    dropout_9[0][0]
# ____________________________________________________________________________________________________
# conv2d_23 (Conv2D)               (None, 256, 256, 64)  73792       concatenate_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_24 (Conv2D)               (None, 256, 256, 64)  36928       conv2d_23[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)   (None, 512, 512, 64)  0           conv2d_24[0][0]
# ____________________________________________________________________________________________________
# conv2d_25 (Conv2D)               (None, 512, 512, 32)  8224        up_sampling2d_5[0][0]
# ____________________________________________________________________________________________________
# dropout_10 (Dropout)             (None, 512, 512, 32)  0           conv2d_25[0][0]
# ____________________________________________________________________________________________________
# concatenate_5 (Concatenate)      (None, 512, 512, 64)  0           dropout_1[0][0]
#                                                                    dropout_10[0][0]
# ____________________________________________________________________________________________________
# conv2d_26 (Conv2D)               (None, 512, 512, 32)  18464       concatenate_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_27 (Conv2D)               (None, 512, 512, 32)  9248        conv2d_26[0][0]
# ____________________________________________________________________________________________________
# prediction (Conv2D)              (None, 512, 512, 1)   33          conv2d_27[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 512, 512, 1)   0           prediction[0][0]
# ====================================================================================================
# Total params: 31,094,497
# Trainable params: 31,094,497
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
#model10.load_weights('../Data-Keras/Models/model-UNet-weights.h5', by_name=False)
batch_size = 1

# %%
epochs     = 150
verbose    = 2
batch_size = 1
metric     = 'binary_accuracy'
metric     = 'dice'

############trX, trY = trX[0:30], trY[0:30]

folds      = 5
foldN      = trX.shape[0]/folds+1

print(datetime.datetime.now(),'Training with folds')

#for i in range(folds) :
for i in range(3,6) :

    print(datetime.datetime.now(),'------------>',i)

    K.clear_session()
    model10 = buildModel((trX.shape[1],trX.shape[2],trX.shape[3]))
    ############if 1 : model10.load_weights('../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7660-2.hdf5')

#    early_stopping = EarlyStopping(monitor='val_loss', patience=10,min_delta=0.0001,verbose=1)
    early_stopping = EarlyStopping(monitor='loss', patience=10,min_delta=0.0001,verbose=1)
    reduce_lr1     = ReduceLROnPlateau(monitor='val_loss', factor=0.5,patience=3, min_lr=0.0000001,verbose=1)
    reduce_lr2     = ReduceLROnPlateau(monitor='loss',     factor=0.5,patience=3, min_lr=0.0000001,verbose=1)

    filepath="../Temp/TempTempG5M5KFold2/V1-UNET-val_"+metric+"={val_"+metric+":.4f}-{"+metric+":.4f}---"+str(i)+".hdf5"
    #checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
    checkpoint1 = ModelCheckpoint(filepath, monitor=metric,        verbose=1, save_best_only=True, mode='max')
    checkpoint2 = ModelCheckpoint(filepath, monitor='val_'+metric, verbose=1, save_best_only=True, mode='max')

    step  = 60
    low   = 0
    high  = low+step
    
    tFold = [True]*(i*foldN)+[False]*foldN+[True]*trX.shape[0];
    tFold = tFold[:trX.shape[0]]
    
    vFold = [not xx for xx in tFold]

    #hist1  = model10.fit(trX[low:high],trY[low:high],
    hist1  = model10.fit(trX[tFold],trY[tFold],
                        epochs=epochs, batch_size=batch_size, 
                        #validation_split=0.20, 
                        validation_data=(trX[vFold],trY[vFold]),
                        initial_epoch = 0,
                        #callbacks=[early_stopping,reduce_lr1,reduce_lr2,checkpoint],
                        callbacks=[reduce_lr1,reduce_lr2,checkpoint1,checkpoint2,early_stopping],
                        verbose=verbose)

print(datetime.datetime.now())
# Out:
# 2017-07-28 21:49:34.757001 Training with folds
# 2017-07-28 21:49:34.757736 ------------> 0
# Train on 806 samples, validate on 202 samples
# Epoch 1/150
# Epoch 00000: dice improved from -inf to 0.58187, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.6392-0.5819---0.hdf5
# Epoch 00000: val_dice improved from -inf to 0.63922, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.6392-0.5819---0.hdf5
# 454s - loss: 0.4181 - dice: 0.5819 - binary_accuracy: 0.7120 - val_loss: 0.3608 - val_dice: 0.6392 - val_binary_accuracy: 0.8355
# Epoch 2/150
# Epoch 00001: dice improved from 0.58187 to 0.66972, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.6698-0.6697---0.hdf5
# Epoch 00001: val_dice improved from 0.63922 to 0.66976, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.6698-0.6697---0.hdf5
# 405s - loss: 0.3303 - dice: 0.6697 - binary_accuracy: 0.8341 - val_loss: 0.3302 - val_dice: 0.6698 - val_binary_accuracy: 0.8203
# Epoch 3/150
# Epoch 00002: dice improved from 0.66972 to 0.69748, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7092-0.6975---0.hdf5
# Epoch 00002: val_dice improved from 0.66976 to 0.70919, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7092-0.6975---0.hdf5
# 401s - loss: 0.3025 - dice: 0.6975 - binary_accuracy: 0.8540 - val_loss: 0.2908 - val_dice: 0.7092 - val_binary_accuracy: 0.8617
# Epoch 4/150
# Epoch 00003: dice improved from 0.69748 to 0.71133, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.6739-0.7113---0.hdf5
# Epoch 00003: val_dice did not improve
# 397s - loss: 0.2887 - dice: 0.7113 - binary_accuracy: 0.8624 - val_loss: 0.3261 - val_dice: 0.6739 - val_binary_accuracy: 0.8151
# Epoch 5/150
# Epoch 00004: dice improved from 0.71133 to 0.72728, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7333-0.7273---0.hdf5
# Epoch 00004: val_dice improved from 0.70919 to 0.73330, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7333-0.7273---0.hdf5
# 400s - loss: 0.2727 - dice: 0.7273 - binary_accuracy: 0.8730 - val_loss: 0.2667 - val_dice: 0.7333 - val_binary_accuracy: 0.8863
# Epoch 6/150
# Epoch 00005: dice improved from 0.72728 to 0.73317, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7397-0.7332---0.hdf5
# Epoch 00005: val_dice improved from 0.73330 to 0.73970, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7397-0.7332---0.hdf5
# 400s - loss: 0.2668 - dice: 0.7332 - binary_accuracy: 0.8766 - val_loss: 0.2603 - val_dice: 0.7397 - val_binary_accuracy: 0.8873
# Epoch 7/150
# Epoch 00006: dice improved from 0.73317 to 0.74053, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7522-0.7405---0.hdf5
# Epoch 00006: val_dice improved from 0.73970 to 0.75217, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7522-0.7405---0.hdf5
# 399s - loss: 0.2595 - dice: 0.7405 - binary_accuracy: 0.8822 - val_loss: 0.2478 - val_dice: 0.7522 - val_binary_accuracy: 0.8934
# Epoch 8/150
# Epoch 00007: dice improved from 0.74053 to 0.75023, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7540-0.7502---0.hdf5
# Epoch 00007: val_dice improved from 0.75217 to 0.75400, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7540-0.7502---0.hdf5
# 399s - loss: 0.2498 - dice: 0.7502 - binary_accuracy: 0.8876 - val_loss: 0.2460 - val_dice: 0.7540 - val_binary_accuracy: 0.8939
# Epoch 9/150
# Epoch 00008: dice improved from 0.75023 to 0.75524, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7541-0.7552---0.hdf5
# Epoch 00008: val_dice improved from 0.75400 to 0.75414, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7541-0.7552---0.hdf5
# 400s - loss: 0.2448 - dice: 0.7552 - binary_accuracy: 0.8910 - val_loss: 0.2459 - val_dice: 0.7541 - val_binary_accuracy: 0.8952
# Epoch 10/150
# Epoch 00009: dice improved from 0.75524 to 0.75658, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7611-0.7566---0.hdf5
# Epoch 00009: val_dice improved from 0.75414 to 0.76114, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7611-0.7566---0.hdf5
# 399s - loss: 0.2434 - dice: 0.7566 - binary_accuracy: 0.8918 - val_loss: 0.2389 - val_dice: 0.7611 - val_binary_accuracy: 0.8991
# Epoch 11/150
# Epoch 00010: dice improved from 0.75658 to 0.76241, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7470-0.7624---0.hdf5
# Epoch 00010: val_dice did not improve
# 397s - loss: 0.2376 - dice: 0.7624 - binary_accuracy: 0.8953 - val_loss: 0.2530 - val_dice: 0.7470 - val_binary_accuracy: 0.8838
# Epoch 12/150
# Epoch 00011: dice did not improve
# Epoch 00011: val_dice did not improve
# 394s - loss: 0.2382 - dice: 0.7618 - binary_accuracy: 0.8920 - val_loss: 0.2405 - val_dice: 0.7595 - val_binary_accuracy: 0.8927
# Epoch 13/150
# Epoch 00012: dice improved from 0.76241 to 0.77203, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7599-0.7720---0.hdf5
# Epoch 00012: val_dice did not improve
# 397s - loss: 0.2280 - dice: 0.7720 - binary_accuracy: 0.9004 - val_loss: 0.2401 - val_dice: 0.7599 - val_binary_accuracy: 0.8920
# Epoch 14/150
#
# Epoch 00013: reducing learning rate to 0.00499999988824.
# Epoch 00013: dice improved from 0.77203 to 0.77706, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7611-0.7771---0.hdf5
# Epoch 00013: val_dice did not improve
# 397s - loss: 0.2229 - dice: 0.7771 - binary_accuracy: 0.9010 - val_loss: 0.2389 - val_dice: 0.7611 - val_binary_accuracy: 0.8924
# Epoch 15/150
# Epoch 00014: dice improved from 0.77706 to 0.78974, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7850-0.7897---0.hdf5
# Epoch 00014: val_dice improved from 0.76114 to 0.78499, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7850-0.7897---0.hdf5
# 401s - loss: 0.2103 - dice: 0.7897 - binary_accuracy: 0.9088 - val_loss: 0.2150 - val_dice: 0.7850 - val_binary_accuracy: 0.9104
# Epoch 16/150
# Epoch 00015: dice improved from 0.78974 to 0.79546, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7815-0.7955---0.hdf5
# Epoch 00015: val_dice did not improve
# 396s - loss: 0.2045 - dice: 0.7955 - binary_accuracy: 0.9122 - val_loss: 0.2185 - val_dice: 0.7815 - val_binary_accuracy: 0.9056
# Epoch 17/150
# Epoch 00016: dice did not improve
# Epoch 00016: val_dice did not improve
# 393s - loss: 0.2049 - dice: 0.7951 - binary_accuracy: 0.9114 - val_loss: 0.2157 - val_dice: 0.7843 - val_binary_accuracy: 0.9091
# Epoch 18/150
# Epoch 00017: dice improved from 0.79546 to 0.79960, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7824-0.7996---0.hdf5
# Epoch 00017: val_dice did not improve
# 396s - loss: 0.2004 - dice: 0.7996 - binary_accuracy: 0.9139 - val_loss: 0.2176 - val_dice: 0.7824 - val_binary_accuracy: 0.9067
# Epoch 19/150
#
# Epoch 00018: reducing learning rate to 0.00249999994412.
# Epoch 00018: dice did not improve
# Epoch 00018: val_dice did not improve
# 393s - loss: 0.2155 - dice: 0.7845 - binary_accuracy: 0.9072 - val_loss: 0.2249 - val_dice: 0.7751 - val_binary_accuracy: 0.9052
# Epoch 20/150
# Epoch 00019: dice did not improve
# Epoch 00019: val_dice did not improve
# 394s - loss: 0.2018 - dice: 0.7982 - binary_accuracy: 0.9143 - val_loss: 0.2495 - val_dice: 0.7505 - val_binary_accuracy: 0.8952
# Epoch 21/150
# Epoch 00020: dice improved from 0.79960 to 0.80665, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7923-0.8067---0.hdf5
# Epoch 00020: val_dice improved from 0.78499 to 0.79227, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7923-0.8067---0.hdf5
# 399s - loss: 0.1933 - dice: 0.8067 - binary_accuracy: 0.9175 - val_loss: 0.2077 - val_dice: 0.7923 - val_binary_accuracy: 0.9126
# Epoch 22/150
# Epoch 00021: dice improved from 0.80665 to 0.81110, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7963-0.8111---0.hdf5
# Epoch 00021: val_dice improved from 0.79227 to 0.79626, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7963-0.8111---0.hdf5
# 399s - loss: 0.1889 - dice: 0.8111 - binary_accuracy: 0.9197 - val_loss: 0.2037 - val_dice: 0.7963 - val_binary_accuracy: 0.9172
# Epoch 23/150
# Epoch 00022: dice improved from 0.81110 to 0.81372, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7978-0.8137---0.hdf5
# Epoch 00022: val_dice improved from 0.79626 to 0.79778, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7978-0.8137---0.hdf5
# 399s - loss: 0.1863 - dice: 0.8137 - binary_accuracy: 0.9210 - val_loss: 0.2022 - val_dice: 0.7978 - val_binary_accuracy: 0.9160
# Epoch 24/150
# Epoch 00023: dice did not improve
# Epoch 00023: val_dice did not improve
# 393s - loss: 0.1924 - dice: 0.8076 - binary_accuracy: 0.9192 - val_loss: 0.2085 - val_dice: 0.7915 - val_binary_accuracy: 0.9165
# Epoch 25/150
# Epoch 00024: dice improved from 0.81372 to 0.81612, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7977-0.8161---0.hdf5
# Epoch 00024: val_dice did not improve
# 396s - loss: 0.1839 - dice: 0.8161 - binary_accuracy: 0.9230 - val_loss: 0.2023 - val_dice: 0.7977 - val_binary_accuracy: 0.9172
# Epoch 26/150
# Epoch 00025: dice improved from 0.81612 to 0.82028, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7847-0.8203---0.hdf5
# Epoch 00025: val_dice did not improve
# 396s - loss: 0.1797 - dice: 0.8203 - binary_accuracy: 0.9242 - val_loss: 0.2153 - val_dice: 0.7847 - val_binary_accuracy: 0.9077
# Epoch 27/150
# Epoch 00026: dice improved from 0.82028 to 0.82053, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7991-0.8205---0.hdf5
# Epoch 00026: val_dice improved from 0.79778 to 0.79914, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7991-0.8205---0.hdf5
# 399s - loss: 0.1795 - dice: 0.8205 - binary_accuracy: 0.9236 - val_loss: 0.2009 - val_dice: 0.7991 - val_binary_accuracy: 0.9178
# Epoch 28/150
# Epoch 00027: dice improved from 0.82053 to 0.82472, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8019-0.8247---0.hdf5
# Epoch 00027: val_dice improved from 0.79914 to 0.80189, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8019-0.8247---0.hdf5
# 399s - loss: 0.1753 - dice: 0.8247 - binary_accuracy: 0.9260 - val_loss: 0.1981 - val_dice: 0.8019 - val_binary_accuracy: 0.9189
# Epoch 29/150
# Epoch 00028: dice improved from 0.82472 to 0.82559, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7993-0.8256---0.hdf5
# Epoch 00028: val_dice did not improve
# 397s - loss: 0.1744 - dice: 0.8256 - binary_accuracy: 0.9260 - val_loss: 0.2007 - val_dice: 0.7993 - val_binary_accuracy: 0.9166
# Epoch 30/150
# Epoch 00029: dice improved from 0.82559 to 0.82704, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8034-0.8270---0.hdf5
# Epoch 00029: val_dice improved from 0.80189 to 0.80345, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8034-0.8270---0.hdf5
# 399s - loss: 0.1730 - dice: 0.8270 - binary_accuracy: 0.9268 - val_loss: 0.1966 - val_dice: 0.8034 - val_binary_accuracy: 0.9189
# Epoch 31/150
# Epoch 00030: dice did not improve
# Epoch 00030: val_dice did not improve
# 393s - loss: 0.1736 - dice: 0.8264 - binary_accuracy: 0.9258 - val_loss: 0.1984 - val_dice: 0.8016 - val_binary_accuracy: 0.9199
# Epoch 32/150
# Epoch 00031: dice improved from 0.82704 to 0.83223, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8046-0.8322---0.hdf5
# Epoch 00031: val_dice improved from 0.80345 to 0.80461, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8046-0.8322---0.hdf5
# 399s - loss: 0.1678 - dice: 0.8322 - binary_accuracy: 0.9297 - val_loss: 0.1954 - val_dice: 0.8046 - val_binary_accuracy: 0.9192
# Epoch 33/150
# Epoch 00032: dice improved from 0.83223 to 0.83319, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8008-0.8332---0.hdf5
# Epoch 00032: val_dice did not improve
# 396s - loss: 0.1668 - dice: 0.8332 - binary_accuracy: 0.9293 - val_loss: 0.1992 - val_dice: 0.8008 - val_binary_accuracy: 0.9164
# Epoch 34/150
# Epoch 00033: dice improved from 0.83319 to 0.83580, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8064-0.8358---0.hdf5
# Epoch 00033: val_dice improved from 0.80461 to 0.80638, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8064-0.8358---0.hdf5
# 399s - loss: 0.1642 - dice: 0.8358 - binary_accuracy: 0.9308 - val_loss: 0.1936 - val_dice: 0.8064 - val_binary_accuracy: 0.9220
# Epoch 35/150
# Epoch 00034: dice improved from 0.83580 to 0.83997, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8095-0.8400---0.hdf5
# Epoch 00034: val_dice improved from 0.80638 to 0.80950, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8095-0.8400---0.hdf5
# 399s - loss: 0.1600 - dice: 0.8400 - binary_accuracy: 0.9328 - val_loss: 0.1905 - val_dice: 0.8095 - val_binary_accuracy: 0.9237
# Epoch 36/150
# Epoch 00035: dice did not improve
# Epoch 00035: val_dice did not improve
# 393s - loss: 0.1624 - dice: 0.8376 - binary_accuracy: 0.9317 - val_loss: 0.2309 - val_dice: 0.7691 - val_binary_accuracy: 0.9027
# Epoch 37/150
# Epoch 00036: dice did not improve
# Epoch 00036: val_dice did not improve
# 393s - loss: 0.1715 - dice: 0.8285 - binary_accuracy: 0.9280 - val_loss: 0.1918 - val_dice: 0.8082 - val_binary_accuracy: 0.9221
# Epoch 38/150
# Epoch 00037: dice improved from 0.83997 to 0.84406, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8098-0.8441---0.hdf5
# Epoch 00037: val_dice improved from 0.80950 to 0.80982, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8098-0.8441---0.hdf5
# 399s - loss: 0.1559 - dice: 0.8441 - binary_accuracy: 0.9347 - val_loss: 0.1902 - val_dice: 0.8098 - val_binary_accuracy: 0.9244
# Epoch 39/150
# Epoch 00038: dice improved from 0.84406 to 0.84555, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8088-0.8455---0.hdf5
# Epoch 00038: val_dice did not improve
# 396s - loss: 0.1545 - dice: 0.8455 - binary_accuracy: 0.9351 - val_loss: 0.1912 - val_dice: 0.8088 - val_binary_accuracy: 0.9225
# Epoch 40/150
# Epoch 00039: dice improved from 0.84555 to 0.84925, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8056-0.8493---0.hdf5
# Epoch 00039: val_dice did not improve
# 396s - loss: 0.1507 - dice: 0.8493 - binary_accuracy: 0.9369 - val_loss: 0.1944 - val_dice: 0.8056 - val_binary_accuracy: 0.9187
# Epoch 41/150
# Epoch 00040: dice did not improve
# Epoch 00040: val_dice did not improve
# 393s - loss: 0.1510 - dice: 0.8490 - binary_accuracy: 0.9365 - val_loss: 0.1965 - val_dice: 0.8035 - val_binary_accuracy: 0.9170
# Epoch 42/150
#
# Epoch 00041: reducing learning rate to 0.00124999997206.
# Epoch 00041: dice improved from 0.84925 to 0.85409, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8079-0.8541---0.hdf5
# Epoch 00041: val_dice did not improve
# 396s - loss: 0.1459 - dice: 0.8541 - binary_accuracy: 0.9386 - val_loss: 0.1921 - val_dice: 0.8079 - val_binary_accuracy: 0.9219
# Epoch 43/150
# Epoch 00042: dice improved from 0.85409 to 0.86034, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8107-0.8603---0.hdf5
# Epoch 00042: val_dice improved from 0.80982 to 0.81074, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8107-0.8603---0.hdf5
# 399s - loss: 0.1397 - dice: 0.8603 - binary_accuracy: 0.9417 - val_loss: 0.1893 - val_dice: 0.8107 - val_binary_accuracy: 0.9238
# Epoch 44/150
# Epoch 00043: dice improved from 0.86034 to 0.86357, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8112-0.8636---0.hdf5
# Epoch 00043: val_dice improved from 0.81074 to 0.81116, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8112-0.8636---0.hdf5
# 399s - loss: 0.1364 - dice: 0.8636 - binary_accuracy: 0.9431 - val_loss: 0.1888 - val_dice: 0.8112 - val_binary_accuracy: 0.9248
# Epoch 45/150
# Epoch 00044: dice improved from 0.86357 to 0.86589, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8123-0.8659---0.hdf5
# Epoch 00044: val_dice improved from 0.81116 to 0.81226, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8123-0.8659---0.hdf5
# 399s - loss: 0.1341 - dice: 0.8659 - binary_accuracy: 0.9440 - val_loss: 0.1877 - val_dice: 0.8123 - val_binary_accuracy: 0.9250
# Epoch 46/150
# Epoch 00045: dice improved from 0.86589 to 0.86711, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8116-0.8671---0.hdf5
# Epoch 00045: val_dice did not improve
# 396s - loss: 0.1329 - dice: 0.8671 - binary_accuracy: 0.9447 - val_loss: 0.1884 - val_dice: 0.8116 - val_binary_accuracy: 0.9261
# Epoch 47/150
# Epoch 00046: dice improved from 0.86711 to 0.86732, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8128-0.8673---0.hdf5
# Epoch 00046: val_dice improved from 0.81226 to 0.81279, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8128-0.8673---0.hdf5
# 400s - loss: 0.1327 - dice: 0.8673 - binary_accuracy: 0.9446 - val_loss: 0.1872 - val_dice: 0.8128 - val_binary_accuracy: 0.9268
# Epoch 48/150
# Epoch 00047: dice improved from 0.86732 to 0.86905, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8133-0.8691---0.hdf5
# Epoch 00047: val_dice improved from 0.81279 to 0.81327, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8133-0.8691---0.hdf5
# 399s - loss: 0.1309 - dice: 0.8691 - binary_accuracy: 0.9451 - val_loss: 0.1867 - val_dice: 0.8133 - val_binary_accuracy: 0.9269
# Epoch 49/150
# Epoch 00048: dice improved from 0.86905 to 0.86937, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8116-0.8694---0.hdf5
# Epoch 00048: val_dice did not improve
# 396s - loss: 0.1306 - dice: 0.8694 - binary_accuracy: 0.9452 - val_loss: 0.1884 - val_dice: 0.8116 - val_binary_accuracy: 0.9254
# Epoch 50/150
# Epoch 00049: dice improved from 0.86937 to 0.87070, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8140-0.8707---0.hdf5
# Epoch 00049: val_dice improved from 0.81327 to 0.81404, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8140-0.8707---0.hdf5
# 399s - loss: 0.1293 - dice: 0.8707 - binary_accuracy: 0.9458 - val_loss: 0.1860 - val_dice: 0.8140 - val_binary_accuracy: 0.9280
# Epoch 51/150
# Epoch 00050: dice did not improve
# Epoch 00050: val_dice did not improve
# 393s - loss: 0.1380 - dice: 0.8620 - binary_accuracy: 0.9428 - val_loss: 0.1870 - val_dice: 0.8130 - val_binary_accuracy: 0.9257
# Epoch 52/150
# Epoch 00051: dice improved from 0.87070 to 0.87156, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8070-0.8716---0.hdf5
# Epoch 00051: val_dice did not improve
# 396s - loss: 0.1284 - dice: 0.8716 - binary_accuracy: 0.9462 - val_loss: 0.1930 - val_dice: 0.8070 - val_binary_accuracy: 0.9270
# Epoch 53/150
# Epoch 00052: dice did not improve
# Epoch 00052: val_dice did not improve
# 393s - loss: 0.1301 - dice: 0.8699 - binary_accuracy: 0.9449 - val_loss: 0.1875 - val_dice: 0.8125 - val_binary_accuracy: 0.9261
# Epoch 54/150
#
# Epoch 00053: reducing learning rate to 0.00062499998603.
# Epoch 00053: dice did not improve
# Epoch 00053: val_dice did not improve
# 393s - loss: 0.1288 - dice: 0.8712 - binary_accuracy: 0.9463 - val_loss: 0.1936 - val_dice: 0.8064 - val_binary_accuracy: 0.9236
# Epoch 55/150
# Epoch 00054: dice improved from 0.87156 to 0.87252, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8104-0.8725---0.hdf5
# Epoch 00054: val_dice did not improve
# 396s - loss: 0.1275 - dice: 0.8725 - binary_accuracy: 0.9474 - val_loss: 0.1896 - val_dice: 0.8104 - val_binary_accuracy: 0.9251
# Epoch 56/150
# Epoch 00055: dice improved from 0.87252 to 0.87852, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8110-0.8785---0.hdf5
# Epoch 00055: val_dice did not improve
# 396s - loss: 0.1215 - dice: 0.8785 - binary_accuracy: 0.9490 - val_loss: 0.1890 - val_dice: 0.8110 - val_binary_accuracy: 0.9258
# Epoch 57/150
#
# Epoch 00056: reducing learning rate to 0.000312499993015.
# Epoch 00056: dice improved from 0.87852 to 0.88228, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8108-0.8823---0.hdf5
# Epoch 00056: val_dice did not improve
# 396s - loss: 0.1177 - dice: 0.8823 - binary_accuracy: 0.9501 - val_loss: 0.1892 - val_dice: 0.8108 - val_binary_accuracy: 0.9255
# Epoch 58/150
# Epoch 00057: dice improved from 0.88228 to 0.88300, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8109-0.8830---0.hdf5
# Epoch 00057: val_dice did not improve
# 396s - loss: 0.1170 - dice: 0.8830 - binary_accuracy: 0.9507 - val_loss: 0.1891 - val_dice: 0.8109 - val_binary_accuracy: 0.9262
# Epoch 59/150
# Epoch 00058: dice improved from 0.88300 to 0.88455, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8116-0.8845---0.hdf5
# Epoch 00058: val_dice did not improve
# 396s - loss: 0.1155 - dice: 0.8845 - binary_accuracy: 0.9511 - val_loss: 0.1884 - val_dice: 0.8116 - val_binary_accuracy: 0.9271
# Epoch 60/150
#
# Epoch 00059: reducing learning rate to 0.000156249996508.
# Epoch 00059: dice improved from 0.88455 to 0.88503, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8104-0.8850---0.hdf5
# Epoch 00059: val_dice did not improve
# 396s - loss: 0.1150 - dice: 0.8850 - binary_accuracy: 0.9514 - val_loss: 0.1896 - val_dice: 0.8104 - val_binary_accuracy: 0.9264
# Epoch 61/150
# Epoch 00060: dice improved from 0.88503 to 0.88626, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8091-0.8863---0.hdf5
# Epoch 00060: val_dice did not improve
# 396s - loss: 0.1137 - dice: 0.8863 - binary_accuracy: 0.9518 - val_loss: 0.1909 - val_dice: 0.8091 - val_binary_accuracy: 0.9250
# Epoch 00060: early stopping
# 2017-07-29 04:36:29.118116 ------------> 1
# Train on 806 samples, validate on 202 samples
# Epoch 1/150
# Epoch 00000: dice improved from -inf to 0.55027, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.6583-0.5503---1.hdf5
# Epoch 00000: val_dice improved from -inf to 0.65831, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.6583-0.5503---1.hdf5
# 439s - loss: 0.4497 - dice: 0.5503 - binary_accuracy: 0.6362 - val_loss: 0.3417 - val_dice: 0.6583 - val_binary_accuracy: 0.8181
# Epoch 2/150
# Epoch 00001: dice improved from 0.55027 to 0.65523, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.6949-0.6552---1.hdf5
# Epoch 00001: val_dice improved from 0.65831 to 0.69491, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.6949-0.6552---1.hdf5
# 404s - loss: 0.3448 - dice: 0.6552 - binary_accuracy: 0.8184 - val_loss: 0.3051 - val_dice: 0.6949 - val_binary_accuracy: 0.8630
# Epoch 3/150
# Epoch 00002: dice improved from 0.65523 to 0.69108, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.6955-0.6911---1.hdf5
# Epoch 00002: val_dice improved from 0.69491 to 0.69552, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.6955-0.6911---1.hdf5
# 401s - loss: 0.3089 - dice: 0.6911 - binary_accuracy: 0.8502 - val_loss: 0.3045 - val_dice: 0.6955 - val_binary_accuracy: 0.8434
# Epoch 4/150
# Epoch 00003: dice improved from 0.69108 to 0.71147, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7295-0.7115---1.hdf5
# Epoch 00003: val_dice improved from 0.69552 to 0.72952, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7295-0.7115---1.hdf5
# 401s - loss: 0.2885 - dice: 0.7115 - binary_accuracy: 0.8629 - val_loss: 0.2705 - val_dice: 0.7295 - val_binary_accuracy: 0.8715
# Epoch 5/150
# Epoch 00004: dice improved from 0.71147 to 0.72592, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7339-0.7259---1.hdf5
# Epoch 00004: val_dice improved from 0.72952 to 0.73387, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7339-0.7259---1.hdf5
# 400s - loss: 0.2741 - dice: 0.7259 - binary_accuracy: 0.8724 - val_loss: 0.2661 - val_dice: 0.7339 - val_binary_accuracy: 0.8770
# Epoch 6/150
# Epoch 00005: dice improved from 0.72592 to 0.74062, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7352-0.7406---1.hdf5
# Epoch 00005: val_dice improved from 0.73387 to 0.73520, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7352-0.7406---1.hdf5
# 400s - loss: 0.2594 - dice: 0.7406 - binary_accuracy: 0.8827 - val_loss: 0.2648 - val_dice: 0.7352 - val_binary_accuracy: 0.8725
# Epoch 7/150
# Epoch 00006: dice improved from 0.74062 to 0.74919, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7505-0.7492---1.hdf5
# Epoch 00006: val_dice improved from 0.73520 to 0.75050, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7505-0.7492---1.hdf5
# 400s - loss: 0.2508 - dice: 0.7492 - binary_accuracy: 0.8877 - val_loss: 0.2495 - val_dice: 0.7505 - val_binary_accuracy: 0.8890
# Epoch 8/150
# Epoch 00007: dice did not improve
# Epoch 00007: val_dice did not improve
# 394s - loss: 0.2538 - dice: 0.7462 - binary_accuracy: 0.8849 - val_loss: 0.2531 - val_dice: 0.7469 - val_binary_accuracy: 0.8868
# Epoch 9/150
# Epoch 00008: dice improved from 0.74919 to 0.75146, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7491-0.7515---1.hdf5
# Epoch 00008: val_dice did not improve
# 396s - loss: 0.2485 - dice: 0.7515 - binary_accuracy: 0.8887 - val_loss: 0.2509 - val_dice: 0.7491 - val_binary_accuracy: 0.8889
# Epoch 10/150
# Epoch 00009: dice improved from 0.75146 to 0.75760, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7295-0.7576---1.hdf5
# Epoch 00009: val_dice did not improve
# 396s - loss: 0.2424 - dice: 0.7576 - binary_accuracy: 0.8913 - val_loss: 0.2705 - val_dice: 0.7295 - val_binary_accuracy: 0.8673
# Epoch 11/150
# Epoch 00010: dice improved from 0.75760 to 0.76303, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7698-0.7630---1.hdf5
# Epoch 00010: val_dice improved from 0.75050 to 0.76975, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7698-0.7630---1.hdf5
# 399s - loss: 0.2370 - dice: 0.7630 - binary_accuracy: 0.8957 - val_loss: 0.2302 - val_dice: 0.7698 - val_binary_accuracy: 0.9004
# Epoch 12/150
# Epoch 00011: dice improved from 0.76303 to 0.77175, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7512-0.7718---1.hdf5
# Epoch 00011: val_dice did not improve
# 396s - loss: 0.2282 - dice: 0.7718 - binary_accuracy: 0.9005 - val_loss: 0.2488 - val_dice: 0.7512 - val_binary_accuracy: 0.8810
# Epoch 13/150
# Epoch 00012: dice improved from 0.77175 to 0.77721, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7727-0.7772---1.hdf5
# Epoch 00012: val_dice improved from 0.76975 to 0.77271, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7727-0.7772---1.hdf5
# 399s - loss: 0.2228 - dice: 0.7772 - binary_accuracy: 0.9039 - val_loss: 0.2273 - val_dice: 0.7727 - val_binary_accuracy: 0.9010
# Epoch 14/150
# Epoch 00013: dice improved from 0.77721 to 0.78055, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7750-0.7806---1.hdf5
# Epoch 00013: val_dice improved from 0.77271 to 0.77501, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7750-0.7806---1.hdf5
# 403s - loss: 0.2194 - dice: 0.7806 - binary_accuracy: 0.9039 - val_loss: 0.2250 - val_dice: 0.7750 - val_binary_accuracy: 0.9032
# Epoch 15/150
# Epoch 00014: dice did not improve
# Epoch 00014: val_dice improved from 0.77501 to 0.78175, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7817-0.7803---1.hdf5
# 396s - loss: 0.2197 - dice: 0.7803 - binary_accuracy: 0.9046 - val_loss: 0.2183 - val_dice: 0.7817 - val_binary_accuracy: 0.9066
# Epoch 16/150
# Epoch 00015: dice did not improve
# Epoch 00015: val_dice did not improve
# 393s - loss: 0.2210 - dice: 0.7790 - binary_accuracy: 0.9054 - val_loss: 0.2189 - val_dice: 0.7811 - val_binary_accuracy: 0.9046
# Epoch 17/150
# Epoch 00016: dice improved from 0.78055 to 0.78834, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7806-0.7883---1.hdf5
# Epoch 00016: val_dice did not improve
# 396s - loss: 0.2117 - dice: 0.7883 - binary_accuracy: 0.9074 - val_loss: 0.2194 - val_dice: 0.7806 - val_binary_accuracy: 0.9018
# Epoch 18/150
# Epoch 00017: dice improved from 0.78834 to 0.79177, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7868-0.7918---1.hdf5
# Epoch 00017: val_dice improved from 0.78175 to 0.78681, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7868-0.7918---1.hdf5
# 399s - loss: 0.2082 - dice: 0.7918 - binary_accuracy: 0.9105 - val_loss: 0.2132 - val_dice: 0.7868 - val_binary_accuracy: 0.9116
# Epoch 19/150
# Epoch 00018: dice did not improve
# Epoch 00018: val_dice did not improve
# 393s - loss: 0.2113 - dice: 0.7887 - binary_accuracy: 0.9089 - val_loss: 0.2218 - val_dice: 0.7782 - val_binary_accuracy: 0.9025
# Epoch 20/150
# Epoch 00019: dice improved from 0.79177 to 0.79719, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7967-0.7972---1.hdf5
# Epoch 00019: val_dice improved from 0.78681 to 0.79673, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7967-0.7972---1.hdf5
# 399s - loss: 0.2028 - dice: 0.7972 - binary_accuracy: 0.9136 - val_loss: 0.2033 - val_dice: 0.7967 - val_binary_accuracy: 0.9163
# Epoch 21/150
# Epoch 00020: dice improved from 0.79719 to 0.79843, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7834-0.7984---1.hdf5
# Epoch 00020: val_dice did not improve
# 396s - loss: 0.2016 - dice: 0.7984 - binary_accuracy: 0.9140 - val_loss: 0.2166 - val_dice: 0.7834 - val_binary_accuracy: 0.9061
# Epoch 22/150
# Epoch 00021: dice improved from 0.79843 to 0.80003, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7596-0.8000---1.hdf5
# Epoch 00021: val_dice did not improve
# 396s - loss: 0.2000 - dice: 0.8000 - binary_accuracy: 0.9149 - val_loss: 0.2404 - val_dice: 0.7596 - val_binary_accuracy: 0.8944
# Epoch 23/150
# Epoch 00022: dice did not improve
# Epoch 00022: val_dice did not improve
# 393s - loss: 0.2001 - dice: 0.7999 - binary_accuracy: 0.9143 - val_loss: 0.2045 - val_dice: 0.7955 - val_binary_accuracy: 0.9103
# Epoch 24/150
#
# Epoch 00023: reducing learning rate to 0.00499999988824.
# Epoch 00023: dice improved from 0.80003 to 0.80551, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.7947-0.8055---1.hdf5
# Epoch 00023: val_dice did not improve
# 396s - loss: 0.1945 - dice: 0.8055 - binary_accuracy: 0.9171 - val_loss: 0.2053 - val_dice: 0.7947 - val_binary_accuracy: 0.9119
# Epoch 25/150
# Epoch 00024: dice improved from 0.80551 to 0.81942, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8013-0.8194---1.hdf5
# Epoch 00024: val_dice improved from 0.79673 to 0.80129, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8013-0.8194---1.hdf5
# 398s - loss: 0.1806 - dice: 0.8194 - binary_accuracy: 0.9248 - val_loss: 0.1987 - val_dice: 0.8013 - val_binary_accuracy: 0.9130
# Epoch 26/150
# Epoch 00025: dice did not improve
# Epoch 00025: val_dice improved from 0.80129 to 0.80393, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8039-0.8145---1.hdf5
# 403s - loss: 0.1855 - dice: 0.8145 - binary_accuracy: 0.9210 - val_loss: 0.1961 - val_dice: 0.8039 - val_binary_accuracy: 0.9160
# Epoch 27/150
# Epoch 00026: dice did not improve
# Epoch 00026: val_dice did not improve
# 395s - loss: 0.1836 - dice: 0.8164 - binary_accuracy: 0.9231 - val_loss: 0.1962 - val_dice: 0.8038 - val_binary_accuracy: 0.9188
# Epoch 28/150
# Epoch 00027: dice improved from 0.81942 to 0.82340, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8111-0.8234---1.hdf5
# Epoch 00027: val_dice improved from 0.80393 to 0.81115, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8111-0.8234---1.hdf5
# 398s - loss: 0.1766 - dice: 0.8234 - binary_accuracy: 0.9257 - val_loss: 0.1889 - val_dice: 0.8111 - val_binary_accuracy: 0.9217
# Epoch 29/150
# Epoch 00028: dice did not improve
# Epoch 00028: val_dice did not improve
# 393s - loss: 0.1795 - dice: 0.8205 - binary_accuracy: 0.9243 - val_loss: 0.2021 - val_dice: 0.7979 - val_binary_accuracy: 0.9146
# Epoch 30/150
# Epoch 00029: dice improved from 0.82340 to 0.82383, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8066-0.8238---1.hdf5
# Epoch 00029: val_dice did not improve
# 395s - loss: 0.1762 - dice: 0.8238 - binary_accuracy: 0.9260 - val_loss: 0.1934 - val_dice: 0.8066 - val_binary_accuracy: 0.9180
# Epoch 31/150
# Epoch 00030: dice improved from 0.82383 to 0.82916, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8098-0.8292---1.hdf5
# Epoch 00030: val_dice did not improve
# 396s - loss: 0.1708 - dice: 0.8292 - binary_accuracy: 0.9288 - val_loss: 0.1902 - val_dice: 0.8098 - val_binary_accuracy: 0.9224
# Epoch 32/150
#
# Epoch 00031: reducing learning rate to 0.00249999994412.
# Epoch 00031: dice improved from 0.82916 to 0.83156, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8068-0.8316---1.hdf5
# Epoch 00031: val_dice did not improve
# 396s - loss: 0.1684 - dice: 0.8316 - binary_accuracy: 0.9275 - val_loss: 0.1932 - val_dice: 0.8068 - val_binary_accuracy: 0.9182
# Epoch 33/150
# Epoch 00032: dice improved from 0.83156 to 0.83875, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8155-0.8387---1.hdf5
# Epoch 00032: val_dice improved from 0.81115 to 0.81552, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8155-0.8387---1.hdf5
# 400s - loss: 0.1613 - dice: 0.8387 - binary_accuracy: 0.9310 - val_loss: 0.1845 - val_dice: 0.8155 - val_binary_accuracy: 0.9207
# Epoch 34/150
# Epoch 00033: dice improved from 0.83875 to 0.84360, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8151-0.8436---1.hdf5
# Epoch 00033: val_dice did not improve
# 396s - loss: 0.1564 - dice: 0.8436 - binary_accuracy: 0.9348 - val_loss: 0.1849 - val_dice: 0.8151 - val_binary_accuracy: 0.9223
# Epoch 35/150
# Epoch 00034: dice did not improve
# Epoch 00034: val_dice did not improve
# 393s - loss: 0.1571 - dice: 0.8429 - binary_accuracy: 0.9342 - val_loss: 0.1854 - val_dice: 0.8146 - val_binary_accuracy: 0.9228
# Epoch 36/150
# Epoch 00035: dice improved from 0.84360 to 0.84767, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8190-0.8477---1.hdf5
# Epoch 00035: val_dice improved from 0.81552 to 0.81896, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8190-0.8477---1.hdf5
# 399s - loss: 0.1523 - dice: 0.8477 - binary_accuracy: 0.9374 - val_loss: 0.1810 - val_dice: 0.8190 - val_binary_accuracy: 0.9249
# Epoch 37/150
# Epoch 00036: dice improved from 0.84767 to 0.84944, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8191-0.8494---1.hdf5
# Epoch 00036: val_dice improved from 0.81896 to 0.81909, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8191-0.8494---1.hdf5
# 401s - loss: 0.1506 - dice: 0.8494 - binary_accuracy: 0.9367 - val_loss: 0.1809 - val_dice: 0.8191 - val_binary_accuracy: 0.9226
# Epoch 38/150
# Epoch 00037: dice improved from 0.84944 to 0.85005, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8198-0.8500---1.hdf5
# Epoch 00037: val_dice improved from 0.81909 to 0.81979, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8198-0.8500---1.hdf5
# 400s - loss: 0.1500 - dice: 0.8500 - binary_accuracy: 0.9370 - val_loss: 0.1802 - val_dice: 0.8198 - val_binary_accuracy: 0.9258
# Epoch 39/150
# Epoch 00038: dice improved from 0.85005 to 0.85162, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8224-0.8516---1.hdf5
# Epoch 00038: val_dice improved from 0.81979 to 0.82244, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8224-0.8516---1.hdf5
# 398s - loss: 0.1484 - dice: 0.8516 - binary_accuracy: 0.9375 - val_loss: 0.1776 - val_dice: 0.8224 - val_binary_accuracy: 0.9266
# Epoch 40/150
# Epoch 00039: dice improved from 0.85162 to 0.85454, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8171-0.8545---1.hdf5
# Epoch 00039: val_dice did not improve
# 396s - loss: 0.1455 - dice: 0.8545 - binary_accuracy: 0.9403 - val_loss: 0.1829 - val_dice: 0.8171 - val_binary_accuracy: 0.9231
# Epoch 41/150
# Epoch 00040: dice improved from 0.85454 to 0.85698, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8199-0.8570---1.hdf5
# Epoch 00040: val_dice did not improve
# 396s - loss: 0.1430 - dice: 0.8570 - binary_accuracy: 0.9404 - val_loss: 0.1801 - val_dice: 0.8199 - val_binary_accuracy: 0.9236
# Epoch 42/150
# Epoch 00041: dice improved from 0.85698 to 0.85820, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8154-0.8582---1.hdf5
# Epoch 00041: val_dice did not improve
# 396s - loss: 0.1418 - dice: 0.8582 - binary_accuracy: 0.9410 - val_loss: 0.1846 - val_dice: 0.8154 - val_binary_accuracy: 0.9230
# Epoch 43/150
#
# Epoch 00042: reducing learning rate to 0.00124999997206.
# Epoch 00042: dice improved from 0.85820 to 0.85901, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8221-0.8590---1.hdf5
# Epoch 00042: val_dice did not improve
# 396s - loss: 0.1410 - dice: 0.8590 - binary_accuracy: 0.9422 - val_loss: 0.1779 - val_dice: 0.8221 - val_binary_accuracy: 0.9271
# Epoch 44/150
# Epoch 00043: dice improved from 0.85901 to 0.86415, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8193-0.8642---1.hdf5
# Epoch 00043: val_dice did not improve
# 396s - loss: 0.1358 - dice: 0.8642 - binary_accuracy: 0.9434 - val_loss: 0.1807 - val_dice: 0.8193 - val_binary_accuracy: 0.9250
# Epoch 45/150
# Epoch 00044: dice improved from 0.86415 to 0.86555, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8217-0.8655---1.hdf5
# Epoch 00044: val_dice did not improve
# 396s - loss: 0.1345 - dice: 0.8655 - binary_accuracy: 0.9444 - val_loss: 0.1783 - val_dice: 0.8217 - val_binary_accuracy: 0.9270
# Epoch 46/150
#
# Epoch 00045: reducing learning rate to 0.00062499998603.
# Epoch 00045: dice improved from 0.86555 to 0.86735, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8174-0.8674---1.hdf5
# Epoch 00045: val_dice did not improve
# 396s - loss: 0.1326 - dice: 0.8674 - binary_accuracy: 0.9448 - val_loss: 0.1826 - val_dice: 0.8174 - val_binary_accuracy: 0.9238
# Epoch 47/150
# Epoch 00046: dice improved from 0.86735 to 0.86937, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8186-0.8694---1.hdf5
# Epoch 00046: val_dice did not improve
# 396s - loss: 0.1306 - dice: 0.8694 - binary_accuracy: 0.9456 - val_loss: 0.1814 - val_dice: 0.8186 - val_binary_accuracy: 0.9244
# Epoch 48/150
# Epoch 00047: dice improved from 0.86937 to 0.87040, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8197-0.8704---1.hdf5
# Epoch 00047: val_dice did not improve
# 396s - loss: 0.1296 - dice: 0.8704 - binary_accuracy: 0.9464 - val_loss: 0.1803 - val_dice: 0.8197 - val_binary_accuracy: 0.9261
# Epoch 49/150
#
# Epoch 00048: reducing learning rate to 0.000312499993015.
# Epoch 00048: dice improved from 0.87040 to 0.87157, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8160-0.8716---1.hdf5
# Epoch 00048: val_dice did not improve
# 396s - loss: 0.1284 - dice: 0.8716 - binary_accuracy: 0.9465 - val_loss: 0.1840 - val_dice: 0.8160 - val_binary_accuracy: 0.9231
# Epoch 50/150
# Epoch 00049: dice improved from 0.87157 to 0.87250, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8184-0.8725---1.hdf5
# Epoch 00049: val_dice did not improve
# 396s - loss: 0.1275 - dice: 0.8725 - binary_accuracy: 0.9471 - val_loss: 0.1816 - val_dice: 0.8184 - val_binary_accuracy: 0.9254
# Epoch 00049: early stopping
# 2017-07-29 10:13:55.017979 ------------> 2
# Train on 806 samples, validate on 202 samples
# Epoch 1/150
# Epoch 00000: dice improved from -inf to 0.43663, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.4421-0.4366---2.hdf5
# Epoch 00000: val_dice improved from -inf to 0.44205, saving model to ../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.4421-0.4366---2.hdf5
# 415s - loss: 0.5634 - dice: 0.4366 - binary_accuracy: 0.3550 - val_loss: 0.5579 - val_dice: 0.4421 - val_binary_accuracy: 0.3275
# Epoch 2/150
# Epoch 00001: dice did not improve
# Epoch 00001: val_dice did not improve
# 391s - loss: 0.5672 - dice: 0.4328 - binary_accuracy: 0.3180 - val_loss: 0.5579 - val_dice: 0.4421 - val_binary_accuracy: 0.3275
# Epoch 3/150
# Epoch 00002: dice did not improve
# Epoch 00002: val_dice did not improve
# 392s - loss: 0.5672 - dice: 0.4328 - binary_accuracy: 0.3180 - val_loss: 0.5579 - val_dice: 0.4421 - val_binary_accuracy: 0.3275
# Epoch 4/150
# Epoch 00003: dice did not improve
# Epoch 00003: val_dice did not improve
# 392s - loss: 0.5672 - dice: 0.4328 - binary_accuracy: 0.3180 - val_loss: 0.5579 - val_dice: 0.4421 - val_binary_accuracy: 0.3275
# Epoch 5/150
#
# Epoch 00004: reducing learning rate to 0.00499999988824.
#
# Epoch 00004: reducing learning rate to 0.00249999994412.
# Epoch 00004: dice did not improve
# Epoch 00004: val_dice did not improve
# 392s - loss: 0.5672 - dice: 0.4328 - binary_accuracy: 0.3180 - val_loss: 0.5579 - val_dice: 0.4421 - val_binary_accuracy: 0.3275
# Epoch 6/150
# Epoch 00005: dice did not improve
# Epoch 00005: val_dice did not improve
# 391s - loss: 0.5672 - dice: 0.4328 - binary_accuracy: 0.3180 - val_loss: 0.5579 - val_dice: 0.4421 - val_binary_accuracy: 0.3275
# Epoch 7/150
# Epoch 00006: dice did not improve
# Epoch 00006: val_dice did not improve
# 392s - loss: 0.5672 - dice: 0.4328 - binary_accuracy: 0.3180 - val_loss: 0.5579 - val_dice: 0.4421 - val_binary_accuracy: 0.3275
# Epoch 8/150
#
# Epoch 00007: reducing learning rate to 0.00124999997206.
#
# Epoch 00007: reducing learning rate to 0.00062499998603.
# Epoch 00007: dice did not improve
# Epoch 00007: val_dice did not improve
# 392s - loss: 0.5672 - dice: 0.4328 - binary_accuracy: 0.3180 - val_loss: 0.5579 - val_dice: 0.4421 - val_binary_accuracy: 0.3275
# Epoch 9/150
# Epoch 00008: dice did not improve
# Epoch 00008: val_dice did not improve
# 391s - loss: 0.5672 - dice: 0.4328 - binary_accuracy: 0.3180 - val_loss: 0.5579 - val_dice: 0.4421 - val_binary_accuracy: 0.3275
# Epoch 10/150
# Epoch 00009: dice did not improve
# Epoch 00009: val_dice did not improve
# 391s - loss: 0.5672 - dice: 0.4328 - binary_accuracy: 0.3180 - val_loss: 0.5579 - val_dice: 0.4421 - val_binary_accuracy: 0.3275
# Epoch 11/150
#
# Epoch 00010: reducing learning rate to 0.000312499993015.
#
# Epoch 00010: reducing learning rate to 0.000156249996508.
# Epoch 00010: dice did not improve
# Epoch 00010: val_dice did not improve
# 392s - loss: 0.5672 - dice: 0.4328 - binary_accuracy: 0.3180 - val_loss: 0.5579 - val_dice: 0.4421 - val_binary_accuracy: 0.3275
# Epoch 12/150
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-d929dcb12cf3> in <module>()
#      47                         #callbacks=[early_stopping,reduce_lr1,reduce_lr2,checkpoint],
#      48                         callbacks=[reduce_lr1,reduce_lr2,checkpoint1,checkpoint2,early_stopping],
# ---> 49                         verbose=verbose)
#      50
#      51 print(datetime.datetime.now())
#
# /home/boba/anaconda2/envs/tensorflow-gpu/lib/python2.7/site-packages/keras/engine/training.pyc in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#    1428                               val_f=val_f, val_ins=val_ins, shuffle=shuffle,
#    1429                               callback_metrics=callback_metrics,
# -> 1430                               initial_epoch=initial_epoch)
#    1431
#    1432     def evaluate(self, x, y, batch_size=32, verbose=1, sample_weight=None):
#
# /home/boba/anaconda2/envs/tensorflow-gpu/lib/python2.7/site-packages/keras/engine/training.pyc in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch)
#    1077                 batch_logs['size'] = len(batch_ids)
#    1078                 callbacks.on_batch_begin(batch_index, batch_logs)
# -> 1079                 outs = f(ins_batch)
#    1080                 if not isinstance(outs, list):
#    1081                     outs = [outs]
#
# /home/boba/anaconda2/envs/tensorflow-gpu/lib/python2.7/site-packages/keras/backend/tensorflow_backend.pyc in __call__(self, inputs)
#    2266         updated = session.run(self.outputs + [self.updates_op],
#    2267                               feed_dict=feed_dict,
# -> 2268                               **self.session_kwargs)
#    2269         return updated[:len(self.outputs)]
#    2270
#
# /home/boba/anaconda2/envs/tensorflow-gpu/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     787     try:
#     788       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 789                          run_metadata_ptr)
#     790       if run_metadata:
#     791         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/boba/anaconda2/envs/tensorflow-gpu/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     995     if final_fetches or final_targets:
#     996       results = self._do_run(handle, final_targets, final_fetches,
# --> 997                              feed_dict_string, options, run_metadata)
#     998     else:
#     999       results = []
#
# /home/boba/anaconda2/envs/tensorflow-gpu/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1130     if handle is None:
#    1131       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1132                            target_list, options, run_metadata)
#    1133     else:
#    1134       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/boba/anaconda2/envs/tensorflow-gpu/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1137   def _do_call(self, fn, *args):
#    1138     try:
# -> 1139       return fn(*args)
#    1140     except errors.OpError as e:
#    1141       message = compat.as_text(e.message)
#
# /home/boba/anaconda2/envs/tensorflow-gpu/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1119         return tf_session.TF_Run(session, options,
#    1120                                  feed_dict, fetch_list, target_list,
# -> 1121                                  status, run_metadata)
#    1122
#    1123     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
#!ls ../Temp/TempTempG5M5KFold -la | tail
# !ls ../Temp/TempTempG5M5KFold2 -la | tail
# Out:
# -rwxrwxrwx 1 boba boba 248917128 июл 29 09:54 V1-UNET-val_dice=0.8186-0.8694---1.hdf5
# -rwxrwxrwx 1 boba boba 248917128 июл 29 08:41 V1-UNET-val_dice=0.8190-0.8477---1.hdf5
# -rwxrwxrwx 1 boba boba 248917128 июл 29 08:47 V1-UNET-val_dice=0.8191-0.8494---1.hdf5
# -rwxrwxrwx 1 boba boba 248917128 июл 29 09:34 V1-UNET-val_dice=0.8193-0.8642---1.hdf5
# -rwxrwxrwx 1 boba boba 248917128 июл 29 10:00 V1-UNET-val_dice=0.8197-0.8704---1.hdf5
# -rwxrwxrwx 1 boba boba 248917128 июл 29 08:54 V1-UNET-val_dice=0.8198-0.8500---1.hdf5
# -rwxrwxrwx 1 boba boba 248917128 июл 29 09:14 V1-UNET-val_dice=0.8199-0.8570---1.hdf5
# -rwxrwxrwx 1 boba boba 248917128 июл 29 09:40 V1-UNET-val_dice=0.8217-0.8655---1.hdf5
# -rwxrwxrwx 1 boba boba 248917128 июл 29 09:27 V1-UNET-val_dice=0.8221-0.8590---1.hdf5
# -rwxrwxrwx 1 boba boba 248917128 июл 29 09:01 V1-UNET-val_dice=0.8224-0.8516---1.hdf5

# %%
if 0 : model10 = load_model('../Temp/TrainModel001+G+M/V1-UNET-0.8511.hdf5')
if 0 : model10 = load_model('../Temp/V1-UNET-0.8853.hdf5')
#if 1 : model10 = load_model('../Temp/TempTempM3/V1-UNET-0.9054.hdf5')
if 0 : model10.load_weights('../Temp/TempTempM3/V1-UNET-0.9054.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5/V1-UNET-val_dice=0.7307.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7879-2.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7632-2.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7660-2.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7828-2.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8224-0.8516---1.hdf5') # 769128
if 0 : model10.load_weights('../Temp/TempTempG5M5KFold2/V1-UNET-val_dice=0.8217-0.8655---1.hdf5')

# %%
# %time trP = model10.predict(trX,batch_size=batch_size)
# Out:
# CPU times: user 1min 30s, sys: 22.6 s, total: 1min 53s
# Wall time: 1min 49s

# %%
trP01 = trP
trP01[trP>0.5] =1.0
trP01[trP<=0.5]=0.0
trP01 = trP01.astype(np.uint8)

# %%
if 0 : # Ощутимых результатов не дает, увеличение в +10-100
    times, medianP = 3,5
    for i in range(trP01.shape[0]) :
        for j in range(times) :
            trP01[i,:,:,0] = cv.medianBlur(trP01[i],medianP)

# %%
iii = 0
print(trX[0].shape,trY[0].shape,trP.shape,trP.min(),trP.max())
for ii in range(iii,iii+10) :
    plt.figure(figsize=(15,5))
    plt.subplot(151); plt.imshow(trX[ii,:,:,0],'gray'); 
    plt.subplot(152); plt.imshow(trY[ii,:,:,0],'gray'); 
    plt.subplot(153); plt.imshow(trP[ii,:,:,0],'gray'); 
    plt.subplot(154); plt.imshow(trP01[ii,:,:,0],'gray'); 
    plt.subplot(155); plt.hist(trP[ii,:,:,0].ravel(),bins=50); 
    plt.show()
plt.close()
# Out:
# (512, 512, 3) (512, 512, 1) (1008, 512, 512, 1) 0.0 1.0

# %%
# Calculate F1-micro

# %%
TP = (trY[:,6:506,6:506,0]*trP01[:,6:506,6:506,0]).sum()
TN = ((1.0-trY[:,6:506,6:506,0])*(1.0-trP01[:,6:506,6:506,0])).sum()
FP = ((trY[:,6:506,6:506,0])*(1.0-trP01[:,6:506,6:506,0])).sum()
FN = ((1.0-trY[:,6:506,6:506,0])*(trP01[:,6:506,6:506,0])).sum()

P  = TP/(TP+FP) if (TP+FP)>0.0 else 1.0
R  = TP/(TP+FN) if (TP+FN)>0.0 else 0.0

F1 = 2.0*P*R/(P+R) if (P+R)>0.0 else 0.0

TP,TN,FP,FN,P,R,F1
#P*R,P+R, 2.0*P*R/(P+R)
# Out:
# (79446937.0,
#  156935231.0,
#  5082383.0,
#  10535449.0,
#  0.93987431816557854,
#  0.88291654102170614,
#  0.91050553365170805)

# %%
# Calculate DI- dice.mean()

# %%
dice, XX = [],[]
for i in range(trP.shape[0]) :
    G = trY  [i,6:506,6:506,0].sum()
    S = trP01[i,6:506,6:506,0].sum()
    X = (trY [i,6:506,6:506,0]*trP01[i,6:506,6:506,0]).sum()
    XX.append(X)
    dice.append((2.0*X/(G+S) if G+S>0 else 1.0))
di = (np.array(dice)).mean()
di #,np.array(dice)  #,np.array(XX)
# Out:
# 0.8582560687294305

# %%
plt.hist(np.array(dice),bins=40); plt.show()
plt.plot(np.array(dice)); plt.show()

# %%
1000000*(F1+di)/2.0
# Out:
# 884380.8011905693

# %%
#np.array(dice)<0.4

# %%
# Подготовка test решения

# %%
if flagGray :
    trO, trO0 = [], np.zeros((512,512,1))
else :
    trO, trO0 = [], np.zeros((512,512,3))

for xx in listTest :
    img = cv.imread(os.path.join(dirTest,xx),-1)
    if 1 and (Gauss or Median): 
        for cc in range(img.shape[2]) : 
            if Gauss  : img[:,:,cc] = cv.GaussianBlur(img[:,:,cc],(Gauss,Gauss),0);
            if Median : img[:,:,cc] = cv.medianBlur  (img[:,:,cc],Median);
    #print(img.mean(),msk.mean())
    if flagGray :
        img = cv.cvtColor(img,cv.COLOR_RGB2GRAY);
        trO0[6:506,6:506,0] = img[:,:]/255.0
    else :
        trO0[6:506,6:506,:] = img[:,:,:]/255.0
    trO.append(trO0.copy())
    #print(trX0.mean(),trY0.mean(),trX1[-1].mean(),trY1[-1].mean())

#print([trY[xx].mean() for xx in range(10)])
trO = np.array(trO)

if 1 :
    for cc in range(meanX.shape[0]) : 
        trO[:,6:506,6:506,cc] -= meanX[cc]
    
trO.shape, trO.min(), trO.max()
#[trY[xx].mean() for xx in range(10)]
# Out:
# ((162, 512, 512, 3), -0.64172901643310909, 0.47912580261435694)

# %%
# %time trOP = model10.predict(trO,batch_size=batch_size)
# Out:
# CPU times: user 14.3 s, sys: 3.82 s, total: 18.1 s
# Wall time: 18.6 s

# %%
trOP01 = trOP
trOP01[trOP>0.5] =1.0
trOP01[trOP<=0.5]=0.0

# %%
iii = 40
print(trO[0].shape,trP01[0].shape,trOP01.shape,trOP.min(),trOP.max())
for ii in range(iii,iii+10) :
    plt.figure(figsize=(15,5))
    plt.subplot(141); plt.imshow(trO[ii,:,:,0]); 
    plt.subplot(142); plt.imshow(trOP01[ii,:,:,0],'gray'); 
    plt.subplot(143); plt.imshow(trOP[ii,:,:,0],'gray'); 
    plt.subplot(144); plt.hist(trOP[ii,:,:,0].ravel(),bins=50); 
    plt.show()
plt.close()
# Out:
# (512, 512, 3) (512, 512, 1) (162, 512, 512, 1) 0.0 1.0

# %%
# Формирование выходной директории

# %%
def convert_to_binary(truth_png_file, truth_txt_file):
    im = Image.open(truth_png_file) #Can be many different formats.
    pix = im.load()
    with open(truth_txt_file, 'w') as out:
        for x in xrange(500):
            for y in xrange(500):
                out.write(str(int(pix[x, y] > 0)))
            out.write('\n')

if not os.path.exists('../Temp/random_submission'):
    os.makedirs('../Temp/random_submission')

# Training
for i in range(len(listTrain)) :
    fn = listTrain[i]
    truth_txt_file = '../Temp/random_submission/' + fn.split('.')[0] + '_mask.txt'
    with open(truth_txt_file, 'w') as out:
        for x in xrange(500):
            for y in xrange(500):
                out.write(str(int(trP01[i,y+6, x+6] > 0.0)))
            out.write('\n')
    out.close()
    
# Testing
for i in range(len(listTest)) :
    fn = listTest[i]
    truth_txt_file = '../Temp/random_submission/' + fn.split('.')[0] + '_mask.txt'
    with open(truth_txt_file, 'w') as out:
        for x in xrange(500):
            for y in xrange(500):
                out.write(str(int(trOP01[i,y+6, x+6] > 0.0)))
            out.write('\n')
    out.close()

# %%
import shutil

# %%
xx=shutil.make_archive('../Result/topcoderkonica','zip','../Temp/random_submission')
xx
# Out:
# '/media/boba/DATA/boba/Working/TopCoder/2017-07-25-Konica-Minolta/Result/topcoderkonica.zip'

# %%
# !ls ../Temp -la
# Out:
# total 4610508
# drwxrwxrwx 1 boba boba      4096 июл 26 10:58 .
# drwxrwxrwx 1 boba boba      4096 июл 26 10:11 ..
# drwxrwxrwx 1 boba boba         0 июл 25 18:17 .ipynb_checkpoints
# drwxrwxrwx 1 boba boba     61440 июл 26 09:14 random_submission
# -rwxrwxrwx 1 boba boba   1057596 июл 26 10:58 random_submission.zip
# drwxrwxrwx 1 boba boba         0 июл 25 23:35 TrainModel001-G-M
# drwxrwxrwx 1 boba boba         0 июл 25 22:21 TrainModel001-G+M
# drwxrwxrwx 1 boba boba         0 июл 25 21:48 TrainModel001+G-M
# drwxrwxrwx 1 boba boba      4096 июл 25 21:05 TrainModel001+G+M
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:02 V1-UNET-0.8167.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:08 V1-UNET-0.8275.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 18:33 V1-UNET-0.8305.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 18:02 V1-UNET-0.8418.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:09 V1-UNET-0.8486.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:09 V1-UNET-0.8593.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 18:34 V1-UNET-0.8601.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:21 V1-UNET-0.8602.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:22 V1-UNET-0.8605.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:35 V1-UNET-0.8628.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:35 V1-UNET-0.8633.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:23 V1-UNET-0.8635.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:36 V1-UNET-0.8645.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:36 V1-UNET-0.8652.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:24 V1-UNET-0.8655.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:11 V1-UNET-0.8793.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:13 V1-UNET-0.8796.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:14 V1-UNET-0.8808.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 18:02 V1-UNET-0.8853.hdf5

# %%
# !ls ../Work -la
#!ls ../Temp/random_submission
# Out:
# total 80768
# drwxrwxrwx 1 boba boba        0 июл 26 09:17 .
# drwxrwxrwx 1 boba boba     4096 июл 25 15:24 ..
# -rwxrwxrwx 1 boba boba 82700662 июл 26 09:32 topcoderkonica.zip

# %%
if False :
    save_model(model10,'../Data-Keras/Models/model-UNet.h5')
    model10.save_weights('../Data-Keras/Models/model-UNet-weights.h5')

# %%
rrr=pd.DataFrame(res,columns=['image_name','tags']); rrr.head(); 
suffixDT = (datetime.datetime.now()).strftime('%Y-%m-%d-%H-%M-%S'); print(suffixDT)
rrr.to_csv('../Result/vss'+suffixDT+'.csv',index=False);
# Out:
# 2017-05-20-05-51-18
