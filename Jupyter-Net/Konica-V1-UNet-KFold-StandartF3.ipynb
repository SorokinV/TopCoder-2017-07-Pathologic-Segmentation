# %%
##
## UNet 
##
## Взята идея по описанию из https://github.com/pietz/unet-keras
##
##
## 2017-07-28
##   Добавлены flip+rotation LB=760393
##
## 2017-07-29
##   LB=769123
##
##

# %%
import sys,os,datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import fbeta_score
import sklearn.metrics as skm
from __future__ import print_function

# %%
print(np.__version__);
print(pd.__version__);
# Out:
# 1.13.1
# 0.19.2

# %%
import  cv2 as cv
cv.__version__
# Out:
# '3.2.0'

# %%
#from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.models import Sequential, save_model, load_model, Input, Model
from keras.layers import Convolution2D, MaxPooling2D, Convolution1D, MaxPooling1D, UpSampling2D, ZeroPadding2D
from keras.layers import Conv2D, Concatenate, Reshape
from keras.layers import Activation, Dropout, Flatten, Dense, Permute
from keras.layers.normalization import BatchNormalization
import keras.optimizers
from keras.callbacks import EarlyStopping,ReduceLROnPlateau,ModelCheckpoint
import keras.backend as K
# Out:
# Using TensorFlow backend.

# %%
keras.__version__
# Out:
# '2.0.6'

# %%
#---------------------------------------------------------------------

# %%
# !ls -la ..
#!ls -la ../Data
#!ls -la ../Data/training
# Out:
# total 25
# drwxrwxrwx 1 boba boba 4096 июл 26 11:10 .
# drwxrwxrwx 1 boba boba    0 июл 25 09:21 ..
# drwxrwxrwx 1 boba boba 4096 июл 25 09:23 Data
# drwxrwxrwx 1 boba boba    0 июл 25 09:22 Data-Arch
# drwxrwxrwx 1 boba boba    0 июл 25 09:26 Data-Keras
# drwxrwxrwx 1 boba boba 4096 июл 30 17:34 .git
# -rwxrwxrwx 2 boba boba  130 июл  9 12:02 .gitignore
# drwxrwxrwx 1 boba boba    0 июл 26 10:11 .ipynb_checkpoints
# drwxrwxrwx 1 boba boba  280 июл 30 17:35 Jupyter
# drwxrwxrwx 1 boba boba 4096 июл 30 17:32 Jupyter-Net
# drwxrwxrwx 1 boba boba 4096 июл 30 17:32 Result
# drwxrwxrwx 1 boba boba 4096 июл 29 22:02 Temp
# drwxrwxrwx 1 boba boba    0 июл 27 07:53 Work

# %%
dirData = '../Data'
dirTemp = '../Temp'
dirWork = '../Work'

dirTest  = os.path.join(dirData,'testing','images')
dirTrain = os.path.join(dirData,'training','images')
dirMask  = os.path.join(dirData,'training','truth')

# %%
listTrain = os.listdir(dirTrain)
listMask  = os.listdir(dirMask)
listTest  = os.listdir(dirTest)
listTrain = [xx for xx in listTrain if os.path.splitext(xx)[1]=='.tif']
listMask  = [xx for xx in listMask  if os.path.splitext(xx)[1]=='.png']
listTest  = [xx for xx in listTest  if os.path.splitext(xx)[1]=='.tif']
print(len(listTrain),len(listMask),len(listTest))
print(listTrain[:5],'\n',listMask[:5],'\n',listTest[:5])
# Out:
# 168 168 162
# ['i105404.tif', 'i117557.tif', 'i124017.tif', 'i130790.tif', 'i137857.tif']
#  ['i105404_mask.png', 'i117557_mask.png', 'i124017_mask.png', 'i130790_mask.png', 'i137857_mask.png']
#  ['i105047.tif', 'i116596.tif', 'i137649.tif', 'i140176.tif', 'i142099.tif']

# %%
if 0 :
    for xx in listTrain[:5] :
        img = cv.imread(os.path.join(dirTrain,xx),-1)
        xxm = os.path.splitext(xx)[0]+"_mask.png"
        msk = cv.imread(os.path.join(dirMask,xxm),-1)
        plt.subplot(121); plt.imshow(img); plt.subplot(122); plt.imshow(msk,'gray'); plt.show()
    plt.close()

# %%
msk.shape, img.shape, img.min(), img.max(), msk.max(), #img[6:10,6:10], msk[6:10,6:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-051c9d5448bc> in <module>()
# ----> 1 msk.shape, img.shape, img.min(), img.max(), msk.max(), #img[6:10,6:10], msk[6:10,6:10]
#
# NameError: name 'msk' is not defined

# %%
flagGray = False
Gauss    = 5
Median   = 5
if flagGray :
    trX, trY, trX0, trY0 = [], [], np.zeros((512,512,1)), np.zeros((512,512,1))
else :
    trX, trY, trX0, trY0 = [], [], np.zeros((512,512,3)), np.zeros((512,512,1))

for xx in listTrain :
    img = cv.imread(os.path.join(dirTrain,xx),-1)
    if 1 and (Gauss or Median): 
        for cc in range(img.shape[2]) : 
            if Gauss  : img[:,:,cc] = cv.GaussianBlur(img[:,:,cc],(Gauss,Gauss),0);
            if Median : img[:,:,cc] = cv.medianBlur  (img[:,:,cc],Median);
    xxm = os.path.splitext(xx)[0]+"_mask.png"
    msk = cv.imread(os.path.join(dirMask,xxm),-1)
    #print(img.mean(),msk.mean())
    if flagGray :
        img = cv.cvtColor(img,cv.COLOR_RGB2GRAY);
        trX0[6:506,6:506,0] = img[:,:]/255.0
        trY0[6:506,6:506,0] = msk[:,:]/255.0
    else :
        trX0[6:506,6:506,:] = img[:,:,:]/255.0
        trY0[6:506,6:506,0] = msk[:,:]/255.0
        trY0[trY0>=0.5] = 1.0
    trX.append(trX0.copy())
    trY.append(trY0.copy())
    #print(trX0.mean(),trY0.mean(),trX1[-1].mean(),trY1[-1].mean())

#print([trY[xx].mean() for xx in range(10)])
trX = np.array(trX)
trY = np.array(trY)

# аугментация
trXX, trYY, trXXX,trYYY = trX.copy(), trY.copy(), np.zeros((1)), np.zeros((1))


if 0 :
    # flipping
    for f in range(-1,2) :
        trXXX, trYYY = trX.copy(), trY.copy()
        for p in range(trXXX.shape[0]) :
            trXXX[p], trYYY[p,:,:,0] = cv.flip(trXXX[p],f), cv.flip(trYYY[p,:,:,0],f)
        trXX = np.vstack([trXX,trXXX])
        trYY = np.vstack([trYY,trYYY])
        print('flip :',f,trXX.shape,trYY.shape)

if 0 :
    # rotate +-90

    # rotate +90
    trXXX, trYYY = trX.copy(), trY.copy()
    for p in range(trX.shape[0]) :
        for i in range(trX.shape[1]) :
            for j in range(trX.shape[2]) :
                trXXX[p,i,j,:] = trX[p,j,trX.shape[1]-i-1]
                trYYY[p,i,j,:] = trY[p,j,trY.shape[1]-i-1]
    trXX = np.vstack([trXX,trXXX])
    trYY = np.vstack([trYY,trYYY])
    print('rotate +90:',trXX.shape,trYY.shape)

    # rotate -90
    trXXX, trYYY = trX.copy(), trY.copy()
    for p in range(trX.shape[0]) :
        for i in range(trX.shape[1]) :
            for j in range(trX.shape[2]) :
                trXXX[p,i,j,:] = trX[p,trX.shape[2]-j-1,i]
                trYYY[p,i,j,:] = trY[p,trY.shape[2]-j-1,i]
    trXX = np.vstack([trXX,trXXX])
    trYY = np.vstack([trYY,trYYY])
    print('rotate -90:',trXX.shape,trYY.shape)
    
trX, trY = trXX.copy(), trYY.copy()
del trXX,trYY
del trXXX,trYYY

# Считаем среднее по каналам и вычитаем из изображений
meanX = (trX[:,6:-6,6:-6,:].mean(axis=(1,2))).mean(axis=0)
stdX  = (trX[:,6:-6,6:-6,:].mean(axis=(1,2))).std(axis=0)
for cc in range(meanX.shape[0]) : 
    trX[:,6:-6,6:-6,cc] -= meanX[cc]    
print("mean={} std={}".format(meanX,stdX))
    
trX.shape, trX.min(), trX.max(), trY.shape, trY.min(), trY.max()
#[trY[xx].mean() for xx in range(10)]
# Out:
# mean=[ 0.6473997   0.48950165  0.70839568] std=[ 0.06249822  0.09179847  0.08778627]
# ((168, 512, 512, 3),
#  -0.62212117329583094,
#  0.48696893986925349,
#  (168, 512, 512, 1),
#  0.0,
#  1.0)

# %%
for xx in range(5) :
    img = trX[xx]
    xxm = trY[xx]
    plt.subplot(121); plt.imshow(img); plt.subplot(122); plt.imshow(xxm[:,:,0],'gray'); plt.show()
plt.close()

# %%
#
# model UNET
#
#    https://github.com/pietz/unet-keras
#
#

def level_block(m, dim, depth, acti, dropout=0.25, batch=True):
    if depth > 0:
        
        x = m
        if batch : x = BatchNormalization()(x)
        n = Conv2D(dim, (3, 3), activation=acti, padding='same')(x) #(m)
        n = Conv2D(dim, (3, 3), activation=acti, padding='same')(n)
        if dropout : n = Dropout(dropout)(n) ## add
        m = MaxPooling2D((2, 2))(n)
        m = level_block(m, 2*dim, depth-1, acti, dropout=dropout, batch=batch)
        m = UpSampling2D((2, 2))(m)
        m = Conv2D(dim, (2, 2), activation=acti, padding='same', kernel_initializer='he_normal')(m)
        if dropout : m = Dropout(dropout)(m) ## add
        m = Concatenate(axis=3)([n, m])
    m = Conv2D(dim, (3, 3), activation=acti, padding='same')(m)
    return Conv2D(dim, (3, 3), activation=acti, padding='same')(m)

def UNet(img_shape, n_out=2, dim=32, depth=5, acti='relu', flatten=False, dropout=0.25, batch=True):
    i = Input(shape=img_shape)
    ## ???? i = ZeroPadding2D((6,6),data_format="channels_last")
    o = level_block(i, dim, depth, acti, dropout=dropout, batch=batch)
    o = Conv2D(n_out, (1, 1), name='prediction')(o)
    if flatten:
        o = Reshape(n_out, img_shape[0] * img_shape[1])(o)
        o = Permute((2, 1))(o)
    #o = Activation('relu')(o)
    if batch : o = BatchNormalization()(o)  ######
    o = Activation('sigmoid')(o)
    return Model(inputs=i, outputs=o)

# %%
model10 = UNet((512,512,3),depth=5,n_out=1, dropout=0.05)
model10.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 512, 512, 3)   0
# ____________________________________________________________________________________________________
# batch_normalization_1 (BatchNorm (None, 512, 512, 3)   12          input_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_1 (Conv2D)                (None, 512, 512, 32)  896         batch_normalization_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_2 (Conv2D)                (None, 512, 512, 32)  9248        conv2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 512, 512, 32)  0           conv2d_2[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)   (None, 256, 256, 32)  0           dropout_1[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_2 (BatchNorm (None, 256, 256, 32)  128         max_pooling2d_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_3 (Conv2D)                (None, 256, 256, 64)  18496       batch_normalization_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_4 (Conv2D)                (None, 256, 256, 64)  36928       conv2d_3[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)              (None, 256, 256, 64)  0           conv2d_4[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)   (None, 128, 128, 64)  0           dropout_2[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_3 (BatchNorm (None, 128, 128, 64)  256         max_pooling2d_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_5 (Conv2D)                (None, 128, 128, 128) 73856       batch_normalization_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_6 (Conv2D)                (None, 128, 128, 128) 147584      conv2d_5[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)              (None, 128, 128, 128) 0           conv2d_6[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)   (None, 64, 64, 128)   0           dropout_3[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_4 (BatchNorm (None, 64, 64, 128)   512         max_pooling2d_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_7 (Conv2D)                (None, 64, 64, 256)   295168      batch_normalization_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_8 (Conv2D)                (None, 64, 64, 256)   590080      conv2d_7[0][0]
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)              (None, 64, 64, 256)   0           conv2d_8[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)   (None, 32, 32, 256)   0           dropout_4[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_5 (BatchNorm (None, 32, 32, 256)   1024        max_pooling2d_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_9 (Conv2D)                (None, 32, 32, 512)   1180160     batch_normalization_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_10 (Conv2D)               (None, 32, 32, 512)   2359808     conv2d_9[0][0]
# ____________________________________________________________________________________________________
# dropout_5 (Dropout)              (None, 32, 32, 512)   0           conv2d_10[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)   (None, 16, 16, 512)   0           dropout_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_11 (Conv2D)               (None, 16, 16, 1024)  4719616     max_pooling2d_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_12 (Conv2D)               (None, 16, 16, 1024)  9438208     conv2d_11[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)   (None, 32, 32, 1024)  0           conv2d_12[0][0]
# ____________________________________________________________________________________________________
# conv2d_13 (Conv2D)               (None, 32, 32, 512)   2097664     up_sampling2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_6 (Dropout)              (None, 32, 32, 512)   0           conv2d_13[0][0]
# ____________________________________________________________________________________________________
# concatenate_1 (Concatenate)      (None, 32, 32, 1024)  0           dropout_5[0][0]
#                                                                    dropout_6[0][0]
# ____________________________________________________________________________________________________
# conv2d_14 (Conv2D)               (None, 32, 32, 512)   4719104     concatenate_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_15 (Conv2D)               (None, 32, 32, 512)   2359808     conv2d_14[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)   (None, 64, 64, 512)   0           conv2d_15[0][0]
# ____________________________________________________________________________________________________
# conv2d_16 (Conv2D)               (None, 64, 64, 256)   524544      up_sampling2d_2[0][0]
# ____________________________________________________________________________________________________
# dropout_7 (Dropout)              (None, 64, 64, 256)   0           conv2d_16[0][0]
# ____________________________________________________________________________________________________
# concatenate_2 (Concatenate)      (None, 64, 64, 512)   0           dropout_4[0][0]
#                                                                    dropout_7[0][0]
# ____________________________________________________________________________________________________
# conv2d_17 (Conv2D)               (None, 64, 64, 256)   1179904     concatenate_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_18 (Conv2D)               (None, 64, 64, 256)   590080      conv2d_17[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)   (None, 128, 128, 256) 0           conv2d_18[0][0]
# ____________________________________________________________________________________________________
# conv2d_19 (Conv2D)               (None, 128, 128, 128) 131200      up_sampling2d_3[0][0]
# ____________________________________________________________________________________________________
# dropout_8 (Dropout)              (None, 128, 128, 128) 0           conv2d_19[0][0]
# ____________________________________________________________________________________________________
# concatenate_3 (Concatenate)      (None, 128, 128, 256) 0           dropout_3[0][0]
#                                                                    dropout_8[0][0]
# ____________________________________________________________________________________________________
# conv2d_20 (Conv2D)               (None, 128, 128, 128) 295040      concatenate_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_21 (Conv2D)               (None, 128, 128, 128) 147584      conv2d_20[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)   (None, 256, 256, 128) 0           conv2d_21[0][0]
# ____________________________________________________________________________________________________
# conv2d_22 (Conv2D)               (None, 256, 256, 64)  32832       up_sampling2d_4[0][0]
# ____________________________________________________________________________________________________
# dropout_9 (Dropout)              (None, 256, 256, 64)  0           conv2d_22[0][0]
# ____________________________________________________________________________________________________
# concatenate_4 (Concatenate)      (None, 256, 256, 128) 0           dropout_2[0][0]
#                                                                    dropout_9[0][0]
# ____________________________________________________________________________________________________
# conv2d_23 (Conv2D)               (None, 256, 256, 64)  73792       concatenate_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_24 (Conv2D)               (None, 256, 256, 64)  36928       conv2d_23[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)   (None, 512, 512, 64)  0           conv2d_24[0][0]
# ____________________________________________________________________________________________________
# conv2d_25 (Conv2D)               (None, 512, 512, 32)  8224        up_sampling2d_5[0][0]
# ____________________________________________________________________________________________________
# dropout_10 (Dropout)             (None, 512, 512, 32)  0           conv2d_25[0][0]
# ____________________________________________________________________________________________________
# concatenate_5 (Concatenate)      (None, 512, 512, 64)  0           dropout_1[0][0]
#                                                                    dropout_10[0][0]
# ____________________________________________________________________________________________________
# conv2d_26 (Conv2D)               (None, 512, 512, 32)  18464       concatenate_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_27 (Conv2D)               (None, 512, 512, 32)  9248        conv2d_26[0][0]
# ____________________________________________________________________________________________________
# prediction (Conv2D)              (None, 512, 512, 1)   33          conv2d_27[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_6 (BatchNorm (None, 512, 512, 1)   4           prediction[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 512, 512, 1)   0           batch_normalization_6[0][0]
# ====================================================================================================
# Total params: 31,096,433
# Trainable params: 31,095,465
# Non-trainable params: 968
# ____________________________________________________________________________________________________

# %%
def dice (truth,pred) :
    g, s = K.sum(truth), K.sum(pred)
    x    = K.sum((truth*pred))
    return((1.0 if K.sum(g+s)==0.0 else 2.0*x/(g+s+K.epsilon())))

def f1 (truth,pred) :
    TP = K.sum(truth*pred)
    TN = K.sum((1.0-truth)*(1.0-pred))
    FP = K.sum(truth*(1.0-pred))
    FN = K.sum((1.0-truth)*pred)

    
    P  = 1.0 if K.sum(TP+FP)==0.0 else TP/(TP+FP)
    R  = 0.0 if K.sum(TP+FN)==0.0 else TP/(TP+FN) 

    F1 = 0.0 if K.sum(P+R)  ==0.0 else 2.0*P*R/(P+R)

    return(F1)

def f1dice (truth,pred) :
    return ((dice(truth,pred)+f1(truth,pred))/2.0)
    
def lossdice (truth,pred) :
    return(1.0 - dice(truth,pred))

def lossfd (truth,pred) :
    return(1.0 - f1dice(truth,pred))

# %%
def buildModel (input_shape) :
    model = UNet(input_shape,depth=5,n_out=1,dropout=0.05,batch=False)
    
    sgd = keras.optimizers.SGD(lr=0.01, momentum=0.9, nesterov=True)
    #model.compile(loss='mean_absolute_error',  #'binary_crossentropy',
    model.compile(loss=lossdice, #'mean_absolute_error',  #'binary_crossentropy',
                  optimizer=sgd, #sgd, #"adam", #'rmsprop',
                  metrics=[dice,'binary_accuracy']) #['binary_accuracy']) #[fbeta_pred]) #['accuracy',fbeta_pred]) #['accuracy'])
    return(model)

# %%
K.clear_session()
model10 = buildModel((trX.shape[1],trX.shape[2],trX.shape[3]))
model10.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 512, 512, 3)   0
# ____________________________________________________________________________________________________
# conv2d_1 (Conv2D)                (None, 512, 512, 32)  896         input_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_2 (Conv2D)                (None, 512, 512, 32)  9248        conv2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 512, 512, 32)  0           conv2d_2[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)   (None, 256, 256, 32)  0           dropout_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_3 (Conv2D)                (None, 256, 256, 64)  18496       max_pooling2d_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_4 (Conv2D)                (None, 256, 256, 64)  36928       conv2d_3[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)              (None, 256, 256, 64)  0           conv2d_4[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)   (None, 128, 128, 64)  0           dropout_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_5 (Conv2D)                (None, 128, 128, 128) 73856       max_pooling2d_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_6 (Conv2D)                (None, 128, 128, 128) 147584      conv2d_5[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)              (None, 128, 128, 128) 0           conv2d_6[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)   (None, 64, 64, 128)   0           dropout_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_7 (Conv2D)                (None, 64, 64, 256)   295168      max_pooling2d_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_8 (Conv2D)                (None, 64, 64, 256)   590080      conv2d_7[0][0]
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)              (None, 64, 64, 256)   0           conv2d_8[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)   (None, 32, 32, 256)   0           dropout_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_9 (Conv2D)                (None, 32, 32, 512)   1180160     max_pooling2d_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_10 (Conv2D)               (None, 32, 32, 512)   2359808     conv2d_9[0][0]
# ____________________________________________________________________________________________________
# dropout_5 (Dropout)              (None, 32, 32, 512)   0           conv2d_10[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)   (None, 16, 16, 512)   0           dropout_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_11 (Conv2D)               (None, 16, 16, 1024)  4719616     max_pooling2d_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_12 (Conv2D)               (None, 16, 16, 1024)  9438208     conv2d_11[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)   (None, 32, 32, 1024)  0           conv2d_12[0][0]
# ____________________________________________________________________________________________________
# conv2d_13 (Conv2D)               (None, 32, 32, 512)   2097664     up_sampling2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_6 (Dropout)              (None, 32, 32, 512)   0           conv2d_13[0][0]
# ____________________________________________________________________________________________________
# concatenate_1 (Concatenate)      (None, 32, 32, 1024)  0           dropout_5[0][0]
#                                                                    dropout_6[0][0]
# ____________________________________________________________________________________________________
# conv2d_14 (Conv2D)               (None, 32, 32, 512)   4719104     concatenate_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_15 (Conv2D)               (None, 32, 32, 512)   2359808     conv2d_14[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)   (None, 64, 64, 512)   0           conv2d_15[0][0]
# ____________________________________________________________________________________________________
# conv2d_16 (Conv2D)               (None, 64, 64, 256)   524544      up_sampling2d_2[0][0]
# ____________________________________________________________________________________________________
# dropout_7 (Dropout)              (None, 64, 64, 256)   0           conv2d_16[0][0]
# ____________________________________________________________________________________________________
# concatenate_2 (Concatenate)      (None, 64, 64, 512)   0           dropout_4[0][0]
#                                                                    dropout_7[0][0]
# ____________________________________________________________________________________________________
# conv2d_17 (Conv2D)               (None, 64, 64, 256)   1179904     concatenate_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_18 (Conv2D)               (None, 64, 64, 256)   590080      conv2d_17[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)   (None, 128, 128, 256) 0           conv2d_18[0][0]
# ____________________________________________________________________________________________________
# conv2d_19 (Conv2D)               (None, 128, 128, 128) 131200      up_sampling2d_3[0][0]
# ____________________________________________________________________________________________________
# dropout_8 (Dropout)              (None, 128, 128, 128) 0           conv2d_19[0][0]
# ____________________________________________________________________________________________________
# concatenate_3 (Concatenate)      (None, 128, 128, 256) 0           dropout_3[0][0]
#                                                                    dropout_8[0][0]
# ____________________________________________________________________________________________________
# conv2d_20 (Conv2D)               (None, 128, 128, 128) 295040      concatenate_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_21 (Conv2D)               (None, 128, 128, 128) 147584      conv2d_20[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)   (None, 256, 256, 128) 0           conv2d_21[0][0]
# ____________________________________________________________________________________________________
# conv2d_22 (Conv2D)               (None, 256, 256, 64)  32832       up_sampling2d_4[0][0]
# ____________________________________________________________________________________________________
# dropout_9 (Dropout)              (None, 256, 256, 64)  0           conv2d_22[0][0]
# ____________________________________________________________________________________________________
# concatenate_4 (Concatenate)      (None, 256, 256, 128) 0           dropout_2[0][0]
#                                                                    dropout_9[0][0]
# ____________________________________________________________________________________________________
# conv2d_23 (Conv2D)               (None, 256, 256, 64)  73792       concatenate_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_24 (Conv2D)               (None, 256, 256, 64)  36928       conv2d_23[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)   (None, 512, 512, 64)  0           conv2d_24[0][0]
# ____________________________________________________________________________________________________
# conv2d_25 (Conv2D)               (None, 512, 512, 32)  8224        up_sampling2d_5[0][0]
# ____________________________________________________________________________________________________
# dropout_10 (Dropout)             (None, 512, 512, 32)  0           conv2d_25[0][0]
# ____________________________________________________________________________________________________
# concatenate_5 (Concatenate)      (None, 512, 512, 64)  0           dropout_1[0][0]
#                                                                    dropout_10[0][0]
# ____________________________________________________________________________________________________
# conv2d_26 (Conv2D)               (None, 512, 512, 32)  18464       concatenate_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_27 (Conv2D)               (None, 512, 512, 32)  9248        conv2d_26[0][0]
# ____________________________________________________________________________________________________
# prediction (Conv2D)              (None, 512, 512, 1)   33          conv2d_27[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 512, 512, 1)   0           prediction[0][0]
# ====================================================================================================
# Total params: 31,094,497
# Trainable params: 31,094,497
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
#model10.load_weights('../Data-Keras/Models/model-UNet-weights.h5', by_name=False)
batch_size = 1

# %%
#epochs     = 150
epochs     = 50
verbose    = 2
batch_size = 1
metric     = 'binary_accuracy'
metric     = 'dice'

############trX, trY = trX[0:30], trY[0:30]

#folds      = 10
folds      = 5
folds      = 3
foldN      = trX.shape[0]/folds+1

print(datetime.datetime.now(),'Training with folds')

for i in range(folds) :
#for i in range(8,11) :

    print(datetime.datetime.now(),'------------>',i)

    K.clear_session()
    model10 = buildModel((trX.shape[1],trX.shape[2],trX.shape[3]))
    ############if 1 : model10.load_weights('../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7660-2.hdf5')

#    early_stopping = EarlyStopping(monitor='val_loss', patience=10,min_delta=0.0001,verbose=1)
    early_stopping = EarlyStopping(monitor='val_loss', patience=5,min_delta=0.0001,verbose=1)
    reduce_lr1     = ReduceLROnPlateau(monitor='val_loss', factor=0.5,patience=3, min_lr=0.0000001,verbose=1)
    reduce_lr2     = ReduceLROnPlateau(monitor='loss',     factor=0.5,patience=3, min_lr=0.0000001,verbose=1)

    filepath="../Temp/NewStep/StandartF3/V1-UNET-val_"+metric+"={val_"+metric+":.4f}-{"+metric+":.4f}---"+str(i)+".hdf5"
    #filepath="../Temp/NewStep/StandartF5/V1-UNET-val_"+metric+"={val_"+metric+":.4f}-{"+metric+":.4f}---"+str(i)+".hdf5"
    #filepath="../Temp/TempTempG5M5KFold10/V1-UNET-val_"+metric+"={val_"+metric+":.4f}-{"+metric+":.4f}---"+str(i)+".hdf5"
    #checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
    checkpoint1 = ModelCheckpoint(filepath, monitor=metric,        verbose=1, save_best_only=True, mode='max')
    checkpoint2 = ModelCheckpoint(filepath, monitor='val_'+metric, verbose=1, save_best_only=True, mode='max')

    step  = 60
    low   = 0
    high  = low+step
    
    tFold = [True]*(i*foldN)+[False]*foldN+[True]*trX.shape[0];
    tFold = tFold[:trX.shape[0]]
    
    vFold = [not xx for xx in tFold]

    #hist1  = model10.fit(trX[low:high],trY[low:high],
    hist1  = model10.fit(trX[tFold],trY[tFold],
                        epochs=epochs, batch_size=batch_size, 
                        #validation_split=0.20, 
                        validation_data=(trX[vFold],trY[vFold]),
                        initial_epoch = 0,
                        #callbacks=[early_stopping,reduce_lr1,reduce_lr2,checkpoint],
                        callbacks=[reduce_lr1,reduce_lr2,checkpoint1,checkpoint2,early_stopping],
                        verbose=verbose)

print(datetime.datetime.now())
# Out:
# 2017-07-30 18:15:27.218338 Training with folds
# 2017-07-30 18:15:27.219067 ------------> 0
# Train on 111 samples, validate on 57 samples
# Epoch 1/50
# Epoch 00000: dice improved from -inf to 0.40434, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.4052-0.4043---0.hdf5
# Epoch 00000: val_dice improved from -inf to 0.40522, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.4052-0.4043---0.hdf5
# 62s - loss: 0.5957 - dice: 0.4043 - binary_accuracy: 0.3484 - val_loss: 0.5948 - val_dice: 0.4052 - val_binary_accuracy: 0.2860
# Epoch 2/50
# Epoch 00001: dice improved from 0.40434 to 0.47022, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.4336-0.4702---0.hdf5
# Epoch 00001: val_dice improved from 0.40522 to 0.43362, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.4336-0.4702---0.hdf5
# 62s - loss: 0.5298 - dice: 0.4702 - binary_accuracy: 0.3373 - val_loss: 0.5664 - val_dice: 0.4336 - val_binary_accuracy: 0.2860
# Epoch 3/50
# Epoch 00002: dice improved from 0.47022 to 0.52908, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.5777-0.5291---0.hdf5
# Epoch 00002: val_dice improved from 0.43362 to 0.57768, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.5777-0.5291---0.hdf5
# 62s - loss: 0.4709 - dice: 0.5291 - binary_accuracy: 0.6222 - val_loss: 0.4223 - val_dice: 0.5777 - val_binary_accuracy: 0.8089
# Epoch 4/50
# Epoch 00003: dice improved from 0.52908 to 0.62263, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.5902-0.6226---0.hdf5
# Epoch 00003: val_dice improved from 0.57768 to 0.59015, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.5902-0.6226---0.hdf5
# 61s - loss: 0.3774 - dice: 0.6226 - binary_accuracy: 0.7928 - val_loss: 0.4098 - val_dice: 0.5902 - val_binary_accuracy: 0.7977
# Epoch 5/50
# Epoch 00004: dice improved from 0.62263 to 0.64411, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.5868-0.6441---0.hdf5
# Epoch 00004: val_dice did not improve
# 59s - loss: 0.3559 - dice: 0.6441 - binary_accuracy: 0.7993 - val_loss: 0.4132 - val_dice: 0.5868 - val_binary_accuracy: 0.7673
# Epoch 6/50
# Epoch 00005: dice did not improve
# Epoch 00005: val_dice improved from 0.59015 to 0.60466, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6047-0.6418---0.hdf5
# 59s - loss: 0.3582 - dice: 0.6418 - binary_accuracy: 0.8142 - val_loss: 0.3953 - val_dice: 0.6047 - val_binary_accuracy: 0.8028
# Epoch 7/50
# Epoch 00006: dice improved from 0.64411 to 0.64624, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6034-0.6462---0.hdf5
# Epoch 00006: val_dice did not improve
# 59s - loss: 0.3538 - dice: 0.6462 - binary_accuracy: 0.8127 - val_loss: 0.3966 - val_dice: 0.6034 - val_binary_accuracy: 0.8193
# Epoch 8/50
# Epoch 00007: dice improved from 0.64624 to 0.65939, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.5959-0.6594---0.hdf5
# Epoch 00007: val_dice did not improve
# 58s - loss: 0.3406 - dice: 0.6594 - binary_accuracy: 0.8248 - val_loss: 0.4041 - val_dice: 0.5959 - val_binary_accuracy: 0.8317
# Epoch 9/50
# Epoch 00008: dice did not improve
# Epoch 00008: val_dice did not improve
# 57s - loss: 0.3516 - dice: 0.6484 - binary_accuracy: 0.8086 - val_loss: 0.4281 - val_dice: 0.5719 - val_binary_accuracy: 0.8249
# Epoch 10/50
#
# Epoch 00009: reducing learning rate to 0.00499999988824.
# Epoch 00009: dice did not improve
# Epoch 00009: val_dice did not improve
# 57s - loss: 0.3564 - dice: 0.6436 - binary_accuracy: 0.8168 - val_loss: 0.4046 - val_dice: 0.5954 - val_binary_accuracy: 0.8291
# Epoch 11/50
# Epoch 00010: dice improved from 0.65939 to 0.66123, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6087-0.6612---0.hdf5
# Epoch 00010: val_dice improved from 0.60466 to 0.60875, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6087-0.6612---0.hdf5
# 60s - loss: 0.3388 - dice: 0.6612 - binary_accuracy: 0.8255 - val_loss: 0.3913 - val_dice: 0.6087 - val_binary_accuracy: 0.7878
# Epoch 12/50
# Epoch 00011: dice improved from 0.66123 to 0.66614, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6144-0.6661---0.hdf5
# Epoch 00011: val_dice improved from 0.60875 to 0.61439, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6144-0.6661---0.hdf5
# 60s - loss: 0.3339 - dice: 0.6661 - binary_accuracy: 0.8294 - val_loss: 0.3856 - val_dice: 0.6144 - val_binary_accuracy: 0.8350
# Epoch 13/50
# Epoch 00012: dice improved from 0.66614 to 0.67524, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6129-0.6752---0.hdf5
# Epoch 00012: val_dice did not improve
# 58s - loss: 0.3248 - dice: 0.6752 - binary_accuracy: 0.8320 - val_loss: 0.3871 - val_dice: 0.6129 - val_binary_accuracy: 0.7900
# Epoch 14/50
# Epoch 00013: dice improved from 0.67524 to 0.68113, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6188-0.6811---0.hdf5
# Epoch 00013: val_dice improved from 0.61439 to 0.61882, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6188-0.6811---0.hdf5
# 60s - loss: 0.3189 - dice: 0.6811 - binary_accuracy: 0.8359 - val_loss: 0.3812 - val_dice: 0.6188 - val_binary_accuracy: 0.8416
# Epoch 15/50
# Epoch 00014: dice did not improve
# Epoch 00014: val_dice improved from 0.61882 to 0.61967, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6197-0.6766---0.hdf5
# 58s - loss: 0.3234 - dice: 0.6766 - binary_accuracy: 0.8390 - val_loss: 0.3803 - val_dice: 0.6197 - val_binary_accuracy: 0.7897
# Epoch 16/50
# Epoch 00015: dice improved from 0.68113 to 0.68653, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6388-0.6865---0.hdf5
# Epoch 00015: val_dice improved from 0.61967 to 0.63876, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6388-0.6865---0.hdf5
# 60s - loss: 0.3135 - dice: 0.6865 - binary_accuracy: 0.8312 - val_loss: 0.3612 - val_dice: 0.6388 - val_binary_accuracy: 0.8297
# Epoch 17/50
# Epoch 00016: dice improved from 0.68653 to 0.68800, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6410-0.6880---0.hdf5
# Epoch 00016: val_dice improved from 0.63876 to 0.64102, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6410-0.6880---0.hdf5
# 60s - loss: 0.3120 - dice: 0.6880 - binary_accuracy: 0.8406 - val_loss: 0.3590 - val_dice: 0.6410 - val_binary_accuracy: 0.8246
# Epoch 18/50
# Epoch 00017: dice did not improve
# Epoch 00017: val_dice did not improve
# 57s - loss: 0.3138 - dice: 0.6862 - binary_accuracy: 0.8302 - val_loss: 0.3869 - val_dice: 0.6131 - val_binary_accuracy: 0.8339
# Epoch 19/50
# Epoch 00018: dice improved from 0.68800 to 0.69355, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6450-0.6936---0.hdf5
# Epoch 00018: val_dice improved from 0.64102 to 0.64499, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6450-0.6936---0.hdf5
# 60s - loss: 0.3064 - dice: 0.6936 - binary_accuracy: 0.8486 - val_loss: 0.3550 - val_dice: 0.6450 - val_binary_accuracy: 0.8364
# Epoch 20/50
# Epoch 00019: dice improved from 0.69355 to 0.69911, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6454-0.6991---0.hdf5
# Epoch 00019: val_dice improved from 0.64499 to 0.64542, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6454-0.6991---0.hdf5
# 60s - loss: 0.3009 - dice: 0.6991 - binary_accuracy: 0.8512 - val_loss: 0.3546 - val_dice: 0.6454 - val_binary_accuracy: 0.8220
# Epoch 21/50
# Epoch 00020: dice improved from 0.69911 to 0.70080, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6416-0.7008---0.hdf5
# Epoch 00020: val_dice did not improve
# 58s - loss: 0.2992 - dice: 0.7008 - binary_accuracy: 0.8438 - val_loss: 0.3584 - val_dice: 0.6416 - val_binary_accuracy: 0.8163
# Epoch 22/50
# Epoch 00021: dice improved from 0.70080 to 0.70637, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6553-0.7064---0.hdf5
# Epoch 00021: val_dice improved from 0.64542 to 0.65529, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6553-0.7064---0.hdf5
# 60s - loss: 0.2936 - dice: 0.7064 - binary_accuracy: 0.8479 - val_loss: 0.3447 - val_dice: 0.6553 - val_binary_accuracy: 0.8455
# Epoch 23/50
# Epoch 00022: dice improved from 0.70637 to 0.71024, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6533-0.7102---0.hdf5
# Epoch 00022: val_dice did not improve
# 58s - loss: 0.2898 - dice: 0.7102 - binary_accuracy: 0.8559 - val_loss: 0.3467 - val_dice: 0.6533 - val_binary_accuracy: 0.8357
# Epoch 24/50
# Epoch 00023: dice improved from 0.71024 to 0.71464, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6607-0.7146---0.hdf5
# Epoch 00023: val_dice improved from 0.65529 to 0.66069, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6607-0.7146---0.hdf5
# 60s - loss: 0.2854 - dice: 0.7146 - binary_accuracy: 0.8592 - val_loss: 0.3393 - val_dice: 0.6607 - val_binary_accuracy: 0.8410
# Epoch 25/50
# Epoch 00024: dice improved from 0.71464 to 0.72086, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6558-0.7209---0.hdf5
# Epoch 00024: val_dice did not improve
# 58s - loss: 0.2791 - dice: 0.7209 - binary_accuracy: 0.8605 - val_loss: 0.3442 - val_dice: 0.6558 - val_binary_accuracy: 0.8517
# Epoch 26/50
# Epoch 00025: dice did not improve
# Epoch 00025: val_dice improved from 0.66069 to 0.66429, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6643-0.7174---0.hdf5
# 58s - loss: 0.2826 - dice: 0.7174 - binary_accuracy: 0.8578 - val_loss: 0.3357 - val_dice: 0.6643 - val_binary_accuracy: 0.8346
# Epoch 27/50
# Epoch 00026: dice improved from 0.72086 to 0.72946, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6054-0.7295---0.hdf5
# Epoch 00026: val_dice did not improve
# 58s - loss: 0.2705 - dice: 0.7295 - binary_accuracy: 0.8696 - val_loss: 0.3946 - val_dice: 0.6054 - val_binary_accuracy: 0.7516
# Epoch 28/50
# Epoch 00027: dice did not improve
# Epoch 00027: val_dice improved from 0.66429 to 0.67113, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6711-0.7198---0.hdf5
# 58s - loss: 0.2802 - dice: 0.7198 - binary_accuracy: 0.8587 - val_loss: 0.3289 - val_dice: 0.6711 - val_binary_accuracy: 0.8548
# Epoch 29/50
# Epoch 00028: dice did not improve
# Epoch 00028: val_dice improved from 0.67113 to 0.67230, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6723-0.7251---0.hdf5
# 58s - loss: 0.2749 - dice: 0.7251 - binary_accuracy: 0.8628 - val_loss: 0.3277 - val_dice: 0.6723 - val_binary_accuracy: 0.8530
# Epoch 30/50
# Epoch 00029: dice improved from 0.72946 to 0.73459, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6611-0.7346---0.hdf5
# Epoch 00029: val_dice did not improve
# 58s - loss: 0.2654 - dice: 0.7346 - binary_accuracy: 0.8704 - val_loss: 0.3389 - val_dice: 0.6611 - val_binary_accuracy: 0.8369
# Epoch 31/50
# Epoch 00030: dice did not improve
# Epoch 00030: val_dice improved from 0.67230 to 0.67463, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6746-0.7302---0.hdf5
# 58s - loss: 0.2698 - dice: 0.7302 - binary_accuracy: 0.8676 - val_loss: 0.3254 - val_dice: 0.6746 - val_binary_accuracy: 0.8530
# Epoch 32/50
# Epoch 00031: dice did not improve
# Epoch 00031: val_dice did not improve
# 57s - loss: 0.2661 - dice: 0.7339 - binary_accuracy: 0.8723 - val_loss: 0.3292 - val_dice: 0.6708 - val_binary_accuracy: 0.8399
# Epoch 33/50
# Epoch 00032: dice improved from 0.73459 to 0.74636, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6660-0.7464---0.hdf5
# Epoch 00032: val_dice did not improve
# 59s - loss: 0.2536 - dice: 0.7464 - binary_accuracy: 0.8756 - val_loss: 0.3340 - val_dice: 0.6660 - val_binary_accuracy: 0.8605
# Epoch 34/50
# Epoch 00033: dice did not improve
# Epoch 00033: val_dice improved from 0.67463 to 0.68107, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6811-0.7418---0.hdf5
# 58s - loss: 0.2582 - dice: 0.7418 - binary_accuracy: 0.8750 - val_loss: 0.3189 - val_dice: 0.6811 - val_binary_accuracy: 0.8541
# Epoch 35/50
# Epoch 00034: dice improved from 0.74636 to 0.74850, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6575-0.7485---0.hdf5
# Epoch 00034: val_dice did not improve
# 58s - loss: 0.2515 - dice: 0.7485 - binary_accuracy: 0.8828 - val_loss: 0.3425 - val_dice: 0.6575 - val_binary_accuracy: 0.8224
# Epoch 36/50
# Epoch 00035: dice did not improve
# Epoch 00035: val_dice improved from 0.68107 to 0.68143, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6814-0.7418---0.hdf5
# 58s - loss: 0.2582 - dice: 0.7418 - binary_accuracy: 0.8758 - val_loss: 0.3186 - val_dice: 0.6814 - val_binary_accuracy: 0.8559
# Epoch 37/50
# Epoch 00036: dice did not improve
# Epoch 00036: val_dice did not improve
# 57s - loss: 0.2616 - dice: 0.7384 - binary_accuracy: 0.8756 - val_loss: 0.3231 - val_dice: 0.6769 - val_binary_accuracy: 0.8443
# Epoch 38/50
# Epoch 00037: dice improved from 0.74850 to 0.74904, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6895-0.7490---0.hdf5
# Epoch 00037: val_dice improved from 0.68143 to 0.68955, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6895-0.7490---0.hdf5
# 60s - loss: 0.2510 - dice: 0.7490 - binary_accuracy: 0.8780 - val_loss: 0.3105 - val_dice: 0.6895 - val_binary_accuracy: 0.8639
# Epoch 39/50
# Epoch 00038: dice improved from 0.74904 to 0.75574, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6907-0.7557---0.hdf5
# Epoch 00038: val_dice improved from 0.68955 to 0.69074, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6907-0.7557---0.hdf5
# 60s - loss: 0.2443 - dice: 0.7557 - binary_accuracy: 0.8833 - val_loss: 0.3093 - val_dice: 0.6907 - val_binary_accuracy: 0.8707
# Epoch 40/50
# Epoch 00039: dice improved from 0.75574 to 0.75782, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6898-0.7578---0.hdf5
# Epoch 00039: val_dice did not improve
# 58s - loss: 0.2422 - dice: 0.7578 - binary_accuracy: 0.8860 - val_loss: 0.3102 - val_dice: 0.6898 - val_binary_accuracy: 0.8588
# Epoch 41/50
# Epoch 00040: dice improved from 0.75782 to 0.76109, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6830-0.7611---0.hdf5
# Epoch 00040: val_dice did not improve
# 58s - loss: 0.2389 - dice: 0.7611 - binary_accuracy: 0.8827 - val_loss: 0.3170 - val_dice: 0.6830 - val_binary_accuracy: 0.8603
# Epoch 42/50
# Epoch 00041: dice improved from 0.76109 to 0.76249, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6895-0.7625---0.hdf5
# Epoch 00041: val_dice did not improve
# 58s - loss: 0.2375 - dice: 0.7625 - binary_accuracy: 0.8839 - val_loss: 0.3105 - val_dice: 0.6895 - val_binary_accuracy: 0.8777
# Epoch 43/50
#
# Epoch 00042: reducing learning rate to 0.00249999994412.
# Epoch 00042: dice improved from 0.76249 to 0.76463, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6907-0.7646---0.hdf5
# Epoch 00042: val_dice did not improve
# 58s - loss: 0.2354 - dice: 0.7646 - binary_accuracy: 0.8912 - val_loss: 0.3093 - val_dice: 0.6907 - val_binary_accuracy: 0.8621
# Epoch 44/50
# Epoch 00043: dice improved from 0.76463 to 0.77435, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7027-0.7743---0.hdf5
# Epoch 00043: val_dice improved from 0.69074 to 0.70274, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7027-0.7743---0.hdf5
# 60s - loss: 0.2257 - dice: 0.7743 - binary_accuracy: 0.8945 - val_loss: 0.2973 - val_dice: 0.7027 - val_binary_accuracy: 0.8774
# Epoch 45/50
# Epoch 00044: dice improved from 0.77435 to 0.77632, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7048-0.7763---0.hdf5
# Epoch 00044: val_dice improved from 0.70274 to 0.70475, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7048-0.7763---0.hdf5
# 60s - loss: 0.2237 - dice: 0.7763 - binary_accuracy: 0.8961 - val_loss: 0.2952 - val_dice: 0.7048 - val_binary_accuracy: 0.8723
# Epoch 46/50
# Epoch 00045: dice improved from 0.77632 to 0.77761, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6931-0.7776---0.hdf5
# Epoch 00045: val_dice did not improve
# 58s - loss: 0.2224 - dice: 0.7776 - binary_accuracy: 0.8946 - val_loss: 0.3069 - val_dice: 0.6931 - val_binary_accuracy: 0.8562
# Epoch 47/50
# Epoch 00046: dice improved from 0.77761 to 0.78035, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7036-0.7803---0.hdf5
# Epoch 00046: val_dice did not improve
# 58s - loss: 0.2197 - dice: 0.7803 - binary_accuracy: 0.8992 - val_loss: 0.2964 - val_dice: 0.7036 - val_binary_accuracy: 0.8709
# Epoch 48/50
# Epoch 00047: dice did not improve
# Epoch 00047: val_dice improved from 0.70475 to 0.70844, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7084-0.7794---0.hdf5
# 58s - loss: 0.2206 - dice: 0.7794 - binary_accuracy: 0.8969 - val_loss: 0.2916 - val_dice: 0.7084 - val_binary_accuracy: 0.8770
# Epoch 49/50
# Epoch 00048: dice improved from 0.78035 to 0.78369, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7068-0.7837---0.hdf5
# Epoch 00048: val_dice did not improve
# 58s - loss: 0.2163 - dice: 0.7837 - binary_accuracy: 0.9003 - val_loss: 0.2932 - val_dice: 0.7068 - val_binary_accuracy: 0.8799
# Epoch 50/50
# Epoch 00049: dice improved from 0.78369 to 0.78568, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7052-0.7857---0.hdf5
# Epoch 00049: val_dice did not improve
# 58s - loss: 0.2143 - dice: 0.7857 - binary_accuracy: 0.8987 - val_loss: 0.2948 - val_dice: 0.7052 - val_binary_accuracy: 0.8707
# 2017-07-30 19:04:57.712214 ------------> 1
# Train on 111 samples, validate on 57 samples
# Epoch 1/50
# Epoch 00000: dice improved from -inf to 0.39772, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.4732-0.3977---1.hdf5
# Epoch 00000: val_dice improved from -inf to 0.47317, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.4732-0.3977---1.hdf5
# 63s - loss: 0.6023 - dice: 0.3977 - binary_accuracy: 0.3281 - val_loss: 0.5268 - val_dice: 0.4732 - val_binary_accuracy: 0.3370
# Epoch 2/50
# Epoch 00001: dice improved from 0.39772 to 0.46969, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.5463-0.4697---1.hdf5
# Epoch 00001: val_dice improved from 0.47317 to 0.54627, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.5463-0.4697---1.hdf5
# 62s - loss: 0.5303 - dice: 0.4697 - binary_accuracy: 0.5142 - val_loss: 0.4537 - val_dice: 0.5463 - val_binary_accuracy: 0.7885
# Epoch 3/50
# Epoch 00002: dice improved from 0.46969 to 0.59119, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6542-0.5912---1.hdf5
# Epoch 00002: val_dice improved from 0.54627 to 0.65420, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6542-0.5912---1.hdf5
# 62s - loss: 0.4088 - dice: 0.5912 - binary_accuracy: 0.7948 - val_loss: 0.3458 - val_dice: 0.6542 - val_binary_accuracy: 0.8258
# Epoch 4/50
# Epoch 00003: dice improved from 0.59119 to 0.61362, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.5900-0.6136---1.hdf5
# Epoch 00003: val_dice did not improve
# 60s - loss: 0.3864 - dice: 0.6136 - binary_accuracy: 0.8050 - val_loss: 0.4100 - val_dice: 0.5900 - val_binary_accuracy: 0.8286
# Epoch 5/50
# Epoch 00004: dice improved from 0.61362 to 0.62107, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6335-0.6211---1.hdf5
# Epoch 00004: val_dice did not improve
# 59s - loss: 0.3789 - dice: 0.6211 - binary_accuracy: 0.7941 - val_loss: 0.3665 - val_dice: 0.6335 - val_binary_accuracy: 0.7900
# Epoch 6/50
# Epoch 00005: dice improved from 0.62107 to 0.64502, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.5483-0.6450---1.hdf5
# Epoch 00005: val_dice did not improve
# 59s - loss: 0.3550 - dice: 0.6450 - binary_accuracy: 0.8150 - val_loss: 0.4517 - val_dice: 0.5483 - val_binary_accuracy: 0.6215
# Epoch 7/50
#
# Epoch 00006: reducing learning rate to 0.00499999988824.
# Epoch 00006: dice did not improve
# Epoch 00006: val_dice did not improve
# 58s - loss: 0.4002 - dice: 0.5998 - binary_accuracy: 0.7276 - val_loss: 0.3463 - val_dice: 0.6537 - val_binary_accuracy: 0.8532
# Epoch 8/50
# Epoch 00007: dice improved from 0.64502 to 0.64900, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6588-0.6490---1.hdf5
# Epoch 00007: val_dice improved from 0.65420 to 0.65877, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6588-0.6490---1.hdf5
# 60s - loss: 0.3510 - dice: 0.6490 - binary_accuracy: 0.8204 - val_loss: 0.3412 - val_dice: 0.6588 - val_binary_accuracy: 0.8576
# Epoch 9/50
# Epoch 00008: dice did not improve
# Epoch 00008: val_dice improved from 0.65877 to 0.67781, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6778-0.6442---1.hdf5
# 59s - loss: 0.3558 - dice: 0.6442 - binary_accuracy: 0.8151 - val_loss: 0.3222 - val_dice: 0.6778 - val_binary_accuracy: 0.8596
# Epoch 10/50
# Epoch 00009: dice improved from 0.64900 to 0.65232, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6567-0.6523---1.hdf5
# Epoch 00009: val_dice did not improve
# 59s - loss: 0.3477 - dice: 0.6523 - binary_accuracy: 0.8265 - val_loss: 0.3433 - val_dice: 0.6567 - val_binary_accuracy: 0.8132
# Epoch 11/50
# Epoch 00010: dice improved from 0.65232 to 0.65646, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6540-0.6565---1.hdf5
# Epoch 00010: val_dice did not improve
# 59s - loss: 0.3435 - dice: 0.6565 - binary_accuracy: 0.8266 - val_loss: 0.3460 - val_dice: 0.6540 - val_binary_accuracy: 0.8566
# Epoch 12/50
# Epoch 00011: dice did not improve
# Epoch 00011: val_dice improved from 0.67781 to 0.67904, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6790-0.6553---1.hdf5
# 59s - loss: 0.3447 - dice: 0.6553 - binary_accuracy: 0.8272 - val_loss: 0.3210 - val_dice: 0.6790 - val_binary_accuracy: 0.8629
# Epoch 13/50
# Epoch 00012: dice improved from 0.65646 to 0.66275, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6841-0.6628---1.hdf5
# Epoch 00012: val_dice improved from 0.67904 to 0.68412, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6841-0.6628---1.hdf5
# 60s - loss: 0.3372 - dice: 0.6628 - binary_accuracy: 0.8297 - val_loss: 0.3159 - val_dice: 0.6841 - val_binary_accuracy: 0.8592
# Epoch 14/50
# Epoch 00013: dice did not improve
# Epoch 00013: val_dice did not improve
# 57s - loss: 0.3477 - dice: 0.6523 - binary_accuracy: 0.8239 - val_loss: 0.3212 - val_dice: 0.6788 - val_binary_accuracy: 0.8559
# Epoch 15/50
# Epoch 00014: dice did not improve
# Epoch 00014: val_dice did not improve
# 57s - loss: 0.3425 - dice: 0.6575 - binary_accuracy: 0.8227 - val_loss: 0.3735 - val_dice: 0.6265 - val_binary_accuracy: 0.7706
# Epoch 16/50
# Epoch 00015: dice did not improve
# Epoch 00015: val_dice improved from 0.68412 to 0.68585, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6858-0.6540---1.hdf5
# 59s - loss: 0.3460 - dice: 0.6540 - binary_accuracy: 0.8180 - val_loss: 0.3142 - val_dice: 0.6858 - val_binary_accuracy: 0.8643
# Epoch 17/50
# Epoch 00016: dice improved from 0.66275 to 0.66646, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6896-0.6665---1.hdf5
# Epoch 00016: val_dice improved from 0.68585 to 0.68956, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6896-0.6665---1.hdf5
# 60s - loss: 0.3335 - dice: 0.6665 - binary_accuracy: 0.8267 - val_loss: 0.3104 - val_dice: 0.6896 - val_binary_accuracy: 0.8680
# Epoch 18/50
# Epoch 00017: dice did not improve
# Epoch 00017: val_dice did not improve
# 57s - loss: 0.3343 - dice: 0.6657 - binary_accuracy: 0.8292 - val_loss: 0.3381 - val_dice: 0.6619 - val_binary_accuracy: 0.8075
# Epoch 19/50
# Epoch 00018: dice improved from 0.66646 to 0.67830, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6852-0.6783---1.hdf5
# Epoch 00018: val_dice did not improve
# 59s - loss: 0.3217 - dice: 0.6783 - binary_accuracy: 0.8430 - val_loss: 0.3148 - val_dice: 0.6852 - val_binary_accuracy: 0.8503
# Epoch 20/50
# Epoch 00019: dice did not improve
# Epoch 00019: val_dice did not improve
# 57s - loss: 0.3256 - dice: 0.6744 - binary_accuracy: 0.8344 - val_loss: 0.3157 - val_dice: 0.6843 - val_binary_accuracy: 0.8434
# Epoch 21/50
# Epoch 00020: dice improved from 0.67830 to 0.67926, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7169-0.6793---1.hdf5
# Epoch 00020: val_dice improved from 0.68956 to 0.71686, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7169-0.6793---1.hdf5
# 60s - loss: 0.3207 - dice: 0.6793 - binary_accuracy: 0.8342 - val_loss: 0.2831 - val_dice: 0.7169 - val_binary_accuracy: 0.8701
# Epoch 22/50
# Epoch 00021: dice improved from 0.67926 to 0.68356, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6941-0.6836---1.hdf5
# Epoch 00021: val_dice did not improve
# 59s - loss: 0.3164 - dice: 0.6836 - binary_accuracy: 0.8436 - val_loss: 0.3059 - val_dice: 0.6941 - val_binary_accuracy: 0.8565
# Epoch 23/50
# Epoch 00022: dice improved from 0.68356 to 0.69005, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6794-0.6901---1.hdf5
# Epoch 00022: val_dice did not improve
# 58s - loss: 0.3099 - dice: 0.6901 - binary_accuracy: 0.8463 - val_loss: 0.3206 - val_dice: 0.6794 - val_binary_accuracy: 0.8716
# Epoch 24/50
# Epoch 00023: dice did not improve
# Epoch 00023: val_dice improved from 0.71686 to 0.72275, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7228-0.6812---1.hdf5
# 59s - loss: 0.3188 - dice: 0.6812 - binary_accuracy: 0.8441 - val_loss: 0.2772 - val_dice: 0.7228 - val_binary_accuracy: 0.8794
# Epoch 25/50
# Epoch 00024: dice improved from 0.69005 to 0.70112, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7264-0.7011---1.hdf5
# Epoch 00024: val_dice improved from 0.72275 to 0.72637, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7264-0.7011---1.hdf5
# 60s - loss: 0.2989 - dice: 0.7011 - binary_accuracy: 0.8498 - val_loss: 0.2736 - val_dice: 0.7264 - val_binary_accuracy: 0.8805
# Epoch 26/50
# Epoch 00025: dice did not improve
# Epoch 00025: val_dice did not improve
# 57s - loss: 0.3006 - dice: 0.6994 - binary_accuracy: 0.8520 - val_loss: 0.3132 - val_dice: 0.6868 - val_binary_accuracy: 0.8692
# Epoch 27/50
# Epoch 00026: dice improved from 0.70112 to 0.70313, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7260-0.7031---1.hdf5
# Epoch 00026: val_dice did not improve
# 58s - loss: 0.2969 - dice: 0.7031 - binary_accuracy: 0.8604 - val_loss: 0.2740 - val_dice: 0.7260 - val_binary_accuracy: 0.8765
# Epoch 28/50
# Epoch 00027: dice improved from 0.70313 to 0.70849, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7068-0.7085---1.hdf5
# Epoch 00027: val_dice did not improve
# 58s - loss: 0.2915 - dice: 0.7085 - binary_accuracy: 0.8579 - val_loss: 0.2932 - val_dice: 0.7068 - val_binary_accuracy: 0.8742
# Epoch 29/50
#
# Epoch 00028: reducing learning rate to 0.00249999994412.
# Epoch 00028: dice did not improve
# Epoch 00028: val_dice did not improve
# 57s - loss: 0.2964 - dice: 0.7036 - binary_accuracy: 0.8536 - val_loss: 0.2822 - val_dice: 0.7178 - val_binary_accuracy: 0.8807
# Epoch 30/50
# Epoch 00029: dice improved from 0.70849 to 0.71272, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6975-0.7127---1.hdf5
# Epoch 00029: val_dice did not improve
# 58s - loss: 0.2873 - dice: 0.7127 - binary_accuracy: 0.8653 - val_loss: 0.3025 - val_dice: 0.6975 - val_binary_accuracy: 0.8468
# Epoch 31/50
# Epoch 00030: dice improved from 0.71272 to 0.72638, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7337-0.7264---1.hdf5
# Epoch 00030: val_dice improved from 0.72637 to 0.73372, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7337-0.7264---1.hdf5
# 65s - loss: 0.2736 - dice: 0.7264 - binary_accuracy: 0.8719 - val_loss: 0.2663 - val_dice: 0.7337 - val_binary_accuracy: 0.8826
# Epoch 32/50
# Epoch 00031: dice improved from 0.72638 to 0.72825, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7302-0.7283---1.hdf5
# Epoch 00031: val_dice did not improve
# 59s - loss: 0.2717 - dice: 0.7283 - binary_accuracy: 0.8751 - val_loss: 0.2698 - val_dice: 0.7302 - val_binary_accuracy: 0.8787
# Epoch 33/50
# Epoch 00032: dice improved from 0.72825 to 0.73162, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7355-0.7316---1.hdf5
# Epoch 00032: val_dice improved from 0.73372 to 0.73554, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7355-0.7316---1.hdf5
# 60s - loss: 0.2684 - dice: 0.7316 - binary_accuracy: 0.8771 - val_loss: 0.2645 - val_dice: 0.7355 - val_binary_accuracy: 0.8806
# Epoch 34/50
# Epoch 00033: dice did not improve
# Epoch 00033: val_dice improved from 0.73554 to 0.73995, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7400-0.7310---1.hdf5
# 58s - loss: 0.2690 - dice: 0.7310 - binary_accuracy: 0.8761 - val_loss: 0.2600 - val_dice: 0.7400 - val_binary_accuracy: 0.8820
# Epoch 35/50
# Epoch 00034: dice did not improve
# Epoch 00034: val_dice did not improve
# 57s - loss: 0.2693 - dice: 0.7307 - binary_accuracy: 0.8757 - val_loss: 0.2682 - val_dice: 0.7318 - val_binary_accuracy: 0.8794
# Epoch 36/50
# Epoch 00035: dice improved from 0.73162 to 0.73392, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7277-0.7339---1.hdf5
# Epoch 00035: val_dice did not improve
# 58s - loss: 0.2661 - dice: 0.7339 - binary_accuracy: 0.8766 - val_loss: 0.2723 - val_dice: 0.7277 - val_binary_accuracy: 0.8752
# Epoch 37/50
# Epoch 00036: dice did not improve
# Epoch 00036: val_dice did not improve
# 57s - loss: 0.2669 - dice: 0.7331 - binary_accuracy: 0.8766 - val_loss: 0.2614 - val_dice: 0.7386 - val_binary_accuracy: 0.8829
# Epoch 38/50
# Epoch 00037: dice did not improve
# Epoch 00037: val_dice improved from 0.73995 to 0.74256, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7426-0.7271---1.hdf5
# 58s - loss: 0.2729 - dice: 0.7271 - binary_accuracy: 0.8743 - val_loss: 0.2574 - val_dice: 0.7426 - val_binary_accuracy: 0.8873
# Epoch 39/50
# Epoch 00038: dice improved from 0.73392 to 0.73782, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7386-0.7378---1.hdf5
# Epoch 00038: val_dice did not improve
# 58s - loss: 0.2622 - dice: 0.7378 - binary_accuracy: 0.8789 - val_loss: 0.2614 - val_dice: 0.7386 - val_binary_accuracy: 0.8874
# Epoch 40/50
# Epoch 00039: dice did not improve
# Epoch 00039: val_dice did not improve
# 57s - loss: 0.2645 - dice: 0.7355 - binary_accuracy: 0.8817 - val_loss: 0.2790 - val_dice: 0.7210 - val_binary_accuracy: 0.8648
# Epoch 41/50
# Epoch 00040: dice improved from 0.73782 to 0.74283, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7421-0.7428---1.hdf5
# Epoch 00040: val_dice did not improve
# 58s - loss: 0.2572 - dice: 0.7428 - binary_accuracy: 0.8820 - val_loss: 0.2579 - val_dice: 0.7421 - val_binary_accuracy: 0.8856
# Epoch 42/50
#
# Epoch 00041: reducing learning rate to 0.00124999997206.
# Epoch 00041: dice improved from 0.74283 to 0.74967, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7317-0.7497---1.hdf5
# Epoch 00041: val_dice did not improve
# 58s - loss: 0.2503 - dice: 0.7497 - binary_accuracy: 0.8901 - val_loss: 0.2683 - val_dice: 0.7317 - val_binary_accuracy: 0.8748
# Epoch 43/50
# Epoch 00042: dice did not improve
# Epoch 00042: val_dice did not improve
# 57s - loss: 0.2522 - dice: 0.7478 - binary_accuracy: 0.8875 - val_loss: 0.2590 - val_dice: 0.7410 - val_binary_accuracy: 0.8868
# Epoch 44/50
# Epoch 00043: dice did not improve
# Epoch 00043: val_dice improved from 0.74256 to 0.74996, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7500-0.7460---1.hdf5
# 58s - loss: 0.2540 - dice: 0.7460 - binary_accuracy: 0.8875 - val_loss: 0.2500 - val_dice: 0.7500 - val_binary_accuracy: 0.8906
# Epoch 45/50
# Epoch 00044: dice improved from 0.74967 to 0.75507, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7423-0.7551---1.hdf5
# Epoch 00044: val_dice did not improve
# 58s - loss: 0.2449 - dice: 0.7551 - binary_accuracy: 0.8932 - val_loss: 0.2577 - val_dice: 0.7423 - val_binary_accuracy: 0.8809
# Epoch 46/50
# Epoch 00045: dice did not improve
# Epoch 00045: val_dice improved from 0.74996 to 0.75105, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7510-0.7538---1.hdf5
# 58s - loss: 0.2462 - dice: 0.7538 - binary_accuracy: 0.8886 - val_loss: 0.2490 - val_dice: 0.7510 - val_binary_accuracy: 0.8908
# Epoch 47/50
# Epoch 00046: dice improved from 0.75507 to 0.75712, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7420-0.7571---1.hdf5
# Epoch 00046: val_dice did not improve
# 58s - loss: 0.2429 - dice: 0.7571 - binary_accuracy: 0.8943 - val_loss: 0.2580 - val_dice: 0.7420 - val_binary_accuracy: 0.8878
# Epoch 48/50
# Epoch 00047: dice improved from 0.75712 to 0.75784, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7516-0.7578---1.hdf5
# Epoch 00047: val_dice improved from 0.75105 to 0.75163, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7516-0.7578---1.hdf5
# 60s - loss: 0.2422 - dice: 0.7578 - binary_accuracy: 0.8912 - val_loss: 0.2484 - val_dice: 0.7516 - val_binary_accuracy: 0.8915
# Epoch 49/50
# Epoch 00048: dice improved from 0.75784 to 0.75947, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7528-0.7595---1.hdf5
# Epoch 00048: val_dice improved from 0.75163 to 0.75275, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7528-0.7595---1.hdf5
# 60s - loss: 0.2405 - dice: 0.7595 - binary_accuracy: 0.8944 - val_loss: 0.2472 - val_dice: 0.7528 - val_binary_accuracy: 0.8920
# Epoch 50/50
# Epoch 00049: dice did not improve
# Epoch 00049: val_dice did not improve
# 57s - loss: 0.2406 - dice: 0.7594 - binary_accuracy: 0.8960 - val_loss: 0.2476 - val_dice: 0.7524 - val_binary_accuracy: 0.8903
# 2017-07-30 19:54:25.096620 ------------> 2
# Train on 114 samples, validate on 54 samples
# Epoch 1/50
# Epoch 00000: dice improved from -inf to 0.39576, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.4557-0.3958---2.hdf5
# Epoch 00000: val_dice improved from -inf to 0.45566, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.4557-0.3958---2.hdf5
# 64s - loss: 0.6042 - dice: 0.3958 - binary_accuracy: 0.3115 - val_loss: 0.5443 - val_dice: 0.4557 - val_binary_accuracy: 0.3377
# Epoch 2/50
# Epoch 00001: dice improved from 0.39576 to 0.43491, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.4800-0.4349---2.hdf5
# Epoch 00001: val_dice improved from 0.45566 to 0.48001, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.4800-0.4349---2.hdf5
# 63s - loss: 0.5651 - dice: 0.4349 - binary_accuracy: 0.3115 - val_loss: 0.5200 - val_dice: 0.4800 - val_binary_accuracy: 0.3377
# Epoch 3/50
# Epoch 00002: dice improved from 0.43491 to 0.47628, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.5366-0.4763---2.hdf5
# Epoch 00002: val_dice improved from 0.48001 to 0.53656, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.5366-0.4763---2.hdf5
# 63s - loss: 0.5237 - dice: 0.4763 - binary_accuracy: 0.5550 - val_loss: 0.4634 - val_dice: 0.5366 - val_binary_accuracy: 0.7279
# Epoch 4/50
# Epoch 00003: dice improved from 0.47628 to 0.56890, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6477-0.5689---2.hdf5
# Epoch 00003: val_dice improved from 0.53656 to 0.64766, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6477-0.5689---2.hdf5
# 62s - loss: 0.4311 - dice: 0.5689 - binary_accuracy: 0.7347 - val_loss: 0.3523 - val_dice: 0.6477 - val_binary_accuracy: 0.8055
# Epoch 5/50
# Epoch 00004: dice improved from 0.56890 to 0.61738, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6467-0.6174---2.hdf5
# Epoch 00004: val_dice did not improve
# 60s - loss: 0.3826 - dice: 0.6174 - binary_accuracy: 0.8012 - val_loss: 0.3533 - val_dice: 0.6467 - val_binary_accuracy: 0.8293
# Epoch 6/50
# Epoch 00005: dice improved from 0.61738 to 0.63165, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.5922-0.6316---2.hdf5
# Epoch 00005: val_dice did not improve
# 60s - loss: 0.3684 - dice: 0.6316 - binary_accuracy: 0.8135 - val_loss: 0.4078 - val_dice: 0.5922 - val_binary_accuracy: 0.6785
# Epoch 7/50
# Epoch 00006: dice did not improve
# Epoch 00006: val_dice improved from 0.64766 to 0.65945, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6594-0.6166---2.hdf5
# 60s - loss: 0.3834 - dice: 0.6166 - binary_accuracy: 0.8026 - val_loss: 0.3406 - val_dice: 0.6594 - val_binary_accuracy: 0.8277
# Epoch 8/50
# Epoch 00007: dice improved from 0.63165 to 0.64074, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.5517-0.6407---2.hdf5
# Epoch 00007: val_dice did not improve
# 60s - loss: 0.3593 - dice: 0.6407 - binary_accuracy: 0.8338 - val_loss: 0.4483 - val_dice: 0.5517 - val_binary_accuracy: 0.5984
# Epoch 9/50
# Epoch 00008: dice did not improve
# Epoch 00008: val_dice did not improve
# 58s - loss: 0.4063 - dice: 0.5937 - binary_accuracy: 0.7401 - val_loss: 0.3639 - val_dice: 0.6361 - val_binary_accuracy: 0.8372
# Epoch 10/50
# Epoch 00009: dice did not improve
# Epoch 00009: val_dice improved from 0.65945 to 0.67116, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6712-0.6321---2.hdf5
# 59s - loss: 0.3679 - dice: 0.6321 - binary_accuracy: 0.8192 - val_loss: 0.3288 - val_dice: 0.6712 - val_binary_accuracy: 0.8319
# Epoch 11/50
# Epoch 00010: dice improved from 0.64074 to 0.64444, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6779-0.6444---2.hdf5
# Epoch 00010: val_dice improved from 0.67116 to 0.67792, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6779-0.6444---2.hdf5
# 65s - loss: 0.3556 - dice: 0.6444 - binary_accuracy: 0.8330 - val_loss: 0.3221 - val_dice: 0.6779 - val_binary_accuracy: 0.8258
# Epoch 12/50
# Epoch 00011: dice did not improve
# Epoch 00011: val_dice improved from 0.67792 to 0.68181, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6818-0.6426---2.hdf5
# 59s - loss: 0.3574 - dice: 0.6426 - binary_accuracy: 0.8274 - val_loss: 0.3182 - val_dice: 0.6818 - val_binary_accuracy: 0.8307
# Epoch 13/50
# Epoch 00012: dice improved from 0.64444 to 0.65151, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6777-0.6515---2.hdf5
# Epoch 00012: val_dice did not improve
# 59s - loss: 0.3485 - dice: 0.6515 - binary_accuracy: 0.8328 - val_loss: 0.3223 - val_dice: 0.6777 - val_binary_accuracy: 0.8094
# Epoch 14/50
# Epoch 00013: dice did not improve
# Epoch 00013: val_dice improved from 0.68181 to 0.68370, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6837-0.6467---2.hdf5
# 59s - loss: 0.3533 - dice: 0.6467 - binary_accuracy: 0.8340 - val_loss: 0.3163 - val_dice: 0.6837 - val_binary_accuracy: 0.8329
# Epoch 15/50
# Epoch 00014: dice improved from 0.65151 to 0.65660, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6839-0.6566---2.hdf5
# Epoch 00014: val_dice improved from 0.68370 to 0.68392, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6839-0.6566---2.hdf5
# 61s - loss: 0.3434 - dice: 0.6566 - binary_accuracy: 0.8376 - val_loss: 0.3161 - val_dice: 0.6839 - val_binary_accuracy: 0.8358
# Epoch 16/50
# Epoch 00015: dice did not improve
# Epoch 00015: val_dice improved from 0.68392 to 0.68683, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6868-0.6345---2.hdf5
# 60s - loss: 0.3655 - dice: 0.6345 - binary_accuracy: 0.8170 - val_loss: 0.3132 - val_dice: 0.6868 - val_binary_accuracy: 0.8403
# Epoch 17/50
# Epoch 00016: dice did not improve
# Epoch 00016: val_dice improved from 0.68683 to 0.68840, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6884-0.6519---2.hdf5
# 59s - loss: 0.3481 - dice: 0.6519 - binary_accuracy: 0.8296 - val_loss: 0.3116 - val_dice: 0.6884 - val_binary_accuracy: 0.8272
# Epoch 18/50
# Epoch 00017: dice did not improve
# Epoch 00017: val_dice did not improve
# 58s - loss: 0.3449 - dice: 0.6551 - binary_accuracy: 0.8367 - val_loss: 0.3120 - val_dice: 0.6880 - val_binary_accuracy: 0.8210
# Epoch 19/50
# Epoch 00018: dice improved from 0.65660 to 0.65959, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6928-0.6596---2.hdf5
# Epoch 00018: val_dice improved from 0.68840 to 0.69275, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6928-0.6596---2.hdf5
# 61s - loss: 0.3404 - dice: 0.6596 - binary_accuracy: 0.8396 - val_loss: 0.3072 - val_dice: 0.6928 - val_binary_accuracy: 0.8463
# Epoch 20/50
# Epoch 00019: dice improved from 0.65959 to 0.66193, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7058-0.6619---2.hdf5
# Epoch 00019: val_dice improved from 0.69275 to 0.70580, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7058-0.6619---2.hdf5
# 61s - loss: 0.3381 - dice: 0.6619 - binary_accuracy: 0.8396 - val_loss: 0.2942 - val_dice: 0.7058 - val_binary_accuracy: 0.8422
# Epoch 21/50
# Epoch 00020: dice improved from 0.66193 to 0.66928, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7004-0.6693---2.hdf5
# Epoch 00020: val_dice did not improve
# 59s - loss: 0.3307 - dice: 0.6693 - binary_accuracy: 0.8489 - val_loss: 0.2996 - val_dice: 0.7004 - val_binary_accuracy: 0.8312
# Epoch 22/50
# Epoch 00021: dice improved from 0.66928 to 0.67426, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7091-0.6743---2.hdf5
# Epoch 00021: val_dice improved from 0.70580 to 0.70914, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7091-0.6743---2.hdf5
# 61s - loss: 0.3257 - dice: 0.6743 - binary_accuracy: 0.8574 - val_loss: 0.2909 - val_dice: 0.7091 - val_binary_accuracy: 0.8523
# Epoch 23/50
# Epoch 00022: dice did not improve
# Epoch 00022: val_dice did not improve
# 58s - loss: 0.3266 - dice: 0.6734 - binary_accuracy: 0.8437 - val_loss: 0.2987 - val_dice: 0.7013 - val_binary_accuracy: 0.8387
# Epoch 24/50
# Epoch 00023: dice did not improve
# Epoch 00023: val_dice did not improve
# 58s - loss: 0.3327 - dice: 0.6673 - binary_accuracy: 0.8425 - val_loss: 0.2938 - val_dice: 0.7062 - val_binary_accuracy: 0.8370
# Epoch 25/50
# Epoch 00024: dice improved from 0.67426 to 0.68051, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7086-0.6805---2.hdf5
# Epoch 00024: val_dice did not improve
# 59s - loss: 0.3195 - dice: 0.6805 - binary_accuracy: 0.8532 - val_loss: 0.2914 - val_dice: 0.7086 - val_binary_accuracy: 0.8480
# Epoch 26/50
# Epoch 00025: dice did not improve
# Epoch 00025: val_dice improved from 0.70914 to 0.71381, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7138-0.6759---2.hdf5
# 59s - loss: 0.3241 - dice: 0.6759 - binary_accuracy: 0.8556 - val_loss: 0.2862 - val_dice: 0.7138 - val_binary_accuracy: 0.8485
# Epoch 27/50
# Epoch 00026: dice improved from 0.68051 to 0.68449, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7086-0.6845---2.hdf5
# Epoch 00026: val_dice did not improve
# 59s - loss: 0.3155 - dice: 0.6845 - binary_accuracy: 0.8573 - val_loss: 0.2914 - val_dice: 0.7086 - val_binary_accuracy: 0.8550
# Epoch 28/50
# Epoch 00027: dice did not improve
# Epoch 00027: val_dice did not improve
# 58s - loss: 0.3242 - dice: 0.6758 - binary_accuracy: 0.8553 - val_loss: 0.2895 - val_dice: 0.7105 - val_binary_accuracy: 0.8401
# Epoch 29/50
# Epoch 00028: dice improved from 0.68449 to 0.68734, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7154-0.6873---2.hdf5
# Epoch 00028: val_dice improved from 0.71381 to 0.71537, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7154-0.6873---2.hdf5
# 61s - loss: 0.3127 - dice: 0.6873 - binary_accuracy: 0.8608 - val_loss: 0.2846 - val_dice: 0.7154 - val_binary_accuracy: 0.8570
# Epoch 30/50
# Epoch 00029: dice improved from 0.68734 to 0.69038, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7162-0.6904---2.hdf5
# Epoch 00029: val_dice improved from 0.71537 to 0.71620, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7162-0.6904---2.hdf5
# 60s - loss: 0.3096 - dice: 0.6904 - binary_accuracy: 0.8636 - val_loss: 0.2838 - val_dice: 0.7162 - val_binary_accuracy: 0.8570
# Epoch 31/50
# Epoch 00030: dice improved from 0.69038 to 0.69052, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7228-0.6905---2.hdf5
# Epoch 00030: val_dice improved from 0.71620 to 0.72277, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7228-0.6905---2.hdf5
# 61s - loss: 0.3095 - dice: 0.6905 - binary_accuracy: 0.8654 - val_loss: 0.2772 - val_dice: 0.7228 - val_binary_accuracy: 0.8601
# Epoch 32/50
# Epoch 00031: dice did not improve
# Epoch 00031: val_dice improved from 0.72277 to 0.72910, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7291-0.6891---2.hdf5
# 59s - loss: 0.3109 - dice: 0.6891 - binary_accuracy: 0.8633 - val_loss: 0.2709 - val_dice: 0.7291 - val_binary_accuracy: 0.8566
# Epoch 33/50
# Epoch 00032: dice did not improve
# Epoch 00032: val_dice did not improve
# 58s - loss: 0.3115 - dice: 0.6885 - binary_accuracy: 0.8647 - val_loss: 0.2828 - val_dice: 0.7172 - val_binary_accuracy: 0.8444
# Epoch 34/50
# Epoch 00033: dice improved from 0.69052 to 0.69959, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7002-0.6996---2.hdf5
# Epoch 00033: val_dice did not improve
# 59s - loss: 0.3004 - dice: 0.6996 - binary_accuracy: 0.8692 - val_loss: 0.2998 - val_dice: 0.7002 - val_binary_accuracy: 0.8225
# Epoch 35/50
# Epoch 00034: dice improved from 0.69959 to 0.70077, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7097-0.7008---2.hdf5
# Epoch 00034: val_dice did not improve
# 59s - loss: 0.2992 - dice: 0.7008 - binary_accuracy: 0.8679 - val_loss: 0.2903 - val_dice: 0.7097 - val_binary_accuracy: 0.8639
# Epoch 36/50
#
# Epoch 00035: reducing learning rate to 0.00499999988824.
# Epoch 00035: dice did not improve
# Epoch 00035: val_dice did not improve
# 58s - loss: 0.3074 - dice: 0.6926 - binary_accuracy: 0.8667 - val_loss: 0.2960 - val_dice: 0.7040 - val_binary_accuracy: 0.8251
# Epoch 37/50
# Epoch 00036: dice improved from 0.70077 to 0.70431, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7231-0.7043---2.hdf5
# Epoch 00036: val_dice did not improve
# 60s - loss: 0.2957 - dice: 0.7043 - binary_accuracy: 0.8749 - val_loss: 0.2769 - val_dice: 0.7231 - val_binary_accuracy: 0.8530
# Epoch 38/50
# Epoch 00037: dice improved from 0.70431 to 0.70974, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7392-0.7097---2.hdf5
# Epoch 00037: val_dice improved from 0.72910 to 0.73925, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7392-0.7097---2.hdf5
# 61s - loss: 0.2903 - dice: 0.7097 - binary_accuracy: 0.8736 - val_loss: 0.2608 - val_dice: 0.7392 - val_binary_accuracy: 0.8611
# Epoch 39/50
# Epoch 00038: dice did not improve
# Epoch 00038: val_dice improved from 0.73925 to 0.74491, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7449-0.7080---2.hdf5
# 59s - loss: 0.2920 - dice: 0.7080 - binary_accuracy: 0.8719 - val_loss: 0.2551 - val_dice: 0.7449 - val_binary_accuracy: 0.8671
# Epoch 40/50
# Epoch 00039: dice did not improve
# Epoch 00039: val_dice did not improve
# 58s - loss: 0.2932 - dice: 0.7068 - binary_accuracy: 0.8709 - val_loss: 0.2610 - val_dice: 0.7390 - val_binary_accuracy: 0.8544
# Epoch 41/50
# Epoch 00040: dice improved from 0.70974 to 0.71235, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7387-0.7123---2.hdf5
# Epoch 00040: val_dice did not improve
# 59s - loss: 0.2877 - dice: 0.7123 - binary_accuracy: 0.8682 - val_loss: 0.2613 - val_dice: 0.7387 - val_binary_accuracy: 0.8626
# Epoch 42/50
# Epoch 00041: dice improved from 0.71235 to 0.72126, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7394-0.7213---2.hdf5
# Epoch 00041: val_dice did not improve
# 59s - loss: 0.2787 - dice: 0.7213 - binary_accuracy: 0.8778 - val_loss: 0.2606 - val_dice: 0.7394 - val_binary_accuracy: 0.8615
# Epoch 43/50
# Epoch 00042: dice improved from 0.72126 to 0.73163, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7482-0.7316---2.hdf5
# Epoch 00042: val_dice improved from 0.74491 to 0.74817, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7482-0.7316---2.hdf5
# 63s - loss: 0.2684 - dice: 0.7316 - binary_accuracy: 0.8846 - val_loss: 0.2518 - val_dice: 0.7482 - val_binary_accuracy: 0.8699
# Epoch 44/50
# Epoch 00043: dice did not improve
# Epoch 00043: val_dice improved from 0.74817 to 0.75021, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7502-0.7177---2.hdf5
# 59s - loss: 0.2823 - dice: 0.7177 - binary_accuracy: 0.8773 - val_loss: 0.2498 - val_dice: 0.7502 - val_binary_accuracy: 0.8708
# Epoch 45/50
# Epoch 00044: dice did not improve
# Epoch 00044: val_dice improved from 0.75021 to 0.76131, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7613-0.7235---2.hdf5
# 59s - loss: 0.2765 - dice: 0.7235 - binary_accuracy: 0.8800 - val_loss: 0.2387 - val_dice: 0.7613 - val_binary_accuracy: 0.8744
# Epoch 46/50
# Epoch 00045: dice did not improve
# Epoch 00045: val_dice did not improve
# 58s - loss: 0.2737 - dice: 0.7263 - binary_accuracy: 0.8856 - val_loss: 0.2415 - val_dice: 0.7585 - val_binary_accuracy: 0.8852
# Epoch 47/50
# Epoch 00046: dice improved from 0.73163 to 0.73697, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.6656-0.7370---2.hdf5
# Epoch 00046: val_dice did not improve
# 59s - loss: 0.2630 - dice: 0.7370 - binary_accuracy: 0.8867 - val_loss: 0.3344 - val_dice: 0.6656 - val_binary_accuracy: 0.7683
# Epoch 48/50
# Epoch 00047: dice did not improve
# Epoch 00047: val_dice improved from 0.76131 to 0.76546, saving model to ../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7655-0.7360---2.hdf5
# 59s - loss: 0.2640 - dice: 0.7360 - binary_accuracy: 0.8853 - val_loss: 0.2345 - val_dice: 0.7655 - val_binary_accuracy: 0.8743
# Epoch 49/50
# Epoch 00048: dice did not improve
# Epoch 00048: val_dice did not improve
# 58s - loss: 0.2659 - dice: 0.7341 - binary_accuracy: 0.8919 - val_loss: 0.2817 - val_dice: 0.7183 - val_binary_accuracy: 0.8376
# Epoch 50/50
# Epoch 00049: dice did not improve
# Epoch 00049: val_dice did not improve
# 58s - loss: 0.2665 - dice: 0.7335 - binary_accuracy: 0.8849 - val_loss: 0.2797 - val_dice: 0.7203 - val_binary_accuracy: 0.8286
# 2017-07-30 20:44:40.767301

# %%
#!ls ../Temp/TempTempG5M5KFold -la | tail
#!ls ../Temp/TempTempG5M5KFold10 -la | tail
# !ls ../Temp/NewStep/StandartF3 -la | tail
# Out:
# -rwxrwxrwx 1 boba boba 248917120 июл 30 19:42 V1-UNET-val_dice=0.7426-0.7271---1.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 20:33 V1-UNET-val_dice=0.7449-0.7080---2.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 20:37 V1-UNET-val_dice=0.7482-0.7316---2.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 19:48 V1-UNET-val_dice=0.7500-0.7460---1.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 20:38 V1-UNET-val_dice=0.7502-0.7177---2.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 19:50 V1-UNET-val_dice=0.7510-0.7538---1.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 19:52 V1-UNET-val_dice=0.7516-0.7578---1.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 19:53 V1-UNET-val_dice=0.7528-0.7595---1.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 20:39 V1-UNET-val_dice=0.7613-0.7235---2.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 20:42 V1-UNET-val_dice=0.7655-0.7360---2.hdf5

# %%
if 0 : model10 = load_model('../Temp/TrainModel001+G+M/V1-UNET-0.8511.hdf5')
if 0 : model10 = load_model('../Temp/V1-UNET-0.8853.hdf5')
#if 1 : model10 = load_model('../Temp/TempTempM3/V1-UNET-0.9054.hdf5')
if 0 : model10.load_weights('../Temp/TempTempM3/V1-UNET-0.9054.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5/V1-UNET-val_dice=0.7307.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7879-2.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7632-2.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7660-2.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7828-2.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFold5/V1-UNET-val_dice=0.8224-0.8516---1.hdf5') # 769128
if 0 : model10.load_weights('../Temp/TempTempG5M5KFold5/V1-UNET-val_dice=0.8217-0.8655---1.hdf5') # 765XXX
if 0 : model10.load_weights('../Temp/TempTempG5M5KFold5/V1-UNET-val_dice=0.8227-0.8643---3.hdf5')    
if 0 : model10.load_weights('../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8315-0.8617---9.hdf5')    
if 1 : model10.load_weights('../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7655-0.7360---2.hdf5')

# %%
# %time trP = model10.predict(trX,batch_size=batch_size)
# Out:
# CPU times: user 15.4 s, sys: 3.51 s, total: 18.9 s
# Wall time: 18.1 s

# %%
trP01 = trP
trP01[trP>0.5] =1.0
trP01[trP<=0.5]=0.0
trP01 = trP01.astype(np.uint8)

# %%
if 0 : # Ощутимых результатов не дает, увеличение в +10-100
    times, medianP = 3,5
    for i in range(trP01.shape[0]) :
        for j in range(times) :
            trP01[i,:,:,0] = cv.medianBlur(trP01[i],medianP)

# %%
iii = 0
print(trX[0].shape,trY[0].shape,trP.shape,trP.min(),trP.max())
for ii in range(iii,iii+10) :
    plt.figure(figsize=(15,5))
    plt.subplot(151); plt.imshow(trX[ii,:,:,0],'gray'); 
    plt.subplot(152); plt.imshow(trY[ii,:,:,0],'gray'); 
    plt.subplot(153); plt.imshow(trP[ii,:,:,0],'gray'); 
    plt.subplot(154); plt.imshow(trP01[ii,:,:,0],'gray'); 
    plt.subplot(155); plt.hist(trP[ii,:,:,0].ravel(),bins=50); 
    plt.show()
plt.close()
# Out:
# (512, 512, 3) (512, 512, 1) (168, 512, 512, 1) 0.0 1.0

# %%
# Calculate F1-micro

# %%
TP = (trY[:,6:506,6:506,0]*trP01[:,6:506,6:506,0]).sum()
TN = ((1.0-trY[:,6:506,6:506,0])*(1.0-trP01[:,6:506,6:506,0])).sum()
FP = ((trY[:,6:506,6:506,0])*(1.0-trP01[:,6:506,6:506,0])).sum()
FN = ((1.0-trY[:,6:506,6:506,0])*(trP01[:,6:506,6:506,0])).sum()

P  = TP/(TP+FP) if (TP+FP)>0.0 else 1.0
R  = TP/(TP+FN) if (TP+FN)>0.0 else 0.0

F1 = 2.0*P*R/(P+R) if (P+R)>0.0 else 0.0

TP,TN,FP,FN,P,R,F1
#P*R,P+R, 2.0*P*R/(P+R)
# Out:
# (12374739.0,
#  24486318.0,
#  1713481.0,
#  3425462.0,
#  0.87837491180574978,
#  0.78320136560288067,
#  0.82806241253092638)

# %%
# Calculate DI- dice.mean()

# %%
dice, XX = [],[]
for i in range(trP.shape[0]) :
    G = trY  [i,6:506,6:506,0].sum()
    S = trP01[i,6:506,6:506,0].sum()
    X = (trY [i,6:506,6:506,0]*trP01[i,6:506,6:506,0]).sum()
    XX.append(X)
    dice.append((2.0*X/(G+S) if G+S>0 else 1.0))
di = (np.array(dice)).mean()
di #,np.array(dice)  #,np.array(XX)
# Out:
# 0.76147537905565321

# %%
plt.hist(np.array(dice),bins=40); plt.show()
plt.plot(np.array(dice)); plt.show()

# %%
1000000*(F1+di)/2.0
# Out:
# 794768.89579328976

# %%
#np.array(dice)<0.4

# %%
# Подготовка test решения

# %%
if flagGray :
    trO, trO0 = [], np.zeros((512,512,1))
else :
    trO, trO0 = [], np.zeros((512,512,3))

for xx in listTest :
    img = cv.imread(os.path.join(dirTest,xx),-1)
    if 1 and (Gauss or Median): 
        for cc in range(img.shape[2]) : 
            if Gauss  : img[:,:,cc] = cv.GaussianBlur(img[:,:,cc],(Gauss,Gauss),0);
            if Median : img[:,:,cc] = cv.medianBlur  (img[:,:,cc],Median);
    #print(img.mean(),msk.mean())
    if flagGray :
        img = cv.cvtColor(img,cv.COLOR_RGB2GRAY);
        trO0[6:506,6:506,0] = img[:,:]/255.0
    else :
        trO0[6:506,6:506,:] = img[:,:,:]/255.0
    trO.append(trO0.copy())
    #print(trX0.mean(),trY0.mean(),trX1[-1].mean(),trY1[-1].mean())

#print([trY[xx].mean() for xx in range(10)])
trO = np.array(trO)

if 1 :
    for cc in range(meanX.shape[0]) : 
        trO[:,6:506,6:506,cc] -= meanX[cc]
    
trO.shape, trO.min(), trO.max()
#[trY[xx].mean() for xx in range(10)]
# Out:
# ((162, 512, 512, 3), -0.64172901643310909, 0.47912580261435694)

# %%
# %time trOP = model10.predict(trO,batch_size=batch_size)
# Out:
# CPU times: user 14.9 s, sys: 3.18 s, total: 18.1 s
# Wall time: 17.4 s

# %%
trOP01 = trOP
trOP01[trOP>0.5] =1.0
trOP01[trOP<=0.5]=0.0

# %%
iii = 40
print(trO[0].shape,trP01[0].shape,trOP01.shape,trOP.min(),trOP.max())
for ii in range(iii,iii+10) :
    plt.figure(figsize=(15,5))
    plt.subplot(151); plt.imshow(trO[ii,:,:,0]); 
    plt.subplot(152); plt.imshow(trOP01[ii,:,:,0],'gray'); 
    plt.subplot(153); plt.imshow(trOP[ii,:,:,0],'gray'); 
    plt.subplot(154); plt.hist(trOP[ii,:,:,0].ravel(),bins=50); 
    plt.show()
plt.close()
# Out:
# (512, 512, 3) (512, 512, 1) (162, 512, 512, 1) 0.0 1.0

# %%
# Формирование выходной директории

# %%
def convert_to_binary(truth_png_file, truth_txt_file):
    im = Image.open(truth_png_file) #Can be many different formats.
    pix = im.load()
    with open(truth_txt_file, 'w') as out:
        for x in xrange(500):
            for y in xrange(500):
                out.write(str(int(pix[x, y] > 0)))
            out.write('\n')

if not os.path.exists('../Temp/random_submission'):
    os.makedirs('../Temp/random_submission')

# Training
for i in range(len(listTrain)) :
    fn = listTrain[i]
    truth_txt_file = '../Temp/random_submission/' + fn.split('.')[0] + '_mask.txt'
    with open(truth_txt_file, 'w') as out:
        for x in xrange(500):
            for y in xrange(500):
                out.write(str(int(trP01[i,y+6, x+6] > 0.0)))
            out.write('\n')
    out.close()
    
# Testing
for i in range(len(listTest)) :
    fn = listTest[i]
    truth_txt_file = '../Temp/random_submission/' + fn.split('.')[0] + '_mask.txt'
    with open(truth_txt_file, 'w') as out:
        for x in xrange(500):
            for y in xrange(500):
                out.write(str(int(trOP01[i,y+6, x+6] > 0.0)))
            out.write('\n')
    out.close()

# %%
import shutil

# %%
xx=shutil.make_archive('../Result/topcoderkonica','zip','../Temp/random_submission')
xx
# Out:
# '/media/boba/DATA/boba/Working/TopCoder/2017-07-25-Konica-Minolta/Result/topcoderkonica.zip'

# %%
# !ls ../Temp -la
# Out:
# total 4610508
# drwxrwxrwx 1 boba boba      4096 июл 26 10:58 .
# drwxrwxrwx 1 boba boba      4096 июл 26 10:11 ..
# drwxrwxrwx 1 boba boba         0 июл 25 18:17 .ipynb_checkpoints
# drwxrwxrwx 1 boba boba     61440 июл 26 09:14 random_submission
# -rwxrwxrwx 1 boba boba   1057596 июл 26 10:58 random_submission.zip
# drwxrwxrwx 1 boba boba         0 июл 25 23:35 TrainModel001-G-M
# drwxrwxrwx 1 boba boba         0 июл 25 22:21 TrainModel001-G+M
# drwxrwxrwx 1 boba boba         0 июл 25 21:48 TrainModel001+G-M
# drwxrwxrwx 1 boba boba      4096 июл 25 21:05 TrainModel001+G+M
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:02 V1-UNET-0.8167.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:08 V1-UNET-0.8275.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 18:33 V1-UNET-0.8305.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 18:02 V1-UNET-0.8418.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:09 V1-UNET-0.8486.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:09 V1-UNET-0.8593.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 18:34 V1-UNET-0.8601.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:21 V1-UNET-0.8602.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:22 V1-UNET-0.8605.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:35 V1-UNET-0.8628.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:35 V1-UNET-0.8633.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:23 V1-UNET-0.8635.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:36 V1-UNET-0.8645.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:36 V1-UNET-0.8652.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:24 V1-UNET-0.8655.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:11 V1-UNET-0.8793.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:13 V1-UNET-0.8796.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:14 V1-UNET-0.8808.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 18:02 V1-UNET-0.8853.hdf5

# %%
# !ls ../Work -la
#!ls ../Temp/random_submission
# Out:
# total 80768
# drwxrwxrwx 1 boba boba        0 июл 26 09:17 .
# drwxrwxrwx 1 boba boba     4096 июл 25 15:24 ..
# -rwxrwxrwx 1 boba boba 82700662 июл 26 09:32 topcoderkonica.zip

# %%
if False :
    save_model(model10,'../Data-Keras/Models/model-UNet.h5')
    model10.save_weights('../Data-Keras/Models/model-UNet-weights.h5')

# %%
rrr=pd.DataFrame(res,columns=['image_name','tags']); rrr.head(); 
suffixDT = (datetime.datetime.now()).strftime('%Y-%m-%d-%H-%M-%S'); print(suffixDT)
rrr.to_csv('../Result/vss'+suffixDT+'.csv',index=False);
# Out:
# 2017-05-20-05-51-18
