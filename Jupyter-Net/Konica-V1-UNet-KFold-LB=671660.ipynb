# %%
##
## UNet 
##
## Взята идея по описанию из https://github.com/pietz/unet-keras
##
##
##

# %%
import sys,os,datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import fbeta_score
import sklearn.metrics as skm
from __future__ import print_function

# %%
print(np.__version__);
print(pd.__version__);
# Out:
# 1.13.1
# 0.19.2

# %%
import  cv2 as cv
cv.__version__
# Out:
# '3.2.0'

# %%
#from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.models import Sequential, save_model, load_model, Input, Model
from keras.layers import Convolution2D, MaxPooling2D, Convolution1D, MaxPooling1D, UpSampling2D, ZeroPadding2D
from keras.layers import Conv2D, Concatenate, Reshape
from keras.layers import Activation, Dropout, Flatten, Dense, Permute
from keras.layers.normalization import BatchNormalization
import keras.optimizers
from keras.callbacks import EarlyStopping,ReduceLROnPlateau,ModelCheckpoint
import keras.backend as K
# Out:
# Using TensorFlow backend.

# %%
keras.__version__
# Out:
# '2.0.6'

# %%
#---------------------------------------------------------------------

# %%
# !ls -la ..
# !ls -la ../Data
# !ls -la ../Data/training
# Out:
# total 17
# drwxrwxrwx 1 boba boba 4096 июл 26 11:10 .
# drwxrwxrwx 1 boba boba    0 июл 25 09:21 ..
# drwxrwxrwx 1 boba boba 4096 июл 25 09:23 Data
# drwxrwxrwx 1 boba boba    0 июл 25 09:22 Data-Arch
# drwxrwxrwx 1 boba boba    0 июл 25 09:26 Data-Keras
# drwxrwxrwx 1 boba boba 4096 июл 26 20:28 .git
# -rwxrwxrwx 2 boba boba  130 июл  9 12:02 .gitignore
# drwxrwxrwx 1 boba boba    0 июл 26 10:11 .ipynb_checkpoints
# drwxrwxrwx 1 boba boba  280 июл 26 20:28 Jupyter
# drwxrwxrwx 1 boba boba  576 июл 26 20:28 Jupyter-Net
# drwxrwxrwx 1 boba boba    0 июл 26 12:27 Result
# drwxrwxrwx 1 boba boba 4096 июл 26 20:00 Temp
# drwxrwxrwx 1 boba boba    0 июл 26 09:17 Work
# total 16
# drwxrwxrwx 1 boba boba 4096 июл 25 09:23 .
# drwxrwxrwx 1 boba boba 4096 июл 26 11:10 ..
# -rwxrwxrwx 2 boba boba 1060 июн 13 15:55 null_submission_generator.py
# -rwxrwxrwx 2 boba boba 1197 июн 13 16:03 random_submission_generator.py
# drwxrwxrwx 1 boba boba    0 июл 24 23:10 testing
# drwxrwxrwx 1 boba boba    0 июл 25 08:14 training
# total 220
# drwxrwxrwx 1 boba boba      0 июл 25 08:14 .
# drwxrwxrwx 1 boba boba   4096 июл 25 09:23 ..
# -rwxrwxrwx 2 boba boba  14340 июн 20 10:04 .DS_Store
# drwxrwxrwx 1 boba boba  40960 июл 25 08:14 images
# drwxrwxrwx 1 boba boba 163840 июл 25 09:17 truth

# %%
dirData = '../Data'
dirTemp = '../Temp'
dirWork = '../Work'

dirTest  = os.path.join(dirData,'testing','images')
dirTrain = os.path.join(dirData,'training','images')
dirMask  = os.path.join(dirData,'training','truth')

# %%
listTrain = os.listdir(dirTrain)
listMask  = os.listdir(dirMask)
listTest  = os.listdir(dirTest)
listTrain = [xx for xx in listTrain if os.path.splitext(xx)[1]=='.tif']
listMask  = [xx for xx in listMask  if os.path.splitext(xx)[1]=='.png']
listTest  = [xx for xx in listTest  if os.path.splitext(xx)[1]=='.tif']
print(len(listTrain),len(listMask),len(listTest))
print(listTrain[:5],'\n',listMask[:5],'\n',listTest[:5])
# Out:
# 168 168 162
# ['i105404.tif', 'i117557.tif', 'i124017.tif', 'i130790.tif', 'i137857.tif']
#  ['i105404_mask.png', 'i117557_mask.png', 'i124017_mask.png', 'i130790_mask.png', 'i137857_mask.png']
#  ['i105047.tif', 'i116596.tif', 'i137649.tif', 'i140176.tif', 'i142099.tif']

# %%
for xx in listTrain[:5] :
    img = cv.imread(os.path.join(dirTrain,xx),-1)
    xxm = os.path.splitext(xx)[0]+"_mask.png"
    msk = cv.imread(os.path.join(dirMask,xxm),-1)
    plt.subplot(121); plt.imshow(img); plt.subplot(122); plt.imshow(msk,'gray'); plt.show()
plt.close()

# %%
msk.shape, img.shape, img.min(), img.max(), msk.max(), #img[6:10,6:10], msk[6:10,6:10]
# Out:
# ((500, 500), (500, 500, 3), 2, 255, 255)

# %%
flagGray = False
Gauss    = 5
Median   = 5
if flagGray :
    trX, trY, trX0, trY0 = [], [], np.zeros((512,512,1)), np.zeros((512,512,1))
else :
    trX, trY, trX0, trY0 = [], [], np.zeros((512,512,3)), np.zeros((512,512,1))

for xx in listTrain :
    img = cv.imread(os.path.join(dirTrain,xx),-1)
    if 1 and (Gauss or Median): 
        for cc in range(img.shape[2]) : 
            if Gauss  : img[:,:,cc] = cv.GaussianBlur(img[:,:,cc],(Gauss,Gauss),0);
            if Median : img[:,:,cc] = cv.medianBlur  (img[:,:,cc],Median);
    xxm = os.path.splitext(xx)[0]+"_mask.png"
    msk = cv.imread(os.path.join(dirMask,xxm),-1)
    #print(img.mean(),msk.mean())
    if flagGray :
        img = cv.cvtColor(img,cv.COLOR_RGB2GRAY);
        trX0[6:506,6:506,0] = img[:,:]/255.0
        trY0[6:506,6:506,0] = msk[:,:]/255.0
    else :
        trX0[6:506,6:506,:] = img[:,:,:]/255.0
        trY0[6:506,6:506,0] = msk[:,:]/255.0
        trY0[trY0>=0.5] = 1.0
    trX.append(trX0.copy())
    trY.append(trY0.copy())
    #print(trX0.mean(),trY0.mean(),trX1[-1].mean(),trY1[-1].mean())

#print([trY[xx].mean() for xx in range(10)])
trX = np.array(trX)
trY = np.array(trY)
    
trX.shape, trX.min(), trX.max(), trY.shape, trY.min(), trY.max()
#[trY[xx].mean() for xx in range(10)]
# Out:
# ((168, 512, 512, 3), 0.0, 0.9882352941176471, (168, 512, 512, 1), 0.0, 1.0)

# %%
for xx in range(5) :
    img = trX[xx]
    xxm = trY[xx]
    plt.subplot(121); plt.imshow(img); plt.subplot(122); plt.imshow(xxm[:,:,0],'gray'); plt.show()
plt.close()

# %%
#
# model UNET
#
#    https://github.com/pietz/unet-keras
#
#

def level_block(m, dim, depth, acti):
    if depth > 0:
        
        x = BatchNormalization(axis=3)(m)
        n = Conv2D(dim, (3, 3), activation=acti, padding='same')(x) #(m)
        n = Conv2D(dim, (3, 3), activation=acti, padding='same')(n)
        n = Dropout(0.25)(n) ## add
        m = MaxPooling2D((2, 2))(n)
        m = level_block(m, 2*dim, depth-1, acti)
        m = UpSampling2D((2, 2))(m)
        m = Conv2D(dim, (2, 2), activation=acti, padding='same')(m)
        m = Dropout(0.25)(m) ## add
        m = Concatenate(axis=3)([n, m])
    m = Conv2D(dim, (3, 3), activation=acti, padding='same')(m)
    return Conv2D(dim, (3, 3), activation=acti, padding='same')(m)

def UNet(img_shape, n_out=2, dim=64, depth=4, acti='relu', flatten=False):
    i = Input(shape=img_shape)
    ## ???? i = ZeroPadding2D((6,6),data_format="channels_last")
    o = level_block(i, dim, depth, acti)
    o = Conv2D(n_out, (1, 1), name='prediction')(o)
    if flatten:
        o = Reshape(n_out, img_shape[0] * img_shape[1])(o)
        o = Permute((2, 1))(o)
    #o = Activation('relu')(o)
    o = Activation('sigmoid')(o)
    return Model(inputs=i, outputs=o)

# %%
model10 = UNet((512,512,3),depth=4,n_out=1)
model10.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 512, 512, 3)   0
# ____________________________________________________________________________________________________
# batch_normalization_1 (BatchNorm (None, 512, 512, 3)   12          input_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_1 (Conv2D)                (None, 512, 512, 64)  1792        batch_normalization_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_2 (Conv2D)                (None, 512, 512, 64)  36928       conv2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 512, 512, 64)  0           conv2d_2[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)   (None, 256, 256, 64)  0           dropout_1[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_2 (BatchNorm (None, 256, 256, 64)  256         max_pooling2d_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_3 (Conv2D)                (None, 256, 256, 128) 73856       batch_normalization_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_4 (Conv2D)                (None, 256, 256, 128) 147584      conv2d_3[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)              (None, 256, 256, 128) 0           conv2d_4[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)   (None, 128, 128, 128) 0           dropout_2[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_3 (BatchNorm (None, 128, 128, 128) 512         max_pooling2d_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_5 (Conv2D)                (None, 128, 128, 256) 295168      batch_normalization_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_6 (Conv2D)                (None, 128, 128, 256) 590080      conv2d_5[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)              (None, 128, 128, 256) 0           conv2d_6[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)   (None, 64, 64, 256)   0           dropout_3[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_4 (BatchNorm (None, 64, 64, 256)   1024        max_pooling2d_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_7 (Conv2D)                (None, 64, 64, 512)   1180160     batch_normalization_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_8 (Conv2D)                (None, 64, 64, 512)   2359808     conv2d_7[0][0]
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)              (None, 64, 64, 512)   0           conv2d_8[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)   (None, 32, 32, 512)   0           dropout_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_9 (Conv2D)                (None, 32, 32, 1024)  4719616     max_pooling2d_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_10 (Conv2D)               (None, 32, 32, 1024)  9438208     conv2d_9[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)   (None, 64, 64, 1024)  0           conv2d_10[0][0]
# ____________________________________________________________________________________________________
# conv2d_11 (Conv2D)               (None, 64, 64, 512)   2097664     up_sampling2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_5 (Dropout)              (None, 64, 64, 512)   0           conv2d_11[0][0]
# ____________________________________________________________________________________________________
# concatenate_1 (Concatenate)      (None, 64, 64, 1024)  0           dropout_4[0][0]
#                                                                    dropout_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_12 (Conv2D)               (None, 64, 64, 512)   4719104     concatenate_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_13 (Conv2D)               (None, 64, 64, 512)   2359808     conv2d_12[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)   (None, 128, 128, 512) 0           conv2d_13[0][0]
# ____________________________________________________________________________________________________
# conv2d_14 (Conv2D)               (None, 128, 128, 256) 524544      up_sampling2d_2[0][0]
# ____________________________________________________________________________________________________
# dropout_6 (Dropout)              (None, 128, 128, 256) 0           conv2d_14[0][0]
# ____________________________________________________________________________________________________
# concatenate_2 (Concatenate)      (None, 128, 128, 512) 0           dropout_3[0][0]
#                                                                    dropout_6[0][0]
# ____________________________________________________________________________________________________
# conv2d_15 (Conv2D)               (None, 128, 128, 256) 1179904     concatenate_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_16 (Conv2D)               (None, 128, 128, 256) 590080      conv2d_15[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)   (None, 256, 256, 256) 0           conv2d_16[0][0]
# ____________________________________________________________________________________________________
# conv2d_17 (Conv2D)               (None, 256, 256, 128) 131200      up_sampling2d_3[0][0]
# ____________________________________________________________________________________________________
# dropout_7 (Dropout)              (None, 256, 256, 128) 0           conv2d_17[0][0]
# ____________________________________________________________________________________________________
# concatenate_3 (Concatenate)      (None, 256, 256, 256) 0           dropout_2[0][0]
#                                                                    dropout_7[0][0]
# ____________________________________________________________________________________________________
# conv2d_18 (Conv2D)               (None, 256, 256, 128) 295040      concatenate_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_19 (Conv2D)               (None, 256, 256, 128) 147584      conv2d_18[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)   (None, 512, 512, 128) 0           conv2d_19[0][0]
# ____________________________________________________________________________________________________
# conv2d_20 (Conv2D)               (None, 512, 512, 64)  32832       up_sampling2d_4[0][0]
# ____________________________________________________________________________________________________
# dropout_8 (Dropout)              (None, 512, 512, 64)  0           conv2d_20[0][0]
# ____________________________________________________________________________________________________
# concatenate_4 (Concatenate)      (None, 512, 512, 128) 0           dropout_1[0][0]
#                                                                    dropout_8[0][0]
# ____________________________________________________________________________________________________
# conv2d_21 (Conv2D)               (None, 512, 512, 64)  73792       concatenate_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_22 (Conv2D)               (None, 512, 512, 64)  36928       conv2d_21[0][0]
# ____________________________________________________________________________________________________
# prediction (Conv2D)              (None, 512, 512, 1)   65          conv2d_22[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 512, 512, 1)   0           prediction[0][0]
# ====================================================================================================
# Total params: 31,033,549
# Trainable params: 31,032,647
# Non-trainable params: 902
# ____________________________________________________________________________________________________

# %%
def dice (truth,pred) :
    g, s = K.sum(truth), K.sum(pred)
    x    = K.sum((truth*pred))
    return((1.0 if K.sum(g+s)==0.0 else 2.0*x/(g+s+K.epsilon())))

def f1 (truth,pred) :
    TP = K.sum(truth*pred)
    TN = K.sum((1.0-truth)*(1.0-pred))
    FP = K.sum(truth*(1.0-pred))
    FN = K.sum((1.0-truth)*pred)

    
    P  = 1.0 if K.sum(TP+FP)==0.0 else TP/(TP+FP)
    R  = 0.0 if K.sum(TP+FN)==0.0 else TP/(TP+FN) 

    F1 = 0.0 if K.sum(P+R)  ==0.0 else 2.0*P*R/(P+R)

    return(F1)

def f1dice (truth,pred) :
    return ((dice(truth,pred)+f1(truth,pred))/2.0)
    
def lossdice (truth,pred) :
    return(1.0 - dice(truth,pred))

def lossfd (truth,pred) :
    return(1.0 - f1dice(truth,pred))

# %%
def buildModel (input_shape) :
    model = UNet(input_shape,depth=4,n_out=1)
    
    sgd = keras.optimizers.SGD(lr=0.01, momentum=0.9, nesterov=True)
    #model.compile(loss='mean_absolute_error',  #'binary_crossentropy',
    model.compile(loss=lossdice, #'mean_absolute_error',  #'binary_crossentropy',
                  optimizer=sgd, #sgd, #"adam", #'rmsprop',
                  metrics=[dice,'binary_accuracy']) #['binary_accuracy']) #[fbeta_pred]) #['accuracy',fbeta_pred]) #['accuracy'])
    return(model)

# %%
K.clear_session()
model10 = buildModel((trX.shape[1],trX.shape[2],trX.shape[3]))
model10.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 512, 512, 3)   0
# ____________________________________________________________________________________________________
# batch_normalization_1 (BatchNorm (None, 512, 512, 3)   12          input_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_1 (Conv2D)                (None, 512, 512, 64)  1792        batch_normalization_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_2 (Conv2D)                (None, 512, 512, 64)  36928       conv2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 512, 512, 64)  0           conv2d_2[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)   (None, 256, 256, 64)  0           dropout_1[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_2 (BatchNorm (None, 256, 256, 64)  256         max_pooling2d_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_3 (Conv2D)                (None, 256, 256, 128) 73856       batch_normalization_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_4 (Conv2D)                (None, 256, 256, 128) 147584      conv2d_3[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)              (None, 256, 256, 128) 0           conv2d_4[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)   (None, 128, 128, 128) 0           dropout_2[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_3 (BatchNorm (None, 128, 128, 128) 512         max_pooling2d_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_5 (Conv2D)                (None, 128, 128, 256) 295168      batch_normalization_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_6 (Conv2D)                (None, 128, 128, 256) 590080      conv2d_5[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)              (None, 128, 128, 256) 0           conv2d_6[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)   (None, 64, 64, 256)   0           dropout_3[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_4 (BatchNorm (None, 64, 64, 256)   1024        max_pooling2d_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_7 (Conv2D)                (None, 64, 64, 512)   1180160     batch_normalization_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_8 (Conv2D)                (None, 64, 64, 512)   2359808     conv2d_7[0][0]
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)              (None, 64, 64, 512)   0           conv2d_8[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)   (None, 32, 32, 512)   0           dropout_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_9 (Conv2D)                (None, 32, 32, 1024)  4719616     max_pooling2d_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_10 (Conv2D)               (None, 32, 32, 1024)  9438208     conv2d_9[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)   (None, 64, 64, 1024)  0           conv2d_10[0][0]
# ____________________________________________________________________________________________________
# conv2d_11 (Conv2D)               (None, 64, 64, 512)   2097664     up_sampling2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_5 (Dropout)              (None, 64, 64, 512)   0           conv2d_11[0][0]
# ____________________________________________________________________________________________________
# concatenate_1 (Concatenate)      (None, 64, 64, 1024)  0           dropout_4[0][0]
#                                                                    dropout_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_12 (Conv2D)               (None, 64, 64, 512)   4719104     concatenate_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_13 (Conv2D)               (None, 64, 64, 512)   2359808     conv2d_12[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)   (None, 128, 128, 512) 0           conv2d_13[0][0]
# ____________________________________________________________________________________________________
# conv2d_14 (Conv2D)               (None, 128, 128, 256) 524544      up_sampling2d_2[0][0]
# ____________________________________________________________________________________________________
# dropout_6 (Dropout)              (None, 128, 128, 256) 0           conv2d_14[0][0]
# ____________________________________________________________________________________________________
# concatenate_2 (Concatenate)      (None, 128, 128, 512) 0           dropout_3[0][0]
#                                                                    dropout_6[0][0]
# ____________________________________________________________________________________________________
# conv2d_15 (Conv2D)               (None, 128, 128, 256) 1179904     concatenate_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_16 (Conv2D)               (None, 128, 128, 256) 590080      conv2d_15[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)   (None, 256, 256, 256) 0           conv2d_16[0][0]
# ____________________________________________________________________________________________________
# conv2d_17 (Conv2D)               (None, 256, 256, 128) 131200      up_sampling2d_3[0][0]
# ____________________________________________________________________________________________________
# dropout_7 (Dropout)              (None, 256, 256, 128) 0           conv2d_17[0][0]
# ____________________________________________________________________________________________________
# concatenate_3 (Concatenate)      (None, 256, 256, 256) 0           dropout_2[0][0]
#                                                                    dropout_7[0][0]
# ____________________________________________________________________________________________________
# conv2d_18 (Conv2D)               (None, 256, 256, 128) 295040      concatenate_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_19 (Conv2D)               (None, 256, 256, 128) 147584      conv2d_18[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)   (None, 512, 512, 128) 0           conv2d_19[0][0]
# ____________________________________________________________________________________________________
# conv2d_20 (Conv2D)               (None, 512, 512, 64)  32832       up_sampling2d_4[0][0]
# ____________________________________________________________________________________________________
# dropout_8 (Dropout)              (None, 512, 512, 64)  0           conv2d_20[0][0]
# ____________________________________________________________________________________________________
# concatenate_4 (Concatenate)      (None, 512, 512, 128) 0           dropout_1[0][0]
#                                                                    dropout_8[0][0]
# ____________________________________________________________________________________________________
# conv2d_21 (Conv2D)               (None, 512, 512, 64)  73792       concatenate_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_22 (Conv2D)               (None, 512, 512, 64)  36928       conv2d_21[0][0]
# ____________________________________________________________________________________________________
# prediction (Conv2D)              (None, 512, 512, 1)   65          conv2d_22[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 512, 512, 1)   0           prediction[0][0]
# ====================================================================================================
# Total params: 31,033,549
# Trainable params: 31,032,647
# Non-trainable params: 902
# ____________________________________________________________________________________________________

# %%
#model10.load_weights('../Data-Keras/Models/model-UNet-weights.h5', by_name=False)

# %%
epochs     = 100
verbose    = 2
batch_size = 2
metric     = 'binary_accuracy'
metric     = 'dice'

############trX, trY = trX[0:30], trY[0:30]

folds      = 5
foldN      = trX.shape[0]/folds+1

print(datetime.datetime.now(),'Training with folds')

for i in range(folds) :

    print(datetime.datetime.now(),'------------>',i)

    K.clear_session()
    model10 = buildModel((trX.shape[1],trX.shape[2],trX.shape[3]))

    early_stopping = EarlyStopping(monitor='val_loss', patience=10,min_delta=0.0001,verbose=1)
    reduce_lr1     = ReduceLROnPlateau(monitor='val_loss', factor=0.5,patience=3, min_lr=0.0000001,verbose=1)
    reduce_lr2     = ReduceLROnPlateau(monitor='loss',     factor=0.5,patience=3, min_lr=0.0000001,verbose=1)

    filepath="../Temp/TempTempG5M5KFold/V1-UNET-val_"+metric+"={val_"+metric+":.4f}-"+str(i)+".hdf5"
    #checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
    checkpoint = ModelCheckpoint(filepath, monitor='val_'+metric, verbose=1, save_best_only=True, mode='max')

    step  = 60
    low   = 0
    high  = low+step
    
    tFold = [True]*(i*foldN)+[False]*foldN+[True]*trX.shape[0];
    tFold = tFold[:trX.shape[0]]
    
    vFold = [not xx for xx in tFold]

    #hist1  = model10.fit(trX[low:high],trY[low:high],
    hist1  = model10.fit(trX[tFold],trY[tFold],
                        epochs=epochs, batch_size=batch_size, 
                        #validation_split=0.20, 
                        validation_data=(trX[vFold],trY[vFold]),
                        initial_epoch = 0,
                        callbacks=[early_stopping,reduce_lr1,reduce_lr2,checkpoint],
                        verbose=verbose)

print(datetime.datetime.now())
# Out:
# 2017-07-26 20:31:09.610364 Training with folds
# 2017-07-26 20:31:09.611002 ------------> 0
# Train on 134 samples, validate on 34 samples
# Epoch 1/100
# Epoch 00000: val_dice improved from -inf to 0.33844, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.3384-0.hdf5
# 148s - loss: 0.5302 - dice: 0.4698 - binary_accuracy: 0.4296 - val_loss: 0.6616 - val_dice: 0.3384 - val_binary_accuracy: 0.6486
# Epoch 2/100
# Epoch 00001: val_dice did not improve
# 135s - loss: 0.3556 - dice: 0.6444 - binary_accuracy: 0.7757 - val_loss: 0.9613 - val_dice: 0.0387 - val_binary_accuracy: 0.6864
# Epoch 3/100
# Epoch 00002: val_dice improved from 0.33844 to 0.43697, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.4370-0.hdf5
# 135s - loss: 0.3149 - dice: 0.6851 - binary_accuracy: 0.8094 - val_loss: 0.5630 - val_dice: 0.4370 - val_binary_accuracy: 0.7674
# Epoch 4/100
# Epoch 00003: val_dice improved from 0.43697 to 0.58534, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.5853-0.hdf5
# 135s - loss: 0.2995 - dice: 0.7005 - binary_accuracy: 0.8233 - val_loss: 0.4147 - val_dice: 0.5853 - val_binary_accuracy: 0.8126
# Epoch 5/100
# Epoch 00004: val_dice improved from 0.58534 to 0.62286, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.6229-0.hdf5
# 135s - loss: 0.2878 - dice: 0.7122 - binary_accuracy: 0.8308 - val_loss: 0.3771 - val_dice: 0.6229 - val_binary_accuracy: 0.8198
# Epoch 6/100
# Epoch 00005: val_dice improved from 0.62286 to 0.66498, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.6650-0.hdf5
# 135s - loss: 0.2837 - dice: 0.7163 - binary_accuracy: 0.8332 - val_loss: 0.3350 - val_dice: 0.6650 - val_binary_accuracy: 0.8289
# Epoch 7/100
# Epoch 00006: val_dice improved from 0.66498 to 0.67307, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.6731-0.hdf5
# 135s - loss: 0.2719 - dice: 0.7281 - binary_accuracy: 0.8387 - val_loss: 0.3269 - val_dice: 0.6731 - val_binary_accuracy: 0.8340
# Epoch 8/100
# Epoch 00007: val_dice did not improve
# 133s - loss: 0.2763 - dice: 0.7237 - binary_accuracy: 0.8297 - val_loss: 0.3401 - val_dice: 0.6599 - val_binary_accuracy: 0.8275
# Epoch 9/100
# Epoch 00008: val_dice did not improve
# 133s - loss: 0.2805 - dice: 0.7195 - binary_accuracy: 0.8340 - val_loss: 0.3437 - val_dice: 0.6563 - val_binary_accuracy: 0.8337
# Epoch 10/100
# Epoch 00009: val_dice did not improve
# 133s - loss: 0.2959 - dice: 0.7041 - binary_accuracy: 0.8199 - val_loss: 0.3458 - val_dice: 0.6542 - val_binary_accuracy: 0.8052
# Epoch 11/100
#
# Epoch 00010: reducing learning rate to 0.00499999988824.
#
# Epoch 00010: reducing learning rate to 0.00249999994412.
# Epoch 00010: val_dice did not improve
# 133s - loss: 0.2818 - dice: 0.7182 - binary_accuracy: 0.8375 - val_loss: 0.3345 - val_dice: 0.6655 - val_binary_accuracy: 0.8248
# Epoch 12/100
# Epoch 00011: val_dice did not improve
# 133s - loss: 0.2604 - dice: 0.7396 - binary_accuracy: 0.8463 - val_loss: 0.3361 - val_dice: 0.6639 - val_binary_accuracy: 0.8346
# Epoch 13/100
# Epoch 00012: val_dice improved from 0.67307 to 0.67568, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.6757-0.hdf5
# 135s - loss: 0.2765 - dice: 0.7235 - binary_accuracy: 0.8445 - val_loss: 0.3243 - val_dice: 0.6757 - val_binary_accuracy: 0.8369
# Epoch 14/100
# Epoch 00013: val_dice did not improve
# 134s - loss: 0.2629 - dice: 0.7371 - binary_accuracy: 0.8459 - val_loss: 0.3501 - val_dice: 0.6499 - val_binary_accuracy: 0.8382
# Epoch 15/100
# Epoch 00014: val_dice did not improve
# 134s - loss: 0.2694 - dice: 0.7306 - binary_accuracy: 0.8448 - val_loss: 0.3261 - val_dice: 0.6739 - val_binary_accuracy: 0.8384
# Epoch 16/100
# Epoch 00015: val_dice improved from 0.67568 to 0.68036, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.6804-0.hdf5
# 135s - loss: 0.2597 - dice: 0.7403 - binary_accuracy: 0.8489 - val_loss: 0.3196 - val_dice: 0.6804 - val_binary_accuracy: 0.8411
# Epoch 17/100
# Epoch 00016: val_dice improved from 0.68036 to 0.69510, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.6951-0.hdf5
# 135s - loss: 0.2560 - dice: 0.7440 - binary_accuracy: 0.8564 - val_loss: 0.3049 - val_dice: 0.6951 - val_binary_accuracy: 0.8393
# Epoch 18/100
# Epoch 00017: val_dice did not improve
# 134s - loss: 0.2656 - dice: 0.7344 - binary_accuracy: 0.8438 - val_loss: 0.3149 - val_dice: 0.6851 - val_binary_accuracy: 0.8414
# Epoch 19/100
# Epoch 00018: val_dice did not improve
# 134s - loss: 0.2483 - dice: 0.7517 - binary_accuracy: 0.8583 - val_loss: 0.3208 - val_dice: 0.6792 - val_binary_accuracy: 0.8312
# Epoch 20/100
# Epoch 00019: val_dice did not improve
# 134s - loss: 0.2622 - dice: 0.7378 - binary_accuracy: 0.8508 - val_loss: 0.3144 - val_dice: 0.6856 - val_binary_accuracy: 0.8360
# Epoch 21/100
#
# Epoch 00020: reducing learning rate to 0.00124999997206.
# Epoch 00020: val_dice did not improve
# 134s - loss: 0.2523 - dice: 0.7477 - binary_accuracy: 0.8578 - val_loss: 0.3350 - val_dice: 0.6650 - val_binary_accuracy: 0.8355
# Epoch 22/100
# Epoch 00021: val_dice did not improve
# 134s - loss: 0.2376 - dice: 0.7624 - binary_accuracy: 0.8648 - val_loss: 0.3236 - val_dice: 0.6764 - val_binary_accuracy: 0.8428
# Epoch 23/100
# Epoch 00022: val_dice did not improve
# 134s - loss: 0.2455 - dice: 0.7545 - binary_accuracy: 0.8613 - val_loss: 0.3413 - val_dice: 0.6587 - val_binary_accuracy: 0.8363
# Epoch 24/100
#
# Epoch 00023: reducing learning rate to 0.00062499998603.
# Epoch 00023: val_dice did not improve
# 134s - loss: 0.2438 - dice: 0.7562 - binary_accuracy: 0.8583 - val_loss: 0.3198 - val_dice: 0.6802 - val_binary_accuracy: 0.8435
# Epoch 25/100
# Epoch 00024: val_dice did not improve
# 134s - loss: 0.2368 - dice: 0.7632 - binary_accuracy: 0.8640 - val_loss: 0.3184 - val_dice: 0.6816 - val_binary_accuracy: 0.8448
# Epoch 26/100
# Epoch 00025: val_dice did not improve
# 134s - loss: 0.2249 - dice: 0.7751 - binary_accuracy: 0.8718 - val_loss: 0.3083 - val_dice: 0.6917 - val_binary_accuracy: 0.8469
# Epoch 27/100
#
# Epoch 00026: reducing learning rate to 0.000312499993015.
# Epoch 00026: val_dice did not improve
# 134s - loss: 0.2319 - dice: 0.7681 - binary_accuracy: 0.8678 - val_loss: 0.3152 - val_dice: 0.6848 - val_binary_accuracy: 0.8447
# Epoch 28/100
# Epoch 00027: val_dice improved from 0.69510 to 0.70087, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7009-0.hdf5
# 135s - loss: 0.2281 - dice: 0.7719 - binary_accuracy: 0.8677 - val_loss: 0.2991 - val_dice: 0.7009 - val_binary_accuracy: 0.8493
# Epoch 29/100
# Epoch 00028: val_dice improved from 0.70087 to 0.70584, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7058-0.hdf5
# 135s - loss: 0.2254 - dice: 0.7746 - binary_accuracy: 0.8707 - val_loss: 0.2942 - val_dice: 0.7058 - val_binary_accuracy: 0.8510
# Epoch 30/100
#
# Epoch 00029: reducing learning rate to 0.000156249996508.
# Epoch 00029: val_dice improved from 0.70584 to 0.70635, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7063-0.hdf5
# 135s - loss: 0.2371 - dice: 0.7629 - binary_accuracy: 0.8672 - val_loss: 0.2937 - val_dice: 0.7063 - val_binary_accuracy: 0.8467
# Epoch 31/100
# Epoch 00030: val_dice did not improve
# 134s - loss: 0.2252 - dice: 0.7748 - binary_accuracy: 0.8743 - val_loss: 0.2973 - val_dice: 0.7027 - val_binary_accuracy: 0.8458
# Epoch 32/100
# Epoch 00031: val_dice did not improve
# 134s - loss: 0.2196 - dice: 0.7804 - binary_accuracy: 0.8737 - val_loss: 0.3025 - val_dice: 0.6975 - val_binary_accuracy: 0.8449
# Epoch 33/100
# Epoch 00032: val_dice improved from 0.70635 to 0.70715, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7071-0.hdf5
# 135s - loss: 0.2239 - dice: 0.7761 - binary_accuracy: 0.8697 - val_loss: 0.2929 - val_dice: 0.7071 - val_binary_accuracy: 0.8480
# Epoch 34/100
# Epoch 00033: val_dice did not improve
# 134s - loss: 0.2388 - dice: 0.7612 - binary_accuracy: 0.8637 - val_loss: 0.3007 - val_dice: 0.6993 - val_binary_accuracy: 0.8480
# Epoch 35/100
# Epoch 00034: val_dice did not improve
# 134s - loss: 0.2258 - dice: 0.7742 - binary_accuracy: 0.8755 - val_loss: 0.2973 - val_dice: 0.7027 - val_binary_accuracy: 0.8480
# Epoch 36/100
#
# Epoch 00035: reducing learning rate to 7.81249982538e-05.
# Epoch 00035: val_dice did not improve
# 134s - loss: 0.2315 - dice: 0.7685 - binary_accuracy: 0.8737 - val_loss: 0.2937 - val_dice: 0.7063 - val_binary_accuracy: 0.8476
# Epoch 37/100
# Epoch 00036: val_dice improved from 0.70715 to 0.70983, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7098-0.hdf5
# 136s - loss: 0.2091 - dice: 0.7909 - binary_accuracy: 0.8798 - val_loss: 0.2902 - val_dice: 0.7098 - val_binary_accuracy: 0.8494
# Epoch 38/100
# Epoch 00037: val_dice improved from 0.70983 to 0.71345, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7134-0.hdf5
# 136s - loss: 0.2112 - dice: 0.7888 - binary_accuracy: 0.8778 - val_loss: 0.2866 - val_dice: 0.7134 - val_binary_accuracy: 0.8500
# Epoch 39/100
# Epoch 00038: val_dice improved from 0.71345 to 0.71487, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7149-0.hdf5
# 136s - loss: 0.2273 - dice: 0.7727 - binary_accuracy: 0.8757 - val_loss: 0.2851 - val_dice: 0.7149 - val_binary_accuracy: 0.8510
# Epoch 40/100
# Epoch 00039: val_dice did not improve
# 134s - loss: 0.2185 - dice: 0.7815 - binary_accuracy: 0.8792 - val_loss: 0.2875 - val_dice: 0.7125 - val_binary_accuracy: 0.8512
# Epoch 41/100
#
# Epoch 00040: reducing learning rate to 3.90624991269e-05.
# Epoch 00040: val_dice did not improve
# 134s - loss: 0.2181 - dice: 0.7819 - binary_accuracy: 0.8791 - val_loss: 0.2876 - val_dice: 0.7124 - val_binary_accuracy: 0.8497
# Epoch 42/100
# Epoch 00041: val_dice did not improve
# 134s - loss: 0.2183 - dice: 0.7817 - binary_accuracy: 0.8772 - val_loss: 0.2913 - val_dice: 0.7087 - val_binary_accuracy: 0.8482
# Epoch 43/100
#
# Epoch 00042: reducing learning rate to 1.95312495634e-05.
# Epoch 00042: val_dice did not improve
# 134s - loss: 0.2162 - dice: 0.7838 - binary_accuracy: 0.8795 - val_loss: 0.2932 - val_dice: 0.7068 - val_binary_accuracy: 0.8485
# Epoch 44/100
#
# Epoch 00043: reducing learning rate to 9.76562478172e-06.
# Epoch 00043: val_dice did not improve
# 134s - loss: 0.2224 - dice: 0.7776 - binary_accuracy: 0.8748 - val_loss: 0.2925 - val_dice: 0.7075 - val_binary_accuracy: 0.8487
# Epoch 45/100
# Epoch 00044: val_dice did not improve
# 134s - loss: 0.2235 - dice: 0.7765 - binary_accuracy: 0.8743 - val_loss: 0.2921 - val_dice: 0.7079 - val_binary_accuracy: 0.8490
# Epoch 46/100
#
# Epoch 00045: reducing learning rate to 4.88281239086e-06.
# Epoch 00045: val_dice did not improve
# 134s - loss: 0.2235 - dice: 0.7765 - binary_accuracy: 0.8721 - val_loss: 0.2908 - val_dice: 0.7092 - val_binary_accuracy: 0.8491
# Epoch 47/100
# Epoch 00046: val_dice did not improve
# 134s - loss: 0.2066 - dice: 0.7934 - binary_accuracy: 0.8852 - val_loss: 0.2901 - val_dice: 0.7099 - val_binary_accuracy: 0.8494
# Epoch 48/100
# Epoch 00047: val_dice did not improve
# 134s - loss: 0.2314 - dice: 0.7686 - binary_accuracy: 0.8705 - val_loss: 0.2904 - val_dice: 0.7096 - val_binary_accuracy: 0.8493
# Epoch 49/100
#
# Epoch 00048: reducing learning rate to 2.44140619543e-06.
# Epoch 00048: val_dice did not improve
# 134s - loss: 0.2256 - dice: 0.7744 - binary_accuracy: 0.8748 - val_loss: 0.2899 - val_dice: 0.7101 - val_binary_accuracy: 0.8497
# Epoch 50/100
# Epoch 00049: val_dice did not improve
# 134s - loss: 0.2058 - dice: 0.7942 - binary_accuracy: 0.8786 - val_loss: 0.2898 - val_dice: 0.7102 - val_binary_accuracy: 0.8498
# Epoch 00049: early stopping
# 2017-07-26 22:23:50.179605 ------------> 1
# Train on 134 samples, validate on 34 samples
# Epoch 1/100
# Epoch 00000: val_dice improved from -inf to 0.13163, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.1316-1.hdf5
# 139s - loss: 0.4844 - dice: 0.5156 - binary_accuracy: 0.5423 - val_loss: 0.8684 - val_dice: 0.1316 - val_binary_accuracy: 0.7257
# Epoch 2/100
# Epoch 00001: val_dice did not improve
# 135s - loss: 0.3162 - dice: 0.6838 - binary_accuracy: 0.7965 - val_loss: 0.9883 - val_dice: 0.0117 - val_binary_accuracy: 0.7264
# Epoch 3/100
# Epoch 00002: val_dice improved from 0.13163 to 0.51376, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.5138-1.hdf5
# 136s - loss: 0.3235 - dice: 0.6765 - binary_accuracy: 0.8016 - val_loss: 0.4862 - val_dice: 0.5138 - val_binary_accuracy: 0.8292
# Epoch 4/100
# Epoch 00003: val_dice improved from 0.51376 to 0.62457, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.6246-1.hdf5
# 135s - loss: 0.3113 - dice: 0.6887 - binary_accuracy: 0.8116 - val_loss: 0.3754 - val_dice: 0.6246 - val_binary_accuracy: 0.8455
# Epoch 5/100
# Epoch 00004: val_dice improved from 0.62457 to 0.70017, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7002-1.hdf5
# 135s - loss: 0.3045 - dice: 0.6955 - binary_accuracy: 0.8136 - val_loss: 0.2998 - val_dice: 0.7002 - val_binary_accuracy: 0.8337
# Epoch 6/100
# Epoch 00005: val_dice improved from 0.70017 to 0.71994, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7199-1.hdf5
# 135s - loss: 0.3031 - dice: 0.6969 - binary_accuracy: 0.8154 - val_loss: 0.2801 - val_dice: 0.7199 - val_binary_accuracy: 0.8590
# Epoch 7/100
# Epoch 00006: val_dice did not improve
# 134s - loss: 0.2982 - dice: 0.7018 - binary_accuracy: 0.8201 - val_loss: 0.3107 - val_dice: 0.6893 - val_binary_accuracy: 0.8164
# Epoch 8/100
# Epoch 00007: val_dice improved from 0.71994 to 0.72269, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7227-1.hdf5
# 135s - loss: 0.2830 - dice: 0.7170 - binary_accuracy: 0.8299 - val_loss: 0.2773 - val_dice: 0.7227 - val_binary_accuracy: 0.8421
# Epoch 9/100
# Epoch 00008: val_dice did not improve
# 134s - loss: 0.2934 - dice: 0.7066 - binary_accuracy: 0.8259 - val_loss: 0.2932 - val_dice: 0.7068 - val_binary_accuracy: 0.8443
# Epoch 10/100
# Epoch 00009: val_dice did not improve
# 134s - loss: 0.2860 - dice: 0.7140 - binary_accuracy: 0.8246 - val_loss: 0.2804 - val_dice: 0.7196 - val_binary_accuracy: 0.8653
# Epoch 11/100
# Epoch 00010: val_dice did not improve
# 134s - loss: 0.2849 - dice: 0.7151 - binary_accuracy: 0.8312 - val_loss: 0.3466 - val_dice: 0.6534 - val_binary_accuracy: 0.8570
# Epoch 12/100
#
# Epoch 00011: reducing learning rate to 0.00499999988824.
#
# Epoch 00011: reducing learning rate to 0.00249999994412.
# Epoch 00011: val_dice did not improve
# 134s - loss: 0.2852 - dice: 0.7148 - binary_accuracy: 0.8286 - val_loss: 0.2965 - val_dice: 0.7035 - val_binary_accuracy: 0.8596
# Epoch 13/100
# Epoch 00012: val_dice improved from 0.72269 to 0.73044, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7304-1.hdf5
# 135s - loss: 0.2653 - dice: 0.7347 - binary_accuracy: 0.8453 - val_loss: 0.2696 - val_dice: 0.7304 - val_binary_accuracy: 0.8641
# Epoch 14/100
# Epoch 00013: val_dice did not improve
# 134s - loss: 0.2531 - dice: 0.7469 - binary_accuracy: 0.8522 - val_loss: 0.2775 - val_dice: 0.7225 - val_binary_accuracy: 0.8694
# Epoch 15/100
# Epoch 00014: val_dice improved from 0.73044 to 0.74402, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7440-1.hdf5
# 135s - loss: 0.2537 - dice: 0.7463 - binary_accuracy: 0.8442 - val_loss: 0.2560 - val_dice: 0.7440 - val_binary_accuracy: 0.8671
# Epoch 16/100
# Epoch 00015: val_dice did not improve
# 134s - loss: 0.2516 - dice: 0.7484 - binary_accuracy: 0.8539 - val_loss: 0.2830 - val_dice: 0.7170 - val_binary_accuracy: 0.8636
# Epoch 17/100
# Epoch 00016: val_dice did not improve
# 134s - loss: 0.2281 - dice: 0.7719 - binary_accuracy: 0.8652 - val_loss: 0.2993 - val_dice: 0.7007 - val_binary_accuracy: 0.8494
# Epoch 18/100
# Epoch 00017: val_dice did not improve
# 134s - loss: 0.2437 - dice: 0.7563 - binary_accuracy: 0.8570 - val_loss: 0.2608 - val_dice: 0.7392 - val_binary_accuracy: 0.8667
# Epoch 19/100
#
# Epoch 00018: reducing learning rate to 0.00124999997206.
# Epoch 00018: val_dice did not improve
# 134s - loss: 0.2496 - dice: 0.7504 - binary_accuracy: 0.8569 - val_loss: 0.3107 - val_dice: 0.6893 - val_binary_accuracy: 0.8603
# Epoch 20/100
# Epoch 00019: val_dice did not improve
# 134s - loss: 0.2355 - dice: 0.7645 - binary_accuracy: 0.8686 - val_loss: 0.3246 - val_dice: 0.6754 - val_binary_accuracy: 0.7982
# Epoch 21/100
#
# Epoch 00020: reducing learning rate to 0.00062499998603.
# Epoch 00020: val_dice improved from 0.74402 to 0.74667, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7467-1.hdf5
# 135s - loss: 0.2528 - dice: 0.7472 - binary_accuracy: 0.8516 - val_loss: 0.2533 - val_dice: 0.7467 - val_binary_accuracy: 0.8685
# Epoch 22/100
# Epoch 00021: val_dice did not improve
# 134s - loss: 0.2249 - dice: 0.7751 - binary_accuracy: 0.8679 - val_loss: 0.2548 - val_dice: 0.7452 - val_binary_accuracy: 0.8678
# Epoch 23/100
# Epoch 00022: val_dice improved from 0.74667 to 0.74817, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7482-1.hdf5
# 135s - loss: 0.2366 - dice: 0.7634 - binary_accuracy: 0.8630 - val_loss: 0.2518 - val_dice: 0.7482 - val_binary_accuracy: 0.8789
# Epoch 24/100
# Epoch 00023: val_dice did not improve
# 134s - loss: 0.2321 - dice: 0.7679 - binary_accuracy: 0.8685 - val_loss: 0.3654 - val_dice: 0.6346 - val_binary_accuracy: 0.8608
# Epoch 25/100
# Epoch 00024: val_dice improved from 0.74817 to 0.75258, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7526-1.hdf5
# 135s - loss: 0.2292 - dice: 0.7708 - binary_accuracy: 0.8704 - val_loss: 0.2474 - val_dice: 0.7526 - val_binary_accuracy: 0.8773
# Epoch 26/100
# Epoch 00025: val_dice did not improve
# 134s - loss: 0.2074 - dice: 0.7926 - binary_accuracy: 0.8835 - val_loss: 0.3474 - val_dice: 0.6526 - val_binary_accuracy: 0.8626
# Epoch 27/100
# Epoch 00026: val_dice did not improve
# 134s - loss: 0.2254 - dice: 0.7746 - binary_accuracy: 0.8707 - val_loss: 0.3350 - val_dice: 0.6650 - val_binary_accuracy: 0.8669
# Epoch 28/100
# Epoch 00027: val_dice did not improve
# 134s - loss: 0.2274 - dice: 0.7726 - binary_accuracy: 0.8717 - val_loss: 0.2779 - val_dice: 0.7221 - val_binary_accuracy: 0.8740
# Epoch 29/100
#
# Epoch 00028: reducing learning rate to 0.000312499993015.
# Epoch 00028: val_dice did not improve
# 134s - loss: 0.2157 - dice: 0.7843 - binary_accuracy: 0.8788 - val_loss: 0.3979 - val_dice: 0.6021 - val_binary_accuracy: 0.8556
# Epoch 30/100
#
# Epoch 00029: reducing learning rate to 0.000156249996508.
# Epoch 00029: val_dice did not improve
# 134s - loss: 0.2192 - dice: 0.7808 - binary_accuracy: 0.8768 - val_loss: 0.2657 - val_dice: 0.7343 - val_binary_accuracy: 0.8824
# Epoch 31/100
# Epoch 00030: val_dice did not improve
# 134s - loss: 0.2166 - dice: 0.7834 - binary_accuracy: 0.8814 - val_loss: 0.2905 - val_dice: 0.7095 - val_binary_accuracy: 0.8764
# Epoch 32/100
#
# Epoch 00031: reducing learning rate to 7.81249982538e-05.
# Epoch 00031: val_dice did not improve
# 134s - loss: 0.1958 - dice: 0.8042 - binary_accuracy: 0.8866 - val_loss: 0.3676 - val_dice: 0.6324 - val_binary_accuracy: 0.8631
# Epoch 33/100
# Epoch 00032: val_dice did not improve
# 134s - loss: 0.2019 - dice: 0.7981 - binary_accuracy: 0.8905 - val_loss: 0.3251 - val_dice: 0.6749 - val_binary_accuracy: 0.8711
# Epoch 34/100
# Epoch 00033: val_dice did not improve
# 134s - loss: 0.1915 - dice: 0.8085 - binary_accuracy: 0.8873 - val_loss: 0.3706 - val_dice: 0.6294 - val_binary_accuracy: 0.8626
# Epoch 35/100
#
# Epoch 00034: reducing learning rate to 3.90624991269e-05.
# Epoch 00034: val_dice did not improve
# 134s - loss: 0.2091 - dice: 0.7909 - binary_accuracy: 0.8904 - val_loss: 0.3612 - val_dice: 0.6388 - val_binary_accuracy: 0.8643
# Epoch 36/100
# Epoch 00035: val_dice did not improve
# 134s - loss: 0.1985 - dice: 0.8015 - binary_accuracy: 0.8920 - val_loss: 0.3691 - val_dice: 0.6309 - val_binary_accuracy: 0.8629
# Epoch 00035: early stopping
# 2017-07-26 23:44:53.034069 ------------> 2
# Train on 134 samples, validate on 34 samples
# Epoch 1/100
# Epoch 00000: val_dice improved from -inf to 0.36632, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.3663-2.hdf5
# 138s - loss: 0.5485 - dice: 0.4515 - binary_accuracy: 0.4154 - val_loss: 0.6337 - val_dice: 0.3663 - val_binary_accuracy: 0.5936
# Epoch 2/100
# Epoch 00001: val_dice did not improve
# 136s - loss: 0.4156 - dice: 0.5844 - binary_accuracy: 0.7251 - val_loss: 0.9793 - val_dice: 0.0207 - val_binary_accuracy: 0.6297
# Epoch 3/100
# Epoch 00002: val_dice did not improve
# 134s - loss: 0.3362 - dice: 0.6638 - binary_accuracy: 0.7957 - val_loss: 0.7963 - val_dice: 0.2037 - val_binary_accuracy: 0.6660
# Epoch 4/100
# Epoch 00003: val_dice improved from 0.36632 to 0.71388, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7139-2.hdf5
# 135s - loss: 0.3104 - dice: 0.6896 - binary_accuracy: 0.8233 - val_loss: 0.2861 - val_dice: 0.7139 - val_binary_accuracy: 0.8365
# Epoch 5/100
# Epoch 00004: val_dice improved from 0.71388 to 0.73721, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7372-2.hdf5
# 135s - loss: 0.3081 - dice: 0.6919 - binary_accuracy: 0.8115 - val_loss: 0.2628 - val_dice: 0.7372 - val_binary_accuracy: 0.8588
# Epoch 6/100
# Epoch 00005: val_dice did not improve
# 134s - loss: 0.2928 - dice: 0.7072 - binary_accuracy: 0.8329 - val_loss: 0.3250 - val_dice: 0.6750 - val_binary_accuracy: 0.8415
# Epoch 7/100
# Epoch 00006: val_dice did not improve
# 133s - loss: 0.2934 - dice: 0.7066 - binary_accuracy: 0.8313 - val_loss: 0.2715 - val_dice: 0.7285 - val_binary_accuracy: 0.8625
# Epoch 8/100
# Epoch 00007: val_dice improved from 0.73721 to 0.74804, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7480-2.hdf5
# 135s - loss: 0.2839 - dice: 0.7161 - binary_accuracy: 0.8373 - val_loss: 0.2520 - val_dice: 0.7480 - val_binary_accuracy: 0.8680
# Epoch 9/100
# Epoch 00008: val_dice did not improve
# 133s - loss: 0.2757 - dice: 0.7243 - binary_accuracy: 0.8388 - val_loss: 0.2547 - val_dice: 0.7453 - val_binary_accuracy: 0.8611
# Epoch 10/100
# Epoch 00009: val_dice did not improve
# 133s - loss: 0.2827 - dice: 0.7173 - binary_accuracy: 0.8391 - val_loss: 0.2562 - val_dice: 0.7438 - val_binary_accuracy: 0.8513
# Epoch 11/100
# Epoch 00010: val_dice improved from 0.74804 to 0.74942, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7494-2.hdf5
# 135s - loss: 0.2914 - dice: 0.7086 - binary_accuracy: 0.8275 - val_loss: 0.2506 - val_dice: 0.7494 - val_binary_accuracy: 0.8597
# Epoch 12/100
# Epoch 00011: val_dice did not improve
# 133s - loss: 0.2967 - dice: 0.7033 - binary_accuracy: 0.8277 - val_loss: 0.2640 - val_dice: 0.7360 - val_binary_accuracy: 0.8588
# Epoch 13/100
# Epoch 00012: val_dice did not improve
# 133s - loss: 0.2632 - dice: 0.7368 - binary_accuracy: 0.8430 - val_loss: 0.2728 - val_dice: 0.7272 - val_binary_accuracy: 0.8332
# Epoch 14/100
# Epoch 00013: val_dice improved from 0.74942 to 0.75627, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7563-2.hdf5
# 135s - loss: 0.2879 - dice: 0.7121 - binary_accuracy: 0.8380 - val_loss: 0.2437 - val_dice: 0.7563 - val_binary_accuracy: 0.8679
# Epoch 15/100
# Epoch 00014: val_dice did not improve
# 133s - loss: 0.2833 - dice: 0.7167 - binary_accuracy: 0.8414 - val_loss: 0.2760 - val_dice: 0.7240 - val_binary_accuracy: 0.8012
# Epoch 16/100
# Epoch 00015: val_dice did not improve
# 133s - loss: 0.2696 - dice: 0.7304 - binary_accuracy: 0.8415 - val_loss: 0.2697 - val_dice: 0.7303 - val_binary_accuracy: 0.8639
# Epoch 17/100
#
# Epoch 00016: reducing learning rate to 0.00499999988824.
# Epoch 00016: val_dice did not improve
# 133s - loss: 0.2735 - dice: 0.7265 - binary_accuracy: 0.8424 - val_loss: 0.3189 - val_dice: 0.6811 - val_binary_accuracy: 0.8515
# Epoch 18/100
# Epoch 00017: val_dice improved from 0.75627 to 0.77341, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7734-2.hdf5
# 134s - loss: 0.2952 - dice: 0.7048 - binary_accuracy: 0.8378 - val_loss: 0.2266 - val_dice: 0.7734 - val_binary_accuracy: 0.8771
# Epoch 19/100
# Epoch 00018: val_dice improved from 0.77341 to 0.78109, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7811-2.hdf5
# 134s - loss: 0.2494 - dice: 0.7506 - binary_accuracy: 0.8607 - val_loss: 0.2189 - val_dice: 0.7811 - val_binary_accuracy: 0.8675
# Epoch 20/100
# Epoch 00019: val_dice did not improve
# 133s - loss: 0.2507 - dice: 0.7493 - binary_accuracy: 0.8623 - val_loss: 0.2482 - val_dice: 0.7518 - val_binary_accuracy: 0.8626
# Epoch 21/100
# Epoch 00020: val_dice did not improve
# 133s - loss: 0.2594 - dice: 0.7406 - binary_accuracy: 0.8557 - val_loss: 0.2396 - val_dice: 0.7604 - val_binary_accuracy: 0.8457
# Epoch 22/100
# Epoch 00021: val_dice did not improve
# 133s - loss: 0.2440 - dice: 0.7560 - binary_accuracy: 0.8624 - val_loss: 0.2394 - val_dice: 0.7606 - val_binary_accuracy: 0.8674
# Epoch 23/100
#
# Epoch 00022: reducing learning rate to 0.00249999994412.
# Epoch 00022: val_dice did not improve
# 133s - loss: 0.2432 - dice: 0.7568 - binary_accuracy: 0.8644 - val_loss: 0.2364 - val_dice: 0.7636 - val_binary_accuracy: 0.8847
# Epoch 24/100
# Epoch 00023: val_dice did not improve
# 133s - loss: 0.2291 - dice: 0.7709 - binary_accuracy: 0.8769 - val_loss: 0.3020 - val_dice: 0.6980 - val_binary_accuracy: 0.7709
# Epoch 25/100
# Epoch 00024: val_dice did not improve
# 133s - loss: 0.2172 - dice: 0.7828 - binary_accuracy: 0.8779 - val_loss: 0.2311 - val_dice: 0.7689 - val_binary_accuracy: 0.8704
# Epoch 26/100
#
# Epoch 00025: reducing learning rate to 0.00124999997206.
# Epoch 00025: val_dice did not improve
# 133s - loss: 0.2343 - dice: 0.7657 - binary_accuracy: 0.8719 - val_loss: 0.2191 - val_dice: 0.7809 - val_binary_accuracy: 0.8666
# Epoch 27/100
# Epoch 00026: val_dice improved from 0.78109 to 0.78296, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7830-2.hdf5
# 135s - loss: 0.2236 - dice: 0.7764 - binary_accuracy: 0.8802 - val_loss: 0.2170 - val_dice: 0.7830 - val_binary_accuracy: 0.8864
# Epoch 28/100
# Epoch 00027: val_dice improved from 0.78296 to 0.78790, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7879-2.hdf5
# 135s - loss: 0.2110 - dice: 0.7890 - binary_accuracy: 0.8819 - val_loss: 0.2121 - val_dice: 0.7879 - val_binary_accuracy: 0.8757
# Epoch 29/100
# Epoch 00028: val_dice did not improve
# 133s - loss: 0.2011 - dice: 0.7989 - binary_accuracy: 0.8919 - val_loss: 0.2418 - val_dice: 0.7582 - val_binary_accuracy: 0.8587
# Epoch 30/100
# Epoch 00029: val_dice did not improve
# 133s - loss: 0.2259 - dice: 0.7741 - binary_accuracy: 0.8800 - val_loss: 0.2288 - val_dice: 0.7712 - val_binary_accuracy: 0.8881
# Epoch 31/100
# Epoch 00030: val_dice did not improve
# 134s - loss: 0.2283 - dice: 0.7717 - binary_accuracy: 0.8812 - val_loss: 0.2269 - val_dice: 0.7731 - val_binary_accuracy: 0.8847
# Epoch 32/100
#
# Epoch 00031: reducing learning rate to 0.00062499998603.
# Epoch 00031: val_dice did not improve
# 134s - loss: 0.1970 - dice: 0.8030 - binary_accuracy: 0.8890 - val_loss: 0.2237 - val_dice: 0.7763 - val_binary_accuracy: 0.8835
# Epoch 33/100
# Epoch 00032: val_dice did not improve
# 134s - loss: 0.2018 - dice: 0.7982 - binary_accuracy: 0.8885 - val_loss: 0.2188 - val_dice: 0.7812 - val_binary_accuracy: 0.8872
# Epoch 34/100
# Epoch 00033: val_dice did not improve
# 133s - loss: 0.2039 - dice: 0.7961 - binary_accuracy: 0.8916 - val_loss: 0.2198 - val_dice: 0.7802 - val_binary_accuracy: 0.8849
# Epoch 35/100
#
# Epoch 00034: reducing learning rate to 0.000312499993015.
# Epoch 00034: val_dice did not improve
# 134s - loss: 0.2059 - dice: 0.7941 - binary_accuracy: 0.8882 - val_loss: 0.2388 - val_dice: 0.7612 - val_binary_accuracy: 0.8634
# Epoch 36/100
#
# Epoch 00035: reducing learning rate to 0.000156249996508.
# Epoch 00035: val_dice did not improve
# 134s - loss: 0.2103 - dice: 0.7897 - binary_accuracy: 0.8873 - val_loss: 0.2141 - val_dice: 0.7859 - val_binary_accuracy: 0.8873
# Epoch 37/100
# Epoch 00036: val_dice did not improve
# 134s - loss: 0.2096 - dice: 0.7904 - binary_accuracy: 0.8962 - val_loss: 0.2260 - val_dice: 0.7740 - val_binary_accuracy: 0.8674
# Epoch 38/100
#
# Epoch 00037: reducing learning rate to 7.81249982538e-05.
# Epoch 00037: val_dice did not improve
# 134s - loss: 0.1905 - dice: 0.8095 - binary_accuracy: 0.8938 - val_loss: 0.2244 - val_dice: 0.7756 - val_binary_accuracy: 0.8690
# Epoch 39/100
# Epoch 00038: val_dice did not improve
# 134s - loss: 0.2067 - dice: 0.7933 - binary_accuracy: 0.8960 - val_loss: 0.2233 - val_dice: 0.7767 - val_binary_accuracy: 0.8703
# Epoch 00038: early stopping
# 2017-07-27 01:12:17.071085 ------------> 3
# Train on 134 samples, validate on 34 samples
# Epoch 1/100
# Epoch 00000: val_dice improved from -inf to 0.32531, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.3253-3.hdf5
# 138s - loss: 0.5297 - dice: 0.4703 - binary_accuracy: 0.4196 - val_loss: 0.6747 - val_dice: 0.3253 - val_binary_accuracy: 0.6179
# Epoch 2/100
# Epoch 00001: val_dice did not improve
# 135s - loss: 0.3971 - dice: 0.6029 - binary_accuracy: 0.7224 - val_loss: 0.8755 - val_dice: 0.1245 - val_binary_accuracy: 0.6391
# Epoch 3/100
# Epoch 00002: val_dice did not improve
# 134s - loss: 0.3132 - dice: 0.6868 - binary_accuracy: 0.7987 - val_loss: 0.9458 - val_dice: 0.0542 - val_binary_accuracy: 0.6714
# Epoch 4/100
# Epoch 00003: val_dice improved from 0.32531 to 0.56075, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.5607-3.hdf5
# 135s - loss: 0.2997 - dice: 0.7003 - binary_accuracy: 0.8244 - val_loss: 0.4393 - val_dice: 0.5607 - val_binary_accuracy: 0.8016
# Epoch 5/100
# Epoch 00004: val_dice did not improve
# 133s - loss: 0.2814 - dice: 0.7186 - binary_accuracy: 0.8337 - val_loss: 0.4957 - val_dice: 0.5043 - val_binary_accuracy: 0.7930
# Epoch 6/100
# Epoch 00005: val_dice improved from 0.56075 to 0.59749, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.5975-3.hdf5
# 135s - loss: 0.2853 - dice: 0.7147 - binary_accuracy: 0.8347 - val_loss: 0.4025 - val_dice: 0.5975 - val_binary_accuracy: 0.8068
# Epoch 7/100
# Epoch 00006: val_dice did not improve
# 133s - loss: 0.3052 - dice: 0.6948 - binary_accuracy: 0.8186 - val_loss: 0.4326 - val_dice: 0.5674 - val_binary_accuracy: 0.8044
# Epoch 8/100
# Epoch 00007: val_dice improved from 0.59749 to 0.63287, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.6329-3.hdf5
# 135s - loss: 0.2579 - dice: 0.7421 - binary_accuracy: 0.8479 - val_loss: 0.3671 - val_dice: 0.6329 - val_binary_accuracy: 0.8181
# Epoch 9/100
# Epoch 00008: val_dice improved from 0.63287 to 0.64272, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.6427-3.hdf5
# 135s - loss: 0.2763 - dice: 0.7237 - binary_accuracy: 0.8388 - val_loss: 0.3573 - val_dice: 0.6427 - val_binary_accuracy: 0.8134
# Epoch 10/100
# Epoch 00009: val_dice improved from 0.64272 to 0.64618, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.6462-3.hdf5
# 134s - loss: 0.2706 - dice: 0.7294 - binary_accuracy: 0.8420 - val_loss: 0.3538 - val_dice: 0.6462 - val_binary_accuracy: 0.8224
# Epoch 11/100
# Epoch 00010: val_dice did not improve
# 133s - loss: 0.2764 - dice: 0.7236 - binary_accuracy: 0.8380 - val_loss: 0.3692 - val_dice: 0.6308 - val_binary_accuracy: 0.8175
# Epoch 12/100
#
# Epoch 00011: reducing learning rate to 0.00499999988824.
# Epoch 00011: val_dice did not improve
# 133s - loss: 0.2841 - dice: 0.7159 - binary_accuracy: 0.8372 - val_loss: 0.3891 - val_dice: 0.6109 - val_binary_accuracy: 0.8226
# Epoch 13/100
# Epoch 00012: val_dice did not improve
# 133s - loss: 0.2661 - dice: 0.7339 - binary_accuracy: 0.8473 - val_loss: 0.3659 - val_dice: 0.6341 - val_binary_accuracy: 0.8255
# Epoch 14/100
# Epoch 00013: val_dice improved from 0.64618 to 0.65570, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.6557-3.hdf5
# 134s - loss: 0.2474 - dice: 0.7526 - binary_accuracy: 0.8538 - val_loss: 0.3443 - val_dice: 0.6557 - val_binary_accuracy: 0.8260
# Epoch 15/100
# Epoch 00014: val_dice did not improve
# 133s - loss: 0.2562 - dice: 0.7438 - binary_accuracy: 0.8560 - val_loss: 0.3603 - val_dice: 0.6397 - val_binary_accuracy: 0.8274
# Epoch 16/100
# Epoch 00015: val_dice did not improve
# 133s - loss: 0.2636 - dice: 0.7364 - binary_accuracy: 0.8471 - val_loss: 0.3443 - val_dice: 0.6557 - val_binary_accuracy: 0.8296
# Epoch 17/100
# Epoch 00016: val_dice did not improve
# 133s - loss: 0.2585 - dice: 0.7415 - binary_accuracy: 0.8441 - val_loss: 0.3882 - val_dice: 0.6118 - val_binary_accuracy: 0.8233
# Epoch 18/100
#
# Epoch 00017: reducing learning rate to 0.00249999994412.
# Epoch 00017: val_dice improved from 0.65570 to 0.65708, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.6571-3.hdf5
# 135s - loss: 0.2674 - dice: 0.7326 - binary_accuracy: 0.8435 - val_loss: 0.3429 - val_dice: 0.6571 - val_binary_accuracy: 0.8193
# Epoch 19/100
# Epoch 00018: val_dice did not improve
# 133s - loss: 0.2525 - dice: 0.7475 - binary_accuracy: 0.8558 - val_loss: 0.3566 - val_dice: 0.6434 - val_binary_accuracy: 0.8295
# Epoch 20/100
# Epoch 00019: val_dice did not improve
# 134s - loss: 0.2637 - dice: 0.7363 - binary_accuracy: 0.8524 - val_loss: 0.3637 - val_dice: 0.6363 - val_binary_accuracy: 0.8289
# Epoch 21/100
# Epoch 00020: val_dice improved from 0.65708 to 0.67503, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.6750-3.hdf5
# 135s - loss: 0.2427 - dice: 0.7573 - binary_accuracy: 0.8633 - val_loss: 0.3250 - val_dice: 0.6750 - val_binary_accuracy: 0.8290
# Epoch 22/100
# Epoch 00021: val_dice did not improve
# 134s - loss: 0.2454 - dice: 0.7546 - binary_accuracy: 0.8621 - val_loss: 0.3404 - val_dice: 0.6596 - val_binary_accuracy: 0.8287
# Epoch 23/100
# Epoch 00022: val_dice did not improve
# 134s - loss: 0.2335 - dice: 0.7665 - binary_accuracy: 0.8681 - val_loss: 0.3820 - val_dice: 0.6180 - val_binary_accuracy: 0.8240
# Epoch 24/100
# Epoch 00023: val_dice improved from 0.67503 to 0.68665, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.6867-3.hdf5
# 135s - loss: 0.2544 - dice: 0.7456 - binary_accuracy: 0.8581 - val_loss: 0.3133 - val_dice: 0.6867 - val_binary_accuracy: 0.8352
# Epoch 25/100
# Epoch 00024: val_dice did not improve
# 134s - loss: 0.2385 - dice: 0.7615 - binary_accuracy: 0.8652 - val_loss: 0.3340 - val_dice: 0.6660 - val_binary_accuracy: 0.8242
# Epoch 26/100
# Epoch 00025: val_dice did not improve
# 134s - loss: 0.2444 - dice: 0.7556 - binary_accuracy: 0.8611 - val_loss: 0.3544 - val_dice: 0.6456 - val_binary_accuracy: 0.8312
# Epoch 27/100
#
# Epoch 00026: reducing learning rate to 0.00124999997206.
# Epoch 00026: val_dice did not improve
# 134s - loss: 0.2435 - dice: 0.7565 - binary_accuracy: 0.8636 - val_loss: 0.3138 - val_dice: 0.6862 - val_binary_accuracy: 0.8309
# Epoch 28/100
# Epoch 00027: val_dice improved from 0.68665 to 0.69013, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.6901-3.hdf5
# 135s - loss: 0.2348 - dice: 0.7652 - binary_accuracy: 0.8689 - val_loss: 0.3099 - val_dice: 0.6901 - val_binary_accuracy: 0.8366
# Epoch 29/100
# Epoch 00028: val_dice improved from 0.69013 to 0.70815, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7082-3.hdf5
# 135s - loss: 0.2132 - dice: 0.7868 - binary_accuracy: 0.8797 - val_loss: 0.2918 - val_dice: 0.7082 - val_binary_accuracy: 0.8376
# Epoch 30/100
# Epoch 00029: val_dice did not improve
# 134s - loss: 0.2272 - dice: 0.7728 - binary_accuracy: 0.8761 - val_loss: 0.3059 - val_dice: 0.6941 - val_binary_accuracy: 0.8182
# Epoch 31/100
# Epoch 00030: val_dice did not improve
# 134s - loss: 0.2430 - dice: 0.7570 - binary_accuracy: 0.8719 - val_loss: 0.3084 - val_dice: 0.6916 - val_binary_accuracy: 0.8257
# Epoch 32/100
# Epoch 00031: val_dice did not improve
# 134s - loss: 0.2100 - dice: 0.7900 - binary_accuracy: 0.8867 - val_loss: 0.3117 - val_dice: 0.6883 - val_binary_accuracy: 0.8246
# Epoch 33/100
#
# Epoch 00032: reducing learning rate to 0.00062499998603.
# Epoch 00032: val_dice did not improve
# 134s - loss: 0.2245 - dice: 0.7755 - binary_accuracy: 0.8756 - val_loss: 0.3250 - val_dice: 0.6750 - val_binary_accuracy: 0.8377
# Epoch 34/100
# Epoch 00033: val_dice did not improve
# 134s - loss: 0.2150 - dice: 0.7850 - binary_accuracy: 0.8818 - val_loss: 0.3096 - val_dice: 0.6904 - val_binary_accuracy: 0.8323
# Epoch 35/100
# Epoch 00034: val_dice improved from 0.70815 to 0.73372, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7337-3.hdf5
# 135s - loss: 0.2151 - dice: 0.7849 - binary_accuracy: 0.8792 - val_loss: 0.2663 - val_dice: 0.7337 - val_binary_accuracy: 0.8394
# Epoch 36/100
# Epoch 00035: val_dice did not improve
# 134s - loss: 0.2074 - dice: 0.7926 - binary_accuracy: 0.8867 - val_loss: 0.2904 - val_dice: 0.7096 - val_binary_accuracy: 0.8322
# Epoch 37/100
# Epoch 00036: val_dice improved from 0.73372 to 0.75477, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7548-3.hdf5
# 135s - loss: 0.2048 - dice: 0.7952 - binary_accuracy: 0.8871 - val_loss: 0.2452 - val_dice: 0.7548 - val_binary_accuracy: 0.8489
# Epoch 38/100
# Epoch 00037: val_dice did not improve
# 134s - loss: 0.2142 - dice: 0.7858 - binary_accuracy: 0.8862 - val_loss: 0.2616 - val_dice: 0.7384 - val_binary_accuracy: 0.8396
# Epoch 39/100
# Epoch 00038: val_dice did not improve
# 134s - loss: 0.2018 - dice: 0.7982 - binary_accuracy: 0.8897 - val_loss: 0.2760 - val_dice: 0.7240 - val_binary_accuracy: 0.8367
# Epoch 40/100
# Epoch 00039: val_dice did not improve
# 134s - loss: 0.2191 - dice: 0.7809 - binary_accuracy: 0.8836 - val_loss: 0.2937 - val_dice: 0.7063 - val_binary_accuracy: 0.8407
# Epoch 41/100
#
# Epoch 00040: reducing learning rate to 0.000312499993015.
# Epoch 00040: val_dice did not improve
# 134s - loss: 0.2270 - dice: 0.7730 - binary_accuracy: 0.8779 - val_loss: 0.2498 - val_dice: 0.7502 - val_binary_accuracy: 0.8502
# Epoch 42/100
# Epoch 00041: val_dice did not improve
# 134s - loss: 0.1977 - dice: 0.8023 - binary_accuracy: 0.8914 - val_loss: 0.2672 - val_dice: 0.7328 - val_binary_accuracy: 0.8421
# Epoch 43/100
# Epoch 00042: val_dice did not improve
# 134s - loss: 0.1931 - dice: 0.8069 - binary_accuracy: 0.8928 - val_loss: 0.2976 - val_dice: 0.7024 - val_binary_accuracy: 0.8375
# Epoch 44/100
#
# Epoch 00043: reducing learning rate to 0.000156249996508.
# Epoch 00043: val_dice did not improve
# 134s - loss: 0.2013 - dice: 0.7987 - binary_accuracy: 0.8939 - val_loss: 0.2708 - val_dice: 0.7292 - val_binary_accuracy: 0.8439
# Epoch 45/100
# Epoch 00044: val_dice did not improve
# 134s - loss: 0.1808 - dice: 0.8192 - binary_accuracy: 0.8989 - val_loss: 0.2617 - val_dice: 0.7383 - val_binary_accuracy: 0.8467
# Epoch 46/100
# Epoch 00045: val_dice did not improve
# 134s - loss: 0.1884 - dice: 0.8116 - binary_accuracy: 0.8941 - val_loss: 0.2765 - val_dice: 0.7235 - val_binary_accuracy: 0.8425
# Epoch 47/100
# Epoch 00046: val_dice improved from 0.75477 to 0.75710, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7571-3.hdf5
# 135s - loss: 0.1993 - dice: 0.8007 - binary_accuracy: 0.8948 - val_loss: 0.2429 - val_dice: 0.7571 - val_binary_accuracy: 0.8528
# Epoch 48/100
# Epoch 00047: val_dice did not improve
# 134s - loss: 0.1895 - dice: 0.8105 - binary_accuracy: 0.8949 - val_loss: 0.2672 - val_dice: 0.7328 - val_binary_accuracy: 0.8396
# Epoch 49/100
#
# Epoch 00048: reducing learning rate to 7.81249982538e-05.
# Epoch 00048: val_dice did not improve
# 134s - loss: 0.1933 - dice: 0.8067 - binary_accuracy: 0.8964 - val_loss: 0.2539 - val_dice: 0.7461 - val_binary_accuracy: 0.8448
# Epoch 50/100
# Epoch 00049: val_dice did not improve
# 134s - loss: 0.1892 - dice: 0.8108 - binary_accuracy: 0.8932 - val_loss: 0.2519 - val_dice: 0.7481 - val_binary_accuracy: 0.8494
# Epoch 51/100
# Epoch 00050: val_dice improved from 0.75710 to 0.76102, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7610-3.hdf5
# 135s - loss: 0.1911 - dice: 0.8089 - binary_accuracy: 0.8949 - val_loss: 0.2390 - val_dice: 0.7610 - val_binary_accuracy: 0.8537
# Epoch 52/100
#
# Epoch 00051: reducing learning rate to 3.90624991269e-05.
# Epoch 00051: val_dice did not improve
# 134s - loss: 0.1945 - dice: 0.8055 - binary_accuracy: 0.9002 - val_loss: 0.2551 - val_dice: 0.7449 - val_binary_accuracy: 0.8444
# Epoch 53/100
# Epoch 00052: val_dice did not improve
# 134s - loss: 0.1896 - dice: 0.8104 - binary_accuracy: 0.8988 - val_loss: 0.2544 - val_dice: 0.7456 - val_binary_accuracy: 0.8461
# Epoch 54/100
# Epoch 00053: val_dice did not improve
# 134s - loss: 0.2064 - dice: 0.7936 - binary_accuracy: 0.8948 - val_loss: 0.2499 - val_dice: 0.7501 - val_binary_accuracy: 0.8493
# Epoch 55/100
#
# Epoch 00054: reducing learning rate to 1.95312495634e-05.
#
# Epoch 00054: reducing learning rate to 9.76562478172e-06.
# Epoch 00054: val_dice did not improve
# 134s - loss: 0.1865 - dice: 0.8135 - binary_accuracy: 0.8958 - val_loss: 0.2501 - val_dice: 0.7499 - val_binary_accuracy: 0.8475
# Epoch 56/100
# Epoch 00055: val_dice did not improve
# 134s - loss: 0.1819 - dice: 0.8181 - binary_accuracy: 0.8996 - val_loss: 0.2476 - val_dice: 0.7524 - val_binary_accuracy: 0.8491
# Epoch 57/100
# Epoch 00056: val_dice did not improve
# 134s - loss: 0.1822 - dice: 0.8178 - binary_accuracy: 0.8990 - val_loss: 0.2471 - val_dice: 0.7529 - val_binary_accuracy: 0.8495
# Epoch 58/100
#
# Epoch 00057: reducing learning rate to 4.88281239086e-06.
#
# Epoch 00057: reducing learning rate to 2.44140619543e-06.
# Epoch 00057: val_dice did not improve
# 134s - loss: 0.1903 - dice: 0.8097 - binary_accuracy: 0.9005 - val_loss: 0.2469 - val_dice: 0.7531 - val_binary_accuracy: 0.8501
# Epoch 59/100
# Epoch 00058: val_dice did not improve
# 134s - loss: 0.1915 - dice: 0.8085 - binary_accuracy: 0.9010 - val_loss: 0.2485 - val_dice: 0.7515 - val_binary_accuracy: 0.8494
# Epoch 60/100
# Epoch 00059: val_dice did not improve
# 134s - loss: 0.1690 - dice: 0.8310 - binary_accuracy: 0.9041 - val_loss: 0.2517 - val_dice: 0.7483 - val_binary_accuracy: 0.8480
# Epoch 61/100
#
# Epoch 00060: reducing learning rate to 1.22070309772e-06.
# Epoch 00060: val_dice did not improve
# 134s - loss: 0.1861 - dice: 0.8139 - binary_accuracy: 0.9007 - val_loss: 0.2496 - val_dice: 0.7504 - val_binary_accuracy: 0.8487
# Epoch 62/100
# Epoch 00061: val_dice did not improve
# 134s - loss: 0.1814 - dice: 0.8186 - binary_accuracy: 0.8984 - val_loss: 0.2508 - val_dice: 0.7492 - val_binary_accuracy: 0.8481
# Epoch 00061: early stopping
# 2017-07-27 03:31:28.536625 ------------> 4
# Train on 136 samples, validate on 32 samples
# Epoch 1/100
# Epoch 00000: val_dice improved from -inf to 0.32151, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.3215-4.hdf5
# 140s - loss: 0.5386 - dice: 0.4614 - binary_accuracy: 0.4250 - val_loss: 0.6785 - val_dice: 0.3215 - val_binary_accuracy: 0.6593
# Epoch 2/100
# Epoch 00001: val_dice did not improve
# 137s - loss: 0.3829 - dice: 0.6171 - binary_accuracy: 0.7319 - val_loss: 0.8769 - val_dice: 0.1231 - val_binary_accuracy: 0.7024
# Epoch 3/100
# Epoch 00002: val_dice did not improve
# 136s - loss: 0.3227 - dice: 0.6773 - binary_accuracy: 0.8045 - val_loss: 0.7782 - val_dice: 0.2218 - val_binary_accuracy: 0.7326
# Epoch 4/100
# Epoch 00003: val_dice improved from 0.32151 to 0.70055, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7005-4.hdf5
# 137s - loss: 0.3190 - dice: 0.6810 - binary_accuracy: 0.8126 - val_loss: 0.2995 - val_dice: 0.7005 - val_binary_accuracy: 0.8577
# Epoch 5/100
# Epoch 00004: val_dice improved from 0.70055 to 0.71856, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7186-4.hdf5
# 137s - loss: 0.3160 - dice: 0.6840 - binary_accuracy: 0.7986 - val_loss: 0.2814 - val_dice: 0.7186 - val_binary_accuracy: 0.8514
# Epoch 6/100
# Epoch 00005: val_dice improved from 0.71856 to 0.72813, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7281-4.hdf5
# 137s - loss: 0.3054 - dice: 0.6946 - binary_accuracy: 0.8257 - val_loss: 0.2719 - val_dice: 0.7281 - val_binary_accuracy: 0.8551
# Epoch 7/100
# Epoch 00006: val_dice did not improve
# 135s - loss: 0.2932 - dice: 0.7068 - binary_accuracy: 0.8232 - val_loss: 0.2835 - val_dice: 0.7165 - val_binary_accuracy: 0.8126
# Epoch 8/100
# Epoch 00007: val_dice improved from 0.72813 to 0.74120, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7412-4.hdf5
# 136s - loss: 0.3251 - dice: 0.6749 - binary_accuracy: 0.7979 - val_loss: 0.2588 - val_dice: 0.7412 - val_binary_accuracy: 0.8651
# Epoch 9/100
# Epoch 00008: val_dice did not improve
# 135s - loss: 0.2753 - dice: 0.7247 - binary_accuracy: 0.8330 - val_loss: 0.2868 - val_dice: 0.7132 - val_binary_accuracy: 0.8015
# Epoch 10/100
# Epoch 00009: val_dice did not improve
# 135s - loss: 0.2835 - dice: 0.7165 - binary_accuracy: 0.8229 - val_loss: 0.2624 - val_dice: 0.7376 - val_binary_accuracy: 0.8652
# Epoch 11/100
# Epoch 00010: val_dice improved from 0.74120 to 0.75121, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7512-4.hdf5
# 136s - loss: 0.2676 - dice: 0.7324 - binary_accuracy: 0.8435 - val_loss: 0.2488 - val_dice: 0.7512 - val_binary_accuracy: 0.8550
# Epoch 12/100
# Epoch 00011: val_dice did not improve
# 135s - loss: 0.2806 - dice: 0.7194 - binary_accuracy: 0.8326 - val_loss: 0.2610 - val_dice: 0.7390 - val_binary_accuracy: 0.8669
# Epoch 13/100
# Epoch 00012: val_dice improved from 0.75121 to 0.75398, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7540-4.hdf5
# 136s - loss: 0.2673 - dice: 0.7327 - binary_accuracy: 0.8395 - val_loss: 0.2460 - val_dice: 0.7540 - val_binary_accuracy: 0.8609
# Epoch 14/100
# Epoch 00013: val_dice improved from 0.75398 to 0.76217, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7622-4.hdf5
# 136s - loss: 0.3079 - dice: 0.6921 - binary_accuracy: 0.8179 - val_loss: 0.2378 - val_dice: 0.7622 - val_binary_accuracy: 0.8755
# Epoch 15/100
# Epoch 00014: val_dice did not improve
# 135s - loss: 0.2727 - dice: 0.7273 - binary_accuracy: 0.8382 - val_loss: 0.2685 - val_dice: 0.7315 - val_binary_accuracy: 0.8744
# Epoch 16/100
# Epoch 00015: val_dice did not improve
# 135s - loss: 0.2882 - dice: 0.7118 - binary_accuracy: 0.8311 - val_loss: 0.2941 - val_dice: 0.7059 - val_binary_accuracy: 0.8820
# Epoch 17/100
# Epoch 00016: val_dice did not improve
# 135s - loss: 0.2621 - dice: 0.7379 - binary_accuracy: 0.8408 - val_loss: 0.2630 - val_dice: 0.7370 - val_binary_accuracy: 0.8769
# Epoch 18/100
#
# Epoch 00017: reducing learning rate to 0.00499999988824.
# Epoch 00017: val_dice did not improve
# 135s - loss: 0.2743 - dice: 0.7257 - binary_accuracy: 0.8382 - val_loss: 0.2487 - val_dice: 0.7513 - val_binary_accuracy: 0.8793
# Epoch 19/100
# Epoch 00018: val_dice did not improve
# 135s - loss: 0.2440 - dice: 0.7560 - binary_accuracy: 0.8596 - val_loss: 0.2490 - val_dice: 0.7510 - val_binary_accuracy: 0.8789
# Epoch 20/100
# Epoch 00019: val_dice did not improve
# 135s - loss: 0.2626 - dice: 0.7374 - binary_accuracy: 0.8495 - val_loss: 0.2515 - val_dice: 0.7485 - val_binary_accuracy: 0.8578
# Epoch 21/100
#
# Epoch 00020: reducing learning rate to 0.00249999994412.
# Epoch 00020: val_dice did not improve
# 135s - loss: 0.2598 - dice: 0.7402 - binary_accuracy: 0.8567 - val_loss: 0.2399 - val_dice: 0.7601 - val_binary_accuracy: 0.8786
# Epoch 22/100
# Epoch 00021: val_dice improved from 0.76217 to 0.77702, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7770-4.hdf5
# 137s - loss: 0.2387 - dice: 0.7613 - binary_accuracy: 0.8688 - val_loss: 0.2230 - val_dice: 0.7770 - val_binary_accuracy: 0.8726
# Epoch 23/100
# Epoch 00022: val_dice improved from 0.77702 to 0.78427, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7843-4.hdf5
# 137s - loss: 0.2576 - dice: 0.7424 - binary_accuracy: 0.8552 - val_loss: 0.2157 - val_dice: 0.7843 - val_binary_accuracy: 0.8885
# Epoch 24/100
# Epoch 00023: val_dice did not improve
# 135s - loss: 0.2387 - dice: 0.7613 - binary_accuracy: 0.8698 - val_loss: 0.2285 - val_dice: 0.7715 - val_binary_accuracy: 0.8893
# Epoch 25/100
# Epoch 00024: val_dice did not improve
# 135s - loss: 0.2238 - dice: 0.7762 - binary_accuracy: 0.8719 - val_loss: 0.2751 - val_dice: 0.7249 - val_binary_accuracy: 0.8796
# Epoch 26/100
# Epoch 00025: val_dice did not improve
# 135s - loss: 0.2285 - dice: 0.7715 - binary_accuracy: 0.8768 - val_loss: 0.2440 - val_dice: 0.7560 - val_binary_accuracy: 0.8834
# Epoch 27/100
#
# Epoch 00026: reducing learning rate to 0.00124999997206.
# Epoch 00026: val_dice did not improve
# 136s - loss: 0.2186 - dice: 0.7814 - binary_accuracy: 0.8811 - val_loss: 0.2494 - val_dice: 0.7506 - val_binary_accuracy: 0.8396
# Epoch 28/100
# Epoch 00027: val_dice did not improve
# 135s - loss: 0.2131 - dice: 0.7869 - binary_accuracy: 0.8821 - val_loss: 0.2594 - val_dice: 0.7406 - val_binary_accuracy: 0.8867
# Epoch 29/100
# Epoch 00028: val_dice did not improve
# 136s - loss: 0.2052 - dice: 0.7948 - binary_accuracy: 0.8856 - val_loss: 0.2426 - val_dice: 0.7574 - val_binary_accuracy: 0.8856
# Epoch 30/100
#
# Epoch 00029: reducing learning rate to 0.00062499998603.
# Epoch 00029: val_dice did not improve
# 136s - loss: 0.2184 - dice: 0.7816 - binary_accuracy: 0.8886 - val_loss: 0.2276 - val_dice: 0.7724 - val_binary_accuracy: 0.8854
# Epoch 31/100
# Epoch 00030: val_dice did not improve
# 136s - loss: 0.2079 - dice: 0.7921 - binary_accuracy: 0.8907 - val_loss: 0.2218 - val_dice: 0.7782 - val_binary_accuracy: 0.8830
# Epoch 32/100
# Epoch 00031: val_dice did not improve
# 136s - loss: 0.2144 - dice: 0.7856 - binary_accuracy: 0.8839 - val_loss: 0.2182 - val_dice: 0.7818 - val_binary_accuracy: 0.8889
# Epoch 33/100
#
# Epoch 00032: reducing learning rate to 0.000312499993015.
# Epoch 00032: val_dice did not improve
# 136s - loss: 0.1985 - dice: 0.8015 - binary_accuracy: 0.8942 - val_loss: 0.2235 - val_dice: 0.7765 - val_binary_accuracy: 0.8905
# Epoch 34/100
# Epoch 00033: val_dice did not improve
# 136s - loss: 0.1883 - dice: 0.8117 - binary_accuracy: 0.8991 - val_loss: 0.2214 - val_dice: 0.7786 - val_binary_accuracy: 0.8889
# Epoch 00033: early stopping
# 2017-07-27 04:48:45.443170

# %%
# !ls ../Temp/TempTempG5M5KFold -la | tail
# Out:
# -rwxrwxrwx 1 boba boba 248418336 июл 27 00:16 V1-UNET-val_dice=0.7563-2.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 27 02:57 V1-UNET-val_dice=0.7571-3.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 27 03:06 V1-UNET-val_dice=0.7610-3.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 27 04:03 V1-UNET-val_dice=0.7622-4.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 27 00:25 V1-UNET-val_dice=0.7734-2.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 27 04:21 V1-UNET-val_dice=0.7770-4.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 27 00:27 V1-UNET-val_dice=0.7811-2.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 27 00:45 V1-UNET-val_dice=0.7830-2.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 27 04:23 V1-UNET-val_dice=0.7843-4.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 27 00:47 V1-UNET-val_dice=0.7879-2.hdf5

# %%
if 0 : model10 = load_model('../Temp/TrainModel001+G+M/V1-UNET-0.8511.hdf5')
if 0 : model10 = load_model('../Temp/V1-UNET-0.8853.hdf5')
#if 1 : model10 = load_model('../Temp/TempTempM3/V1-UNET-0.9054.hdf5')
if 0 : model10.load_weights('../Temp/TempTempM3/V1-UNET-0.9054.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5/V1-UNET-val_dice=0.7307.hdf5')
if 1 : model10.load_weights('../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7879-2.hdf5')

# %%
# %time trP = model10.predict(trX,batch_size=batch_size)
# Out:
# CPU times: user 33.7 s, sys: 8.16 s, total: 41.9 s
# Wall time: 40.6 s

# %%
iii = 0
print(trX[0].shape,trY[0].shape,trP.shape,trP.min(),trP.max())
for ii in range(iii,iii+10) :
    plt.figure(figsize=(15,5))
    plt.subplot(141); plt.imshow(trX[ii,:,:,0],'gray'); 
    plt.subplot(142); plt.imshow(trY[ii,:,:,0],'gray'); 
    plt.subplot(143); plt.imshow(trP[ii,:,:,0],'gray'); 
    plt.subplot(144); plt.hist(trP[ii,:,:,0].ravel(),bins=50); 
    plt.show()
plt.close()
# Out:
# (512, 512, 3) (512, 512, 1) (168, 512, 512, 1) 0.0 1.0

# %%
trP01 = trP
trP01[trP>0.5] =1.0
trP01[trP<=0.5]=0.0

# %%
# Calculate F1-micro

# %%
TP = (trY[:,6:506,6:506,0]*trP01[:,6:506,6:506,0]).sum()
TN = ((1.0-trY[:,6:506,6:506,0])*(1.0-trP01[:,6:506,6:506,0])).sum()
FP = ((trY[:,6:506,6:506,0])*(1.0-trP01[:,6:506,6:506,0])).sum()
FN = ((1.0-trY[:,6:506,6:506,0])*(trP01[:,6:506,6:506,0])).sum()

P  = TP/(TP+FP) if (TP+FP)>0.0 else 1.0
R  = TP/(TP+FN) if (TP+FN)>0.0 else 0.0

F1 = 2.0*P*R/(P+R) if (P+R)>0.0 else 0.0

TP,TN,FP,FN,P,R,F1
#P*R,P+R, 2.0*P*R/(P+R)
# Out:
# (12508098.0,
#  23945989.0,
#  1580122.0,
#  3965791.0,
#  0.88784090538052363,
#  0.75926807568024768,
#  0.81853631239912139)

# %%
# Calculate DI- dice.mean()

# %%
dice, XX = [],[]
for i in range(trP.shape[0]) :
    G = trY  [i,6:506,6:506,0].sum()
    S = trP01[i,6:506,6:506,0].sum()
    X = (trY [i,6:506,6:506,0]*trP01[i,6:506,6:506,0]).sum()
    XX.append(X)
    dice.append((2.0*X/(G+S) if G+S>0 else 1.0))
di = (np.array(dice)).mean()
di,np.array(dice)  #,np.array(XX)
# Out:
# (0.75556086440466586,
#  array([ 0.59482813,  0.72978489,  0.794394  ,  0.84197956,  0.63363711,
#          0.02075765,  0.82873222,  0.77809615,  0.79926734,  0.97135036,
#          0.49070366,  0.43618267,  0.71917508,  0.81146515,  0.87011677,
#          0.80894972,  0.70137632,  0.71024738,  0.88092225,  0.47904557,
#          0.69823478,  0.81972076,  0.73075111,  0.58857394,  0.77383104,
#          0.80486647,  0.9720199 ,  0.9333177 ,  0.81748519,  0.88435037,
#          0.70996115,  0.95783206,  0.7689382 ,  1.        ,  0.49368771,
#          0.89176528,  0.66203039,  0.72384258,  0.8448628 ,  0.87955113,
#          0.69522407,  0.6962954 ,  0.66645086,  0.62493175,  0.70708468,
#          0.85380344,  0.3740169 ,  0.66301171,  0.64979361,  0.61380071,
#          0.80026147,  0.79751807,  0.55527236,  0.4460948 ,  0.96174122,
#          0.87465351,  0.78316824,  0.84688054,  0.90154984,  0.94216646,
#          0.41701248,  0.83651341,  0.88560993,  0.80197915,  0.91688467,
#          0.53344617,  0.76385276,  0.81860146,  0.98816629,  0.73786104,
#          0.92456901,  0.75659369,  0.63293752,  0.97546485,  0.63068271,
#          0.92759642,  0.64853094,  0.88380897,  0.79868197,  0.98853844,
#          0.78269533,  0.90116684,  0.82494844,  0.60490593,  0.70932247,
#          0.71496771,  0.45157593,  0.82678894,  0.95706577,  0.77961272,
#          0.50322973,  0.74429106,  0.21640607,  0.49070901,  0.89403301,
#          0.95221788,  0.89588458,  0.8421537 ,  0.85597927,  0.79877588,
#          0.66128312,  0.64629035,  0.77207872,  0.75878993,  0.88335326,
#          0.1735221 ,  0.80078345,  0.93322862,  0.78645476,  0.74395505,
#          0.78835335,  1.        ,  0.767525  ,  0.49337385,  0.95010167,
#          0.86213879,  0.81214763,  0.9089962 ,  0.80219845,  0.65121121,
#          0.66643946,  0.57015137,  0.93898145,  0.72758621,  0.97622675,
#          0.88318592,  0.91588592,  0.75360645,  0.98302364,  0.93889761,
#          0.48922179,  0.77353874,  0.61821643,  0.88793046,  0.7069939 ,
#          0.48824134,  0.74184091,  0.80381104,  0.86605522,  0.51924975,
#          0.65852991,  0.77852384,  0.79030817,  0.69623587,  0.73950309,
#          0.3725783 ,  0.88892983,  0.79216614,  0.74288088,  0.4265909 ,
#          0.90787342,  0.60638376,  0.79392041,  0.94271134,  0.94855317,
#          0.94712732,  0.82240848,  0.76041257,  0.90625238,  0.61510759,
#          0.9919047 ,  0.90312994,  0.54002966,  0.75261099,  0.93609235,
#          0.50089937,  0.83446563,  0.96880901]))

# %%
plt.hist(np.array(dice),bins=40); plt.show()
plt.plot(np.array(dice)); plt.show()

# %%
1000000*(F1+di)/2.0
# Out:
# 787048.58840189362

# %%
np.array(dice)<0.4
# Out:
# array([False, False, False, False, False,  True, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False,  True, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False,  True, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False,  True, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False], dtype=bool)

# %%
# Подготовка test решения

# %%
if flagGray :
    trO, trO0 = [], np.zeros((512,512,1))
else :
    trO, trO0 = [], np.zeros((512,512,3))

for xx in listTest :
    img = cv.imread(os.path.join(dirTest,xx),-1)
    if 1 and (Gauss or Median): 
        for cc in range(img.shape[2]) : 
            if Gauss  : img[:,:,cc] = cv.GaussianBlur(img[:,:,cc],(Gauss,Gauss),0);
            if Median : img[:,:,cc] = cv.medianBlur  (img[:,:,cc],Median);
    #print(img.mean(),msk.mean())
    if flagGray :
        img = cv.cvtColor(img,cv.COLOR_RGB2GRAY);
        trO0[6:506,6:506,0] = img[:,:]/255.0
    else :
        trO0[6:506,6:506,:] = img[:,:,:]/255.0
    trO.append(trO0.copy())
    #print(trX0.mean(),trY0.mean(),trX1[-1].mean(),trY1[-1].mean())

#print([trY[xx].mean() for xx in range(10)])
trO = np.array(trO)
    
trO.shape, trO.min(), trO.max()
#[trY[xx].mean() for xx in range(10)]
# Out:
# ((162, 512, 512, 3), 0.0, 0.99215686274509807)

# %%
# %time trOP = model10.predict(trO,batch_size=batch_size)
# Out:
# CPU times: user 32.8 s, sys: 7.71 s, total: 40.5 s
# Wall time: 39.2 s

# %%
trOP01 = trOP
trOP01[trOP>0.5] =1.0
trOP01[trOP<=0.5]=0.0

# %%
iii = 40
print(trO[0].shape,trP01[0].shape,trOP01.shape,trOP.min(),trOP.max())
for ii in range(iii,iii+10) :
    plt.figure(figsize=(15,5))
    plt.subplot(141); plt.imshow(trO[ii,:,:,0]); 
    plt.subplot(142); plt.imshow(trOP01[ii,:,:,0],'gray'); 
    plt.subplot(143); plt.imshow(trOP[ii,:,:,0],'gray'); 
    plt.subplot(144); plt.hist(trOP[ii,:,:,0].ravel(),bins=50); 
    plt.show()
plt.close()
# Out:
# (512, 512, 3) (512, 512, 1) (162, 512, 512, 1) 0.0 1.0

# %%
# Формирование выходной директории

# %%
def convert_to_binary(truth_png_file, truth_txt_file):
    im = Image.open(truth_png_file) #Can be many different formats.
    pix = im.load()
    with open(truth_txt_file, 'w') as out:
        for x in xrange(500):
            for y in xrange(500):
                out.write(str(int(pix[x, y] > 0)))
            out.write('\n')

if not os.path.exists('../Temp/random_submission'):
    os.makedirs('../Temp/random_submission')

# Training
for i in range(len(listTrain)) :
    fn = listTrain[i]
    truth_txt_file = '../Temp/random_submission/' + fn.split('.')[0] + '_mask.txt'
    with open(truth_txt_file, 'w') as out:
        for x in xrange(500):
            for y in xrange(500):
                out.write(str(int(trP01[i,y+6, x+6] > 0.0)))
            out.write('\n')
    out.close()
    
# Testing
for i in range(len(listTest)) :
    fn = listTest[i]
    truth_txt_file = '../Temp/random_submission/' + fn.split('.')[0] + '_mask.txt'
    with open(truth_txt_file, 'w') as out:
        for x in xrange(500):
            for y in xrange(500):
                out.write(str(int(trOP01[i,y+6, x+6] > 0.0)))
            out.write('\n')
    out.close()

# %%
import shutil

# %%
xx=shutil.make_archive('../Result/topcoderkonica','zip','../Temp/random_submission')
xx
# Out:
# '/media/boba/DATA/boba/Working/TopCoder/2017-07-25-Konica-Minolta/Result/topcoderkonica.zip'

# %%
# !ls ../Temp -la
# Out:
# total 4610508
# drwxrwxrwx 1 boba boba      4096 июл 26 10:58 .
# drwxrwxrwx 1 boba boba      4096 июл 26 10:11 ..
# drwxrwxrwx 1 boba boba         0 июл 25 18:17 .ipynb_checkpoints
# drwxrwxrwx 1 boba boba     61440 июл 26 09:14 random_submission
# -rwxrwxrwx 1 boba boba   1057596 июл 26 10:58 random_submission.zip
# drwxrwxrwx 1 boba boba         0 июл 25 23:35 TrainModel001-G-M
# drwxrwxrwx 1 boba boba         0 июл 25 22:21 TrainModel001-G+M
# drwxrwxrwx 1 boba boba         0 июл 25 21:48 TrainModel001+G-M
# drwxrwxrwx 1 boba boba      4096 июл 25 21:05 TrainModel001+G+M
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:02 V1-UNET-0.8167.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:08 V1-UNET-0.8275.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 18:33 V1-UNET-0.8305.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 18:02 V1-UNET-0.8418.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:09 V1-UNET-0.8486.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:09 V1-UNET-0.8593.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 18:34 V1-UNET-0.8601.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:21 V1-UNET-0.8602.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:22 V1-UNET-0.8605.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:35 V1-UNET-0.8628.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:35 V1-UNET-0.8633.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:23 V1-UNET-0.8635.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:36 V1-UNET-0.8645.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:36 V1-UNET-0.8652.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:24 V1-UNET-0.8655.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:11 V1-UNET-0.8793.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:13 V1-UNET-0.8796.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:14 V1-UNET-0.8808.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 18:02 V1-UNET-0.8853.hdf5

# %%
# !ls ../Work -la
#!ls ../Temp/random_submission
# Out:
# total 80768
# drwxrwxrwx 1 boba boba        0 июл 26 09:17 .
# drwxrwxrwx 1 boba boba     4096 июл 25 15:24 ..
# -rwxrwxrwx 1 boba boba 82700662 июл 26 09:32 topcoderkonica.zip

# %%
if False :
    save_model(model10,'../Data-Keras/Models/model-UNet.h5')
    model10.save_weights('../Data-Keras/Models/model-UNet-weights.h5')

# %%
rrr=pd.DataFrame(res,columns=['image_name','tags']); rrr.head(); 
suffixDT = (datetime.datetime.now()).strftime('%Y-%m-%d-%H-%M-%S'); print(suffixDT)
rrr.to_csv('../Result/vss'+suffixDT+'.csv',index=False);
# Out:
# 2017-05-20-05-51-18
