# %%
##
## UNet 
##
## Взята идея по описанию из https://github.com/pietz/unet-keras
##
##
## 2017-07-28
##   Добавлены flip+rotation LB=760393
##
## 2017-07-29
##   LB=769123
##
##

# %%
import sys,os,datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import fbeta_score
import sklearn.metrics as skm
from __future__ import print_function

# %%
print(np.__version__);
print(pd.__version__);
# Out:
# 1.13.1
# 0.19.2

# %%
import  cv2 as cv
cv.__version__
# Out:
# '3.2.0'

# %%
#from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.models import Sequential, save_model, load_model, Input, Model
from keras.layers import Convolution2D, MaxPooling2D, Convolution1D, MaxPooling1D, UpSampling2D, ZeroPadding2D
from keras.layers import Conv2D, Concatenate, Reshape
from keras.layers import Activation, Dropout, Flatten, Dense, Permute
from keras.layers.normalization import BatchNormalization
import keras.optimizers
from keras.callbacks import EarlyStopping,ReduceLROnPlateau,ModelCheckpoint
import keras.backend as K
# Out:
# Using TensorFlow backend.

# %%
keras.__version__
# Out:
# '2.0.6'

# %%
#---------------------------------------------------------------------

# %%
# !ls -la ..
#!ls -la ../Data
#!ls -la ../Data/training
# Out:
# total 25
# drwxrwxrwx 1 boba boba 4096 июл 26 11:10 .
# drwxrwxrwx 1 boba boba    0 июл 25 09:21 ..
# drwxrwxrwx 1 boba boba 4096 июл 25 09:23 Data
# drwxrwxrwx 1 boba boba    0 июл 25 09:22 Data-Arch
# drwxrwxrwx 1 boba boba    0 июл 25 09:26 Data-Keras
# drwxrwxrwx 1 boba boba 4096 июл 30 17:42 .git
# -rwxrwxrwx 2 boba boba  130 июл  9 12:02 .gitignore
# drwxrwxrwx 1 boba boba    0 июл 26 10:11 .ipynb_checkpoints
# drwxrwxrwx 1 boba boba    0 июл 30 17:43 Jupyter
# drwxrwxrwx 1 boba boba 4096 июл 30 20:52 Jupyter-Net
# drwxrwxrwx 1 boba boba 4096 июл 30 17:32 Result
# drwxrwxrwx 1 boba boba 4096 июл 30 17:41 Temp
# drwxrwxrwx 1 boba boba    0 июл 27 07:53 Work

# %%
dirData = '../Data'
dirTemp = '../Temp'
dirWork = '../Work'

dirTest  = os.path.join(dirData,'testing','images')
dirTrain = os.path.join(dirData,'training','images')
dirMask  = os.path.join(dirData,'training','truth')

# %%
listTrain = os.listdir(dirTrain)
listMask  = os.listdir(dirMask)
listTest  = os.listdir(dirTest)
listTrain = [xx for xx in listTrain if os.path.splitext(xx)[1]=='.tif']
listMask  = [xx for xx in listMask  if os.path.splitext(xx)[1]=='.png']
listTest  = [xx for xx in listTest  if os.path.splitext(xx)[1]=='.tif']
print(len(listTrain),len(listMask),len(listTest))
print(listTrain[:5],'\n',listMask[:5],'\n',listTest[:5])
# Out:
# 168 168 162
# ['i105404.tif', 'i117557.tif', 'i124017.tif', 'i130790.tif', 'i137857.tif']
#  ['i105404_mask.png', 'i117557_mask.png', 'i124017_mask.png', 'i130790_mask.png', 'i137857_mask.png']
#  ['i105047.tif', 'i116596.tif', 'i137649.tif', 'i140176.tif', 'i142099.tif']

# %%
if 0 :
    for xx in listTrain[:5] :
        img = cv.imread(os.path.join(dirTrain,xx),-1)
        xxm = os.path.splitext(xx)[0]+"_mask.png"
        msk = cv.imread(os.path.join(dirMask,xxm),-1)
        plt.subplot(121); plt.imshow(img); plt.subplot(122); plt.imshow(msk,'gray'); plt.show()
    plt.close()

# %%
msk.shape, img.shape, img.min(), img.max(), msk.max(), #img[6:10,6:10], msk[6:10,6:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-051c9d5448bc> in <module>()
# ----> 1 msk.shape, img.shape, img.min(), img.max(), msk.max(), #img[6:10,6:10], msk[6:10,6:10]
#
# NameError: name 'msk' is not defined

# %%
flagGray = False
Gauss    = 5
Median   = 5
if flagGray :
    trX, trY, trX0, trY0 = [], [], np.zeros((512,512,1)), np.zeros((512,512,1))
else :
    trX, trY, trX0, trY0 = [], [], np.zeros((512,512,3)), np.zeros((512,512,1))

for xx in listTrain :
    img = cv.imread(os.path.join(dirTrain,xx),-1)
    if 1 and (Gauss or Median): 
        for cc in range(img.shape[2]) : 
            if Gauss  : img[:,:,cc] = cv.GaussianBlur(img[:,:,cc],(Gauss,Gauss),0);
            if Median : img[:,:,cc] = cv.medianBlur  (img[:,:,cc],Median);
    xxm = os.path.splitext(xx)[0]+"_mask.png"
    msk = cv.imread(os.path.join(dirMask,xxm),-1)
    #print(img.mean(),msk.mean())
    if flagGray :
        img = cv.cvtColor(img,cv.COLOR_RGB2GRAY);
        trX0[6:506,6:506,0] = img[:,:]/255.0
        trY0[6:506,6:506,0] = msk[:,:]/255.0
    else :
        trX0[6:506,6:506,:] = img[:,:,:]/255.0
        trY0[6:506,6:506,0] = msk[:,:]/255.0
        trY0[trY0>=0.5] = 1.0
    trX.append(trX0.copy())
    trY.append(trY0.copy())
    #print(trX0.mean(),trY0.mean(),trX1[-1].mean(),trY1[-1].mean())

#print([trY[xx].mean() for xx in range(10)])
trX = np.array(trX)
trY = np.array(trY)

# аугментация
trXX, trYY, trXXX,trYYY = trX.copy(), trY.copy(), np.zeros((1)), np.zeros((1))


if 0 :
    # flipping
    for f in range(-1,2) :
        trXXX, trYYY = trX.copy(), trY.copy()
        for p in range(trXXX.shape[0]) :
            trXXX[p], trYYY[p,:,:,0] = cv.flip(trXXX[p],f), cv.flip(trYYY[p,:,:,0],f)
        trXX = np.vstack([trXX,trXXX])
        trYY = np.vstack([trYY,trYYY])
        print('flip :',f,trXX.shape,trYY.shape)

if 0 :
    # rotate +-90

    # rotate +90
    trXXX, trYYY = trX.copy(), trY.copy()
    for p in range(trX.shape[0]) :
        for i in range(trX.shape[1]) :
            for j in range(trX.shape[2]) :
                trXXX[p,i,j,:] = trX[p,j,trX.shape[1]-i-1]
                trYYY[p,i,j,:] = trY[p,j,trY.shape[1]-i-1]
    trXX = np.vstack([trXX,trXXX])
    trYY = np.vstack([trYY,trYYY])
    print('rotate +90:',trXX.shape,trYY.shape)

    # rotate -90
    trXXX, trYYY = trX.copy(), trY.copy()
    for p in range(trX.shape[0]) :
        for i in range(trX.shape[1]) :
            for j in range(trX.shape[2]) :
                trXXX[p,i,j,:] = trX[p,trX.shape[2]-j-1,i]
                trYYY[p,i,j,:] = trY[p,trY.shape[2]-j-1,i]
    trXX = np.vstack([trXX,trXXX])
    trYY = np.vstack([trYY,trYYY])
    print('rotate -90:',trXX.shape,trYY.shape)
    
trX, trY = trXX.copy(), trYY.copy()
del trXX,trYY
del trXXX,trYYY

# Считаем среднее по каналам и вычитаем из изображений
meanX = (trX[:,6:-6,6:-6,:].mean(axis=(1,2))).mean(axis=0)
stdX  = (trX[:,6:-6,6:-6,:].mean(axis=(1,2))).std(axis=0)
for cc in range(meanX.shape[0]) : 
    trX[:,6:-6,6:-6,cc] -= meanX[cc]    
print("mean={} std={}".format(meanX,stdX))
    
trX.shape, trX.min(), trX.max(), trY.shape, trY.min(), trY.max()
#[trY[xx].mean() for xx in range(10)]
# Out:
# mean=[ 0.6473997   0.48950165  0.70839568] std=[ 0.06249822  0.09179847  0.08778627]
# ((168, 512, 512, 3),
#  -0.62212117329583094,
#  0.48696893986925349,
#  (168, 512, 512, 1),
#  0.0,
#  1.0)

# %%
for xx in range(5) :
    img = trX[xx]
    xxm = trY[xx]
    plt.subplot(121); plt.imshow(img); plt.subplot(122); plt.imshow(xxm[:,:,0],'gray'); plt.show()
plt.close()

# %%
#
# model UNET
#
#    https://github.com/pietz/unet-keras
#
#

def level_block(m, dim, depth, acti, dropout=0.25, batch=True):
    if depth > 0:
        
        x = m
        if batch : x = BatchNormalization()(x)
        n = Conv2D(dim, (3, 3), activation=acti, padding='same')(x) #(m)
        n = Conv2D(dim, (3, 3), activation=acti, padding='same')(n)
        if dropout : n = Dropout(dropout)(n) ## add
        m = MaxPooling2D((2, 2))(n)
        m = level_block(m, 2*dim, depth-1, acti, dropout=dropout, batch=batch)
        m = UpSampling2D((2, 2))(m)
        m = Conv2D(dim, (2, 2), activation=acti, padding='same', kernel_initializer='he_normal')(m)
        if dropout : m = Dropout(dropout)(m) ## add
        m = Concatenate(axis=3)([n, m])
    m = Conv2D(dim, (3, 3), activation=acti, padding='same')(m)
    return Conv2D(dim, (3, 3), activation=acti, padding='same')(m)

def UNet(img_shape, n_out=2, dim=32, depth=5, acti='relu', flatten=False, dropout=0.25, batch=True):
    i = Input(shape=img_shape)
    ## ???? i = ZeroPadding2D((6,6),data_format="channels_last")
    o = level_block(i, dim, depth, acti, dropout=dropout, batch=batch)
    o = Conv2D(n_out, (1, 1), name='prediction')(o)
    if flatten:
        o = Reshape(n_out, img_shape[0] * img_shape[1])(o)
        o = Permute((2, 1))(o)
    #o = Activation('relu')(o)
    if batch : o = BatchNormalization()(o)  ######
    o = Activation('sigmoid')(o)
    return Model(inputs=i, outputs=o)

# %%
model10 = UNet((512,512,3),depth=4,n_out=1, dropout=0.05)
model10.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_2 (InputLayer)             (None, 512, 512, 3)   0
# ____________________________________________________________________________________________________
# batch_normalization_7 (BatchNorm (None, 512, 512, 3)   12          input_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_28 (Conv2D)               (None, 512, 512, 32)  896         batch_normalization_7[0][0]
# ____________________________________________________________________________________________________
# conv2d_29 (Conv2D)               (None, 512, 512, 32)  9248        conv2d_28[0][0]
# ____________________________________________________________________________________________________
# dropout_11 (Dropout)             (None, 512, 512, 32)  0           conv2d_29[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)   (None, 256, 256, 32)  0           dropout_11[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_8 (BatchNorm (None, 256, 256, 32)  128         max_pooling2d_6[0][0]
# ____________________________________________________________________________________________________
# conv2d_30 (Conv2D)               (None, 256, 256, 64)  18496       batch_normalization_8[0][0]
# ____________________________________________________________________________________________________
# conv2d_31 (Conv2D)               (None, 256, 256, 64)  36928       conv2d_30[0][0]
# ____________________________________________________________________________________________________
# dropout_12 (Dropout)             (None, 256, 256, 64)  0           conv2d_31[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)   (None, 128, 128, 64)  0           dropout_12[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_9 (BatchNorm (None, 128, 128, 64)  256         max_pooling2d_7[0][0]
# ____________________________________________________________________________________________________
# conv2d_32 (Conv2D)               (None, 128, 128, 128) 73856       batch_normalization_9[0][0]
# ____________________________________________________________________________________________________
# conv2d_33 (Conv2D)               (None, 128, 128, 128) 147584      conv2d_32[0][0]
# ____________________________________________________________________________________________________
# dropout_13 (Dropout)             (None, 128, 128, 128) 0           conv2d_33[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)   (None, 64, 64, 128)   0           dropout_13[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_10 (BatchNor (None, 64, 64, 128)   512         max_pooling2d_8[0][0]
# ____________________________________________________________________________________________________
# conv2d_34 (Conv2D)               (None, 64, 64, 256)   295168      batch_normalization_10[0][0]
# ____________________________________________________________________________________________________
# conv2d_35 (Conv2D)               (None, 64, 64, 256)   590080      conv2d_34[0][0]
# ____________________________________________________________________________________________________
# dropout_14 (Dropout)             (None, 64, 64, 256)   0           conv2d_35[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)   (None, 32, 32, 256)   0           dropout_14[0][0]
# ____________________________________________________________________________________________________
# conv2d_36 (Conv2D)               (None, 32, 32, 512)   1180160     max_pooling2d_9[0][0]
# ____________________________________________________________________________________________________
# conv2d_37 (Conv2D)               (None, 32, 32, 512)   2359808     conv2d_36[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)   (None, 64, 64, 512)   0           conv2d_37[0][0]
# ____________________________________________________________________________________________________
# conv2d_38 (Conv2D)               (None, 64, 64, 256)   524544      up_sampling2d_6[0][0]
# ____________________________________________________________________________________________________
# dropout_15 (Dropout)             (None, 64, 64, 256)   0           conv2d_38[0][0]
# ____________________________________________________________________________________________________
# concatenate_6 (Concatenate)      (None, 64, 64, 512)   0           dropout_14[0][0]
#                                                                    dropout_15[0][0]
# ____________________________________________________________________________________________________
# conv2d_39 (Conv2D)               (None, 64, 64, 256)   1179904     concatenate_6[0][0]
# ____________________________________________________________________________________________________
# conv2d_40 (Conv2D)               (None, 64, 64, 256)   590080      conv2d_39[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)   (None, 128, 128, 256) 0           conv2d_40[0][0]
# ____________________________________________________________________________________________________
# conv2d_41 (Conv2D)               (None, 128, 128, 128) 131200      up_sampling2d_7[0][0]
# ____________________________________________________________________________________________________
# dropout_16 (Dropout)             (None, 128, 128, 128) 0           conv2d_41[0][0]
# ____________________________________________________________________________________________________
# concatenate_7 (Concatenate)      (None, 128, 128, 256) 0           dropout_13[0][0]
#                                                                    dropout_16[0][0]
# ____________________________________________________________________________________________________
# conv2d_42 (Conv2D)               (None, 128, 128, 128) 295040      concatenate_7[0][0]
# ____________________________________________________________________________________________________
# conv2d_43 (Conv2D)               (None, 128, 128, 128) 147584      conv2d_42[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_8 (UpSampling2D)   (None, 256, 256, 128) 0           conv2d_43[0][0]
# ____________________________________________________________________________________________________
# conv2d_44 (Conv2D)               (None, 256, 256, 64)  32832       up_sampling2d_8[0][0]
# ____________________________________________________________________________________________________
# dropout_17 (Dropout)             (None, 256, 256, 64)  0           conv2d_44[0][0]
# ____________________________________________________________________________________________________
# concatenate_8 (Concatenate)      (None, 256, 256, 128) 0           dropout_12[0][0]
#                                                                    dropout_17[0][0]
# ____________________________________________________________________________________________________
# conv2d_45 (Conv2D)               (None, 256, 256, 64)  73792       concatenate_8[0][0]
# ____________________________________________________________________________________________________
# conv2d_46 (Conv2D)               (None, 256, 256, 64)  36928       conv2d_45[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_9 (UpSampling2D)   (None, 512, 512, 64)  0           conv2d_46[0][0]
# ____________________________________________________________________________________________________
# conv2d_47 (Conv2D)               (None, 512, 512, 32)  8224        up_sampling2d_9[0][0]
# ____________________________________________________________________________________________________
# dropout_18 (Dropout)             (None, 512, 512, 32)  0           conv2d_47[0][0]
# ____________________________________________________________________________________________________
# concatenate_9 (Concatenate)      (None, 512, 512, 64)  0           dropout_11[0][0]
#                                                                    dropout_18[0][0]
# ____________________________________________________________________________________________________
# conv2d_48 (Conv2D)               (None, 512, 512, 32)  18464       concatenate_9[0][0]
# ____________________________________________________________________________________________________
# conv2d_49 (Conv2D)               (None, 512, 512, 32)  9248        conv2d_48[0][0]
# ____________________________________________________________________________________________________
# prediction (Conv2D)              (None, 512, 512, 1)   33          conv2d_49[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_11 (BatchNor (None, 512, 512, 1)   4           prediction[0][0]
# ____________________________________________________________________________________________________
# activation_2 (Activation)        (None, 512, 512, 1)   0           batch_normalization_11[0][0]
# ====================================================================================================
# Total params: 7,761,009
# Trainable params: 7,760,553
# Non-trainable params: 456
# ____________________________________________________________________________________________________

# %%
def dice (truth,pred) :
    g, s = K.sum(truth), K.sum(pred)
    x    = K.sum((truth*pred))
    return((1.0 if K.sum(g+s)==0.0 else 2.0*x/(g+s+K.epsilon())))

def f1 (truth,pred) :
    TP = K.sum(truth*pred)
    TN = K.sum((1.0-truth)*(1.0-pred))
    FP = K.sum(truth*(1.0-pred))
    FN = K.sum((1.0-truth)*pred)

    
    P  = 1.0 if K.sum(TP+FP)==0.0 else TP/(TP+FP)
    R  = 0.0 if K.sum(TP+FN)==0.0 else TP/(TP+FN) 

    F1 = 0.0 if K.sum(P+R)  ==0.0 else 2.0*P*R/(P+R)

    return(F1)

def f1dice (truth,pred) :
    return ((dice(truth,pred)+f1(truth,pred))/2.0)
    
def lossdice (truth,pred) :
    return(1.0 - dice(truth,pred))

def lossfd (truth,pred) :
    return(1.0 - f1dice(truth,pred))

# %%
def buildModel (input_shape) :
##    model = UNet(input_shape,depth=5,n_out=1,dropout=0.05,batch=False)
    model = UNet(input_shape,depth=5-1,n_out=1,dropout=0.05,batch=False)
    
    sgd = keras.optimizers.SGD(lr=0.01, momentum=0.9, nesterov=True)
    #model.compile(loss='mean_absolute_error',  #'binary_crossentropy',
    model.compile(loss=lossdice, #'mean_absolute_error',  #'binary_crossentropy',
                  optimizer=sgd, #sgd, #"adam", #'rmsprop',
                  metrics=[dice,'binary_accuracy']) #['binary_accuracy']) #[fbeta_pred]) #['accuracy',fbeta_pred]) #['accuracy'])
    return(model)

# %%
K.clear_session()
model10 = buildModel((trX.shape[1],trX.shape[2],trX.shape[3]))
model10.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 512, 512, 3)   0
# ____________________________________________________________________________________________________
# conv2d_1 (Conv2D)                (None, 512, 512, 32)  896         input_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_2 (Conv2D)                (None, 512, 512, 32)  9248        conv2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 512, 512, 32)  0           conv2d_2[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)   (None, 256, 256, 32)  0           dropout_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_3 (Conv2D)                (None, 256, 256, 64)  18496       max_pooling2d_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_4 (Conv2D)                (None, 256, 256, 64)  36928       conv2d_3[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)              (None, 256, 256, 64)  0           conv2d_4[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)   (None, 128, 128, 64)  0           dropout_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_5 (Conv2D)                (None, 128, 128, 128) 73856       max_pooling2d_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_6 (Conv2D)                (None, 128, 128, 128) 147584      conv2d_5[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)              (None, 128, 128, 128) 0           conv2d_6[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)   (None, 64, 64, 128)   0           dropout_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_7 (Conv2D)                (None, 64, 64, 256)   295168      max_pooling2d_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_8 (Conv2D)                (None, 64, 64, 256)   590080      conv2d_7[0][0]
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)              (None, 64, 64, 256)   0           conv2d_8[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)   (None, 32, 32, 256)   0           dropout_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_9 (Conv2D)                (None, 32, 32, 512)   1180160     max_pooling2d_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_10 (Conv2D)               (None, 32, 32, 512)   2359808     conv2d_9[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)   (None, 64, 64, 512)   0           conv2d_10[0][0]
# ____________________________________________________________________________________________________
# conv2d_11 (Conv2D)               (None, 64, 64, 256)   524544      up_sampling2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_5 (Dropout)              (None, 64, 64, 256)   0           conv2d_11[0][0]
# ____________________________________________________________________________________________________
# concatenate_1 (Concatenate)      (None, 64, 64, 512)   0           dropout_4[0][0]
#                                                                    dropout_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_12 (Conv2D)               (None, 64, 64, 256)   1179904     concatenate_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_13 (Conv2D)               (None, 64, 64, 256)   590080      conv2d_12[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)   (None, 128, 128, 256) 0           conv2d_13[0][0]
# ____________________________________________________________________________________________________
# conv2d_14 (Conv2D)               (None, 128, 128, 128) 131200      up_sampling2d_2[0][0]
# ____________________________________________________________________________________________________
# dropout_6 (Dropout)              (None, 128, 128, 128) 0           conv2d_14[0][0]
# ____________________________________________________________________________________________________
# concatenate_2 (Concatenate)      (None, 128, 128, 256) 0           dropout_3[0][0]
#                                                                    dropout_6[0][0]
# ____________________________________________________________________________________________________
# conv2d_15 (Conv2D)               (None, 128, 128, 128) 295040      concatenate_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_16 (Conv2D)               (None, 128, 128, 128) 147584      conv2d_15[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)   (None, 256, 256, 128) 0           conv2d_16[0][0]
# ____________________________________________________________________________________________________
# conv2d_17 (Conv2D)               (None, 256, 256, 64)  32832       up_sampling2d_3[0][0]
# ____________________________________________________________________________________________________
# dropout_7 (Dropout)              (None, 256, 256, 64)  0           conv2d_17[0][0]
# ____________________________________________________________________________________________________
# concatenate_3 (Concatenate)      (None, 256, 256, 128) 0           dropout_2[0][0]
#                                                                    dropout_7[0][0]
# ____________________________________________________________________________________________________
# conv2d_18 (Conv2D)               (None, 256, 256, 64)  73792       concatenate_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_19 (Conv2D)               (None, 256, 256, 64)  36928       conv2d_18[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)   (None, 512, 512, 64)  0           conv2d_19[0][0]
# ____________________________________________________________________________________________________
# conv2d_20 (Conv2D)               (None, 512, 512, 32)  8224        up_sampling2d_4[0][0]
# ____________________________________________________________________________________________________
# dropout_8 (Dropout)              (None, 512, 512, 32)  0           conv2d_20[0][0]
# ____________________________________________________________________________________________________
# concatenate_4 (Concatenate)      (None, 512, 512, 64)  0           dropout_1[0][0]
#                                                                    dropout_8[0][0]
# ____________________________________________________________________________________________________
# conv2d_21 (Conv2D)               (None, 512, 512, 32)  18464       concatenate_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_22 (Conv2D)               (None, 512, 512, 32)  9248        conv2d_21[0][0]
# ____________________________________________________________________________________________________
# prediction (Conv2D)              (None, 512, 512, 1)   33          conv2d_22[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 512, 512, 1)   0           prediction[0][0]
# ====================================================================================================
# Total params: 7,760,097
# Trainable params: 7,760,097
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
#model10.load_weights('../Data-Keras/Models/model-UNet-weights.h5', by_name=False)
batch_size = 1

# %%
#epochs     = 150
epochs     = 50
verbose    = 2
batch_size = 1
metric     = 'binary_accuracy'
metric     = 'dice'

############trX, trY = trX[0:30], trY[0:30]

#folds      = 10
folds      = 5
folds      = 3
foldN      = trX.shape[0]/folds+1

print(datetime.datetime.now(),'Training with folds')

for i in range(folds) :
#for i in range(8,11) :

    print(datetime.datetime.now(),'------------>',i)

    K.clear_session()
    model10 = buildModel((trX.shape[1],trX.shape[2],trX.shape[3]))
    ############if 1 : model10.load_weights('../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7660-2.hdf5')

#    early_stopping = EarlyStopping(monitor='val_loss', patience=10,min_delta=0.0001,verbose=1)
    early_stopping = EarlyStopping(monitor='val_loss', patience=5,min_delta=0.0001,verbose=1)
    reduce_lr1     = ReduceLROnPlateau(monitor='val_loss', factor=0.5,patience=3, min_lr=0.0000001,verbose=1)
    reduce_lr2     = ReduceLROnPlateau(monitor='loss',     factor=0.5,patience=3, min_lr=0.0000001,verbose=1)

    filepath="../Temp/NewStep/Level-1/V1-UNET-val_"+metric+"={val_"+metric+":.4f}-{"+metric+":.4f}---"+str(i)+".hdf5"
    #filepath="../Temp/NewStep/StandartF5/V1-UNET-val_"+metric+"={val_"+metric+":.4f}-{"+metric+":.4f}---"+str(i)+".hdf5"
    #filepath="../Temp/TempTempG5M5KFold10/V1-UNET-val_"+metric+"={val_"+metric+":.4f}-{"+metric+":.4f}---"+str(i)+".hdf5"
    #checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
    checkpoint1 = ModelCheckpoint(filepath, monitor=metric,        verbose=1, save_best_only=True, mode='max')
    checkpoint2 = ModelCheckpoint(filepath, monitor='val_'+metric, verbose=1, save_best_only=True, mode='max')

    step  = 60
    low   = 0
    high  = low+step
    
    tFold = [True]*(i*foldN)+[False]*foldN+[True]*trX.shape[0];
    tFold = tFold[:trX.shape[0]]
    
    vFold = [not xx for xx in tFold]

    #hist1  = model10.fit(trX[low:high],trY[low:high],
    hist1  = model10.fit(trX[tFold],trY[tFold],
                        epochs=epochs, batch_size=batch_size, 
                        #validation_split=0.20, 
                        validation_data=(trX[vFold],trY[vFold]),
                        initial_epoch = 0,
                        #callbacks=[early_stopping,reduce_lr1,reduce_lr2,checkpoint],
                        callbacks=[reduce_lr1,reduce_lr2,checkpoint1,checkpoint2,early_stopping],
                        verbose=verbose)

print(datetime.datetime.now())
# Out:
# 2017-07-30 20:55:15.104285 Training with folds
# 2017-07-30 20:55:15.104919 ------------> 0
# Train on 111 samples, validate on 57 samples
# Epoch 1/50
# Epoch 00000: dice improved from -inf to 0.42452, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.4075-0.4245---0.hdf5
# Epoch 00000: val_dice improved from -inf to 0.40745, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.4075-0.4245---0.hdf5
# 50s - loss: 0.5755 - dice: 0.4245 - binary_accuracy: 0.3424 - val_loss: 0.5925 - val_dice: 0.4075 - val_binary_accuracy: 0.2860
# Epoch 2/50
# Epoch 00001: dice improved from 0.42452 to 0.48740, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.4886-0.4874---0.hdf5
# Epoch 00001: val_dice improved from 0.40745 to 0.48855, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.4886-0.4874---0.hdf5
# 46s - loss: 0.5126 - dice: 0.4874 - binary_accuracy: 0.4592 - val_loss: 0.5114 - val_dice: 0.4886 - val_binary_accuracy: 0.7123
# Epoch 3/50
# Epoch 00002: dice improved from 0.48740 to 0.61604, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.5793-0.6160---0.hdf5
# Epoch 00002: val_dice improved from 0.48855 to 0.57934, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.5793-0.6160---0.hdf5
# 45s - loss: 0.3840 - dice: 0.6160 - binary_accuracy: 0.7759 - val_loss: 0.4207 - val_dice: 0.5793 - val_binary_accuracy: 0.8159
# Epoch 4/50
# Epoch 00003: dice improved from 0.61604 to 0.63454, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.5886-0.6345---0.hdf5
# Epoch 00003: val_dice improved from 0.57934 to 0.58857, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.5886-0.6345---0.hdf5
# 45s - loss: 0.3655 - dice: 0.6345 - binary_accuracy: 0.7869 - val_loss: 0.4114 - val_dice: 0.5886 - val_binary_accuracy: 0.8166
# Epoch 5/50
# Epoch 00004: dice improved from 0.63454 to 0.65300, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.5171-0.6530---0.hdf5
# Epoch 00004: val_dice did not improve
# 44s - loss: 0.3470 - dice: 0.6530 - binary_accuracy: 0.8236 - val_loss: 0.4829 - val_dice: 0.5171 - val_binary_accuracy: 0.6298
# Epoch 6/50
# Epoch 00005: dice did not improve
# Epoch 00005: val_dice improved from 0.58857 to 0.58946, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.5895-0.6218---0.hdf5
# 44s - loss: 0.3782 - dice: 0.6218 - binary_accuracy: 0.7803 - val_loss: 0.4105 - val_dice: 0.5895 - val_binary_accuracy: 0.7613
# Epoch 7/50
# Epoch 00006: dice did not improve
# Epoch 00006: val_dice improved from 0.58946 to 0.60514, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6051-0.6505---0.hdf5
# 44s - loss: 0.3495 - dice: 0.6505 - binary_accuracy: 0.8081 - val_loss: 0.3949 - val_dice: 0.6051 - val_binary_accuracy: 0.7947
# Epoch 8/50
# Epoch 00007: dice improved from 0.65300 to 0.66408, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6171-0.6641---0.hdf5
# Epoch 00007: val_dice improved from 0.60514 to 0.61711, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6171-0.6641---0.hdf5
# 44s - loss: 0.3359 - dice: 0.6641 - binary_accuracy: 0.8313 - val_loss: 0.3829 - val_dice: 0.6171 - val_binary_accuracy: 0.7940
# Epoch 9/50
# Epoch 00008: dice improved from 0.66408 to 0.67896, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6123-0.6790---0.hdf5
# Epoch 00008: val_dice did not improve
# 44s - loss: 0.3210 - dice: 0.6790 - binary_accuracy: 0.8361 - val_loss: 0.3877 - val_dice: 0.6123 - val_binary_accuracy: 0.7778
# Epoch 10/50
# Epoch 00009: dice improved from 0.67896 to 0.68123, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6354-0.6812---0.hdf5
# Epoch 00009: val_dice improved from 0.61711 to 0.63536, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6354-0.6812---0.hdf5
# 44s - loss: 0.3188 - dice: 0.6812 - binary_accuracy: 0.8401 - val_loss: 0.3646 - val_dice: 0.6354 - val_binary_accuracy: 0.8235
# Epoch 11/50
# Epoch 00010: dice did not improve
# Epoch 00010: val_dice did not improve
# 43s - loss: 0.3269 - dice: 0.6731 - binary_accuracy: 0.8311 - val_loss: 0.3835 - val_dice: 0.6165 - val_binary_accuracy: 0.7913
# Epoch 12/50
# Epoch 00011: dice did not improve
# Epoch 00011: val_dice improved from 0.63536 to 0.63568, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6357-0.6706---0.hdf5
# 44s - loss: 0.3294 - dice: 0.6706 - binary_accuracy: 0.8106 - val_loss: 0.3643 - val_dice: 0.6357 - val_binary_accuracy: 0.8456
# Epoch 13/50
# Epoch 00012: dice did not improve
# Epoch 00012: val_dice did not improve
# 43s - loss: 0.3206 - dice: 0.6794 - binary_accuracy: 0.8260 - val_loss: 0.3828 - val_dice: 0.6172 - val_binary_accuracy: 0.7859
# Epoch 14/50
# Epoch 00013: dice improved from 0.68123 to 0.69008, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6393-0.6901---0.hdf5
# Epoch 00013: val_dice improved from 0.63568 to 0.63928, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6393-0.6901---0.hdf5
# 44s - loss: 0.3099 - dice: 0.6901 - binary_accuracy: 0.8462 - val_loss: 0.3607 - val_dice: 0.6393 - val_binary_accuracy: 0.8470
# Epoch 15/50
# Epoch 00014: dice improved from 0.69008 to 0.70151, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6335-0.7015---0.hdf5
# Epoch 00014: val_dice did not improve
# 44s - loss: 0.2985 - dice: 0.7015 - binary_accuracy: 0.8509 - val_loss: 0.3665 - val_dice: 0.6335 - val_binary_accuracy: 0.8094
# Epoch 16/50
# Epoch 00015: dice did not improve
# Epoch 00015: val_dice did not improve
# 43s - loss: 0.3026 - dice: 0.6974 - binary_accuracy: 0.8433 - val_loss: 0.3616 - val_dice: 0.6384 - val_binary_accuracy: 0.8517
# Epoch 17/50
# Epoch 00016: dice improved from 0.70151 to 0.70833, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6377-0.7083---0.hdf5
# Epoch 00016: val_dice did not improve
# 44s - loss: 0.2917 - dice: 0.7083 - binary_accuracy: 0.8572 - val_loss: 0.3623 - val_dice: 0.6377 - val_binary_accuracy: 0.8522
# Epoch 18/50
# Epoch 00017: dice did not improve
# Epoch 00017: val_dice improved from 0.63928 to 0.65194, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6519-0.7012---0.hdf5
# 44s - loss: 0.2988 - dice: 0.7012 - binary_accuracy: 0.8489 - val_loss: 0.3481 - val_dice: 0.6519 - val_binary_accuracy: 0.8558
# Epoch 19/50
# Epoch 00018: dice improved from 0.70833 to 0.70900, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6516-0.7090---0.hdf5
# Epoch 00018: val_dice did not improve
# 44s - loss: 0.2910 - dice: 0.7090 - binary_accuracy: 0.8569 - val_loss: 0.3484 - val_dice: 0.6516 - val_binary_accuracy: 0.8308
# Epoch 20/50
# Epoch 00019: dice improved from 0.70900 to 0.72165, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6548-0.7217---0.hdf5
# Epoch 00019: val_dice improved from 0.65194 to 0.65481, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6548-0.7217---0.hdf5
# 44s - loss: 0.2783 - dice: 0.7217 - binary_accuracy: 0.8573 - val_loss: 0.3452 - val_dice: 0.6548 - val_binary_accuracy: 0.8480
# Epoch 21/50
# Epoch 00020: dice did not improve
# Epoch 00020: val_dice improved from 0.65481 to 0.65877, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6588-0.7187---0.hdf5
# 44s - loss: 0.2813 - dice: 0.7187 - binary_accuracy: 0.8605 - val_loss: 0.3412 - val_dice: 0.6588 - val_binary_accuracy: 0.8373
# Epoch 22/50
# Epoch 00021: dice did not improve
# Epoch 00021: val_dice improved from 0.65877 to 0.65900, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6590-0.7177---0.hdf5
# 44s - loss: 0.2823 - dice: 0.7177 - binary_accuracy: 0.8600 - val_loss: 0.3410 - val_dice: 0.6590 - val_binary_accuracy: 0.8478
# Epoch 23/50
# Epoch 00022: dice improved from 0.72165 to 0.72553, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6541-0.7255---0.hdf5
# Epoch 00022: val_dice did not improve
# 44s - loss: 0.2745 - dice: 0.7255 - binary_accuracy: 0.8653 - val_loss: 0.3459 - val_dice: 0.6541 - val_binary_accuracy: 0.8537
# Epoch 24/50
# Epoch 00023: dice did not improve
# Epoch 00023: val_dice did not improve
# 43s - loss: 0.2774 - dice: 0.7226 - binary_accuracy: 0.8602 - val_loss: 0.3852 - val_dice: 0.6148 - val_binary_accuracy: 0.8551
# Epoch 25/50
# Epoch 00024: dice did not improve
# Epoch 00024: val_dice did not improve
# 43s - loss: 0.2833 - dice: 0.7167 - binary_accuracy: 0.8540 - val_loss: 0.3547 - val_dice: 0.6453 - val_binary_accuracy: 0.8139
# Epoch 26/50
#
# Epoch 00025: reducing learning rate to 0.00499999988824.
# Epoch 00025: dice improved from 0.72553 to 0.72737, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6525-0.7274---0.hdf5
# Epoch 00025: val_dice did not improve
# 43s - loss: 0.2726 - dice: 0.7274 - binary_accuracy: 0.8660 - val_loss: 0.3475 - val_dice: 0.6525 - val_binary_accuracy: 0.8230
# Epoch 27/50
# Epoch 00026: dice improved from 0.72737 to 0.73042, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6684-0.7304---0.hdf5
# Epoch 00026: val_dice improved from 0.65900 to 0.66838, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6684-0.7304---0.hdf5
# 44s - loss: 0.2696 - dice: 0.7304 - binary_accuracy: 0.8664 - val_loss: 0.3316 - val_dice: 0.6684 - val_binary_accuracy: 0.8520
# Epoch 28/50
# Epoch 00027: dice improved from 0.73042 to 0.73644, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6714-0.7364---0.hdf5
# Epoch 00027: val_dice improved from 0.66838 to 0.67144, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6714-0.7364---0.hdf5
# 44s - loss: 0.2636 - dice: 0.7364 - binary_accuracy: 0.8680 - val_loss: 0.3286 - val_dice: 0.6714 - val_binary_accuracy: 0.8414
# Epoch 29/50
# Epoch 00028: dice improved from 0.73644 to 0.74081, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6587-0.7408---0.hdf5
# Epoch 00028: val_dice did not improve
# 43s - loss: 0.2592 - dice: 0.7408 - binary_accuracy: 0.8747 - val_loss: 0.3413 - val_dice: 0.6587 - val_binary_accuracy: 0.8557
# Epoch 30/50
# Epoch 00029: dice did not improve
# Epoch 00029: val_dice improved from 0.67144 to 0.67254, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6725-0.7398---0.hdf5
# 43s - loss: 0.2602 - dice: 0.7398 - binary_accuracy: 0.8717 - val_loss: 0.3275 - val_dice: 0.6725 - val_binary_accuracy: 0.8397
# Epoch 31/50
# Epoch 00030: dice improved from 0.74081 to 0.74973, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6740-0.7497---0.hdf5
# Epoch 00030: val_dice improved from 0.67254 to 0.67401, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6740-0.7497---0.hdf5
# 44s - loss: 0.2503 - dice: 0.7497 - binary_accuracy: 0.8741 - val_loss: 0.3260 - val_dice: 0.6740 - val_binary_accuracy: 0.8644
# Epoch 32/50
# Epoch 00031: dice did not improve
# Epoch 00031: val_dice improved from 0.67401 to 0.67579, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6758-0.7444---0.hdf5
# 43s - loss: 0.2556 - dice: 0.7444 - binary_accuracy: 0.8746 - val_loss: 0.3242 - val_dice: 0.6758 - val_binary_accuracy: 0.8414
# Epoch 33/50
# Epoch 00032: dice improved from 0.74973 to 0.75043, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6857-0.7504---0.hdf5
# Epoch 00032: val_dice improved from 0.67579 to 0.68574, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6857-0.7504---0.hdf5
# 44s - loss: 0.2496 - dice: 0.7504 - binary_accuracy: 0.8755 - val_loss: 0.3143 - val_dice: 0.6857 - val_binary_accuracy: 0.8569
# Epoch 34/50
# Epoch 00033: dice improved from 0.75043 to 0.75647, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6871-0.7565---0.hdf5
# Epoch 00033: val_dice improved from 0.68574 to 0.68707, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6871-0.7565---0.hdf5
# 44s - loss: 0.2435 - dice: 0.7565 - binary_accuracy: 0.8845 - val_loss: 0.3129 - val_dice: 0.6871 - val_binary_accuracy: 0.8604
# Epoch 35/50
# Epoch 00034: dice did not improve
# Epoch 00034: val_dice did not improve
# 43s - loss: 0.2468 - dice: 0.7532 - binary_accuracy: 0.8807 - val_loss: 0.3145 - val_dice: 0.6855 - val_binary_accuracy: 0.8533
# Epoch 36/50
# Epoch 00035: dice did not improve
# Epoch 00035: val_dice improved from 0.68707 to 0.68875, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6888-0.7520---0.hdf5
# 43s - loss: 0.2480 - dice: 0.7520 - binary_accuracy: 0.8807 - val_loss: 0.3112 - val_dice: 0.6888 - val_binary_accuracy: 0.8666
# Epoch 37/50
# Epoch 00036: dice did not improve
# Epoch 00036: val_dice did not improve
# 43s - loss: 0.2518 - dice: 0.7482 - binary_accuracy: 0.8792 - val_loss: 0.3137 - val_dice: 0.6863 - val_binary_accuracy: 0.8696
# Epoch 38/50
#
# Epoch 00037: reducing learning rate to 0.00249999994412.
# Epoch 00037: dice did not improve
# Epoch 00037: val_dice did not improve
# 43s - loss: 0.2447 - dice: 0.7553 - binary_accuracy: 0.8786 - val_loss: 0.3204 - val_dice: 0.6796 - val_binary_accuracy: 0.8448
# Epoch 39/50
# Epoch 00038: dice improved from 0.75647 to 0.76505, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7023-0.7650---0.hdf5
# Epoch 00038: val_dice improved from 0.68875 to 0.70226, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7023-0.7650---0.hdf5
# 44s - loss: 0.2350 - dice: 0.7650 - binary_accuracy: 0.8880 - val_loss: 0.2977 - val_dice: 0.7023 - val_binary_accuracy: 0.8748
# Epoch 40/50
# Epoch 00039: dice improved from 0.76505 to 0.76846, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6979-0.7685---0.hdf5
# Epoch 00039: val_dice did not improve
# 44s - loss: 0.2315 - dice: 0.7685 - binary_accuracy: 0.8901 - val_loss: 0.3021 - val_dice: 0.6979 - val_binary_accuracy: 0.8671
# Epoch 41/50
# Epoch 00040: dice improved from 0.76846 to 0.77130, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7011-0.7713---0.hdf5
# Epoch 00040: val_dice did not improve
# 44s - loss: 0.2287 - dice: 0.7713 - binary_accuracy: 0.8935 - val_loss: 0.2989 - val_dice: 0.7011 - val_binary_accuracy: 0.8772
# Epoch 42/50
# Epoch 00041: dice improved from 0.77130 to 0.77191, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6981-0.7719---0.hdf5
# Epoch 00041: val_dice did not improve
# 44s - loss: 0.2281 - dice: 0.7719 - binary_accuracy: 0.8936 - val_loss: 0.3019 - val_dice: 0.6981 - val_binary_accuracy: 0.8680
# Epoch 43/50
# Epoch 00042: dice did not improve
# Epoch 00042: val_dice improved from 0.70226 to 0.70606, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7061-0.7685---0.hdf5
# 44s - loss: 0.2315 - dice: 0.7685 - binary_accuracy: 0.8897 - val_loss: 0.2939 - val_dice: 0.7061 - val_binary_accuracy: 0.8770
# Epoch 44/50
# Epoch 00043: dice improved from 0.77191 to 0.77225, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7032-0.7723---0.hdf5
# Epoch 00043: val_dice did not improve
# 44s - loss: 0.2277 - dice: 0.7723 - binary_accuracy: 0.8927 - val_loss: 0.2968 - val_dice: 0.7032 - val_binary_accuracy: 0.8749
# Epoch 45/50
# Epoch 00044: dice improved from 0.77225 to 0.77499, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7041-0.7750---0.hdf5
# Epoch 00044: val_dice did not improve
# 44s - loss: 0.2250 - dice: 0.7750 - binary_accuracy: 0.8947 - val_loss: 0.2959 - val_dice: 0.7041 - val_binary_accuracy: 0.8712
# Epoch 46/50
# Epoch 00045: dice improved from 0.77499 to 0.78059, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7014-0.7806---0.hdf5
# Epoch 00045: val_dice did not improve
# 44s - loss: 0.2194 - dice: 0.7806 - binary_accuracy: 0.8977 - val_loss: 0.2986 - val_dice: 0.7014 - val_binary_accuracy: 0.8759
# Epoch 47/50
# Epoch 00046: dice did not improve
# Epoch 00046: val_dice improved from 0.70606 to 0.71181, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7118-0.7777---0.hdf5
# 44s - loss: 0.2223 - dice: 0.7777 - binary_accuracy: 0.8964 - val_loss: 0.2882 - val_dice: 0.7118 - val_binary_accuracy: 0.8821
# Epoch 48/50
# Epoch 00047: dice did not improve
# Epoch 00047: val_dice did not improve
# 43s - loss: 0.2222 - dice: 0.7778 - binary_accuracy: 0.8971 - val_loss: 0.2883 - val_dice: 0.7117 - val_binary_accuracy: 0.8843
# Epoch 49/50
# Epoch 00048: dice improved from 0.78059 to 0.78409, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7092-0.7841---0.hdf5
# Epoch 00048: val_dice did not improve
# 44s - loss: 0.2159 - dice: 0.7841 - binary_accuracy: 0.9004 - val_loss: 0.2908 - val_dice: 0.7092 - val_binary_accuracy: 0.8735
# Epoch 50/50
# Epoch 00049: dice did not improve
# Epoch 00049: val_dice improved from 0.71181 to 0.71438, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7144-0.7828---0.hdf5
# 44s - loss: 0.2172 - dice: 0.7828 - binary_accuracy: 0.8987 - val_loss: 0.2856 - val_dice: 0.7144 - val_binary_accuracy: 0.8776
# 2017-07-30 21:32:12.221977 ------------> 1
# Train on 111 samples, validate on 57 samples
# Epoch 1/50
# Epoch 00000: dice improved from -inf to 0.36257, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.4262-0.3626---1.hdf5
# Epoch 00000: val_dice improved from -inf to 0.42616, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.4262-0.3626---1.hdf5
# 48s - loss: 0.6374 - dice: 0.3626 - binary_accuracy: 0.3128 - val_loss: 0.5738 - val_dice: 0.4262 - val_binary_accuracy: 0.3370
# Epoch 2/50
# Epoch 00001: dice improved from 0.36257 to 0.42546, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.4583-0.4255---1.hdf5
# Epoch 00001: val_dice improved from 0.42616 to 0.45834, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.4583-0.4255---1.hdf5
# 46s - loss: 0.5745 - dice: 0.4255 - binary_accuracy: 0.3111 - val_loss: 0.5417 - val_dice: 0.4583 - val_binary_accuracy: 0.3370
# Epoch 3/50
# Epoch 00002: dice improved from 0.42546 to 0.44233, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.4849-0.4423---1.hdf5
# Epoch 00002: val_dice improved from 0.45834 to 0.48490, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.4849-0.4423---1.hdf5
# 46s - loss: 0.5577 - dice: 0.4423 - binary_accuracy: 0.3111 - val_loss: 0.5151 - val_dice: 0.4849 - val_binary_accuracy: 0.3370
# Epoch 4/50
# Epoch 00003: dice improved from 0.44233 to 0.50682, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6452-0.5068---1.hdf5
# Epoch 00003: val_dice improved from 0.48490 to 0.64522, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6452-0.5068---1.hdf5
# 46s - loss: 0.4932 - dice: 0.5068 - binary_accuracy: 0.6110 - val_loss: 0.3548 - val_dice: 0.6452 - val_binary_accuracy: 0.8317
# Epoch 5/50
# Epoch 00004: dice improved from 0.50682 to 0.59643, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6291-0.5964---1.hdf5
# Epoch 00004: val_dice did not improve
# 45s - loss: 0.4036 - dice: 0.5964 - binary_accuracy: 0.7831 - val_loss: 0.3709 - val_dice: 0.6291 - val_binary_accuracy: 0.7785
# Epoch 6/50
# Epoch 00005: dice improved from 0.59643 to 0.61159, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6604-0.6116---1.hdf5
# Epoch 00005: val_dice improved from 0.64522 to 0.66038, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6604-0.6116---1.hdf5
# 45s - loss: 0.3884 - dice: 0.6116 - binary_accuracy: 0.7917 - val_loss: 0.3396 - val_dice: 0.6604 - val_binary_accuracy: 0.8269
# Epoch 7/50
# Epoch 00006: dice improved from 0.61159 to 0.61468, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6612-0.6147---1.hdf5
# Epoch 00006: val_dice improved from 0.66038 to 0.66117, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6612-0.6147---1.hdf5
# 45s - loss: 0.3853 - dice: 0.6147 - binary_accuracy: 0.7871 - val_loss: 0.3388 - val_dice: 0.6612 - val_binary_accuracy: 0.8427
# Epoch 8/50
# Epoch 00007: dice improved from 0.61468 to 0.62514, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6765-0.6251---1.hdf5
# Epoch 00007: val_dice improved from 0.66117 to 0.67649, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6765-0.6251---1.hdf5
# 44s - loss: 0.3749 - dice: 0.6251 - binary_accuracy: 0.8013 - val_loss: 0.3235 - val_dice: 0.6765 - val_binary_accuracy: 0.8519
# Epoch 9/50
# Epoch 00008: dice did not improve
# Epoch 00008: val_dice did not improve
# 43s - loss: 0.3898 - dice: 0.6102 - binary_accuracy: 0.7755 - val_loss: 0.3299 - val_dice: 0.6701 - val_binary_accuracy: 0.8507
# Epoch 10/50
# Epoch 00009: dice improved from 0.62514 to 0.63782, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6680-0.6378---1.hdf5
# Epoch 00009: val_dice did not improve
# 44s - loss: 0.3622 - dice: 0.6378 - binary_accuracy: 0.8167 - val_loss: 0.3320 - val_dice: 0.6680 - val_binary_accuracy: 0.8601
# Epoch 11/50
# Epoch 00010: dice improved from 0.63782 to 0.64808, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6693-0.6481---1.hdf5
# Epoch 00010: val_dice did not improve
# 44s - loss: 0.3519 - dice: 0.6481 - binary_accuracy: 0.8219 - val_loss: 0.3307 - val_dice: 0.6693 - val_binary_accuracy: 0.8516
# Epoch 12/50
# Epoch 00011: dice improved from 0.64808 to 0.66357, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6966-0.6636---1.hdf5
# Epoch 00011: val_dice improved from 0.67649 to 0.69657, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6966-0.6636---1.hdf5
# 44s - loss: 0.3364 - dice: 0.6636 - binary_accuracy: 0.8327 - val_loss: 0.3034 - val_dice: 0.6966 - val_binary_accuracy: 0.8550
# Epoch 13/50
# Epoch 00012: dice improved from 0.66357 to 0.66589, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7044-0.6659---1.hdf5
# Epoch 00012: val_dice improved from 0.69657 to 0.70436, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7044-0.6659---1.hdf5
# 44s - loss: 0.3341 - dice: 0.6659 - binary_accuracy: 0.8321 - val_loss: 0.2956 - val_dice: 0.7044 - val_binary_accuracy: 0.8725
# Epoch 14/50
# Epoch 00013: dice improved from 0.66589 to 0.67186, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7016-0.6719---1.hdf5
# Epoch 00013: val_dice did not improve
# 44s - loss: 0.3281 - dice: 0.6719 - binary_accuracy: 0.8365 - val_loss: 0.2984 - val_dice: 0.7016 - val_binary_accuracy: 0.8717
# Epoch 15/50
# Epoch 00014: dice improved from 0.67186 to 0.67554, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7011-0.6755---1.hdf5
# Epoch 00014: val_dice did not improve
# 44s - loss: 0.3245 - dice: 0.6755 - binary_accuracy: 0.8416 - val_loss: 0.2989 - val_dice: 0.7011 - val_binary_accuracy: 0.8631
# Epoch 16/50
# Epoch 00015: dice improved from 0.67554 to 0.67573, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6990-0.6757---1.hdf5
# Epoch 00015: val_dice did not improve
# 44s - loss: 0.3243 - dice: 0.6757 - binary_accuracy: 0.8472 - val_loss: 0.3010 - val_dice: 0.6990 - val_binary_accuracy: 0.8751
# Epoch 17/50
# Epoch 00016: dice improved from 0.67573 to 0.67716, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7162-0.6772---1.hdf5
# Epoch 00016: val_dice improved from 0.70436 to 0.71624, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7162-0.6772---1.hdf5
# 44s - loss: 0.3228 - dice: 0.6772 - binary_accuracy: 0.8449 - val_loss: 0.2838 - val_dice: 0.7162 - val_binary_accuracy: 0.8737
# Epoch 18/50
# Epoch 00017: dice improved from 0.67716 to 0.67897, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7025-0.6790---1.hdf5
# Epoch 00017: val_dice did not improve
# 44s - loss: 0.3210 - dice: 0.6790 - binary_accuracy: 0.8461 - val_loss: 0.2975 - val_dice: 0.7025 - val_binary_accuracy: 0.8642
# Epoch 19/50
# Epoch 00018: dice improved from 0.67897 to 0.67978, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6909-0.6798---1.hdf5
# Epoch 00018: val_dice did not improve
# 44s - loss: 0.3202 - dice: 0.6798 - binary_accuracy: 0.8424 - val_loss: 0.3091 - val_dice: 0.6909 - val_binary_accuracy: 0.8474
# Epoch 20/50
# Epoch 00019: dice improved from 0.67978 to 0.68266, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6792-0.6827---1.hdf5
# Epoch 00019: val_dice did not improve
# 43s - loss: 0.3173 - dice: 0.6827 - binary_accuracy: 0.8413 - val_loss: 0.3208 - val_dice: 0.6792 - val_binary_accuracy: 0.8296
# Epoch 21/50
#
# Epoch 00020: reducing learning rate to 0.00499999988824.
# Epoch 00020: dice did not improve
# Epoch 00020: val_dice did not improve
# 43s - loss: 0.3215 - dice: 0.6785 - binary_accuracy: 0.8320 - val_loss: 0.2939 - val_dice: 0.7061 - val_binary_accuracy: 0.8668
# Epoch 22/50
# Epoch 00021: dice did not improve
# Epoch 00021: val_dice did not improve
# 43s - loss: 0.3204 - dice: 0.6796 - binary_accuracy: 0.8448 - val_loss: 0.2860 - val_dice: 0.7140 - val_binary_accuracy: 0.8765
# Epoch 23/50
# Epoch 00022: dice improved from 0.68266 to 0.68873, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7191-0.6887---1.hdf5
# Epoch 00022: val_dice improved from 0.71624 to 0.71912, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7191-0.6887---1.hdf5
# 44s - loss: 0.3113 - dice: 0.6887 - binary_accuracy: 0.8457 - val_loss: 0.2809 - val_dice: 0.7191 - val_binary_accuracy: 0.8787
# Epoch 24/50
# Epoch 00023: dice improved from 0.68873 to 0.69310, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7154-0.6931---1.hdf5
# Epoch 00023: val_dice did not improve
# 43s - loss: 0.3069 - dice: 0.6931 - binary_accuracy: 0.8499 - val_loss: 0.2846 - val_dice: 0.7154 - val_binary_accuracy: 0.8784
# Epoch 25/50
# Epoch 00024: dice did not improve
# Epoch 00024: val_dice improved from 0.71912 to 0.72068, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7207-0.6907---1.hdf5
# 43s - loss: 0.3093 - dice: 0.6907 - binary_accuracy: 0.8484 - val_loss: 0.2793 - val_dice: 0.7207 - val_binary_accuracy: 0.8723
# Epoch 26/50
# Epoch 00025: dice improved from 0.69310 to 0.69415, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6989-0.6941---1.hdf5
# Epoch 00025: val_dice did not improve
# 43s - loss: 0.3059 - dice: 0.6941 - binary_accuracy: 0.8502 - val_loss: 0.3011 - val_dice: 0.6989 - val_binary_accuracy: 0.8559
# Epoch 27/50
# Epoch 00026: dice improved from 0.69415 to 0.69490, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7222-0.6949---1.hdf5
# Epoch 00026: val_dice improved from 0.72068 to 0.72224, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7222-0.6949---1.hdf5
# 44s - loss: 0.3051 - dice: 0.6949 - binary_accuracy: 0.8517 - val_loss: 0.2778 - val_dice: 0.7222 - val_binary_accuracy: 0.8774
# Epoch 28/50
# Epoch 00027: dice improved from 0.69490 to 0.70602, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7202-0.7060---1.hdf5
# Epoch 00027: val_dice did not improve
# 43s - loss: 0.2940 - dice: 0.7060 - binary_accuracy: 0.8578 - val_loss: 0.2798 - val_dice: 0.7202 - val_binary_accuracy: 0.8796
# Epoch 29/50
# Epoch 00028: dice improved from 0.70602 to 0.70671, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7077-0.7067---1.hdf5
# Epoch 00028: val_dice did not improve
# 43s - loss: 0.2933 - dice: 0.7067 - binary_accuracy: 0.8609 - val_loss: 0.2923 - val_dice: 0.7077 - val_binary_accuracy: 0.8615
# Epoch 30/50
# Epoch 00029: dice did not improve
# Epoch 00029: val_dice improved from 0.72224 to 0.72434, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7243-0.7059---1.hdf5
# 44s - loss: 0.2941 - dice: 0.7059 - binary_accuracy: 0.8606 - val_loss: 0.2757 - val_dice: 0.7243 - val_binary_accuracy: 0.8798
# Epoch 31/50
# Epoch 00030: dice improved from 0.70671 to 0.71757, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7264-0.7176---1.hdf5
# Epoch 00030: val_dice improved from 0.72434 to 0.72641, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7264-0.7176---1.hdf5
# 44s - loss: 0.2824 - dice: 0.7176 - binary_accuracy: 0.8717 - val_loss: 0.2736 - val_dice: 0.7264 - val_binary_accuracy: 0.8793
# Epoch 32/50
# Epoch 00031: dice did not improve
# Epoch 00031: val_dice improved from 0.72641 to 0.72663, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7266-0.7043---1.hdf5
# 43s - loss: 0.2957 - dice: 0.7043 - binary_accuracy: 0.8607 - val_loss: 0.2734 - val_dice: 0.7266 - val_binary_accuracy: 0.8802
# Epoch 33/50
# Epoch 00032: dice did not improve
# Epoch 00032: val_dice improved from 0.72663 to 0.73089, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7309-0.7113---1.hdf5
# 43s - loss: 0.2887 - dice: 0.7113 - binary_accuracy: 0.8659 - val_loss: 0.2691 - val_dice: 0.7309 - val_binary_accuracy: 0.8817
# Epoch 34/50
# Epoch 00033: dice did not improve
# Epoch 00033: val_dice did not improve
# 43s - loss: 0.2973 - dice: 0.7027 - binary_accuracy: 0.8578 - val_loss: 0.2831 - val_dice: 0.7169 - val_binary_accuracy: 0.8772
# Epoch 35/50
#
# Epoch 00034: reducing learning rate to 0.00249999994412.
# Epoch 00034: dice did not improve
# Epoch 00034: val_dice did not improve
# 43s - loss: 0.2835 - dice: 0.7165 - binary_accuracy: 0.8658 - val_loss: 0.2769 - val_dice: 0.7231 - val_binary_accuracy: 0.8829
# Epoch 36/50
# Epoch 00035: dice improved from 0.71757 to 0.72621, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7325-0.7262---1.hdf5
# Epoch 00035: val_dice improved from 0.73089 to 0.73252, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7325-0.7262---1.hdf5
# 44s - loss: 0.2738 - dice: 0.7262 - binary_accuracy: 0.8741 - val_loss: 0.2675 - val_dice: 0.7325 - val_binary_accuracy: 0.8825
# Epoch 37/50
# Epoch 00036: dice improved from 0.72621 to 0.72848, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7379-0.7285---1.hdf5
# Epoch 00036: val_dice improved from 0.73252 to 0.73786, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7379-0.7285---1.hdf5
# 44s - loss: 0.2715 - dice: 0.7285 - binary_accuracy: 0.8757 - val_loss: 0.2621 - val_dice: 0.7379 - val_binary_accuracy: 0.8845
# Epoch 38/50
# Epoch 00037: dice did not improve
# Epoch 00037: val_dice did not improve
# 43s - loss: 0.2767 - dice: 0.7233 - binary_accuracy: 0.8729 - val_loss: 0.2627 - val_dice: 0.7373 - val_binary_accuracy: 0.8853
# Epoch 39/50
# Epoch 00038: dice improved from 0.72848 to 0.73427, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7362-0.7343---1.hdf5
# Epoch 00038: val_dice did not improve
# 44s - loss: 0.2657 - dice: 0.7343 - binary_accuracy: 0.8806 - val_loss: 0.2638 - val_dice: 0.7362 - val_binary_accuracy: 0.8847
# Epoch 40/50
# Epoch 00039: dice did not improve
# Epoch 00039: val_dice did not improve
# 43s - loss: 0.2681 - dice: 0.7319 - binary_accuracy: 0.8775 - val_loss: 0.2638 - val_dice: 0.7362 - val_binary_accuracy: 0.8828
# Epoch 41/50
# Epoch 00040: dice improved from 0.73427 to 0.73493, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7437-0.7349---1.hdf5
# Epoch 00040: val_dice improved from 0.73786 to 0.74370, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7437-0.7349---1.hdf5
# 44s - loss: 0.2651 - dice: 0.7349 - binary_accuracy: 0.8809 - val_loss: 0.2563 - val_dice: 0.7437 - val_binary_accuracy: 0.8864
# Epoch 42/50
# Epoch 00041: dice improved from 0.73493 to 0.74120, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7187-0.7412---1.hdf5
# Epoch 00041: val_dice did not improve
# 43s - loss: 0.2588 - dice: 0.7412 - binary_accuracy: 0.8844 - val_loss: 0.2813 - val_dice: 0.7187 - val_binary_accuracy: 0.8661
# Epoch 43/50
# Epoch 00042: dice did not improve
# Epoch 00042: val_dice did not improve
# 43s - loss: 0.2637 - dice: 0.7363 - binary_accuracy: 0.8805 - val_loss: 0.2590 - val_dice: 0.7410 - val_binary_accuracy: 0.8859
# Epoch 44/50
# Epoch 00043: dice did not improve
# Epoch 00043: val_dice did not improve
# 43s - loss: 0.2628 - dice: 0.7372 - binary_accuracy: 0.8802 - val_loss: 0.2575 - val_dice: 0.7425 - val_binary_accuracy: 0.8847
# Epoch 45/50
#
# Epoch 00044: reducing learning rate to 0.00124999997206.
# Epoch 00044: dice did not improve
# Epoch 00044: val_dice did not improve
# 43s - loss: 0.2650 - dice: 0.7350 - binary_accuracy: 0.8780 - val_loss: 0.2581 - val_dice: 0.7419 - val_binary_accuracy: 0.8864
# Epoch 46/50
# Epoch 00045: dice improved from 0.74120 to 0.74380, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7440-0.7438---1.hdf5
# Epoch 00045: val_dice improved from 0.74370 to 0.74402, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7440-0.7438---1.hdf5
# 44s - loss: 0.2562 - dice: 0.7438 - binary_accuracy: 0.8826 - val_loss: 0.2560 - val_dice: 0.7440 - val_binary_accuracy: 0.8869
# Epoch 47/50
# Epoch 00046: dice improved from 0.74380 to 0.74852, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7475-0.7485---1.hdf5
# Epoch 00046: val_dice improved from 0.74402 to 0.74747, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7475-0.7485---1.hdf5
# 44s - loss: 0.2515 - dice: 0.7485 - binary_accuracy: 0.8896 - val_loss: 0.2525 - val_dice: 0.7475 - val_binary_accuracy: 0.8877
# Epoch 48/50
# Epoch 00047: dice improved from 0.74852 to 0.74955, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7410-0.7496---1.hdf5
# Epoch 00047: val_dice did not improve
# 44s - loss: 0.2504 - dice: 0.7496 - binary_accuracy: 0.8867 - val_loss: 0.2590 - val_dice: 0.7410 - val_binary_accuracy: 0.8891
# Epoch 49/50
# Epoch 00048: dice did not improve
# Epoch 00048: val_dice improved from 0.74747 to 0.74802, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7480-0.7484---1.hdf5
# 44s - loss: 0.2516 - dice: 0.7484 - binary_accuracy: 0.8923 - val_loss: 0.2520 - val_dice: 0.7480 - val_binary_accuracy: 0.8901
# Epoch 50/50
# Epoch 00049: dice did not improve
# Epoch 00049: val_dice improved from 0.74802 to 0.75059, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7506-0.7483---1.hdf5
# 44s - loss: 0.2517 - dice: 0.7483 - binary_accuracy: 0.8876 - val_loss: 0.2494 - val_dice: 0.7506 - val_binary_accuracy: 0.8908
# 2017-07-30 22:09:13.085167 ------------> 2
# Train on 114 samples, validate on 54 samples
# Epoch 1/50
# Epoch 00000: dice improved from -inf to 0.39472, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.4664-0.3947---2.hdf5
# Epoch 00000: val_dice improved from -inf to 0.46640, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.4664-0.3947---2.hdf5
# 47s - loss: 0.6053 - dice: 0.3947 - binary_accuracy: 0.3114 - val_loss: 0.5336 - val_dice: 0.4664 - val_binary_accuracy: 0.3377
# Epoch 2/50
# Epoch 00001: dice improved from 0.39472 to 0.46616, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.5878-0.4662---2.hdf5
# Epoch 00001: val_dice improved from 0.46640 to 0.58784, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.5878-0.4662---2.hdf5
# 47s - loss: 0.5338 - dice: 0.4662 - binary_accuracy: 0.4507 - val_loss: 0.4122 - val_dice: 0.5878 - val_binary_accuracy: 0.7875
# Epoch 3/50
# Epoch 00002: dice improved from 0.46616 to 0.58951, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6382-0.5895---2.hdf5
# Epoch 00002: val_dice improved from 0.58784 to 0.63817, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6382-0.5895---2.hdf5
# 46s - loss: 0.4105 - dice: 0.5895 - binary_accuracy: 0.7920 - val_loss: 0.3618 - val_dice: 0.6382 - val_binary_accuracy: 0.7707
# Epoch 4/50
# Epoch 00003: dice improved from 0.58951 to 0.61888, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.5900-0.6189---2.hdf5
# Epoch 00003: val_dice did not improve
# 45s - loss: 0.3811 - dice: 0.6189 - binary_accuracy: 0.8083 - val_loss: 0.4100 - val_dice: 0.5900 - val_binary_accuracy: 0.8280
# Epoch 5/50
# Epoch 00004: dice improved from 0.61888 to 0.62316, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6730-0.6232---2.hdf5
# Epoch 00004: val_dice improved from 0.63817 to 0.67303, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6730-0.6232---2.hdf5
# 45s - loss: 0.3768 - dice: 0.6232 - binary_accuracy: 0.8138 - val_loss: 0.3270 - val_dice: 0.6730 - val_binary_accuracy: 0.8286
# Epoch 6/50
# Epoch 00005: dice improved from 0.62316 to 0.63885, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6642-0.6389---2.hdf5
# Epoch 00005: val_dice did not improve
# 44s - loss: 0.3611 - dice: 0.6389 - binary_accuracy: 0.8236 - val_loss: 0.3358 - val_dice: 0.6642 - val_binary_accuracy: 0.7894
# Epoch 7/50
# Epoch 00006: dice did not improve
# Epoch 00006: val_dice improved from 0.67303 to 0.67780, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6778-0.6355---2.hdf5
# 44s - loss: 0.3645 - dice: 0.6355 - binary_accuracy: 0.7974 - val_loss: 0.3222 - val_dice: 0.6778 - val_binary_accuracy: 0.8110
# Epoch 8/50
# Epoch 00007: dice did not improve
# Epoch 00007: val_dice did not improve
# 44s - loss: 0.3640 - dice: 0.6360 - binary_accuracy: 0.8245 - val_loss: 0.3925 - val_dice: 0.6075 - val_binary_accuracy: 0.6997
# Epoch 9/50
# Epoch 00008: dice improved from 0.63885 to 0.63919, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6832-0.6392---2.hdf5
# Epoch 00008: val_dice improved from 0.67780 to 0.68323, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6832-0.6392---2.hdf5
# 45s - loss: 0.3608 - dice: 0.6392 - binary_accuracy: 0.8267 - val_loss: 0.3168 - val_dice: 0.6832 - val_binary_accuracy: 0.8260
# Epoch 10/50
# Epoch 00009: dice improved from 0.63919 to 0.64683, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6749-0.6468---2.hdf5
# Epoch 00009: val_dice did not improve
# 44s - loss: 0.3532 - dice: 0.6468 - binary_accuracy: 0.8359 - val_loss: 0.3251 - val_dice: 0.6749 - val_binary_accuracy: 0.8025
# Epoch 11/50
# Epoch 00010: dice improved from 0.64683 to 0.65294, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6954-0.6529---2.hdf5
# Epoch 00010: val_dice improved from 0.68323 to 0.69540, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6954-0.6529---2.hdf5
# 45s - loss: 0.3471 - dice: 0.6529 - binary_accuracy: 0.8326 - val_loss: 0.3046 - val_dice: 0.6954 - val_binary_accuracy: 0.8290
# Epoch 12/50
# Epoch 00011: dice did not improve
# Epoch 00011: val_dice did not improve
# 44s - loss: 0.3482 - dice: 0.6518 - binary_accuracy: 0.8363 - val_loss: 0.3410 - val_dice: 0.6590 - val_binary_accuracy: 0.7708
# Epoch 13/50
# Epoch 00012: dice improved from 0.65294 to 0.66027, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7011-0.6603---2.hdf5
# Epoch 00012: val_dice improved from 0.69540 to 0.70108, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7011-0.6603---2.hdf5
# 44s - loss: 0.3397 - dice: 0.6603 - binary_accuracy: 0.8420 - val_loss: 0.2989 - val_dice: 0.7011 - val_binary_accuracy: 0.8503
# Epoch 14/50
# Epoch 00013: dice improved from 0.66027 to 0.66440, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7079-0.6644---2.hdf5
# Epoch 00013: val_dice improved from 0.70108 to 0.70787, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7079-0.6644---2.hdf5
# 44s - loss: 0.3356 - dice: 0.6644 - binary_accuracy: 0.8438 - val_loss: 0.2921 - val_dice: 0.7079 - val_binary_accuracy: 0.8414
# Epoch 15/50
# Epoch 00014: dice improved from 0.66440 to 0.66874, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7016-0.6687---2.hdf5
# Epoch 00014: val_dice did not improve
# 44s - loss: 0.3313 - dice: 0.6687 - binary_accuracy: 0.8426 - val_loss: 0.2984 - val_dice: 0.7016 - val_binary_accuracy: 0.8437
# Epoch 16/50
# Epoch 00015: dice improved from 0.66874 to 0.67018, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7100-0.6702---2.hdf5
# Epoch 00015: val_dice improved from 0.70787 to 0.71004, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7100-0.6702---2.hdf5
# 44s - loss: 0.3298 - dice: 0.6702 - binary_accuracy: 0.8501 - val_loss: 0.2900 - val_dice: 0.7100 - val_binary_accuracy: 0.8442
# Epoch 17/50
# Epoch 00016: dice improved from 0.67018 to 0.67361, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7068-0.6736---2.hdf5
# Epoch 00016: val_dice did not improve
# 44s - loss: 0.3264 - dice: 0.6736 - binary_accuracy: 0.8510 - val_loss: 0.2932 - val_dice: 0.7068 - val_binary_accuracy: 0.8536
# Epoch 18/50
# Epoch 00017: dice improved from 0.67361 to 0.68188, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6943-0.6819---2.hdf5
# Epoch 00017: val_dice did not improve
# 44s - loss: 0.3181 - dice: 0.6819 - binary_accuracy: 0.8591 - val_loss: 0.3057 - val_dice: 0.6943 - val_binary_accuracy: 0.8208
# Epoch 19/50
# Epoch 00018: dice improved from 0.68188 to 0.68600, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7038-0.6860---2.hdf5
# Epoch 00018: val_dice did not improve
# 44s - loss: 0.3140 - dice: 0.6860 - binary_accuracy: 0.8536 - val_loss: 0.2962 - val_dice: 0.7038 - val_binary_accuracy: 0.8555
# Epoch 20/50
#
# Epoch 00019: reducing learning rate to 0.00499999988824.
# Epoch 00019: dice did not improve
# Epoch 00019: val_dice did not improve
# 44s - loss: 0.3211 - dice: 0.6789 - binary_accuracy: 0.8460 - val_loss: 0.2961 - val_dice: 0.7039 - val_binary_accuracy: 0.8276
# Epoch 21/50
# Epoch 00020: dice did not improve
# Epoch 00020: val_dice improved from 0.71004 to 0.71650, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7165-0.6761---2.hdf5
# 44s - loss: 0.3239 - dice: 0.6761 - binary_accuracy: 0.8493 - val_loss: 0.2835 - val_dice: 0.7165 - val_binary_accuracy: 0.8525
# Epoch 22/50
# Epoch 00021: dice improved from 0.68600 to 0.68685, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7129-0.6868---2.hdf5
# Epoch 00021: val_dice did not improve
# 44s - loss: 0.3132 - dice: 0.6868 - binary_accuracy: 0.8602 - val_loss: 0.2871 - val_dice: 0.7129 - val_binary_accuracy: 0.8468
# Epoch 23/50
# Epoch 00022: dice improved from 0.68685 to 0.68870, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7133-0.6887---2.hdf5
# Epoch 00022: val_dice did not improve
# 44s - loss: 0.3113 - dice: 0.6887 - binary_accuracy: 0.8603 - val_loss: 0.2867 - val_dice: 0.7133 - val_binary_accuracy: 0.8389
# Epoch 24/50
# Epoch 00023: dice improved from 0.68870 to 0.69291, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7136-0.6929---2.hdf5
# Epoch 00023: val_dice did not improve
# 44s - loss: 0.3071 - dice: 0.6929 - binary_accuracy: 0.8624 - val_loss: 0.2864 - val_dice: 0.7136 - val_binary_accuracy: 0.8397
# Epoch 25/50
# Epoch 00024: dice did not improve
# Epoch 00024: val_dice improved from 0.71650 to 0.71738, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7174-0.6921---2.hdf5
# 44s - loss: 0.3079 - dice: 0.6921 - binary_accuracy: 0.8646 - val_loss: 0.2826 - val_dice: 0.7174 - val_binary_accuracy: 0.8451
# Epoch 26/50
# Epoch 00025: dice improved from 0.69291 to 0.69500, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7095-0.6950---2.hdf5
# Epoch 00025: val_dice did not improve
# 44s - loss: 0.3050 - dice: 0.6950 - binary_accuracy: 0.8672 - val_loss: 0.2905 - val_dice: 0.7095 - val_binary_accuracy: 0.8576
# Epoch 27/50
# Epoch 00026: dice did not improve
# Epoch 00026: val_dice did not improve
# 44s - loss: 0.3052 - dice: 0.6948 - binary_accuracy: 0.8626 - val_loss: 0.2946 - val_dice: 0.7054 - val_binary_accuracy: 0.8581
# Epoch 28/50
# Epoch 00027: dice did not improve
# Epoch 00027: val_dice improved from 0.71738 to 0.71810, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7181-0.6897---2.hdf5
# 44s - loss: 0.3103 - dice: 0.6897 - binary_accuracy: 0.8633 - val_loss: 0.2819 - val_dice: 0.7181 - val_binary_accuracy: 0.8499
# Epoch 29/50
# Epoch 00028: dice improved from 0.69500 to 0.69637, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7165-0.6964---2.hdf5
# Epoch 00028: val_dice did not improve
# 44s - loss: 0.3036 - dice: 0.6964 - binary_accuracy: 0.8671 - val_loss: 0.2835 - val_dice: 0.7165 - val_binary_accuracy: 0.8532
# Epoch 30/50
# Epoch 00029: dice improved from 0.69637 to 0.70161, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7088-0.7016---2.hdf5
# Epoch 00029: val_dice did not improve
# 44s - loss: 0.2984 - dice: 0.7016 - binary_accuracy: 0.8651 - val_loss: 0.2912 - val_dice: 0.7088 - val_binary_accuracy: 0.8344
# Epoch 31/50
# Epoch 00030: dice did not improve
# Epoch 00030: val_dice improved from 0.71810 to 0.72815, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7282-0.6942---2.hdf5
# 44s - loss: 0.3058 - dice: 0.6942 - binary_accuracy: 0.8603 - val_loss: 0.2718 - val_dice: 0.7282 - val_binary_accuracy: 0.8564
# Epoch 32/50
# Epoch 00031: dice did not improve
# Epoch 00031: val_dice did not improve
# 44s - loss: 0.3016 - dice: 0.6984 - binary_accuracy: 0.8635 - val_loss: 0.2729 - val_dice: 0.7271 - val_binary_accuracy: 0.8547
# Epoch 33/50
# Epoch 00032: dice did not improve
# Epoch 00032: val_dice did not improve
# 44s - loss: 0.3088 - dice: 0.6912 - binary_accuracy: 0.8586 - val_loss: 0.2769 - val_dice: 0.7231 - val_binary_accuracy: 0.8573
# Epoch 34/50
#
# Epoch 00033: reducing learning rate to 0.00249999994412.
# Epoch 00033: dice did not improve
# Epoch 00033: val_dice improved from 0.72815 to 0.72988, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7299-0.6973---2.hdf5
# 44s - loss: 0.3027 - dice: 0.6973 - binary_accuracy: 0.8654 - val_loss: 0.2701 - val_dice: 0.7299 - val_binary_accuracy: 0.8542
# Epoch 35/50
# Epoch 00034: dice improved from 0.70161 to 0.70189, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7253-0.7019---2.hdf5
# Epoch 00034: val_dice did not improve
# 44s - loss: 0.2981 - dice: 0.7019 - binary_accuracy: 0.8637 - val_loss: 0.2747 - val_dice: 0.7253 - val_binary_accuracy: 0.8562
# Epoch 36/50
# Epoch 00035: dice improved from 0.70189 to 0.70299, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7312-0.7030---2.hdf5
# Epoch 00035: val_dice improved from 0.72988 to 0.73116, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7312-0.7030---2.hdf5
# 45s - loss: 0.2970 - dice: 0.7030 - binary_accuracy: 0.8661 - val_loss: 0.2688 - val_dice: 0.7312 - val_binary_accuracy: 0.8564
# Epoch 37/50
# Epoch 00036: dice improved from 0.70299 to 0.71023, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7311-0.7102---2.hdf5
# Epoch 00036: val_dice did not improve
# 44s - loss: 0.2898 - dice: 0.7102 - binary_accuracy: 0.8645 - val_loss: 0.2689 - val_dice: 0.7311 - val_binary_accuracy: 0.8622
# Epoch 38/50
# Epoch 00037: dice did not improve
# Epoch 00037: val_dice improved from 0.73116 to 0.74145, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7415-0.7085---2.hdf5
# 44s - loss: 0.2915 - dice: 0.7085 - binary_accuracy: 0.8676 - val_loss: 0.2585 - val_dice: 0.7415 - val_binary_accuracy: 0.8620
# Epoch 39/50
# Epoch 00038: dice improved from 0.71023 to 0.71678, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.6646-0.7168---2.hdf5
# Epoch 00038: val_dice did not improve
# 44s - loss: 0.2832 - dice: 0.7168 - binary_accuracy: 0.8708 - val_loss: 0.3354 - val_dice: 0.6646 - val_binary_accuracy: 0.7745
# Epoch 40/50
# Epoch 00039: dice did not improve
# Epoch 00039: val_dice did not improve
# 44s - loss: 0.2988 - dice: 0.7012 - binary_accuracy: 0.8620 - val_loss: 0.2782 - val_dice: 0.7218 - val_binary_accuracy: 0.8440
# Epoch 41/50
# Epoch 00040: dice did not improve
# Epoch 00040: val_dice improved from 0.74145 to 0.74442, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7444-0.7109---2.hdf5
# 44s - loss: 0.2891 - dice: 0.7109 - binary_accuracy: 0.8684 - val_loss: 0.2556 - val_dice: 0.7444 - val_binary_accuracy: 0.8616
# Epoch 42/50
# Epoch 00041: dice improved from 0.71678 to 0.71917, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7525-0.7192---2.hdf5
# Epoch 00041: val_dice improved from 0.74442 to 0.75250, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7525-0.7192---2.hdf5
# 45s - loss: 0.2808 - dice: 0.7192 - binary_accuracy: 0.8757 - val_loss: 0.2475 - val_dice: 0.7525 - val_binary_accuracy: 0.8691
# Epoch 43/50
# Epoch 00042: dice did not improve
# Epoch 00042: val_dice did not improve
# 44s - loss: 0.2863 - dice: 0.7137 - binary_accuracy: 0.8675 - val_loss: 0.2618 - val_dice: 0.7382 - val_binary_accuracy: 0.8634
# Epoch 44/50
# Epoch 00043: dice did not improve
# Epoch 00043: val_dice did not improve
# 44s - loss: 0.2816 - dice: 0.7184 - binary_accuracy: 0.8739 - val_loss: 0.2557 - val_dice: 0.7443 - val_binary_accuracy: 0.8628
# Epoch 45/50
# Epoch 00044: dice did not improve
# Epoch 00044: val_dice did not improve
# 44s - loss: 0.2828 - dice: 0.7172 - binary_accuracy: 0.8721 - val_loss: 0.2678 - val_dice: 0.7322 - val_binary_accuracy: 0.8455
# Epoch 46/50
#
# Epoch 00045: reducing learning rate to 0.00124999997206.
# Epoch 00045: dice improved from 0.71917 to 0.72223, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7277-0.7222---2.hdf5
# Epoch 00045: val_dice did not improve
# 44s - loss: 0.2778 - dice: 0.7222 - binary_accuracy: 0.8742 - val_loss: 0.2723 - val_dice: 0.7277 - val_binary_accuracy: 0.8411
# Epoch 47/50
# Epoch 00046: dice improved from 0.72223 to 0.72872, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7549-0.7287---2.hdf5
# Epoch 00046: val_dice improved from 0.75250 to 0.75489, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7549-0.7287---2.hdf5
# 45s - loss: 0.2713 - dice: 0.7287 - binary_accuracy: 0.8758 - val_loss: 0.2451 - val_dice: 0.7549 - val_binary_accuracy: 0.8700
# Epoch 48/50
# Epoch 00047: dice did not improve
# Epoch 00047: val_dice improved from 0.75489 to 0.75609, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7561-0.7261---2.hdf5
# 44s - loss: 0.2739 - dice: 0.7261 - binary_accuracy: 0.8815 - val_loss: 0.2439 - val_dice: 0.7561 - val_binary_accuracy: 0.8727
# Epoch 49/50
# Epoch 00048: dice improved from 0.72872 to 0.72971, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7366-0.7297---2.hdf5
# Epoch 00048: val_dice did not improve
# 44s - loss: 0.2703 - dice: 0.7297 - binary_accuracy: 0.8801 - val_loss: 0.2634 - val_dice: 0.7366 - val_binary_accuracy: 0.8519
# Epoch 50/50
# Epoch 00049: dice improved from 0.72971 to 0.73434, saving model to ../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7542-0.7343---2.hdf5
# Epoch 00049: val_dice did not improve
# 44s - loss: 0.2657 - dice: 0.7343 - binary_accuracy: 0.8828 - val_loss: 0.2458 - val_dice: 0.7542 - val_binary_accuracy: 0.8707
# 2017-07-30 22:46:34.196351

# %%
#!ls ../Temp/TempTempG5M5KFold -la | tail
#!ls ../Temp/TempTempG5M5KFold10 -la | tail
# !ls ../Temp/NewStep/StandartF3 -la | tail
# !ls ../Temp/NewStep/Level-1 -la | tail
# Out:
# -rwxrwxrwx 1 boba boba 248917120 июл 30 19:42 V1-UNET-val_dice=0.7426-0.7271---1.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 20:33 V1-UNET-val_dice=0.7449-0.7080---2.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 20:37 V1-UNET-val_dice=0.7482-0.7316---2.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 19:48 V1-UNET-val_dice=0.7500-0.7460---1.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 20:38 V1-UNET-val_dice=0.7502-0.7177---2.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 19:50 V1-UNET-val_dice=0.7510-0.7538---1.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 19:52 V1-UNET-val_dice=0.7516-0.7578---1.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 19:53 V1-UNET-val_dice=0.7528-0.7595---1.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 20:39 V1-UNET-val_dice=0.7613-0.7235---2.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 20:42 V1-UNET-val_dice=0.7655-0.7360---2.hdf5
# -rwxrwxrwx 1 boba boba 62214256 июл 30 22:02 V1-UNET-val_dice=0.7437-0.7349---1.hdf5
# -rwxrwxrwx 1 boba boba 62214256 июл 30 22:06 V1-UNET-val_dice=0.7440-0.7438---1.hdf5
# -rwxrwxrwx 1 boba boba 62214256 июл 30 22:39 V1-UNET-val_dice=0.7444-0.7109---2.hdf5
# -rwxrwxrwx 1 boba boba 62214256 июл 30 22:07 V1-UNET-val_dice=0.7475-0.7485---1.hdf5
# -rwxrwxrwx 1 boba boba 62214256 июл 30 22:08 V1-UNET-val_dice=0.7480-0.7484---1.hdf5
# -rwxrwxrwx 1 boba boba 62214256 июл 30 22:09 V1-UNET-val_dice=0.7506-0.7483---1.hdf5
# -rwxrwxrwx 1 boba boba 62214256 июл 30 22:40 V1-UNET-val_dice=0.7525-0.7192---2.hdf5
# -rwxrwxrwx 1 boba boba 62214256 июл 30 22:46 V1-UNET-val_dice=0.7542-0.7343---2.hdf5
# -rwxrwxrwx 1 boba boba 62214256 июл 30 22:44 V1-UNET-val_dice=0.7549-0.7287---2.hdf5
# -rwxrwxrwx 1 boba boba 62214256 июл 30 22:45 V1-UNET-val_dice=0.7561-0.7261---2.hdf5

# %%
if 0 : model10 = load_model('../Temp/TrainModel001+G+M/V1-UNET-0.8511.hdf5')
if 0 : model10 = load_model('../Temp/V1-UNET-0.8853.hdf5')
#if 1 : model10 = load_model('../Temp/TempTempM3/V1-UNET-0.9054.hdf5')
if 0 : model10.load_weights('../Temp/TempTempM3/V1-UNET-0.9054.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5/V1-UNET-val_dice=0.7307.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7879-2.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7632-2.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7660-2.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7828-2.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFold5/V1-UNET-val_dice=0.8224-0.8516---1.hdf5') # 769128
if 0 : model10.load_weights('../Temp/TempTempG5M5KFold5/V1-UNET-val_dice=0.8217-0.8655---1.hdf5') # 765XXX
if 0 : model10.load_weights('../Temp/TempTempG5M5KFold5/V1-UNET-val_dice=0.8227-0.8643---3.hdf5')    
if 0 : model10.load_weights('../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8315-0.8617---9.hdf5')    
if 0 : model10.load_weights('../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7655-0.7360---2.hdf5')    
if 1 : model10.load_weights('../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7561-0.7261---2.hdf5')

# %%
# %time trP = model10.predict(trX,batch_size=batch_size)
# Out:
# CPU times: user 12.1 s, sys: 2.43 s, total: 14.5 s
# Wall time: 13.9 s

# %%
trP01 = trP
trP01[trP>0.5] =1.0
trP01[trP<=0.5]=0.0
trP01 = trP01.astype(np.uint8)

# %%
if 0 : # Ощутимых результатов не дает, увеличение в +10-100
    times, medianP = 3,5
    for i in range(trP01.shape[0]) :
        for j in range(times) :
            trP01[i,:,:,0] = cv.medianBlur(trP01[i],medianP)

# %%
iii = 0
print(trX[0].shape,trY[0].shape,trP.shape,trP.min(),trP.max())
for ii in range(iii,iii+10) :
    plt.figure(figsize=(15,5))
    plt.subplot(151); plt.imshow(trX[ii,:,:,0],'gray'); 
    plt.subplot(152); plt.imshow(trY[ii,:,:,0],'gray'); 
    plt.subplot(153); plt.imshow(trP[ii,:,:,0],'gray'); 
    plt.subplot(154); plt.imshow(trP01[ii,:,:,0],'gray'); 
    plt.subplot(155); plt.hist(trP[ii,:,:,0].ravel(),bins=50); 
    plt.show()
plt.close()
# Out:
# (512, 512, 3) (512, 512, 1) (168, 512, 512, 1) 0.0 1.0

# %%
# Calculate F1-micro

# %%
TP = (trY[:,6:506,6:506,0]*trP01[:,6:506,6:506,0]).sum()
TN = ((1.0-trY[:,6:506,6:506,0])*(1.0-trP01[:,6:506,6:506,0])).sum()
FP = ((trY[:,6:506,6:506,0])*(1.0-trP01[:,6:506,6:506,0])).sum()
FN = ((1.0-trY[:,6:506,6:506,0])*(trP01[:,6:506,6:506,0])).sum()

P  = TP/(TP+FP) if (TP+FP)>0.0 else 1.0
R  = TP/(TP+FN) if (TP+FN)>0.0 else 0.0

F1 = 2.0*P*R/(P+R) if (P+R)>0.0 else 0.0

TP,TN,FP,FN,P,R,F1
#P*R,P+R, 2.0*P*R/(P+R)
# Out:
# (11949670.0,
#  24679171.0,
#  2138550.0,
#  3232609.0,
#  0.8482029667339096,
#  0.78708012150218032,
#  0.8164992335798581)

# %%
# Calculate DI- dice.mean()

# %%
dice, XX = [],[]
for i in range(trP.shape[0]) :
    G = trY  [i,6:506,6:506,0].sum()
    S = trP01[i,6:506,6:506,0].sum()
    X = (trY [i,6:506,6:506,0]*trP01[i,6:506,6:506,0]).sum()
    XX.append(X)
    dice.append((2.0*X/(G+S) if G+S>0 else 1.0))
di = (np.array(dice)).mean()
di #,np.array(dice)  #,np.array(XX)
# Out:
# 0.75381278352842462

# %%
plt.hist(np.array(dice),bins=40); plt.show()
plt.plot(np.array(dice)); plt.show()

# %%
1000000*(F1+di)/2.0
# Out:
# 785156.00855414139

# %%
#np.array(dice)<0.4

# %%
# Подготовка test решения

# %%
if flagGray :
    trO, trO0 = [], np.zeros((512,512,1))
else :
    trO, trO0 = [], np.zeros((512,512,3))

for xx in listTest :
    img = cv.imread(os.path.join(dirTest,xx),-1)
    if 1 and (Gauss or Median): 
        for cc in range(img.shape[2]) : 
            if Gauss  : img[:,:,cc] = cv.GaussianBlur(img[:,:,cc],(Gauss,Gauss),0);
            if Median : img[:,:,cc] = cv.medianBlur  (img[:,:,cc],Median);
    #print(img.mean(),msk.mean())
    if flagGray :
        img = cv.cvtColor(img,cv.COLOR_RGB2GRAY);
        trO0[6:506,6:506,0] = img[:,:]/255.0
    else :
        trO0[6:506,6:506,:] = img[:,:,:]/255.0
    trO.append(trO0.copy())
    #print(trX0.mean(),trY0.mean(),trX1[-1].mean(),trY1[-1].mean())

#print([trY[xx].mean() for xx in range(10)])
trO = np.array(trO)

if 1 :
    for cc in range(meanX.shape[0]) : 
        trO[:,6:506,6:506,cc] -= meanX[cc]
    
trO.shape, trO.min(), trO.max()
#[trY[xx].mean() for xx in range(10)]
# Out:
# ((162, 512, 512, 3), -0.64172901643310909, 0.47912580261435694)

# %%
# %time trOP = model10.predict(trO,batch_size=batch_size)
# Out:
# CPU times: user 14.9 s, sys: 3.18 s, total: 18.1 s
# Wall time: 17.4 s

# %%
trOP01 = trOP
trOP01[trOP>0.5] =1.0
trOP01[trOP<=0.5]=0.0

# %%
iii = 40
print(trO[0].shape,trP01[0].shape,trOP01.shape,trOP.min(),trOP.max())
for ii in range(iii,iii+10) :
    plt.figure(figsize=(15,5))
    plt.subplot(151); plt.imshow(trO[ii,:,:,0]); 
    plt.subplot(152); plt.imshow(trOP01[ii,:,:,0],'gray'); 
    plt.subplot(153); plt.imshow(trOP[ii,:,:,0],'gray'); 
    plt.subplot(154); plt.hist(trOP[ii,:,:,0].ravel(),bins=50); 
    plt.show()
plt.close()
# Out:
# (512, 512, 3) (512, 512, 1) (162, 512, 512, 1) 0.0 1.0

# %%
# Формирование выходной директории

# %%
def convert_to_binary(truth_png_file, truth_txt_file):
    im = Image.open(truth_png_file) #Can be many different formats.
    pix = im.load()
    with open(truth_txt_file, 'w') as out:
        for x in xrange(500):
            for y in xrange(500):
                out.write(str(int(pix[x, y] > 0)))
            out.write('\n')

if not os.path.exists('../Temp/random_submission'):
    os.makedirs('../Temp/random_submission')

# Training
for i in range(len(listTrain)) :
    fn = listTrain[i]
    truth_txt_file = '../Temp/random_submission/' + fn.split('.')[0] + '_mask.txt'
    with open(truth_txt_file, 'w') as out:
        for x in xrange(500):
            for y in xrange(500):
                out.write(str(int(trP01[i,y+6, x+6] > 0.0)))
            out.write('\n')
    out.close()
    
# Testing
for i in range(len(listTest)) :
    fn = listTest[i]
    truth_txt_file = '../Temp/random_submission/' + fn.split('.')[0] + '_mask.txt'
    with open(truth_txt_file, 'w') as out:
        for x in xrange(500):
            for y in xrange(500):
                out.write(str(int(trOP01[i,y+6, x+6] > 0.0)))
            out.write('\n')
    out.close()

# %%
import shutil

# %%
xx=shutil.make_archive('../Result/topcoderkonica','zip','../Temp/random_submission')
xx
# Out:
# '/media/boba/DATA/boba/Working/TopCoder/2017-07-25-Konica-Minolta/Result/topcoderkonica.zip'

# %%
# !ls ../Temp -la
# Out:
# total 4610508
# drwxrwxrwx 1 boba boba      4096 июл 26 10:58 .
# drwxrwxrwx 1 boba boba      4096 июл 26 10:11 ..
# drwxrwxrwx 1 boba boba         0 июл 25 18:17 .ipynb_checkpoints
# drwxrwxrwx 1 boba boba     61440 июл 26 09:14 random_submission
# -rwxrwxrwx 1 boba boba   1057596 июл 26 10:58 random_submission.zip
# drwxrwxrwx 1 boba boba         0 июл 25 23:35 TrainModel001-G-M
# drwxrwxrwx 1 boba boba         0 июл 25 22:21 TrainModel001-G+M
# drwxrwxrwx 1 boba boba         0 июл 25 21:48 TrainModel001+G-M
# drwxrwxrwx 1 boba boba      4096 июл 25 21:05 TrainModel001+G+M
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:02 V1-UNET-0.8167.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:08 V1-UNET-0.8275.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 18:33 V1-UNET-0.8305.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 18:02 V1-UNET-0.8418.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:09 V1-UNET-0.8486.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:09 V1-UNET-0.8593.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 18:34 V1-UNET-0.8601.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:21 V1-UNET-0.8602.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:22 V1-UNET-0.8605.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:35 V1-UNET-0.8628.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:35 V1-UNET-0.8633.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:23 V1-UNET-0.8635.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:36 V1-UNET-0.8645.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:36 V1-UNET-0.8652.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:24 V1-UNET-0.8655.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:11 V1-UNET-0.8793.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:13 V1-UNET-0.8796.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:14 V1-UNET-0.8808.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 18:02 V1-UNET-0.8853.hdf5

# %%
# !ls ../Work -la
#!ls ../Temp/random_submission
# Out:
# total 80768
# drwxrwxrwx 1 boba boba        0 июл 26 09:17 .
# drwxrwxrwx 1 boba boba     4096 июл 25 15:24 ..
# -rwxrwxrwx 1 boba boba 82700662 июл 26 09:32 topcoderkonica.zip

# %%
if False :
    save_model(model10,'../Data-Keras/Models/model-UNet.h5')
    model10.save_weights('../Data-Keras/Models/model-UNet-weights.h5')

# %%
rrr=pd.DataFrame(res,columns=['image_name','tags']); rrr.head(); 
suffixDT = (datetime.datetime.now()).strftime('%Y-%m-%d-%H-%M-%S'); print(suffixDT)
rrr.to_csv('../Result/vss'+suffixDT+'.csv',index=False);
# Out:
# 2017-05-20-05-51-18
