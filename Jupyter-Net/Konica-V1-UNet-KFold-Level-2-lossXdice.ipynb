# %%
##
## UNet 
##
## Взята идея по описанию из https://github.com/pietz/unet-keras
##
##
## 2017-07-28
##   Добавлены flip+rotation LB=760393
##
## 2017-07-29
##   LB=769123 +-3000
##
##

# %%
import sys,os,datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import fbeta_score
import sklearn.metrics as skm
from __future__ import print_function

# %%
print(np.__version__);
print(pd.__version__);
# Out:
# 1.13.1
# 0.19.2

# %%
import  cv2 as cv
cv.__version__
# Out:
# '3.2.0'

# %%
#from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.models import Sequential, save_model, load_model, Input, Model
from keras.layers import Convolution2D, MaxPooling2D, Convolution1D, MaxPooling1D, UpSampling2D, ZeroPadding2D
from keras.layers import Conv2D, Concatenate, Reshape
from keras.layers import Activation, Dropout, Flatten, Dense, Permute
from keras.layers.normalization import BatchNormalization
import keras.optimizers
from keras.callbacks import EarlyStopping,ReduceLROnPlateau,ModelCheckpoint
import keras.backend as K
# Out:
# Using TensorFlow backend.

# %%
keras.__version__
# Out:
# '2.0.6'

# %%
#---------------------------------------------------------------------

# %%
# !ls -la ..
#!ls -la ../Data
#!ls -la ../Data/training
# Out:
# total 25
# drwxrwxrwx 1 boba boba 4096 июл 26 11:10 .
# drwxrwxrwx 1 boba boba    0 июл 25 09:21 ..
# drwxrwxrwx 1 boba boba 4096 июл 25 09:23 Data
# drwxrwxrwx 1 boba boba    0 июл 25 09:22 Data-Arch
# drwxrwxrwx 1 boba boba    0 июл 25 09:26 Data-Keras
# drwxrwxrwx 1 boba boba 4096 июл 30 23:54 .git
# -rwxrwxrwx 2 boba boba  130 июл  9 12:02 .gitignore
# drwxrwxrwx 1 boba boba    0 июл 26 10:11 .ipynb_checkpoints
# drwxrwxrwx 1 boba boba    0 июл 30 23:31 Jupyter
# drwxrwxrwx 1 boba boba 4096 июл 30 23:54 Jupyter-Net
# drwxrwxrwx 1 boba boba 4096 июл 30 17:32 Result
# drwxrwxrwx 1 boba boba 4096 июл 30 17:41 Temp
# drwxrwxrwx 1 boba boba    0 июл 27 07:53 Work

# %%
dirData = '../Data'
dirTemp = '../Temp'
dirWork = '../Work'

dirTest  = os.path.join(dirData,'testing','images')
dirTrain = os.path.join(dirData,'training','images')
dirMask  = os.path.join(dirData,'training','truth')

# %%
listTrain = os.listdir(dirTrain)
listMask  = os.listdir(dirMask)
listTest  = os.listdir(dirTest)
listTrain = [xx for xx in listTrain if os.path.splitext(xx)[1]=='.tif']
listMask  = [xx for xx in listMask  if os.path.splitext(xx)[1]=='.png']
listTest  = [xx for xx in listTest  if os.path.splitext(xx)[1]=='.tif']
print(len(listTrain),len(listMask),len(listTest))
print(listTrain[:5],'\n',listMask[:5],'\n',listTest[:5])
# Out:
# 168 168 162
# ['i105404.tif', 'i117557.tif', 'i124017.tif', 'i130790.tif', 'i137857.tif']
#  ['i105404_mask.png', 'i117557_mask.png', 'i124017_mask.png', 'i130790_mask.png', 'i137857_mask.png']
#  ['i105047.tif', 'i116596.tif', 'i137649.tif', 'i140176.tif', 'i142099.tif']

# %%
if 0 :
    for xx in listTrain[:5] :
        img = cv.imread(os.path.join(dirTrain,xx),-1)
        xxm = os.path.splitext(xx)[0]+"_mask.png"
        msk = cv.imread(os.path.join(dirMask,xxm),-1)
        plt.subplot(121); plt.imshow(img); plt.subplot(122); plt.imshow(msk,'gray'); plt.show()
    plt.close()

# %%
msk.shape, img.shape, img.min(), img.max(), msk.max(), #img[6:10,6:10], msk[6:10,6:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-051c9d5448bc> in <module>()
# ----> 1 msk.shape, img.shape, img.min(), img.max(), msk.max(), #img[6:10,6:10], msk[6:10,6:10]
#
# NameError: name 'msk' is not defined

# %%
flagGray = False
Gauss    = 5
Median   = 5
if flagGray :
    trX, trY, trX0, trY0 = [], [], np.zeros((512,512,1)), np.zeros((512,512,1))
else :
    trX, trY, trX0, trY0 = [], [], np.zeros((512,512,3)), np.zeros((512,512,1))

for xx in listTrain :
    img = cv.imread(os.path.join(dirTrain,xx),-1)
    if 1 and (Gauss or Median): 
        for cc in range(img.shape[2]) : 
            if Gauss  : img[:,:,cc] = cv.GaussianBlur(img[:,:,cc],(Gauss,Gauss),0);
            if Median : img[:,:,cc] = cv.medianBlur  (img[:,:,cc],Median);
    xxm = os.path.splitext(xx)[0]+"_mask.png"
    msk = cv.imread(os.path.join(dirMask,xxm),-1)
    #print(img.mean(),msk.mean())
    if flagGray :
        img = cv.cvtColor(img,cv.COLOR_RGB2GRAY);
        trX0[6:506,6:506,0] = img[:,:]/255.0
        trY0[6:506,6:506,0] = msk[:,:]/255.0
    else :
        trX0[6:506,6:506,:] = img[:,:,:]/255.0
        trY0[6:506,6:506,0] = msk[:,:]/255.0
        trY0[trY0>=0.5] = 1.0
    trX.append(trX0.copy())
    trY.append(trY0.copy())
    #print(trX0.mean(),trY0.mean(),trX1[-1].mean(),trY1[-1].mean())

#print([trY[xx].mean() for xx in range(10)])
trX = np.array(trX)
trY = np.array(trY)

# аугментация
trXX, trYY, trXXX,trYYY = trX.copy(), trY.copy(), np.zeros((1)), np.zeros((1))


if 0 :
    # flipping
    for f in range(-1,2) :
        trXXX, trYYY = trX.copy(), trY.copy()
        for p in range(trXXX.shape[0]) :
            trXXX[p], trYYY[p,:,:,0] = cv.flip(trXXX[p],f), cv.flip(trYYY[p,:,:,0],f)
        trXX = np.vstack([trXX,trXXX])
        trYY = np.vstack([trYY,trYYY])
        print('flip :',f,trXX.shape,trYY.shape)

if 0 :
    # rotate +-90

    # rotate +90
    trXXX, trYYY = trX.copy(), trY.copy()
    for p in range(trX.shape[0]) :
        for i in range(trX.shape[1]) :
            for j in range(trX.shape[2]) :
                trXXX[p,i,j,:] = trX[p,j,trX.shape[1]-i-1]
                trYYY[p,i,j,:] = trY[p,j,trY.shape[1]-i-1]
    trXX = np.vstack([trXX,trXXX])
    trYY = np.vstack([trYY,trYYY])
    print('rotate +90:',trXX.shape,trYY.shape)

    # rotate -90
    trXXX, trYYY = trX.copy(), trY.copy()
    for p in range(trX.shape[0]) :
        for i in range(trX.shape[1]) :
            for j in range(trX.shape[2]) :
                trXXX[p,i,j,:] = trX[p,trX.shape[2]-j-1,i]
                trYYY[p,i,j,:] = trY[p,trY.shape[2]-j-1,i]
    trXX = np.vstack([trXX,trXXX])
    trYY = np.vstack([trYY,trYYY])
    print('rotate -90:',trXX.shape,trYY.shape)
    
trX, trY = trXX.copy(), trYY.copy()
del trXX,trYY
del trXXX,trYYY

# Считаем среднее по каналам и вычитаем из изображений
meanX = (trX[:,6:-6,6:-6,:].mean(axis=(1,2))).mean(axis=0)
stdX  = (trX[:,6:-6,6:-6,:].mean(axis=(1,2))).std(axis=0)
for cc in range(meanX.shape[0]) : 
    trX[:,6:-6,6:-6,cc] -= meanX[cc]    
print("mean={} std={}".format(meanX,stdX))
    
trX.shape, trX.min(), trX.max(), trY.shape, trY.min(), trY.max()
#[trY[xx].mean() for xx in range(10)]
# Out:
# mean=[ 0.6473997   0.48950165  0.70839568] std=[ 0.06249822  0.09179847  0.08778627]
# ((168, 512, 512, 3),
#  -0.62212117329583094,
#  0.48696893986925349,
#  (168, 512, 512, 1),
#  0.0,
#  1.0)

# %%
for xx in range(5) :
    img = trX[xx]
    xxm = trY[xx]
    plt.subplot(121); plt.imshow(img); plt.subplot(122); plt.imshow(xxm[:,:,0],'gray'); plt.show()
plt.close()

# %%
#
# model UNET
#
#    https://github.com/pietz/unet-keras
#
#

def level_block(m, dim, depth, acti, dropout=0.25, batch=True):
    if depth > 0:
        
        x = m
        if batch : x = BatchNormalization()(x)
        n = Conv2D(dim, (3, 3), activation=acti, padding='same')(x) #(m)
        n = Conv2D(dim, (3, 3), activation=acti, padding='same')(n)
        if dropout : n = Dropout(dropout)(n) ## add
        m = MaxPooling2D((2, 2))(n)
        m = level_block(m, 2*dim, depth-1, acti, dropout=dropout, batch=batch)
        m = UpSampling2D((2, 2))(m)
        m = Conv2D(dim, (2, 2), activation=acti, padding='same', kernel_initializer='he_normal')(m)
        if dropout : m = Dropout(dropout)(m) ## add
        m = Concatenate(axis=3)([n, m])
    m = Conv2D(dim, (3, 3), activation=acti, padding='same')(m)
    return Conv2D(dim, (3, 3), activation=acti, padding='same')(m)

def UNet(img_shape, n_out=2, dim=32, depth=5, acti='relu', flatten=False, dropout=0.25, batch=True):
    i = Input(shape=img_shape)
    ## ???? i = ZeroPadding2D((6,6),data_format="channels_last")
    o = level_block(i, dim, depth, acti, dropout=dropout, batch=batch)
    o = Conv2D(n_out, (1, 1), name='prediction')(o)
    if flatten:
        o = Reshape(n_out, img_shape[0] * img_shape[1])(o)
        o = Permute((2, 1))(o)
    #o = Activation('relu')(o)
    if batch : o = BatchNormalization()(o)  ######
    o = Activation('sigmoid')(o)
    return Model(inputs=i, outputs=o)

# %%
model10 = UNet((512,512,3),depth=4,n_out=1, dropout=0.05)
model10.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 512, 512, 3)   0
# ____________________________________________________________________________________________________
# batch_normalization_1 (BatchNorm (None, 512, 512, 3)   12          input_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_1 (Conv2D)                (None, 512, 512, 32)  896         batch_normalization_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_2 (Conv2D)                (None, 512, 512, 32)  9248        conv2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 512, 512, 32)  0           conv2d_2[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)   (None, 256, 256, 32)  0           dropout_1[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_2 (BatchNorm (None, 256, 256, 32)  128         max_pooling2d_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_3 (Conv2D)                (None, 256, 256, 64)  18496       batch_normalization_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_4 (Conv2D)                (None, 256, 256, 64)  36928       conv2d_3[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)              (None, 256, 256, 64)  0           conv2d_4[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)   (None, 128, 128, 64)  0           dropout_2[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_3 (BatchNorm (None, 128, 128, 64)  256         max_pooling2d_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_5 (Conv2D)                (None, 128, 128, 128) 73856       batch_normalization_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_6 (Conv2D)                (None, 128, 128, 128) 147584      conv2d_5[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)              (None, 128, 128, 128) 0           conv2d_6[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)   (None, 64, 64, 128)   0           dropout_3[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_4 (BatchNorm (None, 64, 64, 128)   512         max_pooling2d_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_7 (Conv2D)                (None, 64, 64, 256)   295168      batch_normalization_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_8 (Conv2D)                (None, 64, 64, 256)   590080      conv2d_7[0][0]
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)              (None, 64, 64, 256)   0           conv2d_8[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)   (None, 32, 32, 256)   0           dropout_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_9 (Conv2D)                (None, 32, 32, 512)   1180160     max_pooling2d_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_10 (Conv2D)               (None, 32, 32, 512)   2359808     conv2d_9[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)   (None, 64, 64, 512)   0           conv2d_10[0][0]
# ____________________________________________________________________________________________________
# conv2d_11 (Conv2D)               (None, 64, 64, 256)   524544      up_sampling2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_5 (Dropout)              (None, 64, 64, 256)   0           conv2d_11[0][0]
# ____________________________________________________________________________________________________
# concatenate_1 (Concatenate)      (None, 64, 64, 512)   0           dropout_4[0][0]
#                                                                    dropout_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_12 (Conv2D)               (None, 64, 64, 256)   1179904     concatenate_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_13 (Conv2D)               (None, 64, 64, 256)   590080      conv2d_12[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)   (None, 128, 128, 256) 0           conv2d_13[0][0]
# ____________________________________________________________________________________________________
# conv2d_14 (Conv2D)               (None, 128, 128, 128) 131200      up_sampling2d_2[0][0]
# ____________________________________________________________________________________________________
# dropout_6 (Dropout)              (None, 128, 128, 128) 0           conv2d_14[0][0]
# ____________________________________________________________________________________________________
# concatenate_2 (Concatenate)      (None, 128, 128, 256) 0           dropout_3[0][0]
#                                                                    dropout_6[0][0]
# ____________________________________________________________________________________________________
# conv2d_15 (Conv2D)               (None, 128, 128, 128) 295040      concatenate_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_16 (Conv2D)               (None, 128, 128, 128) 147584      conv2d_15[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)   (None, 256, 256, 128) 0           conv2d_16[0][0]
# ____________________________________________________________________________________________________
# conv2d_17 (Conv2D)               (None, 256, 256, 64)  32832       up_sampling2d_3[0][0]
# ____________________________________________________________________________________________________
# dropout_7 (Dropout)              (None, 256, 256, 64)  0           conv2d_17[0][0]
# ____________________________________________________________________________________________________
# concatenate_3 (Concatenate)      (None, 256, 256, 128) 0           dropout_2[0][0]
#                                                                    dropout_7[0][0]
# ____________________________________________________________________________________________________
# conv2d_18 (Conv2D)               (None, 256, 256, 64)  73792       concatenate_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_19 (Conv2D)               (None, 256, 256, 64)  36928       conv2d_18[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)   (None, 512, 512, 64)  0           conv2d_19[0][0]
# ____________________________________________________________________________________________________
# conv2d_20 (Conv2D)               (None, 512, 512, 32)  8224        up_sampling2d_4[0][0]
# ____________________________________________________________________________________________________
# dropout_8 (Dropout)              (None, 512, 512, 32)  0           conv2d_20[0][0]
# ____________________________________________________________________________________________________
# concatenate_4 (Concatenate)      (None, 512, 512, 64)  0           dropout_1[0][0]
#                                                                    dropout_8[0][0]
# ____________________________________________________________________________________________________
# conv2d_21 (Conv2D)               (None, 512, 512, 32)  18464       concatenate_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_22 (Conv2D)               (None, 512, 512, 32)  9248        conv2d_21[0][0]
# ____________________________________________________________________________________________________
# prediction (Conv2D)              (None, 512, 512, 1)   33          conv2d_22[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_5 (BatchNorm (None, 512, 512, 1)   4           prediction[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 512, 512, 1)   0           batch_normalization_5[0][0]
# ====================================================================================================
# Total params: 7,761,009
# Trainable params: 7,760,553
# Non-trainable params: 456
# ____________________________________________________________________________________________________

# %%
def dice (truth,pred) :
    g, s = K.sum(truth), K.sum(pred)
    x    = K.sum((truth*pred))
    return((1.0 if K.sum(g+s)==0.0 else 2.0*x/(g+s+K.epsilon())))

def f1 (truth,pred) :
    TP = K.sum(truth*pred)
    TN = K.sum((1.0-truth)*(1.0-pred))
    FP = K.sum(truth*(1.0-pred))
    FN = K.sum((1.0-truth)*pred)

    
    P  = 1.0 if K.sum(TP+FP)==0.0 else TP/(TP+FP)
    R  = 0.0 if K.sum(TP+FN)==0.0 else TP/(TP+FN) 

    F1 = 0.0 if K.sum(P+R)  ==0.0 else 2.0*P*R/(P+R)

    return(F1)

def f1dice (truth,pred) :
    return ((dice(truth,pred)+f1(truth,pred))/2.0)
    
def lossdice (truth,pred) :
    return(1.0 - dice(truth,pred))

def lossfd (truth,pred) :
    return(1.0 - f1dice(truth,pred))

import keras.losses as losses

def lossXdice (truth,pred) :
    return(losses.binary_crossentropy(truth,pred) - K.log(dice(truth,pred)+K.epsilon()))
    #return(-K.log(dice(truth,pred)+K.epsilon()))

# %%
def buildModel (input_shape) :
##    model = UNet(input_shape,depth=5,n_out=1,dropout=0.05,batch=False)
    model = UNet(input_shape,depth=5-2,n_out=1,dropout=0.05,batch=False)
    
    sgd = keras.optimizers.SGD(lr=0.01, momentum=0.9, nesterov=True)
    #model.compile(loss='mean_absolute_error',  #'binary_crossentropy',
    model.compile(loss=lossXdice, #'mean_absolute_error',  #'binary_crossentropy',
                  optimizer=sgd, #sgd, #"adam", #'rmsprop',
                  metrics=[dice,'binary_accuracy']) #['binary_accuracy']) #[fbeta_pred]) #['accuracy',fbeta_pred]) #['accuracy'])
    return(model)

# %%
K.clear_session()
model10 = buildModel((trX.shape[1],trX.shape[2],trX.shape[3]))
model10.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 512, 512, 3)   0
# ____________________________________________________________________________________________________
# conv2d_1 (Conv2D)                (None, 512, 512, 32)  896         input_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_2 (Conv2D)                (None, 512, 512, 32)  9248        conv2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 512, 512, 32)  0           conv2d_2[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)   (None, 256, 256, 32)  0           dropout_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_3 (Conv2D)                (None, 256, 256, 64)  18496       max_pooling2d_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_4 (Conv2D)                (None, 256, 256, 64)  36928       conv2d_3[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)              (None, 256, 256, 64)  0           conv2d_4[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)   (None, 128, 128, 64)  0           dropout_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_5 (Conv2D)                (None, 128, 128, 128) 73856       max_pooling2d_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_6 (Conv2D)                (None, 128, 128, 128) 147584      conv2d_5[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)              (None, 128, 128, 128) 0           conv2d_6[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)   (None, 64, 64, 128)   0           dropout_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_7 (Conv2D)                (None, 64, 64, 256)   295168      max_pooling2d_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_8 (Conv2D)                (None, 64, 64, 256)   590080      conv2d_7[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)   (None, 128, 128, 256) 0           conv2d_8[0][0]
# ____________________________________________________________________________________________________
# conv2d_9 (Conv2D)                (None, 128, 128, 128) 131200      up_sampling2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)              (None, 128, 128, 128) 0           conv2d_9[0][0]
# ____________________________________________________________________________________________________
# concatenate_1 (Concatenate)      (None, 128, 128, 256) 0           dropout_3[0][0]
#                                                                    dropout_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_10 (Conv2D)               (None, 128, 128, 128) 295040      concatenate_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_11 (Conv2D)               (None, 128, 128, 128) 147584      conv2d_10[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)   (None, 256, 256, 128) 0           conv2d_11[0][0]
# ____________________________________________________________________________________________________
# conv2d_12 (Conv2D)               (None, 256, 256, 64)  32832       up_sampling2d_2[0][0]
# ____________________________________________________________________________________________________
# dropout_5 (Dropout)              (None, 256, 256, 64)  0           conv2d_12[0][0]
# ____________________________________________________________________________________________________
# concatenate_2 (Concatenate)      (None, 256, 256, 128) 0           dropout_2[0][0]
#                                                                    dropout_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_13 (Conv2D)               (None, 256, 256, 64)  73792       concatenate_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_14 (Conv2D)               (None, 256, 256, 64)  36928       conv2d_13[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)   (None, 512, 512, 64)  0           conv2d_14[0][0]
# ____________________________________________________________________________________________________
# conv2d_15 (Conv2D)               (None, 512, 512, 32)  8224        up_sampling2d_3[0][0]
# ____________________________________________________________________________________________________
# dropout_6 (Dropout)              (None, 512, 512, 32)  0           conv2d_15[0][0]
# ____________________________________________________________________________________________________
# concatenate_3 (Concatenate)      (None, 512, 512, 64)  0           dropout_1[0][0]
#                                                                    dropout_6[0][0]
# ____________________________________________________________________________________________________
# conv2d_16 (Conv2D)               (None, 512, 512, 32)  18464       concatenate_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_17 (Conv2D)               (None, 512, 512, 32)  9248        conv2d_16[0][0]
# ____________________________________________________________________________________________________
# prediction (Conv2D)              (None, 512, 512, 1)   33          conv2d_17[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 512, 512, 1)   0           prediction[0][0]
# ====================================================================================================
# Total params: 1,925,601
# Trainable params: 1,925,601
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
#model10.load_weights('../Data-Keras/Models/model-UNet-weights.h5', by_name=False)
batch_size = 1

# %%
#epochs     = 150
epochs     = 50
verbose    = 2
batch_size = 1
metric     = 'binary_accuracy'
metric     = 'dice'

############trX, trY = trX[0:30], trY[0:30]

#folds      = 10
folds      = 5
folds      = 3
foldN      = trX.shape[0]/folds+1

print(datetime.datetime.now(),'Training with folds')

for i in range(folds) :
#for i in range(8,11) :

    print(datetime.datetime.now(),'------------>',i)

    K.clear_session()
    model10 = buildModel((trX.shape[1],trX.shape[2],trX.shape[3]))
    ############if 1 : model10.load_weights('../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7660-2.hdf5')

#    early_stopping = EarlyStopping(monitor='val_loss', patience=10,min_delta=0.0001,verbose=1)
    early_stopping = EarlyStopping(monitor='val_loss', patience=5,min_delta=0.0001,verbose=1)
    reduce_lr1     = ReduceLROnPlateau(monitor='val_loss', factor=0.5,patience=3, min_lr=0.0000001,verbose=1)
    reduce_lr2     = ReduceLROnPlateau(monitor='loss',     factor=0.5,patience=3, min_lr=0.0000001,verbose=1)

    filepath="../Temp/NewStep/Level-2-loss/V1-UNET-val_"+metric+"={val_"+metric+":.4f}-{"+metric+":.4f}---"+str(i)+".hdf5"
    #filepath="../Temp/NewStep/StandartF5/V1-UNET-val_"+metric+"={val_"+metric+":.4f}-{"+metric+":.4f}---"+str(i)+".hdf5"
    #filepath="../Temp/TempTempG5M5KFold10/V1-UNET-val_"+metric+"={val_"+metric+":.4f}-{"+metric+":.4f}---"+str(i)+".hdf5"
    #checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
    checkpoint1 = ModelCheckpoint(filepath, monitor=metric,        verbose=1, save_best_only=True, mode='max')
    checkpoint2 = ModelCheckpoint(filepath, monitor='val_'+metric, verbose=1, save_best_only=True, mode='max')

    step  = 60
    low   = 0
    high  = low+step
    
    tFold = [True]*(i*foldN)+[False]*foldN+[True]*trX.shape[0];
    tFold = tFold[:trX.shape[0]]
    
    vFold = [not xx for xx in tFold]

    #hist1  = model10.fit(trX[low:high],trY[low:high],
    hist1  = model10.fit(trX[tFold],trY[tFold],
                        epochs=epochs, batch_size=batch_size, 
                        #validation_split=0.20, 
                        validation_data=(trX[vFold],trY[vFold]),
                        initial_epoch = 0,
                        #callbacks=[early_stopping,reduce_lr1,reduce_lr2,checkpoint],
                        callbacks=[reduce_lr1,reduce_lr2,checkpoint1,checkpoint2,early_stopping],
                        verbose=verbose)

print(datetime.datetime.now())
# Out:
# 2017-07-31 00:11:41.508134 Training with folds
# 2017-07-31 00:11:41.508907 ------------> 0
# Train on 111 samples, validate on 57 samples
# Epoch 1/50
# Epoch 00000: dice improved from -inf to 0.47812, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.4990-0.4781---0.hdf5
# Epoch 00000: val_dice improved from -inf to 0.49903, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.4990-0.4781---0.hdf5
# 39s - loss: 1.5982 - dice: 0.4781 - binary_accuracy: 0.6840 - val_loss: 1.5379 - val_dice: 0.4990 - val_binary_accuracy: 0.7948
# Epoch 2/50
# Epoch 00001: dice improved from 0.47812 to 0.55322, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5594-0.5532---0.hdf5
# Epoch 00001: val_dice improved from 0.49903 to 0.55938, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5594-0.5532---0.hdf5
# 39s - loss: 1.3188 - dice: 0.5532 - binary_accuracy: 0.8001 - val_loss: 1.5692 - val_dice: 0.5594 - val_binary_accuracy: 0.7910
# Epoch 3/50
# Epoch 00002: dice improved from 0.55322 to 0.56195, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5607-0.5619---0.hdf5
# Epoch 00002: val_dice improved from 0.55938 to 0.56065, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5607-0.5619---0.hdf5
# 39s - loss: 1.2884 - dice: 0.5619 - binary_accuracy: 0.8032 - val_loss: 1.5291 - val_dice: 0.5607 - val_binary_accuracy: 0.7982
# Epoch 4/50
# Epoch 00003: dice improved from 0.56195 to 0.56355, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5385-0.5636---0.hdf5
# Epoch 00003: val_dice did not improve
# 39s - loss: 1.2805 - dice: 0.5636 - binary_accuracy: 0.8007 - val_loss: 1.5712 - val_dice: 0.5385 - val_binary_accuracy: 0.8133
# Epoch 5/50
# Epoch 00004: dice improved from 0.56355 to 0.57070, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.4943-0.5707---0.hdf5
# Epoch 00004: val_dice did not improve
# 39s - loss: 1.2723 - dice: 0.5707 - binary_accuracy: 0.8004 - val_loss: 1.5251 - val_dice: 0.4943 - val_binary_accuracy: 0.8096
# Epoch 6/50
# Epoch 00005: dice improved from 0.57070 to 0.57150, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5105-0.5715---0.hdf5
# Epoch 00005: val_dice did not improve
# 39s - loss: 1.2992 - dice: 0.5715 - binary_accuracy: 0.8060 - val_loss: 1.5418 - val_dice: 0.5105 - val_binary_accuracy: 0.7811
# Epoch 7/50
# Epoch 00006: dice improved from 0.57150 to 0.57281, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5168-0.5728---0.hdf5
# Epoch 00006: val_dice did not improve
# 39s - loss: 1.2604 - dice: 0.5728 - binary_accuracy: 0.8105 - val_loss: 1.6904 - val_dice: 0.5168 - val_binary_accuracy: 0.7279
# Epoch 8/50
# Epoch 00007: dice did not improve
# Epoch 00007: val_dice improved from 0.56065 to 0.56574, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5657-0.5670---0.hdf5
# 39s - loss: 1.2782 - dice: 0.5670 - binary_accuracy: 0.8134 - val_loss: 1.4759 - val_dice: 0.5657 - val_binary_accuracy: 0.8063
# Epoch 9/50
# Epoch 00008: dice improved from 0.57281 to 0.57528, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5473-0.5753---0.hdf5
# Epoch 00008: val_dice did not improve
# 39s - loss: 1.2608 - dice: 0.5753 - binary_accuracy: 0.8183 - val_loss: 1.4702 - val_dice: 0.5473 - val_binary_accuracy: 0.8164
# Epoch 10/50
# Epoch 00009: dice improved from 0.57528 to 0.60443, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5099-0.6044---0.hdf5
# Epoch 00009: val_dice did not improve
# 39s - loss: 1.1737 - dice: 0.6044 - binary_accuracy: 0.8304 - val_loss: 1.5322 - val_dice: 0.5099 - val_binary_accuracy: 0.7827
# Epoch 11/50
# Epoch 00010: dice did not improve
# Epoch 00010: val_dice did not improve
# 39s - loss: 1.1932 - dice: 0.5881 - binary_accuracy: 0.8241 - val_loss: 1.6319 - val_dice: 0.5613 - val_binary_accuracy: 0.7683
# Epoch 12/50
# Epoch 00011: dice did not improve
# Epoch 00011: val_dice improved from 0.56574 to 0.58918, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5892-0.5895---0.hdf5
# 39s - loss: 1.2133 - dice: 0.5895 - binary_accuracy: 0.8203 - val_loss: 1.4905 - val_dice: 0.5892 - val_binary_accuracy: 0.8089
# Epoch 13/50
#
# Epoch 00012: reducing learning rate to 0.00499999988824.
# Epoch 00012: dice did not improve
# Epoch 00012: val_dice did not improve
# 39s - loss: 1.2101 - dice: 0.5928 - binary_accuracy: 0.8253 - val_loss: 1.5515 - val_dice: 0.5708 - val_binary_accuracy: 0.7835
# Epoch 14/50
# Epoch 00013: dice did not improve
# Epoch 00013: val_dice did not improve
# 39s - loss: 1.1386 - dice: 0.6036 - binary_accuracy: 0.8261 - val_loss: 1.4057 - val_dice: 0.5865 - val_binary_accuracy: 0.8269
# Epoch 15/50
# Epoch 00014: dice improved from 0.60443 to 0.60868, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5495-0.6087---0.hdf5
# Epoch 00014: val_dice did not improve
# 39s - loss: 1.1378 - dice: 0.6087 - binary_accuracy: 0.8277 - val_loss: 1.4594 - val_dice: 0.5495 - val_binary_accuracy: 0.8362
# Epoch 16/50
# Epoch 00015: dice improved from 0.60868 to 0.61616, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5815-0.6162---0.hdf5
# Epoch 00015: val_dice did not improve
# 39s - loss: 1.1348 - dice: 0.6162 - binary_accuracy: 0.8359 - val_loss: 1.4080 - val_dice: 0.5815 - val_binary_accuracy: 0.8158
# Epoch 17/50
# Epoch 00016: dice improved from 0.61616 to 0.61639, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5760-0.6164---0.hdf5
# Epoch 00016: val_dice did not improve
# 39s - loss: 1.1038 - dice: 0.6164 - binary_accuracy: 0.8318 - val_loss: 1.3880 - val_dice: 0.5760 - val_binary_accuracy: 0.8113
# Epoch 18/50
# Epoch 00017: dice improved from 0.61639 to 0.61990, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5812-0.6199---0.hdf5
# Epoch 00017: val_dice did not improve
# 39s - loss: 1.0950 - dice: 0.6199 - binary_accuracy: 0.8372 - val_loss: 1.3624 - val_dice: 0.5812 - val_binary_accuracy: 0.8195
# Epoch 19/50
# Epoch 00018: dice improved from 0.61990 to 0.62188, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5653-0.6219---0.hdf5
# Epoch 00018: val_dice did not improve
# 39s - loss: 1.1096 - dice: 0.6219 - binary_accuracy: 0.8367 - val_loss: 1.3494 - val_dice: 0.5653 - val_binary_accuracy: 0.8260
# Epoch 20/50
# Epoch 00019: dice did not improve
# Epoch 00019: val_dice did not improve
# 39s - loss: 1.1191 - dice: 0.6126 - binary_accuracy: 0.8298 - val_loss: 1.3686 - val_dice: 0.5640 - val_binary_accuracy: 0.8248
# Epoch 21/50
# Epoch 00020: dice improved from 0.62188 to 0.62447, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5659-0.6245---0.hdf5
# Epoch 00020: val_dice did not improve
# 39s - loss: 1.1009 - dice: 0.6245 - binary_accuracy: 0.8370 - val_loss: 1.3551 - val_dice: 0.5659 - val_binary_accuracy: 0.8155
# Epoch 22/50
# Epoch 00021: dice improved from 0.62447 to 0.62921, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5725-0.6292---0.hdf5
# Epoch 00021: val_dice did not improve
# 39s - loss: 1.0829 - dice: 0.6292 - binary_accuracy: 0.8400 - val_loss: 1.3710 - val_dice: 0.5725 - val_binary_accuracy: 0.8073
# Epoch 23/50
#
# Epoch 00022: reducing learning rate to 0.00249999994412.
# Epoch 00022: dice improved from 0.62921 to 0.63123, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5998-0.6312---0.hdf5
# Epoch 00022: val_dice improved from 0.58918 to 0.59985, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5998-0.6312---0.hdf5
# 39s - loss: 1.0655 - dice: 0.6312 - binary_accuracy: 0.8400 - val_loss: 1.3927 - val_dice: 0.5998 - val_binary_accuracy: 0.8013
# Epoch 24/50
# Epoch 00023: dice improved from 0.63123 to 0.63156, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5762-0.6316---0.hdf5
# Epoch 00023: val_dice did not improve
# 39s - loss: 1.0559 - dice: 0.6316 - binary_accuracy: 0.8358 - val_loss: 1.3292 - val_dice: 0.5762 - val_binary_accuracy: 0.8439
# Epoch 25/50
# Epoch 00024: dice improved from 0.63156 to 0.64969, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5883-0.6497---0.hdf5
# Epoch 00024: val_dice did not improve
# 39s - loss: 1.0010 - dice: 0.6497 - binary_accuracy: 0.8496 - val_loss: 1.3165 - val_dice: 0.5883 - val_binary_accuracy: 0.8079
# Epoch 26/50
# Epoch 00025: dice improved from 0.64969 to 0.65670, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6056-0.6567---0.hdf5
# Epoch 00025: val_dice improved from 0.59985 to 0.60561, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6056-0.6567---0.hdf5
# 39s - loss: 0.9776 - dice: 0.6567 - binary_accuracy: 0.8546 - val_loss: 1.2602 - val_dice: 0.6056 - val_binary_accuracy: 0.8282
# Epoch 27/50
# Epoch 00026: dice improved from 0.65670 to 0.66460, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6029-0.6646---0.hdf5
# Epoch 00026: val_dice did not improve
# 39s - loss: 0.9565 - dice: 0.6646 - binary_accuracy: 0.8564 - val_loss: 1.2528 - val_dice: 0.6029 - val_binary_accuracy: 0.8266
# Epoch 28/50
# Epoch 00027: dice did not improve
# Epoch 00027: val_dice improved from 0.60561 to 0.61156, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6116-0.6542---0.hdf5
# 39s - loss: 0.9793 - dice: 0.6542 - binary_accuracy: 0.8548 - val_loss: 1.3323 - val_dice: 0.6116 - val_binary_accuracy: 0.8073
# Epoch 29/50
# Epoch 00028: dice did not improve
# Epoch 00028: val_dice improved from 0.61156 to 0.62217, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6222-0.6536---0.hdf5
# 39s - loss: 0.9877 - dice: 0.6536 - binary_accuracy: 0.8500 - val_loss: 1.2305 - val_dice: 0.6222 - val_binary_accuracy: 0.8384
# Epoch 30/50
# Epoch 00029: dice did not improve
# Epoch 00029: val_dice improved from 0.62217 to 0.62428, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6243-0.6644---0.hdf5
# 39s - loss: 0.9590 - dice: 0.6644 - binary_accuracy: 0.8559 - val_loss: 1.2319 - val_dice: 0.6243 - val_binary_accuracy: 0.8418
# Epoch 31/50
#
# Epoch 00030: reducing learning rate to 0.00124999997206.
# Epoch 00030: dice improved from 0.66460 to 0.66547, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6044-0.6655---0.hdf5
# Epoch 00030: val_dice did not improve
# 39s - loss: 0.9602 - dice: 0.6655 - binary_accuracy: 0.8580 - val_loss: 1.2453 - val_dice: 0.6044 - val_binary_accuracy: 0.8456
# Epoch 32/50
# Epoch 00031: dice improved from 0.66547 to 0.66599, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6332-0.6660---0.hdf5
# Epoch 00031: val_dice improved from 0.62428 to 0.63318, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6332-0.6660---0.hdf5
# 39s - loss: 0.9408 - dice: 0.6660 - binary_accuracy: 0.8605 - val_loss: 1.2323 - val_dice: 0.6332 - val_binary_accuracy: 0.8395
# Epoch 33/50
# Epoch 00032: dice improved from 0.66599 to 0.67898, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6409-0.6790---0.hdf5
# Epoch 00032: val_dice improved from 0.63318 to 0.64093, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6409-0.6790---0.hdf5
# 39s - loss: 0.9103 - dice: 0.6790 - binary_accuracy: 0.8679 - val_loss: 1.1876 - val_dice: 0.6409 - val_binary_accuracy: 0.8490
# Epoch 34/50
# Epoch 00033: dice improved from 0.67898 to 0.68668, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6283-0.6867---0.hdf5
# Epoch 00033: val_dice did not improve
# 39s - loss: 0.8899 - dice: 0.6867 - binary_accuracy: 0.8719 - val_loss: 1.1756 - val_dice: 0.6283 - val_binary_accuracy: 0.8529
# Epoch 35/50
# Epoch 00034: dice did not improve
# Epoch 00034: val_dice did not improve
# 39s - loss: 0.8943 - dice: 0.6805 - binary_accuracy: 0.8701 - val_loss: 1.1989 - val_dice: 0.6332 - val_binary_accuracy: 0.8477
# Epoch 36/50
# Epoch 00035: dice did not improve
# Epoch 00035: val_dice did not improve
# 39s - loss: 0.8893 - dice: 0.6861 - binary_accuracy: 0.8714 - val_loss: 1.1726 - val_dice: 0.6340 - val_binary_accuracy: 0.8546
# Epoch 37/50
# Epoch 00036: dice improved from 0.68668 to 0.68751, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6429-0.6875---0.hdf5
# Epoch 00036: val_dice improved from 0.64093 to 0.64295, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6429-0.6875---0.hdf5
# 39s - loss: 0.8870 - dice: 0.6875 - binary_accuracy: 0.8728 - val_loss: 1.1655 - val_dice: 0.6429 - val_binary_accuracy: 0.8593
# Epoch 38/50
# Epoch 00037: dice improved from 0.68751 to 0.69638, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6379-0.6964---0.hdf5
# Epoch 00037: val_dice did not improve
# 39s - loss: 0.8706 - dice: 0.6964 - binary_accuracy: 0.8767 - val_loss: 1.1574 - val_dice: 0.6379 - val_binary_accuracy: 0.8631
# Epoch 39/50
# Epoch 00038: dice improved from 0.69638 to 0.69836, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6116-0.6984---0.hdf5
# Epoch 00038: val_dice did not improve
# 39s - loss: 0.8477 - dice: 0.6984 - binary_accuracy: 0.8816 - val_loss: 1.3404 - val_dice: 0.6116 - val_binary_accuracy: 0.8009
# Epoch 40/50
# Epoch 00039: dice did not improve
# Epoch 00039: val_dice did not improve
# 39s - loss: 0.8672 - dice: 0.6962 - binary_accuracy: 0.8772 - val_loss: 1.2367 - val_dice: 0.6242 - val_binary_accuracy: 0.8365
# Epoch 41/50
# Epoch 00040: dice improved from 0.69836 to 0.70066, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5928-0.7007---0.hdf5
# Epoch 00040: val_dice did not improve
# 39s - loss: 0.8468 - dice: 0.7007 - binary_accuracy: 0.8797 - val_loss: 1.3879 - val_dice: 0.5928 - val_binary_accuracy: 0.7945
# Epoch 42/50
#
# Epoch 00041: reducing learning rate to 0.00062499998603.
# Epoch 00041: dice did not improve
# Epoch 00041: val_dice did not improve
# 39s - loss: 0.8811 - dice: 0.6937 - binary_accuracy: 0.8747 - val_loss: 1.1732 - val_dice: 0.6419 - val_binary_accuracy: 0.8600
# Epoch 43/50
# Epoch 00042: dice improved from 0.70066 to 0.70644, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6576-0.7064---0.hdf5
# Epoch 00042: val_dice improved from 0.64295 to 0.65758, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6576-0.7064---0.hdf5
# 39s - loss: 0.8271 - dice: 0.7064 - binary_accuracy: 0.8847 - val_loss: 1.1459 - val_dice: 0.6576 - val_binary_accuracy: 0.8621
# Epoch 44/50
# Epoch 00043: dice improved from 0.70644 to 0.70872, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6594-0.7087---0.hdf5
# Epoch 00043: val_dice improved from 0.65758 to 0.65937, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6594-0.7087---0.hdf5
# 39s - loss: 0.8169 - dice: 0.7087 - binary_accuracy: 0.8857 - val_loss: 1.1457 - val_dice: 0.6594 - val_binary_accuracy: 0.8761
# Epoch 45/50
# Epoch 00044: dice improved from 0.70872 to 0.71499, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6405-0.7150---0.hdf5
# Epoch 00044: val_dice did not improve
# 39s - loss: 0.8146 - dice: 0.7150 - binary_accuracy: 0.8872 - val_loss: 1.2280 - val_dice: 0.6405 - val_binary_accuracy: 0.8371
# Epoch 46/50
# Epoch 00045: dice did not improve
# Epoch 00045: val_dice improved from 0.65937 to 0.65952, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6595-0.7140---0.hdf5
# 39s - loss: 0.8021 - dice: 0.7140 - binary_accuracy: 0.8896 - val_loss: 1.1569 - val_dice: 0.6595 - val_binary_accuracy: 0.8583
# Epoch 47/50
# Epoch 00046: dice improved from 0.71499 to 0.71701, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6549-0.7170---0.hdf5
# Epoch 00046: val_dice did not improve
# 39s - loss: 0.8004 - dice: 0.7170 - binary_accuracy: 0.8900 - val_loss: 1.1556 - val_dice: 0.6549 - val_binary_accuracy: 0.8574
# Epoch 48/50
# Epoch 00047: dice improved from 0.71701 to 0.71807, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6592-0.7181---0.hdf5
# Epoch 00047: val_dice did not improve
# 39s - loss: 0.8043 - dice: 0.7181 - binary_accuracy: 0.8873 - val_loss: 1.1183 - val_dice: 0.6592 - val_binary_accuracy: 0.8697
# Epoch 49/50
# Epoch 00048: dice did not improve
# Epoch 00048: val_dice improved from 0.65952 to 0.66483, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6648-0.7144---0.hdf5
# 39s - loss: 0.8055 - dice: 0.7144 - binary_accuracy: 0.8887 - val_loss: 1.1124 - val_dice: 0.6648 - val_binary_accuracy: 0.8713
# Epoch 50/50
# Epoch 00049: dice did not improve
# Epoch 00049: val_dice did not improve
# 39s - loss: 0.8186 - dice: 0.7134 - binary_accuracy: 0.8857 - val_loss: 1.1159 - val_dice: 0.6636 - val_binary_accuracy: 0.8690
# 2017-07-31 00:44:30.127211 ------------> 1
# Train on 111 samples, validate on 57 samples
# Epoch 1/50
# Epoch 00000: dice improved from -inf to 0.42864, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5716-0.4286---1.hdf5
# Epoch 00000: val_dice improved from -inf to 0.57161, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5716-0.4286---1.hdf5
# 39s - loss: 1.7738 - dice: 0.4286 - binary_accuracy: 0.6743 - val_loss: 1.4109 - val_dice: 0.5716 - val_binary_accuracy: 0.8211
# Epoch 2/50
# Epoch 00001: dice improved from 0.42864 to 0.51503, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5362-0.5150---1.hdf5
# Epoch 00001: val_dice did not improve
# 39s - loss: 1.4809 - dice: 0.5150 - binary_accuracy: 0.7874 - val_loss: 1.4048 - val_dice: 0.5362 - val_binary_accuracy: 0.8233
# Epoch 3/50
# Epoch 00002: dice improved from 0.51503 to 0.53348, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5196-0.5335---1.hdf5
# Epoch 00002: val_dice did not improve
# 39s - loss: 1.3899 - dice: 0.5335 - binary_accuracy: 0.7952 - val_loss: 1.4463 - val_dice: 0.5196 - val_binary_accuracy: 0.8077
# Epoch 4/50
# Epoch 00003: dice did not improve
# Epoch 00003: val_dice improved from 0.57161 to 0.59886, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5989-0.5236---1.hdf5
# 39s - loss: 1.4063 - dice: 0.5236 - binary_accuracy: 0.7967 - val_loss: 1.4062 - val_dice: 0.5989 - val_binary_accuracy: 0.8108
# Epoch 5/50
# Epoch 00004: dice improved from 0.53348 to 0.54297, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5606-0.5430---1.hdf5
# Epoch 00004: val_dice did not improve
# 39s - loss: 1.3652 - dice: 0.5430 - binary_accuracy: 0.8014 - val_loss: 1.3233 - val_dice: 0.5606 - val_binary_accuracy: 0.8262
# Epoch 6/50
# Epoch 00005: dice did not improve
# Epoch 00005: val_dice did not improve
# 39s - loss: 1.3953 - dice: 0.5423 - binary_accuracy: 0.8028 - val_loss: 1.4259 - val_dice: 0.5206 - val_binary_accuracy: 0.8261
# Epoch 7/50
# Epoch 00006: dice did not improve
# Epoch 00006: val_dice did not improve
# 39s - loss: 1.3453 - dice: 0.5355 - binary_accuracy: 0.8036 - val_loss: 1.3676 - val_dice: 0.5901 - val_binary_accuracy: 0.8391
# Epoch 8/50
# Epoch 00007: dice improved from 0.54297 to 0.55993, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5693-0.5599---1.hdf5
# Epoch 00007: val_dice did not improve
# 39s - loss: 1.3014 - dice: 0.5599 - binary_accuracy: 0.8074 - val_loss: 1.3002 - val_dice: 0.5693 - val_binary_accuracy: 0.8375
# Epoch 9/50
# Epoch 00008: dice did not improve
# Epoch 00008: val_dice did not improve
# 39s - loss: 1.3217 - dice: 0.5481 - binary_accuracy: 0.8083 - val_loss: 1.2658 - val_dice: 0.5823 - val_binary_accuracy: 0.8505
# Epoch 10/50
# Epoch 00009: dice did not improve
# Epoch 00009: val_dice improved from 0.59886 to 0.60070, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6007-0.5551---1.hdf5
# 39s - loss: 1.3486 - dice: 0.5551 - binary_accuracy: 0.8067 - val_loss: 1.3414 - val_dice: 0.6007 - val_binary_accuracy: 0.8199
# Epoch 11/50
# Epoch 00010: dice did not improve
# Epoch 00010: val_dice improved from 0.60070 to 0.62070, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6207-0.5581---1.hdf5
# 39s - loss: 1.3136 - dice: 0.5581 - binary_accuracy: 0.8169 - val_loss: 1.4013 - val_dice: 0.6207 - val_binary_accuracy: 0.8273
# Epoch 12/50
# Epoch 00011: dice improved from 0.55993 to 0.56747, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5619-0.5675---1.hdf5
# Epoch 00011: val_dice did not improve
# 39s - loss: 1.2847 - dice: 0.5675 - binary_accuracy: 0.8180 - val_loss: 1.3388 - val_dice: 0.5619 - val_binary_accuracy: 0.8491
# Epoch 13/50
#
# Epoch 00012: reducing learning rate to 0.00499999988824.
# Epoch 00012: dice did not improve
# Epoch 00012: val_dice did not improve
# 39s - loss: 1.3323 - dice: 0.5586 - binary_accuracy: 0.8079 - val_loss: 1.4099 - val_dice: 0.5172 - val_binary_accuracy: 0.8346
# Epoch 14/50
# Epoch 00013: dice improved from 0.56747 to 0.57196, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6342-0.5720---1.hdf5
# Epoch 00013: val_dice improved from 0.62070 to 0.63416, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6342-0.5720---1.hdf5
# 39s - loss: 1.2351 - dice: 0.5720 - binary_accuracy: 0.8222 - val_loss: 1.2491 - val_dice: 0.6342 - val_binary_accuracy: 0.8470
# Epoch 15/50
# Epoch 00014: dice improved from 0.57196 to 0.58915, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5730-0.5891---1.hdf5
# Epoch 00014: val_dice did not improve
# 39s - loss: 1.2148 - dice: 0.5891 - binary_accuracy: 0.8185 - val_loss: 1.3192 - val_dice: 0.5730 - val_binary_accuracy: 0.8164
# Epoch 16/50
# Epoch 00015: dice did not improve
# Epoch 00015: val_dice did not improve
# 39s - loss: 1.2281 - dice: 0.5747 - binary_accuracy: 0.8176 - val_loss: 1.2874 - val_dice: 0.5711 - val_binary_accuracy: 0.8516
# Epoch 17/50
# Epoch 00016: dice did not improve
# Epoch 00016: val_dice did not improve
# 39s - loss: 1.2245 - dice: 0.5820 - binary_accuracy: 0.8260 - val_loss: 1.2239 - val_dice: 0.6156 - val_binary_accuracy: 0.8554
# Epoch 18/50
# Epoch 00017: dice did not improve
# Epoch 00017: val_dice did not improve
# 39s - loss: 1.2266 - dice: 0.5852 - binary_accuracy: 0.8247 - val_loss: 1.2133 - val_dice: 0.5998 - val_binary_accuracy: 0.8405
# Epoch 19/50
# Epoch 00018: dice did not improve
# Epoch 00018: val_dice did not improve
# 39s - loss: 1.1977 - dice: 0.5824 - binary_accuracy: 0.8262 - val_loss: 1.2080 - val_dice: 0.6311 - val_binary_accuracy: 0.8520
# Epoch 20/50
# Epoch 00019: dice improved from 0.58915 to 0.60590, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5385-0.6059---1.hdf5
# Epoch 00019: val_dice did not improve
# 39s - loss: 1.1778 - dice: 0.6059 - binary_accuracy: 0.8271 - val_loss: 1.3710 - val_dice: 0.5385 - val_binary_accuracy: 0.8184
# Epoch 21/50
# Epoch 00020: dice did not improve
# Epoch 00020: val_dice did not improve
# 39s - loss: 1.2588 - dice: 0.5751 - binary_accuracy: 0.8171 - val_loss: 1.2330 - val_dice: 0.6087 - val_binary_accuracy: 0.8340
# Epoch 22/50
# Epoch 00021: dice did not improve
# Epoch 00021: val_dice did not improve
# 39s - loss: 1.1724 - dice: 0.5956 - binary_accuracy: 0.8222 - val_loss: 1.3576 - val_dice: 0.5451 - val_binary_accuracy: 0.8456
# Epoch 23/50
# Epoch 00022: dice did not improve
# Epoch 00022: val_dice did not improve
# 39s - loss: 1.1990 - dice: 0.5907 - binary_accuracy: 0.8240 - val_loss: 1.2021 - val_dice: 0.6173 - val_binary_accuracy: 0.8368
# Epoch 24/50
# Epoch 00023: dice did not improve
# Epoch 00023: val_dice did not improve
# 39s - loss: 1.1868 - dice: 0.5943 - binary_accuracy: 0.8297 - val_loss: 1.1798 - val_dice: 0.6137 - val_binary_accuracy: 0.8573
# Epoch 25/50
# Epoch 00024: dice did not improve
# Epoch 00024: val_dice did not improve
# 39s - loss: 1.1717 - dice: 0.5994 - binary_accuracy: 0.8267 - val_loss: 1.1528 - val_dice: 0.6318 - val_binary_accuracy: 0.8575
# Epoch 26/50
# Epoch 00025: dice did not improve
# Epoch 00025: val_dice did not improve
# 39s - loss: 1.1744 - dice: 0.5978 - binary_accuracy: 0.8264 - val_loss: 1.2346 - val_dice: 0.6044 - val_binary_accuracy: 0.8384
# Epoch 27/50
# Epoch 00026: dice did not improve
# Epoch 00026: val_dice did not improve
# 39s - loss: 1.1696 - dice: 0.5972 - binary_accuracy: 0.8224 - val_loss: 1.1564 - val_dice: 0.6294 - val_binary_accuracy: 0.8500
# Epoch 28/50
# Epoch 00027: dice did not improve
# Epoch 00027: val_dice did not improve
# 39s - loss: 1.1524 - dice: 0.6039 - binary_accuracy: 0.8290 - val_loss: 1.2139 - val_dice: 0.5943 - val_binary_accuracy: 0.8560
# Epoch 29/50
#
# Epoch 00028: reducing learning rate to 0.00249999994412.
# Epoch 00028: dice improved from 0.60590 to 0.60689, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6049-0.6069---1.hdf5
# Epoch 00028: val_dice did not improve
# 39s - loss: 1.1292 - dice: 0.6069 - binary_accuracy: 0.8274 - val_loss: 1.1945 - val_dice: 0.6049 - val_binary_accuracy: 0.8331
# Epoch 30/50
# Epoch 00029: dice improved from 0.60689 to 0.61996, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6431-0.6200---1.hdf5
# Epoch 00029: val_dice improved from 0.63416 to 0.64312, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6431-0.6200---1.hdf5
# 39s - loss: 1.0692 - dice: 0.6200 - binary_accuracy: 0.8379 - val_loss: 1.1217 - val_dice: 0.6431 - val_binary_accuracy: 0.8583
# Epoch 31/50
# Epoch 00030: dice improved from 0.61996 to 0.62264, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6523-0.6226---1.hdf5
# Epoch 00030: val_dice improved from 0.64312 to 0.65231, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6523-0.6226---1.hdf5
# 39s - loss: 1.0696 - dice: 0.6226 - binary_accuracy: 0.8384 - val_loss: 1.1108 - val_dice: 0.6523 - val_binary_accuracy: 0.8627
# Epoch 32/50
# Epoch 00031: dice improved from 0.62264 to 0.63796, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6518-0.6380---1.hdf5
# Epoch 00031: val_dice did not improve
# 39s - loss: 1.0252 - dice: 0.6380 - binary_accuracy: 0.8465 - val_loss: 1.1316 - val_dice: 0.6518 - val_binary_accuracy: 0.8677
# Epoch 33/50
# Epoch 00032: dice improved from 0.63796 to 0.63872, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6626-0.6387---1.hdf5
# Epoch 00032: val_dice improved from 0.65231 to 0.66263, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6626-0.6387---1.hdf5
# 39s - loss: 1.0327 - dice: 0.6387 - binary_accuracy: 0.8478 - val_loss: 1.0983 - val_dice: 0.6626 - val_binary_accuracy: 0.8590
# Epoch 34/50
# Epoch 00033: dice did not improve
# Epoch 00033: val_dice did not improve
# 39s - loss: 1.0451 - dice: 0.6341 - binary_accuracy: 0.8429 - val_loss: 1.1232 - val_dice: 0.6381 - val_binary_accuracy: 0.8673
# Epoch 35/50
# Epoch 00034: dice improved from 0.63872 to 0.64714, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6700-0.6471---1.hdf5
# Epoch 00034: val_dice improved from 0.66263 to 0.66996, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6700-0.6471---1.hdf5
# 39s - loss: 0.9980 - dice: 0.6471 - binary_accuracy: 0.8549 - val_loss: 1.0723 - val_dice: 0.6700 - val_binary_accuracy: 0.8663
# Epoch 36/50
# Epoch 00035: dice improved from 0.64714 to 0.65794, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6506-0.6579---1.hdf5
# Epoch 00035: val_dice did not improve
# 39s - loss: 0.9844 - dice: 0.6579 - binary_accuracy: 0.8605 - val_loss: 1.1136 - val_dice: 0.6506 - val_binary_accuracy: 0.8697
# Epoch 37/50
# Epoch 00036: dice did not improve
# Epoch 00036: val_dice did not improve
# 39s - loss: 1.0365 - dice: 0.6395 - binary_accuracy: 0.8495 - val_loss: 1.0925 - val_dice: 0.6690 - val_binary_accuracy: 0.8641
# Epoch 38/50
# Epoch 00037: dice did not improve
# Epoch 00037: val_dice did not improve
# 39s - loss: 1.0551 - dice: 0.6345 - binary_accuracy: 0.8422 - val_loss: 1.1223 - val_dice: 0.6429 - val_binary_accuracy: 0.8613
# Epoch 39/50
#
# Epoch 00038: reducing learning rate to 0.00124999997206.
# Epoch 00038: dice did not improve
# Epoch 00038: val_dice did not improve
# 39s - loss: 1.0116 - dice: 0.6447 - binary_accuracy: 0.8519 - val_loss: 1.1507 - val_dice: 0.6253 - val_binary_accuracy: 0.8396
# Epoch 40/50
# Epoch 00039: dice did not improve
# Epoch 00039: val_dice did not improve
# 39s - loss: 0.9644 - dice: 0.6560 - binary_accuracy: 0.8587 - val_loss: 1.0508 - val_dice: 0.6656 - val_binary_accuracy: 0.8751
# Epoch 41/50
# Epoch 00040: dice improved from 0.65794 to 0.66872, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6826-0.6687---1.hdf5
# Epoch 00040: val_dice improved from 0.66996 to 0.68255, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6826-0.6687---1.hdf5
# 39s - loss: 0.9169 - dice: 0.6687 - binary_accuracy: 0.8729 - val_loss: 1.0521 - val_dice: 0.6826 - val_binary_accuracy: 0.8748
# Epoch 42/50
# Epoch 00041: dice improved from 0.66872 to 0.67469, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6915-0.6747---1.hdf5
# Epoch 00041: val_dice improved from 0.68255 to 0.69146, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6915-0.6747---1.hdf5
# 39s - loss: 0.9237 - dice: 0.6747 - binary_accuracy: 0.8711 - val_loss: 1.0123 - val_dice: 0.6915 - val_binary_accuracy: 0.8759
# Epoch 43/50
# Epoch 00042: dice improved from 0.67469 to 0.67719, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6860-0.6772---1.hdf5
# Epoch 00042: val_dice did not improve
# 39s - loss: 0.9157 - dice: 0.6772 - binary_accuracy: 0.8732 - val_loss: 1.0141 - val_dice: 0.6860 - val_binary_accuracy: 0.8775
# Epoch 44/50
# Epoch 00043: dice improved from 0.67719 to 0.68485, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6816-0.6849---1.hdf5
# Epoch 00043: val_dice did not improve
# 39s - loss: 0.8967 - dice: 0.6849 - binary_accuracy: 0.8761 - val_loss: 1.0032 - val_dice: 0.6816 - val_binary_accuracy: 0.8826
# Epoch 45/50
# Epoch 00044: dice improved from 0.68485 to 0.68764, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6936-0.6876---1.hdf5
# Epoch 00044: val_dice improved from 0.69146 to 0.69356, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6936-0.6876---1.hdf5
# 39s - loss: 0.8839 - dice: 0.6876 - binary_accuracy: 0.8785 - val_loss: 1.0080 - val_dice: 0.6936 - val_binary_accuracy: 0.8860
# Epoch 46/50
# Epoch 00045: dice did not improve
# Epoch 00045: val_dice improved from 0.69356 to 0.69901, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6990-0.6723---1.hdf5
# 39s - loss: 0.9295 - dice: 0.6723 - binary_accuracy: 0.8700 - val_loss: 0.9969 - val_dice: 0.6990 - val_binary_accuracy: 0.8800
# Epoch 47/50
# Epoch 00046: dice improved from 0.68764 to 0.69320, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6876-0.6932---1.hdf5
# Epoch 00046: val_dice did not improve
# 39s - loss: 0.8672 - dice: 0.6932 - binary_accuracy: 0.8807 - val_loss: 1.0012 - val_dice: 0.6876 - val_binary_accuracy: 0.8808
# Epoch 48/50
# Epoch 00047: dice did not improve
# Epoch 00047: val_dice did not improve
# 39s - loss: 0.8688 - dice: 0.6921 - binary_accuracy: 0.8799 - val_loss: 0.9900 - val_dice: 0.6983 - val_binary_accuracy: 0.8771
# Epoch 49/50
# Epoch 00048: dice improved from 0.69320 to 0.70042, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6888-0.7004---1.hdf5
# Epoch 00048: val_dice did not improve
# 39s - loss: 0.8487 - dice: 0.7004 - binary_accuracy: 0.8821 - val_loss: 0.9909 - val_dice: 0.6888 - val_binary_accuracy: 0.8777
# Epoch 50/50
# Epoch 00049: dice did not improve
# Epoch 00049: val_dice did not improve
# 39s - loss: 0.8508 - dice: 0.6934 - binary_accuracy: 0.8805 - val_loss: 1.1103 - val_dice: 0.6794 - val_binary_accuracy: 0.8785
# 2017-07-31 01:17:16.051056 ------------> 2
# Train on 114 samples, validate on 54 samples
# Epoch 1/50
# Epoch 00000: dice improved from -inf to 0.46309, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5651-0.4631---2.hdf5
# Epoch 00000: val_dice improved from -inf to 0.56513, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5651-0.4631---2.hdf5
# 40s - loss: 1.7808 - dice: 0.4631 - binary_accuracy: 0.7745 - val_loss: 1.1551 - val_dice: 0.5651 - val_binary_accuracy: 0.8096
# Epoch 2/50
# Epoch 00001: dice improved from 0.46309 to 0.51779, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.4877-0.5178---2.hdf5
# Epoch 00001: val_dice did not improve
# 40s - loss: 1.5774 - dice: 0.5178 - binary_accuracy: 0.7889 - val_loss: 1.2224 - val_dice: 0.4877 - val_binary_accuracy: 0.8051
# Epoch 3/50
# Epoch 00002: dice improved from 0.51779 to 0.53655, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5792-0.5365---2.hdf5
# Epoch 00002: val_dice improved from 0.56513 to 0.57918, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5792-0.5365---2.hdf5
# 40s - loss: 1.5026 - dice: 0.5365 - binary_accuracy: 0.8042 - val_loss: 1.0506 - val_dice: 0.5792 - val_binary_accuracy: 0.8106
# Epoch 4/50
# Epoch 00003: dice improved from 0.53655 to 0.53746, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5650-0.5375---2.hdf5
# Epoch 00003: val_dice did not improve
# 40s - loss: 1.4821 - dice: 0.5375 - binary_accuracy: 0.8026 - val_loss: 1.0891 - val_dice: 0.5650 - val_binary_accuracy: 0.8185
# Epoch 5/50
# Epoch 00004: dice improved from 0.53746 to 0.55084, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5789-0.5508---2.hdf5
# Epoch 00004: val_dice did not improve
# 40s - loss: 1.4529 - dice: 0.5508 - binary_accuracy: 0.8143 - val_loss: 1.1518 - val_dice: 0.5789 - val_binary_accuracy: 0.7858
# Epoch 6/50
# Epoch 00005: dice did not improve
# Epoch 00005: val_dice improved from 0.57918 to 0.60449, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6045-0.5475---2.hdf5
# 40s - loss: 1.4588 - dice: 0.5475 - binary_accuracy: 0.8142 - val_loss: 1.0421 - val_dice: 0.6045 - val_binary_accuracy: 0.8003
# Epoch 7/50
# Epoch 00006: dice improved from 0.55084 to 0.55445, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5559-0.5545---2.hdf5
# Epoch 00006: val_dice did not improve
# 40s - loss: 1.4232 - dice: 0.5545 - binary_accuracy: 0.8143 - val_loss: 1.0582 - val_dice: 0.5559 - val_binary_accuracy: 0.8172
# Epoch 8/50
# Epoch 00007: dice did not improve
# Epoch 00007: val_dice did not improve
# 39s - loss: 1.4278 - dice: 0.5540 - binary_accuracy: 0.8199 - val_loss: 1.0578 - val_dice: 0.5985 - val_binary_accuracy: 0.8391
# Epoch 9/50
# Epoch 00008: dice improved from 0.55445 to 0.56581, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5318-0.5658---2.hdf5
# Epoch 00008: val_dice did not improve
# 40s - loss: 1.4071 - dice: 0.5658 - binary_accuracy: 0.8186 - val_loss: 1.3889 - val_dice: 0.5318 - val_binary_accuracy: 0.8266
# Epoch 10/50
#
# Epoch 00009: reducing learning rate to 0.00499999988824.
# Epoch 00009: dice did not improve
# Epoch 00009: val_dice did not improve
# 39s - loss: 1.5115 - dice: 0.5443 - binary_accuracy: 0.8151 - val_loss: 1.0837 - val_dice: 0.5724 - val_binary_accuracy: 0.8138
# Epoch 11/50
# Epoch 00010: dice improved from 0.56581 to 0.56688, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6213-0.5669---2.hdf5
# Epoch 00010: val_dice improved from 0.60449 to 0.62126, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6213-0.5669---2.hdf5
# 40s - loss: 1.3770 - dice: 0.5669 - binary_accuracy: 0.8257 - val_loss: 1.0004 - val_dice: 0.6213 - val_binary_accuracy: 0.8329
# Epoch 12/50
# Epoch 00011: dice improved from 0.56688 to 0.58207, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6025-0.5821---2.hdf5
# Epoch 00011: val_dice did not improve
# 40s - loss: 1.3554 - dice: 0.5821 - binary_accuracy: 0.8285 - val_loss: 0.9662 - val_dice: 0.6025 - val_binary_accuracy: 0.8289
# Epoch 13/50
# Epoch 00012: dice did not improve
# Epoch 00012: val_dice did not improve
# 39s - loss: 1.3395 - dice: 0.5786 - binary_accuracy: 0.8294 - val_loss: 0.9694 - val_dice: 0.6168 - val_binary_accuracy: 0.8228
# Epoch 14/50
# Epoch 00013: dice improved from 0.58207 to 0.58827, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6383-0.5883---2.hdf5
# Epoch 00013: val_dice improved from 0.62126 to 0.63832, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6383-0.5883---2.hdf5
# 40s - loss: 1.3052 - dice: 0.5883 - binary_accuracy: 0.8320 - val_loss: 0.9736 - val_dice: 0.6383 - val_binary_accuracy: 0.8377
# Epoch 15/50
# Epoch 00014: dice improved from 0.58827 to 0.59009, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5885-0.5901---2.hdf5
# Epoch 00014: val_dice did not improve
# 40s - loss: 1.3193 - dice: 0.5901 - binary_accuracy: 0.8234 - val_loss: 0.9661 - val_dice: 0.5885 - val_binary_accuracy: 0.8330
# Epoch 16/50
# Epoch 00015: dice did not improve
# Epoch 00015: val_dice did not improve
# 39s - loss: 1.3327 - dice: 0.5826 - binary_accuracy: 0.8276 - val_loss: 0.9249 - val_dice: 0.6360 - val_binary_accuracy: 0.8258
# Epoch 17/50
# Epoch 00016: dice did not improve
# Epoch 00016: val_dice did not improve
# 39s - loss: 1.3148 - dice: 0.5890 - binary_accuracy: 0.8290 - val_loss: 0.9191 - val_dice: 0.6246 - val_binary_accuracy: 0.8296
# Epoch 18/50
# Epoch 00017: dice improved from 0.59009 to 0.59123, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5883-0.5912---2.hdf5
# Epoch 00017: val_dice did not improve
# 40s - loss: 1.2993 - dice: 0.5912 - binary_accuracy: 0.8291 - val_loss: 1.0121 - val_dice: 0.5883 - val_binary_accuracy: 0.8398
# Epoch 19/50
# Epoch 00018: dice improved from 0.59123 to 0.59764, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.5758-0.5976---2.hdf5
# Epoch 00018: val_dice did not improve
# 40s - loss: 1.2764 - dice: 0.5976 - binary_accuracy: 0.8314 - val_loss: 0.9969 - val_dice: 0.5758 - val_binary_accuracy: 0.8425
# Epoch 20/50
# Epoch 00019: dice did not improve
# Epoch 00019: val_dice did not improve
# 39s - loss: 1.3050 - dice: 0.5926 - binary_accuracy: 0.8312 - val_loss: 0.9783 - val_dice: 0.6335 - val_binary_accuracy: 0.7942
# Epoch 21/50
#
# Epoch 00020: reducing learning rate to 0.00249999994412.
# Epoch 00020: dice did not improve
# Epoch 00020: val_dice improved from 0.63832 to 0.64947, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6495-0.5927---2.hdf5
# 40s - loss: 1.2877 - dice: 0.5927 - binary_accuracy: 0.8326 - val_loss: 0.9279 - val_dice: 0.6495 - val_binary_accuracy: 0.8330
# Epoch 22/50
# Epoch 00021: dice improved from 0.59764 to 0.60152, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6304-0.6015---2.hdf5
# Epoch 00021: val_dice did not improve
# 40s - loss: 1.2859 - dice: 0.6015 - binary_accuracy: 0.8338 - val_loss: 0.9078 - val_dice: 0.6304 - val_binary_accuracy: 0.8167
# Epoch 23/50
# Epoch 00022: dice improved from 0.60152 to 0.60441, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6549-0.6044---2.hdf5
# Epoch 00022: val_dice improved from 0.64947 to 0.65487, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6549-0.6044---2.hdf5
# 40s - loss: 1.2468 - dice: 0.6044 - binary_accuracy: 0.8335 - val_loss: 0.9003 - val_dice: 0.6549 - val_binary_accuracy: 0.8306
# Epoch 24/50
# Epoch 00023: dice improved from 0.60441 to 0.60665, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6395-0.6066---2.hdf5
# Epoch 00023: val_dice did not improve
# 40s - loss: 1.2352 - dice: 0.6066 - binary_accuracy: 0.8333 - val_loss: 0.9347 - val_dice: 0.6395 - val_binary_accuracy: 0.8444
# Epoch 25/50
# Epoch 00024: dice did not improve
# Epoch 00024: val_dice did not improve
# 39s - loss: 1.2561 - dice: 0.6023 - binary_accuracy: 0.8319 - val_loss: 0.9031 - val_dice: 0.6399 - val_binary_accuracy: 0.8357
# Epoch 26/50
# Epoch 00025: dice improved from 0.60665 to 0.61605, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6344-0.6161---2.hdf5
# Epoch 00025: val_dice did not improve
# 40s - loss: 1.2155 - dice: 0.6161 - binary_accuracy: 0.8433 - val_loss: 0.8847 - val_dice: 0.6344 - val_binary_accuracy: 0.8354
# Epoch 27/50
# Epoch 00026: dice did not improve
# Epoch 00026: val_dice did not improve
# 39s - loss: 1.2584 - dice: 0.6035 - binary_accuracy: 0.8319 - val_loss: 0.8916 - val_dice: 0.6344 - val_binary_accuracy: 0.8362
# Epoch 28/50
# Epoch 00027: dice did not improve
# Epoch 00027: val_dice improved from 0.65487 to 0.65835, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6584-0.6071---2.hdf5
# 40s - loss: 1.2390 - dice: 0.6071 - binary_accuracy: 0.8351 - val_loss: 0.8999 - val_dice: 0.6584 - val_binary_accuracy: 0.8300
# Epoch 29/50
# Epoch 00028: dice did not improve
# Epoch 00028: val_dice did not improve
# 39s - loss: 1.2493 - dice: 0.6113 - binary_accuracy: 0.8366 - val_loss: 0.8767 - val_dice: 0.6509 - val_binary_accuracy: 0.8308
# Epoch 30/50
#
# Epoch 00029: reducing learning rate to 0.00124999997206.
# Epoch 00029: dice did not improve
# Epoch 00029: val_dice improved from 0.65835 to 0.66408, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6641-0.6091---2.hdf5
# 40s - loss: 1.2364 - dice: 0.6091 - binary_accuracy: 0.8366 - val_loss: 0.8703 - val_dice: 0.6641 - val_binary_accuracy: 0.8321
# Epoch 31/50
# Epoch 00030: dice improved from 0.61605 to 0.62111, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6545-0.6211---2.hdf5
# Epoch 00030: val_dice did not improve
# 40s - loss: 1.1959 - dice: 0.6211 - binary_accuracy: 0.8406 - val_loss: 0.8576 - val_dice: 0.6545 - val_binary_accuracy: 0.8277
# Epoch 32/50
# Epoch 00031: dice improved from 0.62111 to 0.62141, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6610-0.6214---2.hdf5
# Epoch 00031: val_dice did not improve
# 40s - loss: 1.1916 - dice: 0.6214 - binary_accuracy: 0.8427 - val_loss: 0.8699 - val_dice: 0.6610 - val_binary_accuracy: 0.8484
# Epoch 33/50
# Epoch 00032: dice improved from 0.62141 to 0.62962, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6436-0.6296---2.hdf5
# Epoch 00032: val_dice did not improve
# 40s - loss: 1.1833 - dice: 0.6296 - binary_accuracy: 0.8489 - val_loss: 0.9282 - val_dice: 0.6436 - val_binary_accuracy: 0.8000
# Epoch 34/50
# Epoch 00033: dice did not improve
# Epoch 00033: val_dice did not improve
# 39s - loss: 1.2124 - dice: 0.6159 - binary_accuracy: 0.8368 - val_loss: 0.8568 - val_dice: 0.6626 - val_binary_accuracy: 0.8254
# Epoch 35/50
# Epoch 00034: dice did not improve
# Epoch 00034: val_dice improved from 0.66408 to 0.66579, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6658-0.6242---2.hdf5
# 40s - loss: 1.1787 - dice: 0.6242 - binary_accuracy: 0.8455 - val_loss: 0.8445 - val_dice: 0.6658 - val_binary_accuracy: 0.8491
# Epoch 36/50
# Epoch 00035: dice improved from 0.62962 to 0.63033, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6618-0.6303---2.hdf5
# Epoch 00035: val_dice did not improve
# 40s - loss: 1.1758 - dice: 0.6303 - binary_accuracy: 0.8472 - val_loss: 0.8292 - val_dice: 0.6618 - val_binary_accuracy: 0.8374
# Epoch 37/50
# Epoch 00036: dice improved from 0.63033 to 0.63640, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6768-0.6364---2.hdf5
# Epoch 00036: val_dice improved from 0.66579 to 0.67681, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6768-0.6364---2.hdf5
# 40s - loss: 1.1499 - dice: 0.6364 - binary_accuracy: 0.8487 - val_loss: 0.8217 - val_dice: 0.6768 - val_binary_accuracy: 0.8407
# Epoch 38/50
# Epoch 00037: dice improved from 0.63640 to 0.63954, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6788-0.6395---2.hdf5
# Epoch 00037: val_dice improved from 0.67681 to 0.67880, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6788-0.6395---2.hdf5
# 40s - loss: 1.1301 - dice: 0.6395 - binary_accuracy: 0.8537 - val_loss: 0.8627 - val_dice: 0.6788 - val_binary_accuracy: 0.8533
# Epoch 39/50
# Epoch 00038: dice did not improve
# Epoch 00038: val_dice did not improve
# 39s - loss: 1.1638 - dice: 0.6349 - binary_accuracy: 0.8509 - val_loss: 0.8577 - val_dice: 0.6575 - val_binary_accuracy: 0.8555
# Epoch 40/50
# Epoch 00039: dice did not improve
# Epoch 00039: val_dice improved from 0.67880 to 0.68587, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6859-0.6334---2.hdf5
# 40s - loss: 1.1506 - dice: 0.6334 - binary_accuracy: 0.8541 - val_loss: 0.8208 - val_dice: 0.6859 - val_binary_accuracy: 0.8415
# Epoch 41/50
# Epoch 00040: dice did not improve
# Epoch 00040: val_dice did not improve
# 39s - loss: 1.1539 - dice: 0.6364 - binary_accuracy: 0.8525 - val_loss: 0.8051 - val_dice: 0.6830 - val_binary_accuracy: 0.8445
# Epoch 42/50
# Epoch 00041: dice improved from 0.63954 to 0.64342, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6763-0.6434---2.hdf5
# Epoch 00041: val_dice did not improve
# 40s - loss: 1.1240 - dice: 0.6434 - binary_accuracy: 0.8576 - val_loss: 0.8450 - val_dice: 0.6763 - val_binary_accuracy: 0.8323
# Epoch 43/50
# Epoch 00042: dice did not improve
# Epoch 00042: val_dice improved from 0.68587 to 0.68817, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6882-0.6405---2.hdf5
# 40s - loss: 1.1390 - dice: 0.6405 - binary_accuracy: 0.8549 - val_loss: 0.7781 - val_dice: 0.6882 - val_binary_accuracy: 0.8538
# Epoch 44/50
# Epoch 00043: dice did not improve
# Epoch 00043: val_dice did not improve
# 39s - loss: 1.1442 - dice: 0.6400 - binary_accuracy: 0.8545 - val_loss: 0.7711 - val_dice: 0.6830 - val_binary_accuracy: 0.8555
# Epoch 45/50
# Epoch 00044: dice did not improve
# Epoch 00044: val_dice did not improve
# 39s - loss: 1.1360 - dice: 0.6410 - binary_accuracy: 0.8542 - val_loss: 0.7849 - val_dice: 0.6649 - val_binary_accuracy: 0.8556
# Epoch 46/50
# Epoch 00045: dice improved from 0.64342 to 0.64725, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6897-0.6472---2.hdf5
# Epoch 00045: val_dice improved from 0.68817 to 0.68973, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6897-0.6472---2.hdf5
# 40s - loss: 1.1128 - dice: 0.6472 - binary_accuracy: 0.8622 - val_loss: 0.7895 - val_dice: 0.6897 - val_binary_accuracy: 0.8450
# Epoch 47/50
# Epoch 00046: dice did not improve
# Epoch 00046: val_dice did not improve
# 39s - loss: 1.1363 - dice: 0.6403 - binary_accuracy: 0.8561 - val_loss: 0.8288 - val_dice: 0.6841 - val_binary_accuracy: 0.8349
# Epoch 48/50
#
# Epoch 00047: reducing learning rate to 0.00062499998603.
# Epoch 00047: dice did not improve
# Epoch 00047: val_dice did not improve
# 39s - loss: 1.1213 - dice: 0.6470 - binary_accuracy: 0.8615 - val_loss: 0.7890 - val_dice: 0.6859 - val_binary_accuracy: 0.8448
# Epoch 49/50
# Epoch 00048: dice improved from 0.64725 to 0.65621, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.6895-0.6562---2.hdf5
# Epoch 00048: val_dice did not improve
# 40s - loss: 1.0893 - dice: 0.6562 - binary_accuracy: 0.8661 - val_loss: 0.7834 - val_dice: 0.6895 - val_binary_accuracy: 0.8463
# Epoch 50/50
# Epoch 00049: dice improved from 0.65621 to 0.65982, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.7014-0.6598---2.hdf5
# Epoch 00049: val_dice improved from 0.68973 to 0.70135, saving model to ../Temp/NewStep/Level-2-loss/V1-UNET-val_dice=0.7014-0.6598---2.hdf5
# 40s - loss: 1.0718 - dice: 0.6598 - binary_accuracy: 0.8680 - val_loss: 0.7222 - val_dice: 0.7014 - val_binary_accuracy: 0.8682
# 2017-07-31 01:50:40.645465

# %%
#!ls ../Temp/TempTempG5M5KFold -la | tail
#!ls ../Temp/TempTempG5M5KFold10 -la | tail
# !ls ../Temp/NewStep/StandartF3 -la | tail
# !ls ../Temp/NewStep/Level-2-loss -la | tail
# Out:
# -rwxrwxrwx 1 boba boba 248917120 июл 30 19:42 V1-UNET-val_dice=0.7426-0.7271---1.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 20:33 V1-UNET-val_dice=0.7449-0.7080---2.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 20:37 V1-UNET-val_dice=0.7482-0.7316---2.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 19:48 V1-UNET-val_dice=0.7500-0.7460---1.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 20:38 V1-UNET-val_dice=0.7502-0.7177---2.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 19:50 V1-UNET-val_dice=0.7510-0.7538---1.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 19:52 V1-UNET-val_dice=0.7516-0.7578---1.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 19:53 V1-UNET-val_dice=0.7528-0.7595---1.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 20:39 V1-UNET-val_dice=0.7613-0.7235---2.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 20:42 V1-UNET-val_dice=0.7655-0.7360---2.hdf5
# -rwxrwxrwx 1 boba boba 15510512 июл 31 01:12 V1-UNET-val_dice=0.6860-0.6772---1.hdf5
# -rwxrwxrwx 1 boba boba 15510512 июл 31 01:15 V1-UNET-val_dice=0.6876-0.6932---1.hdf5
# -rwxrwxrwx 1 boba boba 15510512 июл 31 01:46 V1-UNET-val_dice=0.6882-0.6405---2.hdf5
# -rwxrwxrwx 1 boba boba 15510512 июл 31 01:16 V1-UNET-val_dice=0.6888-0.7004---1.hdf5
# -rwxrwxrwx 1 boba boba 15510512 июл 31 01:50 V1-UNET-val_dice=0.6895-0.6562---2.hdf5
# -rwxrwxrwx 1 boba boba 15510512 июл 31 01:48 V1-UNET-val_dice=0.6897-0.6472---2.hdf5
# -rwxrwxrwx 1 boba boba 15510512 июл 31 01:12 V1-UNET-val_dice=0.6915-0.6747---1.hdf5
# -rwxrwxrwx 1 boba boba 15510512 июл 31 01:13 V1-UNET-val_dice=0.6936-0.6876---1.hdf5
# -rwxrwxrwx 1 boba boba 15510512 июл 31 01:14 V1-UNET-val_dice=0.6990-0.6723---1.hdf5
# -rwxrwxrwx 1 boba boba 15510512 июл 31 01:50 V1-UNET-val_dice=0.7014-0.6598---2.hdf5

# %%
if 0 : model10 = load_model('../Temp/TrainModel001+G+M/V1-UNET-0.8511.hdf5')
if 0 : model10 = load_model('../Temp/V1-UNET-0.8853.hdf5')
#if 1 : model10 = load_model('../Temp/TempTempM3/V1-UNET-0.9054.hdf5')
if 0 : model10.load_weights('../Temp/TempTempM3/V1-UNET-0.9054.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5/V1-UNET-val_dice=0.7307.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7879-2.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7632-2.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7660-2.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7828-2.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFold5/V1-UNET-val_dice=0.8224-0.8516---1.hdf5') # 769128
if 0 : model10.load_weights('../Temp/TempTempG5M5KFold5/V1-UNET-val_dice=0.8217-0.8655---1.hdf5') # 765XXX
if 0 : model10.load_weights('../Temp/TempTempG5M5KFold5/V1-UNET-val_dice=0.8227-0.8643---3.hdf5')    
if 0 : model10.load_weights('../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8315-0.8617---9.hdf5')    
if 0 : model10.load_weights('../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7655-0.7360---2.hdf5')    
if 0 : model10.load_weights('../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7561-0.7261---2.hdf5')

# %%
# %time trP = model10.predict(trX,batch_size=batch_size)
# Out:
# CPU times: user 9.96 s, sys: 2.32 s, total: 12.3 s
# Wall time: 11.7 s

# %%
trP01 = trP
trP01[trP>0.5] =1.0
trP01[trP<=0.5]=0.0
trP01 = trP01.astype(np.uint8)

# %%
if 0 : # Ощутимых результатов не дает, увеличение в +10-100
    times, medianP = 3,5
    for i in range(trP01.shape[0]) :
        for j in range(times) :
            trP01[i,:,:,0] = cv.medianBlur(trP01[i],medianP)

# %%
iii = 0
print(trX[0].shape,trY[0].shape,trP.shape,trP.min(),trP.max())
for ii in range(iii,iii+10) :
    plt.figure(figsize=(15,5))
    plt.subplot(151); plt.imshow(trX[ii,:,:,0],'gray'); 
    plt.subplot(152); plt.imshow(trY[ii,:,:,0],'gray'); 
    plt.subplot(153); plt.imshow(trP[ii,:,:,0],'gray'); 
    plt.subplot(154); plt.imshow(trP01[ii,:,:,0],'gray'); 
    plt.subplot(155); plt.hist(trP[ii,:,:,0].ravel(),bins=50); 
    plt.show()
plt.close()
# Out:
# (512, 512, 3) (512, 512, 1) (168, 512, 512, 1) 0.0 1.0

# %%
# Calculate F1-micro

# %%
TP = (trY[:,6:506,6:506,0]*trP01[:,6:506,6:506,0]).sum()
TN = ((1.0-trY[:,6:506,6:506,0])*(1.0-trP01[:,6:506,6:506,0])).sum()
FP = ((trY[:,6:506,6:506,0])*(1.0-trP01[:,6:506,6:506,0])).sum()
FN = ((1.0-trY[:,6:506,6:506,0])*(trP01[:,6:506,6:506,0])).sum()

P  = TP/(TP+FP) if (TP+FP)>0.0 else 1.0
R  = TP/(TP+FN) if (TP+FN)>0.0 else 0.0

F1 = 2.0*P*R/(P+R) if (P+R)>0.0 else 0.0

TP,TN,FP,FN,P,R,F1
#P*R,P+R, 2.0*P*R/(P+R)
# Out:
# (12329286.0,
#  23941804.0,
#  1758934.0,
#  3969976.0,
#  0.87514859932624567,
#  0.75643216238870203,
#  0.81147138153796361)

# %%
# Calculate DI- dice.mean()

# %%
dice, XX = [],[]
for i in range(trP.shape[0]) :
    G = trY  [i,6:506,6:506,0].sum()
    S = trP01[i,6:506,6:506,0].sum()
    X = (trY [i,6:506,6:506,0]*trP01[i,6:506,6:506,0]).sum()
    XX.append(X)
    dice.append((2.0*X/(G+S) if G+S>0 else 1.0))
di = (np.array(dice)).mean()
di #,np.array(dice)  #,np.array(XX)
# Out:
# 0.7326046640554621

# %%
plt.hist(np.array(dice),bins=40); plt.show()
plt.plot(np.array(dice)); plt.show()

# %%
1000000*(F1+di)/2.0
# Out:
# 772038.02279671282

# %%
#np.array(dice)<0.4

# %%
# Подготовка test решения

# %%
if flagGray :
    trO, trO0 = [], np.zeros((512,512,1))
else :
    trO, trO0 = [], np.zeros((512,512,3))

for xx in listTest :
    img = cv.imread(os.path.join(dirTest,xx),-1)
    if 1 and (Gauss or Median): 
        for cc in range(img.shape[2]) : 
            if Gauss  : img[:,:,cc] = cv.GaussianBlur(img[:,:,cc],(Gauss,Gauss),0);
            if Median : img[:,:,cc] = cv.medianBlur  (img[:,:,cc],Median);
    #print(img.mean(),msk.mean())
    if flagGray :
        img = cv.cvtColor(img,cv.COLOR_RGB2GRAY);
        trO0[6:506,6:506,0] = img[:,:]/255.0
    else :
        trO0[6:506,6:506,:] = img[:,:,:]/255.0
    trO.append(trO0.copy())
    #print(trX0.mean(),trY0.mean(),trX1[-1].mean(),trY1[-1].mean())

#print([trY[xx].mean() for xx in range(10)])
trO = np.array(trO)

if 1 :
    for cc in range(meanX.shape[0]) : 
        trO[:,6:506,6:506,cc] -= meanX[cc]
    
trO.shape, trO.min(), trO.max()
#[trY[xx].mean() for xx in range(10)]
# Out:
# ((162, 512, 512, 3), -0.64172901643310909, 0.47912580261435694)

# %%
# %time trOP = model10.predict(trO,batch_size=batch_size)
# Out:
# CPU times: user 14.9 s, sys: 3.18 s, total: 18.1 s
# Wall time: 17.4 s

# %%
trOP01 = trOP
trOP01[trOP>0.5] =1.0
trOP01[trOP<=0.5]=0.0

# %%
iii = 40
print(trO[0].shape,trP01[0].shape,trOP01.shape,trOP.min(),trOP.max())
for ii in range(iii,iii+10) :
    plt.figure(figsize=(15,5))
    plt.subplot(151); plt.imshow(trO[ii,:,:,0]); 
    plt.subplot(152); plt.imshow(trOP01[ii,:,:,0],'gray'); 
    plt.subplot(153); plt.imshow(trOP[ii,:,:,0],'gray'); 
    plt.subplot(154); plt.hist(trOP[ii,:,:,0].ravel(),bins=50); 
    plt.show()
plt.close()
# Out:
# (512, 512, 3) (512, 512, 1) (162, 512, 512, 1) 0.0 1.0

# %%
# Формирование выходной директории

# %%
def convert_to_binary(truth_png_file, truth_txt_file):
    im = Image.open(truth_png_file) #Can be many different formats.
    pix = im.load()
    with open(truth_txt_file, 'w') as out:
        for x in xrange(500):
            for y in xrange(500):
                out.write(str(int(pix[x, y] > 0)))
            out.write('\n')

if not os.path.exists('../Temp/random_submission'):
    os.makedirs('../Temp/random_submission')

# Training
for i in range(len(listTrain)) :
    fn = listTrain[i]
    truth_txt_file = '../Temp/random_submission/' + fn.split('.')[0] + '_mask.txt'
    with open(truth_txt_file, 'w') as out:
        for x in xrange(500):
            for y in xrange(500):
                out.write(str(int(trP01[i,y+6, x+6] > 0.0)))
            out.write('\n')
    out.close()
    
# Testing
for i in range(len(listTest)) :
    fn = listTest[i]
    truth_txt_file = '../Temp/random_submission/' + fn.split('.')[0] + '_mask.txt'
    with open(truth_txt_file, 'w') as out:
        for x in xrange(500):
            for y in xrange(500):
                out.write(str(int(trOP01[i,y+6, x+6] > 0.0)))
            out.write('\n')
    out.close()

# %%
import shutil

# %%
xx=shutil.make_archive('../Result/topcoderkonica','zip','../Temp/random_submission')
xx
# Out:
# '/media/boba/DATA/boba/Working/TopCoder/2017-07-25-Konica-Minolta/Result/topcoderkonica.zip'

# %%
# !ls ../Temp -la
# Out:
# total 4610508
# drwxrwxrwx 1 boba boba      4096 июл 26 10:58 .
# drwxrwxrwx 1 boba boba      4096 июл 26 10:11 ..
# drwxrwxrwx 1 boba boba         0 июл 25 18:17 .ipynb_checkpoints
# drwxrwxrwx 1 boba boba     61440 июл 26 09:14 random_submission
# -rwxrwxrwx 1 boba boba   1057596 июл 26 10:58 random_submission.zip
# drwxrwxrwx 1 boba boba         0 июл 25 23:35 TrainModel001-G-M
# drwxrwxrwx 1 boba boba         0 июл 25 22:21 TrainModel001-G+M
# drwxrwxrwx 1 boba boba         0 июл 25 21:48 TrainModel001+G-M
# drwxrwxrwx 1 boba boba      4096 июл 25 21:05 TrainModel001+G+M
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:02 V1-UNET-0.8167.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:08 V1-UNET-0.8275.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 18:33 V1-UNET-0.8305.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 18:02 V1-UNET-0.8418.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:09 V1-UNET-0.8486.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:09 V1-UNET-0.8593.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 18:34 V1-UNET-0.8601.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:21 V1-UNET-0.8602.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:22 V1-UNET-0.8605.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:35 V1-UNET-0.8628.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:35 V1-UNET-0.8633.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:23 V1-UNET-0.8635.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:36 V1-UNET-0.8645.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:36 V1-UNET-0.8652.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:24 V1-UNET-0.8655.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:11 V1-UNET-0.8793.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:13 V1-UNET-0.8796.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:14 V1-UNET-0.8808.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 18:02 V1-UNET-0.8853.hdf5

# %%
# !ls ../Work -la
#!ls ../Temp/random_submission
# Out:
# total 80768
# drwxrwxrwx 1 boba boba        0 июл 26 09:17 .
# drwxrwxrwx 1 boba boba     4096 июл 25 15:24 ..
# -rwxrwxrwx 1 boba boba 82700662 июл 26 09:32 topcoderkonica.zip

# %%
if False :
    save_model(model10,'../Data-Keras/Models/model-UNet.h5')
    model10.save_weights('../Data-Keras/Models/model-UNet-weights.h5')

# %%
rrr=pd.DataFrame(res,columns=['image_name','tags']); rrr.head(); 
suffixDT = (datetime.datetime.now()).strftime('%Y-%m-%d-%H-%M-%S'); print(suffixDT)
rrr.to_csv('../Result/vss'+suffixDT+'.csv',index=False);
# Out:
# 2017-05-20-05-51-18
