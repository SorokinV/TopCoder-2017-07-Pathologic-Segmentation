# %%
##
## UNet 
##
## Взята идея по описанию из https://github.com/pietz/unet-keras
##
##
## 2017-07-28
##   Добавлены flip+rotation LB=760393
##
## 2017-07-29
##   LB=769123
##
## 2017-07-30
##   LB=772342
##

# %%
import sys,os,datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import fbeta_score
import sklearn.metrics as skm
from __future__ import print_function

# %%
print(np.__version__);
print(pd.__version__);
# Out:
# 1.13.1
# 0.19.2

# %%
import  cv2 as cv
cv.__version__
# Out:
# '3.2.0'

# %%
#from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.models import Sequential, save_model, load_model, Input, Model
from keras.layers import Convolution2D, MaxPooling2D, Convolution1D, MaxPooling1D, UpSampling2D, ZeroPadding2D
from keras.layers import Conv2D, Concatenate, Reshape
from keras.layers import Activation, Dropout, Flatten, Dense, Permute
from keras.layers.normalization import BatchNormalization
import keras.optimizers
from keras.callbacks import EarlyStopping,ReduceLROnPlateau,ModelCheckpoint
import keras.backend as K
# Out:
# Using TensorFlow backend.

# %%
keras.__version__
# Out:
# '2.0.6'

# %%
#---------------------------------------------------------------------

# %%
# !ls -la ..
#!ls -la ../Data
#!ls -la ../Data/training
# Out:
# total 25
# drwxrwxrwx 1 boba boba 4096 июл 26 11:10 .
# drwxrwxrwx 1 boba boba    0 июл 25 09:21 ..
# drwxrwxrwx 1 boba boba 4096 июл 25 09:23 Data
# drwxrwxrwx 1 boba boba    0 июл 25 09:22 Data-Arch
# drwxrwxrwx 1 boba boba    0 июл 25 09:26 Data-Keras
# drwxrwxrwx 1 boba boba 4096 июл 29 22:07 .git
# -rwxrwxrwx 2 boba boba  130 июл  9 12:02 .gitignore
# drwxrwxrwx 1 boba boba    0 июл 26 10:11 .ipynb_checkpoints
# drwxrwxrwx 1 boba boba  280 июл 29 22:07 Jupyter
# drwxrwxrwx 1 boba boba 4096 июл 29 22:09 Jupyter-Net
# drwxrwxrwx 1 boba boba 4096 июл 29 22:06 Result
# drwxrwxrwx 1 boba boba 4096 июл 29 22:02 Temp
# drwxrwxrwx 1 boba boba    0 июл 27 07:53 Work

# %%
dirData = '../Data'
dirTemp = '../Temp'
dirWork = '../Work'

dirTest  = os.path.join(dirData,'testing','images')
dirTrain = os.path.join(dirData,'training','images')
dirMask  = os.path.join(dirData,'training','truth')

# %%
listTrain = os.listdir(dirTrain)
listMask  = os.listdir(dirMask)
listTest  = os.listdir(dirTest)
listTrain = [xx for xx in listTrain if os.path.splitext(xx)[1]=='.tif']
listMask  = [xx for xx in listMask  if os.path.splitext(xx)[1]=='.png']
listTest  = [xx for xx in listTest  if os.path.splitext(xx)[1]=='.tif']
print(len(listTrain),len(listMask),len(listTest))
print(listTrain[:5],'\n',listMask[:5],'\n',listTest[:5])
# Out:
# 168 168 162
# ['i105404.tif', 'i117557.tif', 'i124017.tif', 'i130790.tif', 'i137857.tif']
#  ['i105404_mask.png', 'i117557_mask.png', 'i124017_mask.png', 'i130790_mask.png', 'i137857_mask.png']
#  ['i105047.tif', 'i116596.tif', 'i137649.tif', 'i140176.tif', 'i142099.tif']

# %%
if 0 :
    for xx in listTrain[:5] :
        img = cv.imread(os.path.join(dirTrain,xx),-1)
        xxm = os.path.splitext(xx)[0]+"_mask.png"
        msk = cv.imread(os.path.join(dirMask,xxm),-1)
        plt.subplot(121); plt.imshow(img); plt.subplot(122); plt.imshow(msk,'gray'); plt.show()
    plt.close()

# %%
msk.shape, img.shape, img.min(), img.max(), msk.max(), #img[6:10,6:10], msk[6:10,6:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-051c9d5448bc> in <module>()
# ----> 1 msk.shape, img.shape, img.min(), img.max(), msk.max(), #img[6:10,6:10], msk[6:10,6:10]
#
# NameError: name 'msk' is not defined

# %%
flagGray = False
Gauss    = 5
Median   = 5
if flagGray :
    trX, trY, trX0, trY0 = [], [], np.zeros((512,512,1)), np.zeros((512,512,1))
else :
    trX, trY, trX0, trY0 = [], [], np.zeros((512,512,3)), np.zeros((512,512,1))

for xx in listTrain :
    img = cv.imread(os.path.join(dirTrain,xx),-1)
    if 1 and (Gauss or Median): 
        for cc in range(img.shape[2]) : 
            if Gauss  : img[:,:,cc] = cv.GaussianBlur(img[:,:,cc],(Gauss,Gauss),0);
            if Median : img[:,:,cc] = cv.medianBlur  (img[:,:,cc],Median);
    xxm = os.path.splitext(xx)[0]+"_mask.png"
    msk = cv.imread(os.path.join(dirMask,xxm),-1)
    #print(img.mean(),msk.mean())
    if flagGray :
        img = cv.cvtColor(img,cv.COLOR_RGB2GRAY);
        trX0[6:506,6:506,0] = img[:,:]/255.0
        trY0[6:506,6:506,0] = msk[:,:]/255.0
    else :
        trX0[6:506,6:506,:] = img[:,:,:]/255.0
        trY0[6:506,6:506,0] = msk[:,:]/255.0
        trY0[trY0>=0.5] = 1.0
    trX.append(trX0.copy())
    trY.append(trY0.copy())
    #print(trX0.mean(),trY0.mean(),trX1[-1].mean(),trY1[-1].mean())

#print([trY[xx].mean() for xx in range(10)])
trX = np.array(trX)
trY = np.array(trY)

# аугментация
trXX, trYY = trX.copy(), trY.copy()

# flipping
for f in range(-1,2) :
    trXXX, trYYY = trX.copy(), trY.copy()
    for p in range(trXXX.shape[0]) :
        trXXX[p], trYYY[p,:,:,0] = cv.flip(trXXX[p],f), cv.flip(trYYY[p,:,:,0],f)
    trXX = np.vstack([trXX,trXXX])
    trYY = np.vstack([trYY,trYYY])
    print('flip :',f,trXX.shape,trYY.shape)
    
# rotate +-90

# rotate +90
trXXX, trYYY = trX.copy(), trY.copy()
for p in range(trX.shape[0]) :
    for i in range(trX.shape[1]) :
        for j in range(trX.shape[2]) :
            trXXX[p,i,j,:] = trX[p,j,trX.shape[1]-i-1]
            trYYY[p,i,j,:] = trY[p,j,trY.shape[1]-i-1]
trXX = np.vstack([trXX,trXXX])
trYY = np.vstack([trYY,trYYY])
print('rotate +90:',trXX.shape,trYY.shape)

# rotate -90
trXXX, trYYY = trX.copy(), trY.copy()
for p in range(trX.shape[0]) :
    for i in range(trX.shape[1]) :
        for j in range(trX.shape[2]) :
            trXXX[p,i,j,:] = trX[p,trX.shape[2]-j-1,i]
            trYYY[p,i,j,:] = trY[p,trY.shape[2]-j-1,i]
trXX = np.vstack([trXX,trXXX])
trYY = np.vstack([trYY,trYYY])
print('rotate -90:',trXX.shape,trYY.shape)
    
trX, trY = trXX.copy(), trYY.copy()
del trXX,trXXX,trYY,trYYY

# Считаем среднее по каналам и вычитаем из изображений
meanX = (trX[:,6:-6,6:-6,:].mean(axis=(1,2))).mean(axis=0)
stdX  = (trX[:,6:-6,6:-6,:].mean(axis=(1,2))).std(axis=0)
for cc in range(meanX.shape[0]) : 
    trX[:,6:-6,6:-6,cc] -= meanX[cc]    
print("mean={} std={}".format(meanX,stdX))
    
trX.shape, trX.min(), trX.max(), trY.shape, trY.min(), trY.max()
#[trY[xx].mean() for xx in range(10)]
# Out:
# flip : -1 (336, 512, 512, 3) (336, 512, 512, 1)
# flip : 0 (504, 512, 512, 3) (504, 512, 512, 1)
# flip : 1 (672, 512, 512, 3) (672, 512, 512, 1)
# rotate +90: (840, 512, 512, 3) (840, 512, 512, 1)
# rotate -90: (1008, 512, 512, 3) (1008, 512, 512, 1)
# mean=[ 0.6473997   0.48950165  0.70839568] std=[ 0.06249822  0.09179847  0.08778627]
# ((1008, 512, 512, 3),
#  -0.62212117329585415,
#  0.48696893986925888,
#  (1008, 512, 512, 1),
#  0.0,
#  1.0)

# %%
for xx in range(5) :
    img = trX[xx]
    xxm = trY[xx]
    plt.subplot(121); plt.imshow(img); plt.subplot(122); plt.imshow(xxm[:,:,0],'gray'); plt.show()
plt.close()

# %%
#
# model UNET
#
#    https://github.com/pietz/unet-keras
#
#

def level_block(m, dim, depth, acti, dropout=0.25, batch=True):
    if depth > 0:
        
        x = m
        if batch : x = BatchNormalization()(x)
        n = Conv2D(dim, (3, 3), activation=acti, padding='same')(x) #(m)
        n = Conv2D(dim, (3, 3), activation=acti, padding='same')(n)
        if dropout : n = Dropout(dropout)(n) ## add
        m = MaxPooling2D((2, 2))(n)
        m = level_block(m, 2*dim, depth-1, acti, dropout=dropout, batch=batch)
        m = UpSampling2D((2, 2))(m)
        m = Conv2D(dim, (2, 2), activation=acti, padding='same', kernel_initializer='he_normal')(m)
        if dropout : m = Dropout(dropout)(m) ## add
        m = Concatenate(axis=3)([n, m])
    m = Conv2D(dim, (3, 3), activation=acti, padding='same')(m)
    return Conv2D(dim, (3, 3), activation=acti, padding='same')(m)

def UNet(img_shape, n_out=2, dim=32, depth=5, acti='relu', flatten=False, dropout=0.25, batch=True):
    i = Input(shape=img_shape)
    ## ???? i = ZeroPadding2D((6,6),data_format="channels_last")
    o = level_block(i, dim, depth, acti, dropout=dropout, batch=batch)
    o = Conv2D(n_out, (1, 1), name='prediction')(o)
    if flatten:
        o = Reshape(n_out, img_shape[0] * img_shape[1])(o)
        o = Permute((2, 1))(o)
    #o = Activation('relu')(o)
    if batch : o = BatchNormalization()(o)  ######
    o = Activation('sigmoid')(o)
    return Model(inputs=i, outputs=o)

# %%
model10 = UNet((512,512,3),depth=5,n_out=1, dropout=0.05)
model10.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 512, 512, 3)   0
# ____________________________________________________________________________________________________
# batch_normalization_1 (BatchNorm (None, 512, 512, 3)   12          input_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_1 (Conv2D)                (None, 512, 512, 32)  896         batch_normalization_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_2 (Conv2D)                (None, 512, 512, 32)  9248        conv2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 512, 512, 32)  0           conv2d_2[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)   (None, 256, 256, 32)  0           dropout_1[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_2 (BatchNorm (None, 256, 256, 32)  128         max_pooling2d_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_3 (Conv2D)                (None, 256, 256, 64)  18496       batch_normalization_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_4 (Conv2D)                (None, 256, 256, 64)  36928       conv2d_3[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)              (None, 256, 256, 64)  0           conv2d_4[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)   (None, 128, 128, 64)  0           dropout_2[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_3 (BatchNorm (None, 128, 128, 64)  256         max_pooling2d_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_5 (Conv2D)                (None, 128, 128, 128) 73856       batch_normalization_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_6 (Conv2D)                (None, 128, 128, 128) 147584      conv2d_5[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)              (None, 128, 128, 128) 0           conv2d_6[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)   (None, 64, 64, 128)   0           dropout_3[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_4 (BatchNorm (None, 64, 64, 128)   512         max_pooling2d_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_7 (Conv2D)                (None, 64, 64, 256)   295168      batch_normalization_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_8 (Conv2D)                (None, 64, 64, 256)   590080      conv2d_7[0][0]
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)              (None, 64, 64, 256)   0           conv2d_8[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)   (None, 32, 32, 256)   0           dropout_4[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_5 (BatchNorm (None, 32, 32, 256)   1024        max_pooling2d_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_9 (Conv2D)                (None, 32, 32, 512)   1180160     batch_normalization_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_10 (Conv2D)               (None, 32, 32, 512)   2359808     conv2d_9[0][0]
# ____________________________________________________________________________________________________
# dropout_5 (Dropout)              (None, 32, 32, 512)   0           conv2d_10[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)   (None, 16, 16, 512)   0           dropout_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_11 (Conv2D)               (None, 16, 16, 1024)  4719616     max_pooling2d_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_12 (Conv2D)               (None, 16, 16, 1024)  9438208     conv2d_11[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)   (None, 32, 32, 1024)  0           conv2d_12[0][0]
# ____________________________________________________________________________________________________
# conv2d_13 (Conv2D)               (None, 32, 32, 512)   2097664     up_sampling2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_6 (Dropout)              (None, 32, 32, 512)   0           conv2d_13[0][0]
# ____________________________________________________________________________________________________
# concatenate_1 (Concatenate)      (None, 32, 32, 1024)  0           dropout_5[0][0]
#                                                                    dropout_6[0][0]
# ____________________________________________________________________________________________________
# conv2d_14 (Conv2D)               (None, 32, 32, 512)   4719104     concatenate_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_15 (Conv2D)               (None, 32, 32, 512)   2359808     conv2d_14[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)   (None, 64, 64, 512)   0           conv2d_15[0][0]
# ____________________________________________________________________________________________________
# conv2d_16 (Conv2D)               (None, 64, 64, 256)   524544      up_sampling2d_2[0][0]
# ____________________________________________________________________________________________________
# dropout_7 (Dropout)              (None, 64, 64, 256)   0           conv2d_16[0][0]
# ____________________________________________________________________________________________________
# concatenate_2 (Concatenate)      (None, 64, 64, 512)   0           dropout_4[0][0]
#                                                                    dropout_7[0][0]
# ____________________________________________________________________________________________________
# conv2d_17 (Conv2D)               (None, 64, 64, 256)   1179904     concatenate_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_18 (Conv2D)               (None, 64, 64, 256)   590080      conv2d_17[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)   (None, 128, 128, 256) 0           conv2d_18[0][0]
# ____________________________________________________________________________________________________
# conv2d_19 (Conv2D)               (None, 128, 128, 128) 131200      up_sampling2d_3[0][0]
# ____________________________________________________________________________________________________
# dropout_8 (Dropout)              (None, 128, 128, 128) 0           conv2d_19[0][0]
# ____________________________________________________________________________________________________
# concatenate_3 (Concatenate)      (None, 128, 128, 256) 0           dropout_3[0][0]
#                                                                    dropout_8[0][0]
# ____________________________________________________________________________________________________
# conv2d_20 (Conv2D)               (None, 128, 128, 128) 295040      concatenate_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_21 (Conv2D)               (None, 128, 128, 128) 147584      conv2d_20[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)   (None, 256, 256, 128) 0           conv2d_21[0][0]
# ____________________________________________________________________________________________________
# conv2d_22 (Conv2D)               (None, 256, 256, 64)  32832       up_sampling2d_4[0][0]
# ____________________________________________________________________________________________________
# dropout_9 (Dropout)              (None, 256, 256, 64)  0           conv2d_22[0][0]
# ____________________________________________________________________________________________________
# concatenate_4 (Concatenate)      (None, 256, 256, 128) 0           dropout_2[0][0]
#                                                                    dropout_9[0][0]
# ____________________________________________________________________________________________________
# conv2d_23 (Conv2D)               (None, 256, 256, 64)  73792       concatenate_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_24 (Conv2D)               (None, 256, 256, 64)  36928       conv2d_23[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)   (None, 512, 512, 64)  0           conv2d_24[0][0]
# ____________________________________________________________________________________________________
# conv2d_25 (Conv2D)               (None, 512, 512, 32)  8224        up_sampling2d_5[0][0]
# ____________________________________________________________________________________________________
# dropout_10 (Dropout)             (None, 512, 512, 32)  0           conv2d_25[0][0]
# ____________________________________________________________________________________________________
# concatenate_5 (Concatenate)      (None, 512, 512, 64)  0           dropout_1[0][0]
#                                                                    dropout_10[0][0]
# ____________________________________________________________________________________________________
# conv2d_26 (Conv2D)               (None, 512, 512, 32)  18464       concatenate_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_27 (Conv2D)               (None, 512, 512, 32)  9248        conv2d_26[0][0]
# ____________________________________________________________________________________________________
# prediction (Conv2D)              (None, 512, 512, 1)   33          conv2d_27[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_6 (BatchNorm (None, 512, 512, 1)   4           prediction[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 512, 512, 1)   0           batch_normalization_6[0][0]
# ====================================================================================================
# Total params: 31,096,433
# Trainable params: 31,095,465
# Non-trainable params: 968
# ____________________________________________________________________________________________________

# %%
def dice (truth,pred) :
    g, s = K.sum(truth), K.sum(pred)
    x    = K.sum((truth*pred))
    return((1.0 if K.sum(g+s)==0.0 else 2.0*x/(g+s+K.epsilon())))

def f1 (truth,pred) :
    TP = K.sum(truth*pred)
    TN = K.sum((1.0-truth)*(1.0-pred))
    FP = K.sum(truth*(1.0-pred))
    FN = K.sum((1.0-truth)*pred)

    
    P  = 1.0 if K.sum(TP+FP)==0.0 else TP/(TP+FP)
    R  = 0.0 if K.sum(TP+FN)==0.0 else TP/(TP+FN) 

    F1 = 0.0 if K.sum(P+R)  ==0.0 else 2.0*P*R/(P+R)

    return(F1)

def f1dice (truth,pred) :
    return ((dice(truth,pred)+f1(truth,pred))/2.0)
    
def lossdice (truth,pred) :
    return(1.0 - dice(truth,pred))

def lossfd (truth,pred) :
    return(1.0 - f1dice(truth,pred))

# %%
def buildModel (input_shape) :
    model = UNet(input_shape,depth=5,n_out=1,dropout=0.05,batch=False)
    
    sgd = keras.optimizers.SGD(lr=0.01, momentum=0.9, nesterov=True)
    #model.compile(loss='mean_absolute_error',  #'binary_crossentropy',
    model.compile(loss=lossdice, #'mean_absolute_error',  #'binary_crossentropy',
                  optimizer=sgd, #sgd, #"adam", #'rmsprop',
                  metrics=[dice,'binary_accuracy']) #['binary_accuracy']) #[fbeta_pred]) #['accuracy',fbeta_pred]) #['accuracy'])
    return(model)

# %%
K.clear_session()
model10 = buildModel((trX.shape[1],trX.shape[2],trX.shape[3]))
model10.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 512, 512, 3)   0
# ____________________________________________________________________________________________________
# conv2d_1 (Conv2D)                (None, 512, 512, 32)  896         input_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_2 (Conv2D)                (None, 512, 512, 32)  9248        conv2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 512, 512, 32)  0           conv2d_2[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)   (None, 256, 256, 32)  0           dropout_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_3 (Conv2D)                (None, 256, 256, 64)  18496       max_pooling2d_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_4 (Conv2D)                (None, 256, 256, 64)  36928       conv2d_3[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)              (None, 256, 256, 64)  0           conv2d_4[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)   (None, 128, 128, 64)  0           dropout_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_5 (Conv2D)                (None, 128, 128, 128) 73856       max_pooling2d_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_6 (Conv2D)                (None, 128, 128, 128) 147584      conv2d_5[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)              (None, 128, 128, 128) 0           conv2d_6[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)   (None, 64, 64, 128)   0           dropout_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_7 (Conv2D)                (None, 64, 64, 256)   295168      max_pooling2d_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_8 (Conv2D)                (None, 64, 64, 256)   590080      conv2d_7[0][0]
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)              (None, 64, 64, 256)   0           conv2d_8[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)   (None, 32, 32, 256)   0           dropout_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_9 (Conv2D)                (None, 32, 32, 512)   1180160     max_pooling2d_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_10 (Conv2D)               (None, 32, 32, 512)   2359808     conv2d_9[0][0]
# ____________________________________________________________________________________________________
# dropout_5 (Dropout)              (None, 32, 32, 512)   0           conv2d_10[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)   (None, 16, 16, 512)   0           dropout_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_11 (Conv2D)               (None, 16, 16, 1024)  4719616     max_pooling2d_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_12 (Conv2D)               (None, 16, 16, 1024)  9438208     conv2d_11[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)   (None, 32, 32, 1024)  0           conv2d_12[0][0]
# ____________________________________________________________________________________________________
# conv2d_13 (Conv2D)               (None, 32, 32, 512)   2097664     up_sampling2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_6 (Dropout)              (None, 32, 32, 512)   0           conv2d_13[0][0]
# ____________________________________________________________________________________________________
# concatenate_1 (Concatenate)      (None, 32, 32, 1024)  0           dropout_5[0][0]
#                                                                    dropout_6[0][0]
# ____________________________________________________________________________________________________
# conv2d_14 (Conv2D)               (None, 32, 32, 512)   4719104     concatenate_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_15 (Conv2D)               (None, 32, 32, 512)   2359808     conv2d_14[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)   (None, 64, 64, 512)   0           conv2d_15[0][0]
# ____________________________________________________________________________________________________
# conv2d_16 (Conv2D)               (None, 64, 64, 256)   524544      up_sampling2d_2[0][0]
# ____________________________________________________________________________________________________
# dropout_7 (Dropout)              (None, 64, 64, 256)   0           conv2d_16[0][0]
# ____________________________________________________________________________________________________
# concatenate_2 (Concatenate)      (None, 64, 64, 512)   0           dropout_4[0][0]
#                                                                    dropout_7[0][0]
# ____________________________________________________________________________________________________
# conv2d_17 (Conv2D)               (None, 64, 64, 256)   1179904     concatenate_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_18 (Conv2D)               (None, 64, 64, 256)   590080      conv2d_17[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)   (None, 128, 128, 256) 0           conv2d_18[0][0]
# ____________________________________________________________________________________________________
# conv2d_19 (Conv2D)               (None, 128, 128, 128) 131200      up_sampling2d_3[0][0]
# ____________________________________________________________________________________________________
# dropout_8 (Dropout)              (None, 128, 128, 128) 0           conv2d_19[0][0]
# ____________________________________________________________________________________________________
# concatenate_3 (Concatenate)      (None, 128, 128, 256) 0           dropout_3[0][0]
#                                                                    dropout_8[0][0]
# ____________________________________________________________________________________________________
# conv2d_20 (Conv2D)               (None, 128, 128, 128) 295040      concatenate_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_21 (Conv2D)               (None, 128, 128, 128) 147584      conv2d_20[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)   (None, 256, 256, 128) 0           conv2d_21[0][0]
# ____________________________________________________________________________________________________
# conv2d_22 (Conv2D)               (None, 256, 256, 64)  32832       up_sampling2d_4[0][0]
# ____________________________________________________________________________________________________
# dropout_9 (Dropout)              (None, 256, 256, 64)  0           conv2d_22[0][0]
# ____________________________________________________________________________________________________
# concatenate_4 (Concatenate)      (None, 256, 256, 128) 0           dropout_2[0][0]
#                                                                    dropout_9[0][0]
# ____________________________________________________________________________________________________
# conv2d_23 (Conv2D)               (None, 256, 256, 64)  73792       concatenate_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_24 (Conv2D)               (None, 256, 256, 64)  36928       conv2d_23[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)   (None, 512, 512, 64)  0           conv2d_24[0][0]
# ____________________________________________________________________________________________________
# conv2d_25 (Conv2D)               (None, 512, 512, 32)  8224        up_sampling2d_5[0][0]
# ____________________________________________________________________________________________________
# dropout_10 (Dropout)             (None, 512, 512, 32)  0           conv2d_25[0][0]
# ____________________________________________________________________________________________________
# concatenate_5 (Concatenate)      (None, 512, 512, 64)  0           dropout_1[0][0]
#                                                                    dropout_10[0][0]
# ____________________________________________________________________________________________________
# conv2d_26 (Conv2D)               (None, 512, 512, 32)  18464       concatenate_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_27 (Conv2D)               (None, 512, 512, 32)  9248        conv2d_26[0][0]
# ____________________________________________________________________________________________________
# prediction (Conv2D)              (None, 512, 512, 1)   33          conv2d_27[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 512, 512, 1)   0           prediction[0][0]
# ====================================================================================================
# Total params: 31,094,497
# Trainable params: 31,094,497
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
#model10.load_weights('../Data-Keras/Models/model-UNet-weights.h5', by_name=False)
batch_size = 1

# %%
epochs     = 150
verbose    = 2
batch_size = 1
metric     = 'binary_accuracy'
metric     = 'dice'

############trX, trY = trX[0:30], trY[0:30]

folds      = 10
foldN      = trX.shape[0]/folds+1

print(datetime.datetime.now(),'Training with folds')

#for i in range(folds) :
for i in range(8,11) :

    print(datetime.datetime.now(),'------------>',i)

    K.clear_session()
    model10 = buildModel((trX.shape[1],trX.shape[2],trX.shape[3]))
    ############if 1 : model10.load_weights('../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7660-2.hdf5')

#    early_stopping = EarlyStopping(monitor='val_loss', patience=10,min_delta=0.0001,verbose=1)
    early_stopping = EarlyStopping(monitor='loss', patience=5,min_delta=0.0001,verbose=1)
    reduce_lr1     = ReduceLROnPlateau(monitor='val_loss', factor=0.5,patience=3, min_lr=0.0000001,verbose=1)
    reduce_lr2     = ReduceLROnPlateau(monitor='loss',     factor=0.5,patience=3, min_lr=0.0000001,verbose=1)

    filepath="../Temp/TempTempG5M5KFold10/V1-UNET-val_"+metric+"={val_"+metric+":.4f}-{"+metric+":.4f}---"+str(i)+".hdf5"
    #checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
    checkpoint1 = ModelCheckpoint(filepath, monitor=metric,        verbose=1, save_best_only=True, mode='max')
    checkpoint2 = ModelCheckpoint(filepath, monitor='val_'+metric, verbose=1, save_best_only=True, mode='max')

    step  = 60
    low   = 0
    high  = low+step
    
    tFold = [True]*(i*foldN)+[False]*foldN+[True]*trX.shape[0];
    tFold = tFold[:trX.shape[0]]
    
    vFold = [not xx for xx in tFold]

    #hist1  = model10.fit(trX[low:high],trY[low:high],
    hist1  = model10.fit(trX[tFold],trY[tFold],
                        epochs=epochs, batch_size=batch_size, 
                        #validation_split=0.20, 
                        validation_data=(trX[vFold],trY[vFold]),
                        initial_epoch = 0,
                        #callbacks=[early_stopping,reduce_lr1,reduce_lr2,checkpoint],
                        callbacks=[reduce_lr1,reduce_lr2,checkpoint1,checkpoint2,early_stopping],
                        verbose=verbose)

print(datetime.datetime.now())
# Out:
# 2017-07-29 22:18:54.597686 Training with folds
# 2017-07-29 22:18:54.598936 ------------> 8
# Train on 907 samples, validate on 101 samples
# Epoch 1/150
# Epoch 00000: dice improved from -inf to 0.56559, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.6559-0.5656---8.hdf5
# Epoch 00000: val_dice improved from -inf to 0.65589, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.6559-0.5656---8.hdf5
# 512s - loss: 0.4344 - dice: 0.5656 - binary_accuracy: 0.6744 - val_loss: 0.3441 - val_dice: 0.6559 - val_binary_accuracy: 0.8527
# Epoch 2/150
# Epoch 00001: dice improved from 0.56559 to 0.67154, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.6991-0.6715---8.hdf5
# Epoch 00001: val_dice improved from 0.65589 to 0.69908, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.6991-0.6715---8.hdf5
# 440s - loss: 0.3285 - dice: 0.6715 - binary_accuracy: 0.8313 - val_loss: 0.3009 - val_dice: 0.6991 - val_binary_accuracy: 0.8679
# Epoch 3/150
# Epoch 00002: dice improved from 0.67154 to 0.70772, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7186-0.7077---8.hdf5
# Epoch 00002: val_dice improved from 0.69908 to 0.71864, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7186-0.7077---8.hdf5
# 436s - loss: 0.2923 - dice: 0.7077 - binary_accuracy: 0.8621 - val_loss: 0.2814 - val_dice: 0.7186 - val_binary_accuracy: 0.8638
# Epoch 4/150
# Epoch 00003: dice improved from 0.70772 to 0.72208, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7073-0.7221---8.hdf5
# Epoch 00003: val_dice did not improve
# 432s - loss: 0.2779 - dice: 0.7221 - binary_accuracy: 0.8698 - val_loss: 0.2927 - val_dice: 0.7073 - val_binary_accuracy: 0.8741
# Epoch 5/150
# Epoch 00004: dice improved from 0.72208 to 0.73467, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7297-0.7347---8.hdf5
# Epoch 00004: val_dice improved from 0.71864 to 0.72973, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7297-0.7347---8.hdf5
# 436s - loss: 0.2653 - dice: 0.7347 - binary_accuracy: 0.8790 - val_loss: 0.2703 - val_dice: 0.7297 - val_binary_accuracy: 0.8832
# Epoch 6/150
# Epoch 00005: dice improved from 0.73467 to 0.75088, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7228-0.7509---8.hdf5
# Epoch 00005: val_dice did not improve
# 432s - loss: 0.2491 - dice: 0.7509 - binary_accuracy: 0.8879 - val_loss: 0.2772 - val_dice: 0.7228 - val_binary_accuracy: 0.8621
# Epoch 7/150
# Epoch 00006: dice did not improve
# Epoch 00006: val_dice improved from 0.72973 to 0.74933, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7493-0.7502---8.hdf5
# 432s - loss: 0.2498 - dice: 0.7502 - binary_accuracy: 0.8883 - val_loss: 0.2507 - val_dice: 0.7493 - val_binary_accuracy: 0.8880
# Epoch 8/150
# Epoch 00007: dice improved from 0.75088 to 0.76542, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7547-0.7654---8.hdf5
# Epoch 00007: val_dice improved from 0.74933 to 0.75469, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7547-0.7654---8.hdf5
# 435s - loss: 0.2346 - dice: 0.7654 - binary_accuracy: 0.8986 - val_loss: 0.2453 - val_dice: 0.7547 - val_binary_accuracy: 0.8906
# Epoch 9/150
# Epoch 00008: dice improved from 0.76542 to 0.76869, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7416-0.7687---8.hdf5
# Epoch 00008: val_dice did not improve
# 432s - loss: 0.2313 - dice: 0.7687 - binary_accuracy: 0.8988 - val_loss: 0.2584 - val_dice: 0.7416 - val_binary_accuracy: 0.8883
# Epoch 10/150
# Epoch 00009: dice improved from 0.76869 to 0.77223, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7585-0.7722---8.hdf5
# Epoch 00009: val_dice improved from 0.75469 to 0.75852, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7585-0.7722---8.hdf5
# 435s - loss: 0.2278 - dice: 0.7722 - binary_accuracy: 0.8997 - val_loss: 0.2415 - val_dice: 0.7585 - val_binary_accuracy: 0.8910
# Epoch 11/150
# Epoch 00010: dice improved from 0.77223 to 0.77588, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7340-0.7759---8.hdf5
# Epoch 00010: val_dice did not improve
# 431s - loss: 0.2241 - dice: 0.7759 - binary_accuracy: 0.9038 - val_loss: 0.2660 - val_dice: 0.7340 - val_binary_accuracy: 0.8659
# Epoch 12/150
# Epoch 00011: dice improved from 0.77588 to 0.77794, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7749-0.7779---8.hdf5
# Epoch 00011: val_dice improved from 0.75852 to 0.77493, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7749-0.7779---8.hdf5
# 435s - loss: 0.2221 - dice: 0.7779 - binary_accuracy: 0.9039 - val_loss: 0.2251 - val_dice: 0.7749 - val_binary_accuracy: 0.9025
# Epoch 13/150
# Epoch 00012: dice improved from 0.77794 to 0.78316, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7698-0.7832---8.hdf5
# Epoch 00012: val_dice did not improve
# 431s - loss: 0.2168 - dice: 0.7832 - binary_accuracy: 0.9060 - val_loss: 0.2302 - val_dice: 0.7698 - val_binary_accuracy: 0.8988
# Epoch 14/150
# Epoch 00013: dice improved from 0.78316 to 0.79244, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7769-0.7924---8.hdf5
# Epoch 00013: val_dice improved from 0.77493 to 0.77692, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7769-0.7924---8.hdf5
# 434s - loss: 0.2076 - dice: 0.7924 - binary_accuracy: 0.9113 - val_loss: 0.2231 - val_dice: 0.7769 - val_binary_accuracy: 0.9028
# Epoch 15/150
# Epoch 00014: dice improved from 0.79244 to 0.79271, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7852-0.7927---8.hdf5
# Epoch 00014: val_dice improved from 0.77692 to 0.78523, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7852-0.7927---8.hdf5
# 434s - loss: 0.2073 - dice: 0.7927 - binary_accuracy: 0.9124 - val_loss: 0.2148 - val_dice: 0.7852 - val_binary_accuracy: 0.9102
# Epoch 16/150
# Epoch 00015: dice did not improve
# Epoch 00015: val_dice improved from 0.78523 to 0.78652, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7865-0.7915---8.hdf5
# 431s - loss: 0.2085 - dice: 0.7915 - binary_accuracy: 0.9106 - val_loss: 0.2135 - val_dice: 0.7865 - val_binary_accuracy: 0.9096
# Epoch 17/150
# Epoch 00016: dice improved from 0.79271 to 0.79537, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7785-0.7954---8.hdf5
# Epoch 00016: val_dice did not improve
# 431s - loss: 0.2046 - dice: 0.7954 - binary_accuracy: 0.9122 - val_loss: 0.2215 - val_dice: 0.7785 - val_binary_accuracy: 0.9002
# Epoch 18/150
# Epoch 00017: dice improved from 0.79537 to 0.79831, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7838-0.7983---8.hdf5
# Epoch 00017: val_dice did not improve
# 431s - loss: 0.2017 - dice: 0.7983 - binary_accuracy: 0.9135 - val_loss: 0.2162 - val_dice: 0.7838 - val_binary_accuracy: 0.9101
# Epoch 19/150
# Epoch 00018: dice improved from 0.79831 to 0.79985, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7914-0.7998---8.hdf5
# Epoch 00018: val_dice improved from 0.78652 to 0.79140, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7914-0.7998---8.hdf5
# 435s - loss: 0.2002 - dice: 0.7998 - binary_accuracy: 0.9133 - val_loss: 0.2086 - val_dice: 0.7914 - val_binary_accuracy: 0.9149
# Epoch 20/150
# Epoch 00019: dice improved from 0.79985 to 0.80335, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7840-0.8034---8.hdf5
# Epoch 00019: val_dice did not improve
# 431s - loss: 0.1966 - dice: 0.8034 - binary_accuracy: 0.9161 - val_loss: 0.2160 - val_dice: 0.7840 - val_binary_accuracy: 0.9093
# Epoch 21/150
# Epoch 00020: dice improved from 0.80335 to 0.80656, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7942-0.8066---8.hdf5
# Epoch 00020: val_dice improved from 0.79140 to 0.79422, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7942-0.8066---8.hdf5
# 434s - loss: 0.1934 - dice: 0.8066 - binary_accuracy: 0.9176 - val_loss: 0.2058 - val_dice: 0.7942 - val_binary_accuracy: 0.9150
# Epoch 22/150
# Epoch 00021: dice did not improve
# Epoch 00021: val_dice did not improve
# 428s - loss: 0.1974 - dice: 0.8026 - binary_accuracy: 0.9164 - val_loss: 0.2111 - val_dice: 0.7889 - val_binary_accuracy: 0.9068
# Epoch 23/150
# Epoch 00022: dice improved from 0.80656 to 0.81124, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7976-0.8112---8.hdf5
# Epoch 00022: val_dice improved from 0.79422 to 0.79761, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7976-0.8112---8.hdf5
# 434s - loss: 0.1888 - dice: 0.8112 - binary_accuracy: 0.9196 - val_loss: 0.2024 - val_dice: 0.7976 - val_binary_accuracy: 0.9152
# Epoch 24/150
# Epoch 00023: dice improved from 0.81124 to 0.81558, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7935-0.8156---8.hdf5
# Epoch 00023: val_dice did not improve
# 431s - loss: 0.1844 - dice: 0.8156 - binary_accuracy: 0.9212 - val_loss: 0.2065 - val_dice: 0.7935 - val_binary_accuracy: 0.9095
# Epoch 25/150
# Epoch 00024: dice did not improve
# Epoch 00024: val_dice did not improve
# 428s - loss: 0.1847 - dice: 0.8153 - binary_accuracy: 0.9208 - val_loss: 0.2194 - val_dice: 0.7806 - val_binary_accuracy: 0.9029
# Epoch 26/150
# Epoch 00025: dice improved from 0.81558 to 0.81779, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7844-0.8178---8.hdf5
# Epoch 00025: val_dice did not improve
# 431s - loss: 0.1822 - dice: 0.8178 - binary_accuracy: 0.9221 - val_loss: 0.2156 - val_dice: 0.7844 - val_binary_accuracy: 0.9083
# Epoch 27/150
#
# Epoch 00026: reducing learning rate to 0.00499999988824.
# Epoch 00026: dice did not improve
# Epoch 00026: val_dice did not improve
# 428s - loss: 0.1827 - dice: 0.8173 - binary_accuracy: 0.9231 - val_loss: 0.2081 - val_dice: 0.7919 - val_binary_accuracy: 0.9074
# Epoch 28/150
# Epoch 00027: dice improved from 0.81779 to 0.83400, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8089-0.8340---8.hdf5
# Epoch 00027: val_dice improved from 0.79761 to 0.80893, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8089-0.8340---8.hdf5
# 434s - loss: 0.1660 - dice: 0.8340 - binary_accuracy: 0.9304 - val_loss: 0.1911 - val_dice: 0.8089 - val_binary_accuracy: 0.9225
# Epoch 29/150
# Epoch 00028: dice improved from 0.83400 to 0.83833, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8127-0.8383---8.hdf5
# Epoch 00028: val_dice improved from 0.80893 to 0.81265, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8127-0.8383---8.hdf5
# 434s - loss: 0.1617 - dice: 0.8383 - binary_accuracy: 0.9329 - val_loss: 0.1873 - val_dice: 0.8127 - val_binary_accuracy: 0.9210
# Epoch 30/150
# Epoch 00029: dice improved from 0.83833 to 0.83910, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8154-0.8391---8.hdf5
# Epoch 00029: val_dice improved from 0.81265 to 0.81538, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8154-0.8391---8.hdf5
# 435s - loss: 0.1609 - dice: 0.8391 - binary_accuracy: 0.9324 - val_loss: 0.1846 - val_dice: 0.8154 - val_binary_accuracy: 0.9242
# Epoch 31/150
# Epoch 00030: dice improved from 0.83910 to 0.84286, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8177-0.8429---8.hdf5
# Epoch 00030: val_dice improved from 0.81538 to 0.81768, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8177-0.8429---8.hdf5
# 434s - loss: 0.1571 - dice: 0.8429 - binary_accuracy: 0.9345 - val_loss: 0.1823 - val_dice: 0.8177 - val_binary_accuracy: 0.9250
# Epoch 32/150
# Epoch 00031: dice did not improve
# Epoch 00031: val_dice did not improve
# 428s - loss: 0.1640 - dice: 0.8360 - binary_accuracy: 0.9324 - val_loss: 0.1945 - val_dice: 0.8055 - val_binary_accuracy: 0.9208
# Epoch 33/150
# Epoch 00032: dice improved from 0.84286 to 0.84496, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8148-0.8450---8.hdf5
# Epoch 00032: val_dice did not improve
# 431s - loss: 0.1550 - dice: 0.8450 - binary_accuracy: 0.9354 - val_loss: 0.1852 - val_dice: 0.8148 - val_binary_accuracy: 0.9237
# Epoch 34/150
# Epoch 00033: dice improved from 0.84496 to 0.84793, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7998-0.8479---8.hdf5
# Epoch 00033: val_dice did not improve
# 431s - loss: 0.1521 - dice: 0.8479 - binary_accuracy: 0.9368 - val_loss: 0.2002 - val_dice: 0.7998 - val_binary_accuracy: 0.9148
# Epoch 35/150
#
# Epoch 00034: reducing learning rate to 0.00249999994412.
# Epoch 00034: dice improved from 0.84793 to 0.85113, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8119-0.8511---8.hdf5
# Epoch 00034: val_dice did not improve
# 431s - loss: 0.1489 - dice: 0.8511 - binary_accuracy: 0.9381 - val_loss: 0.1881 - val_dice: 0.8119 - val_binary_accuracy: 0.9230
# Epoch 36/150
# Epoch 00035: dice improved from 0.85113 to 0.85628, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8163-0.8563---8.hdf5
# Epoch 00035: val_dice did not improve
# 431s - loss: 0.1437 - dice: 0.8563 - binary_accuracy: 0.9407 - val_loss: 0.1837 - val_dice: 0.8163 - val_binary_accuracy: 0.9250
# Epoch 37/150
# Epoch 00036: dice improved from 0.85628 to 0.85846, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8153-0.8585---8.hdf5
# Epoch 00036: val_dice did not improve
# 431s - loss: 0.1415 - dice: 0.8585 - binary_accuracy: 0.9416 - val_loss: 0.1847 - val_dice: 0.8153 - val_binary_accuracy: 0.9266
# Epoch 38/150
#
# Epoch 00037: reducing learning rate to 0.00124999997206.
# Epoch 00037: dice improved from 0.85846 to 0.86063, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8162-0.8606---8.hdf5
# Epoch 00037: val_dice did not improve
# 431s - loss: 0.1394 - dice: 0.8606 - binary_accuracy: 0.9425 - val_loss: 0.1838 - val_dice: 0.8162 - val_binary_accuracy: 0.9256
# Epoch 39/150
# Epoch 00038: dice improved from 0.86063 to 0.86354, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8194-0.8635---8.hdf5
# Epoch 00038: val_dice improved from 0.81768 to 0.81938, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8194-0.8635---8.hdf5
# 434s - loss: 0.1365 - dice: 0.8635 - binary_accuracy: 0.9439 - val_loss: 0.1806 - val_dice: 0.8194 - val_binary_accuracy: 0.9270
# Epoch 40/150
# Epoch 00039: dice improved from 0.86354 to 0.86513, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8194-0.8651---8.hdf5
# Epoch 00039: val_dice did not improve
# 431s - loss: 0.1349 - dice: 0.8651 - binary_accuracy: 0.9446 - val_loss: 0.1806 - val_dice: 0.8194 - val_binary_accuracy: 0.9279
# Epoch 41/150
# Epoch 00040: dice improved from 0.86513 to 0.86613, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8158-0.8661---8.hdf5
# Epoch 00040: val_dice did not improve
# 431s - loss: 0.1339 - dice: 0.8661 - binary_accuracy: 0.9450 - val_loss: 0.1842 - val_dice: 0.8158 - val_binary_accuracy: 0.9252
# Epoch 42/150
# Epoch 00041: dice improved from 0.86613 to 0.86724, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8195-0.8672---8.hdf5
# Epoch 00041: val_dice improved from 0.81938 to 0.81951, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8195-0.8672---8.hdf5
# 434s - loss: 0.1328 - dice: 0.8672 - binary_accuracy: 0.9455 - val_loss: 0.1805 - val_dice: 0.8195 - val_binary_accuracy: 0.9279
# Epoch 43/150
# Epoch 00042: dice improved from 0.86724 to 0.86829, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8136-0.8683---8.hdf5
# Epoch 00042: val_dice did not improve
# 431s - loss: 0.1317 - dice: 0.8683 - binary_accuracy: 0.9460 - val_loss: 0.1864 - val_dice: 0.8136 - val_binary_accuracy: 0.9237
# Epoch 44/150
# Epoch 00043: dice improved from 0.86829 to 0.86915, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8177-0.8692---8.hdf5
# Epoch 00043: val_dice did not improve
# 431s - loss: 0.1308 - dice: 0.8692 - binary_accuracy: 0.9463 - val_loss: 0.1823 - val_dice: 0.8177 - val_binary_accuracy: 0.9271
# Epoch 45/150
# Epoch 00044: dice improved from 0.86915 to 0.87026, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8174-0.8703---8.hdf5
# Epoch 00044: val_dice did not improve
# 431s - loss: 0.1297 - dice: 0.8703 - binary_accuracy: 0.9467 - val_loss: 0.1826 - val_dice: 0.8174 - val_binary_accuracy: 0.9264
# Epoch 46/150
#
# Epoch 00045: reducing learning rate to 0.00062499998603.
# Epoch 00045: dice improved from 0.87026 to 0.87064, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8121-0.8706---8.hdf5
# Epoch 00045: val_dice did not improve
# 431s - loss: 0.1294 - dice: 0.8706 - binary_accuracy: 0.9469 - val_loss: 0.1879 - val_dice: 0.8121 - val_binary_accuracy: 0.9229
# Epoch 47/150
# Epoch 00046: dice improved from 0.87064 to 0.87259, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8161-0.8726---8.hdf5
# Epoch 00046: val_dice did not improve
# 431s - loss: 0.1274 - dice: 0.8726 - binary_accuracy: 0.9478 - val_loss: 0.1839 - val_dice: 0.8161 - val_binary_accuracy: 0.9259
# Epoch 48/150
# Epoch 00047: dice improved from 0.87259 to 0.87353, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8164-0.8735---8.hdf5
# Epoch 00047: val_dice did not improve
# 431s - loss: 0.1265 - dice: 0.8735 - binary_accuracy: 0.9482 - val_loss: 0.1836 - val_dice: 0.8164 - val_binary_accuracy: 0.9261
# Epoch 49/150
#
# Epoch 00048: reducing learning rate to 0.000312499993015.
# Epoch 00048: dice improved from 0.87353 to 0.87435, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8159-0.8744---8.hdf5
# Epoch 00048: val_dice did not improve
# 431s - loss: 0.1256 - dice: 0.8744 - binary_accuracy: 0.9484 - val_loss: 0.1841 - val_dice: 0.8159 - val_binary_accuracy: 0.9256
# Epoch 50/150
# Epoch 00049: dice improved from 0.87435 to 0.87535, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8156-0.8753---8.hdf5
# Epoch 00049: val_dice did not improve
# 431s - loss: 0.1247 - dice: 0.8753 - binary_accuracy: 0.9489 - val_loss: 0.1844 - val_dice: 0.8156 - val_binary_accuracy: 0.9256
# Epoch 51/150
# Epoch 00050: dice improved from 0.87535 to 0.87580, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8160-0.8758---8.hdf5
# Epoch 00050: val_dice did not improve
# 431s - loss: 0.1242 - dice: 0.8758 - binary_accuracy: 0.9490 - val_loss: 0.1840 - val_dice: 0.8160 - val_binary_accuracy: 0.9263
# Epoch 52/150
#
# Epoch 00051: reducing learning rate to 0.000156249996508.
# Epoch 00051: dice improved from 0.87580 to 0.87631, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8148-0.8763---8.hdf5
# Epoch 00051: val_dice did not improve
# 431s - loss: 0.1237 - dice: 0.8763 - binary_accuracy: 0.9492 - val_loss: 0.1852 - val_dice: 0.8148 - val_binary_accuracy: 0.9255
# Epoch 53/150
# Epoch 00052: dice improved from 0.87631 to 0.87696, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8160-0.8770---8.hdf5
# Epoch 00052: val_dice did not improve
# 431s - loss: 0.1230 - dice: 0.8770 - binary_accuracy: 0.9494 - val_loss: 0.1840 - val_dice: 0.8160 - val_binary_accuracy: 0.9262
# Epoch 54/150
# Epoch 00053: dice improved from 0.87696 to 0.87740, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8154-0.8774---8.hdf5
# Epoch 00053: val_dice did not improve
# 431s - loss: 0.1226 - dice: 0.8774 - binary_accuracy: 0.9495 - val_loss: 0.1846 - val_dice: 0.8154 - val_binary_accuracy: 0.9260
# Epoch 55/150
#
# Epoch 00054: reducing learning rate to 7.81249982538e-05.
# Epoch 00054: dice improved from 0.87740 to 0.87765, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8152-0.8776---8.hdf5
# Epoch 00054: val_dice did not improve
# 431s - loss: 0.1224 - dice: 0.8776 - binary_accuracy: 0.9495 - val_loss: 0.1848 - val_dice: 0.8152 - val_binary_accuracy: 0.9257
# Epoch 56/150
# Epoch 00055: dice improved from 0.87765 to 0.87795, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8145-0.8780---8.hdf5
# Epoch 00055: val_dice did not improve
# 431s - loss: 0.1220 - dice: 0.8780 - binary_accuracy: 0.9497 - val_loss: 0.1855 - val_dice: 0.8145 - val_binary_accuracy: 0.9252
# Epoch 57/150
# Epoch 00056: dice improved from 0.87795 to 0.87818, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8153-0.8782---8.hdf5
# Epoch 00056: val_dice did not improve
# 431s - loss: 0.1218 - dice: 0.8782 - binary_accuracy: 0.9498 - val_loss: 0.1847 - val_dice: 0.8153 - val_binary_accuracy: 0.9259
# Epoch 58/150
#
# Epoch 00057: reducing learning rate to 3.90624991269e-05.
# Epoch 00057: dice improved from 0.87818 to 0.87832, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8147-0.8783---8.hdf5
# Epoch 00057: val_dice did not improve
# 431s - loss: 0.1217 - dice: 0.8783 - binary_accuracy: 0.9498 - val_loss: 0.1853 - val_dice: 0.8147 - val_binary_accuracy: 0.9261
# Epoch 59/150
# Epoch 00058: dice improved from 0.87832 to 0.87839, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8145-0.8784---8.hdf5
# Epoch 00058: val_dice did not improve
# 431s - loss: 0.1216 - dice: 0.8784 - binary_accuracy: 0.9498 - val_loss: 0.1855 - val_dice: 0.8145 - val_binary_accuracy: 0.9255
# Epoch 60/150
# Epoch 00059: dice improved from 0.87839 to 0.87858, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8144-0.8786---8.hdf5
# Epoch 00059: val_dice did not improve
# 431s - loss: 0.1214 - dice: 0.8786 - binary_accuracy: 0.9498 - val_loss: 0.1856 - val_dice: 0.8144 - val_binary_accuracy: 0.9253
# Epoch 61/150
#
# Epoch 00060: reducing learning rate to 1.95312495634e-05.
# Epoch 00060: dice improved from 0.87858 to 0.87863, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8148-0.8786---8.hdf5
# Epoch 00060: val_dice did not improve
# 431s - loss: 0.1214 - dice: 0.8786 - binary_accuracy: 0.9498 - val_loss: 0.1852 - val_dice: 0.8148 - val_binary_accuracy: 0.9255
# Epoch 62/150
# Epoch 00061: dice improved from 0.87863 to 0.87869, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8148-0.8787---8.hdf5
# Epoch 00061: val_dice did not improve
# 431s - loss: 0.1213 - dice: 0.8787 - binary_accuracy: 0.9499 - val_loss: 0.1852 - val_dice: 0.8148 - val_binary_accuracy: 0.9256
# Epoch 63/150
# Epoch 00062: dice improved from 0.87869 to 0.87883, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8146-0.8788---8.hdf5
# Epoch 00062: val_dice did not improve
# 431s - loss: 0.1212 - dice: 0.8788 - binary_accuracy: 0.9500 - val_loss: 0.1854 - val_dice: 0.8146 - val_binary_accuracy: 0.9254
# Epoch 64/150
#
# Epoch 00063: reducing learning rate to 9.76562478172e-06.
# Epoch 00063: dice did not improve
# Epoch 00063: val_dice did not improve
# 428s - loss: 0.1212 - dice: 0.8788 - binary_accuracy: 0.9499 - val_loss: 0.1853 - val_dice: 0.8147 - val_binary_accuracy: 0.9257
# Epoch 65/150
# Epoch 00064: dice improved from 0.87883 to 0.87890, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8145-0.8789---8.hdf5
# Epoch 00064: val_dice did not improve
# 431s - loss: 0.1211 - dice: 0.8789 - binary_accuracy: 0.9499 - val_loss: 0.1855 - val_dice: 0.8145 - val_binary_accuracy: 0.9255
# Epoch 66/150
# Epoch 00065: dice improved from 0.87890 to 0.87897, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8145-0.8790---8.hdf5
# Epoch 00065: val_dice did not improve
# 431s - loss: 0.1210 - dice: 0.8790 - binary_accuracy: 0.9499 - val_loss: 0.1855 - val_dice: 0.8145 - val_binary_accuracy: 0.9255
# Epoch 67/150
#
# Epoch 00066: reducing learning rate to 4.88281239086e-06.
# Epoch 00066: dice improved from 0.87897 to 0.87903, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8146-0.8790---8.hdf5
# Epoch 00066: val_dice did not improve
# 431s - loss: 0.1210 - dice: 0.8790 - binary_accuracy: 0.9500 - val_loss: 0.1854 - val_dice: 0.8146 - val_binary_accuracy: 0.9256
# Epoch 68/150
# Epoch 00067: dice improved from 0.87903 to 0.87905, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8145-0.8790---8.hdf5
# Epoch 00067: val_dice did not improve
# 431s - loss: 0.1210 - dice: 0.8790 - binary_accuracy: 0.9500 - val_loss: 0.1855 - val_dice: 0.8145 - val_binary_accuracy: 0.9254
# Epoch 69/150
# Epoch 00068: dice did not improve
# Epoch 00068: val_dice did not improve
# 428s - loss: 0.1211 - dice: 0.8789 - binary_accuracy: 0.9499 - val_loss: 0.1854 - val_dice: 0.8146 - val_binary_accuracy: 0.9256
# Epoch 70/150
#
# Epoch 00069: reducing learning rate to 2.44140619543e-06.
#
# Epoch 00069: reducing learning rate to 1.22070309772e-06.
# Epoch 00069: dice improved from 0.87905 to 0.87905, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8145-0.8791---8.hdf5
# Epoch 00069: val_dice did not improve
# 431s - loss: 0.1209 - dice: 0.8791 - binary_accuracy: 0.9500 - val_loss: 0.1855 - val_dice: 0.8145 - val_binary_accuracy: 0.9255
# Epoch 71/150
# Epoch 00070: dice improved from 0.87905 to 0.87908, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8145-0.8791---8.hdf5
# Epoch 00070: val_dice did not improve
# 431s - loss: 0.1209 - dice: 0.8791 - binary_accuracy: 0.9500 - val_loss: 0.1855 - val_dice: 0.8145 - val_binary_accuracy: 0.9255
# Epoch 72/150
# Epoch 00071: dice did not improve
# Epoch 00071: val_dice did not improve
# 428s - loss: 0.1210 - dice: 0.8790 - binary_accuracy: 0.9500 - val_loss: 0.1855 - val_dice: 0.8145 - val_binary_accuracy: 0.9255
# Epoch 73/150
#
# Epoch 00072: reducing learning rate to 6.10351548858e-07.
# Epoch 00072: dice improved from 0.87908 to 0.87909, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8145-0.8791---8.hdf5
# Epoch 00072: val_dice did not improve
# 433s - loss: 0.1209 - dice: 0.8791 - binary_accuracy: 0.9500 - val_loss: 0.1855 - val_dice: 0.8145 - val_binary_accuracy: 0.9255
# Epoch 74/150
# Epoch 00073: dice improved from 0.87909 to 0.87914, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8145-0.8791---8.hdf5
# Epoch 00073: val_dice did not improve
# 431s - loss: 0.1209 - dice: 0.8791 - binary_accuracy: 0.9500 - val_loss: 0.1855 - val_dice: 0.8145 - val_binary_accuracy: 0.9255
# Epoch 75/150
#
# Epoch 00074: reducing learning rate to 3.05175774429e-07.
# Epoch 00074: dice did not improve
# Epoch 00074: val_dice did not improve
# 428s - loss: 0.1209 - dice: 0.8791 - binary_accuracy: 0.9500 - val_loss: 0.1855 - val_dice: 0.8145 - val_binary_accuracy: 0.9255
# Epoch 76/150
#
# Epoch 00075: reducing learning rate to 1.52587887214e-07.
# Epoch 00075: dice did not improve
# Epoch 00075: val_dice did not improve
# 428s - loss: 0.1210 - dice: 0.8790 - binary_accuracy: 0.9500 - val_loss: 0.1855 - val_dice: 0.8145 - val_binary_accuracy: 0.9255
# Epoch 77/150
# Epoch 00076: dice did not improve
# Epoch 00076: val_dice did not improve
# 428s - loss: 0.1210 - dice: 0.8790 - binary_accuracy: 0.9500 - val_loss: 0.1855 - val_dice: 0.8145 - val_binary_accuracy: 0.9255
# Epoch 00076: early stopping
# 2017-07-30 07:36:00.369578 ------------> 9
# Train on 909 samples, validate on 99 samples
# Epoch 1/150
# Epoch 00000: dice improved from -inf to 0.57331, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.6468-0.5733---9.hdf5
# Epoch 00000: val_dice improved from -inf to 0.64681, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.6468-0.5733---9.hdf5
# 507s - loss: 0.4267 - dice: 0.5733 - binary_accuracy: 0.6815 - val_loss: 0.3532 - val_dice: 0.6468 - val_binary_accuracy: 0.7928
# Epoch 2/150
# Epoch 00001: dice improved from 0.57331 to 0.67238, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.6538-0.6724---9.hdf5
# Epoch 00001: val_dice improved from 0.64681 to 0.65385, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.6538-0.6724---9.hdf5
# 439s - loss: 0.3276 - dice: 0.6724 - binary_accuracy: 0.8369 - val_loss: 0.3462 - val_dice: 0.6538 - val_binary_accuracy: 0.7840
# Epoch 3/150
# Epoch 00002: dice improved from 0.67238 to 0.69993, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7247-0.6999---9.hdf5
# Epoch 00002: val_dice improved from 0.65385 to 0.72471, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7247-0.6999---9.hdf5
# 438s - loss: 0.3001 - dice: 0.6999 - binary_accuracy: 0.8554 - val_loss: 0.2753 - val_dice: 0.7247 - val_binary_accuracy: 0.8584
# Epoch 4/150
# Epoch 00003: dice improved from 0.69993 to 0.70625, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7245-0.7062---9.hdf5
# Epoch 00003: val_dice did not improve
# 432s - loss: 0.2938 - dice: 0.7062 - binary_accuracy: 0.8605 - val_loss: 0.2755 - val_dice: 0.7245 - val_binary_accuracy: 0.8712
# Epoch 5/150
# Epoch 00004: dice improved from 0.70625 to 0.72469, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7587-0.7247---9.hdf5
# Epoch 00004: val_dice improved from 0.72471 to 0.75867, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7587-0.7247---9.hdf5
# 436s - loss: 0.2753 - dice: 0.7247 - binary_accuracy: 0.8735 - val_loss: 0.2413 - val_dice: 0.7587 - val_binary_accuracy: 0.8853
# Epoch 6/150
# Epoch 00005: dice improved from 0.72469 to 0.73823, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7539-0.7382---9.hdf5
# Epoch 00005: val_dice did not improve
# 432s - loss: 0.2618 - dice: 0.7382 - binary_accuracy: 0.8828 - val_loss: 0.2461 - val_dice: 0.7539 - val_binary_accuracy: 0.8831
# Epoch 7/150
# Epoch 00006: dice improved from 0.73823 to 0.74334, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7610-0.7433---9.hdf5
# Epoch 00006: val_dice improved from 0.75867 to 0.76099, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7610-0.7433---9.hdf5
# 437s - loss: 0.2567 - dice: 0.7433 - binary_accuracy: 0.8828 - val_loss: 0.2390 - val_dice: 0.7610 - val_binary_accuracy: 0.8928
# Epoch 8/150
# Epoch 00007: dice improved from 0.74334 to 0.74993, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7437-0.7499---9.hdf5
# Epoch 00007: val_dice did not improve
# 433s - loss: 0.2501 - dice: 0.7499 - binary_accuracy: 0.8899 - val_loss: 0.2563 - val_dice: 0.7437 - val_binary_accuracy: 0.8707
# Epoch 9/150
# Epoch 00008: dice improved from 0.74993 to 0.75953, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7446-0.7595---9.hdf5
# Epoch 00008: val_dice did not improve
# 432s - loss: 0.2405 - dice: 0.7595 - binary_accuracy: 0.8943 - val_loss: 0.2554 - val_dice: 0.7446 - val_binary_accuracy: 0.8690
# Epoch 10/150
# Epoch 00009: dice improved from 0.75953 to 0.76418, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7869-0.7642---9.hdf5
# Epoch 00009: val_dice improved from 0.76099 to 0.78693, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7869-0.7642---9.hdf5
# 436s - loss: 0.2358 - dice: 0.7642 - binary_accuracy: 0.8972 - val_loss: 0.2131 - val_dice: 0.7869 - val_binary_accuracy: 0.9057
# Epoch 11/150
# Epoch 00010: dice improved from 0.76418 to 0.77208, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7716-0.7721---9.hdf5
# Epoch 00010: val_dice did not improve
# 433s - loss: 0.2279 - dice: 0.7721 - binary_accuracy: 0.9019 - val_loss: 0.2284 - val_dice: 0.7716 - val_binary_accuracy: 0.8880
# Epoch 12/150
# Epoch 00011: dice improved from 0.77208 to 0.77671, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7376-0.7767---9.hdf5
# Epoch 00011: val_dice did not improve
# 432s - loss: 0.2233 - dice: 0.7767 - binary_accuracy: 0.9021 - val_loss: 0.2624 - val_dice: 0.7376 - val_binary_accuracy: 0.8617
# Epoch 13/150
# Epoch 00012: dice improved from 0.77671 to 0.77775, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7897-0.7777---9.hdf5
# Epoch 00012: val_dice improved from 0.78693 to 0.78972, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7897-0.7777---9.hdf5
# 435s - loss: 0.2223 - dice: 0.7777 - binary_accuracy: 0.9034 - val_loss: 0.2103 - val_dice: 0.7897 - val_binary_accuracy: 0.9054
# Epoch 14/150
# Epoch 00013: dice improved from 0.77775 to 0.77956, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8011-0.7796---9.hdf5
# Epoch 00013: val_dice improved from 0.78972 to 0.80110, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8011-0.7796---9.hdf5
# 435s - loss: 0.2204 - dice: 0.7796 - binary_accuracy: 0.9043 - val_loss: 0.1989 - val_dice: 0.8011 - val_binary_accuracy: 0.9169
# Epoch 15/150
# Epoch 00014: dice improved from 0.77956 to 0.78254, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7860-0.7825---9.hdf5
# Epoch 00014: val_dice did not improve
# 431s - loss: 0.2175 - dice: 0.7825 - binary_accuracy: 0.9056 - val_loss: 0.2140 - val_dice: 0.7860 - val_binary_accuracy: 0.9120
# Epoch 16/150
# Epoch 00015: dice improved from 0.78254 to 0.79017, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7931-0.7902---9.hdf5
# Epoch 00015: val_dice did not improve
# 431s - loss: 0.2098 - dice: 0.7902 - binary_accuracy: 0.9104 - val_loss: 0.2069 - val_dice: 0.7931 - val_binary_accuracy: 0.9085
# Epoch 17/150
# Epoch 00016: dice improved from 0.79017 to 0.79051, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7881-0.7905---9.hdf5
# Epoch 00016: val_dice did not improve
# 431s - loss: 0.2095 - dice: 0.7905 - binary_accuracy: 0.9101 - val_loss: 0.2119 - val_dice: 0.7881 - val_binary_accuracy: 0.9009
# Epoch 18/150
#
# Epoch 00017: reducing learning rate to 0.00499999988824.
# Epoch 00017: dice improved from 0.79051 to 0.79585, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.7984-0.7959---9.hdf5
# Epoch 00017: val_dice did not improve
# 432s - loss: 0.2041 - dice: 0.7959 - binary_accuracy: 0.9125 - val_loss: 0.2016 - val_dice: 0.7984 - val_binary_accuracy: 0.9112
# Epoch 19/150
# Epoch 00018: dice improved from 0.79585 to 0.80739, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8092-0.8074---9.hdf5
# Epoch 00018: val_dice improved from 0.80110 to 0.80921, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8092-0.8074---9.hdf5
# 434s - loss: 0.1926 - dice: 0.8074 - binary_accuracy: 0.9186 - val_loss: 0.1908 - val_dice: 0.8092 - val_binary_accuracy: 0.9200
# Epoch 20/150
# Epoch 00019: dice improved from 0.80739 to 0.80972, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8096-0.8097---9.hdf5
# Epoch 00019: val_dice improved from 0.80921 to 0.80956, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8096-0.8097---9.hdf5
# 434s - loss: 0.1903 - dice: 0.8097 - binary_accuracy: 0.9192 - val_loss: 0.1904 - val_dice: 0.8096 - val_binary_accuracy: 0.9179
# Epoch 21/150
# Epoch 00020: dice did not improve
# Epoch 00020: val_dice did not improve
# 429s - loss: 0.1917 - dice: 0.8083 - binary_accuracy: 0.9189 - val_loss: 0.1930 - val_dice: 0.8070 - val_binary_accuracy: 0.9151
# Epoch 22/150
# Epoch 00021: dice improved from 0.80972 to 0.81479, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8103-0.8148---9.hdf5
# Epoch 00021: val_dice improved from 0.80956 to 0.81035, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8103-0.8148---9.hdf5
# 434s - loss: 0.1852 - dice: 0.8148 - binary_accuracy: 0.9214 - val_loss: 0.1897 - val_dice: 0.8103 - val_binary_accuracy: 0.9164
# Epoch 23/150
# Epoch 00022: dice did not improve
# Epoch 00022: val_dice did not improve
# 428s - loss: 0.1904 - dice: 0.8096 - binary_accuracy: 0.9199 - val_loss: 0.1903 - val_dice: 0.8097 - val_binary_accuracy: 0.9170
# Epoch 24/150
# Epoch 00023: dice did not improve
# Epoch 00023: val_dice did not improve
# 428s - loss: 0.1887 - dice: 0.8113 - binary_accuracy: 0.9205 - val_loss: 0.1989 - val_dice: 0.8011 - val_binary_accuracy: 0.9122
# Epoch 25/150
# Epoch 00024: dice improved from 0.81479 to 0.81635, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8134-0.8163---9.hdf5
# Epoch 00024: val_dice improved from 0.81035 to 0.81335, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8134-0.8163---9.hdf5
# 434s - loss: 0.1837 - dice: 0.8163 - binary_accuracy: 0.9219 - val_loss: 0.1866 - val_dice: 0.8134 - val_binary_accuracy: 0.9194
# Epoch 26/150
# Epoch 00025: dice improved from 0.81635 to 0.82018, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8181-0.8202---9.hdf5
# Epoch 00025: val_dice improved from 0.81335 to 0.81805, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8181-0.8202---9.hdf5
# 434s - loss: 0.1798 - dice: 0.8202 - binary_accuracy: 0.9243 - val_loss: 0.1819 - val_dice: 0.8181 - val_binary_accuracy: 0.9238
# Epoch 27/150
# Epoch 00026: dice improved from 0.82018 to 0.82576, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8161-0.8258---9.hdf5
# Epoch 00026: val_dice did not improve
# 432s - loss: 0.1742 - dice: 0.8258 - binary_accuracy: 0.9264 - val_loss: 0.1839 - val_dice: 0.8161 - val_binary_accuracy: 0.9220
# Epoch 28/150
# Epoch 00027: dice did not improve
# Epoch 00027: val_dice did not improve
# 430s - loss: 0.1753 - dice: 0.8247 - binary_accuracy: 0.9256 - val_loss: 0.1854 - val_dice: 0.8146 - val_binary_accuracy: 0.9230
# Epoch 29/150
# Epoch 00028: dice did not improve
# Epoch 00028: val_dice did not improve
# 428s - loss: 0.1751 - dice: 0.8249 - binary_accuracy: 0.9270 - val_loss: 0.1857 - val_dice: 0.8143 - val_binary_accuracy: 0.9166
# Epoch 30/150
#
# Epoch 00029: reducing learning rate to 0.00249999994412.
# Epoch 00029: dice improved from 0.82576 to 0.82855, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8165-0.8286---9.hdf5
# Epoch 00029: val_dice did not improve
# 431s - loss: 0.1714 - dice: 0.8286 - binary_accuracy: 0.9273 - val_loss: 0.1835 - val_dice: 0.8165 - val_binary_accuracy: 0.9212
# Epoch 31/150
# Epoch 00030: dice improved from 0.82855 to 0.84085, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8256-0.8408---9.hdf5
# Epoch 00030: val_dice improved from 0.81805 to 0.82555, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8256-0.8408---9.hdf5
# 434s - loss: 0.1592 - dice: 0.8408 - binary_accuracy: 0.9339 - val_loss: 0.1744 - val_dice: 0.8256 - val_binary_accuracy: 0.9272
# Epoch 32/150
# Epoch 00031: dice improved from 0.84085 to 0.84388, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8275-0.8439---9.hdf5
# Epoch 00031: val_dice improved from 0.82555 to 0.82752, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8275-0.8439---9.hdf5
# 434s - loss: 0.1561 - dice: 0.8439 - binary_accuracy: 0.9356 - val_loss: 0.1725 - val_dice: 0.8275 - val_binary_accuracy: 0.9289
# Epoch 33/150
# Epoch 00032: dice improved from 0.84388 to 0.84624, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8231-0.8462---9.hdf5
# Epoch 00032: val_dice did not improve
# 431s - loss: 0.1538 - dice: 0.8462 - binary_accuracy: 0.9365 - val_loss: 0.1769 - val_dice: 0.8231 - val_binary_accuracy: 0.9252
# Epoch 34/150
# Epoch 00033: dice improved from 0.84624 to 0.84897, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8252-0.8490---9.hdf5
# Epoch 00033: val_dice did not improve
# 431s - loss: 0.1510 - dice: 0.8490 - binary_accuracy: 0.9376 - val_loss: 0.1748 - val_dice: 0.8252 - val_binary_accuracy: 0.9263
# Epoch 35/150
# Epoch 00034: dice improved from 0.84897 to 0.85019, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8212-0.8502---9.hdf5
# Epoch 00034: val_dice did not improve
# 431s - loss: 0.1498 - dice: 0.8502 - binary_accuracy: 0.9386 - val_loss: 0.1788 - val_dice: 0.8212 - val_binary_accuracy: 0.9242
# Epoch 36/150
#
# Epoch 00035: reducing learning rate to 0.00124999997206.
# Epoch 00035: dice did not improve
# Epoch 00035: val_dice did not improve
# 429s - loss: 0.1544 - dice: 0.8456 - binary_accuracy: 0.9369 - val_loss: 0.1753 - val_dice: 0.8247 - val_binary_accuracy: 0.9263
# Epoch 37/150
# Epoch 00036: dice improved from 0.85019 to 0.85556, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8224-0.8556---9.hdf5
# Epoch 00036: val_dice did not improve
# 431s - loss: 0.1444 - dice: 0.8556 - binary_accuracy: 0.9408 - val_loss: 0.1776 - val_dice: 0.8224 - val_binary_accuracy: 0.9256
# Epoch 38/150
# Epoch 00037: dice improved from 0.85556 to 0.85778, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8310-0.8578---9.hdf5
# Epoch 00037: val_dice improved from 0.82752 to 0.83101, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8310-0.8578---9.hdf5
# 435s - loss: 0.1422 - dice: 0.8578 - binary_accuracy: 0.9418 - val_loss: 0.1690 - val_dice: 0.8310 - val_binary_accuracy: 0.9315
# Epoch 39/150
# Epoch 00038: dice improved from 0.85778 to 0.85868, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8279-0.8587---9.hdf5
# Epoch 00038: val_dice did not improve
# 431s - loss: 0.1413 - dice: 0.8587 - binary_accuracy: 0.9423 - val_loss: 0.1721 - val_dice: 0.8279 - val_binary_accuracy: 0.9293
# Epoch 40/150
# Epoch 00039: dice improved from 0.85868 to 0.86015, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8273-0.8602---9.hdf5
# Epoch 00039: val_dice did not improve
# 432s - loss: 0.1398 - dice: 0.8602 - binary_accuracy: 0.9428 - val_loss: 0.1727 - val_dice: 0.8273 - val_binary_accuracy: 0.9281
# Epoch 41/150
# Epoch 00040: dice improved from 0.86015 to 0.86173, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8315-0.8617---9.hdf5
# Epoch 00040: val_dice improved from 0.83101 to 0.83151, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8315-0.8617---9.hdf5
# 436s - loss: 0.1383 - dice: 0.8617 - binary_accuracy: 0.9435 - val_loss: 0.1685 - val_dice: 0.8315 - val_binary_accuracy: 0.9318
# Epoch 42/150
# Epoch 00041: dice improved from 0.86173 to 0.86263, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8286-0.8626---9.hdf5
# Epoch 00041: val_dice did not improve
# 431s - loss: 0.1374 - dice: 0.8626 - binary_accuracy: 0.9440 - val_loss: 0.1714 - val_dice: 0.8286 - val_binary_accuracy: 0.9298
# Epoch 43/150
# Epoch 00042: dice improved from 0.86263 to 0.86386, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8308-0.8639---9.hdf5
# Epoch 00042: val_dice did not improve
# 431s - loss: 0.1361 - dice: 0.8639 - binary_accuracy: 0.9445 - val_loss: 0.1692 - val_dice: 0.8308 - val_binary_accuracy: 0.9317
# Epoch 44/150
# Epoch 00043: dice improved from 0.86386 to 0.86497, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8251-0.8650---9.hdf5
# Epoch 00043: val_dice did not improve
# 431s - loss: 0.1350 - dice: 0.8650 - binary_accuracy: 0.9449 - val_loss: 0.1749 - val_dice: 0.8251 - val_binary_accuracy: 0.9274
# Epoch 45/150
#
# Epoch 00044: reducing learning rate to 0.00062499998603.
# Epoch 00044: dice improved from 0.86497 to 0.86594, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8299-0.8659---9.hdf5
# Epoch 00044: val_dice did not improve
# 432s - loss: 0.1341 - dice: 0.8659 - binary_accuracy: 0.9453 - val_loss: 0.1701 - val_dice: 0.8299 - val_binary_accuracy: 0.9316
# Epoch 46/150
# Epoch 00045: dice improved from 0.86594 to 0.86872, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8287-0.8687---9.hdf5
# Epoch 00045: val_dice did not improve
# 431s - loss: 0.1313 - dice: 0.8687 - binary_accuracy: 0.9465 - val_loss: 0.1713 - val_dice: 0.8287 - val_binary_accuracy: 0.9302
# Epoch 47/150
# Epoch 00046: dice improved from 0.86872 to 0.87044, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8278-0.8704---9.hdf5
# Epoch 00046: val_dice did not improve
# 431s - loss: 0.1296 - dice: 0.8704 - binary_accuracy: 0.9470 - val_loss: 0.1722 - val_dice: 0.8278 - val_binary_accuracy: 0.9297
# Epoch 48/150
#
# Epoch 00047: reducing learning rate to 0.000312499993015.
# Epoch 00047: dice improved from 0.87044 to 0.87085, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8306-0.8709---9.hdf5
# Epoch 00047: val_dice did not improve
# 431s - loss: 0.1291 - dice: 0.8709 - binary_accuracy: 0.9473 - val_loss: 0.1694 - val_dice: 0.8306 - val_binary_accuracy: 0.9325
# Epoch 49/150
# Epoch 00048: dice improved from 0.87085 to 0.87196, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8285-0.8720---9.hdf5
# Epoch 00048: val_dice did not improve
# 431s - loss: 0.1280 - dice: 0.8720 - binary_accuracy: 0.9478 - val_loss: 0.1715 - val_dice: 0.8285 - val_binary_accuracy: 0.9303
# Epoch 50/150
# Epoch 00049: dice improved from 0.87196 to 0.87346, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8283-0.8735---9.hdf5
# Epoch 00049: val_dice did not improve
# 431s - loss: 0.1265 - dice: 0.8735 - binary_accuracy: 0.9481 - val_loss: 0.1717 - val_dice: 0.8283 - val_binary_accuracy: 0.9304
# Epoch 51/150
#
# Epoch 00050: reducing learning rate to 0.000156249996508.
# Epoch 00050: dice improved from 0.87346 to 0.87443, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8291-0.8744---9.hdf5
# Epoch 00050: val_dice did not improve
# 431s - loss: 0.1256 - dice: 0.8744 - binary_accuracy: 0.9484 - val_loss: 0.1709 - val_dice: 0.8291 - val_binary_accuracy: 0.9305
# Epoch 52/150
# Epoch 00051: dice improved from 0.87443 to 0.87514, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8290-0.8751---9.hdf5
# Epoch 00051: val_dice did not improve
# 431s - loss: 0.1249 - dice: 0.8751 - binary_accuracy: 0.9486 - val_loss: 0.1710 - val_dice: 0.8290 - val_binary_accuracy: 0.9309
# Epoch 53/150
# Epoch 00052: dice improved from 0.87514 to 0.87551, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8286-0.8755---9.hdf5
# Epoch 00052: val_dice did not improve
# 431s - loss: 0.1245 - dice: 0.8755 - binary_accuracy: 0.9487 - val_loss: 0.1714 - val_dice: 0.8286 - val_binary_accuracy: 0.9303
# Epoch 54/150
#
# Epoch 00053: reducing learning rate to 7.81249982538e-05.
# Epoch 00053: dice did not improve
# Epoch 00053: val_dice did not improve
# 428s - loss: 0.1250 - dice: 0.8750 - binary_accuracy: 0.9485 - val_loss: 0.1725 - val_dice: 0.8275 - val_binary_accuracy: 0.9296
# Epoch 55/150
# Epoch 00054: dice improved from 0.87551 to 0.87643, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8280-0.8764---9.hdf5
# Epoch 00054: val_dice did not improve
# 431s - loss: 0.1236 - dice: 0.8764 - binary_accuracy: 0.9489 - val_loss: 0.1720 - val_dice: 0.8280 - val_binary_accuracy: 0.9301
# Epoch 56/150
# Epoch 00055: dice improved from 0.87643 to 0.87671, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8290-0.8767---9.hdf5
# Epoch 00055: val_dice did not improve
# 431s - loss: 0.1233 - dice: 0.8767 - binary_accuracy: 0.9491 - val_loss: 0.1710 - val_dice: 0.8290 - val_binary_accuracy: 0.9307
# Epoch 57/150
#
# Epoch 00056: reducing learning rate to 3.90624991269e-05.
# Epoch 00056: dice improved from 0.87671 to 0.87700, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8286-0.8770---9.hdf5
# Epoch 00056: val_dice did not improve
# 431s - loss: 0.1230 - dice: 0.8770 - binary_accuracy: 0.9491 - val_loss: 0.1714 - val_dice: 0.8286 - val_binary_accuracy: 0.9306
# Epoch 58/150
# Epoch 00057: dice improved from 0.87700 to 0.87742, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8283-0.8774---9.hdf5
# Epoch 00057: val_dice did not improve
# 431s - loss: 0.1226 - dice: 0.8774 - binary_accuracy: 0.9492 - val_loss: 0.1717 - val_dice: 0.8283 - val_binary_accuracy: 0.9305
# Epoch 59/150
# Epoch 00058: dice improved from 0.87742 to 0.87757, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8285-0.8776---9.hdf5
# Epoch 00058: val_dice did not improve
# 431s - loss: 0.1224 - dice: 0.8776 - binary_accuracy: 0.9492 - val_loss: 0.1715 - val_dice: 0.8285 - val_binary_accuracy: 0.9305
# Epoch 60/150
#
# Epoch 00059: reducing learning rate to 1.95312495634e-05.
# Epoch 00059: dice improved from 0.87757 to 0.87787, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8286-0.8779---9.hdf5
# Epoch 00059: val_dice did not improve
# 432s - loss: 0.1221 - dice: 0.8779 - binary_accuracy: 0.9492 - val_loss: 0.1714 - val_dice: 0.8286 - val_binary_accuracy: 0.9306
# Epoch 61/150
# Epoch 00060: dice improved from 0.87787 to 0.87805, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8280-0.8780---9.hdf5
# Epoch 00060: val_dice did not improve
# 432s - loss: 0.1220 - dice: 0.8780 - binary_accuracy: 0.9493 - val_loss: 0.1720 - val_dice: 0.8280 - val_binary_accuracy: 0.9302
# Epoch 62/150
# Epoch 00061: dice improved from 0.87805 to 0.87815, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8284-0.8782---9.hdf5
# Epoch 00061: val_dice did not improve
# 432s - loss: 0.1218 - dice: 0.8782 - binary_accuracy: 0.9493 - val_loss: 0.1716 - val_dice: 0.8284 - val_binary_accuracy: 0.9306
# Epoch 63/150
#
# Epoch 00062: reducing learning rate to 9.76562478172e-06.
# Epoch 00062: dice improved from 0.87815 to 0.87816, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8279-0.8782---9.hdf5
# Epoch 00062: val_dice did not improve
# 431s - loss: 0.1218 - dice: 0.8782 - binary_accuracy: 0.9493 - val_loss: 0.1721 - val_dice: 0.8279 - val_binary_accuracy: 0.9301
# Epoch 64/150
# Epoch 00063: dice improved from 0.87816 to 0.87825, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8282-0.8782---9.hdf5
# Epoch 00063: val_dice did not improve
# 431s - loss: 0.1218 - dice: 0.8782 - binary_accuracy: 0.9493 - val_loss: 0.1718 - val_dice: 0.8282 - val_binary_accuracy: 0.9304
# Epoch 65/150
# Epoch 00064: dice improved from 0.87825 to 0.87826, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8282-0.8783---9.hdf5
# Epoch 00064: val_dice did not improve
# 433s - loss: 0.1217 - dice: 0.8783 - binary_accuracy: 0.9493 - val_loss: 0.1718 - val_dice: 0.8282 - val_binary_accuracy: 0.9303
# Epoch 66/150
#
# Epoch 00065: reducing learning rate to 4.88281239086e-06.
# Epoch 00065: dice improved from 0.87826 to 0.87840, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8284-0.8784---9.hdf5
# Epoch 00065: val_dice did not improve
# 430s - loss: 0.1216 - dice: 0.8784 - binary_accuracy: 0.9494 - val_loss: 0.1716 - val_dice: 0.8284 - val_binary_accuracy: 0.9306
# Epoch 67/150
# Epoch 00066: dice did not improve
# Epoch 00066: val_dice did not improve
# 428s - loss: 0.1216 - dice: 0.8784 - binary_accuracy: 0.9494 - val_loss: 0.1720 - val_dice: 0.8280 - val_binary_accuracy: 0.9301
# Epoch 68/150
# Epoch 00067: dice improved from 0.87840 to 0.87845, saving model to ../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8282-0.8784---9.hdf5
# Epoch 00067: val_dice did not improve
# 431s - loss: 0.1216 - dice: 0.8784 - binary_accuracy: 0.9493 - val_loss: 0.1718 - val_dice: 0.8282 - val_binary_accuracy: 0.9304
# Epoch 69/150
#
# Epoch 00068: reducing learning rate to 2.44140619543e-06.
# Epoch 00068: dice did not improve
# Epoch 00068: val_dice did not improve
# 428s - loss: 0.1216 - dice: 0.8784 - binary_accuracy: 0.9493 - val_loss: 0.1718 - val_dice: 0.8282 - val_binary_accuracy: 0.9304
# Epoch 70/150
#
# Epoch 00069: reducing learning rate to 1.22070309772e-06.
# Epoch 00069: dice did not improve
# Epoch 00069: val_dice did not improve
# 428s - loss: 0.1216 - dice: 0.8784 - binary_accuracy: 0.9494 - val_loss: 0.1719 - val_dice: 0.8281 - val_binary_accuracy: 0.9302
# Epoch 71/150
# Epoch 00070: dice did not improve
# Epoch 00070: val_dice did not improve
# 428s - loss: 0.1216 - dice: 0.8784 - binary_accuracy: 0.9493 - val_loss: 0.1718 - val_dice: 0.8282 - val_binary_accuracy: 0.9303
# Epoch 72/150
#
# Epoch 00071: reducing learning rate to 6.10351548858e-07.
# Epoch 00071: dice did not improve
# Epoch 00071: val_dice did not improve
# 428s - loss: 0.1216 - dice: 0.8784 - binary_accuracy: 0.9494 - val_loss: 0.1719 - val_dice: 0.8281 - val_binary_accuracy: 0.9302
# Epoch 00071: early stopping
# 2017-07-30 16:19:49.226537 ------------> 10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-d2a32de57b20> in <module>()
#      41
#      42     #hist1  = model10.fit(trX[low:high],trY[low:high],
# ---> 43     hist1  = model10.fit(trX[tFold],trY[tFold],
#      44                         epochs=epochs, batch_size=batch_size,
#      45                         #validation_split=0.20,
#
# KeyboardInterrupt:

# %%
#!ls ../Temp/TempTempG5M5KFold -la | tail
# !ls ../Temp/TempTempG5M5KFold10 -la | tail
# Out:
# -rwxrwxrwx 1 boba boba 248917120 июл 30 14:53 V1-UNET-val_dice=0.8286-0.8779---9.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 13:12 V1-UNET-val_dice=0.8287-0.8687---9.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 13:56 V1-UNET-val_dice=0.8290-0.8751---9.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 14:24 V1-UNET-val_dice=0.8290-0.8767---9.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 13:48 V1-UNET-val_dice=0.8291-0.8744---9.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 13:05 V1-UNET-val_dice=0.8299-0.8659---9.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 13:27 V1-UNET-val_dice=0.8306-0.8709---9.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 12:51 V1-UNET-val_dice=0.8308-0.8639---9.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 12:15 V1-UNET-val_dice=0.8310-0.8578---9.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 12:37 V1-UNET-val_dice=0.8315-0.8617---9.hdf5

# %%
if 0 : model10 = load_model('../Temp/TrainModel001+G+M/V1-UNET-0.8511.hdf5')
if 0 : model10 = load_model('../Temp/V1-UNET-0.8853.hdf5')
#if 1 : model10 = load_model('../Temp/TempTempM3/V1-UNET-0.9054.hdf5')
if 0 : model10.load_weights('../Temp/TempTempM3/V1-UNET-0.9054.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5/V1-UNET-val_dice=0.7307.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7879-2.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7632-2.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7660-2.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7828-2.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFold5/V1-UNET-val_dice=0.8224-0.8516---1.hdf5') # 769128
if 0 : model10.load_weights('../Temp/TempTempG5M5KFold5/V1-UNET-val_dice=0.8217-0.8655---1.hdf5') # 765XXX
if 0 : model10.load_weights('../Temp/TempTempG5M5KFold5/V1-UNET-val_dice=0.8227-0.8643---3.hdf5')    
if 1 : model10.load_weights('../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8315-0.8617---9.hdf5')

# %%
# %time trP = model10.predict(trX,batch_size=batch_size)
# Out:
# CPU times: user 1min 31s, sys: 21.7 s, total: 1min 53s
# Wall time: 1min 48s

# %%
trP01 = trP
trP01[trP>0.5] =1.0
trP01[trP<=0.5]=0.0
trP01 = trP01.astype(np.uint8)

# %%
if 0 : # Ощутимых результатов не дает, увеличение в +10-100
    times, medianP = 3,5
    for i in range(trP01.shape[0]) :
        for j in range(times) :
            trP01[i,:,:,0] = cv.medianBlur(trP01[i],medianP)

# %%
iii = 0
print(trX[0].shape,trY[0].shape,trP.shape,trP.min(),trP.max())
for ii in range(iii,iii+10) :
    plt.figure(figsize=(15,5))
    plt.subplot(151); plt.imshow(trX[ii,:,:,0],'gray'); 
    plt.subplot(152); plt.imshow(trY[ii,:,:,0],'gray'); 
    plt.subplot(153); plt.imshow(trP[ii,:,:,0],'gray'); 
    plt.subplot(154); plt.imshow(trP01[ii,:,:,0],'gray'); 
    plt.subplot(155); plt.hist(trP[ii,:,:,0].ravel(),bins=50); 
    plt.show()
plt.close()
# Out:
# (512, 512, 3) (512, 512, 1) (1008, 512, 512, 1) 0.0 1.0

# %%
# Calculate F1-micro

# %%
TP = (trY[:,6:506,6:506,0]*trP01[:,6:506,6:506,0]).sum()
TN = ((1.0-trY[:,6:506,6:506,0])*(1.0-trP01[:,6:506,6:506,0])).sum()
FP = ((trY[:,6:506,6:506,0])*(1.0-trP01[:,6:506,6:506,0])).sum()
FN = ((1.0-trY[:,6:506,6:506,0])*(trP01[:,6:506,6:506,0])).sum()

P  = TP/(TP+FP) if (TP+FP)>0.0 else 1.0
R  = TP/(TP+FN) if (TP+FN)>0.0 else 0.0

F1 = 2.0*P*R/(P+R) if (P+R)>0.0 else 0.0

TP,TN,FP,FN,P,R,F1
#P*R,P+R, 2.0*P*R/(P+R)
# Out:
# (79039437.0,
#  157914619.0,
#  5489883.0,
#  9556061.0,
#  0.9350535056948287,
#  0.8921383003005412,
#  0.91309192885332002)

# %%
# Calculate DI- dice.mean()

# %%
dice, XX = [],[]
for i in range(trP.shape[0]) :
    G = trY  [i,6:506,6:506,0].sum()
    S = trP01[i,6:506,6:506,0].sum()
    X = (trY [i,6:506,6:506,0]*trP01[i,6:506,6:506,0]).sum()
    XX.append(X)
    dice.append((2.0*X/(G+S) if G+S>0 else 1.0))
di = (np.array(dice)).mean()
di #,np.array(dice)  #,np.array(XX)
# Out:
# 0.87281417956803031

# %%
plt.hist(np.array(dice),bins=40); plt.show()
plt.plot(np.array(dice)); plt.show()

# %%
1000000*(F1+di)/2.0
# Out:
# 892953.05421067518

# %%
#np.array(dice)<0.4

# %%
# Подготовка test решения

# %%
if flagGray :
    trO, trO0 = [], np.zeros((512,512,1))
else :
    trO, trO0 = [], np.zeros((512,512,3))

for xx in listTest :
    img = cv.imread(os.path.join(dirTest,xx),-1)
    if 1 and (Gauss or Median): 
        for cc in range(img.shape[2]) : 
            if Gauss  : img[:,:,cc] = cv.GaussianBlur(img[:,:,cc],(Gauss,Gauss),0);
            if Median : img[:,:,cc] = cv.medianBlur  (img[:,:,cc],Median);
    #print(img.mean(),msk.mean())
    if flagGray :
        img = cv.cvtColor(img,cv.COLOR_RGB2GRAY);
        trO0[6:506,6:506,0] = img[:,:]/255.0
    else :
        trO0[6:506,6:506,:] = img[:,:,:]/255.0
    trO.append(trO0.copy())
    #print(trX0.mean(),trY0.mean(),trX1[-1].mean(),trY1[-1].mean())

#print([trY[xx].mean() for xx in range(10)])
trO = np.array(trO)

if 1 :
    for cc in range(meanX.shape[0]) : 
        trO[:,6:506,6:506,cc] -= meanX[cc]
    
trO.shape, trO.min(), trO.max()
#[trY[xx].mean() for xx in range(10)]
# Out:
# ((162, 512, 512, 3), -0.64172901643310909, 0.47912580261435694)

# %%
# %time trOP = model10.predict(trO,batch_size=batch_size)
# Out:
# CPU times: user 14.9 s, sys: 3.18 s, total: 18.1 s
# Wall time: 17.4 s

# %%
trOP01 = trOP
trOP01[trOP>0.5] =1.0
trOP01[trOP<=0.5]=0.0

# %%
iii = 40
print(trO[0].shape,trP01[0].shape,trOP01.shape,trOP.min(),trOP.max())
for ii in range(iii,iii+10) :
    plt.figure(figsize=(15,5))
    plt.subplot(151); plt.imshow(trO[ii,:,:,0]); 
    plt.subplot(152); plt.imshow(trOP01[ii,:,:,0],'gray'); 
    plt.subplot(153); plt.imshow(trOP[ii,:,:,0],'gray'); 
    plt.subplot(154); plt.hist(trOP[ii,:,:,0].ravel(),bins=50); 
    plt.show()
plt.close()
# Out:
# (512, 512, 3) (512, 512, 1) (162, 512, 512, 1) 0.0 1.0

# %%
# Формирование выходной директории

# %%
def convert_to_binary(truth_png_file, truth_txt_file):
    im = Image.open(truth_png_file) #Can be many different formats.
    pix = im.load()
    with open(truth_txt_file, 'w') as out:
        for x in xrange(500):
            for y in xrange(500):
                out.write(str(int(pix[x, y] > 0)))
            out.write('\n')

if not os.path.exists('../Temp/random_submission'):
    os.makedirs('../Temp/random_submission')

# Training
for i in range(len(listTrain)) :
    fn = listTrain[i]
    truth_txt_file = '../Temp/random_submission/' + fn.split('.')[0] + '_mask.txt'
    with open(truth_txt_file, 'w') as out:
        for x in xrange(500):
            for y in xrange(500):
                out.write(str(int(trP01[i,y+6, x+6] > 0.0)))
            out.write('\n')
    out.close()
    
# Testing
for i in range(len(listTest)) :
    fn = listTest[i]
    truth_txt_file = '../Temp/random_submission/' + fn.split('.')[0] + '_mask.txt'
    with open(truth_txt_file, 'w') as out:
        for x in xrange(500):
            for y in xrange(500):
                out.write(str(int(trOP01[i,y+6, x+6] > 0.0)))
            out.write('\n')
    out.close()

# %%
import shutil

# %%
xx=shutil.make_archive('../Result/topcoderkonica','zip','../Temp/random_submission')
xx
# Out:
# '/media/boba/DATA/boba/Working/TopCoder/2017-07-25-Konica-Minolta/Result/topcoderkonica.zip'

# %%
# !ls ../Temp -la
# Out:
# total 4610508
# drwxrwxrwx 1 boba boba      4096 июл 26 10:58 .
# drwxrwxrwx 1 boba boba      4096 июл 26 10:11 ..
# drwxrwxrwx 1 boba boba         0 июл 25 18:17 .ipynb_checkpoints
# drwxrwxrwx 1 boba boba     61440 июл 26 09:14 random_submission
# -rwxrwxrwx 1 boba boba   1057596 июл 26 10:58 random_submission.zip
# drwxrwxrwx 1 boba boba         0 июл 25 23:35 TrainModel001-G-M
# drwxrwxrwx 1 boba boba         0 июл 25 22:21 TrainModel001-G+M
# drwxrwxrwx 1 boba boba         0 июл 25 21:48 TrainModel001+G-M
# drwxrwxrwx 1 boba boba      4096 июл 25 21:05 TrainModel001+G+M
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:02 V1-UNET-0.8167.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:08 V1-UNET-0.8275.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 18:33 V1-UNET-0.8305.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 18:02 V1-UNET-0.8418.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:09 V1-UNET-0.8486.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:09 V1-UNET-0.8593.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 18:34 V1-UNET-0.8601.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:21 V1-UNET-0.8602.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:22 V1-UNET-0.8605.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:35 V1-UNET-0.8628.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:35 V1-UNET-0.8633.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:23 V1-UNET-0.8635.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:36 V1-UNET-0.8645.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:36 V1-UNET-0.8652.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:24 V1-UNET-0.8655.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:11 V1-UNET-0.8793.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:13 V1-UNET-0.8796.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:14 V1-UNET-0.8808.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 18:02 V1-UNET-0.8853.hdf5

# %%
# !ls ../Work -la
#!ls ../Temp/random_submission
# Out:
# total 80768
# drwxrwxrwx 1 boba boba        0 июл 26 09:17 .
# drwxrwxrwx 1 boba boba     4096 июл 25 15:24 ..
# -rwxrwxrwx 1 boba boba 82700662 июл 26 09:32 topcoderkonica.zip

# %%
if False :
    save_model(model10,'../Data-Keras/Models/model-UNet.h5')
    model10.save_weights('../Data-Keras/Models/model-UNet-weights.h5')

# %%
rrr=pd.DataFrame(res,columns=['image_name','tags']); rrr.head(); 
suffixDT = (datetime.datetime.now()).strftime('%Y-%m-%d-%H-%M-%S'); print(suffixDT)
rrr.to_csv('../Result/vss'+suffixDT+'.csv',index=False);
# Out:
# 2017-05-20-05-51-18
