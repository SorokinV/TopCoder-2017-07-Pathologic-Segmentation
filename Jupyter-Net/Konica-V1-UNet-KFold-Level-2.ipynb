# %%
##
## UNet 
##
## Взята идея по описанию из https://github.com/pietz/unet-keras
##
##
## 2017-07-28
##   Добавлены flip+rotation LB=760393
##
## 2017-07-29
##   LB=769123
##
##

# %%
import sys,os,datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import fbeta_score
import sklearn.metrics as skm
from __future__ import print_function

# %%
print(np.__version__);
print(pd.__version__);
# Out:
# 1.13.1
# 0.19.2

# %%
import  cv2 as cv
cv.__version__
# Out:
# '3.2.0'

# %%
#from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.models import Sequential, save_model, load_model, Input, Model
from keras.layers import Convolution2D, MaxPooling2D, Convolution1D, MaxPooling1D, UpSampling2D, ZeroPadding2D
from keras.layers import Conv2D, Concatenate, Reshape
from keras.layers import Activation, Dropout, Flatten, Dense, Permute
from keras.layers.normalization import BatchNormalization
import keras.optimizers
from keras.callbacks import EarlyStopping,ReduceLROnPlateau,ModelCheckpoint
import keras.backend as K
# Out:
# Using TensorFlow backend.

# %%
keras.__version__
# Out:
# '2.0.6'

# %%
#---------------------------------------------------------------------

# %%
# !ls -la ..
#!ls -la ../Data
#!ls -la ../Data/training
# Out:
# total 25
# drwxrwxrwx 1 boba boba 4096 июл 26 11:10 .
# drwxrwxrwx 1 boba boba    0 июл 25 09:21 ..
# drwxrwxrwx 1 boba boba 4096 июл 25 09:23 Data
# drwxrwxrwx 1 boba boba    0 июл 25 09:22 Data-Arch
# drwxrwxrwx 1 boba boba    0 июл 25 09:26 Data-Keras
# drwxrwxrwx 1 boba boba 4096 июл 30 21:33 .git
# -rwxrwxrwx 2 boba boba  130 июл  9 12:02 .gitignore
# drwxrwxrwx 1 boba boba    0 июл 26 10:11 .ipynb_checkpoints
# drwxrwxrwx 1 boba boba    0 июл 30 21:33 Jupyter
# drwxrwxrwx 1 boba boba 4096 июл 30 22:50 Jupyter-Net
# drwxrwxrwx 1 boba boba 4096 июл 30 17:32 Result
# drwxrwxrwx 1 boba boba 4096 июл 30 17:41 Temp
# drwxrwxrwx 1 boba boba    0 июл 27 07:53 Work

# %%
dirData = '../Data'
dirTemp = '../Temp'
dirWork = '../Work'

dirTest  = os.path.join(dirData,'testing','images')
dirTrain = os.path.join(dirData,'training','images')
dirMask  = os.path.join(dirData,'training','truth')

# %%
listTrain = os.listdir(dirTrain)
listMask  = os.listdir(dirMask)
listTest  = os.listdir(dirTest)
listTrain = [xx for xx in listTrain if os.path.splitext(xx)[1]=='.tif']
listMask  = [xx for xx in listMask  if os.path.splitext(xx)[1]=='.png']
listTest  = [xx for xx in listTest  if os.path.splitext(xx)[1]=='.tif']
print(len(listTrain),len(listMask),len(listTest))
print(listTrain[:5],'\n',listMask[:5],'\n',listTest[:5])
# Out:
# 168 168 162
# ['i105404.tif', 'i117557.tif', 'i124017.tif', 'i130790.tif', 'i137857.tif']
#  ['i105404_mask.png', 'i117557_mask.png', 'i124017_mask.png', 'i130790_mask.png', 'i137857_mask.png']
#  ['i105047.tif', 'i116596.tif', 'i137649.tif', 'i140176.tif', 'i142099.tif']

# %%
if 0 :
    for xx in listTrain[:5] :
        img = cv.imread(os.path.join(dirTrain,xx),-1)
        xxm = os.path.splitext(xx)[0]+"_mask.png"
        msk = cv.imread(os.path.join(dirMask,xxm),-1)
        plt.subplot(121); plt.imshow(img); plt.subplot(122); plt.imshow(msk,'gray'); plt.show()
    plt.close()

# %%
msk.shape, img.shape, img.min(), img.max(), msk.max(), #img[6:10,6:10], msk[6:10,6:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-051c9d5448bc> in <module>()
# ----> 1 msk.shape, img.shape, img.min(), img.max(), msk.max(), #img[6:10,6:10], msk[6:10,6:10]
#
# NameError: name 'msk' is not defined

# %%
flagGray = False
Gauss    = 5
Median   = 5
if flagGray :
    trX, trY, trX0, trY0 = [], [], np.zeros((512,512,1)), np.zeros((512,512,1))
else :
    trX, trY, trX0, trY0 = [], [], np.zeros((512,512,3)), np.zeros((512,512,1))

for xx in listTrain :
    img = cv.imread(os.path.join(dirTrain,xx),-1)
    if 1 and (Gauss or Median): 
        for cc in range(img.shape[2]) : 
            if Gauss  : img[:,:,cc] = cv.GaussianBlur(img[:,:,cc],(Gauss,Gauss),0);
            if Median : img[:,:,cc] = cv.medianBlur  (img[:,:,cc],Median);
    xxm = os.path.splitext(xx)[0]+"_mask.png"
    msk = cv.imread(os.path.join(dirMask,xxm),-1)
    #print(img.mean(),msk.mean())
    if flagGray :
        img = cv.cvtColor(img,cv.COLOR_RGB2GRAY);
        trX0[6:506,6:506,0] = img[:,:]/255.0
        trY0[6:506,6:506,0] = msk[:,:]/255.0
    else :
        trX0[6:506,6:506,:] = img[:,:,:]/255.0
        trY0[6:506,6:506,0] = msk[:,:]/255.0
        trY0[trY0>=0.5] = 1.0
    trX.append(trX0.copy())
    trY.append(trY0.copy())
    #print(trX0.mean(),trY0.mean(),trX1[-1].mean(),trY1[-1].mean())

#print([trY[xx].mean() for xx in range(10)])
trX = np.array(trX)
trY = np.array(trY)

# аугментация
trXX, trYY, trXXX,trYYY = trX.copy(), trY.copy(), np.zeros((1)), np.zeros((1))


if 0 :
    # flipping
    for f in range(-1,2) :
        trXXX, trYYY = trX.copy(), trY.copy()
        for p in range(trXXX.shape[0]) :
            trXXX[p], trYYY[p,:,:,0] = cv.flip(trXXX[p],f), cv.flip(trYYY[p,:,:,0],f)
        trXX = np.vstack([trXX,trXXX])
        trYY = np.vstack([trYY,trYYY])
        print('flip :',f,trXX.shape,trYY.shape)

if 0 :
    # rotate +-90

    # rotate +90
    trXXX, trYYY = trX.copy(), trY.copy()
    for p in range(trX.shape[0]) :
        for i in range(trX.shape[1]) :
            for j in range(trX.shape[2]) :
                trXXX[p,i,j,:] = trX[p,j,trX.shape[1]-i-1]
                trYYY[p,i,j,:] = trY[p,j,trY.shape[1]-i-1]
    trXX = np.vstack([trXX,trXXX])
    trYY = np.vstack([trYY,trYYY])
    print('rotate +90:',trXX.shape,trYY.shape)

    # rotate -90
    trXXX, trYYY = trX.copy(), trY.copy()
    for p in range(trX.shape[0]) :
        for i in range(trX.shape[1]) :
            for j in range(trX.shape[2]) :
                trXXX[p,i,j,:] = trX[p,trX.shape[2]-j-1,i]
                trYYY[p,i,j,:] = trY[p,trY.shape[2]-j-1,i]
    trXX = np.vstack([trXX,trXXX])
    trYY = np.vstack([trYY,trYYY])
    print('rotate -90:',trXX.shape,trYY.shape)
    
trX, trY = trXX.copy(), trYY.copy()
del trXX,trYY
del trXXX,trYYY

# Считаем среднее по каналам и вычитаем из изображений
meanX = (trX[:,6:-6,6:-6,:].mean(axis=(1,2))).mean(axis=0)
stdX  = (trX[:,6:-6,6:-6,:].mean(axis=(1,2))).std(axis=0)
for cc in range(meanX.shape[0]) : 
    trX[:,6:-6,6:-6,cc] -= meanX[cc]    
print("mean={} std={}".format(meanX,stdX))
    
trX.shape, trX.min(), trX.max(), trY.shape, trY.min(), trY.max()
#[trY[xx].mean() for xx in range(10)]
# Out:
# mean=[ 0.6473997   0.48950165  0.70839568] std=[ 0.06249822  0.09179847  0.08778627]
# ((168, 512, 512, 3),
#  -0.62212117329583094,
#  0.48696893986925349,
#  (168, 512, 512, 1),
#  0.0,
#  1.0)

# %%
for xx in range(5) :
    img = trX[xx]
    xxm = trY[xx]
    plt.subplot(121); plt.imshow(img); plt.subplot(122); plt.imshow(xxm[:,:,0],'gray'); plt.show()
plt.close()

# %%
#
# model UNET
#
#    https://github.com/pietz/unet-keras
#
#

def level_block(m, dim, depth, acti, dropout=0.25, batch=True):
    if depth > 0:
        
        x = m
        if batch : x = BatchNormalization()(x)
        n = Conv2D(dim, (3, 3), activation=acti, padding='same')(x) #(m)
        n = Conv2D(dim, (3, 3), activation=acti, padding='same')(n)
        if dropout : n = Dropout(dropout)(n) ## add
        m = MaxPooling2D((2, 2))(n)
        m = level_block(m, 2*dim, depth-1, acti, dropout=dropout, batch=batch)
        m = UpSampling2D((2, 2))(m)
        m = Conv2D(dim, (2, 2), activation=acti, padding='same', kernel_initializer='he_normal')(m)
        if dropout : m = Dropout(dropout)(m) ## add
        m = Concatenate(axis=3)([n, m])
    m = Conv2D(dim, (3, 3), activation=acti, padding='same')(m)
    return Conv2D(dim, (3, 3), activation=acti, padding='same')(m)

def UNet(img_shape, n_out=2, dim=32, depth=5, acti='relu', flatten=False, dropout=0.25, batch=True):
    i = Input(shape=img_shape)
    ## ???? i = ZeroPadding2D((6,6),data_format="channels_last")
    o = level_block(i, dim, depth, acti, dropout=dropout, batch=batch)
    o = Conv2D(n_out, (1, 1), name='prediction')(o)
    if flatten:
        o = Reshape(n_out, img_shape[0] * img_shape[1])(o)
        o = Permute((2, 1))(o)
    #o = Activation('relu')(o)
    if batch : o = BatchNormalization()(o)  ######
    o = Activation('sigmoid')(o)
    return Model(inputs=i, outputs=o)

# %%
model10 = UNet((512,512,3),depth=4,n_out=1, dropout=0.05)
model10.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 512, 512, 3)   0
# ____________________________________________________________________________________________________
# batch_normalization_1 (BatchNorm (None, 512, 512, 3)   12          input_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_1 (Conv2D)                (None, 512, 512, 32)  896         batch_normalization_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_2 (Conv2D)                (None, 512, 512, 32)  9248        conv2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 512, 512, 32)  0           conv2d_2[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)   (None, 256, 256, 32)  0           dropout_1[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_2 (BatchNorm (None, 256, 256, 32)  128         max_pooling2d_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_3 (Conv2D)                (None, 256, 256, 64)  18496       batch_normalization_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_4 (Conv2D)                (None, 256, 256, 64)  36928       conv2d_3[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)              (None, 256, 256, 64)  0           conv2d_4[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)   (None, 128, 128, 64)  0           dropout_2[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_3 (BatchNorm (None, 128, 128, 64)  256         max_pooling2d_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_5 (Conv2D)                (None, 128, 128, 128) 73856       batch_normalization_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_6 (Conv2D)                (None, 128, 128, 128) 147584      conv2d_5[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)              (None, 128, 128, 128) 0           conv2d_6[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)   (None, 64, 64, 128)   0           dropout_3[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_4 (BatchNorm (None, 64, 64, 128)   512         max_pooling2d_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_7 (Conv2D)                (None, 64, 64, 256)   295168      batch_normalization_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_8 (Conv2D)                (None, 64, 64, 256)   590080      conv2d_7[0][0]
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)              (None, 64, 64, 256)   0           conv2d_8[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)   (None, 32, 32, 256)   0           dropout_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_9 (Conv2D)                (None, 32, 32, 512)   1180160     max_pooling2d_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_10 (Conv2D)               (None, 32, 32, 512)   2359808     conv2d_9[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)   (None, 64, 64, 512)   0           conv2d_10[0][0]
# ____________________________________________________________________________________________________
# conv2d_11 (Conv2D)               (None, 64, 64, 256)   524544      up_sampling2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_5 (Dropout)              (None, 64, 64, 256)   0           conv2d_11[0][0]
# ____________________________________________________________________________________________________
# concatenate_1 (Concatenate)      (None, 64, 64, 512)   0           dropout_4[0][0]
#                                                                    dropout_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_12 (Conv2D)               (None, 64, 64, 256)   1179904     concatenate_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_13 (Conv2D)               (None, 64, 64, 256)   590080      conv2d_12[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)   (None, 128, 128, 256) 0           conv2d_13[0][0]
# ____________________________________________________________________________________________________
# conv2d_14 (Conv2D)               (None, 128, 128, 128) 131200      up_sampling2d_2[0][0]
# ____________________________________________________________________________________________________
# dropout_6 (Dropout)              (None, 128, 128, 128) 0           conv2d_14[0][0]
# ____________________________________________________________________________________________________
# concatenate_2 (Concatenate)      (None, 128, 128, 256) 0           dropout_3[0][0]
#                                                                    dropout_6[0][0]
# ____________________________________________________________________________________________________
# conv2d_15 (Conv2D)               (None, 128, 128, 128) 295040      concatenate_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_16 (Conv2D)               (None, 128, 128, 128) 147584      conv2d_15[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)   (None, 256, 256, 128) 0           conv2d_16[0][0]
# ____________________________________________________________________________________________________
# conv2d_17 (Conv2D)               (None, 256, 256, 64)  32832       up_sampling2d_3[0][0]
# ____________________________________________________________________________________________________
# dropout_7 (Dropout)              (None, 256, 256, 64)  0           conv2d_17[0][0]
# ____________________________________________________________________________________________________
# concatenate_3 (Concatenate)      (None, 256, 256, 128) 0           dropout_2[0][0]
#                                                                    dropout_7[0][0]
# ____________________________________________________________________________________________________
# conv2d_18 (Conv2D)               (None, 256, 256, 64)  73792       concatenate_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_19 (Conv2D)               (None, 256, 256, 64)  36928       conv2d_18[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)   (None, 512, 512, 64)  0           conv2d_19[0][0]
# ____________________________________________________________________________________________________
# conv2d_20 (Conv2D)               (None, 512, 512, 32)  8224        up_sampling2d_4[0][0]
# ____________________________________________________________________________________________________
# dropout_8 (Dropout)              (None, 512, 512, 32)  0           conv2d_20[0][0]
# ____________________________________________________________________________________________________
# concatenate_4 (Concatenate)      (None, 512, 512, 64)  0           dropout_1[0][0]
#                                                                    dropout_8[0][0]
# ____________________________________________________________________________________________________
# conv2d_21 (Conv2D)               (None, 512, 512, 32)  18464       concatenate_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_22 (Conv2D)               (None, 512, 512, 32)  9248        conv2d_21[0][0]
# ____________________________________________________________________________________________________
# prediction (Conv2D)              (None, 512, 512, 1)   33          conv2d_22[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_5 (BatchNorm (None, 512, 512, 1)   4           prediction[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 512, 512, 1)   0           batch_normalization_5[0][0]
# ====================================================================================================
# Total params: 7,761,009
# Trainable params: 7,760,553
# Non-trainable params: 456
# ____________________________________________________________________________________________________

# %%
def dice (truth,pred) :
    g, s = K.sum(truth), K.sum(pred)
    x    = K.sum((truth*pred))
    return((1.0 if K.sum(g+s)==0.0 else 2.0*x/(g+s+K.epsilon())))

def f1 (truth,pred) :
    TP = K.sum(truth*pred)
    TN = K.sum((1.0-truth)*(1.0-pred))
    FP = K.sum(truth*(1.0-pred))
    FN = K.sum((1.0-truth)*pred)

    
    P  = 1.0 if K.sum(TP+FP)==0.0 else TP/(TP+FP)
    R  = 0.0 if K.sum(TP+FN)==0.0 else TP/(TP+FN) 

    F1 = 0.0 if K.sum(P+R)  ==0.0 else 2.0*P*R/(P+R)

    return(F1)

def f1dice (truth,pred) :
    return ((dice(truth,pred)+f1(truth,pred))/2.0)
    
def lossdice (truth,pred) :
    return(1.0 - dice(truth,pred))

def lossfd (truth,pred) :
    return(1.0 - f1dice(truth,pred))

# %%
def buildModel (input_shape) :
##    model = UNet(input_shape,depth=5,n_out=1,dropout=0.05,batch=False)
    model = UNet(input_shape,depth=5-2,n_out=1,dropout=0.05,batch=False)
    
    sgd = keras.optimizers.SGD(lr=0.01, momentum=0.9, nesterov=True)
    #model.compile(loss='mean_absolute_error',  #'binary_crossentropy',
    model.compile(loss=lossdice, #'mean_absolute_error',  #'binary_crossentropy',
                  optimizer=sgd, #sgd, #"adam", #'rmsprop',
                  metrics=[dice,'binary_accuracy']) #['binary_accuracy']) #[fbeta_pred]) #['accuracy',fbeta_pred]) #['accuracy'])
    return(model)

# %%
K.clear_session()
model10 = buildModel((trX.shape[1],trX.shape[2],trX.shape[3]))
model10.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 512, 512, 3)   0
# ____________________________________________________________________________________________________
# conv2d_1 (Conv2D)                (None, 512, 512, 32)  896         input_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_2 (Conv2D)                (None, 512, 512, 32)  9248        conv2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 512, 512, 32)  0           conv2d_2[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)   (None, 256, 256, 32)  0           dropout_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_3 (Conv2D)                (None, 256, 256, 64)  18496       max_pooling2d_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_4 (Conv2D)                (None, 256, 256, 64)  36928       conv2d_3[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)              (None, 256, 256, 64)  0           conv2d_4[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)   (None, 128, 128, 64)  0           dropout_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_5 (Conv2D)                (None, 128, 128, 128) 73856       max_pooling2d_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_6 (Conv2D)                (None, 128, 128, 128) 147584      conv2d_5[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)              (None, 128, 128, 128) 0           conv2d_6[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)   (None, 64, 64, 128)   0           dropout_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_7 (Conv2D)                (None, 64, 64, 256)   295168      max_pooling2d_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_8 (Conv2D)                (None, 64, 64, 256)   590080      conv2d_7[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)   (None, 128, 128, 256) 0           conv2d_8[0][0]
# ____________________________________________________________________________________________________
# conv2d_9 (Conv2D)                (None, 128, 128, 128) 131200      up_sampling2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)              (None, 128, 128, 128) 0           conv2d_9[0][0]
# ____________________________________________________________________________________________________
# concatenate_1 (Concatenate)      (None, 128, 128, 256) 0           dropout_3[0][0]
#                                                                    dropout_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_10 (Conv2D)               (None, 128, 128, 128) 295040      concatenate_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_11 (Conv2D)               (None, 128, 128, 128) 147584      conv2d_10[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)   (None, 256, 256, 128) 0           conv2d_11[0][0]
# ____________________________________________________________________________________________________
# conv2d_12 (Conv2D)               (None, 256, 256, 64)  32832       up_sampling2d_2[0][0]
# ____________________________________________________________________________________________________
# dropout_5 (Dropout)              (None, 256, 256, 64)  0           conv2d_12[0][0]
# ____________________________________________________________________________________________________
# concatenate_2 (Concatenate)      (None, 256, 256, 128) 0           dropout_2[0][0]
#                                                                    dropout_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_13 (Conv2D)               (None, 256, 256, 64)  73792       concatenate_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_14 (Conv2D)               (None, 256, 256, 64)  36928       conv2d_13[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)   (None, 512, 512, 64)  0           conv2d_14[0][0]
# ____________________________________________________________________________________________________
# conv2d_15 (Conv2D)               (None, 512, 512, 32)  8224        up_sampling2d_3[0][0]
# ____________________________________________________________________________________________________
# dropout_6 (Dropout)              (None, 512, 512, 32)  0           conv2d_15[0][0]
# ____________________________________________________________________________________________________
# concatenate_3 (Concatenate)      (None, 512, 512, 64)  0           dropout_1[0][0]
#                                                                    dropout_6[0][0]
# ____________________________________________________________________________________________________
# conv2d_16 (Conv2D)               (None, 512, 512, 32)  18464       concatenate_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_17 (Conv2D)               (None, 512, 512, 32)  9248        conv2d_16[0][0]
# ____________________________________________________________________________________________________
# prediction (Conv2D)              (None, 512, 512, 1)   33          conv2d_17[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 512, 512, 1)   0           prediction[0][0]
# ====================================================================================================
# Total params: 1,925,601
# Trainable params: 1,925,601
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
#model10.load_weights('../Data-Keras/Models/model-UNet-weights.h5', by_name=False)
batch_size = 1

# %%
#epochs     = 150
epochs     = 50
verbose    = 2
batch_size = 1
metric     = 'binary_accuracy'
metric     = 'dice'

############trX, trY = trX[0:30], trY[0:30]

#folds      = 10
folds      = 5
folds      = 3
foldN      = trX.shape[0]/folds+1

print(datetime.datetime.now(),'Training with folds')

for i in range(folds) :
#for i in range(8,11) :

    print(datetime.datetime.now(),'------------>',i)

    K.clear_session()
    model10 = buildModel((trX.shape[1],trX.shape[2],trX.shape[3]))
    ############if 1 : model10.load_weights('../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7660-2.hdf5')

#    early_stopping = EarlyStopping(monitor='val_loss', patience=10,min_delta=0.0001,verbose=1)
    early_stopping = EarlyStopping(monitor='val_loss', patience=5,min_delta=0.0001,verbose=1)
    reduce_lr1     = ReduceLROnPlateau(monitor='val_loss', factor=0.5,patience=3, min_lr=0.0000001,verbose=1)
    reduce_lr2     = ReduceLROnPlateau(monitor='loss',     factor=0.5,patience=3, min_lr=0.0000001,verbose=1)

    filepath="../Temp/NewStep/Level-2/V1-UNET-val_"+metric+"={val_"+metric+":.4f}-{"+metric+":.4f}---"+str(i)+".hdf5"
    #filepath="../Temp/NewStep/StandartF5/V1-UNET-val_"+metric+"={val_"+metric+":.4f}-{"+metric+":.4f}---"+str(i)+".hdf5"
    #filepath="../Temp/TempTempG5M5KFold10/V1-UNET-val_"+metric+"={val_"+metric+":.4f}-{"+metric+":.4f}---"+str(i)+".hdf5"
    #checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
    checkpoint1 = ModelCheckpoint(filepath, monitor=metric,        verbose=1, save_best_only=True, mode='max')
    checkpoint2 = ModelCheckpoint(filepath, monitor='val_'+metric, verbose=1, save_best_only=True, mode='max')

    step  = 60
    low   = 0
    high  = low+step
    
    tFold = [True]*(i*foldN)+[False]*foldN+[True]*trX.shape[0];
    tFold = tFold[:trX.shape[0]]
    
    vFold = [not xx for xx in tFold]

    #hist1  = model10.fit(trX[low:high],trY[low:high],
    hist1  = model10.fit(trX[tFold],trY[tFold],
                        epochs=epochs, batch_size=batch_size, 
                        #validation_split=0.20, 
                        validation_data=(trX[vFold],trY[vFold]),
                        initial_epoch = 0,
                        #callbacks=[early_stopping,reduce_lr1,reduce_lr2,checkpoint],
                        callbacks=[reduce_lr1,reduce_lr2,checkpoint1,checkpoint2,early_stopping],
                        verbose=verbose)

print(datetime.datetime.now())
# Out:
# 2017-07-30 22:52:36.288070 Training with folds
# 2017-07-30 22:52:36.288818 ------------> 0
# Train on 111 samples, validate on 57 samples
# Epoch 1/50
# Epoch 00000: dice improved from -inf to 0.42569, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.4151-0.4257---0.hdf5
# Epoch 00000: val_dice improved from -inf to 0.41506, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.4151-0.4257---0.hdf5
# 42s - loss: 0.5743 - dice: 0.4257 - binary_accuracy: 0.3374 - val_loss: 0.5849 - val_dice: 0.4151 - val_binary_accuracy: 0.2860
# Epoch 2/50
# Epoch 00001: dice improved from 0.42569 to 0.49720, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.4910-0.4972---0.hdf5
# Epoch 00001: val_dice improved from 0.41506 to 0.49102, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.4910-0.4972---0.hdf5
# 39s - loss: 0.5028 - dice: 0.4972 - binary_accuracy: 0.5062 - val_loss: 0.5090 - val_dice: 0.4910 - val_binary_accuracy: 0.8015
# Epoch 3/50
# Epoch 00002: dice improved from 0.49720 to 0.61418, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.5813-0.6142---0.hdf5
# Epoch 00002: val_dice improved from 0.49102 to 0.58129, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.5813-0.6142---0.hdf5
# 38s - loss: 0.3858 - dice: 0.6142 - binary_accuracy: 0.7914 - val_loss: 0.4187 - val_dice: 0.5813 - val_binary_accuracy: 0.8086
# Epoch 4/50
# Epoch 00003: dice improved from 0.61418 to 0.63341, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.5945-0.6334---0.hdf5
# Epoch 00003: val_dice improved from 0.58129 to 0.59451, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.5945-0.6334---0.hdf5
# 38s - loss: 0.3666 - dice: 0.6334 - binary_accuracy: 0.8092 - val_loss: 0.4055 - val_dice: 0.5945 - val_binary_accuracy: 0.8073
# Epoch 5/50
# Epoch 00004: dice improved from 0.63341 to 0.65110, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6053-0.6511---0.hdf5
# Epoch 00004: val_dice improved from 0.59451 to 0.60532, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6053-0.6511---0.hdf5
# 37s - loss: 0.3489 - dice: 0.6511 - binary_accuracy: 0.8081 - val_loss: 0.3947 - val_dice: 0.6053 - val_binary_accuracy: 0.8155
# Epoch 6/50
# Epoch 00005: dice improved from 0.65110 to 0.65692, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6059-0.6569---0.hdf5
# Epoch 00005: val_dice improved from 0.60532 to 0.60595, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6059-0.6569---0.hdf5
# 37s - loss: 0.3431 - dice: 0.6569 - binary_accuracy: 0.8117 - val_loss: 0.3941 - val_dice: 0.6059 - val_binary_accuracy: 0.8296
# Epoch 7/50
# Epoch 00006: dice improved from 0.65692 to 0.65847, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6176-0.6585---0.hdf5
# Epoch 00006: val_dice improved from 0.60595 to 0.61759, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6176-0.6585---0.hdf5
# 37s - loss: 0.3415 - dice: 0.6585 - binary_accuracy: 0.8221 - val_loss: 0.3824 - val_dice: 0.6176 - val_binary_accuracy: 0.8277
# Epoch 8/50
# Epoch 00007: dice improved from 0.65847 to 0.66480, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6234-0.6648---0.hdf5
# Epoch 00007: val_dice improved from 0.61759 to 0.62338, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6234-0.6648---0.hdf5
# 37s - loss: 0.3352 - dice: 0.6648 - binary_accuracy: 0.8222 - val_loss: 0.3766 - val_dice: 0.6234 - val_binary_accuracy: 0.8256
# Epoch 9/50
# Epoch 00008: dice did not improve
# Epoch 00008: val_dice did not improve
# 37s - loss: 0.3387 - dice: 0.6613 - binary_accuracy: 0.8088 - val_loss: 0.3795 - val_dice: 0.6205 - val_binary_accuracy: 0.8167
# Epoch 10/50
# Epoch 00009: dice did not improve
# Epoch 00009: val_dice did not improve
# 37s - loss: 0.3358 - dice: 0.6642 - binary_accuracy: 0.8230 - val_loss: 0.3858 - val_dice: 0.6142 - val_binary_accuracy: 0.7834
# Epoch 11/50
# Epoch 00010: dice improved from 0.66480 to 0.68341, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6339-0.6834---0.hdf5
# Epoch 00010: val_dice improved from 0.62338 to 0.63389, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6339-0.6834---0.hdf5
# 37s - loss: 0.3166 - dice: 0.6834 - binary_accuracy: 0.8350 - val_loss: 0.3661 - val_dice: 0.6339 - val_binary_accuracy: 0.8294
# Epoch 12/50
# Epoch 00011: dice did not improve
# Epoch 00011: val_dice did not improve
# 36s - loss: 0.3313 - dice: 0.6687 - binary_accuracy: 0.8282 - val_loss: 0.3829 - val_dice: 0.6171 - val_binary_accuracy: 0.7871
# Epoch 13/50
# Epoch 00012: dice did not improve
# Epoch 00012: val_dice did not improve
# 37s - loss: 0.3283 - dice: 0.6717 - binary_accuracy: 0.8273 - val_loss: 0.3770 - val_dice: 0.6230 - val_binary_accuracy: 0.8352
# Epoch 14/50
# Epoch 00013: dice improved from 0.68341 to 0.68748, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.5674-0.6875---0.hdf5
# Epoch 00013: val_dice did not improve
# 37s - loss: 0.3125 - dice: 0.6875 - binary_accuracy: 0.8385 - val_loss: 0.4326 - val_dice: 0.5674 - val_binary_accuracy: 0.8448
# Epoch 15/50
#
# Epoch 00014: reducing learning rate to 0.00499999988824.
# Epoch 00014: dice did not improve
# Epoch 00014: val_dice did not improve
# 36s - loss: 0.3249 - dice: 0.6751 - binary_accuracy: 0.8358 - val_loss: 0.3748 - val_dice: 0.6252 - val_binary_accuracy: 0.8367
# Epoch 16/50
# Epoch 00015: dice improved from 0.68748 to 0.69795, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6199-0.6979---0.hdf5
# Epoch 00015: val_dice did not improve
# 36s - loss: 0.3021 - dice: 0.6979 - binary_accuracy: 0.8526 - val_loss: 0.3801 - val_dice: 0.6199 - val_binary_accuracy: 0.7852
# Epoch 17/50
# Epoch 00016: dice did not improve
# Epoch 00016: val_dice improved from 0.63389 to 0.63801, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6380-0.6960---0.hdf5
# 36s - loss: 0.3040 - dice: 0.6960 - binary_accuracy: 0.8426 - val_loss: 0.3620 - val_dice: 0.6380 - val_binary_accuracy: 0.8228
# Epoch 18/50
# Epoch 00017: dice did not improve
# Epoch 00017: val_dice improved from 0.63801 to 0.64015, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6401-0.6939---0.hdf5
# 36s - loss: 0.3061 - dice: 0.6939 - binary_accuracy: 0.8421 - val_loss: 0.3599 - val_dice: 0.6401 - val_binary_accuracy: 0.8251
# Epoch 19/50
# Epoch 00018: dice did not improve
# Epoch 00018: val_dice improved from 0.64015 to 0.64343, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6434-0.6918---0.hdf5
# 36s - loss: 0.3082 - dice: 0.6918 - binary_accuracy: 0.8449 - val_loss: 0.3566 - val_dice: 0.6434 - val_binary_accuracy: 0.8232
# Epoch 20/50
# Epoch 00019: dice improved from 0.69795 to 0.69832, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6438-0.6983---0.hdf5
# Epoch 00019: val_dice improved from 0.64343 to 0.64383, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6438-0.6983---0.hdf5
# 37s - loss: 0.3017 - dice: 0.6983 - binary_accuracy: 0.8478 - val_loss: 0.3562 - val_dice: 0.6438 - val_binary_accuracy: 0.8296
# Epoch 21/50
# Epoch 00020: dice did not improve
# Epoch 00020: val_dice did not improve
# 36s - loss: 0.3033 - dice: 0.6967 - binary_accuracy: 0.8501 - val_loss: 0.3672 - val_dice: 0.6328 - val_binary_accuracy: 0.8039
# Epoch 22/50
# Epoch 00021: dice did not improve
# Epoch 00021: val_dice did not improve
# 36s - loss: 0.3046 - dice: 0.6954 - binary_accuracy: 0.8491 - val_loss: 0.3713 - val_dice: 0.6287 - val_binary_accuracy: 0.7912
# Epoch 23/50
# Epoch 00022: dice did not improve
# Epoch 00022: val_dice did not improve
# 36s - loss: 0.3071 - dice: 0.6929 - binary_accuracy: 0.8457 - val_loss: 0.3710 - val_dice: 0.6290 - val_binary_accuracy: 0.7949
# Epoch 24/50
# Epoch 00023: dice improved from 0.69832 to 0.70466, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6464-0.7047---0.hdf5
# Epoch 00023: val_dice improved from 0.64383 to 0.64640, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6464-0.7047---0.hdf5
# 37s - loss: 0.2953 - dice: 0.7047 - binary_accuracy: 0.8465 - val_loss: 0.3536 - val_dice: 0.6464 - val_binary_accuracy: 0.8451
# Epoch 25/50
# Epoch 00024: dice did not improve
# Epoch 00024: val_dice improved from 0.64640 to 0.64869, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6487-0.7016---0.hdf5
# 36s - loss: 0.2984 - dice: 0.7016 - binary_accuracy: 0.8523 - val_loss: 0.3513 - val_dice: 0.6487 - val_binary_accuracy: 0.8383
# Epoch 26/50
# Epoch 00025: dice did not improve
# Epoch 00025: val_dice did not improve
# 36s - loss: 0.3006 - dice: 0.6994 - binary_accuracy: 0.8469 - val_loss: 0.3640 - val_dice: 0.6360 - val_binary_accuracy: 0.8464
# Epoch 27/50
# Epoch 00026: dice did not improve
# Epoch 00026: val_dice did not improve
# 36s - loss: 0.2988 - dice: 0.7012 - binary_accuracy: 0.8525 - val_loss: 0.3522 - val_dice: 0.6478 - val_binary_accuracy: 0.8309
# Epoch 28/50
# Epoch 00027: dice improved from 0.70466 to 0.70590, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6477-0.7059---0.hdf5
# Epoch 00027: val_dice did not improve
# 36s - loss: 0.2941 - dice: 0.7059 - binary_accuracy: 0.8523 - val_loss: 0.3523 - val_dice: 0.6477 - val_binary_accuracy: 0.8250
# Epoch 29/50
#
# Epoch 00028: reducing learning rate to 0.00249999994412.
# Epoch 00028: dice improved from 0.70590 to 0.70985, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6253-0.7098---0.hdf5
# Epoch 00028: val_dice did not improve
# 36s - loss: 0.2902 - dice: 0.7098 - binary_accuracy: 0.8533 - val_loss: 0.3747 - val_dice: 0.6253 - val_binary_accuracy: 0.7843
# Epoch 30/50
# Epoch 00029: dice did not improve
# Epoch 00029: val_dice improved from 0.64869 to 0.65403, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6540-0.7091---0.hdf5
# 36s - loss: 0.2909 - dice: 0.7091 - binary_accuracy: 0.8462 - val_loss: 0.3460 - val_dice: 0.6540 - val_binary_accuracy: 0.8296
# Epoch 31/50
# Epoch 00030: dice improved from 0.70985 to 0.71423, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6534-0.7142---0.hdf5
# Epoch 00030: val_dice did not improve
# 36s - loss: 0.2858 - dice: 0.7142 - binary_accuracy: 0.8530 - val_loss: 0.3466 - val_dice: 0.6534 - val_binary_accuracy: 0.8307
# Epoch 32/50
# Epoch 00031: dice improved from 0.71423 to 0.71776, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6542-0.7178---0.hdf5
# Epoch 00031: val_dice improved from 0.65403 to 0.65415, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6542-0.7178---0.hdf5
# 36s - loss: 0.2822 - dice: 0.7178 - binary_accuracy: 0.8580 - val_loss: 0.3458 - val_dice: 0.6542 - val_binary_accuracy: 0.8399
# Epoch 33/50
# Epoch 00032: dice did not improve
# Epoch 00032: val_dice improved from 0.65415 to 0.65425, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6543-0.7165---0.hdf5
# 36s - loss: 0.2835 - dice: 0.7165 - binary_accuracy: 0.8556 - val_loss: 0.3457 - val_dice: 0.6543 - val_binary_accuracy: 0.8264
# Epoch 34/50
# Epoch 00033: dice improved from 0.71776 to 0.72206, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6573-0.7221---0.hdf5
# Epoch 00033: val_dice improved from 0.65425 to 0.65726, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6573-0.7221---0.hdf5
# 36s - loss: 0.2779 - dice: 0.7221 - binary_accuracy: 0.8602 - val_loss: 0.3427 - val_dice: 0.6573 - val_binary_accuracy: 0.8399
# Epoch 35/50
# Epoch 00034: dice did not improve
# Epoch 00034: val_dice did not improve
# 36s - loss: 0.2819 - dice: 0.7181 - binary_accuracy: 0.8575 - val_loss: 0.3444 - val_dice: 0.6556 - val_binary_accuracy: 0.8365
# Epoch 36/50
# Epoch 00035: dice did not improve
# Epoch 00035: val_dice improved from 0.65726 to 0.65740, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6574-0.7211---0.hdf5
# 36s - loss: 0.2789 - dice: 0.7211 - binary_accuracy: 0.8598 - val_loss: 0.3426 - val_dice: 0.6574 - val_binary_accuracy: 0.8277
# Epoch 37/50
# Epoch 00036: dice did not improve
# Epoch 00036: val_dice did not improve
# 36s - loss: 0.2863 - dice: 0.7137 - binary_accuracy: 0.8516 - val_loss: 0.3455 - val_dice: 0.6545 - val_binary_accuracy: 0.8315
# Epoch 38/50
# Epoch 00037: dice improved from 0.72206 to 0.72231, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6575-0.7223---0.hdf5
# Epoch 00037: val_dice improved from 0.65740 to 0.65748, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6575-0.7223---0.hdf5
# 36s - loss: 0.2777 - dice: 0.7223 - binary_accuracy: 0.8609 - val_loss: 0.3425 - val_dice: 0.6575 - val_binary_accuracy: 0.8351
# Epoch 39/50
# Epoch 00038: dice did not improve
# Epoch 00038: val_dice did not improve
# 36s - loss: 0.2857 - dice: 0.7143 - binary_accuracy: 0.8544 - val_loss: 0.3445 - val_dice: 0.6555 - val_binary_accuracy: 0.8277
# Epoch 40/50
# Epoch 00039: dice did not improve
# Epoch 00039: val_dice improved from 0.65748 to 0.65790, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6579-0.7222---0.hdf5
# 36s - loss: 0.2778 - dice: 0.7222 - binary_accuracy: 0.8600 - val_loss: 0.3421 - val_dice: 0.6579 - val_binary_accuracy: 0.8434
# Epoch 41/50
# Epoch 00040: dice improved from 0.72231 to 0.72331, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6532-0.7233---0.hdf5
# Epoch 00040: val_dice did not improve
# 36s - loss: 0.2767 - dice: 0.7233 - binary_accuracy: 0.8639 - val_loss: 0.3468 - val_dice: 0.6532 - val_binary_accuracy: 0.8415
# Epoch 42/50
# Epoch 00041: dice did not improve
# Epoch 00041: val_dice did not improve
# 36s - loss: 0.2803 - dice: 0.7197 - binary_accuracy: 0.8607 - val_loss: 0.3442 - val_dice: 0.6558 - val_binary_accuracy: 0.8336
# Epoch 43/50
# Epoch 00042: dice improved from 0.72331 to 0.72480, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6554-0.7248---0.hdf5
# Epoch 00042: val_dice did not improve
# 36s - loss: 0.2752 - dice: 0.7248 - binary_accuracy: 0.8590 - val_loss: 0.3446 - val_dice: 0.6554 - val_binary_accuracy: 0.8368
# Epoch 44/50
#
# Epoch 00043: reducing learning rate to 0.00124999997206.
# Epoch 00043: dice did not improve
# Epoch 00043: val_dice did not improve
# 36s - loss: 0.2758 - dice: 0.7242 - binary_accuracy: 0.8635 - val_loss: 0.3477 - val_dice: 0.6523 - val_binary_accuracy: 0.8206
# Epoch 45/50
# Epoch 00044: dice improved from 0.72480 to 0.72633, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6569-0.7263---0.hdf5
# Epoch 00044: val_dice did not improve
# 36s - loss: 0.2737 - dice: 0.7263 - binary_accuracy: 0.8629 - val_loss: 0.3431 - val_dice: 0.6569 - val_binary_accuracy: 0.8420
# Epoch 46/50
# Epoch 00045: dice improved from 0.72633 to 0.72840, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6606-0.7284---0.hdf5
# Epoch 00045: val_dice improved from 0.65790 to 0.66056, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6606-0.7284---0.hdf5
# 36s - loss: 0.2716 - dice: 0.7284 - binary_accuracy: 0.8645 - val_loss: 0.3394 - val_dice: 0.6606 - val_binary_accuracy: 0.8391
# Epoch 47/50
# Epoch 00046: dice did not improve
# Epoch 00046: val_dice improved from 0.66056 to 0.66236, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6624-0.7283---0.hdf5
# 36s - loss: 0.2717 - dice: 0.7283 - binary_accuracy: 0.8642 - val_loss: 0.3376 - val_dice: 0.6624 - val_binary_accuracy: 0.8356
# Epoch 48/50
# Epoch 00047: dice improved from 0.72840 to 0.72956, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6637-0.7296---0.hdf5
# Epoch 00047: val_dice improved from 0.66236 to 0.66373, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6637-0.7296---0.hdf5
# 36s - loss: 0.2704 - dice: 0.7296 - binary_accuracy: 0.8651 - val_loss: 0.3363 - val_dice: 0.6637 - val_binary_accuracy: 0.8397
# Epoch 49/50
# Epoch 00048: dice did not improve
# Epoch 00048: val_dice improved from 0.66373 to 0.66395, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6640-0.7277---0.hdf5
# 36s - loss: 0.2723 - dice: 0.7277 - binary_accuracy: 0.8658 - val_loss: 0.3360 - val_dice: 0.6640 - val_binary_accuracy: 0.8375
# Epoch 50/50
# Epoch 00049: dice improved from 0.72956 to 0.72974, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6643-0.7297---0.hdf5
# Epoch 00049: val_dice improved from 0.66395 to 0.66427, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6643-0.7297---0.hdf5
# 37s - loss: 0.2703 - dice: 0.7297 - binary_accuracy: 0.8649 - val_loss: 0.3357 - val_dice: 0.6643 - val_binary_accuracy: 0.8344
# 2017-07-30 23:23:34.766025 ------------> 1
# Train on 111 samples, validate on 57 samples
# Epoch 1/50
# Epoch 00000: dice improved from -inf to 0.41230, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.4732-0.4123---1.hdf5
# Epoch 00000: val_dice improved from -inf to 0.47322, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.4732-0.4123---1.hdf5
# 39s - loss: 0.5877 - dice: 0.4123 - binary_accuracy: 0.3111 - val_loss: 0.5268 - val_dice: 0.4732 - val_binary_accuracy: 0.3370
# Epoch 2/50
# Epoch 00001: dice improved from 0.41230 to 0.46860, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.5140-0.4686---1.hdf5
# Epoch 00001: val_dice improved from 0.47322 to 0.51403, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.5140-0.4686---1.hdf5
# 39s - loss: 0.5314 - dice: 0.4686 - binary_accuracy: 0.5323 - val_loss: 0.4860 - val_dice: 0.5140 - val_binary_accuracy: 0.8212
# Epoch 3/50
# Epoch 00002: dice improved from 0.46860 to 0.50550, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.4516-0.5055---1.hdf5
# Epoch 00002: val_dice did not improve
# 38s - loss: 0.4945 - dice: 0.5055 - binary_accuracy: 0.6437 - val_loss: 0.5484 - val_dice: 0.4516 - val_binary_accuracy: 0.3370
# Epoch 4/50
# Epoch 00003: dice did not improve
# Epoch 00003: val_dice did not improve
# 36s - loss: 0.5740 - dice: 0.4260 - binary_accuracy: 0.3111 - val_loss: 0.5484 - val_dice: 0.4516 - val_binary_accuracy: 0.3370
# Epoch 5/50
# Epoch 00004: dice did not improve
# Epoch 00004: val_dice did not improve
# 36s - loss: 0.5740 - dice: 0.4260 - binary_accuracy: 0.3111 - val_loss: 0.5484 - val_dice: 0.4516 - val_binary_accuracy: 0.3370
# Epoch 6/50
#
# Epoch 00005: reducing learning rate to 0.00499999988824.
# Epoch 00005: dice did not improve
# Epoch 00005: val_dice did not improve
# 36s - loss: 0.5740 - dice: 0.4260 - binary_accuracy: 0.3111 - val_loss: 0.5484 - val_dice: 0.4516 - val_binary_accuracy: 0.3370
# Epoch 7/50
#
# Epoch 00006: reducing learning rate to 0.00249999994412.
# Epoch 00006: dice did not improve
# Epoch 00006: val_dice did not improve
# 36s - loss: 0.5740 - dice: 0.4260 - binary_accuracy: 0.3111 - val_loss: 0.5484 - val_dice: 0.4516 - val_binary_accuracy: 0.3370
# Epoch 8/50
# Epoch 00007: dice did not improve
# Epoch 00007: val_dice did not improve
# 36s - loss: 0.5740 - dice: 0.4260 - binary_accuracy: 0.3111 - val_loss: 0.5484 - val_dice: 0.4516 - val_binary_accuracy: 0.3370
# Epoch 00007: early stopping
# 2017-07-30 23:28:32.818706 ------------> 2
# Train on 114 samples, validate on 54 samples
# Epoch 1/50
# Epoch 00000: dice improved from -inf to 0.36977, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.4475-0.3698---2.hdf5
# Epoch 00000: val_dice improved from -inf to 0.44750, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.4475-0.3698---2.hdf5
# 40s - loss: 0.6302 - dice: 0.3698 - binary_accuracy: 0.3185 - val_loss: 0.5525 - val_dice: 0.4475 - val_binary_accuracy: 0.3377
# Epoch 2/50
# Epoch 00001: dice improved from 0.36977 to 0.42997, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.4637-0.4300---2.hdf5
# Epoch 00001: val_dice improved from 0.44750 to 0.46372, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.4637-0.4300---2.hdf5
# 40s - loss: 0.5700 - dice: 0.4300 - binary_accuracy: 0.3115 - val_loss: 0.5363 - val_dice: 0.4637 - val_binary_accuracy: 0.3377
# Epoch 3/50
# Epoch 00002: dice improved from 0.42997 to 0.44665, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.4867-0.4467---2.hdf5
# Epoch 00002: val_dice improved from 0.46372 to 0.48668, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.4867-0.4467---2.hdf5
# 40s - loss: 0.5533 - dice: 0.4467 - binary_accuracy: 0.3115 - val_loss: 0.5133 - val_dice: 0.4867 - val_binary_accuracy: 0.3377
# Epoch 4/50
# Epoch 00003: dice improved from 0.44665 to 0.46841, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.5116-0.4684---2.hdf5
# Epoch 00003: val_dice improved from 0.48668 to 0.51156, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.5116-0.4684---2.hdf5
# 39s - loss: 0.5316 - dice: 0.4684 - binary_accuracy: 0.4580 - val_loss: 0.4884 - val_dice: 0.5116 - val_binary_accuracy: 0.6727
# Epoch 5/50
# Epoch 00004: dice improved from 0.46841 to 0.56585, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6508-0.5659---2.hdf5
# Epoch 00004: val_dice improved from 0.51156 to 0.65079, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6508-0.5659---2.hdf5
# 39s - loss: 0.4341 - dice: 0.5659 - binary_accuracy: 0.7598 - val_loss: 0.3492 - val_dice: 0.6508 - val_binary_accuracy: 0.8187
# Epoch 6/50
# Epoch 00005: dice improved from 0.56585 to 0.61407, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6517-0.6141---2.hdf5
# Epoch 00005: val_dice improved from 0.65079 to 0.65166, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6517-0.6141---2.hdf5
# 39s - loss: 0.3859 - dice: 0.6141 - binary_accuracy: 0.8075 - val_loss: 0.3483 - val_dice: 0.6517 - val_binary_accuracy: 0.7924
# Epoch 7/50
# Epoch 00006: dice did not improve
# Epoch 00006: val_dice improved from 0.65166 to 0.65524, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6552-0.6049---2.hdf5
# 38s - loss: 0.3951 - dice: 0.6049 - binary_accuracy: 0.7883 - val_loss: 0.3448 - val_dice: 0.6552 - val_binary_accuracy: 0.8088
# Epoch 8/50
# Epoch 00007: dice improved from 0.61407 to 0.62443, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6626-0.6244---2.hdf5
# Epoch 00007: val_dice improved from 0.65524 to 0.66263, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6626-0.6244---2.hdf5
# 38s - loss: 0.3756 - dice: 0.6244 - binary_accuracy: 0.8148 - val_loss: 0.3374 - val_dice: 0.6626 - val_binary_accuracy: 0.8137
# Epoch 9/50
# Epoch 00008: dice improved from 0.62443 to 0.63789, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.5342-0.6379---2.hdf5
# Epoch 00008: val_dice did not improve
# 37s - loss: 0.3621 - dice: 0.6379 - binary_accuracy: 0.8133 - val_loss: 0.4658 - val_dice: 0.5342 - val_binary_accuracy: 0.5655
# Epoch 10/50
# Epoch 00009: dice did not improve
# Epoch 00009: val_dice improved from 0.66263 to 0.67045, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6704-0.6134---2.hdf5
# 37s - loss: 0.3866 - dice: 0.6134 - binary_accuracy: 0.7929 - val_loss: 0.3296 - val_dice: 0.6704 - val_binary_accuracy: 0.8018
# Epoch 11/50
# Epoch 00010: dice improved from 0.63789 to 0.63887, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6829-0.6389---2.hdf5
# Epoch 00010: val_dice improved from 0.67045 to 0.68294, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6829-0.6389---2.hdf5
# 37s - loss: 0.3611 - dice: 0.6389 - binary_accuracy: 0.8188 - val_loss: 0.3171 - val_dice: 0.6829 - val_binary_accuracy: 0.8351
# Epoch 12/50
# Epoch 00011: dice improved from 0.63887 to 0.64609, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6770-0.6461---2.hdf5
# Epoch 00011: val_dice did not improve
# 37s - loss: 0.3539 - dice: 0.6461 - binary_accuracy: 0.8296 - val_loss: 0.3230 - val_dice: 0.6770 - val_binary_accuracy: 0.8433
# Epoch 13/50
# Epoch 00012: dice improved from 0.64609 to 0.64960, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6856-0.6496---2.hdf5
# Epoch 00012: val_dice improved from 0.68294 to 0.68557, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6856-0.6496---2.hdf5
# 37s - loss: 0.3504 - dice: 0.6496 - binary_accuracy: 0.8326 - val_loss: 0.3144 - val_dice: 0.6856 - val_binary_accuracy: 0.8237
# Epoch 14/50
# Epoch 00013: dice improved from 0.64960 to 0.65350, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6861-0.6535---2.hdf5
# Epoch 00013: val_dice improved from 0.68557 to 0.68613, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6861-0.6535---2.hdf5
# 37s - loss: 0.3465 - dice: 0.6535 - binary_accuracy: 0.8355 - val_loss: 0.3139 - val_dice: 0.6861 - val_binary_accuracy: 0.8398
# Epoch 15/50
# Epoch 00014: dice improved from 0.65350 to 0.65425, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6930-0.6543---2.hdf5
# Epoch 00014: val_dice improved from 0.68613 to 0.69297, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6930-0.6543---2.hdf5
# 37s - loss: 0.3457 - dice: 0.6543 - binary_accuracy: 0.8379 - val_loss: 0.3070 - val_dice: 0.6930 - val_binary_accuracy: 0.8383
# Epoch 16/50
# Epoch 00015: dice improved from 0.65425 to 0.66375, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6963-0.6638---2.hdf5
# Epoch 00015: val_dice improved from 0.69297 to 0.69631, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6963-0.6638---2.hdf5
# 37s - loss: 0.3362 - dice: 0.6638 - binary_accuracy: 0.8382 - val_loss: 0.3037 - val_dice: 0.6963 - val_binary_accuracy: 0.8438
# Epoch 17/50
# Epoch 00016: dice did not improve
# Epoch 00016: val_dice did not improve
# 37s - loss: 0.3374 - dice: 0.6626 - binary_accuracy: 0.8423 - val_loss: 0.3413 - val_dice: 0.6587 - val_binary_accuracy: 0.8526
# Epoch 18/50
# Epoch 00017: dice did not improve
# Epoch 00017: val_dice did not improve
# 37s - loss: 0.3399 - dice: 0.6601 - binary_accuracy: 0.8319 - val_loss: 0.3067 - val_dice: 0.6933 - val_binary_accuracy: 0.8393
# Epoch 19/50
# Epoch 00018: dice did not improve
# Epoch 00018: val_dice improved from 0.69631 to 0.70146, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.7015-0.6620---2.hdf5
# 37s - loss: 0.3380 - dice: 0.6620 - binary_accuracy: 0.8420 - val_loss: 0.2985 - val_dice: 0.7015 - val_binary_accuracy: 0.8402
# Epoch 20/50
# Epoch 00019: dice improved from 0.66375 to 0.67428, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.6859-0.6743---2.hdf5
# Epoch 00019: val_dice did not improve
# 37s - loss: 0.3257 - dice: 0.6743 - binary_accuracy: 0.8514 - val_loss: 0.3141 - val_dice: 0.6859 - val_binary_accuracy: 0.8127
# Epoch 21/50
# Epoch 00020: dice did not improve
# Epoch 00020: val_dice did not improve
# 37s - loss: 0.3398 - dice: 0.6602 - binary_accuracy: 0.8454 - val_loss: 0.3281 - val_dice: 0.6719 - val_binary_accuracy: 0.7911
# Epoch 22/50
# Epoch 00021: dice did not improve
# Epoch 00021: val_dice did not improve
# 37s - loss: 0.3321 - dice: 0.6679 - binary_accuracy: 0.8490 - val_loss: 0.3053 - val_dice: 0.6947 - val_binary_accuracy: 0.8169
# Epoch 23/50
#
# Epoch 00022: reducing learning rate to 0.00499999988824.
# Epoch 00022: dice did not improve
# Epoch 00022: val_dice did not improve
# 37s - loss: 0.3273 - dice: 0.6727 - binary_accuracy: 0.8525 - val_loss: 0.3095 - val_dice: 0.6905 - val_binary_accuracy: 0.8107
# Epoch 24/50
#
# Epoch 00023: reducing learning rate to 0.00249999994412.
# Epoch 00023: dice did not improve
# Epoch 00023: val_dice did not improve
# 37s - loss: 0.3334 - dice: 0.6666 - binary_accuracy: 0.8394 - val_loss: 0.2991 - val_dice: 0.7009 - val_binary_accuracy: 0.8270
# Epoch 25/50
# Epoch 00024: dice improved from 0.67428 to 0.68082, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.7033-0.6808---2.hdf5
# Epoch 00024: val_dice improved from 0.70146 to 0.70327, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.7033-0.6808---2.hdf5
# 37s - loss: 0.3192 - dice: 0.6808 - binary_accuracy: 0.8514 - val_loss: 0.2967 - val_dice: 0.7033 - val_binary_accuracy: 0.8299
# Epoch 26/50
# Epoch 00025: dice did not improve
# Epoch 00025: val_dice improved from 0.70327 to 0.70397, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.7040-0.6797---2.hdf5
# 37s - loss: 0.3203 - dice: 0.6797 - binary_accuracy: 0.8546 - val_loss: 0.2960 - val_dice: 0.7040 - val_binary_accuracy: 0.8304
# Epoch 27/50
# Epoch 00026: dice improved from 0.68082 to 0.68916, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.7085-0.6892---2.hdf5
# Epoch 00026: val_dice improved from 0.70397 to 0.70846, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.7085-0.6892---2.hdf5
# 37s - loss: 0.3108 - dice: 0.6892 - binary_accuracy: 0.8557 - val_loss: 0.2915 - val_dice: 0.7085 - val_binary_accuracy: 0.8457
# Epoch 28/50
# Epoch 00027: dice did not improve
# Epoch 00027: val_dice did not improve
# 37s - loss: 0.3142 - dice: 0.6858 - binary_accuracy: 0.8582 - val_loss: 0.2989 - val_dice: 0.7011 - val_binary_accuracy: 0.8276
# Epoch 29/50
# Epoch 00028: dice did not improve
# Epoch 00028: val_dice did not improve
# 37s - loss: 0.3171 - dice: 0.6829 - binary_accuracy: 0.8521 - val_loss: 0.2916 - val_dice: 0.7084 - val_binary_accuracy: 0.8455
# Epoch 30/50
# Epoch 00029: dice did not improve
# Epoch 00029: val_dice did not improve
# 37s - loss: 0.3187 - dice: 0.6813 - binary_accuracy: 0.8578 - val_loss: 0.2924 - val_dice: 0.7076 - val_binary_accuracy: 0.8435
# Epoch 31/50
#
# Epoch 00030: reducing learning rate to 0.00124999997206.
# Epoch 00030: dice did not improve
# Epoch 00030: val_dice improved from 0.70846 to 0.70876, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.7088-0.6879---2.hdf5
# 37s - loss: 0.3121 - dice: 0.6879 - binary_accuracy: 0.8585 - val_loss: 0.2912 - val_dice: 0.7088 - val_binary_accuracy: 0.8415
# Epoch 32/50
# Epoch 00031: dice did not improve
# Epoch 00031: val_dice did not improve
# 37s - loss: 0.3114 - dice: 0.6886 - binary_accuracy: 0.8603 - val_loss: 0.2927 - val_dice: 0.7073 - val_binary_accuracy: 0.8469
# Epoch 33/50
# Epoch 00032: dice improved from 0.68916 to 0.68983, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.7028-0.6898---2.hdf5
# Epoch 00032: val_dice did not improve
# 37s - loss: 0.3102 - dice: 0.6898 - binary_accuracy: 0.8609 - val_loss: 0.2972 - val_dice: 0.7028 - val_binary_accuracy: 0.8514
# Epoch 34/50
# Epoch 00033: dice improved from 0.68983 to 0.69001, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.7080-0.6900---2.hdf5
# Epoch 00033: val_dice did not improve
# 37s - loss: 0.3100 - dice: 0.6900 - binary_accuracy: 0.8599 - val_loss: 0.2920 - val_dice: 0.7080 - val_binary_accuracy: 0.8431
# Epoch 35/50
#
# Epoch 00034: reducing learning rate to 0.00062499998603.
# Epoch 00034: dice did not improve
# Epoch 00034: val_dice did not improve
# 37s - loss: 0.3101 - dice: 0.6899 - binary_accuracy: 0.8623 - val_loss: 0.2933 - val_dice: 0.7067 - val_binary_accuracy: 0.8473
# Epoch 36/50
# Epoch 00035: dice improved from 0.69001 to 0.69031, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.7085-0.6903---2.hdf5
# Epoch 00035: val_dice did not improve
# 37s - loss: 0.3097 - dice: 0.6903 - binary_accuracy: 0.8567 - val_loss: 0.2915 - val_dice: 0.7085 - val_binary_accuracy: 0.8464
# Epoch 37/50
# Epoch 00036: dice improved from 0.69031 to 0.69350, saving model to ../Temp/NewStep/Level-2/V1-UNET-val_dice=0.7081-0.6935---2.hdf5
# Epoch 00036: val_dice did not improve
# 37s - loss: 0.3065 - dice: 0.6935 - binary_accuracy: 0.8640 - val_loss: 0.2919 - val_dice: 0.7081 - val_binary_accuracy: 0.8457
# Epoch 00036: early stopping
# 2017-07-30 23:51:56.257858

# %%
#!ls ../Temp/TempTempG5M5KFold -la | tail
#!ls ../Temp/TempTempG5M5KFold10 -la | tail
# !ls ../Temp/NewStep/StandartF3 -la | tail
# !ls ../Temp/NewStep/Level-2 -la | tail
# Out:
# -rwxrwxrwx 1 boba boba 248917120 июл 30 19:42 V1-UNET-val_dice=0.7426-0.7271---1.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 20:33 V1-UNET-val_dice=0.7449-0.7080---2.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 20:37 V1-UNET-val_dice=0.7482-0.7316---2.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 19:48 V1-UNET-val_dice=0.7500-0.7460---1.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 20:38 V1-UNET-val_dice=0.7502-0.7177---2.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 19:50 V1-UNET-val_dice=0.7510-0.7538---1.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 19:52 V1-UNET-val_dice=0.7516-0.7578---1.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 19:53 V1-UNET-val_dice=0.7528-0.7595---1.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 20:39 V1-UNET-val_dice=0.7613-0.7235---2.hdf5
# -rwxrwxrwx 1 boba boba 248917120 июл 30 20:42 V1-UNET-val_dice=0.7655-0.7360---2.hdf5
# -rwxrwxrwx 1 boba boba 15510512 июл 30 23:38 V1-UNET-val_dice=0.6963-0.6638---2.hdf5
# -rwxrwxrwx 1 boba boba 15510512 июл 30 23:40 V1-UNET-val_dice=0.7015-0.6620---2.hdf5
# -rwxrwxrwx 1 boba boba 15510512 июл 30 23:49 V1-UNET-val_dice=0.7028-0.6898---2.hdf5
# -rwxrwxrwx 1 boba boba 15510512 июл 30 23:44 V1-UNET-val_dice=0.7033-0.6808---2.hdf5
# -rwxrwxrwx 1 boba boba 15510512 июл 30 23:45 V1-UNET-val_dice=0.7040-0.6797---2.hdf5
# -rwxrwxrwx 1 boba boba 15510512 июл 30 23:50 V1-UNET-val_dice=0.7080-0.6900---2.hdf5
# -rwxrwxrwx 1 boba boba 15510512 июл 30 23:51 V1-UNET-val_dice=0.7081-0.6935---2.hdf5
# -rwxrwxrwx 1 boba boba 15510512 июл 30 23:45 V1-UNET-val_dice=0.7085-0.6892---2.hdf5
# -rwxrwxrwx 1 boba boba 15510512 июл 30 23:51 V1-UNET-val_dice=0.7085-0.6903---2.hdf5
# -rwxrwxrwx 1 boba boba 15510512 июл 30 23:48 V1-UNET-val_dice=0.7088-0.6879---2.hdf5

# %%
if 0 : model10 = load_model('../Temp/TrainModel001+G+M/V1-UNET-0.8511.hdf5')
if 0 : model10 = load_model('../Temp/V1-UNET-0.8853.hdf5')
#if 1 : model10 = load_model('../Temp/TempTempM3/V1-UNET-0.9054.hdf5')
if 0 : model10.load_weights('../Temp/TempTempM3/V1-UNET-0.9054.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5/V1-UNET-val_dice=0.7307.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7879-2.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7632-2.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7660-2.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7828-2.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFold5/V1-UNET-val_dice=0.8224-0.8516---1.hdf5') # 769128
if 0 : model10.load_weights('../Temp/TempTempG5M5KFold5/V1-UNET-val_dice=0.8217-0.8655---1.hdf5') # 765XXX
if 0 : model10.load_weights('../Temp/TempTempG5M5KFold5/V1-UNET-val_dice=0.8227-0.8643---3.hdf5')    
if 0 : model10.load_weights('../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8315-0.8617---9.hdf5')    
if 0 : model10.load_weights('../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7655-0.7360---2.hdf5')    
if 1 : model10.load_weights('../Temp/NewStep/Level-2/V1-UNET-val_dice=0.7088-0.6879---2.hdf5')

# %%
# %time trP = model10.predict(trX,batch_size=batch_size)
# Out:
# CPU times: user 9.96 s, sys: 2.29 s, total: 12.2 s
# Wall time: 11.8 s

# %%
trP01 = trP
trP01[trP>0.5] =1.0
trP01[trP<=0.5]=0.0
trP01 = trP01.astype(np.uint8)

# %%
if 0 : # Ощутимых результатов не дает, увеличение в +10-100
    times, medianP = 3,5
    for i in range(trP01.shape[0]) :
        for j in range(times) :
            trP01[i,:,:,0] = cv.medianBlur(trP01[i],medianP)

# %%
iii = 0
print(trX[0].shape,trY[0].shape,trP.shape,trP.min(),trP.max())
for ii in range(iii,iii+10) :
    plt.figure(figsize=(15,5))
    plt.subplot(151); plt.imshow(trX[ii,:,:,0],'gray'); 
    plt.subplot(152); plt.imshow(trY[ii,:,:,0],'gray'); 
    plt.subplot(153); plt.imshow(trP[ii,:,:,0],'gray'); 
    plt.subplot(154); plt.imshow(trP01[ii,:,:,0],'gray'); 
    plt.subplot(155); plt.hist(trP[ii,:,:,0].ravel(),bins=50); 
    plt.show()
plt.close()
# Out:
# (512, 512, 3) (512, 512, 1) (168, 512, 512, 1) 0.0 1.0

# %%
# Calculate F1-micro

# %%
TP = (trY[:,6:506,6:506,0]*trP01[:,6:506,6:506,0]).sum()
TN = ((1.0-trY[:,6:506,6:506,0])*(1.0-trP01[:,6:506,6:506,0])).sum()
FP = ((trY[:,6:506,6:506,0])*(1.0-trP01[:,6:506,6:506,0])).sum()
FN = ((1.0-trY[:,6:506,6:506,0])*(trP01[:,6:506,6:506,0])).sum()

P  = TP/(TP+FP) if (TP+FP)>0.0 else 1.0
R  = TP/(TP+FN) if (TP+FN)>0.0 else 0.0

F1 = 2.0*P*R/(P+R) if (P+R)>0.0 else 0.0

TP,TN,FP,FN,P,R,F1
#P*R,P+R, 2.0*P*R/(P+R)
# Out:
# (11508829.0,
#  23975136.0,
#  2579391.0,
#  3936644.0,
#  0.81691150478910746,
#  0.74512635514626191,
#  0.77936944763392779)

# %%
# Calculate DI- dice.mean()

# %%
dice, XX = [],[]
for i in range(trP.shape[0]) :
    G = trY  [i,6:506,6:506,0].sum()
    S = trP01[i,6:506,6:506,0].sum()
    X = (trY [i,6:506,6:506,0]*trP01[i,6:506,6:506,0]).sum()
    XX.append(X)
    dice.append((2.0*X/(G+S) if G+S>0 else 1.0))
di = (np.array(dice)).mean()
di #,np.array(dice)  #,np.array(XX)
# Out:
# 0.7086494180315952

# %%
plt.hist(np.array(dice),bins=40); plt.show()
plt.plot(np.array(dice)); plt.show()

# %%
1000000*(F1+di)/2.0
# Out:
# 744009.43283276155

# %%
#np.array(dice)<0.4

# %%
# Подготовка test решения

# %%
if flagGray :
    trO, trO0 = [], np.zeros((512,512,1))
else :
    trO, trO0 = [], np.zeros((512,512,3))

for xx in listTest :
    img = cv.imread(os.path.join(dirTest,xx),-1)
    if 1 and (Gauss or Median): 
        for cc in range(img.shape[2]) : 
            if Gauss  : img[:,:,cc] = cv.GaussianBlur(img[:,:,cc],(Gauss,Gauss),0);
            if Median : img[:,:,cc] = cv.medianBlur  (img[:,:,cc],Median);
    #print(img.mean(),msk.mean())
    if flagGray :
        img = cv.cvtColor(img,cv.COLOR_RGB2GRAY);
        trO0[6:506,6:506,0] = img[:,:]/255.0
    else :
        trO0[6:506,6:506,:] = img[:,:,:]/255.0
    trO.append(trO0.copy())
    #print(trX0.mean(),trY0.mean(),trX1[-1].mean(),trY1[-1].mean())

#print([trY[xx].mean() for xx in range(10)])
trO = np.array(trO)

if 1 :
    for cc in range(meanX.shape[0]) : 
        trO[:,6:506,6:506,cc] -= meanX[cc]
    
trO.shape, trO.min(), trO.max()
#[trY[xx].mean() for xx in range(10)]
# Out:
# ((162, 512, 512, 3), -0.64172901643310909, 0.47912580261435694)

# %%
# %time trOP = model10.predict(trO,batch_size=batch_size)
# Out:
# CPU times: user 14.9 s, sys: 3.18 s, total: 18.1 s
# Wall time: 17.4 s

# %%
trOP01 = trOP
trOP01[trOP>0.5] =1.0
trOP01[trOP<=0.5]=0.0

# %%
iii = 40
print(trO[0].shape,trP01[0].shape,trOP01.shape,trOP.min(),trOP.max())
for ii in range(iii,iii+10) :
    plt.figure(figsize=(15,5))
    plt.subplot(151); plt.imshow(trO[ii,:,:,0]); 
    plt.subplot(152); plt.imshow(trOP01[ii,:,:,0],'gray'); 
    plt.subplot(153); plt.imshow(trOP[ii,:,:,0],'gray'); 
    plt.subplot(154); plt.hist(trOP[ii,:,:,0].ravel(),bins=50); 
    plt.show()
plt.close()
# Out:
# (512, 512, 3) (512, 512, 1) (162, 512, 512, 1) 0.0 1.0

# %%
# Формирование выходной директории

# %%
def convert_to_binary(truth_png_file, truth_txt_file):
    im = Image.open(truth_png_file) #Can be many different formats.
    pix = im.load()
    with open(truth_txt_file, 'w') as out:
        for x in xrange(500):
            for y in xrange(500):
                out.write(str(int(pix[x, y] > 0)))
            out.write('\n')

if not os.path.exists('../Temp/random_submission'):
    os.makedirs('../Temp/random_submission')

# Training
for i in range(len(listTrain)) :
    fn = listTrain[i]
    truth_txt_file = '../Temp/random_submission/' + fn.split('.')[0] + '_mask.txt'
    with open(truth_txt_file, 'w') as out:
        for x in xrange(500):
            for y in xrange(500):
                out.write(str(int(trP01[i,y+6, x+6] > 0.0)))
            out.write('\n')
    out.close()
    
# Testing
for i in range(len(listTest)) :
    fn = listTest[i]
    truth_txt_file = '../Temp/random_submission/' + fn.split('.')[0] + '_mask.txt'
    with open(truth_txt_file, 'w') as out:
        for x in xrange(500):
            for y in xrange(500):
                out.write(str(int(trOP01[i,y+6, x+6] > 0.0)))
            out.write('\n')
    out.close()

# %%
import shutil

# %%
xx=shutil.make_archive('../Result/topcoderkonica','zip','../Temp/random_submission')
xx
# Out:
# '/media/boba/DATA/boba/Working/TopCoder/2017-07-25-Konica-Minolta/Result/topcoderkonica.zip'

# %%
# !ls ../Temp -la
# Out:
# total 4610508
# drwxrwxrwx 1 boba boba      4096 июл 26 10:58 .
# drwxrwxrwx 1 boba boba      4096 июл 26 10:11 ..
# drwxrwxrwx 1 boba boba         0 июл 25 18:17 .ipynb_checkpoints
# drwxrwxrwx 1 boba boba     61440 июл 26 09:14 random_submission
# -rwxrwxrwx 1 boba boba   1057596 июл 26 10:58 random_submission.zip
# drwxrwxrwx 1 boba boba         0 июл 25 23:35 TrainModel001-G-M
# drwxrwxrwx 1 boba boba         0 июл 25 22:21 TrainModel001-G+M
# drwxrwxrwx 1 boba boba         0 июл 25 21:48 TrainModel001+G-M
# drwxrwxrwx 1 boba boba      4096 июл 25 21:05 TrainModel001+G+M
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:02 V1-UNET-0.8167.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:08 V1-UNET-0.8275.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 18:33 V1-UNET-0.8305.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 18:02 V1-UNET-0.8418.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:09 V1-UNET-0.8486.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:09 V1-UNET-0.8593.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 18:34 V1-UNET-0.8601.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:21 V1-UNET-0.8602.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:22 V1-UNET-0.8605.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:35 V1-UNET-0.8628.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:35 V1-UNET-0.8633.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:23 V1-UNET-0.8635.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:36 V1-UNET-0.8645.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:36 V1-UNET-0.8652.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:24 V1-UNET-0.8655.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:11 V1-UNET-0.8793.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:13 V1-UNET-0.8796.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:14 V1-UNET-0.8808.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 18:02 V1-UNET-0.8853.hdf5

# %%
# !ls ../Work -la
#!ls ../Temp/random_submission
# Out:
# total 80768
# drwxrwxrwx 1 boba boba        0 июл 26 09:17 .
# drwxrwxrwx 1 boba boba     4096 июл 25 15:24 ..
# -rwxrwxrwx 1 boba boba 82700662 июл 26 09:32 topcoderkonica.zip

# %%
if False :
    save_model(model10,'../Data-Keras/Models/model-UNet.h5')
    model10.save_weights('../Data-Keras/Models/model-UNet-weights.h5')

# %%
rrr=pd.DataFrame(res,columns=['image_name','tags']); rrr.head(); 
suffixDT = (datetime.datetime.now()).strftime('%Y-%m-%d-%H-%M-%S'); print(suffixDT)
rrr.to_csv('../Result/vss'+suffixDT+'.csv',index=False);
# Out:
# 2017-05-20-05-51-18
