# %%
##
## UNet 
##
## Взята идея по описанию из https://github.com/pietz/unet-keras
##

# %%
import sys,os,datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import fbeta_score
import sklearn.metrics as skm
from __future__ import print_function

# %%
print(np.__version__);
print(pd.__version__);
# Out:
# 1.13.1
# 0.19.2

# %%
import  cv2 as cv
cv.__version__
# Out:
# '3.2.0'

# %%
#from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.models import Sequential, save_model, load_model, Input, Model
from keras.layers import Convolution2D, MaxPooling2D, Convolution1D, MaxPooling1D, UpSampling2D, ZeroPadding2D
from keras.layers import Conv2D, Concatenate, Reshape
from keras.layers import Activation, Dropout, Flatten, Dense, Permute
from keras.layers.normalization import BatchNormalization
import keras.optimizers
from keras.callbacks import EarlyStopping,ReduceLROnPlateau,ModelCheckpoint
import keras.backend as K
# Out:
# Using TensorFlow backend.

# %%
keras.__version__
# Out:
# '2.0.6'

# %%
#---------------------------------------------------------------------

# %%
# !ls -la ..
# !ls -la ../Data
# !ls -la ../Data/training
# Out:
# total 25
# drwxrwxrwx 1 boba boba 4096 июл 26 11:10 .
# drwxrwxrwx 1 boba boba    0 июл 25 09:21 ..
# drwxrwxrwx 1 boba boba 4096 июл 25 09:23 Data
# drwxrwxrwx 1 boba boba    0 июл 25 09:22 Data-Arch
# drwxrwxrwx 1 boba boba    0 июл 25 09:26 Data-Keras
# drwxrwxrwx 1 boba boba 4096 июл 27 21:53 .git
# -rwxrwxrwx 2 boba boba  130 июл  9 12:02 .gitignore
# drwxrwxrwx 1 boba boba    0 июл 26 10:11 .ipynb_checkpoints
# drwxrwxrwx 1 boba boba    0 июл 27 21:54 Jupyter
# drwxrwxrwx 1 boba boba 4096 июл 28 13:40 Jupyter-Net
# drwxrwxrwx 1 boba boba 4096 июл 27 21:53 Result
# drwxrwxrwx 1 boba boba 4096 июл 27 20:58 Temp
# drwxrwxrwx 1 boba boba    0 июл 27 07:53 Work
# total 16
# drwxrwxrwx 1 boba boba 4096 июл 25 09:23 .
# drwxrwxrwx 1 boba boba 4096 июл 26 11:10 ..
# -rwxrwxrwx 2 boba boba 1060 июн 13 15:55 null_submission_generator.py
# -rwxrwxrwx 2 boba boba 1197 июн 13 16:03 random_submission_generator.py
# drwxrwxrwx 1 boba boba    0 июл 24 23:10 testing
# drwxrwxrwx 1 boba boba    0 июл 25 08:14 training
# total 220
# drwxrwxrwx 1 boba boba      0 июл 25 08:14 .
# drwxrwxrwx 1 boba boba   4096 июл 25 09:23 ..
# -rwxrwxrwx 2 boba boba  14340 июн 20 10:04 .DS_Store
# drwxrwxrwx 1 boba boba  40960 июл 25 08:14 images
# drwxrwxrwx 1 boba boba 163840 июл 25 09:17 truth

# %%
dirData = '../Data'
dirTemp = '../Temp'
dirWork = '../Work'

dirTest  = os.path.join(dirData,'testing','images')
dirTrain = os.path.join(dirData,'training','images')
dirMask  = os.path.join(dirData,'training','truth')

# %%
listTrain = os.listdir(dirTrain)
listMask  = os.listdir(dirMask)
listTest  = os.listdir(dirTest)
listTrain = [xx for xx in listTrain if os.path.splitext(xx)[1]=='.tif']
listMask  = [xx for xx in listMask  if os.path.splitext(xx)[1]=='.png']
listTest  = [xx for xx in listTest  if os.path.splitext(xx)[1]=='.tif']
print(len(listTrain),len(listMask),len(listTest))
print(listTrain[:5],'\n',listMask[:5],'\n',listTest[:5])
# Out:
# 168 168 162
# ['i105404.tif', 'i117557.tif', 'i124017.tif', 'i130790.tif', 'i137857.tif']
#  ['i105404_mask.png', 'i117557_mask.png', 'i124017_mask.png', 'i130790_mask.png', 'i137857_mask.png']
#  ['i105047.tif', 'i116596.tif', 'i137649.tif', 'i140176.tif', 'i142099.tif']

# %%
for xx in listTrain[:5] :
    img = cv.imread(os.path.join(dirTrain,xx),-1)
    xxm = os.path.splitext(xx)[0]+"_mask.png"
    msk = cv.imread(os.path.join(dirMask,xxm),-1)
    plt.subplot(121); plt.imshow(img); plt.subplot(122); plt.imshow(msk,'gray'); plt.show()
plt.close()

# %%
msk.shape, img.shape, img.min(), img.max(), msk.max(), #img[6:10,6:10], msk[6:10,6:10]
# Out:
# ((500, 500), (500, 500, 3), 2, 255, 255)

# %%
flagGray = False
Gauss    = 5
Median   = 5
if flagGray :
    trX, trY, trX0, trY0 = [], [], np.zeros((512,512,1)), np.zeros((512,512,1))
else :
    trX, trY, trX0, trY0 = [], [], np.zeros((512,512,3)), np.zeros((512,512,1))

for xx in listTrain :
    img = cv.imread(os.path.join(dirTrain,xx),-1)
    if 1 and (Gauss or Median): 
        for cc in range(img.shape[2]) : 
            if Gauss  : img[:,:,cc] = cv.GaussianBlur(img[:,:,cc],(Gauss,Gauss),0);
            if Median : img[:,:,cc] = cv.medianBlur  (img[:,:,cc],Median);
    xxm = os.path.splitext(xx)[0]+"_mask.png"
    msk = cv.imread(os.path.join(dirMask,xxm),-1)
    #print(img.mean(),msk.mean())
    if flagGray :
        img = cv.cvtColor(img,cv.COLOR_RGB2GRAY);
        trX0[6:506,6:506,0] = img[:,:]/255.0
        trY0[6:506,6:506,0] = msk[:,:]/255.0
    else :
        trX0[6:506,6:506,:] = img[:,:,:]/255.0
        trY0[6:506,6:506,0] = msk[:,:]/255.0
        trY0[trY0>=0.5] = 1.0
    trX.append(trX0.copy())
    trY.append(trY0.copy())
    #print(trX0.mean(),trY0.mean(),trX1[-1].mean(),trY1[-1].mean())

#print([trY[xx].mean() for xx in range(10)])
trX = np.array(trX)
trY = np.array(trY)

trXX, trYY = trX.copy(), trY.copy()

for f in range(-1,2) :
    trXXX, trYYY = trX.copy(), trY.copy()
    for p in range(trXXX.shape[0]) :
        trXXX[p], trYYY[p,:,:,0] = cv.flip(trXXX[p],f), cv.flip(trYYY[p,:,:,0],f)
    trXX = np.vstack([trXX,trXXX])
    trYY = np.vstack([trYY,trYYY])
    print(trXX.shape,trYY.shape)
    
trX, trY = trXX.copy(), trYY.copy()
del trXX,trXXX,trYY,trYYY

# Считаем среднее по каналам и вычитаем из изображений
meanX = (trX[:,6:506,6:506,:].mean(axis=(1,2))).mean(axis=0)
stdX  = (trX[:,6:506,6:506,:].mean(axis=(1,2))).std(axis=0)
for cc in range(meanX.shape[0]) : 
    trX[:,6:506,6:506,cc] -= meanX[cc]    
print("mean={} std={}".format(meanX,stdX))
    
trX.shape, trX.min(), trX.max(), trY.shape, trY.min(), trY.max()
#[trY[xx].mean() for xx in range(10)]
# Out:
# (336, 512, 512, 3) (336, 512, 512, 1)
# (504, 512, 512, 3) (504, 512, 512, 1)
# (672, 512, 512, 3) (672, 512, 512, 1)
# mean=[ 0.6473997   0.48950165  0.70839568] std=[ 0.06249822  0.09179847  0.08778627]
# ((672, 512, 512, 3),
#  -0.62212117329585626,
#  0.48696893986925865,
#  (672, 512, 512, 1),
#  0.0,
#  1.0)

# %%
for xx in range(5) :
    img = trX[xx]
    xxm = trY[xx]
    plt.subplot(121); plt.imshow(img); plt.subplot(122); plt.imshow(xxm[:,:,0],'gray'); plt.show()
plt.close()

# %%
#
# model UNET
#
#    https://github.com/pietz/unet-keras
#
#

def level_block(m, dim, depth, acti, dropout=0.25, batch=True):
    if depth > 0:
        
        x = m
        if batch : x = BatchNormalization()(x)
        n = Conv2D(dim, (3, 3), activation=acti, padding='same')(x) #(m)
        n = Conv2D(dim, (3, 3), activation=acti, padding='same')(n)
        if dropout : n = Dropout(dropout)(n) ## add
        m = MaxPooling2D((2, 2))(n)
        m = level_block(m, 2*dim, depth-1, acti, dropout=dropout, batch=batch)
        m = UpSampling2D((2, 2))(m)
        m = Conv2D(dim, (2, 2), activation=acti, padding='same')(m)
        if dropout : m = Dropout(dropout)(m) ## add
        m = Concatenate(axis=3)([n, m])
    m = Conv2D(dim, (3, 3), activation=acti, padding='same')(m)
    return Conv2D(dim, (3, 3), activation=acti, padding='same')(m)

def UNet(img_shape, n_out=2, dim=32, depth=5, acti='relu', flatten=False, dropout=0.25, batch=True):
    i = Input(shape=img_shape)
    ## ???? i = ZeroPadding2D((6,6),data_format="channels_last")
    o = level_block(i, dim, depth, acti, dropout=dropout, batch=batch)
    o = Conv2D(n_out, (1, 1), name='prediction')(o)
    if flatten:
        o = Reshape(n_out, img_shape[0] * img_shape[1])(o)
        o = Permute((2, 1))(o)
    #o = Activation('relu')(o)
    if batch : o = BatchNormalization()(o)  ######
    o = Activation('sigmoid')(o)
    return Model(inputs=i, outputs=o)

# %%
model10 = UNet((512,512,3),depth=5,n_out=1, dropout=0.05)
model10.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 512, 512, 3)   0
# ____________________________________________________________________________________________________
# batch_normalization_1 (BatchNorm (None, 512, 512, 3)   12          input_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_1 (Conv2D)                (None, 512, 512, 32)  896         batch_normalization_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_2 (Conv2D)                (None, 512, 512, 32)  9248        conv2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 512, 512, 32)  0           conv2d_2[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)   (None, 256, 256, 32)  0           dropout_1[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_2 (BatchNorm (None, 256, 256, 32)  128         max_pooling2d_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_3 (Conv2D)                (None, 256, 256, 64)  18496       batch_normalization_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_4 (Conv2D)                (None, 256, 256, 64)  36928       conv2d_3[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)              (None, 256, 256, 64)  0           conv2d_4[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)   (None, 128, 128, 64)  0           dropout_2[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_3 (BatchNorm (None, 128, 128, 64)  256         max_pooling2d_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_5 (Conv2D)                (None, 128, 128, 128) 73856       batch_normalization_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_6 (Conv2D)                (None, 128, 128, 128) 147584      conv2d_5[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)              (None, 128, 128, 128) 0           conv2d_6[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)   (None, 64, 64, 128)   0           dropout_3[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_4 (BatchNorm (None, 64, 64, 128)   512         max_pooling2d_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_7 (Conv2D)                (None, 64, 64, 256)   295168      batch_normalization_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_8 (Conv2D)                (None, 64, 64, 256)   590080      conv2d_7[0][0]
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)              (None, 64, 64, 256)   0           conv2d_8[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)   (None, 32, 32, 256)   0           dropout_4[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_5 (BatchNorm (None, 32, 32, 256)   1024        max_pooling2d_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_9 (Conv2D)                (None, 32, 32, 512)   1180160     batch_normalization_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_10 (Conv2D)               (None, 32, 32, 512)   2359808     conv2d_9[0][0]
# ____________________________________________________________________________________________________
# dropout_5 (Dropout)              (None, 32, 32, 512)   0           conv2d_10[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)   (None, 16, 16, 512)   0           dropout_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_11 (Conv2D)               (None, 16, 16, 1024)  4719616     max_pooling2d_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_12 (Conv2D)               (None, 16, 16, 1024)  9438208     conv2d_11[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)   (None, 32, 32, 1024)  0           conv2d_12[0][0]
# ____________________________________________________________________________________________________
# conv2d_13 (Conv2D)               (None, 32, 32, 512)   2097664     up_sampling2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_6 (Dropout)              (None, 32, 32, 512)   0           conv2d_13[0][0]
# ____________________________________________________________________________________________________
# concatenate_1 (Concatenate)      (None, 32, 32, 1024)  0           dropout_5[0][0]
#                                                                    dropout_6[0][0]
# ____________________________________________________________________________________________________
# conv2d_14 (Conv2D)               (None, 32, 32, 512)   4719104     concatenate_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_15 (Conv2D)               (None, 32, 32, 512)   2359808     conv2d_14[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)   (None, 64, 64, 512)   0           conv2d_15[0][0]
# ____________________________________________________________________________________________________
# conv2d_16 (Conv2D)               (None, 64, 64, 256)   524544      up_sampling2d_2[0][0]
# ____________________________________________________________________________________________________
# dropout_7 (Dropout)              (None, 64, 64, 256)   0           conv2d_16[0][0]
# ____________________________________________________________________________________________________
# concatenate_2 (Concatenate)      (None, 64, 64, 512)   0           dropout_4[0][0]
#                                                                    dropout_7[0][0]
# ____________________________________________________________________________________________________
# conv2d_17 (Conv2D)               (None, 64, 64, 256)   1179904     concatenate_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_18 (Conv2D)               (None, 64, 64, 256)   590080      conv2d_17[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)   (None, 128, 128, 256) 0           conv2d_18[0][0]
# ____________________________________________________________________________________________________
# conv2d_19 (Conv2D)               (None, 128, 128, 128) 131200      up_sampling2d_3[0][0]
# ____________________________________________________________________________________________________
# dropout_8 (Dropout)              (None, 128, 128, 128) 0           conv2d_19[0][0]
# ____________________________________________________________________________________________________
# concatenate_3 (Concatenate)      (None, 128, 128, 256) 0           dropout_3[0][0]
#                                                                    dropout_8[0][0]
# ____________________________________________________________________________________________________
# conv2d_20 (Conv2D)               (None, 128, 128, 128) 295040      concatenate_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_21 (Conv2D)               (None, 128, 128, 128) 147584      conv2d_20[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)   (None, 256, 256, 128) 0           conv2d_21[0][0]
# ____________________________________________________________________________________________________
# conv2d_22 (Conv2D)               (None, 256, 256, 64)  32832       up_sampling2d_4[0][0]
# ____________________________________________________________________________________________________
# dropout_9 (Dropout)              (None, 256, 256, 64)  0           conv2d_22[0][0]
# ____________________________________________________________________________________________________
# concatenate_4 (Concatenate)      (None, 256, 256, 128) 0           dropout_2[0][0]
#                                                                    dropout_9[0][0]
# ____________________________________________________________________________________________________
# conv2d_23 (Conv2D)               (None, 256, 256, 64)  73792       concatenate_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_24 (Conv2D)               (None, 256, 256, 64)  36928       conv2d_23[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)   (None, 512, 512, 64)  0           conv2d_24[0][0]
# ____________________________________________________________________________________________________
# conv2d_25 (Conv2D)               (None, 512, 512, 32)  8224        up_sampling2d_5[0][0]
# ____________________________________________________________________________________________________
# dropout_10 (Dropout)             (None, 512, 512, 32)  0           conv2d_25[0][0]
# ____________________________________________________________________________________________________
# concatenate_5 (Concatenate)      (None, 512, 512, 64)  0           dropout_1[0][0]
#                                                                    dropout_10[0][0]
# ____________________________________________________________________________________________________
# conv2d_26 (Conv2D)               (None, 512, 512, 32)  18464       concatenate_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_27 (Conv2D)               (None, 512, 512, 32)  9248        conv2d_26[0][0]
# ____________________________________________________________________________________________________
# prediction (Conv2D)              (None, 512, 512, 1)   33          conv2d_27[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_6 (BatchNorm (None, 512, 512, 1)   4           prediction[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 512, 512, 1)   0           batch_normalization_6[0][0]
# ====================================================================================================
# Total params: 31,096,433
# Trainable params: 31,095,465
# Non-trainable params: 968
# ____________________________________________________________________________________________________

# %%
def dice (truth,pred) :
    g, s = K.sum(truth), K.sum(pred)
    x    = K.sum((truth*pred))
    return((1.0 if K.sum(g+s)==0.0 else 2.0*x/(g+s+K.epsilon())))

def f1 (truth,pred) :
    TP = K.sum(truth*pred)
    TN = K.sum((1.0-truth)*(1.0-pred))
    FP = K.sum(truth*(1.0-pred))
    FN = K.sum((1.0-truth)*pred)

    
    P  = 1.0 if K.sum(TP+FP)==0.0 else TP/(TP+FP)
    R  = 0.0 if K.sum(TP+FN)==0.0 else TP/(TP+FN) 

    F1 = 0.0 if K.sum(P+R)  ==0.0 else 2.0*P*R/(P+R)

    return(F1)

def f1dice (truth,pred) :
    return ((dice(truth,pred)+f1(truth,pred))/2.0)
    
def lossdice (truth,pred) :
    return(1.0 - dice(truth,pred))

def lossfd (truth,pred) :
    return(1.0 - f1dice(truth,pred))

# %%
def buildModel (input_shape) :
    model = UNet(input_shape,depth=5,n_out=1,dropout=0.05,batch=False)
    
    sgd = keras.optimizers.SGD(lr=0.01, momentum=0.9, nesterov=True)
    #model.compile(loss='mean_absolute_error',  #'binary_crossentropy',
    model.compile(loss=lossdice, #'mean_absolute_error',  #'binary_crossentropy',
                  optimizer=sgd, #sgd, #"adam", #'rmsprop',
                  metrics=[dice,'binary_accuracy']) #['binary_accuracy']) #[fbeta_pred]) #['accuracy',fbeta_pred]) #['accuracy'])
    return(model)

# %%
K.clear_session()
model10 = buildModel((trX.shape[1],trX.shape[2],trX.shape[3]))
model10.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 512, 512, 3)   0
# ____________________________________________________________________________________________________
# conv2d_1 (Conv2D)                (None, 512, 512, 32)  896         input_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_2 (Conv2D)                (None, 512, 512, 32)  9248        conv2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 512, 512, 32)  0           conv2d_2[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)   (None, 256, 256, 32)  0           dropout_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_3 (Conv2D)                (None, 256, 256, 64)  18496       max_pooling2d_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_4 (Conv2D)                (None, 256, 256, 64)  36928       conv2d_3[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)              (None, 256, 256, 64)  0           conv2d_4[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)   (None, 128, 128, 64)  0           dropout_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_5 (Conv2D)                (None, 128, 128, 128) 73856       max_pooling2d_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_6 (Conv2D)                (None, 128, 128, 128) 147584      conv2d_5[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)              (None, 128, 128, 128) 0           conv2d_6[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)   (None, 64, 64, 128)   0           dropout_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_7 (Conv2D)                (None, 64, 64, 256)   295168      max_pooling2d_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_8 (Conv2D)                (None, 64, 64, 256)   590080      conv2d_7[0][0]
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)              (None, 64, 64, 256)   0           conv2d_8[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)   (None, 32, 32, 256)   0           dropout_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_9 (Conv2D)                (None, 32, 32, 512)   1180160     max_pooling2d_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_10 (Conv2D)               (None, 32, 32, 512)   2359808     conv2d_9[0][0]
# ____________________________________________________________________________________________________
# dropout_5 (Dropout)              (None, 32, 32, 512)   0           conv2d_10[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)   (None, 16, 16, 512)   0           dropout_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_11 (Conv2D)               (None, 16, 16, 1024)  4719616     max_pooling2d_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_12 (Conv2D)               (None, 16, 16, 1024)  9438208     conv2d_11[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)   (None, 32, 32, 1024)  0           conv2d_12[0][0]
# ____________________________________________________________________________________________________
# conv2d_13 (Conv2D)               (None, 32, 32, 512)   2097664     up_sampling2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_6 (Dropout)              (None, 32, 32, 512)   0           conv2d_13[0][0]
# ____________________________________________________________________________________________________
# concatenate_1 (Concatenate)      (None, 32, 32, 1024)  0           dropout_5[0][0]
#                                                                    dropout_6[0][0]
# ____________________________________________________________________________________________________
# conv2d_14 (Conv2D)               (None, 32, 32, 512)   4719104     concatenate_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_15 (Conv2D)               (None, 32, 32, 512)   2359808     conv2d_14[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)   (None, 64, 64, 512)   0           conv2d_15[0][0]
# ____________________________________________________________________________________________________
# conv2d_16 (Conv2D)               (None, 64, 64, 256)   524544      up_sampling2d_2[0][0]
# ____________________________________________________________________________________________________
# dropout_7 (Dropout)              (None, 64, 64, 256)   0           conv2d_16[0][0]
# ____________________________________________________________________________________________________
# concatenate_2 (Concatenate)      (None, 64, 64, 512)   0           dropout_4[0][0]
#                                                                    dropout_7[0][0]
# ____________________________________________________________________________________________________
# conv2d_17 (Conv2D)               (None, 64, 64, 256)   1179904     concatenate_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_18 (Conv2D)               (None, 64, 64, 256)   590080      conv2d_17[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)   (None, 128, 128, 256) 0           conv2d_18[0][0]
# ____________________________________________________________________________________________________
# conv2d_19 (Conv2D)               (None, 128, 128, 128) 131200      up_sampling2d_3[0][0]
# ____________________________________________________________________________________________________
# dropout_8 (Dropout)              (None, 128, 128, 128) 0           conv2d_19[0][0]
# ____________________________________________________________________________________________________
# concatenate_3 (Concatenate)      (None, 128, 128, 256) 0           dropout_3[0][0]
#                                                                    dropout_8[0][0]
# ____________________________________________________________________________________________________
# conv2d_20 (Conv2D)               (None, 128, 128, 128) 295040      concatenate_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_21 (Conv2D)               (None, 128, 128, 128) 147584      conv2d_20[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)   (None, 256, 256, 128) 0           conv2d_21[0][0]
# ____________________________________________________________________________________________________
# conv2d_22 (Conv2D)               (None, 256, 256, 64)  32832       up_sampling2d_4[0][0]
# ____________________________________________________________________________________________________
# dropout_9 (Dropout)              (None, 256, 256, 64)  0           conv2d_22[0][0]
# ____________________________________________________________________________________________________
# concatenate_4 (Concatenate)      (None, 256, 256, 128) 0           dropout_2[0][0]
#                                                                    dropout_9[0][0]
# ____________________________________________________________________________________________________
# conv2d_23 (Conv2D)               (None, 256, 256, 64)  73792       concatenate_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_24 (Conv2D)               (None, 256, 256, 64)  36928       conv2d_23[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)   (None, 512, 512, 64)  0           conv2d_24[0][0]
# ____________________________________________________________________________________________________
# conv2d_25 (Conv2D)               (None, 512, 512, 32)  8224        up_sampling2d_5[0][0]
# ____________________________________________________________________________________________________
# dropout_10 (Dropout)             (None, 512, 512, 32)  0           conv2d_25[0][0]
# ____________________________________________________________________________________________________
# concatenate_5 (Concatenate)      (None, 512, 512, 64)  0           dropout_1[0][0]
#                                                                    dropout_10[0][0]
# ____________________________________________________________________________________________________
# conv2d_26 (Conv2D)               (None, 512, 512, 32)  18464       concatenate_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_27 (Conv2D)               (None, 512, 512, 32)  9248        conv2d_26[0][0]
# ____________________________________________________________________________________________________
# prediction (Conv2D)              (None, 512, 512, 1)   33          conv2d_27[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 512, 512, 1)   0           prediction[0][0]
# ====================================================================================================
# Total params: 31,094,497
# Trainable params: 31,094,497
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
#model10.load_weights('../Data-Keras/Models/model-UNet-weights.h5', by_name=False)
batch_size = 2

# %%
epochs     = 100
verbose    = 2
batch_size = 1
metric     = 'binary_accuracy'
metric     = 'dice'

############trX, trY = trX[0:30], trY[0:30]

folds      = 5
foldN      = trX.shape[0]/folds+1

print(datetime.datetime.now(),'Training with folds')

#for i in range(folds) :
for i in range(2,3) :

    print(datetime.datetime.now(),'------------>',i)

    K.clear_session()
    model10 = buildModel((trX.shape[1],trX.shape[2],trX.shape[3]))
    ############if 1 : model10.load_weights('../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7660-2.hdf5')

    early_stopping = EarlyStopping(monitor='val_loss', patience=10,min_delta=0.0001,verbose=1)
    reduce_lr1     = ReduceLROnPlateau(monitor='val_loss', factor=0.5,patience=3, min_lr=0.0000001,verbose=1)
    reduce_lr2     = ReduceLROnPlateau(monitor='loss',     factor=0.5,patience=3, min_lr=0.0000001,verbose=1)

    filepath="../Temp/TempTempG5M5KFold/V1-UNET-val_"+metric+"={val_"+metric+":.4f}-{"+metric+":.4f}---"+str(i)+".hdf5"
    #checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
    checkpoint1 = ModelCheckpoint(filepath, monitor=metric,        verbose=1, save_best_only=True, mode='max')
    checkpoint2 = ModelCheckpoint(filepath, monitor='val_'+metric, verbose=1, save_best_only=True, mode='max')

    step  = 60
    low   = 0
    high  = low+step
    
    tFold = [True]*(i*foldN)+[False]*foldN+[True]*trX.shape[0];
    tFold = tFold[:trX.shape[0]]
    
    vFold = [not xx for xx in tFold]

    #hist1  = model10.fit(trX[low:high],trY[low:high],
    hist1  = model10.fit(trX[tFold],trY[tFold],
                        epochs=epochs, batch_size=batch_size, 
                        #validation_split=0.20, 
                        validation_data=(trX[vFold],trY[vFold]),
                        initial_epoch = 0,
                        #callbacks=[early_stopping,reduce_lr1,reduce_lr2,checkpoint],
                        callbacks=[reduce_lr1,reduce_lr2,checkpoint1,checkpoint2,early_stopping],
                        verbose=verbose)

print(datetime.datetime.now())
# Out:
# 2017-07-28 13:46:36.362931 Training with folds
# 2017-07-28 13:46:36.363710 ------------> 2
# Train on 537 samples, validate on 135 samples
# Epoch 1/60
# Epoch 00000: dice improved from -inf to 0.53072, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.6276-0.5307---2.hdf5
# Epoch 00000: val_dice improved from -inf to 0.62757, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.6276-0.5307---2.hdf5
# 287s - loss: 0.4693 - dice: 0.5307 - binary_accuracy: 0.6042 - val_loss: 0.3724 - val_dice: 0.6276 - val_binary_accuracy: 0.7934
# Epoch 2/60
# Epoch 00001: dice improved from 0.53072 to 0.64651, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.6473-0.6465---2.hdf5
# Epoch 00001: val_dice improved from 0.62757 to 0.64735, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.6473-0.6465---2.hdf5
# 271s - loss: 0.3535 - dice: 0.6465 - binary_accuracy: 0.8190 - val_loss: 0.3527 - val_dice: 0.6473 - val_binary_accuracy: 0.8175
# Epoch 3/60
# Epoch 00002: dice improved from 0.64651 to 0.66588, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.6771-0.6659---2.hdf5
# Epoch 00002: val_dice improved from 0.64735 to 0.67708, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.6771-0.6659---2.hdf5
# 268s - loss: 0.3341 - dice: 0.6659 - binary_accuracy: 0.8263 - val_loss: 0.3229 - val_dice: 0.6771 - val_binary_accuracy: 0.8575
# Epoch 4/60
# Epoch 00003: dice improved from 0.66588 to 0.69475, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.6872-0.6948---2.hdf5
# Epoch 00003: val_dice improved from 0.67708 to 0.68723, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.6872-0.6948---2.hdf5
# 268s - loss: 0.3052 - dice: 0.6948 - binary_accuracy: 0.8534 - val_loss: 0.3128 - val_dice: 0.6872 - val_binary_accuracy: 0.8375
# Epoch 5/60
# Epoch 00004: dice improved from 0.69475 to 0.71163, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7087-0.7116---2.hdf5
# Epoch 00004: val_dice improved from 0.68723 to 0.70867, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7087-0.7116---2.hdf5
# 267s - loss: 0.2884 - dice: 0.7116 - binary_accuracy: 0.8634 - val_loss: 0.2913 - val_dice: 0.7087 - val_binary_accuracy: 0.8612
# Epoch 6/60
# Epoch 00005: dice improved from 0.71163 to 0.71491, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7207-0.7149---2.hdf5
# Epoch 00005: val_dice improved from 0.70867 to 0.72070, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7207-0.7149---2.hdf5
# 266s - loss: 0.2851 - dice: 0.7149 - binary_accuracy: 0.8631 - val_loss: 0.2793 - val_dice: 0.7207 - val_binary_accuracy: 0.8717
# Epoch 7/60
# Epoch 00006: dice improved from 0.71491 to 0.72998, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7324-0.7300---2.hdf5
# Epoch 00006: val_dice improved from 0.72070 to 0.73238, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7324-0.7300---2.hdf5
# 266s - loss: 0.2700 - dice: 0.7300 - binary_accuracy: 0.8744 - val_loss: 0.2676 - val_dice: 0.7324 - val_binary_accuracy: 0.8781
# Epoch 8/60
# Epoch 00007: dice improved from 0.72998 to 0.73712, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7229-0.7371---2.hdf5
# Epoch 00007: val_dice did not improve
# 263s - loss: 0.2629 - dice: 0.7371 - binary_accuracy: 0.8804 - val_loss: 0.2771 - val_dice: 0.7229 - val_binary_accuracy: 0.8756
# Epoch 9/60
# Epoch 00008: dice improved from 0.73712 to 0.74147, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7413-0.7415---2.hdf5
# Epoch 00008: val_dice improved from 0.73238 to 0.74135, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7413-0.7415---2.hdf5
# 266s - loss: 0.2585 - dice: 0.7415 - binary_accuracy: 0.8838 - val_loss: 0.2587 - val_dice: 0.7413 - val_binary_accuracy: 0.8856
# Epoch 10/60
# Epoch 00009: dice improved from 0.74147 to 0.74921, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7380-0.7492---2.hdf5
# Epoch 00009: val_dice did not improve
# 264s - loss: 0.2508 - dice: 0.7492 - binary_accuracy: 0.8872 - val_loss: 0.2620 - val_dice: 0.7380 - val_binary_accuracy: 0.8817
# Epoch 11/60
# Epoch 00010: dice improved from 0.74921 to 0.75456, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7507-0.7546---2.hdf5
# Epoch 00010: val_dice improved from 0.74135 to 0.75074, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7507-0.7546---2.hdf5
# 266s - loss: 0.2454 - dice: 0.7546 - binary_accuracy: 0.8913 - val_loss: 0.2493 - val_dice: 0.7507 - val_binary_accuracy: 0.8915
# Epoch 12/60
# Epoch 00011: dice did not improve
# Epoch 00011: val_dice improved from 0.75074 to 0.75205, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7520-0.7528---2.hdf5
# 263s - loss: 0.2472 - dice: 0.7528 - binary_accuracy: 0.8896 - val_loss: 0.2480 - val_dice: 0.7520 - val_binary_accuracy: 0.8899
# Epoch 13/60
# Epoch 00012: dice improved from 0.75456 to 0.76216, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7504-0.7622---2.hdf5
# Epoch 00012: val_dice did not improve
# 263s - loss: 0.2378 - dice: 0.7622 - binary_accuracy: 0.8960 - val_loss: 0.2496 - val_dice: 0.7504 - val_binary_accuracy: 0.8900
# Epoch 14/60
# Epoch 00013: dice improved from 0.76216 to 0.76527, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7389-0.7653---2.hdf5
# Epoch 00013: val_dice did not improve
# 263s - loss: 0.2347 - dice: 0.7653 - binary_accuracy: 0.8960 - val_loss: 0.2611 - val_dice: 0.7389 - val_binary_accuracy: 0.8782
# Epoch 15/60
# Epoch 00014: dice improved from 0.76527 to 0.77313, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7610-0.7731---2.hdf5
# Epoch 00014: val_dice improved from 0.75205 to 0.76097, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7610-0.7731---2.hdf5
# 266s - loss: 0.2269 - dice: 0.7731 - binary_accuracy: 0.9000 - val_loss: 0.2390 - val_dice: 0.7610 - val_binary_accuracy: 0.8952
# Epoch 16/60
# Epoch 00015: dice did not improve
# Epoch 00015: val_dice did not improve
# 262s - loss: 0.2330 - dice: 0.7670 - binary_accuracy: 0.8955 - val_loss: 0.3150 - val_dice: 0.6850 - val_binary_accuracy: 0.8731
# Epoch 17/60
# Epoch 00016: dice improved from 0.77313 to 0.77391, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7529-0.7739---2.hdf5
# Epoch 00016: val_dice did not improve
# 263s - loss: 0.2261 - dice: 0.7739 - binary_accuracy: 0.8993 - val_loss: 0.2471 - val_dice: 0.7529 - val_binary_accuracy: 0.8950
# Epoch 18/60
# Epoch 00017: dice improved from 0.77391 to 0.78191, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7656-0.7819---2.hdf5
# Epoch 00017: val_dice improved from 0.76097 to 0.76563, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7656-0.7819---2.hdf5
# 265s - loss: 0.2181 - dice: 0.7819 - binary_accuracy: 0.9055 - val_loss: 0.2344 - val_dice: 0.7656 - val_binary_accuracy: 0.8961
# Epoch 19/60
# Epoch 00018: dice improved from 0.78191 to 0.78513, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7715-0.7851---2.hdf5
# Epoch 00018: val_dice improved from 0.76563 to 0.77147, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7715-0.7851---2.hdf5
# 266s - loss: 0.2149 - dice: 0.7851 - binary_accuracy: 0.9073 - val_loss: 0.2285 - val_dice: 0.7715 - val_binary_accuracy: 0.9011
# Epoch 20/60
# Epoch 00019: dice improved from 0.78513 to 0.78800, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7447-0.7880---2.hdf5
# Epoch 00019: val_dice did not improve
# 263s - loss: 0.2120 - dice: 0.7880 - binary_accuracy: 0.9076 - val_loss: 0.2553 - val_dice: 0.7447 - val_binary_accuracy: 0.8957
# Epoch 21/60
# Epoch 00020: dice did not improve
# Epoch 00020: val_dice improved from 0.77147 to 0.77422, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7742-0.7841---2.hdf5
# 263s - loss: 0.2159 - dice: 0.7841 - binary_accuracy: 0.9062 - val_loss: 0.2258 - val_dice: 0.7742 - val_binary_accuracy: 0.9033
# Epoch 22/60
# Epoch 00021: dice improved from 0.78800 to 0.79275, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7693-0.7927---2.hdf5
# Epoch 00021: val_dice did not improve
# 263s - loss: 0.2073 - dice: 0.7927 - binary_accuracy: 0.9084 - val_loss: 0.2307 - val_dice: 0.7693 - val_binary_accuracy: 0.8995
# Epoch 23/60
# Epoch 00022: dice did not improve
# Epoch 00022: val_dice did not improve
# 261s - loss: 0.2073 - dice: 0.7927 - binary_accuracy: 0.9105 - val_loss: 0.2274 - val_dice: 0.7726 - val_binary_accuracy: 0.9022
# Epoch 24/60
# Epoch 00023: dice improved from 0.79275 to 0.79356, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7655-0.7936---2.hdf5
# Epoch 00023: val_dice did not improve
# 263s - loss: 0.2064 - dice: 0.7936 - binary_accuracy: 0.9093 - val_loss: 0.2345 - val_dice: 0.7655 - val_binary_accuracy: 0.8992
# Epoch 25/60
# Epoch 00024: dice improved from 0.79356 to 0.79873, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7802-0.7987---2.hdf5
# Epoch 00024: val_dice improved from 0.77422 to 0.78018, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7802-0.7987---2.hdf5
# 265s - loss: 0.2013 - dice: 0.7987 - binary_accuracy: 0.9146 - val_loss: 0.2198 - val_dice: 0.7802 - val_binary_accuracy: 0.9068
# Epoch 26/60
# Epoch 00025: dice did not improve
# Epoch 00025: val_dice did not improve
# 261s - loss: 0.2024 - dice: 0.7976 - binary_accuracy: 0.9136 - val_loss: 0.2288 - val_dice: 0.7712 - val_binary_accuracy: 0.8997
# Epoch 27/60
# Epoch 00026: dice improved from 0.79873 to 0.80475, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7732-0.8047---2.hdf5
# Epoch 00026: val_dice did not improve
# 263s - loss: 0.1953 - dice: 0.8047 - binary_accuracy: 0.9158 - val_loss: 0.2268 - val_dice: 0.7732 - val_binary_accuracy: 0.9014
# Epoch 28/60
# Epoch 00027: dice did not improve
# Epoch 00027: val_dice improved from 0.78018 to 0.78988, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7899-0.8043---2.hdf5
# 263s - loss: 0.1957 - dice: 0.8043 - binary_accuracy: 0.9145 - val_loss: 0.2101 - val_dice: 0.7899 - val_binary_accuracy: 0.9107
# Epoch 29/60
# Epoch 00028: dice improved from 0.80475 to 0.80551, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7466-0.8055---2.hdf5
# Epoch 00028: val_dice did not improve
# 263s - loss: 0.1945 - dice: 0.8055 - binary_accuracy: 0.9135 - val_loss: 0.2534 - val_dice: 0.7466 - val_binary_accuracy: 0.8835
# Epoch 30/60
# Epoch 00029: dice improved from 0.80551 to 0.80648, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7888-0.8065---2.hdf5
# Epoch 00029: val_dice did not improve
# 263s - loss: 0.1935 - dice: 0.8065 - binary_accuracy: 0.9157 - val_loss: 0.2112 - val_dice: 0.7888 - val_binary_accuracy: 0.9129
# Epoch 31/60
# Epoch 00030: dice improved from 0.80648 to 0.81526, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7768-0.8153---2.hdf5
# Epoch 00030: val_dice did not improve
# 263s - loss: 0.1847 - dice: 0.8153 - binary_accuracy: 0.9206 - val_loss: 0.2232 - val_dice: 0.7768 - val_binary_accuracy: 0.9003
# Epoch 32/60
#
# Epoch 00031: reducing learning rate to 0.00499999988824.
# Epoch 00031: dice improved from 0.81526 to 0.81841, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7755-0.8184---2.hdf5
# Epoch 00031: val_dice did not improve
# 262s - loss: 0.1816 - dice: 0.8184 - binary_accuracy: 0.9222 - val_loss: 0.2245 - val_dice: 0.7755 - val_binary_accuracy: 0.9059
# Epoch 33/60
# Epoch 00032: dice improved from 0.81841 to 0.82897, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7973-0.8290---2.hdf5
# Epoch 00032: val_dice improved from 0.78988 to 0.79730, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7973-0.8290---2.hdf5
# 265s - loss: 0.1710 - dice: 0.8290 - binary_accuracy: 0.9272 - val_loss: 0.2027 - val_dice: 0.7973 - val_binary_accuracy: 0.9155
# Epoch 34/60
# Epoch 00033: dice improved from 0.82897 to 0.83466, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.8002-0.8347---2.hdf5
# Epoch 00033: val_dice improved from 0.79730 to 0.80024, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.8002-0.8347---2.hdf5
# 265s - loss: 0.1653 - dice: 0.8347 - binary_accuracy: 0.9302 - val_loss: 0.1998 - val_dice: 0.8002 - val_binary_accuracy: 0.9174
# Epoch 35/60
# Epoch 00034: dice improved from 0.83466 to 0.83806, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.8041-0.8381---2.hdf5
# Epoch 00034: val_dice improved from 0.80024 to 0.80409, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.8041-0.8381---2.hdf5
# 265s - loss: 0.1619 - dice: 0.8381 - binary_accuracy: 0.9315 - val_loss: 0.1959 - val_dice: 0.8041 - val_binary_accuracy: 0.9198
# Epoch 36/60
# Epoch 00035: dice improved from 0.83806 to 0.84114, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7982-0.8411---2.hdf5
# Epoch 00035: val_dice did not improve
# 263s - loss: 0.1589 - dice: 0.8411 - binary_accuracy: 0.9330 - val_loss: 0.2018 - val_dice: 0.7982 - val_binary_accuracy: 0.9142
# Epoch 37/60
# Epoch 00036: dice improved from 0.84114 to 0.84555, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.8054-0.8456---2.hdf5
# Epoch 00036: val_dice improved from 0.80409 to 0.80542, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.8054-0.8456---2.hdf5
# 265s - loss: 0.1544 - dice: 0.8456 - binary_accuracy: 0.9344 - val_loss: 0.1946 - val_dice: 0.8054 - val_binary_accuracy: 0.9225
# Epoch 38/60
# Epoch 00037: dice improved from 0.84555 to 0.84628, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.8005-0.8463---2.hdf5
# Epoch 00037: val_dice did not improve
# 263s - loss: 0.1537 - dice: 0.8463 - binary_accuracy: 0.9350 - val_loss: 0.1995 - val_dice: 0.8005 - val_binary_accuracy: 0.9181
# Epoch 39/60
# Epoch 00038: dice did not improve
# Epoch 00038: val_dice did not improve
# 261s - loss: 0.1615 - dice: 0.8385 - binary_accuracy: 0.9312 - val_loss: 0.2002 - val_dice: 0.7998 - val_binary_accuracy: 0.9178
# Epoch 40/60
# Epoch 00039: dice did not improve
# Epoch 00039: val_dice did not improve
# 261s - loss: 0.1571 - dice: 0.8429 - binary_accuracy: 0.9332 - val_loss: 0.1951 - val_dice: 0.8049 - val_binary_accuracy: 0.9192
# Epoch 41/60
# Epoch 00040: dice improved from 0.84628 to 0.85265, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.8073-0.8527---2.hdf5
# Epoch 00040: val_dice improved from 0.80542 to 0.80728, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.8073-0.8527---2.hdf5
# 265s - loss: 0.1473 - dice: 0.8527 - binary_accuracy: 0.9380 - val_loss: 0.1927 - val_dice: 0.8073 - val_binary_accuracy: 0.9209
# Epoch 42/60
# Epoch 00041: dice improved from 0.85265 to 0.85493, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.8002-0.8549---2.hdf5
# Epoch 00041: val_dice did not improve
# 263s - loss: 0.1451 - dice: 0.8549 - binary_accuracy: 0.9388 - val_loss: 0.1998 - val_dice: 0.8002 - val_binary_accuracy: 0.9145
# Epoch 43/60
# Epoch 00042: dice improved from 0.85493 to 0.85926, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.8080-0.8593---2.hdf5
# Epoch 00042: val_dice improved from 0.80728 to 0.80798, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.8080-0.8593---2.hdf5
# 265s - loss: 0.1407 - dice: 0.8593 - binary_accuracy: 0.9409 - val_loss: 0.1920 - val_dice: 0.8080 - val_binary_accuracy: 0.9231
# Epoch 44/60
# Epoch 00043: dice improved from 0.85926 to 0.86176, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.8107-0.8618---2.hdf5
# Epoch 00043: val_dice improved from 0.80798 to 0.81068, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.8107-0.8618---2.hdf5
# 265s - loss: 0.1382 - dice: 0.8618 - binary_accuracy: 0.9418 - val_loss: 0.1893 - val_dice: 0.8107 - val_binary_accuracy: 0.9239
# Epoch 45/60
# Epoch 00044: dice improved from 0.86176 to 0.86319, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.8084-0.8632---2.hdf5
# Epoch 00044: val_dice did not improve
# 263s - loss: 0.1368 - dice: 0.8632 - binary_accuracy: 0.9423 - val_loss: 0.1916 - val_dice: 0.8084 - val_binary_accuracy: 0.9237
# Epoch 46/60
# Epoch 00045: dice did not improve
# Epoch 00045: val_dice did not improve
# 261s - loss: 0.1386 - dice: 0.8614 - binary_accuracy: 0.9418 - val_loss: 0.1930 - val_dice: 0.8070 - val_binary_accuracy: 0.9248
# Epoch 47/60
# Epoch 00046: dice improved from 0.86319 to 0.86675, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.8050-0.8667---2.hdf5
# Epoch 00046: val_dice did not improve
# 263s - loss: 0.1333 - dice: 0.8667 - binary_accuracy: 0.9437 - val_loss: 0.1950 - val_dice: 0.8050 - val_binary_accuracy: 0.9198
# Epoch 48/60
# Epoch 00047: dice improved from 0.86675 to 0.87005, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.8109-0.8701---2.hdf5
# Epoch 00047: val_dice improved from 0.81068 to 0.81089, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.8109-0.8701---2.hdf5
# 265s - loss: 0.1299 - dice: 0.8701 - binary_accuracy: 0.9451 - val_loss: 0.1891 - val_dice: 0.8109 - val_binary_accuracy: 0.9240
# Epoch 49/60
# Epoch 00048: dice improved from 0.87005 to 0.87218, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.8080-0.8722---2.hdf5
# Epoch 00048: val_dice did not improve
# 263s - loss: 0.1278 - dice: 0.8722 - binary_accuracy: 0.9457 - val_loss: 0.1920 - val_dice: 0.8080 - val_binary_accuracy: 0.9224
# Epoch 50/60
# Epoch 00049: dice did not improve
# Epoch 00049: val_dice did not improve
# 261s - loss: 0.1390 - dice: 0.8610 - binary_accuracy: 0.9408 - val_loss: 0.1921 - val_dice: 0.8079 - val_binary_accuracy: 0.9228
# Epoch 51/60
# Epoch 00050: dice did not improve
# Epoch 00050: val_dice did not improve
# 261s - loss: 0.1335 - dice: 0.8665 - binary_accuracy: 0.9435 - val_loss: 0.1956 - val_dice: 0.8044 - val_binary_accuracy: 0.9228
# Epoch 52/60
#
# Epoch 00051: reducing learning rate to 0.00249999994412.
# Epoch 00051: dice did not improve
# Epoch 00051: val_dice did not improve
# 261s - loss: 0.1365 - dice: 0.8635 - binary_accuracy: 0.9422 - val_loss: 0.1981 - val_dice: 0.8019 - val_binary_accuracy: 0.9185
# Epoch 53/60
# Epoch 00052: dice improved from 0.87218 to 0.87719, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.8109-0.8772---2.hdf5
# Epoch 00052: val_dice improved from 0.81089 to 0.81091, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.8109-0.8772---2.hdf5
# 265s - loss: 0.1228 - dice: 0.8772 - binary_accuracy: 0.9475 - val_loss: 0.1891 - val_dice: 0.8109 - val_binary_accuracy: 0.9250
# Epoch 54/60
# Epoch 00053: dice improved from 0.87719 to 0.88066, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.8074-0.8807---2.hdf5
# Epoch 00053: val_dice did not improve
# 263s - loss: 0.1193 - dice: 0.8807 - binary_accuracy: 0.9494 - val_loss: 0.1926 - val_dice: 0.8074 - val_binary_accuracy: 0.9219
# Epoch 55/60
# Epoch 00054: dice improved from 0.88066 to 0.88339, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.8114-0.8834---2.hdf5
# Epoch 00054: val_dice improved from 0.81091 to 0.81139, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.8114-0.8834---2.hdf5
# 265s - loss: 0.1166 - dice: 0.8834 - binary_accuracy: 0.9504 - val_loss: 0.1886 - val_dice: 0.8114 - val_binary_accuracy: 0.9252
# Epoch 56/60
# Epoch 00055: dice improved from 0.88339 to 0.88588, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.8080-0.8859---2.hdf5
# Epoch 00055: val_dice did not improve
# 263s - loss: 0.1141 - dice: 0.8859 - binary_accuracy: 0.9516 - val_loss: 0.1920 - val_dice: 0.8080 - val_binary_accuracy: 0.9232
# Epoch 57/60
# Epoch 00056: dice improved from 0.88588 to 0.88823, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.8092-0.8882---2.hdf5
# Epoch 00056: val_dice did not improve
# 263s - loss: 0.1118 - dice: 0.8882 - binary_accuracy: 0.9523 - val_loss: 0.1908 - val_dice: 0.8092 - val_binary_accuracy: 0.9245
# Epoch 58/60
# Epoch 00057: dice improved from 0.88823 to 0.88890, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.8063-0.8889---2.hdf5
# Epoch 00057: val_dice did not improve
# 263s - loss: 0.1111 - dice: 0.8889 - binary_accuracy: 0.9529 - val_loss: 0.1937 - val_dice: 0.8063 - val_binary_accuracy: 0.9218
# Epoch 59/60
#
# Epoch 00058: reducing learning rate to 0.00124999997206.
# Epoch 00058: dice improved from 0.88890 to 0.89238, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.8073-0.8924---2.hdf5
# Epoch 00058: val_dice did not improve
# 263s - loss: 0.1076 - dice: 0.8924 - binary_accuracy: 0.9540 - val_loss: 0.1927 - val_dice: 0.8073 - val_binary_accuracy: 0.9233
# Epoch 60/60
# Epoch 00059: dice improved from 0.89238 to 0.89455, saving model to ../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.8112-0.8946---2.hdf5
# Epoch 00059: val_dice did not improve
# 263s - loss: 0.1054 - dice: 0.8946 - binary_accuracy: 0.9550 - val_loss: 0.1888 - val_dice: 0.8112 - val_binary_accuracy: 0.9258
# 2017-07-28 18:11:13.820183

# %%
#!ls ../Temp/TempTempG5M5KFold -la | tail
# !ls ../Temp/TempTempG5M5KFold -la | tail
# Out:
# -rwxrwxrwx 1 boba boba 248917128 июл 28 16:56 V1-UNET-val_dice=0.8080-0.8593---2.hdf5
# -rwxrwxrwx 1 boba boba 248917128 июл 28 17:22 V1-UNET-val_dice=0.8080-0.8722---2.hdf5
# -rwxrwxrwx 1 boba boba 248917128 июл 28 17:53 V1-UNET-val_dice=0.8080-0.8859---2.hdf5
# -rwxrwxrwx 1 boba boba 248917128 июл 28 17:05 V1-UNET-val_dice=0.8084-0.8632---2.hdf5
# -rwxrwxrwx 1 boba boba 248917128 июл 28 17:58 V1-UNET-val_dice=0.8092-0.8882---2.hdf5
# -rwxrwxrwx 1 boba boba 248917128 июл 28 17:01 V1-UNET-val_dice=0.8107-0.8618---2.hdf5
# -rwxrwxrwx 1 boba boba 248917128 июл 28 17:18 V1-UNET-val_dice=0.8109-0.8701---2.hdf5
# -rwxrwxrwx 1 boba boba 248917128 июл 28 17:40 V1-UNET-val_dice=0.8109-0.8772---2.hdf5
# -rwxrwxrwx 1 boba boba 248917128 июл 28 18:11 V1-UNET-val_dice=0.8112-0.8946---2.hdf5
# -rwxrwxrwx 1 boba boba 248917128 июл 28 17:49 V1-UNET-val_dice=0.8114-0.8834---2.hdf5

# %%
if 0 : model10 = load_model('../Temp/TrainModel001+G+M/V1-UNET-0.8511.hdf5')
if 0 : model10 = load_model('../Temp/V1-UNET-0.8853.hdf5')
#if 1 : model10 = load_model('../Temp/TempTempM3/V1-UNET-0.9054.hdf5')
if 0 : model10.load_weights('../Temp/TempTempM3/V1-UNET-0.9054.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5/V1-UNET-val_dice=0.7307.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7879-2.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7632-2.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7660-2.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7828-2.hdf5')

# %%
# %time trP = model10.predict(trX,batch_size=batch_size)
# Out:
# CPU times: user 1min, sys: 14.1 s, total: 1min 14s
# Wall time: 1min 12s

# %%
trP01 = trP
trP01[trP>0.5] =1.0
trP01[trP<=0.5]=0.0
trP01 = trP01.astype(np.uint8)

# %%
if 0 : # Ощутимых результатов не дает, увеличение в +10-100
    times, medianP = 3,5
    for i in range(trP01.shape[0]) :
        for j in range(times) :
            trP01[i,:,:,0] = cv.medianBlur(trP01[i],medianP)

# %%
iii = 0
print(trX[0].shape,trY[0].shape,trP.shape,trP.min(),trP.max())
for ii in range(iii,iii+10) :
    plt.figure(figsize=(15,5))
    plt.subplot(151); plt.imshow(trX[ii,:,:,0],'gray'); 
    plt.subplot(152); plt.imshow(trY[ii,:,:,0],'gray'); 
    plt.subplot(153); plt.imshow(trP[ii,:,:,0],'gray'); 
    plt.subplot(154); plt.imshow(trP01[ii,:,:,0],'gray'); 
    plt.subplot(155); plt.hist(trP[ii,:,:,0].ravel(),bins=50); 
    plt.show()
plt.close()
# Out:
# (512, 512, 3) (512, 512, 1) (672, 512, 512, 1) 0.0 1.0

# %%
# Calculate F1-micro

# %%
TP = (trY[:,6:506,6:506,0]*trP01[:,6:506,6:506,0]).sum()
TN = ((1.0-trY[:,6:506,6:506,0])*(1.0-trP01[:,6:506,6:506,0])).sum()
FP = ((trY[:,6:506,6:506,0])*(1.0-trP01[:,6:506,6:506,0])).sum()
FN = ((1.0-trY[:,6:506,6:506,0])*(trP01[:,6:506,6:506,0])).sum()

P  = TP/(TP+FP) if (TP+FP)>0.0 else 1.0
R  = TP/(TP+FN) if (TP+FN)>0.0 else 0.0

F1 = 2.0*P*R/(P+R) if (P+R)>0.0 else 0.0

TP,TN,FP,FN,P,R,F1
#P*R,P+R, 2.0*P*R/(P+R)
# Out:
# (53258360.0,
#  105814259.0,
#  3094520.0,
#  5832861.0,
#  0.94508674623195832,
#  0.90129056564933729,
#  0.92266923192550121)

# %%
# Calculate DI- dice.mean()

# %%
dice, XX = [],[]
for i in range(trP.shape[0]) :
    G = trY  [i,6:506,6:506,0].sum()
    S = trP01[i,6:506,6:506,0].sum()
    X = (trY [i,6:506,6:506,0]*trP01[i,6:506,6:506,0]).sum()
    XX.append(X)
    dice.append((2.0*X/(G+S) if G+S>0 else 1.0))
di = (np.array(dice)).mean()
di #,np.array(dice)  #,np.array(XX)
# Out:
# 0.89140002833851839

# %%
plt.hist(np.array(dice),bins=40); plt.show()
plt.plot(np.array(dice)); plt.show()

# %%
1000000*(F1+di)/2.0
# Out:
# 907034.63013200986

# %%
#np.array(dice)<0.4

# %%
# Подготовка test решения

# %%
if flagGray :
    trO, trO0 = [], np.zeros((512,512,1))
else :
    trO, trO0 = [], np.zeros((512,512,3))

for xx in listTest :
    img = cv.imread(os.path.join(dirTest,xx),-1)
    if 1 and (Gauss or Median): 
        for cc in range(img.shape[2]) : 
            if Gauss  : img[:,:,cc] = cv.GaussianBlur(img[:,:,cc],(Gauss,Gauss),0);
            if Median : img[:,:,cc] = cv.medianBlur  (img[:,:,cc],Median);
    #print(img.mean(),msk.mean())
    if flagGray :
        img = cv.cvtColor(img,cv.COLOR_RGB2GRAY);
        trO0[6:506,6:506,0] = img[:,:]/255.0
    else :
        trO0[6:506,6:506,:] = img[:,:,:]/255.0
    trO.append(trO0.copy())
    #print(trX0.mean(),trY0.mean(),trX1[-1].mean(),trY1[-1].mean())

#print([trY[xx].mean() for xx in range(10)])
trO = np.array(trO)

if 1 :
    for cc in range(meanX.shape[0]) : 
        trO[:,6:506,6:506,cc] -= meanX[cc]
    
trO.shape, trO.min(), trO.max()
#[trY[xx].mean() for xx in range(10)]
# Out:
# ((162, 512, 512, 3), -0.6417290164331112, 0.47912580261435672)

# %%
# %time trOP = model10.predict(trO,batch_size=batch_size)
# Out:
# CPU times: user 14.7 s, sys: 3.39 s, total: 18.1 s
# Wall time: 17.4 s

# %%
trOP01 = trOP
trOP01[trOP>0.5] =1.0
trOP01[trOP<=0.5]=0.0

# %%
iii = 40
print(trO[0].shape,trP01[0].shape,trOP01.shape,trOP.min(),trOP.max())
for ii in range(iii,iii+10) :
    plt.figure(figsize=(15,5))
    plt.subplot(141); plt.imshow(trO[ii,:,:,0]); 
    plt.subplot(142); plt.imshow(trOP01[ii,:,:,0],'gray'); 
    plt.subplot(143); plt.imshow(trOP[ii,:,:,0],'gray'); 
    plt.subplot(144); plt.hist(trOP[ii,:,:,0].ravel(),bins=50); 
    plt.show()
plt.close()
# Out:
# (512, 512, 3) (512, 512, 1) (162, 512, 512, 1) 0.0 1.0

# %%
# Формирование выходной директории

# %%
def convert_to_binary(truth_png_file, truth_txt_file):
    im = Image.open(truth_png_file) #Can be many different formats.
    pix = im.load()
    with open(truth_txt_file, 'w') as out:
        for x in xrange(500):
            for y in xrange(500):
                out.write(str(int(pix[x, y] > 0)))
            out.write('\n')

if not os.path.exists('../Temp/random_submission'):
    os.makedirs('../Temp/random_submission')

# Training
for i in range(len(listTrain)) :
    fn = listTrain[i]
    truth_txt_file = '../Temp/random_submission/' + fn.split('.')[0] + '_mask.txt'
    with open(truth_txt_file, 'w') as out:
        for x in xrange(500):
            for y in xrange(500):
                out.write(str(int(trP01[i,y+6, x+6] > 0.0)))
            out.write('\n')
    out.close()
    
# Testing
for i in range(len(listTest)) :
    fn = listTest[i]
    truth_txt_file = '../Temp/random_submission/' + fn.split('.')[0] + '_mask.txt'
    with open(truth_txt_file, 'w') as out:
        for x in xrange(500):
            for y in xrange(500):
                out.write(str(int(trOP01[i,y+6, x+6] > 0.0)))
            out.write('\n')
    out.close()

# %%
import shutil

# %%
xx=shutil.make_archive('../Result/topcoderkonica','zip','../Temp/random_submission')
xx
# Out:
# '/media/boba/DATA/boba/Working/TopCoder/2017-07-25-Konica-Minolta/Result/topcoderkonica.zip'

# %%
# !ls ../Temp -la
# Out:
# total 4610508
# drwxrwxrwx 1 boba boba      4096 июл 26 10:58 .
# drwxrwxrwx 1 boba boba      4096 июл 26 10:11 ..
# drwxrwxrwx 1 boba boba         0 июл 25 18:17 .ipynb_checkpoints
# drwxrwxrwx 1 boba boba     61440 июл 26 09:14 random_submission
# -rwxrwxrwx 1 boba boba   1057596 июл 26 10:58 random_submission.zip
# drwxrwxrwx 1 boba boba         0 июл 25 23:35 TrainModel001-G-M
# drwxrwxrwx 1 boba boba         0 июл 25 22:21 TrainModel001-G+M
# drwxrwxrwx 1 boba boba         0 июл 25 21:48 TrainModel001+G-M
# drwxrwxrwx 1 boba boba      4096 июл 25 21:05 TrainModel001+G+M
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:02 V1-UNET-0.8167.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:08 V1-UNET-0.8275.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 18:33 V1-UNET-0.8305.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 18:02 V1-UNET-0.8418.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:09 V1-UNET-0.8486.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:09 V1-UNET-0.8593.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 18:34 V1-UNET-0.8601.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:21 V1-UNET-0.8602.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:22 V1-UNET-0.8605.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:35 V1-UNET-0.8628.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:35 V1-UNET-0.8633.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:23 V1-UNET-0.8635.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:36 V1-UNET-0.8645.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:36 V1-UNET-0.8652.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:24 V1-UNET-0.8655.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:11 V1-UNET-0.8793.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:13 V1-UNET-0.8796.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:14 V1-UNET-0.8808.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 18:02 V1-UNET-0.8853.hdf5

# %%
# !ls ../Work -la
#!ls ../Temp/random_submission
# Out:
# total 80768
# drwxrwxrwx 1 boba boba        0 июл 26 09:17 .
# drwxrwxrwx 1 boba boba     4096 июл 25 15:24 ..
# -rwxrwxrwx 1 boba boba 82700662 июл 26 09:32 topcoderkonica.zip

# %%
if False :
    save_model(model10,'../Data-Keras/Models/model-UNet.h5')
    model10.save_weights('../Data-Keras/Models/model-UNet-weights.h5')

# %%
rrr=pd.DataFrame(res,columns=['image_name','tags']); rrr.head(); 
suffixDT = (datetime.datetime.now()).strftime('%Y-%m-%d-%H-%M-%S'); print(suffixDT)
rrr.to_csv('../Result/vss'+suffixDT+'.csv',index=False);
# Out:
# 2017-05-20-05-51-18
