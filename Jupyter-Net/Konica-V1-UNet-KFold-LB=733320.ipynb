# %%
##
## UNet 
##
## Взята идея по описанию из https://github.com/pietz/unet-keras
##

# %%
import sys,os,datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import fbeta_score
import sklearn.metrics as skm
from __future__ import print_function

# %%
print(np.__version__);
print(pd.__version__);
# Out:
# 1.13.1
# 0.19.2

# %%
import  cv2 as cv
cv.__version__
# Out:
# '3.2.0'

# %%
#from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.models import Sequential, save_model, load_model, Input, Model
from keras.layers import Convolution2D, MaxPooling2D, Convolution1D, MaxPooling1D, UpSampling2D, ZeroPadding2D
from keras.layers import Conv2D, Concatenate, Reshape
from keras.layers import Activation, Dropout, Flatten, Dense, Permute
from keras.layers.normalization import BatchNormalization
import keras.optimizers
from keras.callbacks import EarlyStopping,ReduceLROnPlateau,ModelCheckpoint
import keras.backend as K
# Out:
# Using TensorFlow backend.

# %%
keras.__version__
# Out:
# '2.0.6'

# %%
#---------------------------------------------------------------------

# %%
# !ls -la ..
# !ls -la ../Data
# !ls -la ../Data/training
# Out:
# total 25
# drwxrwxrwx 1 boba boba 4096 июл 26 11:10 .
# drwxrwxrwx 1 boba boba    0 июл 25 09:21 ..
# drwxrwxrwx 1 boba boba 4096 июл 25 09:23 Data
# drwxrwxrwx 1 boba boba    0 июл 25 09:22 Data-Arch
# drwxrwxrwx 1 boba boba    0 июл 25 09:26 Data-Keras
# drwxrwxrwx 1 boba boba 4096 июл 27 14:30 .git
# -rwxrwxrwx 2 boba boba  130 июл  9 12:02 .gitignore
# drwxrwxrwx 1 boba boba    0 июл 26 10:11 .ipynb_checkpoints
# drwxrwxrwx 1 boba boba  280 июл 27 14:30 Jupyter
# drwxrwxrwx 1 boba boba 4096 июл 27 18:07 Jupyter-Net
# drwxrwxrwx 1 boba boba 4096 июл 27 14:30 Result
# drwxrwxrwx 1 boba boba 4096 июл 27 11:23 Temp
# drwxrwxrwx 1 boba boba    0 июл 27 07:53 Work
# total 16
# drwxrwxrwx 1 boba boba 4096 июл 25 09:23 .
# drwxrwxrwx 1 boba boba 4096 июл 26 11:10 ..
# -rwxrwxrwx 2 boba boba 1060 июн 13 15:55 null_submission_generator.py
# -rwxrwxrwx 2 boba boba 1197 июн 13 16:03 random_submission_generator.py
# drwxrwxrwx 1 boba boba    0 июл 24 23:10 testing
# drwxrwxrwx 1 boba boba    0 июл 25 08:14 training
# total 220
# drwxrwxrwx 1 boba boba      0 июл 25 08:14 .
# drwxrwxrwx 1 boba boba   4096 июл 25 09:23 ..
# -rwxrwxrwx 2 boba boba  14340 июн 20 10:04 .DS_Store
# drwxrwxrwx 1 boba boba  40960 июл 25 08:14 images
# drwxrwxrwx 1 boba boba 163840 июл 25 09:17 truth

# %%
dirData = '../Data'
dirTemp = '../Temp'
dirWork = '../Work'

dirTest  = os.path.join(dirData,'testing','images')
dirTrain = os.path.join(dirData,'training','images')
dirMask  = os.path.join(dirData,'training','truth')

# %%
listTrain = os.listdir(dirTrain)
listMask  = os.listdir(dirMask)
listTest  = os.listdir(dirTest)
listTrain = [xx for xx in listTrain if os.path.splitext(xx)[1]=='.tif']
listMask  = [xx for xx in listMask  if os.path.splitext(xx)[1]=='.png']
listTest  = [xx for xx in listTest  if os.path.splitext(xx)[1]=='.tif']
print(len(listTrain),len(listMask),len(listTest))
print(listTrain[:5],'\n',listMask[:5],'\n',listTest[:5])
# Out:
# 168 168 162
# ['i105404.tif', 'i117557.tif', 'i124017.tif', 'i130790.tif', 'i137857.tif']
#  ['i105404_mask.png', 'i117557_mask.png', 'i124017_mask.png', 'i130790_mask.png', 'i137857_mask.png']
#  ['i105047.tif', 'i116596.tif', 'i137649.tif', 'i140176.tif', 'i142099.tif']

# %%
for xx in listTrain[:5] :
    img = cv.imread(os.path.join(dirTrain,xx),-1)
    xxm = os.path.splitext(xx)[0]+"_mask.png"
    msk = cv.imread(os.path.join(dirMask,xxm),-1)
    plt.subplot(121); plt.imshow(img); plt.subplot(122); plt.imshow(msk,'gray'); plt.show()
plt.close()

# %%
msk.shape, img.shape, img.min(), img.max(), msk.max(), #img[6:10,6:10], msk[6:10,6:10]
# Out:
# ((500, 500), (500, 500, 3), 2, 255, 255)

# %%
flagGray = False
Gauss    = 5
Median   = 5
if flagGray :
    trX, trY, trX0, trY0 = [], [], np.zeros((512,512,1)), np.zeros((512,512,1))
else :
    trX, trY, trX0, trY0 = [], [], np.zeros((512,512,3)), np.zeros((512,512,1))

for xx in listTrain :
    img = cv.imread(os.path.join(dirTrain,xx),-1)
    if 1 and (Gauss or Median): 
        for cc in range(img.shape[2]) : 
            if Gauss  : img[:,:,cc] = cv.GaussianBlur(img[:,:,cc],(Gauss,Gauss),0);
            if Median : img[:,:,cc] = cv.medianBlur  (img[:,:,cc],Median);
    xxm = os.path.splitext(xx)[0]+"_mask.png"
    msk = cv.imread(os.path.join(dirMask,xxm),-1)
    #print(img.mean(),msk.mean())
    if flagGray :
        img = cv.cvtColor(img,cv.COLOR_RGB2GRAY);
        trX0[6:506,6:506,0] = img[:,:]/255.0
        trY0[6:506,6:506,0] = msk[:,:]/255.0
    else :
        trX0[6:506,6:506,:] = img[:,:,:]/255.0
        trY0[6:506,6:506,0] = msk[:,:]/255.0
        trY0[trY0>=0.5] = 1.0
    trX.append(trX0.copy())
    trY.append(trY0.copy())
    #print(trX0.mean(),trY0.mean(),trX1[-1].mean(),trY1[-1].mean())

#print([trY[xx].mean() for xx in range(10)])
trX = np.array(trX)
trY = np.array(trY)

# Считаем среднее по каналам и вычитаем из изображений
meanX = (trX[:,6:506,6:506,:].mean(axis=(1,2))).mean(axis=0)
stdX  = (trX[:,6:506,6:506,:].mean(axis=(1,2))).std(axis=0)
for cc in range(meanX.shape[0]) : 
    trX[:,6:506,6:506,cc] -= meanX[cc]    
print("mean={} std={}".format(meanX,stdX))
    
trX.shape, trX.min(), trX.max(), trY.shape, trY.min(), trY.max()
#[trY[xx].mean() for xx in range(10)]
# Out:
# mean=[ 0.6473997   0.48950165  0.70839568] std=[ 0.06249822  0.09179847  0.08778627]
# ((168, 512, 512, 3),
#  -0.62212117329583094,
#  0.48696893986925349,
#  (168, 512, 512, 1),
#  0.0,
#  1.0)

# %%
for xx in range(5) :
    img = trX[xx]
    xxm = trY[xx]
    plt.subplot(121); plt.imshow(img); plt.subplot(122); plt.imshow(xxm[:,:,0],'gray'); plt.show()
plt.close()

# %%
#
# model UNET
#
#    https://github.com/pietz/unet-keras
#
#

def level_block(m, dim, depth, acti, dropout=0.25, batch=True):
    if depth > 0:
        
        x = m
        if batch : x = BatchNormalization()(x)
        n = Conv2D(dim, (3, 3), activation=acti, padding='same')(x) #(m)
        n = Conv2D(dim, (3, 3), activation=acti, padding='same')(n)
        if dropout : n = Dropout(dropout)(n) ## add
        m = MaxPooling2D((2, 2))(n)
        m = level_block(m, 2*dim, depth-1, acti, dropout=dropout, batch=batch)
        m = UpSampling2D((2, 2))(m)
        m = Conv2D(dim, (2, 2), activation=acti, padding='same')(m)
        if dropout : m = Dropout(dropout)(m) ## add
        m = Concatenate(axis=3)([n, m])
    m = Conv2D(dim, (3, 3), activation=acti, padding='same')(m)
    return Conv2D(dim, (3, 3), activation=acti, padding='same')(m)

def UNet(img_shape, n_out=2, dim=32, depth=5, acti='relu', flatten=False, dropout=0.25, batch=True):
    i = Input(shape=img_shape)
    ## ???? i = ZeroPadding2D((6,6),data_format="channels_last")
    o = level_block(i, dim, depth, acti, dropout=dropout, batch=batch)
    o = Conv2D(n_out, (1, 1), name='prediction')(o)
    if flatten:
        o = Reshape(n_out, img_shape[0] * img_shape[1])(o)
        o = Permute((2, 1))(o)
    #o = Activation('relu')(o)
    if batch : o = BatchNormalization()(o)  ######
    o = Activation('sigmoid')(o)
    return Model(inputs=i, outputs=o)

# %%
model10 = UNet((512,512,3),depth=5,n_out=1, dropout=0.05)
model10.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_3 (InputLayer)             (None, 512, 512, 3)   0
# ____________________________________________________________________________________________________
# batch_normalization_14 (BatchNor (None, 512, 512, 3)   12          input_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_60 (Conv2D)               (None, 512, 512, 32)  896         batch_normalization_14[0][0]
# ____________________________________________________________________________________________________
# conv2d_61 (Conv2D)               (None, 512, 512, 32)  9248        conv2d_60[0][0]
# ____________________________________________________________________________________________________
# dropout_23 (Dropout)             (None, 512, 512, 32)  0           conv2d_61[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D)  (None, 256, 256, 32)  0           dropout_23[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_15 (BatchNor (None, 256, 256, 32)  128         max_pooling2d_12[0][0]
# ____________________________________________________________________________________________________
# conv2d_62 (Conv2D)               (None, 256, 256, 64)  18496       batch_normalization_15[0][0]
# ____________________________________________________________________________________________________
# conv2d_63 (Conv2D)               (None, 256, 256, 64)  36928       conv2d_62[0][0]
# ____________________________________________________________________________________________________
# dropout_24 (Dropout)             (None, 256, 256, 64)  0           conv2d_63[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D)  (None, 128, 128, 64)  0           dropout_24[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_16 (BatchNor (None, 128, 128, 64)  256         max_pooling2d_13[0][0]
# ____________________________________________________________________________________________________
# conv2d_64 (Conv2D)               (None, 128, 128, 128) 73856       batch_normalization_16[0][0]
# ____________________________________________________________________________________________________
# conv2d_65 (Conv2D)               (None, 128, 128, 128) 147584      conv2d_64[0][0]
# ____________________________________________________________________________________________________
# dropout_25 (Dropout)             (None, 128, 128, 128) 0           conv2d_65[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D)  (None, 64, 64, 128)   0           dropout_25[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_17 (BatchNor (None, 64, 64, 128)   512         max_pooling2d_14[0][0]
# ____________________________________________________________________________________________________
# conv2d_66 (Conv2D)               (None, 64, 64, 256)   295168      batch_normalization_17[0][0]
# ____________________________________________________________________________________________________
# conv2d_67 (Conv2D)               (None, 64, 64, 256)   590080      conv2d_66[0][0]
# ____________________________________________________________________________________________________
# dropout_26 (Dropout)             (None, 64, 64, 256)   0           conv2d_67[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D)  (None, 32, 32, 256)   0           dropout_26[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_18 (BatchNor (None, 32, 32, 256)   1024        max_pooling2d_15[0][0]
# ____________________________________________________________________________________________________
# conv2d_68 (Conv2D)               (None, 32, 32, 512)   1180160     batch_normalization_18[0][0]
# ____________________________________________________________________________________________________
# conv2d_69 (Conv2D)               (None, 32, 32, 512)   2359808     conv2d_68[0][0]
# ____________________________________________________________________________________________________
# dropout_27 (Dropout)             (None, 32, 32, 512)   0           conv2d_69[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D)  (None, 16, 16, 512)   0           dropout_27[0][0]
# ____________________________________________________________________________________________________
# conv2d_70 (Conv2D)               (None, 16, 16, 1024)  4719616     max_pooling2d_16[0][0]
# ____________________________________________________________________________________________________
# conv2d_71 (Conv2D)               (None, 16, 16, 1024)  9438208     conv2d_70[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_12 (UpSampling2D)  (None, 32, 32, 1024)  0           conv2d_71[0][0]
# ____________________________________________________________________________________________________
# conv2d_72 (Conv2D)               (None, 32, 32, 512)   2097664     up_sampling2d_12[0][0]
# ____________________________________________________________________________________________________
# dropout_28 (Dropout)             (None, 32, 32, 512)   0           conv2d_72[0][0]
# ____________________________________________________________________________________________________
# concatenate_12 (Concatenate)     (None, 32, 32, 1024)  0           dropout_27[0][0]
#                                                                    dropout_28[0][0]
# ____________________________________________________________________________________________________
# conv2d_73 (Conv2D)               (None, 32, 32, 512)   4719104     concatenate_12[0][0]
# ____________________________________________________________________________________________________
# conv2d_74 (Conv2D)               (None, 32, 32, 512)   2359808     conv2d_73[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_13 (UpSampling2D)  (None, 64, 64, 512)   0           conv2d_74[0][0]
# ____________________________________________________________________________________________________
# conv2d_75 (Conv2D)               (None, 64, 64, 256)   524544      up_sampling2d_13[0][0]
# ____________________________________________________________________________________________________
# dropout_29 (Dropout)             (None, 64, 64, 256)   0           conv2d_75[0][0]
# ____________________________________________________________________________________________________
# concatenate_13 (Concatenate)     (None, 64, 64, 512)   0           dropout_26[0][0]
#                                                                    dropout_29[0][0]
# ____________________________________________________________________________________________________
# conv2d_76 (Conv2D)               (None, 64, 64, 256)   1179904     concatenate_13[0][0]
# ____________________________________________________________________________________________________
# conv2d_77 (Conv2D)               (None, 64, 64, 256)   590080      conv2d_76[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_14 (UpSampling2D)  (None, 128, 128, 256) 0           conv2d_77[0][0]
# ____________________________________________________________________________________________________
# conv2d_78 (Conv2D)               (None, 128, 128, 128) 131200      up_sampling2d_14[0][0]
# ____________________________________________________________________________________________________
# dropout_30 (Dropout)             (None, 128, 128, 128) 0           conv2d_78[0][0]
# ____________________________________________________________________________________________________
# concatenate_14 (Concatenate)     (None, 128, 128, 256) 0           dropout_25[0][0]
#                                                                    dropout_30[0][0]
# ____________________________________________________________________________________________________
# conv2d_79 (Conv2D)               (None, 128, 128, 128) 295040      concatenate_14[0][0]
# ____________________________________________________________________________________________________
# conv2d_80 (Conv2D)               (None, 128, 128, 128) 147584      conv2d_79[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_15 (UpSampling2D)  (None, 256, 256, 128) 0           conv2d_80[0][0]
# ____________________________________________________________________________________________________
# conv2d_81 (Conv2D)               (None, 256, 256, 64)  32832       up_sampling2d_15[0][0]
# ____________________________________________________________________________________________________
# dropout_31 (Dropout)             (None, 256, 256, 64)  0           conv2d_81[0][0]
# ____________________________________________________________________________________________________
# concatenate_15 (Concatenate)     (None, 256, 256, 128) 0           dropout_24[0][0]
#                                                                    dropout_31[0][0]
# ____________________________________________________________________________________________________
# conv2d_82 (Conv2D)               (None, 256, 256, 64)  73792       concatenate_15[0][0]
# ____________________________________________________________________________________________________
# conv2d_83 (Conv2D)               (None, 256, 256, 64)  36928       conv2d_82[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_16 (UpSampling2D)  (None, 512, 512, 64)  0           conv2d_83[0][0]
# ____________________________________________________________________________________________________
# conv2d_84 (Conv2D)               (None, 512, 512, 32)  8224        up_sampling2d_16[0][0]
# ____________________________________________________________________________________________________
# dropout_32 (Dropout)             (None, 512, 512, 32)  0           conv2d_84[0][0]
# ____________________________________________________________________________________________________
# concatenate_16 (Concatenate)     (None, 512, 512, 64)  0           dropout_23[0][0]
#                                                                    dropout_32[0][0]
# ____________________________________________________________________________________________________
# conv2d_85 (Conv2D)               (None, 512, 512, 32)  18464       concatenate_16[0][0]
# ____________________________________________________________________________________________________
# conv2d_86 (Conv2D)               (None, 512, 512, 32)  9248        conv2d_85[0][0]
# ____________________________________________________________________________________________________
# prediction (Conv2D)              (None, 512, 512, 1)   33          conv2d_86[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_19 (BatchNor (None, 512, 512, 1)   4           prediction[0][0]
# ____________________________________________________________________________________________________
# activation_3 (Activation)        (None, 512, 512, 1)   0           batch_normalization_19[0][0]
# ====================================================================================================
# Total params: 31,096,433
# Trainable params: 31,095,465
# Non-trainable params: 968
# ____________________________________________________________________________________________________

# %%
def dice (truth,pred) :
    g, s = K.sum(truth), K.sum(pred)
    x    = K.sum((truth*pred))
    return((1.0 if K.sum(g+s)==0.0 else 2.0*x/(g+s+K.epsilon())))

def f1 (truth,pred) :
    TP = K.sum(truth*pred)
    TN = K.sum((1.0-truth)*(1.0-pred))
    FP = K.sum(truth*(1.0-pred))
    FN = K.sum((1.0-truth)*pred)

    
    P  = 1.0 if K.sum(TP+FP)==0.0 else TP/(TP+FP)
    R  = 0.0 if K.sum(TP+FN)==0.0 else TP/(TP+FN) 

    F1 = 0.0 if K.sum(P+R)  ==0.0 else 2.0*P*R/(P+R)

    return(F1)

def f1dice (truth,pred) :
    return ((dice(truth,pred)+f1(truth,pred))/2.0)
    
def lossdice (truth,pred) :
    return(1.0 - dice(truth,pred))

def lossfd (truth,pred) :
    return(1.0 - f1dice(truth,pred))

# %%
def buildModel (input_shape) :
    model = UNet(input_shape,depth=5,n_out=1,dropout=0.05,batch=False)
    
    sgd = keras.optimizers.SGD(lr=0.01, momentum=0.9, nesterov=True)
    #model.compile(loss='mean_absolute_error',  #'binary_crossentropy',
    model.compile(loss=lossdice, #'mean_absolute_error',  #'binary_crossentropy',
                  optimizer=sgd, #sgd, #"adam", #'rmsprop',
                  metrics=[dice,'binary_accuracy']) #['binary_accuracy']) #[fbeta_pred]) #['accuracy',fbeta_pred]) #['accuracy'])
    return(model)

# %%
K.clear_session()
model10 = buildModel((trX.shape[1],trX.shape[2],trX.shape[3]))
model10.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 512, 512, 3)   0
# ____________________________________________________________________________________________________
# conv2d_1 (Conv2D)                (None, 512, 512, 32)  896         input_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_2 (Conv2D)                (None, 512, 512, 32)  9248        conv2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 512, 512, 32)  0           conv2d_2[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)   (None, 256, 256, 32)  0           dropout_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_3 (Conv2D)                (None, 256, 256, 64)  18496       max_pooling2d_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_4 (Conv2D)                (None, 256, 256, 64)  36928       conv2d_3[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)              (None, 256, 256, 64)  0           conv2d_4[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)   (None, 128, 128, 64)  0           dropout_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_5 (Conv2D)                (None, 128, 128, 128) 73856       max_pooling2d_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_6 (Conv2D)                (None, 128, 128, 128) 147584      conv2d_5[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)              (None, 128, 128, 128) 0           conv2d_6[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)   (None, 64, 64, 128)   0           dropout_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_7 (Conv2D)                (None, 64, 64, 256)   295168      max_pooling2d_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_8 (Conv2D)                (None, 64, 64, 256)   590080      conv2d_7[0][0]
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)              (None, 64, 64, 256)   0           conv2d_8[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)   (None, 32, 32, 256)   0           dropout_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_9 (Conv2D)                (None, 32, 32, 512)   1180160     max_pooling2d_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_10 (Conv2D)               (None, 32, 32, 512)   2359808     conv2d_9[0][0]
# ____________________________________________________________________________________________________
# dropout_5 (Dropout)              (None, 32, 32, 512)   0           conv2d_10[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)   (None, 16, 16, 512)   0           dropout_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_11 (Conv2D)               (None, 16, 16, 1024)  4719616     max_pooling2d_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_12 (Conv2D)               (None, 16, 16, 1024)  9438208     conv2d_11[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)   (None, 32, 32, 1024)  0           conv2d_12[0][0]
# ____________________________________________________________________________________________________
# conv2d_13 (Conv2D)               (None, 32, 32, 512)   2097664     up_sampling2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_6 (Dropout)              (None, 32, 32, 512)   0           conv2d_13[0][0]
# ____________________________________________________________________________________________________
# concatenate_1 (Concatenate)      (None, 32, 32, 1024)  0           dropout_5[0][0]
#                                                                    dropout_6[0][0]
# ____________________________________________________________________________________________________
# conv2d_14 (Conv2D)               (None, 32, 32, 512)   4719104     concatenate_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_15 (Conv2D)               (None, 32, 32, 512)   2359808     conv2d_14[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)   (None, 64, 64, 512)   0           conv2d_15[0][0]
# ____________________________________________________________________________________________________
# conv2d_16 (Conv2D)               (None, 64, 64, 256)   524544      up_sampling2d_2[0][0]
# ____________________________________________________________________________________________________
# dropout_7 (Dropout)              (None, 64, 64, 256)   0           conv2d_16[0][0]
# ____________________________________________________________________________________________________
# concatenate_2 (Concatenate)      (None, 64, 64, 512)   0           dropout_4[0][0]
#                                                                    dropout_7[0][0]
# ____________________________________________________________________________________________________
# conv2d_17 (Conv2D)               (None, 64, 64, 256)   1179904     concatenate_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_18 (Conv2D)               (None, 64, 64, 256)   590080      conv2d_17[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)   (None, 128, 128, 256) 0           conv2d_18[0][0]
# ____________________________________________________________________________________________________
# conv2d_19 (Conv2D)               (None, 128, 128, 128) 131200      up_sampling2d_3[0][0]
# ____________________________________________________________________________________________________
# dropout_8 (Dropout)              (None, 128, 128, 128) 0           conv2d_19[0][0]
# ____________________________________________________________________________________________________
# concatenate_3 (Concatenate)      (None, 128, 128, 256) 0           dropout_3[0][0]
#                                                                    dropout_8[0][0]
# ____________________________________________________________________________________________________
# conv2d_20 (Conv2D)               (None, 128, 128, 128) 295040      concatenate_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_21 (Conv2D)               (None, 128, 128, 128) 147584      conv2d_20[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)   (None, 256, 256, 128) 0           conv2d_21[0][0]
# ____________________________________________________________________________________________________
# conv2d_22 (Conv2D)               (None, 256, 256, 64)  32832       up_sampling2d_4[0][0]
# ____________________________________________________________________________________________________
# dropout_9 (Dropout)              (None, 256, 256, 64)  0           conv2d_22[0][0]
# ____________________________________________________________________________________________________
# concatenate_4 (Concatenate)      (None, 256, 256, 128) 0           dropout_2[0][0]
#                                                                    dropout_9[0][0]
# ____________________________________________________________________________________________________
# conv2d_23 (Conv2D)               (None, 256, 256, 64)  73792       concatenate_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_24 (Conv2D)               (None, 256, 256, 64)  36928       conv2d_23[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)   (None, 512, 512, 64)  0           conv2d_24[0][0]
# ____________________________________________________________________________________________________
# conv2d_25 (Conv2D)               (None, 512, 512, 32)  8224        up_sampling2d_5[0][0]
# ____________________________________________________________________________________________________
# dropout_10 (Dropout)             (None, 512, 512, 32)  0           conv2d_25[0][0]
# ____________________________________________________________________________________________________
# concatenate_5 (Concatenate)      (None, 512, 512, 64)  0           dropout_1[0][0]
#                                                                    dropout_10[0][0]
# ____________________________________________________________________________________________________
# conv2d_26 (Conv2D)               (None, 512, 512, 32)  18464       concatenate_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_27 (Conv2D)               (None, 512, 512, 32)  9248        conv2d_26[0][0]
# ____________________________________________________________________________________________________
# prediction (Conv2D)              (None, 512, 512, 1)   33          conv2d_27[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 512, 512, 1)   0           prediction[0][0]
# ====================================================================================================
# Total params: 31,094,497
# Trainable params: 31,094,497
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
#model10.load_weights('../Data-Keras/Models/model-UNet-weights.h5', by_name=False)
batch_size = 2

# %%
epochs     = 100
verbose    = 2
batch_size = 1
metric     = 'binary_accuracy'
metric     = 'dice'

############trX, trY = trX[0:30], trY[0:30]

folds      = 5
foldN      = trX.shape[0]/folds+1

print(datetime.datetime.now(),'Training with folds')

#######for i in range(folds) :
for i in range(2,3) :

    print(datetime.datetime.now(),'------------>',i)

    K.clear_session()
    model10 = buildModel((trX.shape[1],trX.shape[2],trX.shape[3]))
    ############if 1 : model10.load_weights('../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7660-2.hdf5')

    early_stopping = EarlyStopping(monitor='val_loss', patience=10,min_delta=0.0001,verbose=1)
    reduce_lr1     = ReduceLROnPlateau(monitor='val_loss', factor=0.5,patience=3, min_lr=0.0000001,verbose=1)
    reduce_lr2     = ReduceLROnPlateau(monitor='loss',     factor=0.5,patience=3, min_lr=0.0000001,verbose=1)

    filepath="../Temp/TempTempG5M5KFoldMean/V1-UNET-val_"+metric+"={val_"+metric+":.4f}--"+str(i)+".hdf5"
    #checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
    checkpoint = ModelCheckpoint(filepath, monitor='val_'+metric, verbose=1, save_best_only=True, mode='max')

    step  = 60
    low   = 0
    high  = low+step
    
    tFold = [True]*(i*foldN)+[False]*foldN+[True]*trX.shape[0];
    tFold = tFold[:trX.shape[0]]
    
    vFold = [not xx for xx in tFold]

    #hist1  = model10.fit(trX[low:high],trY[low:high],
    hist1  = model10.fit(trX[tFold],trY[tFold],
                        epochs=epochs, batch_size=batch_size, 
                        #validation_split=0.20, 
                        validation_data=(trX[vFold],trY[vFold]),
                        initial_epoch = 0,
                        callbacks=[early_stopping,reduce_lr1,reduce_lr2,checkpoint],
                        verbose=verbose)

print(datetime.datetime.now())
# Out:
# 2017-07-27 20:38:00.959604 Training with folds
# 2017-07-27 20:38:00.960849 ------------> 2
# Train on 134 samples, validate on 34 samples
# Epoch 1/100
# Epoch 00000: val_dice improved from -inf to 0.48533, saving model to ../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.4853--2.hdf5
# 70s - loss: 0.6123 - dice: 0.3877 - binary_accuracy: 0.3417 - val_loss: 0.5147 - val_dice: 0.4853 - val_binary_accuracy: 0.3653
# Epoch 2/100
# Epoch 00001: val_dice improved from 0.48533 to 0.52438, saving model to ../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.5244--2.hdf5
# 69s - loss: 0.5561 - dice: 0.4439 - binary_accuracy: 0.3179 - val_loss: 0.4756 - val_dice: 0.5244 - val_binary_accuracy: 0.6089
# Epoch 3/100
# Epoch 00002: val_dice improved from 0.52438 to 0.65955, saving model to ../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.6596--2.hdf5
# 69s - loss: 0.4545 - dice: 0.5455 - binary_accuracy: 0.7651 - val_loss: 0.3404 - val_dice: 0.6596 - val_binary_accuracy: 0.7983
# Epoch 4/100
# Epoch 00003: val_dice improved from 0.65955 to 0.68189, saving model to ../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.6819--2.hdf5
# 69s - loss: 0.3926 - dice: 0.6074 - binary_accuracy: 0.7822 - val_loss: 0.3181 - val_dice: 0.6819 - val_binary_accuracy: 0.8279
# Epoch 5/100
# Epoch 00004: val_dice improved from 0.68189 to 0.69321, saving model to ../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.6932--2.hdf5
# 68s - loss: 0.3881 - dice: 0.6119 - binary_accuracy: 0.8012 - val_loss: 0.3068 - val_dice: 0.6932 - val_binary_accuracy: 0.8445
# Epoch 6/100
# Epoch 00005: val_dice did not improve
# 67s - loss: 0.3750 - dice: 0.6250 - binary_accuracy: 0.8073 - val_loss: 0.3112 - val_dice: 0.6888 - val_binary_accuracy: 0.8303
# Epoch 7/100
# Epoch 00006: val_dice did not improve
# 66s - loss: 0.3726 - dice: 0.6274 - binary_accuracy: 0.7994 - val_loss: 0.3526 - val_dice: 0.6474 - val_binary_accuracy: 0.7671
# Epoch 8/100
# Epoch 00007: val_dice improved from 0.69321 to 0.69740, saving model to ../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.6974--2.hdf5
# 68s - loss: 0.3671 - dice: 0.6329 - binary_accuracy: 0.8014 - val_loss: 0.3026 - val_dice: 0.6974 - val_binary_accuracy: 0.8346
# Epoch 9/100
# Epoch 00008: val_dice improved from 0.69740 to 0.70617, saving model to ../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7062--2.hdf5
# 67s - loss: 0.3611 - dice: 0.6389 - binary_accuracy: 0.8146 - val_loss: 0.2938 - val_dice: 0.7062 - val_binary_accuracy: 0.8473
# Epoch 10/100
# Epoch 00009: val_dice improved from 0.70617 to 0.72099, saving model to ../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7210--2.hdf5
# 67s - loss: 0.3409 - dice: 0.6591 - binary_accuracy: 0.8293 - val_loss: 0.2790 - val_dice: 0.7210 - val_binary_accuracy: 0.8579
# Epoch 11/100
# Epoch 00010: val_dice improved from 0.72099 to 0.72519, saving model to ../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7252--2.hdf5
# 67s - loss: 0.3463 - dice: 0.6537 - binary_accuracy: 0.8309 - val_loss: 0.2748 - val_dice: 0.7252 - val_binary_accuracy: 0.8612
# Epoch 12/100
# Epoch 00011: val_dice did not improve
# 66s - loss: 0.3456 - dice: 0.6544 - binary_accuracy: 0.8143 - val_loss: 0.2931 - val_dice: 0.7069 - val_binary_accuracy: 0.8414
# Epoch 13/100
# Epoch 00012: val_dice did not improve
# 66s - loss: 0.3459 - dice: 0.6541 - binary_accuracy: 0.8159 - val_loss: 0.2777 - val_dice: 0.7223 - val_binary_accuracy: 0.8513
# Epoch 14/100
# Epoch 00013: val_dice improved from 0.72519 to 0.72872, saving model to ../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7287--2.hdf5
# 67s - loss: 0.3255 - dice: 0.6745 - binary_accuracy: 0.8398 - val_loss: 0.2713 - val_dice: 0.7287 - val_binary_accuracy: 0.8594
# Epoch 15/100
# Epoch 00014: val_dice improved from 0.72872 to 0.73461, saving model to ../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7346--2.hdf5
# 67s - loss: 0.3164 - dice: 0.6836 - binary_accuracy: 0.8512 - val_loss: 0.2654 - val_dice: 0.7346 - val_binary_accuracy: 0.8612
# Epoch 16/100
# Epoch 00015: val_dice did not improve
# 65s - loss: 0.3075 - dice: 0.6925 - binary_accuracy: 0.8514 - val_loss: 0.2803 - val_dice: 0.7197 - val_binary_accuracy: 0.8457
# Epoch 17/100
# Epoch 00016: val_dice did not improve
# 65s - loss: 0.3041 - dice: 0.6959 - binary_accuracy: 0.8516 - val_loss: 0.2804 - val_dice: 0.7196 - val_binary_accuracy: 0.8422
# Epoch 18/100
# Epoch 00017: val_dice improved from 0.73461 to 0.74281, saving model to ../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7428--2.hdf5
# 67s - loss: 0.3121 - dice: 0.6879 - binary_accuracy: 0.8425 - val_loss: 0.2572 - val_dice: 0.7428 - val_binary_accuracy: 0.8770
# Epoch 19/100
# Epoch 00018: val_dice improved from 0.74281 to 0.75452, saving model to ../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7545--2.hdf5
# 67s - loss: 0.3128 - dice: 0.6872 - binary_accuracy: 0.8526 - val_loss: 0.2455 - val_dice: 0.7545 - val_binary_accuracy: 0.8783
# Epoch 20/100
# Epoch 00019: val_dice improved from 0.75452 to 0.75645, saving model to ../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7565--2.hdf5
# 66s - loss: 0.3032 - dice: 0.6968 - binary_accuracy: 0.8583 - val_loss: 0.2435 - val_dice: 0.7565 - val_binary_accuracy: 0.8845
# Epoch 21/100
# Epoch 00020: val_dice did not improve
# 65s - loss: 0.2967 - dice: 0.7033 - binary_accuracy: 0.8594 - val_loss: 0.2497 - val_dice: 0.7503 - val_binary_accuracy: 0.8755
# Epoch 22/100
# Epoch 00021: val_dice did not improve
# 65s - loss: 0.3002 - dice: 0.6998 - binary_accuracy: 0.8561 - val_loss: 0.2661 - val_dice: 0.7339 - val_binary_accuracy: 0.8552
# Epoch 23/100
# Epoch 00022: val_dice did not improve
# 65s - loss: 0.2926 - dice: 0.7074 - binary_accuracy: 0.8598 - val_loss: 0.2951 - val_dice: 0.7049 - val_binary_accuracy: 0.8328
# Epoch 24/100
# Epoch 00023: val_dice improved from 0.75645 to 0.76110, saving model to ../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7611--2.hdf5
# 66s - loss: 0.2870 - dice: 0.7130 - binary_accuracy: 0.8609 - val_loss: 0.2389 - val_dice: 0.7611 - val_binary_accuracy: 0.8824
# Epoch 25/100
# Epoch 00024: val_dice improved from 0.76110 to 0.76887, saving model to ../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7689--2.hdf5
# 66s - loss: 0.2845 - dice: 0.7155 - binary_accuracy: 0.8659 - val_loss: 0.2311 - val_dice: 0.7689 - val_binary_accuracy: 0.8867
# Epoch 26/100
# Epoch 00025: val_dice did not improve
# 65s - loss: 0.2864 - dice: 0.7136 - binary_accuracy: 0.8718 - val_loss: 0.2537 - val_dice: 0.7463 - val_binary_accuracy: 0.8810
# Epoch 27/100
# Epoch 00026: val_dice improved from 0.76887 to 0.76926, saving model to ../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7693--2.hdf5
# 66s - loss: 0.2779 - dice: 0.7221 - binary_accuracy: 0.8746 - val_loss: 0.2307 - val_dice: 0.7693 - val_binary_accuracy: 0.8872
# Epoch 28/100
# Epoch 00027: val_dice improved from 0.76926 to 0.78712, saving model to ../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7871--2.hdf5
# 66s - loss: 0.2729 - dice: 0.7271 - binary_accuracy: 0.8753 - val_loss: 0.2129 - val_dice: 0.7871 - val_binary_accuracy: 0.8941
# Epoch 29/100
# Epoch 00028: val_dice did not improve
# 65s - loss: 0.2728 - dice: 0.7272 - binary_accuracy: 0.8722 - val_loss: 0.2377 - val_dice: 0.7623 - val_binary_accuracy: 0.8800
# Epoch 30/100
# Epoch 00029: val_dice did not improve
# 65s - loss: 0.2769 - dice: 0.7231 - binary_accuracy: 0.8743 - val_loss: 0.2292 - val_dice: 0.7708 - val_binary_accuracy: 0.8892
# Epoch 31/100
# Epoch 00030: val_dice did not improve
# 65s - loss: 0.2730 - dice: 0.7270 - binary_accuracy: 0.8751 - val_loss: 0.2325 - val_dice: 0.7675 - val_binary_accuracy: 0.8841
# Epoch 32/100
#
# Epoch 00031: reducing learning rate to 0.00499999988824.
# Epoch 00031: val_dice did not improve
# 65s - loss: 0.2657 - dice: 0.7343 - binary_accuracy: 0.8781 - val_loss: 0.2392 - val_dice: 0.7608 - val_binary_accuracy: 0.8809
# Epoch 33/100
# Epoch 00032: val_dice did not improve
# 65s - loss: 0.2607 - dice: 0.7393 - binary_accuracy: 0.8845 - val_loss: 0.2331 - val_dice: 0.7669 - val_binary_accuracy: 0.8869
# Epoch 34/100
# Epoch 00033: val_dice did not improve
# 65s - loss: 0.2516 - dice: 0.7484 - binary_accuracy: 0.8865 - val_loss: 0.2194 - val_dice: 0.7806 - val_binary_accuracy: 0.8950
# Epoch 35/100
#
# Epoch 00034: reducing learning rate to 0.00249999994412.
# Epoch 00034: val_dice did not improve
# 65s - loss: 0.2481 - dice: 0.7519 - binary_accuracy: 0.8896 - val_loss: 0.2305 - val_dice: 0.7695 - val_binary_accuracy: 0.8937
# Epoch 36/100
# Epoch 00035: val_dice did not improve
# 65s - loss: 0.2412 - dice: 0.7588 - binary_accuracy: 0.8923 - val_loss: 0.2227 - val_dice: 0.7773 - val_binary_accuracy: 0.8952
# Epoch 37/100
# Epoch 00036: val_dice did not improve
# 65s - loss: 0.2387 - dice: 0.7613 - binary_accuracy: 0.8921 - val_loss: 0.2220 - val_dice: 0.7780 - val_binary_accuracy: 0.8958
# Epoch 38/100
#
# Epoch 00037: reducing learning rate to 0.00124999997206.
# Epoch 00037: val_dice did not improve
# 65s - loss: 0.2375 - dice: 0.7625 - binary_accuracy: 0.8945 - val_loss: 0.2150 - val_dice: 0.7850 - val_binary_accuracy: 0.8997
# Epoch 39/100
# Epoch 00038: val_dice did not improve
# 65s - loss: 0.2313 - dice: 0.7687 - binary_accuracy: 0.8967 - val_loss: 0.2151 - val_dice: 0.7849 - val_binary_accuracy: 0.8997
# Epoch 00038: early stopping
# 2017-07-27 21:21:27.997019

# %%
#!ls ../Temp/TempTempG5M5KFold -la | tail
# !ls ../Temp/TempTempG5M5KFoldMean -la | tail
# Out:
# -rwxrwxrwx 1 boba boba 248917128 июл 27 21:06 V1-UNET-val_dice=0.7689--2.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 27 13:17 V1-UNET-val_dice=0.7689-2.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 27 13:24 V1-UNET-val_dice=0.7690-2.hdf5
# -rwxrwxrwx 1 boba boba 248917128 июл 27 21:08 V1-UNET-val_dice=0.7693--2.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 27 13:28 V1-UNET-val_dice=0.7697-2.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 27 13:31 V1-UNET-val_dice=0.7700-2.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 27 13:33 V1-UNET-val_dice=0.7711-2.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 27 13:57 V1-UNET-val_dice=0.7713-2.hdf5
# -rwxrwxrwx 1 boba boba 248957752 июл 27 19:23 V1-UNET-val_dice=0.7828-2.hdf5
# -rwxrwxrwx 1 boba boba 248917128 июл 27 21:09 V1-UNET-val_dice=0.7871--2.hdf5

# %%
if 0 : model10 = load_model('../Temp/TrainModel001+G+M/V1-UNET-0.8511.hdf5')
if 0 : model10 = load_model('../Temp/V1-UNET-0.8853.hdf5')
#if 1 : model10 = load_model('../Temp/TempTempM3/V1-UNET-0.9054.hdf5')
if 0 : model10.load_weights('../Temp/TempTempM3/V1-UNET-0.9054.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5/V1-UNET-val_dice=0.7307.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7879-2.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7632-2.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7660-2.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7828-2.hdf5')

# %%
# %time trP = model10.predict(trX,batch_size=batch_size)
# Out:
# CPU times: user 15.1 s, sys: 3.88 s, total: 19 s
# Wall time: 18.2 s

# %%
trP01 = trP
trP01[trP>0.5] =1.0
trP01[trP<=0.5]=0.0
trP01 = trP01.astype(np.uint8)

# %%
if 0 : # Ощутимых результатов не дает, увеличение в +10-100
    times, medianP = 3,5
    for i in range(trP01.shape[0]) :
        for j in range(times) :
            trP01[i,:,:,0] = cv.medianBlur(trP01[i],medianP)

# %%
iii = 10
print(trX[0].shape,trY[0].shape,trP.shape,trP.min(),trP.max())
for ii in range(iii,iii+10) :
    plt.figure(figsize=(15,5))
    plt.subplot(151); plt.imshow(trX[ii,:,:,0],'gray'); 
    plt.subplot(152); plt.imshow(trY[ii,:,:,0],'gray'); 
    plt.subplot(153); plt.imshow(trP[ii,:,:,0],'gray'); 
    plt.subplot(154); plt.imshow(trP01[ii,:,:,0],'gray'); 
    plt.subplot(155); plt.hist(trP[ii,:,:,0].ravel(),bins=50); 
    plt.show()
plt.close()
# Out:
# (512, 512, 3) (512, 512, 1) (168, 512, 512, 1) 0.0 1.0

# %%
# Calculate F1-micro

# %%
TP = (trY[:,6:506,6:506,0]*trP01[:,6:506,6:506,0]).sum()
TN = ((1.0-trY[:,6:506,6:506,0])*(1.0-trP01[:,6:506,6:506,0])).sum()
FP = ((trY[:,6:506,6:506,0])*(1.0-trP01[:,6:506,6:506,0])).sum()
FN = ((1.0-trY[:,6:506,6:506,0])*(trP01[:,6:506,6:506,0])).sum()

P  = TP/(TP+FP) if (TP+FP)>0.0 else 1.0
R  = TP/(TP+FN) if (TP+FN)>0.0 else 0.0

F1 = 2.0*P*R/(P+R) if (P+R)>0.0 else 0.0

TP,TN,FP,FN,P,R,F1
#P*R,P+R, 2.0*P*R/(P+R)
# Out:
# (12294325.0,
#  25291285.0,
#  1793895.0,
#  2620495.0,
#  0.87266702251952344,
#  0.82430260640088182,
#  0.84779561039118656)

# %%
# Calculate DI- dice.mean()

# %%
dice, XX = [],[]
for i in range(trP.shape[0]) :
    G = trY  [i,6:506,6:506,0].sum()
    S = trP01[i,6:506,6:506,0].sum()
    X = (trY [i,6:506,6:506,0]*trP01[i,6:506,6:506,0]).sum()
    XX.append(X)
    dice.append((2.0*X/(G+S) if G+S>0 else 1.0))
di = (np.array(dice)).mean()
di #,np.array(dice)  #,np.array(XX)
# Out:
# 0.77594776025533463

# %%
plt.hist(np.array(dice),bins=40); plt.show()
plt.plot(np.array(dice)); plt.show()

# %%
1000000*(F1+di)/2.0
# Out:
# 811871.68532326061

# %%
#np.array(dice)<0.4

# %%
# Подготовка test решения

# %%
if flagGray :
    trO, trO0 = [], np.zeros((512,512,1))
else :
    trO, trO0 = [], np.zeros((512,512,3))

for xx in listTest :
    img = cv.imread(os.path.join(dirTest,xx),-1)
    if 1 and (Gauss or Median): 
        for cc in range(img.shape[2]) : 
            if Gauss  : img[:,:,cc] = cv.GaussianBlur(img[:,:,cc],(Gauss,Gauss),0);
            if Median : img[:,:,cc] = cv.medianBlur  (img[:,:,cc],Median);
    #print(img.mean(),msk.mean())
    if flagGray :
        img = cv.cvtColor(img,cv.COLOR_RGB2GRAY);
        trO0[6:506,6:506,0] = img[:,:]/255.0
    else :
        trO0[6:506,6:506,:] = img[:,:,:]/255.0
    trO.append(trO0.copy())
    #print(trX0.mean(),trY0.mean(),trX1[-1].mean(),trY1[-1].mean())

#print([trY[xx].mean() for xx in range(10)])
trO = np.array(trO)

if 1 :
    for cc in range(meanX.shape[0]) : 
        trO[:,6:506,6:506,cc] -= meanX[cc]
    
trO.shape, trO.min(), trO.max()
#[trY[xx].mean() for xx in range(10)]
# Out:
# ((162, 512, 512, 3), -0.64172901643308589, 0.47912580261435156)

# %%
# %time trOP = model10.predict(trO,batch_size=batch_size)
# Out:
# CPU times: user 14.4 s, sys: 3.8 s, total: 18.2 s
# Wall time: 17.4 s

# %%
trOP01 = trOP
trOP01[trOP>0.5] =1.0
trOP01[trOP<=0.5]=0.0

# %%
iii = 40
print(trO[0].shape,trP01[0].shape,trOP01.shape,trOP.min(),trOP.max())
for ii in range(iii,iii+10) :
    plt.figure(figsize=(15,5))
    plt.subplot(141); plt.imshow(trO[ii,:,:,0]); 
    plt.subplot(142); plt.imshow(trOP01[ii,:,:,0],'gray'); 
    plt.subplot(143); plt.imshow(trOP[ii,:,:,0],'gray'); 
    plt.subplot(144); plt.hist(trOP[ii,:,:,0].ravel(),bins=50); 
    plt.show()
plt.close()
# Out:
# (512, 512, 3) (512, 512, 1) (162, 512, 512, 1) 0.0 1.0

# %%
# Формирование выходной директории

# %%
def convert_to_binary(truth_png_file, truth_txt_file):
    im = Image.open(truth_png_file) #Can be many different formats.
    pix = im.load()
    with open(truth_txt_file, 'w') as out:
        for x in xrange(500):
            for y in xrange(500):
                out.write(str(int(pix[x, y] > 0)))
            out.write('\n')

if not os.path.exists('../Temp/random_submission'):
    os.makedirs('../Temp/random_submission')

# Training
for i in range(len(listTrain)) :
    fn = listTrain[i]
    truth_txt_file = '../Temp/random_submission/' + fn.split('.')[0] + '_mask.txt'
    with open(truth_txt_file, 'w') as out:
        for x in xrange(500):
            for y in xrange(500):
                out.write(str(int(trP01[i,y+6, x+6] > 0.0)))
            out.write('\n')
    out.close()
    
# Testing
for i in range(len(listTest)) :
    fn = listTest[i]
    truth_txt_file = '../Temp/random_submission/' + fn.split('.')[0] + '_mask.txt'
    with open(truth_txt_file, 'w') as out:
        for x in xrange(500):
            for y in xrange(500):
                out.write(str(int(trOP01[i,y+6, x+6] > 0.0)))
            out.write('\n')
    out.close()

# %%
import shutil

# %%
xx=shutil.make_archive('../Result/topcoderkonica','zip','../Temp/random_submission')
xx
# Out:
# '/media/boba/DATA/boba/Working/TopCoder/2017-07-25-Konica-Minolta/Result/topcoderkonica.zip'

# %%
# !ls ../Temp -la
# Out:
# total 4610508
# drwxrwxrwx 1 boba boba      4096 июл 26 10:58 .
# drwxrwxrwx 1 boba boba      4096 июл 26 10:11 ..
# drwxrwxrwx 1 boba boba         0 июл 25 18:17 .ipynb_checkpoints
# drwxrwxrwx 1 boba boba     61440 июл 26 09:14 random_submission
# -rwxrwxrwx 1 boba boba   1057596 июл 26 10:58 random_submission.zip
# drwxrwxrwx 1 boba boba         0 июл 25 23:35 TrainModel001-G-M
# drwxrwxrwx 1 boba boba         0 июл 25 22:21 TrainModel001-G+M
# drwxrwxrwx 1 boba boba         0 июл 25 21:48 TrainModel001+G-M
# drwxrwxrwx 1 boba boba      4096 июл 25 21:05 TrainModel001+G+M
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:02 V1-UNET-0.8167.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:08 V1-UNET-0.8275.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 18:33 V1-UNET-0.8305.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 18:02 V1-UNET-0.8418.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:09 V1-UNET-0.8486.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:09 V1-UNET-0.8593.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 18:34 V1-UNET-0.8601.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:21 V1-UNET-0.8602.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:22 V1-UNET-0.8605.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:35 V1-UNET-0.8628.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:35 V1-UNET-0.8633.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:23 V1-UNET-0.8635.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:36 V1-UNET-0.8645.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:36 V1-UNET-0.8652.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:24 V1-UNET-0.8655.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:11 V1-UNET-0.8793.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:13 V1-UNET-0.8796.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 19:14 V1-UNET-0.8808.hdf5
# -rwxrwxrwx 1 boba boba 248418336 июл 25 18:02 V1-UNET-0.8853.hdf5

# %%
# !ls ../Work -la
#!ls ../Temp/random_submission
# Out:
# total 80768
# drwxrwxrwx 1 boba boba        0 июл 26 09:17 .
# drwxrwxrwx 1 boba boba     4096 июл 25 15:24 ..
# -rwxrwxrwx 1 boba boba 82700662 июл 26 09:32 topcoderkonica.zip

# %%
if False :
    save_model(model10,'../Data-Keras/Models/model-UNet.h5')
    model10.save_weights('../Data-Keras/Models/model-UNet-weights.h5')

# %%
rrr=pd.DataFrame(res,columns=['image_name','tags']); rrr.head(); 
suffixDT = (datetime.datetime.now()).strftime('%Y-%m-%d-%H-%M-%S'); print(suffixDT)
rrr.to_csv('../Result/vss'+suffixDT+'.csv',index=False);
# Out:
# 2017-05-20-05-51-18
