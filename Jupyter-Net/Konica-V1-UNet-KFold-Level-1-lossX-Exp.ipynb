# %%
##
## UNet 
##
## Взята идея по описанию из https://github.com/pietz/unet-keras
##
##
## 2017-07-28
##   Добавлены flip+rotation LB=760393
##
## 2017-07-29
##   LB=769123 += 3000
##
## 2017-07-31
##   Level-1, KFold = 5, xloss, only flip
##   Покoпытим этот вариант, пока других идей нет
##
##

# %%
import sys,os,datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import fbeta_score
import sklearn.metrics as skm
from __future__ import print_function

# %%
print(np.__version__);
print(pd.__version__);
# Out:
# 1.13.1
# 0.19.2

# %%
import  cv2 as cv
cv.__version__
# Out:
# '3.2.0'

# %%
#from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.models import Sequential, save_model, load_model, Input, Model
from keras.layers import Convolution2D, MaxPooling2D, Convolution1D, MaxPooling1D, UpSampling2D, ZeroPadding2D
from keras.layers import Conv2D, Concatenate, Reshape
from keras.layers import Activation, Dropout, Flatten, Dense, Permute
from keras.layers.normalization import BatchNormalization
import keras.optimizers
from keras.callbacks import EarlyStopping,ReduceLROnPlateau,ModelCheckpoint
import keras.backend as K
# Out:
# Using TensorFlow backend.

# %%
keras.__version__
# Out:
# '2.0.6'

# %%
#---------------------------------------------------------------------

# %%
# !ls -la ..
#!ls -la ../Data
#!ls -la ../Data/training
# Out:
# total 25
# drwxrwxrwx 1 boba boba 4096 июл 26 11:10 .
# drwxrwxrwx 1 boba boba    0 июл 25 09:21 ..
# drwxrwxrwx 1 boba boba 4096 июл 25 09:23 Data
# drwxrwxrwx 1 boba boba    0 июл 25 09:22 Data-Arch
# drwxrwxrwx 1 boba boba    0 июл 25 09:26 Data-Keras
# drwxrwxrwx 1 boba boba 4096 авг  1 18:26 .git
# -rwxrwxrwx 2 boba boba  130 июл  9 12:02 .gitignore
# drwxrwxrwx 1 boba boba    0 июл 26 10:11 .ipynb_checkpoints
# drwxrwxrwx 1 boba boba    0 авг  1 18:26 Jupyter
# drwxrwxrwx 1 boba boba 4096 авг  2 10:00 Jupyter-Net
# drwxrwxrwx 1 boba boba 4096 июл 30 17:32 Result
# drwxrwxrwx 1 boba boba 4096 июл 30 17:41 Temp
# drwxrwxrwx 1 boba boba    0 июл 27 07:53 Work

# %%
dirData = '../Data'
dirTemp = '../Temp'
dirWork = '../Work'

dirTest  = os.path.join(dirData,'testing','images')
dirTrain = os.path.join(dirData,'training','images')
dirMask  = os.path.join(dirData,'training','truth')

# %%
listTrain = os.listdir(dirTrain)
listMask  = os.listdir(dirMask)
listTest  = os.listdir(dirTest)
listTrain = [xx for xx in listTrain if os.path.splitext(xx)[1]=='.tif']
listMask  = [xx for xx in listMask  if os.path.splitext(xx)[1]=='.png']
listTest  = [xx for xx in listTest  if os.path.splitext(xx)[1]=='.tif']
print(len(listTrain),len(listMask),len(listTest))
print(listTrain[:5],'\n',listMask[:5],'\n',listTest[:5])
# Out:
# 168 168 162
# ['i105404.tif', 'i117557.tif', 'i124017.tif', 'i130790.tif', 'i137857.tif']
#  ['i105404_mask.png', 'i117557_mask.png', 'i124017_mask.png', 'i130790_mask.png', 'i137857_mask.png']
#  ['i105047.tif', 'i116596.tif', 'i137649.tif', 'i140176.tif', 'i142099.tif']

# %%
if 0 :
    for xx in listTrain[:5] :
        img = cv.imread(os.path.join(dirTrain,xx),-1)
        xxm = os.path.splitext(xx)[0]+"_mask.png"
        msk = cv.imread(os.path.join(dirMask,xxm),-1)
        plt.subplot(121); plt.imshow(img); plt.subplot(122); plt.imshow(msk,'gray'); plt.show()
    plt.close()

# %%
#msk.shape, img.shape, img.min(), img.max(), msk.max(), #img[6:10,6:10], msk[6:10,6:10]

# %%
flagGray = False
Gauss    = 5
Median   = 5
if flagGray :
    trX, trY, trX0, trY0 = [], [], np.zeros((512,512,1)), np.zeros((512,512,1))
else :
    trX, trY, trX0, trY0 = [], [], np.zeros((512,512,3)), np.zeros((512,512,1))

for xx in listTrain :
    img = cv.imread(os.path.join(dirTrain,xx),-1)
    if 1 and (Gauss or Median): 
        for cc in range(img.shape[2]) : 
            if Gauss  : img[:,:,cc] = cv.GaussianBlur(img[:,:,cc],(Gauss,Gauss),0);
            if Median : img[:,:,cc] = cv.medianBlur  (img[:,:,cc],Median);
    xxm = os.path.splitext(xx)[0]+"_mask.png"
    msk = cv.imread(os.path.join(dirMask,xxm),-1)
    #print(img.mean(),msk.mean())
    if flagGray :
        img = cv.cvtColor(img,cv.COLOR_RGB2GRAY);
        trX0[6:506,6:506,0] = img[:,:]/255.0
        trY0[6:506,6:506,0] = msk[:,:]/255.0
    else :
        trX0[6:506,6:506,:] = img[:,:,:]/255.0
        trY0[6:506,6:506,0] = msk[:,:]/255.0
        trY0[trY0>=0.5] = 1.0
    trX.append(trX0.copy())
    trY.append(trY0.copy())
    #print(trX0.mean(),trY0.mean(),trX1[-1].mean(),trY1[-1].mean())

#print([trY[xx].mean() for xx in range(10)])
trX = np.array(trX)
trY = np.array(trY)

# аугментация
trXX, trYY, trXXX,trYYY = trX.copy(), trY.copy(), np.zeros((1)), np.zeros((1))


if 1 :
    # flipping
    for f in range(-1,2) :
        trXXX, trYYY = trX.copy(), trY.copy()
        for p in range(trXXX.shape[0]) :
            trXXX[p], trYYY[p,:,:,0] = cv.flip(trXXX[p],f), cv.flip(trYYY[p,:,:,0],f)
        trXX = np.vstack([trXX,trXXX])
        trYY = np.vstack([trYY,trYYY])
        print('flip :',f,trXX.shape,trYY.shape)

if 0 :
    # rotate +-90

    # rotate +90
    trXXX, trYYY = trX.copy(), trY.copy()
    for p in range(trX.shape[0]) :
        for i in range(trX.shape[1]) :
            for j in range(trX.shape[2]) :
                trXXX[p,i,j,:] = trX[p,j,trX.shape[1]-i-1]
                trYYY[p,i,j,:] = trY[p,j,trY.shape[1]-i-1]
    trXX = np.vstack([trXX,trXXX])
    trYY = np.vstack([trYY,trYYY])
    print('rotate +90:',trXX.shape,trYY.shape)

    # rotate -90
    trXXX, trYYY = trX.copy(), trY.copy()
    for p in range(trX.shape[0]) :
        for i in range(trX.shape[1]) :
            for j in range(trX.shape[2]) :
                trXXX[p,i,j,:] = trX[p,trX.shape[2]-j-1,i]
                trYYY[p,i,j,:] = trY[p,trY.shape[2]-j-1,i]
    trXX = np.vstack([trXX,trXXX])
    trYY = np.vstack([trYY,trYYY])
    print('rotate -90:',trXX.shape,trYY.shape)
    
trX, trY = trXX.copy(), trYY.copy()
del trXX,trYY
del trXXX,trYYY

# Считаем среднее по каналам и вычитаем из изображений
meanX = (trX[:,6:-6,6:-6,:].mean(axis=(1,2))).mean(axis=0)
stdX  = (trX[:,6:-6,6:-6,:].mean(axis=(1,2))).std(axis=0)
for cc in range(meanX.shape[0]) : 
    trX[:,6:-6,6:-6,cc] -= meanX[cc]    
print("mean={} std={}".format(meanX,stdX))
    
trX.shape, trX.min(), trX.max(), trY.shape, trY.min(), trY.max()
#[trY[xx].mean() for xx in range(10)]
# Out:
# flip : -1 (336, 512, 512, 3) (336, 512, 512, 1)
# flip : 0 (504, 512, 512, 3) (504, 512, 512, 1)
# flip : 1 (672, 512, 512, 3) (672, 512, 512, 1)
# mean=[ 0.6473997   0.48950165  0.70839568] std=[ 0.06249822  0.09179847  0.08778627]
# ((672, 512, 512, 3),
#  -0.62212117329585626,
#  0.48696893986925865,
#  (672, 512, 512, 1),
#  0.0,
#  1.0)

# %%
for xx in range(5) :
    img = trX[xx]
    xxm = trY[xx]
    plt.subplot(121); plt.imshow(img); plt.subplot(122); plt.imshow(xxm[:,:,0],'gray'); plt.show()
plt.close()

# %%
#
# model UNET
#
#    https://github.com/pietz/unet-keras
#
#

def level_block(m, dim, depth, acti, dropout=0.25, batch=True):
    if depth > 0:
        
        x = m
        if batch : x = BatchNormalization()(x)
        n = Conv2D(dim, (3, 3), activation=acti, padding='same')(x) #(m)
        n = Conv2D(dim, (3, 3), activation=acti, padding='same')(n)
        m = MaxPooling2D((2, 2))(n)
        if dropout : n = Dropout(dropout)(n) ## add
        m = level_block(m, 2*dim, depth-1, acti, dropout=dropout, batch=batch)
        m = UpSampling2D((2, 2))(m)
        m = Conv2D(dim, (2, 2), activation=acti, padding='same', kernel_initializer='he_normal')(m)
        ### 2017-08-01  !!!!!!!!!!! if dropout : m = Dropout(dropout)(m) ## add
        m = Concatenate(axis=3)([n, m])
    m = Conv2D(dim, (3, 3), activation=acti, padding='same')(m)
    return Conv2D(dim, (3, 3), activation=acti, padding='same')(m)

def UNet(img_shape, n_out=2, dim=32, depth=5, acti='relu', flatten=False, dropout=0.25, batch=True):
    i = Input(shape=img_shape)
    ## ???? i = ZeroPadding2D((6,6),data_format="channels_last")
    o = level_block(i, dim, depth, acti, dropout=dropout, batch=batch)
    o = Conv2D(n_out, (1, 1), name='prediction')(o)
    if flatten:
        o = Reshape(n_out, img_shape[0] * img_shape[1])(o)
        o = Permute((2, 1))(o)
    #o = Activation('relu')(o)
    if batch : o = BatchNormalization()(o)  ######
    o = Activation('sigmoid')(o)
    if dropout : o = Dropout(dropout)(o) ## add 2017-08-01
    return Model(inputs=i, outputs=o)

# %%
model10 = UNet((512,512,3),depth=4,n_out=1, dropout=0.05)
model10.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 512, 512, 3)   0
# ____________________________________________________________________________________________________
# batch_normalization_1 (BatchNorm (None, 512, 512, 3)   12          input_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_1 (Conv2D)                (None, 512, 512, 32)  896         batch_normalization_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_2 (Conv2D)                (None, 512, 512, 32)  9248        conv2d_1[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)   (None, 256, 256, 32)  0           conv2d_2[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_2 (BatchNorm (None, 256, 256, 32)  128         max_pooling2d_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_3 (Conv2D)                (None, 256, 256, 64)  18496       batch_normalization_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_4 (Conv2D)                (None, 256, 256, 64)  36928       conv2d_3[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)   (None, 128, 128, 64)  0           conv2d_4[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_3 (BatchNorm (None, 128, 128, 64)  256         max_pooling2d_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_5 (Conv2D)                (None, 128, 128, 128) 73856       batch_normalization_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_6 (Conv2D)                (None, 128, 128, 128) 147584      conv2d_5[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)   (None, 64, 64, 128)   0           conv2d_6[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_4 (BatchNorm (None, 64, 64, 128)   512         max_pooling2d_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_7 (Conv2D)                (None, 64, 64, 256)   295168      batch_normalization_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_8 (Conv2D)                (None, 64, 64, 256)   590080      conv2d_7[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)   (None, 32, 32, 256)   0           conv2d_8[0][0]
# ____________________________________________________________________________________________________
# conv2d_9 (Conv2D)                (None, 32, 32, 512)   1180160     max_pooling2d_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_10 (Conv2D)               (None, 32, 32, 512)   2359808     conv2d_9[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)   (None, 64, 64, 512)   0           conv2d_10[0][0]
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)              (None, 64, 64, 256)   0           conv2d_8[0][0]
# ____________________________________________________________________________________________________
# conv2d_11 (Conv2D)               (None, 64, 64, 256)   524544      up_sampling2d_1[0][0]
# ____________________________________________________________________________________________________
# concatenate_1 (Concatenate)      (None, 64, 64, 512)   0           dropout_4[0][0]
#                                                                    conv2d_11[0][0]
# ____________________________________________________________________________________________________
# conv2d_12 (Conv2D)               (None, 64, 64, 256)   1179904     concatenate_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_13 (Conv2D)               (None, 64, 64, 256)   590080      conv2d_12[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)   (None, 128, 128, 256) 0           conv2d_13[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)              (None, 128, 128, 128) 0           conv2d_6[0][0]
# ____________________________________________________________________________________________________
# conv2d_14 (Conv2D)               (None, 128, 128, 128) 131200      up_sampling2d_2[0][0]
# ____________________________________________________________________________________________________
# concatenate_2 (Concatenate)      (None, 128, 128, 256) 0           dropout_3[0][0]
#                                                                    conv2d_14[0][0]
# ____________________________________________________________________________________________________
# conv2d_15 (Conv2D)               (None, 128, 128, 128) 295040      concatenate_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_16 (Conv2D)               (None, 128, 128, 128) 147584      conv2d_15[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)   (None, 256, 256, 128) 0           conv2d_16[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)              (None, 256, 256, 64)  0           conv2d_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_17 (Conv2D)               (None, 256, 256, 64)  32832       up_sampling2d_3[0][0]
# ____________________________________________________________________________________________________
# concatenate_3 (Concatenate)      (None, 256, 256, 128) 0           dropout_2[0][0]
#                                                                    conv2d_17[0][0]
# ____________________________________________________________________________________________________
# conv2d_18 (Conv2D)               (None, 256, 256, 64)  73792       concatenate_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_19 (Conv2D)               (None, 256, 256, 64)  36928       conv2d_18[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)   (None, 512, 512, 64)  0           conv2d_19[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 512, 512, 32)  0           conv2d_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_20 (Conv2D)               (None, 512, 512, 32)  8224        up_sampling2d_4[0][0]
# ____________________________________________________________________________________________________
# concatenate_4 (Concatenate)      (None, 512, 512, 64)  0           dropout_1[0][0]
#                                                                    conv2d_20[0][0]
# ____________________________________________________________________________________________________
# conv2d_21 (Conv2D)               (None, 512, 512, 32)  18464       concatenate_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_22 (Conv2D)               (None, 512, 512, 32)  9248        conv2d_21[0][0]
# ____________________________________________________________________________________________________
# prediction (Conv2D)              (None, 512, 512, 1)   33          conv2d_22[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_5 (BatchNorm (None, 512, 512, 1)   4           prediction[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 512, 512, 1)   0           batch_normalization_5[0][0]
# ____________________________________________________________________________________________________
# dropout_5 (Dropout)              (None, 512, 512, 1)   0           activation_1[0][0]
# ====================================================================================================
# Total params: 7,761,009
# Trainable params: 7,760,553
# Non-trainable params: 456
# ____________________________________________________________________________________________________

# %%
#
# 2017-07-31
#   Перестроил реализацию на метод ZFTurbo : +1.0 к знаменателю и числителю. Более корректно работает на пустых картинках.
#   На пустых картинках возможно зависание (==0, nan для x=0,  g = 0, s <> 0 (10-200))
#
#   Не очень понятно как это работает на всем batch, но на одном с batch_size=1 должно работать корректно
#
#
def dice (truth,pred) :
    g, s = K.sum(truth), K.sum(pred)
    x    = K.sum(truth*pred)
    return(K.clip((2.0*x+1.0)/(g+s+1.0), 0.01, 1.0))
    #return((1.0 if K.sum(g+s)==0.0 else 2.0*x/(g+s+K.epsilon())))
    
def diceNP (truth,pred, printOK=False) :
    g, s = truth.sum(), pred.sum()
    x    = (truth*pred).sum()
    if printOK : print('x={} g={} s={}'.format(x,g,s))
    return((2.0*x+1.0)/(g+s+1.0))
    #return((1.0 if K.sum(g+s)==0.0 else 2.0*x/(g+s+K.epsilon())))

def f1 (truth,pred) :
    TP = K.sum(truth*pred)
    TN = K.sum((1.0-truth)*(1.0-pred))
    FP = K.sum(truth*(1.0-pred))
    FN = K.sum((1.0-truth)*pred)

    
    P  = 1.0 if K.sum(TP+FP)==0.0 else TP/(TP+FP)
    R  = 0.0 if K.sum(TP+FN)==0.0 else TP/(TP+FN) 

    F1 = 0.0 if K.sum(P+R)  ==0.0 else 2.0*P*R/(P+R)

    return(F1)

def f1dice (truth,pred) :
    return ((dice(truth,pred)+f1(truth,pred))/2.0)
    
def lossdice (truth,pred) :
    return(1.0 - dice(truth,pred))

def lossfd (truth,pred) :
    return(1.0 - f1dice(truth,pred))
    
import keras.losses as losses

def lossXdice (truth,pred) :
    return(losses.binary_crossentropy(truth,pred) - K.log(dice(truth,pred)))

def lossYdice (truth,pred) :
    return( - K.log(dice(truth,pred) ))

def lossZdice (truth,pred) :
    return(1.0 - dice(truth,pred)**3+losses.binary_crossentropy(truth,pred))

def lossZ2dice (truth,pred) :
    return(1.0 - dice(truth,pred)**3+losses.binary_crossentropy(truth,pred))

# %%
def modelBuild (input_shape) :
##    model = UNet(input_shape,depth=5,n_out=1,dropout=0.05,batch=False)
#    model = UNet(input_shape,depth=5-1,n_out=1,dropout=0.05,batch=False)
#    model = UNet(input_shape,depth=5-1,n_out=1,dropout=0.75,batch=False)
    model = UNet(input_shape,depth=5-1,n_out=1,dropout=0.10,batch=False)
    return(model)
    
def modelCompile (model, lr=0.01) :
    sgd = keras.optimizers.SGD(lr=lr, momentum=0.9, nesterov=True)
    #model.compile(loss='mean_absolute_error',  #'binary_crossentropy',
    model.compile(loss=lossXdice, #'mean_absolute_error',  #'binary_crossentropy',
                  optimizer=sgd, #sgd, #"adam", #'rmsprop',
                  metrics=[dice,'binary_accuracy']) #['binary_accuracy']) #[fbeta_pred]) #['accuracy',fbeta_pred]) #['accuracy'])
    return(model)


def buildModel (input_shape) :
##    model = UNet(input_shape,depth=5,n_out=1,dropout=0.05,batch=False)
#    model = UNet(input_shape,depth=5-1,n_out=1,dropout=0.05,batch=False)
#    model = UNet(input_shape,depth=5-1,n_out=1,dropout=0.75,batch=False)
    model = UNet(input_shape,depth=5-1,n_out=1,dropout=0.45,batch=False)
    
    sgd = keras.optimizers.SGD(lr=0.01, momentum=0.9, nesterov=True)
    #model.compile(loss='mean_absolute_error',  #'binary_crossentropy',
    model.compile(loss=lossZ2dice, #'mean_absolute_error',  #'binary_crossentropy',
                  optimizer=sgd, #sgd, #"adam", #'rmsprop',
                  metrics=[dice,'binary_accuracy']) #['binary_accuracy']) #[fbeta_pred]) #['accuracy',fbeta_pred]) #['accuracy'])
    return(model)

# %%
K.clear_session()
model10 = buildModel((trX.shape[1],trX.shape[2],trX.shape[3]))
model10.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 512, 512, 3)   0
# ____________________________________________________________________________________________________
# conv2d_1 (Conv2D)                (None, 512, 512, 32)  896         input_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_2 (Conv2D)                (None, 512, 512, 32)  9248        conv2d_1[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)   (None, 256, 256, 32)  0           conv2d_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_3 (Conv2D)                (None, 256, 256, 64)  18496       max_pooling2d_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_4 (Conv2D)                (None, 256, 256, 64)  36928       conv2d_3[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)   (None, 128, 128, 64)  0           conv2d_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_5 (Conv2D)                (None, 128, 128, 128) 73856       max_pooling2d_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_6 (Conv2D)                (None, 128, 128, 128) 147584      conv2d_5[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)   (None, 64, 64, 128)   0           conv2d_6[0][0]
# ____________________________________________________________________________________________________
# conv2d_7 (Conv2D)                (None, 64, 64, 256)   295168      max_pooling2d_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_8 (Conv2D)                (None, 64, 64, 256)   590080      conv2d_7[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)   (None, 32, 32, 256)   0           conv2d_8[0][0]
# ____________________________________________________________________________________________________
# conv2d_9 (Conv2D)                (None, 32, 32, 512)   1180160     max_pooling2d_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_10 (Conv2D)               (None, 32, 32, 512)   2359808     conv2d_9[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)   (None, 64, 64, 512)   0           conv2d_10[0][0]
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)              (None, 64, 64, 256)   0           conv2d_8[0][0]
# ____________________________________________________________________________________________________
# conv2d_11 (Conv2D)               (None, 64, 64, 256)   524544      up_sampling2d_1[0][0]
# ____________________________________________________________________________________________________
# concatenate_1 (Concatenate)      (None, 64, 64, 512)   0           dropout_4[0][0]
#                                                                    conv2d_11[0][0]
# ____________________________________________________________________________________________________
# conv2d_12 (Conv2D)               (None, 64, 64, 256)   1179904     concatenate_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_13 (Conv2D)               (None, 64, 64, 256)   590080      conv2d_12[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)   (None, 128, 128, 256) 0           conv2d_13[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)              (None, 128, 128, 128) 0           conv2d_6[0][0]
# ____________________________________________________________________________________________________
# conv2d_14 (Conv2D)               (None, 128, 128, 128) 131200      up_sampling2d_2[0][0]
# ____________________________________________________________________________________________________
# concatenate_2 (Concatenate)      (None, 128, 128, 256) 0           dropout_3[0][0]
#                                                                    conv2d_14[0][0]
# ____________________________________________________________________________________________________
# conv2d_15 (Conv2D)               (None, 128, 128, 128) 295040      concatenate_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_16 (Conv2D)               (None, 128, 128, 128) 147584      conv2d_15[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)   (None, 256, 256, 128) 0           conv2d_16[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)              (None, 256, 256, 64)  0           conv2d_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_17 (Conv2D)               (None, 256, 256, 64)  32832       up_sampling2d_3[0][0]
# ____________________________________________________________________________________________________
# concatenate_3 (Concatenate)      (None, 256, 256, 128) 0           dropout_2[0][0]
#                                                                    conv2d_17[0][0]
# ____________________________________________________________________________________________________
# conv2d_18 (Conv2D)               (None, 256, 256, 64)  73792       concatenate_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_19 (Conv2D)               (None, 256, 256, 64)  36928       conv2d_18[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)   (None, 512, 512, 64)  0           conv2d_19[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 512, 512, 32)  0           conv2d_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_20 (Conv2D)               (None, 512, 512, 32)  8224        up_sampling2d_4[0][0]
# ____________________________________________________________________________________________________
# concatenate_4 (Concatenate)      (None, 512, 512, 64)  0           dropout_1[0][0]
#                                                                    conv2d_20[0][0]
# ____________________________________________________________________________________________________
# conv2d_21 (Conv2D)               (None, 512, 512, 32)  18464       concatenate_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_22 (Conv2D)               (None, 512, 512, 32)  9248        conv2d_21[0][0]
# ____________________________________________________________________________________________________
# prediction (Conv2D)              (None, 512, 512, 1)   33          conv2d_22[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 512, 512, 1)   0           prediction[0][0]
# ____________________________________________________________________________________________________
# dropout_5 (Dropout)              (None, 512, 512, 1)   0           activation_1[0][0]
# ====================================================================================================
# Total params: 7,760,097
# Trainable params: 7,760,097
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
#model10.load_weights('../Data-Keras/Models/model-UNet-weights.h5', by_name=False)
batch_size = 1

# %%
epochs     = 150
#epochs     = 50
verbose    = 2
batch_size = 1
metric     = 'binary_accuracy'
metric     = 'dice'

############trX, trY = trX[0:30], trY[0:30]

##folds      = 10
folds      = 5
##folds      = 3
foldN      = trX.shape[0]/folds+1

print(datetime.datetime.now(),'Training with folds')

##for i in range(folds) :
for i in range(1,3) :

    print(datetime.datetime.now(),'------------>',i)

    K.clear_session()
    model10 = modelBuild((trX.shape[1],trX.shape[2],trX.shape[3]))
    ############if 1 : model10.load_weights('../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7660-2.hdf5')
    model10 = modelCompile(model10)
    if 0 : model10.load_weights('../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.5332-0.7462-Z3BCE-D75G0M0-0.hdf5')

    early_stopping = EarlyStopping(monitor='val_loss', patience=12,min_delta=0.0001,verbose=1)
#    early_stopping = EarlyStopping(monitor='val_loss', patience=5,min_delta=0.0001,verbose=1)
    reduce_lr1     = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, min_lr=0.0000001,verbose=1)
    reduce_lr2     = ReduceLROnPlateau(monitor='loss',     factor=0.2, patience=3, min_lr=0.0000001,verbose=1)

    filepath="../Temp/NewStep/Level-1-loss/V1-UNET-val_"+metric+"={val_"+metric+":.4f}-{"+metric+":.4f}-e={epoch}--X--D10G5M5---"+str(i)+".hdf5"
    #filepath="../Temp/NewStep/StandartF5/V1-UNET-val_"+metric+"={val_"+metric+":.4f}-{"+metric+":.4f}---"+str(i)+".hdf5"
    #filepath="../Temp/TempTempG5M5KFold10/V1-UNET-val_"+metric+"={val_"+metric+":.4f}-{"+metric+":.4f}---"+str(i)+".hdf5"
    #checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
    checkpoint1 = ModelCheckpoint(filepath, monitor=metric,        verbose=1, save_best_only=True, mode='max')
    checkpoint2 = ModelCheckpoint(filepath, monitor='val_'+metric, verbose=1, save_best_only=True, mode='max')

    step  = 60
    low   = 0
    high  = low+step
    
    tFold = [True]*(i*foldN)+[False]*foldN+[True]*trX.shape[0];
    tFold = tFold[:trX.shape[0]]
    
    vFold = [not xx for xx in tFold]

    #hist1  = model10.fit(trX[low:high],trY[low:high],
    hist1  = model10.fit(trX[tFold],trY[tFold],
                        epochs=epochs, batch_size=batch_size, 
                        #validation_split=0.20, 
                        validation_data=(trX[vFold],trY[vFold]),
                        initial_epoch = 0, # 0,
                        #callbacks=[early_stopping,reduce_lr1,reduce_lr2,checkpoint],
                        callbacks=[reduce_lr1,reduce_lr2,checkpoint1,checkpoint2,early_stopping],
                        verbose=verbose)

print(datetime.datetime.now())
# Out:
# 2017-08-01 18:24:29.765022 Training with folds
# 2017-08-01 18:24:29.766413 ------------> 1
# Train on 537 samples, validate on 135 samples
# Epoch 1/150
# Epoch 00000: dice improved from -inf to 0.47430, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.5309-0.4743-e=0--X--D10G5M5---1.hdf5
# Epoch 00000: val_dice improved from -inf to 0.53094, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.5309-0.4743-e=0--X--D10G5M5---1.hdf5
# 204s - loss: 1.9177 - dice: 0.4743 - binary_accuracy: 0.7565 - val_loss: 1.2910 - val_dice: 0.5309 - val_binary_accuracy: 0.7404
# Epoch 2/150
# Epoch 00001: dice improved from 0.47430 to 0.53101, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.5726-0.5310-e=1--X--D10G5M5---1.hdf5
# Epoch 00001: val_dice improved from 0.53094 to 0.57261, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.5726-0.5310-e=1--X--D10G5M5---1.hdf5
# 200s - loss: 1.7406 - dice: 0.5310 - binary_accuracy: 0.7823 - val_loss: 1.1818 - val_dice: 0.5726 - val_binary_accuracy: 0.8512
# Epoch 3/150
# Epoch 00002: dice did not improve
# Epoch 00002: val_dice did not improve
# 199s - loss: 1.7701 - dice: 0.5296 - binary_accuracy: 0.7832 - val_loss: 1.1253 - val_dice: 0.5567 - val_binary_accuracy: 0.8247
# Epoch 4/150
# Epoch 00003: dice improved from 0.53101 to 0.55547, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.5664-0.5555-e=3--X--D10G5M5---1.hdf5
# Epoch 00003: val_dice did not improve
# 199s - loss: 1.6574 - dice: 0.5555 - binary_accuracy: 0.8041 - val_loss: 1.1543 - val_dice: 0.5664 - val_binary_accuracy: 0.7771
# Epoch 5/150
# Epoch 00004: dice improved from 0.55547 to 0.56528, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.5973-0.5653-e=4--X--D10G5M5---1.hdf5
# Epoch 00004: val_dice improved from 0.57261 to 0.59727, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.5973-0.5653-e=4--X--D10G5M5---1.hdf5
# 199s - loss: 1.6383 - dice: 0.5653 - binary_accuracy: 0.8058 - val_loss: 1.0349 - val_dice: 0.5973 - val_binary_accuracy: 0.8167
# Epoch 6/150
# Epoch 00005: dice improved from 0.56528 to 0.56779, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6123-0.5678-e=5--X--D10G5M5---1.hdf5
# Epoch 00005: val_dice improved from 0.59727 to 0.61228, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6123-0.5678-e=5--X--D10G5M5---1.hdf5
# 200s - loss: 1.6255 - dice: 0.5678 - binary_accuracy: 0.8083 - val_loss: 0.9686 - val_dice: 0.6123 - val_binary_accuracy: 0.8455
# Epoch 7/150
# Epoch 00006: dice improved from 0.56779 to 0.58542, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.5862-0.5854-e=6--X--D10G5M5---1.hdf5
# Epoch 00006: val_dice did not improve
# 200s - loss: 1.5791 - dice: 0.5854 - binary_accuracy: 0.8180 - val_loss: 1.0314 - val_dice: 0.5862 - val_binary_accuracy: 0.8185
# Epoch 8/150
# Epoch 00007: dice improved from 0.58542 to 0.58939, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6238-0.5894-e=7--X--D10G5M5---1.hdf5
# Epoch 00007: val_dice improved from 0.61228 to 0.62382, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6238-0.5894-e=7--X--D10G5M5---1.hdf5
# 199s - loss: 1.5563 - dice: 0.5894 - binary_accuracy: 0.8196 - val_loss: 0.9085 - val_dice: 0.6238 - val_binary_accuracy: 0.8581
# Epoch 9/150
# Epoch 00008: dice improved from 0.58939 to 0.59612, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6209-0.5961-e=8--X--D10G5M5---1.hdf5
# Epoch 00008: val_dice did not improve
# 199s - loss: 1.5369 - dice: 0.5961 - binary_accuracy: 0.8232 - val_loss: 0.9464 - val_dice: 0.6209 - val_binary_accuracy: 0.8423
# Epoch 10/150
# Epoch 00009: dice improved from 0.59612 to 0.61809, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6288-0.6181-e=9--X--D10G5M5---1.hdf5
# Epoch 00009: val_dice improved from 0.62382 to 0.62881, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6288-0.6181-e=9--X--D10G5M5---1.hdf5
# 199s - loss: 1.4735 - dice: 0.6181 - binary_accuracy: 0.8368 - val_loss: 0.9400 - val_dice: 0.6288 - val_binary_accuracy: 0.8740
# Epoch 11/150
# Epoch 00010: dice improved from 0.61809 to 0.62368, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6305-0.6237-e=10--X--D10G5M5---1.hdf5
# Epoch 00010: val_dice improved from 0.62881 to 0.63052, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6305-0.6237-e=10--X--D10G5M5---1.hdf5
# 199s - loss: 1.4578 - dice: 0.6237 - binary_accuracy: 0.8395 - val_loss: 0.8700 - val_dice: 0.6305 - val_binary_accuracy: 0.8812
# Epoch 12/150
# Epoch 00011: dice did not improve
# Epoch 00011: val_dice improved from 0.63052 to 0.65584, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6558-0.6134-e=11--X--D10G5M5---1.hdf5
# 199s - loss: 1.5086 - dice: 0.6134 - binary_accuracy: 0.8340 - val_loss: 0.8291 - val_dice: 0.6558 - val_binary_accuracy: 0.8717
# Epoch 13/150
# Epoch 00012: dice improved from 0.62368 to 0.63489, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6772-0.6349-e=12--X--D10G5M5---1.hdf5
# Epoch 00012: val_dice improved from 0.65584 to 0.67724, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6772-0.6349-e=12--X--D10G5M5---1.hdf5
# 199s - loss: 1.4096 - dice: 0.6349 - binary_accuracy: 0.8450 - val_loss: 0.8203 - val_dice: 0.6772 - val_binary_accuracy: 0.8773
# Epoch 14/150
# Epoch 00013: dice improved from 0.63489 to 0.63904, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6527-0.6390-e=13--X--D10G5M5---1.hdf5
# Epoch 00013: val_dice did not improve
# 199s - loss: 1.4016 - dice: 0.6390 - binary_accuracy: 0.8485 - val_loss: 0.8139 - val_dice: 0.6527 - val_binary_accuracy: 0.8777
# Epoch 15/150
# Epoch 00014: dice improved from 0.63904 to 0.64794, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6659-0.6479-e=14--X--D10G5M5---1.hdf5
# Epoch 00014: val_dice did not improve
# 199s - loss: 1.3734 - dice: 0.6479 - binary_accuracy: 0.8543 - val_loss: 0.8100 - val_dice: 0.6659 - val_binary_accuracy: 0.8856
# Epoch 16/150
# Epoch 00015: dice improved from 0.64794 to 0.66418, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6842-0.6642-e=15--X--D10G5M5---1.hdf5
# Epoch 00015: val_dice improved from 0.67724 to 0.68419, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6842-0.6642-e=15--X--D10G5M5---1.hdf5
# 199s - loss: 1.3212 - dice: 0.6642 - binary_accuracy: 0.8637 - val_loss: 0.7699 - val_dice: 0.6842 - val_binary_accuracy: 0.8797
# Epoch 17/150
# Epoch 00016: dice improved from 0.66418 to 0.66707, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6283-0.6671-e=16--X--D10G5M5---1.hdf5
# Epoch 00016: val_dice did not improve
# 203s - loss: 1.3172 - dice: 0.6671 - binary_accuracy: 0.8634 - val_loss: 0.8676 - val_dice: 0.6283 - val_binary_accuracy: 0.8638
# Epoch 18/150
# Epoch 00017: dice improved from 0.66707 to 0.66775, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6853-0.6678-e=17--X--D10G5M5---1.hdf5
# Epoch 00017: val_dice improved from 0.68419 to 0.68533, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6853-0.6678-e=17--X--D10G5M5---1.hdf5
# 199s - loss: 1.3164 - dice: 0.6678 - binary_accuracy: 0.8616 - val_loss: 0.7439 - val_dice: 0.6853 - val_binary_accuracy: 0.8977
# Epoch 19/150
# Epoch 00018: dice improved from 0.66775 to 0.67505, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6676-0.6751-e=18--X--D10G5M5---1.hdf5
# Epoch 00018: val_dice did not improve
# 199s - loss: 1.2929 - dice: 0.6751 - binary_accuracy: 0.8671 - val_loss: 0.7796 - val_dice: 0.6676 - val_binary_accuracy: 0.8785
# Epoch 20/150
# Epoch 00019: dice did not improve
# Epoch 00019: val_dice did not improve
# 198s - loss: 1.3412 - dice: 0.6617 - binary_accuracy: 0.8583 - val_loss: 0.7788 - val_dice: 0.6731 - val_binary_accuracy: 0.8746
# Epoch 21/150
# Epoch 00020: dice did not improve
# Epoch 00020: val_dice improved from 0.68533 to 0.69274, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6927-0.6740-e=20--X--D10G5M5---1.hdf5
# 198s - loss: 1.2927 - dice: 0.6740 - binary_accuracy: 0.8664 - val_loss: 0.7206 - val_dice: 0.6927 - val_binary_accuracy: 0.8959
# Epoch 22/150
# Epoch 00021: dice improved from 0.67505 to 0.68039, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6875-0.6804-e=21--X--D10G5M5---1.hdf5
# Epoch 00021: val_dice did not improve
# 198s - loss: 1.2747 - dice: 0.6804 - binary_accuracy: 0.8697 - val_loss: 0.7137 - val_dice: 0.6875 - val_binary_accuracy: 0.8983
# Epoch 23/150
# Epoch 00022: dice improved from 0.68039 to 0.68278, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7046-0.6828-e=22--X--D10G5M5---1.hdf5
# Epoch 00022: val_dice improved from 0.69274 to 0.70458, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7046-0.6828-e=22--X--D10G5M5---1.hdf5
# 199s - loss: 1.2704 - dice: 0.6828 - binary_accuracy: 0.8723 - val_loss: 0.6875 - val_dice: 0.7046 - val_binary_accuracy: 0.9047
# Epoch 24/150
# Epoch 00023: dice improved from 0.68278 to 0.68748, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6970-0.6875-e=23--X--D10G5M5---1.hdf5
# Epoch 00023: val_dice did not improve
# 198s - loss: 1.2553 - dice: 0.6875 - binary_accuracy: 0.8725 - val_loss: 0.7031 - val_dice: 0.6970 - val_binary_accuracy: 0.9035
# Epoch 25/150
# Epoch 00024: dice improved from 0.68748 to 0.70001, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6368-0.7000-e=24--X--D10G5M5---1.hdf5
# Epoch 00024: val_dice did not improve
# 199s - loss: 1.2112 - dice: 0.7000 - binary_accuracy: 0.8792 - val_loss: 0.9857 - val_dice: 0.6368 - val_binary_accuracy: 0.8847
# Epoch 26/150
#
# Epoch 00025: reducing learning rate to 0.00499999988824.
# Epoch 00025: dice improved from 0.70001 to 0.70074, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6704-0.7007-e=25--X--D10G5M5---1.hdf5
# Epoch 00025: val_dice did not improve
# 198s - loss: 1.2108 - dice: 0.7007 - binary_accuracy: 0.8777 - val_loss: 0.7490 - val_dice: 0.6704 - val_binary_accuracy: 0.8954
# Epoch 27/150
# Epoch 00026: dice improved from 0.70074 to 0.71368, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7150-0.7137-e=26--X--D10G5M5---1.hdf5
# Epoch 00026: val_dice improved from 0.70458 to 0.71499, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7150-0.7137-e=26--X--D10G5M5---1.hdf5
# 199s - loss: 1.1636 - dice: 0.7137 - binary_accuracy: 0.8850 - val_loss: 0.6372 - val_dice: 0.7150 - val_binary_accuracy: 0.9121
# Epoch 28/150
# Epoch 00027: dice improved from 0.71368 to 0.72084, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7217-0.7208-e=27--X--D10G5M5---1.hdf5
# Epoch 00027: val_dice improved from 0.71499 to 0.72166, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7217-0.7208-e=27--X--D10G5M5---1.hdf5
# 200s - loss: 1.1423 - dice: 0.7208 - binary_accuracy: 0.8882 - val_loss: 0.6409 - val_dice: 0.7217 - val_binary_accuracy: 0.9121
# Epoch 29/150
# Epoch 00028: dice improved from 0.72084 to 0.72494, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7109-0.7249-e=28--X--D10G5M5---1.hdf5
# Epoch 00028: val_dice did not improve
# 198s - loss: 1.1302 - dice: 0.7249 - binary_accuracy: 0.8889 - val_loss: 0.6526 - val_dice: 0.7109 - val_binary_accuracy: 0.9011
# Epoch 30/150
# Epoch 00029: dice improved from 0.72494 to 0.72688, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7239-0.7269-e=29--X--D10G5M5---1.hdf5
# Epoch 00029: val_dice improved from 0.72166 to 0.72394, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7239-0.7269-e=29--X--D10G5M5---1.hdf5
# 199s - loss: 1.1213 - dice: 0.7269 - binary_accuracy: 0.8894 - val_loss: 0.6357 - val_dice: 0.7239 - val_binary_accuracy: 0.9022
# Epoch 31/150
# Epoch 00030: dice improved from 0.72688 to 0.73246, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7363-0.7325-e=30--X--D10G5M5---1.hdf5
# Epoch 00030: val_dice improved from 0.72394 to 0.73628, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7363-0.7325-e=30--X--D10G5M5---1.hdf5
# 199s - loss: 1.1101 - dice: 0.7325 - binary_accuracy: 0.8922 - val_loss: 0.5994 - val_dice: 0.7363 - val_binary_accuracy: 0.9179
# Epoch 32/150
# Epoch 00031: dice improved from 0.73246 to 0.73684, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7360-0.7368-e=31--X--D10G5M5---1.hdf5
# Epoch 00031: val_dice did not improve
# 198s - loss: 1.0930 - dice: 0.7368 - binary_accuracy: 0.8933 - val_loss: 0.6119 - val_dice: 0.7360 - val_binary_accuracy: 0.9147
# Epoch 33/150
# Epoch 00032: dice improved from 0.73684 to 0.74052, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7231-0.7405-e=32--X--D10G5M5---1.hdf5
# Epoch 00032: val_dice did not improve
# 198s - loss: 1.0856 - dice: 0.7405 - binary_accuracy: 0.8947 - val_loss: 0.6272 - val_dice: 0.7231 - val_binary_accuracy: 0.9124
# Epoch 34/150
#
# Epoch 00033: reducing learning rate to 0.00249999994412.
# Epoch 00033: dice improved from 0.74052 to 0.74467, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7357-0.7447-e=33--X--D10G5M5---1.hdf5
# Epoch 00033: val_dice did not improve
# 198s - loss: 1.0722 - dice: 0.7447 - binary_accuracy: 0.8962 - val_loss: 0.6056 - val_dice: 0.7357 - val_binary_accuracy: 0.9169
# Epoch 35/150
# Epoch 00034: dice improved from 0.74467 to 0.75770, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7409-0.7577-e=34--X--D10G5M5---1.hdf5
# Epoch 00034: val_dice improved from 0.73628 to 0.74093, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7409-0.7577-e=34--X--D10G5M5---1.hdf5
# 199s - loss: 1.0354 - dice: 0.7577 - binary_accuracy: 0.9017 - val_loss: 0.5853 - val_dice: 0.7409 - val_binary_accuracy: 0.9218
# Epoch 36/150
# Epoch 00035: dice improved from 0.75770 to 0.76175, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7453-0.7617-e=35--X--D10G5M5---1.hdf5
# Epoch 00035: val_dice improved from 0.74093 to 0.74534, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7453-0.7617-e=35--X--D10G5M5---1.hdf5
# 199s - loss: 1.0252 - dice: 0.7617 - binary_accuracy: 0.9039 - val_loss: 0.5818 - val_dice: 0.7453 - val_binary_accuracy: 0.9223
# Epoch 37/150
# Epoch 00036: dice improved from 0.76175 to 0.76497, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7424-0.7650-e=36--X--D10G5M5---1.hdf5
# Epoch 00036: val_dice did not improve
# 199s - loss: 1.0188 - dice: 0.7650 - binary_accuracy: 0.9044 - val_loss: 0.5709 - val_dice: 0.7424 - val_binary_accuracy: 0.9187
# Epoch 38/150
# Epoch 00037: dice improved from 0.76497 to 0.76548, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7529-0.7655-e=37--X--D10G5M5---1.hdf5
# Epoch 00037: val_dice improved from 0.74534 to 0.75285, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7529-0.7655-e=37--X--D10G5M5---1.hdf5
# 200s - loss: 1.0134 - dice: 0.7655 - binary_accuracy: 0.9055 - val_loss: 0.5618 - val_dice: 0.7529 - val_binary_accuracy: 0.9234
# Epoch 39/150
# Epoch 00038: dice improved from 0.76548 to 0.76820, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7479-0.7682-e=38--X--D10G5M5---1.hdf5
# Epoch 00038: val_dice did not improve
# 199s - loss: 1.0110 - dice: 0.7682 - binary_accuracy: 0.9054 - val_loss: 0.5516 - val_dice: 0.7479 - val_binary_accuracy: 0.9224
# Epoch 40/150
# Epoch 00039: dice did not improve
# Epoch 00039: val_dice did not improve
# 198s - loss: 1.1635 - dice: 0.7182 - binary_accuracy: 0.8818 - val_loss: 0.7009 - val_dice: 0.7120 - val_binary_accuracy: 0.9036
# Epoch 41/150
# Epoch 00040: dice did not improve
# Epoch 00040: val_dice did not improve
# 199s - loss: 1.1250 - dice: 0.7297 - binary_accuracy: 0.8915 - val_loss: 0.6016 - val_dice: 0.7310 - val_binary_accuracy: 0.9194
# Epoch 42/150
#
# Epoch 00041: reducing learning rate to 0.00124999997206.
# Epoch 00041: dice did not improve
# Epoch 00041: val_dice did not improve
# 198s - loss: 1.0589 - dice: 0.7513 - binary_accuracy: 0.8994 - val_loss: 0.5782 - val_dice: 0.7421 - val_binary_accuracy: 0.9199
# Epoch 43/150
#
# Epoch 00042: reducing learning rate to 0.000249999994412.
# Epoch 00042: dice did not improve
# Epoch 00042: val_dice did not improve
# 195s - loss: 1.0140 - dice: 0.7657 - binary_accuracy: 0.9009 - val_loss: 0.5837 - val_dice: 0.7354 - val_binary_accuracy: 0.9110
# Epoch 44/150
# Epoch 00043: dice improved from 0.76820 to 0.77100, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7475-0.7710-e=43--X--D10G5M5---1.hdf5
# Epoch 00043: val_dice did not improve
# 195s - loss: 0.9815 - dice: 0.7710 - binary_accuracy: 0.9012 - val_loss: 0.5473 - val_dice: 0.7475 - val_binary_accuracy: 0.9199
# Epoch 45/150
# Epoch 00044: dice improved from 0.77100 to 0.77422, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7538-0.7742-e=44--X--D10G5M5---1.hdf5
# Epoch 00044: val_dice improved from 0.75285 to 0.75380, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7538-0.7742-e=44--X--D10G5M5---1.hdf5
# 196s - loss: 0.9798 - dice: 0.7742 - binary_accuracy: 0.9034 - val_loss: 0.5369 - val_dice: 0.7538 - val_binary_accuracy: 0.9193
# Epoch 46/150
# Epoch 00045: dice improved from 0.77422 to 0.77914, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7545-0.7791-e=45--X--D10G5M5---1.hdf5
# Epoch 00045: val_dice improved from 0.75380 to 0.75452, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7545-0.7791-e=45--X--D10G5M5---1.hdf5
# 196s - loss: 0.9607 - dice: 0.7791 - binary_accuracy: 0.9048 - val_loss: 0.5377 - val_dice: 0.7545 - val_binary_accuracy: 0.9225
# Epoch 47/150
# Epoch 00046: dice improved from 0.77914 to 0.78162, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7570-0.7816-e=46--X--D10G5M5---1.hdf5
# Epoch 00046: val_dice improved from 0.75452 to 0.75699, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7570-0.7816-e=46--X--D10G5M5---1.hdf5
# 196s - loss: 0.9506 - dice: 0.7816 - binary_accuracy: 0.9064 - val_loss: 0.5307 - val_dice: 0.7570 - val_binary_accuracy: 0.9225
# Epoch 48/150
# Epoch 00047: dice improved from 0.78162 to 0.78400, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7566-0.7840-e=47--X--D10G5M5---1.hdf5
# Epoch 00047: val_dice did not improve
# 196s - loss: 0.9439 - dice: 0.7840 - binary_accuracy: 0.9069 - val_loss: 0.5302 - val_dice: 0.7566 - val_binary_accuracy: 0.9230
# Epoch 49/150
# Epoch 00048: dice improved from 0.78400 to 0.78510, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7590-0.7851-e=48--X--D10G5M5---1.hdf5
# Epoch 00048: val_dice improved from 0.75699 to 0.75901, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7590-0.7851-e=48--X--D10G5M5---1.hdf5
# 197s - loss: 0.9402 - dice: 0.7851 - binary_accuracy: 0.9076 - val_loss: 0.5263 - val_dice: 0.7590 - val_binary_accuracy: 0.9238
# Epoch 50/150
# Epoch 00049: dice improved from 0.78510 to 0.78691, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7587-0.7869-e=49--X--D10G5M5---1.hdf5
# Epoch 00049: val_dice did not improve
# 197s - loss: 0.9357 - dice: 0.7869 - binary_accuracy: 0.9082 - val_loss: 0.5293 - val_dice: 0.7587 - val_binary_accuracy: 0.9241
# Epoch 51/150
# Epoch 00050: dice improved from 0.78691 to 0.78779, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7589-0.7878-e=50--X--D10G5M5---1.hdf5
# Epoch 00050: val_dice did not improve
# 198s - loss: 0.9344 - dice: 0.7878 - binary_accuracy: 0.9085 - val_loss: 0.5266 - val_dice: 0.7589 - val_binary_accuracy: 0.9240
# Epoch 52/150
# Epoch 00051: dice improved from 0.78779 to 0.78910, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7581-0.7891-e=51--X--D10G5M5---1.hdf5
# Epoch 00051: val_dice did not improve
# 197s - loss: 0.9315 - dice: 0.7891 - binary_accuracy: 0.9089 - val_loss: 0.5235 - val_dice: 0.7581 - val_binary_accuracy: 0.9237
# Epoch 53/150
# Epoch 00052: dice improved from 0.78910 to 0.78914, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7585-0.7891-e=52--X--D10G5M5---1.hdf5
# Epoch 00052: val_dice did not improve
# 197s - loss: 0.9299 - dice: 0.7891 - binary_accuracy: 0.9092 - val_loss: 0.5259 - val_dice: 0.7585 - val_binary_accuracy: 0.9247
# Epoch 54/150
# Epoch 00053: dice improved from 0.78914 to 0.79049, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7582-0.7905-e=53--X--D10G5M5---1.hdf5
# Epoch 00053: val_dice did not improve
# 198s - loss: 0.9268 - dice: 0.7905 - binary_accuracy: 0.9096 - val_loss: 0.5240 - val_dice: 0.7582 - val_binary_accuracy: 0.9242
# Epoch 55/150
# Epoch 00054: dice improved from 0.79049 to 0.79113, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7601-0.7911-e=54--X--D10G5M5---1.hdf5
# Epoch 00054: val_dice improved from 0.75901 to 0.76013, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7601-0.7911-e=54--X--D10G5M5---1.hdf5
# 197s - loss: 0.9249 - dice: 0.7911 - binary_accuracy: 0.9098 - val_loss: 0.5207 - val_dice: 0.7601 - val_binary_accuracy: 0.9250
# Epoch 56/150
# Epoch 00055: dice improved from 0.79113 to 0.79184, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7597-0.7918-e=55--X--D10G5M5---1.hdf5
# Epoch 00055: val_dice did not improve
# 197s - loss: 0.9230 - dice: 0.7918 - binary_accuracy: 0.9103 - val_loss: 0.5207 - val_dice: 0.7597 - val_binary_accuracy: 0.9247
# Epoch 57/150
# Epoch 00056: dice improved from 0.79184 to 0.79279, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7609-0.7928-e=56--X--D10G5M5---1.hdf5
# Epoch 00056: val_dice improved from 0.76013 to 0.76088, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7609-0.7928-e=56--X--D10G5M5---1.hdf5
# 197s - loss: 0.9211 - dice: 0.7928 - binary_accuracy: 0.9105 - val_loss: 0.5185 - val_dice: 0.7609 - val_binary_accuracy: 0.9249
# Epoch 58/150
# Epoch 00057: dice improved from 0.79279 to 0.79325, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7587-0.7932-e=57--X--D10G5M5---1.hdf5
# Epoch 00057: val_dice did not improve
# 197s - loss: 0.9197 - dice: 0.7932 - binary_accuracy: 0.9107 - val_loss: 0.5251 - val_dice: 0.7587 - val_binary_accuracy: 0.9252
# Epoch 59/150
# Epoch 00058: dice improved from 0.79325 to 0.79356, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7617-0.7936-e=58--X--D10G5M5---1.hdf5
# Epoch 00058: val_dice improved from 0.76088 to 0.76172, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7617-0.7936-e=58--X--D10G5M5---1.hdf5
# 197s - loss: 0.9187 - dice: 0.7936 - binary_accuracy: 0.9109 - val_loss: 0.5211 - val_dice: 0.7617 - val_binary_accuracy: 0.9257
# Epoch 60/150
#
# Epoch 00059: reducing learning rate to 0.000124999991385.
# Epoch 00059: dice improved from 0.79356 to 0.79463, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7595-0.7946-e=59--X--D10G5M5---1.hdf5
# Epoch 00059: val_dice did not improve
# 197s - loss: 0.9166 - dice: 0.7946 - binary_accuracy: 0.9112 - val_loss: 0.5264 - val_dice: 0.7595 - val_binary_accuracy: 0.9256
# Epoch 61/150
# Epoch 00060: dice improved from 0.79463 to 0.79640, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7612-0.7964-e=60--X--D10G5M5---1.hdf5
# Epoch 00060: val_dice did not improve
# 197s - loss: 0.9132 - dice: 0.7964 - binary_accuracy: 0.9116 - val_loss: 0.5185 - val_dice: 0.7612 - val_binary_accuracy: 0.9256
# Epoch 62/150
#
# Epoch 00061: reducing learning rate to 6.24999956926e-05.
# Epoch 00061: dice did not improve
# Epoch 00061: val_dice did not improve
# 197s - loss: 0.9126 - dice: 0.7964 - binary_accuracy: 0.9119 - val_loss: 0.5187 - val_dice: 0.7612 - val_binary_accuracy: 0.9256
# Epoch 63/150
# Epoch 00062: dice did not improve
# Epoch 00062: val_dice did not improve
# 197s - loss: 0.9110 - dice: 0.7962 - binary_accuracy: 0.9121 - val_loss: 0.5184 - val_dice: 0.7617 - val_binary_accuracy: 0.9257
# Epoch 64/150
# Epoch 00063: dice improved from 0.79640 to 0.79672, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7615-0.7967-e=63--X--D10G5M5---1.hdf5
# Epoch 00063: val_dice did not improve
# 197s - loss: 0.9109 - dice: 0.7967 - binary_accuracy: 0.9121 - val_loss: 0.5191 - val_dice: 0.7615 - val_binary_accuracy: 0.9258
# Epoch 65/150
# Epoch 00064: dice improved from 0.79672 to 0.79675, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7626-0.7968-e=64--X--D10G5M5---1.hdf5
# Epoch 00064: val_dice improved from 0.76172 to 0.76265, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7626-0.7968-e=64--X--D10G5M5---1.hdf5
# 197s - loss: 0.9103 - dice: 0.7968 - binary_accuracy: 0.9123 - val_loss: 0.5167 - val_dice: 0.7626 - val_binary_accuracy: 0.9253
# Epoch 66/150
# Epoch 00065: dice improved from 0.79675 to 0.79708, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7630-0.7971-e=65--X--D10G5M5---1.hdf5
# Epoch 00065: val_dice improved from 0.76265 to 0.76298, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7630-0.7971-e=65--X--D10G5M5---1.hdf5
# 197s - loss: 0.9098 - dice: 0.7971 - binary_accuracy: 0.9123 - val_loss: 0.5167 - val_dice: 0.7630 - val_binary_accuracy: 0.9256
# Epoch 67/150
# Epoch 00066: dice improved from 0.79708 to 0.79746, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7621-0.7975-e=66--X--D10G5M5---1.hdf5
# Epoch 00066: val_dice did not improve
# 197s - loss: 0.9096 - dice: 0.7975 - binary_accuracy: 0.9123 - val_loss: 0.5180 - val_dice: 0.7621 - val_binary_accuracy: 0.9257
# Epoch 68/150
#
# Epoch 00067: reducing learning rate to 3.12499978463e-05.
# Epoch 00067: dice did not improve
# Epoch 00067: val_dice did not improve
# 197s - loss: 0.9089 - dice: 0.7972 - binary_accuracy: 0.9124 - val_loss: 0.5176 - val_dice: 0.7627 - val_binary_accuracy: 0.9259
# Epoch 69/150
# Epoch 00068: dice improved from 0.79746 to 0.79828, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7623-0.7983-e=68--X--D10G5M5---1.hdf5
# Epoch 00068: val_dice did not improve
# 197s - loss: 0.9081 - dice: 0.7983 - binary_accuracy: 0.9126 - val_loss: 0.5183 - val_dice: 0.7623 - val_binary_accuracy: 0.9259
# Epoch 70/150
#
# Epoch 00069: reducing learning rate to 1.56249989232e-05.
# Epoch 00069: dice did not improve
# Epoch 00069: val_dice did not improve
# 197s - loss: 0.9077 - dice: 0.7979 - binary_accuracy: 0.9127 - val_loss: 0.5166 - val_dice: 0.7629 - val_binary_accuracy: 0.9256
# Epoch 71/150
# Epoch 00070: dice did not improve
# Epoch 00070: val_dice did not improve
# 197s - loss: 0.9079 - dice: 0.7981 - binary_accuracy: 0.9127 - val_loss: 0.5168 - val_dice: 0.7628 - val_binary_accuracy: 0.9257
# Epoch 72/150
#
# Epoch 00071: reducing learning rate to 7.81249946158e-06.
# Epoch 00071: dice did not improve
# Epoch 00071: val_dice did not improve
# 197s - loss: 0.9074 - dice: 0.7981 - binary_accuracy: 0.9127 - val_loss: 0.5168 - val_dice: 0.7627 - val_binary_accuracy: 0.9257
# Epoch 73/150
# Epoch 00072: dice improved from 0.79828 to 0.79853, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7626-0.7985-e=72--X--D10G5M5---1.hdf5
# Epoch 00072: val_dice did not improve
# 197s - loss: 0.9069 - dice: 0.7985 - binary_accuracy: 0.9127 - val_loss: 0.5171 - val_dice: 0.7626 - val_binary_accuracy: 0.9258
# Epoch 74/150
#
# Epoch 00073: reducing learning rate to 3.90624973079e-06.
# Epoch 00073: dice did not improve
# Epoch 00073: val_dice did not improve
# 197s - loss: 0.9071 - dice: 0.7984 - binary_accuracy: 0.9128 - val_loss: 0.5172 - val_dice: 0.7625 - val_binary_accuracy: 0.9258
# Epoch 75/150
# Epoch 00074: dice did not improve
# Epoch 00074: val_dice did not improve
# 197s - loss: 0.9065 - dice: 0.7985 - binary_accuracy: 0.9128 - val_loss: 0.5172 - val_dice: 0.7626 - val_binary_accuracy: 0.9258
# Epoch 76/150
#
# Epoch 00075: reducing learning rate to 1.95312486539e-06.
# Epoch 00075: dice did not improve
# Epoch 00075: val_dice did not improve
# 197s - loss: 0.9070 - dice: 0.7982 - binary_accuracy: 0.9128 - val_loss: 0.5170 - val_dice: 0.7626 - val_binary_accuracy: 0.9257
# Epoch 77/150
# Epoch 00076: dice did not improve
# Epoch 00076: val_dice did not improve
# 197s - loss: 0.9072 - dice: 0.7983 - binary_accuracy: 0.9128 - val_loss: 0.5170 - val_dice: 0.7626 - val_binary_accuracy: 0.9257
# Epoch 78/150
#
# Epoch 00077: reducing learning rate to 9.76562432697e-07.
# Epoch 00077: dice improved from 0.79853 to 0.79855, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7626-0.7986-e=77--X--D10G5M5---1.hdf5
# Epoch 00077: val_dice did not improve
# 197s - loss: 0.9063 - dice: 0.7986 - binary_accuracy: 0.9128 - val_loss: 0.5170 - val_dice: 0.7626 - val_binary_accuracy: 0.9257
# Epoch 00077: early stopping
# 2017-08-01 22:42:35.185702 ------------> 2
# Train on 537 samples, validate on 135 samples
# Epoch 1/150
# Epoch 00000: dice improved from -inf to 0.48206, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.5181-0.4821-e=0--X--D10G5M5---2.hdf5
# Epoch 00000: val_dice improved from -inf to 0.51810, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.5181-0.4821-e=0--X--D10G5M5---2.hdf5
# 201s - loss: 1.9001 - dice: 0.4821 - binary_accuracy: 0.7643 - val_loss: 1.3059 - val_dice: 0.5181 - val_binary_accuracy: 0.8089
# Epoch 2/150
# Epoch 00001: dice improved from 0.48206 to 0.53725, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.5230-0.5373-e=1--X--D10G5M5---2.hdf5
# Epoch 00001: val_dice improved from 0.51810 to 0.52299, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.5230-0.5373-e=1--X--D10G5M5---2.hdf5
# 200s - loss: 1.7323 - dice: 0.5373 - binary_accuracy: 0.7911 - val_loss: 1.3144 - val_dice: 0.5230 - val_binary_accuracy: 0.7377
# Epoch 3/150
# Epoch 00002: dice improved from 0.53725 to 0.54817, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.5829-0.5482-e=2--X--D10G5M5---2.hdf5
# Epoch 00002: val_dice improved from 0.52299 to 0.58294, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.5829-0.5482-e=2--X--D10G5M5---2.hdf5
# 200s - loss: 1.6807 - dice: 0.5482 - binary_accuracy: 0.7984 - val_loss: 1.1131 - val_dice: 0.5829 - val_binary_accuracy: 0.8278
# Epoch 4/150
# Epoch 00003: dice improved from 0.54817 to 0.56452, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.5126-0.5645-e=3--X--D10G5M5---2.hdf5
# Epoch 00003: val_dice did not improve
# 200s - loss: 1.6476 - dice: 0.5645 - binary_accuracy: 0.8069 - val_loss: 1.2229 - val_dice: 0.5126 - val_binary_accuracy: 0.8285
# Epoch 5/150
# Epoch 00004: dice improved from 0.56452 to 0.56905, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.5719-0.5690-e=4--X--D10G5M5---2.hdf5
# Epoch 00004: val_dice did not improve
# 199s - loss: 1.6277 - dice: 0.5690 - binary_accuracy: 0.8106 - val_loss: 1.1716 - val_dice: 0.5719 - val_binary_accuracy: 0.8460
# Epoch 6/150
# Epoch 00005: dice improved from 0.56905 to 0.58013, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.5918-0.5801-e=5--X--D10G5M5---2.hdf5
# Epoch 00005: val_dice improved from 0.58294 to 0.59179, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.5918-0.5801-e=5--X--D10G5M5---2.hdf5
# 200s - loss: 1.5920 - dice: 0.5801 - binary_accuracy: 0.8157 - val_loss: 1.1069 - val_dice: 0.5918 - val_binary_accuracy: 0.8448
# Epoch 7/150
# Epoch 00006: dice improved from 0.58013 to 0.58812, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.5999-0.5881-e=6--X--D10G5M5---2.hdf5
# Epoch 00006: val_dice improved from 0.59179 to 0.59994, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.5999-0.5881-e=6--X--D10G5M5---2.hdf5
# 199s - loss: 1.5734 - dice: 0.5881 - binary_accuracy: 0.8191 - val_loss: 1.0405 - val_dice: 0.5999 - val_binary_accuracy: 0.8355
# Epoch 8/150
# Epoch 00007: dice improved from 0.58812 to 0.59895, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6033-0.5989-e=7--X--D10G5M5---2.hdf5
# Epoch 00007: val_dice improved from 0.59994 to 0.60327, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6033-0.5989-e=7--X--D10G5M5---2.hdf5
# 199s - loss: 1.5282 - dice: 0.5989 - binary_accuracy: 0.8257 - val_loss: 1.0195 - val_dice: 0.6033 - val_binary_accuracy: 0.8284
# Epoch 9/150
# Epoch 00008: dice did not improve
# Epoch 00008: val_dice did not improve
# 198s - loss: 1.5397 - dice: 0.5958 - binary_accuracy: 0.8226 - val_loss: 1.1614 - val_dice: 0.5674 - val_binary_accuracy: 0.8484
# Epoch 10/150
# Epoch 00009: dice improved from 0.59895 to 0.60181, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6268-0.6018-e=9--X--D10G5M5---2.hdf5
# Epoch 00009: val_dice improved from 0.60327 to 0.62681, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6268-0.6018-e=9--X--D10G5M5---2.hdf5
# 199s - loss: 1.5207 - dice: 0.6018 - binary_accuracy: 0.8248 - val_loss: 0.9856 - val_dice: 0.6268 - val_binary_accuracy: 0.8568
# Epoch 11/150
# Epoch 00010: dice improved from 0.60181 to 0.61827, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6206-0.6183-e=10--X--D10G5M5---2.hdf5
# Epoch 00010: val_dice did not improve
# 199s - loss: 1.4757 - dice: 0.6183 - binary_accuracy: 0.8353 - val_loss: 1.0212 - val_dice: 0.6206 - val_binary_accuracy: 0.8681
# Epoch 12/150
# Epoch 00011: dice improved from 0.61827 to 0.63763, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6585-0.6376-e=11--X--D10G5M5---2.hdf5
# Epoch 00011: val_dice improved from 0.62681 to 0.65854, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6585-0.6376-e=11--X--D10G5M5---2.hdf5
# 199s - loss: 1.4120 - dice: 0.6376 - binary_accuracy: 0.8472 - val_loss: 0.8675 - val_dice: 0.6585 - val_binary_accuracy: 0.8767
# Epoch 13/150
# Epoch 00012: dice improved from 0.63763 to 0.65074, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6398-0.6507-e=12--X--D10G5M5---2.hdf5
# Epoch 00012: val_dice did not improve
# 199s - loss: 1.3700 - dice: 0.6507 - binary_accuracy: 0.8531 - val_loss: 0.9080 - val_dice: 0.6398 - val_binary_accuracy: 0.8510
# Epoch 14/150
# Epoch 00013: dice improved from 0.65074 to 0.65797, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6674-0.6580-e=13--X--D10G5M5---2.hdf5
# Epoch 00013: val_dice improved from 0.65854 to 0.66736, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6674-0.6580-e=13--X--D10G5M5---2.hdf5
# 199s - loss: 1.3413 - dice: 0.6580 - binary_accuracy: 0.8581 - val_loss: 0.8367 - val_dice: 0.6674 - val_binary_accuracy: 0.8881
# Epoch 15/150
# Epoch 00014: dice improved from 0.65797 to 0.66209, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6460-0.6621-e=14--X--D10G5M5---2.hdf5
# Epoch 00014: val_dice did not improve
# 199s - loss: 1.3340 - dice: 0.6621 - binary_accuracy: 0.8591 - val_loss: 0.8787 - val_dice: 0.6460 - val_binary_accuracy: 0.8685
# Epoch 16/150
# Epoch 00015: dice did not improve
# Epoch 00015: val_dice improved from 0.66736 to 0.67008, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6701-0.6589-e=15--X--D10G5M5---2.hdf5
# 199s - loss: 1.3361 - dice: 0.6589 - binary_accuracy: 0.8593 - val_loss: 0.8316 - val_dice: 0.6701 - val_binary_accuracy: 0.8845
# Epoch 17/150
# Epoch 00016: dice improved from 0.66209 to 0.66802, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6474-0.6680-e=16--X--D10G5M5---2.hdf5
# Epoch 00016: val_dice did not improve
# 198s - loss: 1.3170 - dice: 0.6680 - binary_accuracy: 0.8614 - val_loss: 0.8391 - val_dice: 0.6474 - val_binary_accuracy: 0.8816
# Epoch 18/150
# Epoch 00017: dice improved from 0.66802 to 0.66882, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6571-0.6688-e=17--X--D10G5M5---2.hdf5
# Epoch 00017: val_dice did not improve
# 198s - loss: 1.3027 - dice: 0.6688 - binary_accuracy: 0.8629 - val_loss: 0.8165 - val_dice: 0.6571 - val_binary_accuracy: 0.8855
# Epoch 19/150
# Epoch 00018: dice improved from 0.66882 to 0.67685, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6864-0.6769-e=18--X--D10G5M5---2.hdf5
# Epoch 00018: val_dice improved from 0.67008 to 0.68638, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6864-0.6769-e=18--X--D10G5M5---2.hdf5
# 199s - loss: 1.2852 - dice: 0.6769 - binary_accuracy: 0.8647 - val_loss: 0.7664 - val_dice: 0.6864 - val_binary_accuracy: 0.8919
# Epoch 20/150
# Epoch 00019: dice improved from 0.67685 to 0.68371, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6898-0.6837-e=19--X--D10G5M5---2.hdf5
# Epoch 00019: val_dice improved from 0.68638 to 0.68985, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6898-0.6837-e=19--X--D10G5M5---2.hdf5
# 199s - loss: 1.2554 - dice: 0.6837 - binary_accuracy: 0.8706 - val_loss: 0.7619 - val_dice: 0.6898 - val_binary_accuracy: 0.8968
# Epoch 21/150
# Epoch 00020: dice improved from 0.68371 to 0.68819, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6861-0.6882-e=20--X--D10G5M5---2.hdf5
# Epoch 00020: val_dice did not improve
# 199s - loss: 1.2421 - dice: 0.6882 - binary_accuracy: 0.8730 - val_loss: 0.7445 - val_dice: 0.6861 - val_binary_accuracy: 0.8966
# Epoch 22/150
# Epoch 00021: dice did not improve
# Epoch 00021: val_dice did not improve
# 198s - loss: 1.2534 - dice: 0.6854 - binary_accuracy: 0.8703 - val_loss: 0.8444 - val_dice: 0.6660 - val_binary_accuracy: 0.8879
# Epoch 23/150
# Epoch 00022: dice improved from 0.68819 to 0.69299, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6875-0.6930-e=22--X--D10G5M5---2.hdf5
# Epoch 00022: val_dice did not improve
# 198s - loss: 1.2288 - dice: 0.6930 - binary_accuracy: 0.8745 - val_loss: 0.7695 - val_dice: 0.6875 - val_binary_accuracy: 0.8854
# Epoch 24/150
# Epoch 00023: dice did not improve
# Epoch 00023: val_dice did not improve
# 198s - loss: 1.2318 - dice: 0.6927 - binary_accuracy: 0.8730 - val_loss: 0.7417 - val_dice: 0.6864 - val_binary_accuracy: 0.8994
# Epoch 25/150
# Epoch 00024: dice improved from 0.69299 to 0.69581, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6932-0.6958-e=24--X--D10G5M5---2.hdf5
# Epoch 00024: val_dice improved from 0.68985 to 0.69317, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6932-0.6958-e=24--X--D10G5M5---2.hdf5
# 199s - loss: 1.2179 - dice: 0.6958 - binary_accuracy: 0.8761 - val_loss: 0.7457 - val_dice: 0.6932 - val_binary_accuracy: 0.9006
# Epoch 26/150
# Epoch 00025: dice improved from 0.69581 to 0.70120, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6886-0.7012-e=25--X--D10G5M5---2.hdf5
# Epoch 00025: val_dice did not improve
# 198s - loss: 1.2076 - dice: 0.7012 - binary_accuracy: 0.8781 - val_loss: 0.7522 - val_dice: 0.6886 - val_binary_accuracy: 0.8986
# Epoch 27/150
#
# Epoch 00026: reducing learning rate to 0.00499999988824.
# Epoch 00026: dice improved from 0.70120 to 0.70246, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.6586-0.7025-e=26--X--D10G5M5---2.hdf5
# Epoch 00026: val_dice did not improve
# 199s - loss: 1.1981 - dice: 0.7025 - binary_accuracy: 0.8792 - val_loss: 0.8307 - val_dice: 0.6586 - val_binary_accuracy: 0.8676
# Epoch 28/150
# Epoch 00027: dice improved from 0.70246 to 0.71809, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7070-0.7181-e=27--X--D10G5M5---2.hdf5
# Epoch 00027: val_dice improved from 0.69317 to 0.70697, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7070-0.7181-e=27--X--D10G5M5---2.hdf5
# 199s - loss: 1.1488 - dice: 0.7181 - binary_accuracy: 0.8857 - val_loss: 0.7006 - val_dice: 0.7070 - val_binary_accuracy: 0.9010
# Epoch 29/150
# Epoch 00028: dice did not improve
# Epoch 00028: val_dice improved from 0.70697 to 0.71520, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7152-0.7171-e=28--X--D10G5M5---2.hdf5
# 199s - loss: 1.1502 - dice: 0.7171 - binary_accuracy: 0.8863 - val_loss: 0.6778 - val_dice: 0.7152 - val_binary_accuracy: 0.9022
# Epoch 30/150
# Epoch 00029: dice improved from 0.71809 to 0.72310, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7148-0.7231-e=29--X--D10G5M5---2.hdf5
# Epoch 00029: val_dice did not improve
# 199s - loss: 1.1313 - dice: 0.7231 - binary_accuracy: 0.8878 - val_loss: 0.6758 - val_dice: 0.7148 - val_binary_accuracy: 0.9024
# Epoch 31/150
# Epoch 00030: dice did not improve
# Epoch 00030: val_dice did not improve
# 198s - loss: 1.1405 - dice: 0.7208 - binary_accuracy: 0.8866 - val_loss: 0.6737 - val_dice: 0.7099 - val_binary_accuracy: 0.9034
# Epoch 32/150
# Epoch 00031: dice did not improve
# Epoch 00031: val_dice did not improve
# 198s - loss: 1.1488 - dice: 0.7167 - binary_accuracy: 0.8851 - val_loss: 0.7085 - val_dice: 0.7092 - val_binary_accuracy: 0.9083
# Epoch 33/150
# Epoch 00032: dice did not improve
# Epoch 00032: val_dice improved from 0.71520 to 0.71907, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7191-0.7192-e=32--X--D10G5M5---2.hdf5
# 199s - loss: 1.1436 - dice: 0.7192 - binary_accuracy: 0.8857 - val_loss: 0.6602 - val_dice: 0.7191 - val_binary_accuracy: 0.9102
# Epoch 34/150
# Epoch 00033: dice improved from 0.72310 to 0.73099, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7151-0.7310-e=33--X--D10G5M5---2.hdf5
# Epoch 00033: val_dice did not improve
# 199s - loss: 1.1071 - dice: 0.7310 - binary_accuracy: 0.8908 - val_loss: 0.6535 - val_dice: 0.7151 - val_binary_accuracy: 0.9096
# Epoch 35/150
# Epoch 00034: dice improved from 0.73099 to 0.73532, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7172-0.7353-e=34--X--D10G5M5---2.hdf5
# Epoch 00034: val_dice did not improve
# 199s - loss: 1.0917 - dice: 0.7353 - binary_accuracy: 0.8935 - val_loss: 0.6826 - val_dice: 0.7172 - val_binary_accuracy: 0.9119
# Epoch 36/150
# Epoch 00035: dice did not improve
# Epoch 00035: val_dice did not improve
# 198s - loss: 1.0986 - dice: 0.7337 - binary_accuracy: 0.8927 - val_loss: 0.8236 - val_dice: 0.6816 - val_binary_accuracy: 0.8840
# Epoch 37/150
# Epoch 00036: dice did not improve
# Epoch 00036: val_dice did not improve
# 198s - loss: 1.1354 - dice: 0.7245 - binary_accuracy: 0.8887 - val_loss: 0.6511 - val_dice: 0.7189 - val_binary_accuracy: 0.9097
# Epoch 38/150
# Epoch 00037: dice did not improve
# Epoch 00037: val_dice did not improve
# 198s - loss: 1.1034 - dice: 0.7333 - binary_accuracy: 0.8925 - val_loss: 0.6694 - val_dice: 0.7112 - val_binary_accuracy: 0.9051
# Epoch 39/150
#
# Epoch 00038: reducing learning rate to 0.000999999977648.
# Epoch 00038: dice improved from 0.73532 to 0.73550, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7223-0.7355-e=38--X--D10G5M5---2.hdf5
# Epoch 00038: val_dice improved from 0.71907 to 0.72227, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7223-0.7355-e=38--X--D10G5M5---2.hdf5
# 199s - loss: 1.0949 - dice: 0.7355 - binary_accuracy: 0.8923 - val_loss: 0.6458 - val_dice: 0.7223 - val_binary_accuracy: 0.9124
# Epoch 40/150
# Epoch 00039: dice improved from 0.73550 to 0.75202, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7323-0.7520-e=39--X--D10G5M5---2.hdf5
# Epoch 00039: val_dice improved from 0.72227 to 0.73230, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7323-0.7520-e=39--X--D10G5M5---2.hdf5
# 199s - loss: 1.0439 - dice: 0.7520 - binary_accuracy: 0.9005 - val_loss: 0.6067 - val_dice: 0.7323 - val_binary_accuracy: 0.9169
# Epoch 41/150
# Epoch 00040: dice improved from 0.75202 to 0.75641, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7391-0.7564-e=40--X--D10G5M5---2.hdf5
# Epoch 00040: val_dice improved from 0.73230 to 0.73907, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7391-0.7564-e=40--X--D10G5M5---2.hdf5
# 199s - loss: 1.0313 - dice: 0.7564 - binary_accuracy: 0.9022 - val_loss: 0.5973 - val_dice: 0.7391 - val_binary_accuracy: 0.9173
# Epoch 42/150
# Epoch 00041: dice improved from 0.75641 to 0.76001, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7371-0.7600-e=41--X--D10G5M5---2.hdf5
# Epoch 00041: val_dice did not improve
# 199s - loss: 1.0250 - dice: 0.7600 - binary_accuracy: 0.9031 - val_loss: 0.6022 - val_dice: 0.7371 - val_binary_accuracy: 0.9187
# Epoch 43/150
# Epoch 00042: dice improved from 0.76001 to 0.76270, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7368-0.7627-e=42--X--D10G5M5---2.hdf5
# Epoch 00042: val_dice did not improve
# 199s - loss: 1.0087 - dice: 0.7627 - binary_accuracy: 0.9038 - val_loss: 0.5863 - val_dice: 0.7368 - val_binary_accuracy: 0.9184
# Epoch 44/150
# Epoch 00043: dice did not improve
# Epoch 00043: val_dice improved from 0.73907 to 0.74111, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7411-0.7579-e=43--X--D10G5M5---2.hdf5
# 198s - loss: 1.0302 - dice: 0.7579 - binary_accuracy: 0.9023 - val_loss: 0.5659 - val_dice: 0.7411 - val_binary_accuracy: 0.9195
# Epoch 45/150
# Epoch 00044: dice improved from 0.76270 to 0.76476, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7342-0.7648-e=44--X--D10G5M5---2.hdf5
# Epoch 00044: val_dice did not improve
# 198s - loss: 0.9933 - dice: 0.7648 - binary_accuracy: 0.9039 - val_loss: 0.5877 - val_dice: 0.7342 - val_binary_accuracy: 0.9180
# Epoch 46/150
# Epoch 00045: dice improved from 0.76476 to 0.76481, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7425-0.7648-e=45--X--D10G5M5---2.hdf5
# Epoch 00045: val_dice improved from 0.74111 to 0.74254, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7425-0.7648-e=45--X--D10G5M5---2.hdf5
# 198s - loss: 0.9970 - dice: 0.7648 - binary_accuracy: 0.9033 - val_loss: 0.5886 - val_dice: 0.7425 - val_binary_accuracy: 0.9191
# Epoch 47/150
# Epoch 00046: dice improved from 0.76481 to 0.76510, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7510-0.7651-e=46--X--D10G5M5---2.hdf5
# Epoch 00046: val_dice improved from 0.74254 to 0.75104, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7510-0.7651-e=46--X--D10G5M5---2.hdf5
# 198s - loss: 0.9949 - dice: 0.7651 - binary_accuracy: 0.9034 - val_loss: 0.5467 - val_dice: 0.7510 - val_binary_accuracy: 0.9209
# Epoch 48/150
# Epoch 00047: dice improved from 0.76510 to 0.77161, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7532-0.7716-e=47--X--D10G5M5---2.hdf5
# Epoch 00047: val_dice improved from 0.75104 to 0.75322, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7532-0.7716-e=47--X--D10G5M5---2.hdf5
# 198s - loss: 0.9741 - dice: 0.7716 - binary_accuracy: 0.9047 - val_loss: 0.5337 - val_dice: 0.7532 - val_binary_accuracy: 0.9202
# Epoch 49/150
# Epoch 00048: dice improved from 0.77161 to 0.77570, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7533-0.7757-e=48--X--D10G5M5---2.hdf5
# Epoch 00048: val_dice improved from 0.75322 to 0.75327, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7533-0.7757-e=48--X--D10G5M5---2.hdf5
# 198s - loss: 0.9636 - dice: 0.7757 - binary_accuracy: 0.9058 - val_loss: 0.5373 - val_dice: 0.7533 - val_binary_accuracy: 0.9205
# Epoch 50/150
# Epoch 00049: dice improved from 0.77570 to 0.77788, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7517-0.7779-e=49--X--D10G5M5---2.hdf5
# Epoch 00049: val_dice did not improve
# 198s - loss: 0.9568 - dice: 0.7779 - binary_accuracy: 0.9063 - val_loss: 0.5313 - val_dice: 0.7517 - val_binary_accuracy: 0.9182
# Epoch 51/150
# Epoch 00050: dice improved from 0.77788 to 0.78018, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7533-0.7802-e=50--X--D10G5M5---2.hdf5
# Epoch 00050: val_dice did not improve
# 198s - loss: 0.9509 - dice: 0.7802 - binary_accuracy: 0.9074 - val_loss: 0.5481 - val_dice: 0.7533 - val_binary_accuracy: 0.9206
# Epoch 52/150
# Epoch 00051: dice improved from 0.78018 to 0.78217, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7529-0.7822-e=51--X--D10G5M5---2.hdf5
# Epoch 00051: val_dice did not improve
# 198s - loss: 0.9468 - dice: 0.7822 - binary_accuracy: 0.9077 - val_loss: 0.5333 - val_dice: 0.7529 - val_binary_accuracy: 0.9225
# Epoch 53/150
# Epoch 00052: dice improved from 0.78217 to 0.78494, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7546-0.7849-e=52--X--D10G5M5---2.hdf5
# Epoch 00052: val_dice improved from 0.75327 to 0.75457, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7546-0.7849-e=52--X--D10G5M5---2.hdf5
# 198s - loss: 0.9401 - dice: 0.7849 - binary_accuracy: 0.9088 - val_loss: 0.5266 - val_dice: 0.7546 - val_binary_accuracy: 0.9202
# Epoch 54/150
# Epoch 00053: dice improved from 0.78494 to 0.78635, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7603-0.7863-e=53--X--D10G5M5---2.hdf5
# Epoch 00053: val_dice improved from 0.75457 to 0.76032, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7603-0.7863-e=53--X--D10G5M5---2.hdf5
# 198s - loss: 0.9356 - dice: 0.7863 - binary_accuracy: 0.9095 - val_loss: 0.5206 - val_dice: 0.7603 - val_binary_accuracy: 0.9231
# Epoch 55/150
# Epoch 00054: dice improved from 0.78635 to 0.78868, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7584-0.7887-e=54--X--D10G5M5---2.hdf5
# Epoch 00054: val_dice did not improve
# 198s - loss: 0.9305 - dice: 0.7887 - binary_accuracy: 0.9100 - val_loss: 0.5285 - val_dice: 0.7584 - val_binary_accuracy: 0.9236
# Epoch 56/150
# Epoch 00055: dice improved from 0.78868 to 0.79082, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7574-0.7908-e=55--X--D10G5M5---2.hdf5
# Epoch 00055: val_dice did not improve
# 198s - loss: 0.9255 - dice: 0.7908 - binary_accuracy: 0.9106 - val_loss: 0.5227 - val_dice: 0.7574 - val_binary_accuracy: 0.9235
# Epoch 57/150
#
# Epoch 00056: reducing learning rate to 0.000499999965541.
# Epoch 00056: dice did not improve
# Epoch 00056: val_dice did not improve
# 197s - loss: 0.9319 - dice: 0.7896 - binary_accuracy: 0.9105 - val_loss: 0.5251 - val_dice: 0.7576 - val_binary_accuracy: 0.9222
# Epoch 58/150
# Epoch 00057: dice improved from 0.79082 to 0.79432, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7612-0.7943-e=57--X--D10G5M5---2.hdf5
# Epoch 00057: val_dice improved from 0.76032 to 0.76119, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7612-0.7943-e=57--X--D10G5M5---2.hdf5
# 198s - loss: 0.9162 - dice: 0.7943 - binary_accuracy: 0.9124 - val_loss: 0.5155 - val_dice: 0.7612 - val_binary_accuracy: 0.9229
# Epoch 59/150
# Epoch 00058: dice improved from 0.79432 to 0.79680, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7623-0.7968-e=58--X--D10G5M5---2.hdf5
# Epoch 00058: val_dice improved from 0.76119 to 0.76231, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7623-0.7968-e=58--X--D10G5M5---2.hdf5
# 198s - loss: 0.9103 - dice: 0.7968 - binary_accuracy: 0.9131 - val_loss: 0.5202 - val_dice: 0.7623 - val_binary_accuracy: 0.9244
# Epoch 60/150
# Epoch 00059: dice improved from 0.79680 to 0.79825, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7615-0.7982-e=59--X--D10G5M5---2.hdf5
# Epoch 00059: val_dice did not improve
# 198s - loss: 0.9068 - dice: 0.7982 - binary_accuracy: 0.9136 - val_loss: 0.5154 - val_dice: 0.7615 - val_binary_accuracy: 0.9245
# Epoch 61/150
# Epoch 00060: dice improved from 0.79825 to 0.79953, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7619-0.7995-e=60--X--D10G5M5---2.hdf5
# Epoch 00060: val_dice did not improve
# 198s - loss: 0.9039 - dice: 0.7995 - binary_accuracy: 0.9141 - val_loss: 0.5133 - val_dice: 0.7619 - val_binary_accuracy: 0.9242
# Epoch 62/150
# Epoch 00061: dice improved from 0.79953 to 0.80086, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7621-0.8009-e=61--X--D10G5M5---2.hdf5
# Epoch 00061: val_dice did not improve
# 198s - loss: 0.9008 - dice: 0.8009 - binary_accuracy: 0.9146 - val_loss: 0.5151 - val_dice: 0.7621 - val_binary_accuracy: 0.9249
# Epoch 63/150
# Epoch 00062: dice improved from 0.80086 to 0.80218, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7594-0.8022-e=62--X--D10G5M5---2.hdf5
# Epoch 00062: val_dice did not improve
# 198s - loss: 0.8977 - dice: 0.8022 - binary_accuracy: 0.9150 - val_loss: 0.5209 - val_dice: 0.7594 - val_binary_accuracy: 0.9253
# Epoch 64/150
#
# Epoch 00063: reducing learning rate to 0.000249999982771.
# Epoch 00063: dice improved from 0.80218 to 0.80322, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7614-0.8032-e=63--X--D10G5M5---2.hdf5
# Epoch 00063: val_dice did not improve
# 198s - loss: 0.8943 - dice: 0.8032 - binary_accuracy: 0.9155 - val_loss: 0.5224 - val_dice: 0.7614 - val_binary_accuracy: 0.9249
# Epoch 65/150
# Epoch 00064: dice improved from 0.80322 to 0.80513, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7623-0.8051-e=64--X--D10G5M5---2.hdf5
# Epoch 00064: val_dice did not improve
# 198s - loss: 0.8899 - dice: 0.8051 - binary_accuracy: 0.9163 - val_loss: 0.5152 - val_dice: 0.7623 - val_binary_accuracy: 0.9251
# Epoch 66/150
# Epoch 00065: dice improved from 0.80513 to 0.80621, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7642-0.8062-e=65--X--D10G5M5---2.hdf5
# Epoch 00065: val_dice improved from 0.76231 to 0.76416, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7642-0.8062-e=65--X--D10G5M5---2.hdf5
# 198s - loss: 0.8877 - dice: 0.8062 - binary_accuracy: 0.9166 - val_loss: 0.5124 - val_dice: 0.7642 - val_binary_accuracy: 0.9255
# Epoch 67/150
# Epoch 00066: dice improved from 0.80621 to 0.80676, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7646-0.8068-e=66--X--D10G5M5---2.hdf5
# Epoch 00066: val_dice improved from 0.76416 to 0.76462, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7646-0.8068-e=66--X--D10G5M5---2.hdf5
# 198s - loss: 0.8858 - dice: 0.8068 - binary_accuracy: 0.9170 - val_loss: 0.5094 - val_dice: 0.7646 - val_binary_accuracy: 0.9246
# Epoch 68/150
# Epoch 00067: dice improved from 0.80676 to 0.80763, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7618-0.8076-e=67--X--D10G5M5---2.hdf5
# Epoch 00067: val_dice did not improve
# 198s - loss: 0.8846 - dice: 0.8076 - binary_accuracy: 0.9171 - val_loss: 0.5200 - val_dice: 0.7618 - val_binary_accuracy: 0.9254
# Epoch 69/150
# Epoch 00068: dice improved from 0.80763 to 0.80844, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7619-0.8084-e=68--X--D10G5M5---2.hdf5
# Epoch 00068: val_dice did not improve
# 198s - loss: 0.8828 - dice: 0.8084 - binary_accuracy: 0.9173 - val_loss: 0.5104 - val_dice: 0.7619 - val_binary_accuracy: 0.9250
# Epoch 70/150
#
# Epoch 00069: reducing learning rate to 0.000124999991385.
# Epoch 00069: dice improved from 0.80844 to 0.80863, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7636-0.8086-e=69--X--D10G5M5---2.hdf5
# Epoch 00069: val_dice did not improve
# 198s - loss: 0.8817 - dice: 0.8086 - binary_accuracy: 0.9175 - val_loss: 0.5095 - val_dice: 0.7636 - val_binary_accuracy: 0.9240
# Epoch 71/150
# Epoch 00070: dice improved from 0.80863 to 0.80976, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7648-0.8098-e=70--X--D10G5M5---2.hdf5
# Epoch 00070: val_dice improved from 0.76462 to 0.76479, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7648-0.8098-e=70--X--D10G5M5---2.hdf5
# 198s - loss: 0.8785 - dice: 0.8098 - binary_accuracy: 0.9181 - val_loss: 0.5116 - val_dice: 0.7648 - val_binary_accuracy: 0.9256
# Epoch 72/150
# Epoch 00071: dice improved from 0.80976 to 0.81043, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7653-0.8104-e=71--X--D10G5M5---2.hdf5
# Epoch 00071: val_dice improved from 0.76479 to 0.76526, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7653-0.8104-e=71--X--D10G5M5---2.hdf5
# 198s - loss: 0.8774 - dice: 0.8104 - binary_accuracy: 0.9182 - val_loss: 0.5081 - val_dice: 0.7653 - val_binary_accuracy: 0.9247
# Epoch 73/150
# Epoch 00072: dice improved from 0.81043 to 0.81076, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7655-0.8108-e=72--X--D10G5M5---2.hdf5
# Epoch 00072: val_dice improved from 0.76526 to 0.76551, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7655-0.8108-e=72--X--D10G5M5---2.hdf5
# 198s - loss: 0.8766 - dice: 0.8108 - binary_accuracy: 0.9183 - val_loss: 0.5094 - val_dice: 0.7655 - val_binary_accuracy: 0.9255
# Epoch 74/150
# Epoch 00073: dice improved from 0.81076 to 0.81146, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7642-0.8115-e=73--X--D10G5M5---2.hdf5
# Epoch 00073: val_dice did not improve
# 198s - loss: 0.8752 - dice: 0.8115 - binary_accuracy: 0.9185 - val_loss: 0.5095 - val_dice: 0.7642 - val_binary_accuracy: 0.9253
# Epoch 75/150
#
# Epoch 00074: reducing learning rate to 6.24999956926e-05.
# Epoch 00074: dice did not improve
# Epoch 00074: val_dice did not improve
# 197s - loss: 0.8746 - dice: 0.8114 - binary_accuracy: 0.9186 - val_loss: 0.5111 - val_dice: 0.7655 - val_binary_accuracy: 0.9256
# Epoch 76/150
# Epoch 00075: dice improved from 0.81146 to 0.81256, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7647-0.8126-e=75--X--D10G5M5---2.hdf5
# Epoch 00075: val_dice did not improve
# 198s - loss: 0.8731 - dice: 0.8126 - binary_accuracy: 0.9188 - val_loss: 0.5108 - val_dice: 0.7647 - val_binary_accuracy: 0.9257
# Epoch 77/150
# Epoch 00076: dice did not improve
# Epoch 00076: val_dice improved from 0.76551 to 0.76573, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7657-0.8122-e=76--X--D10G5M5---2.hdf5
# 198s - loss: 0.8731 - dice: 0.8122 - binary_accuracy: 0.9189 - val_loss: 0.5076 - val_dice: 0.7657 - val_binary_accuracy: 0.9256
# Epoch 78/150
# Epoch 00077: dice improved from 0.81256 to 0.81260, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7650-0.8126-e=77--X--D10G5M5---2.hdf5
# Epoch 00077: val_dice did not improve
# 198s - loss: 0.8721 - dice: 0.8126 - binary_accuracy: 0.9190 - val_loss: 0.5073 - val_dice: 0.7650 - val_binary_accuracy: 0.9254
# Epoch 79/150
# Epoch 00078: dice did not improve
# Epoch 00078: val_dice did not improve
# 197s - loss: 0.8723 - dice: 0.8125 - binary_accuracy: 0.9190 - val_loss: 0.5080 - val_dice: 0.7652 - val_binary_accuracy: 0.9256
# Epoch 80/150
# Epoch 00079: dice improved from 0.81260 to 0.81288, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7658-0.8129-e=79--X--D10G5M5---2.hdf5
# Epoch 00079: val_dice improved from 0.76573 to 0.76577, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7658-0.8129-e=79--X--D10G5M5---2.hdf5
# 198s - loss: 0.8711 - dice: 0.8129 - binary_accuracy: 0.9191 - val_loss: 0.5067 - val_dice: 0.7658 - val_binary_accuracy: 0.9255
# Epoch 81/150
# Epoch 00080: dice improved from 0.81288 to 0.81305, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7661-0.8130-e=80--X--D10G5M5---2.hdf5
# Epoch 00080: val_dice improved from 0.76577 to 0.76610, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7661-0.8130-e=80--X--D10G5M5---2.hdf5
# 198s - loss: 0.8706 - dice: 0.8130 - binary_accuracy: 0.9192 - val_loss: 0.5076 - val_dice: 0.7661 - val_binary_accuracy: 0.9258
# Epoch 82/150
# Epoch 00081: dice improved from 0.81305 to 0.81346, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7656-0.8135-e=81--X--D10G5M5---2.hdf5
# Epoch 00081: val_dice did not improve
# 198s - loss: 0.8706 - dice: 0.8135 - binary_accuracy: 0.9193 - val_loss: 0.5079 - val_dice: 0.7656 - val_binary_accuracy: 0.9259
# Epoch 83/150
#
# Epoch 00082: reducing learning rate to 3.12499978463e-05.
# Epoch 00082: dice did not improve
# Epoch 00082: val_dice did not improve
# 197s - loss: 0.8698 - dice: 0.8133 - binary_accuracy: 0.9193 - val_loss: 0.5095 - val_dice: 0.7657 - val_binary_accuracy: 0.9259
# Epoch 84/150
# Epoch 00083: dice improved from 0.81346 to 0.81394, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7660-0.8139-e=83--X--D10G5M5---2.hdf5
# Epoch 00083: val_dice did not improve
# 198s - loss: 0.8690 - dice: 0.8139 - binary_accuracy: 0.9194 - val_loss: 0.5069 - val_dice: 0.7660 - val_binary_accuracy: 0.9258
# Epoch 85/150
#
# Epoch 00084: reducing learning rate to 1.56249989232e-05.
# Epoch 00084: dice did not improve
# Epoch 00084: val_dice did not improve
# 197s - loss: 0.8693 - dice: 0.8138 - binary_accuracy: 0.9194 - val_loss: 0.5069 - val_dice: 0.7660 - val_binary_accuracy: 0.9257
# Epoch 86/150
# Epoch 00085: dice improved from 0.81394 to 0.81416, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7656-0.8142-e=85--X--D10G5M5---2.hdf5
# Epoch 00085: val_dice did not improve
# 198s - loss: 0.8685 - dice: 0.8142 - binary_accuracy: 0.9195 - val_loss: 0.5083 - val_dice: 0.7656 - val_binary_accuracy: 0.9258
# Epoch 87/150
#
# Epoch 00086: reducing learning rate to 7.81249946158e-06.
# Epoch 00086: dice improved from 0.81416 to 0.81417, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7657-0.8142-e=86--X--D10G5M5---2.hdf5
# Epoch 00086: val_dice did not improve
# 198s - loss: 0.8682 - dice: 0.8142 - binary_accuracy: 0.9196 - val_loss: 0.5074 - val_dice: 0.7657 - val_binary_accuracy: 0.9257
# Epoch 88/150
# Epoch 00087: dice did not improve
# Epoch 00087: val_dice did not improve
# 197s - loss: 0.8688 - dice: 0.8140 - binary_accuracy: 0.9195 - val_loss: 0.5069 - val_dice: 0.7658 - val_binary_accuracy: 0.9257
# Epoch 89/150
#
# Epoch 00088: reducing learning rate to 3.90624973079e-06.
# Epoch 00088: dice did not improve
# Epoch 00088: val_dice did not improve
# 197s - loss: 0.8685 - dice: 0.8142 - binary_accuracy: 0.9195 - val_loss: 0.5078 - val_dice: 0.7657 - val_binary_accuracy: 0.9258
# Epoch 90/150
# Epoch 00089: dice improved from 0.81417 to 0.81424, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7658-0.8142-e=89--X--D10G5M5---2.hdf5
# Epoch 00089: val_dice did not improve
# 198s - loss: 0.8681 - dice: 0.8142 - binary_accuracy: 0.9196 - val_loss: 0.5076 - val_dice: 0.7658 - val_binary_accuracy: 0.9258
# Epoch 91/150
#
# Epoch 00090: reducing learning rate to 1.95312486539e-06.
# Epoch 00090: dice did not improve
# Epoch 00090: val_dice did not improve
# 197s - loss: 0.8678 - dice: 0.8142 - binary_accuracy: 0.9196 - val_loss: 0.5074 - val_dice: 0.7658 - val_binary_accuracy: 0.9258
# Epoch 92/150
# Epoch 00091: dice did not improve
# Epoch 00091: val_dice did not improve
# 199s - loss: 0.8683 - dice: 0.8142 - binary_accuracy: 0.9196 - val_loss: 0.5074 - val_dice: 0.7658 - val_binary_accuracy: 0.9258
# Epoch 93/150
#
# Epoch 00092: reducing learning rate to 9.76562432697e-07.
# Epoch 00092: dice improved from 0.81424 to 0.81430, saving model to ../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7658-0.8143-e=92--X--D10G5M5---2.hdf5
# Epoch 00092: val_dice did not improve
# 198s - loss: 0.8678 - dice: 0.8143 - binary_accuracy: 0.9197 - val_loss: 0.5074 - val_dice: 0.7658 - val_binary_accuracy: 0.9258
# Epoch 00092: early stopping
# 2017-08-02 03:50:47.251898

# %%
#!ls ../Temp/TempTempG5M5KFold -la | tail
#!ls ../Temp/TempTempG5M5KFold10 -la | tail
#!ls ../Temp/NewStep/StandartF3 -la | tail
#!ls ../Temp/NewStep/Level-1-loss -la | tail
# !ls ../Temp/NewStep/Level-1-loss -la | grep 'X--D10G5M5---1' | tail
# Out:
# -rwxrwxrwx 1 boba boba 62210480 авг  1 21:33 V1-UNET-val_dice=0.7609-0.7928-e=56--X--D10G5M5---1.hdf5
# -rwxrwxrwx 1 boba boba 62210480 авг  1 21:46 V1-UNET-val_dice=0.7612-0.7964-e=60--X--D10G5M5---1.hdf5
# -rwxrwxrwx 1 boba boba 62210480 авг  1 21:56 V1-UNET-val_dice=0.7615-0.7967-e=63--X--D10G5M5---1.hdf5
# -rwxrwxrwx 1 boba boba 62210480 авг  1 21:40 V1-UNET-val_dice=0.7617-0.7936-e=58--X--D10G5M5---1.hdf5
# -rwxrwxrwx 1 boba boba 62210480 авг  1 22:06 V1-UNET-val_dice=0.7621-0.7975-e=66--X--D10G5M5---1.hdf5
# -rwxrwxrwx 1 boba boba 62210480 авг  1 22:12 V1-UNET-val_dice=0.7623-0.7983-e=68--X--D10G5M5---1.hdf5
# -rwxrwxrwx 1 boba boba 62210480 авг  1 21:59 V1-UNET-val_dice=0.7626-0.7968-e=64--X--D10G5M5---1.hdf5
# -rwxrwxrwx 1 boba boba 62210480 авг  1 22:26 V1-UNET-val_dice=0.7626-0.7985-e=72--X--D10G5M5---1.hdf5
# -rwxrwxrwx 1 boba boba 62210480 авг  1 22:42 V1-UNET-val_dice=0.7626-0.7986-e=77--X--D10G5M5---1.hdf5
# -rwxrwxrwx 1 boba boba 62210480 авг  1 22:03 V1-UNET-val_dice=0.7630-0.7971-e=65--X--D10G5M5---1.hdf5

# %%
if 0 : model10 = load_model('../Temp/TrainModel001+G+M/V1-UNET-0.8511.hdf5')
if 0 : model10 = load_model('../Temp/V1-UNET-0.8853.hdf5')
#if 1 : model10 = load_model('../Temp/TempTempM3/V1-UNET-0.9054.hdf5')
if 0 : model10.load_weights('../Temp/TempTempM3/V1-UNET-0.9054.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5/V1-UNET-val_dice=0.7307.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFold/V1-UNET-val_dice=0.7879-2.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7632-2.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7660-2.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFoldMean/V1-UNET-val_dice=0.7828-2.hdf5')
if 0 : model10.load_weights('../Temp/TempTempG5M5KFold5/V1-UNET-val_dice=0.8224-0.8516---1.hdf5') # 769128
if 0 : model10.load_weights('../Temp/TempTempG5M5KFold5/V1-UNET-val_dice=0.8217-0.8655---1.hdf5') # 765XXX
if 0 : model10.load_weights('../Temp/TempTempG5M5KFold5/V1-UNET-val_dice=0.8227-0.8643---3.hdf5')    
if 0 : model10.load_weights('../Temp/TempTempG5M5KFold10/V1-UNET-val_dice=0.8315-0.8617---9.hdf5')    
if 0 : model10.load_weights('../Temp/NewStep/StandartF3/V1-UNET-val_dice=0.7655-0.7360---2.hdf5')    
if 0 : model10.load_weights('../Temp/NewStep/Level-1/V1-UNET-val_dice=0.7561-0.7261---2.hdf5')    
if 0 : model10.load_weights('../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.8063-0.8532---0.hdf5') # 767XXX
if 0 : model10.load_weights('../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.8183-0.8691---1.hdf5') # 770XXX
if 0 : model10.load_weights('../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7695-0.7984-Z3BCE-D02G0M0-0.hdf5') # 755959 test=872197
#---------------------------------------

if 1 : model10.load_weights('../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7630-0.7971-e=65--X--D10G5M5---1.hdf5') #
if 0 : model10.load_weights('../Temp/NewStep/Level-1-loss/V1-UNET-val_dice=0.7661-0.8130-e=80--X--D10G5M5---2.hdf5') # 763517 test=899919

# %%
# %time trP = model10.predict(trX,batch_size=batch_size)
# Out:
# CPU times: user 45.7 s, sys: 11.5 s, total: 57.2 s
# Wall time: 55.1 s

# %%
def thP01 (trP, th=0.5) :
    trP01 = trP.copy()
    trP01[trP>th] =1.0
    trP01[trP<=th]=0.0
    trP01 = trP01.astype(np.uint8)
    return(trP01)

def thP01OTSU (trP, ext=False) :
    trP01 = trP.copy()
    th_otsu = []
    for i in range(trP.shape[0]) :
        trP01X = (trP[i,:,:,0]*255.0).astype(np.uint8)
        ret,trP01X = cv.threshold(trP01X,0,1,cv.THRESH_BINARY+cv.THRESH_OTSU)
        trP01[i,:,:,0] = trP01X[:,:]
        th_otsu.append(ret); #print(thresh,ret)
        #plt.subplot(121); plt.imshow(trP[i,:,:,0]); plt.subplot(122); plt.imshow(trP[i,:,:,0]); plt.show()
        
    if not ext : return(trP01)    
    
    th_otsu = np.array(th_otsu).astype(np.int16)/255.0
    return(trP01,th_otsu)
    #plt.hist(th_otsu.ravel(),bins=50); plt.show()
    #plt.close()        
    #print('th-otsu mean={}, std={}'.format(th_otsu.mean(),th_otsu.std()))
    #print(np.array(th_otsu[:166]))

# %%
trP01 = thP01(trP)

# %%
#
#
# 2017-07-31 otsu расчет для каждой картинки
#
#
otsu = 1
if otsu :
    trP01O, th_otsu = thP01OTSU(trP[:166],ext=True)
    plt.hist(th_otsu.ravel(),bins=50); plt.show()
    plt.close()        
    print('train th-otsu mean={}, std={}'.format(th_otsu.mean(),th_otsu.std()))
    #print(np.array(th_otsu[:166]))
# Out:
# train th-otsu mean=0.421426884007, std=0.0512280986567

# %%
if 0 : # Ощутимых результатов не дает, увеличение в +10-100
    times, medianP = 3,5
    for i in range(trP01.shape[0]) :
        for j in range(times) :
            trP01[i,:,:,0] = cv.medianBlur(trP01[i],medianP)

# %%
iii = 10
print(trX[0].shape,trY[0].shape,trP.shape,trP.min(),trP.max())
for ii in range(iii,iii+11) :
    plt.figure(figsize=(16,4))
    pdice = diceNP(trY[ii,:,:,0],trP01[ii,:,:,0])
    plt.subplot(161); plt.imshow(trX[ii,:,:,0],'gray'); plt.title('train dice={:.4f}'.format(pdice))
    plt.subplot(162); plt.imshow(trY[ii,:,:,0],'gray'); plt.title('mask')
    plt.subplot(163); plt.imshow(trP[ii,:,:,0],'gray'); plt.title('pred P')
    plt.subplot(165); plt.imshow(trP01[ii,:,:,0],'gray'); plt.title('pred P01'+'({:.4f})'.format(pdice))
    if otsu : 
        pdice = diceNP(trY[ii,:,:,0],trP01O[ii,:,:,0])
        plt.subplot(164); plt.imshow(trP01O[ii,:,:,0],'gray'); plt.title('pred P OUTSU'+'({:.4f})'.format(pdice))
    plt.subplot(166); plt.hist(trP[ii,:,:,0].ravel(),bins=50); plt.title('hist P')
    plt.show()
plt.close()
# Out:
# (512, 512, 3) (512, 512, 1) (672, 512, 512, 1) 0.0 0.895027

# %%
# Calculate F1-micro

# %%
TP = (trY[:,6:506,6:506,0]*trP01[:,6:506,6:506,0]).sum()
TN = ((1.0-trY[:,6:506,6:506,0])*(1.0-trP01[:,6:506,6:506,0])).sum()
FP = ((trY[:,6:506,6:506,0])*(1.0-trP01[:,6:506,6:506,0])).sum()
FN = ((1.0-trY[:,6:506,6:506,0])*(trP01[:,6:506,6:506,0])).sum()

P  = TP/(TP+FP) if (TP+FP)>0.0001 else 1.0
R  = TP/(TP+FN) if (TP+FN)>0.0001 else 0.0

F1 = 2.0*P*R/(P+R) if (P+R)>0.0001 else 0.0

TP,TN,FP,FN,P,R,F1
#P*R,P+R, 2.0*P*R/(P+R)
# Out:
# (51961521.0,
#  104785734.0,
#  4391359.0,
#  6861386.0,
#  0.92207392062304538,
#  0.88335520378141119,
#  0.90229938693624889)

# %%
# Calculate DI- dice.mean()

# %%
diceTrain = []
for i in range(166) : #trP.shape[0]) :
    diceTrain.append(diceNP(trY[i,6:-6,6:-6,0],trP01[i,6:-6,6:-6,0]))
di = (np.array(diceTrain)).mean()
di #,np.array(dice)  #,np.array(XX)
# Out:
# 0.85857429049021516

# %%
if 1 :
    di_th = []
    for i in range(1,10) : 
        th = (0.0+i)/10.0
        trP01D = thP01(trP,th=th)
        diceTrainD = []
        for i in range(166) : #trP.shape[0]) :
            diceTrainD.append(diceNP(trY[i,6:-6,6:-6,0],trP01D[i,6:-6,6:-6,0]))
        diD = (np.array(diceTrainD)).mean()
        di_th.append((th,diD))
di_th
# Out:
# [(0.1, 0.83967368024829758),
#  (0.2, 0.85106773607266117),
#  (0.3, 0.85568435651925523),
#  (0.4, 0.85788621280969346),
#  (0.5, 0.85857429049021516),
#  (0.6, 0.85771870384648108),
#  (0.7, 0.85344691399678885),
#  (0.8, 0.82984659282080464),
#  (0.9, 0.012105102108819231)]

# %%
plt.plot(np.array([xx for th,xx in di_th])); plt.plot(np.array([xx for th,xx in di_th])); plt.show(); plt.close() 

plt.hist(np.array(diceTrain),bins=40); plt.show()
plt.plot(np.array(diceTrain)); plt.show()
np.array(diceTrain).argmin()
# Out:
# 92

# %%
1000000*(F1+di)/2.0
# Out:
# 880436.83871323196

# %%
#np.array(dice)<0.4

# %%
# Подготовка test решения

# %%
if flagGray :
    trO, trO0 = [], np.zeros((512,512,1))
else :
    trO, trO0 = [], np.zeros((512,512,3))

for xx in listTest :
    img = cv.imread(os.path.join(dirTest,xx),-1)
    if 1 and (Gauss or Median): 
        for cc in range(img.shape[2]) : 
            if Gauss  : img[:,:,cc] = cv.GaussianBlur(img[:,:,cc],(Gauss,Gauss),0);
            if Median : img[:,:,cc] = cv.medianBlur  (img[:,:,cc],Median);
    #print(img.mean(),msk.mean())
    if flagGray :
        img = cv.cvtColor(img,cv.COLOR_RGB2GRAY);
        trO0[6:506,6:506,0] = img[:,:]/255.0
    else :
        trO0[6:506,6:506,:] = img[:,:,:]/255.0
    trO.append(trO0.copy())
    #print(trX0.mean(),trY0.mean(),trX1[-1].mean(),trY1[-1].mean())

#print([trY[xx].mean() for xx in range(10)])
trO = np.array(trO)

if 1 :
    for cc in range(meanX.shape[0]) : 
        trO[:,6:506,6:506,cc] -= meanX[cc]
    
trO.shape, trO.min(), trO.max()
#[trY[xx].mean() for xx in range(10)]
# Out:
# ((162, 512, 512, 3), -0.6417290164331112, 0.47912580261435672)

# %%
# %time trOP = model10.predict(trO,batch_size=batch_size)
# Out:
# CPU times: user 11 s, sys: 2.79 s, total: 13.8 s
# Wall time: 13.3 s

# %%
trOP01 = thP01(trOP)

# %%
otsu = 1
if otsu :
    trOP01O, th_otsu = thP01OTSU(trOP,ext=True)
    plt.hist(th_otsu.ravel(),bins=50); plt.show()
    plt.close()        
    print('test th-otsu mean={}, std={}'.format(th_otsu.mean(),th_otsu.std()))
    #print(np.array(th_otsu[:166]))
# Out:
# test th-otsu mean=0.424449285887, std=0.0415809192669

# %%
iii = 10
print(trO[0].shape,trP01[0].shape,trOP01.shape,trOP.min(),trOP.max())
for ii in range(iii,iii+10) :
    plt.figure(figsize=(17,4))
    plt.subplot(161); plt.imshow(trO[ii,:,:,0]); plt.title('test')
    plt.subplot(162); plt.imshow(trOP01 [ii,:,:,0],'gray'); plt.title('P01')
    if otsu : plt.subplot(163); plt.imshow(trOP01O[ii,:,:,0],'gray'); plt.title('P01 OTSU')
    plt.subplot(164); plt.imshow(trOP[ii,:,:,0],'gray');  plt.title('P gray')
    plt.subplot(165); plt.hist(trOP[ii,:,:,0].ravel(),bins=50);  plt.title('P hist')
    plt.show()
plt.close()
# Out:
# (512, 512, 3) (512, 512, 1) (162, 512, 512, 1) 0.0 0.895027

# %%
otsu = 0
if otsu : trOP01 = trOP01O; print(datetime.datetime.now(),'otsu datas')

# %%
# Формирование выходной директории

# %%
def convert_to_binary(truth_png_file, truth_txt_file):
    im = Image.open(truth_png_file) #Can be many different formats.
    pix = im.load()
    with open(truth_txt_file, 'w') as out:
        for x in xrange(500):
            for y in xrange(500):
                out.write(str(int(pix[x, y] > 0)))
            out.write('\n')

if not os.path.exists('../Temp/random_submission'):
    os.makedirs('../Temp/random_submission')

# Training
for i in range(len(listTrain)) :
    fn = listTrain[i]
    truth_txt_file = '../Temp/random_submission/' + fn.split('.')[0] + '_mask.txt'
    with open(truth_txt_file, 'w') as out:
        for x in xrange(500):
            for y in xrange(500):
                out.write(str(int(trP01[i,y+6, x+6] > 0.0)))
            out.write('\n')
    out.close()
    
# Testing
for i in range(len(listTest)) :
    fn = listTest[i]
    truth_txt_file = '../Temp/random_submission/' + fn.split('.')[0] + '_mask.txt'
    with open(truth_txt_file, 'w') as out:
        for x in xrange(500):
            for y in xrange(500):
                out.write(str(int(trOP01[i,y+6, x+6] > 0.0)))
            out.write('\n')
    out.close()

# %%
import shutil

# %%
xx=shutil.make_archive('../Result/topcoderkonica','zip','../Temp/random_submission')
xx
# Out:
# '/media/boba/DATA/boba/Working/TopCoder/2017-07-25-Konica-Minolta/Result/topcoderkonica.zip'

# %%
# !ls ../Temp/NewStep/Exp/1 -la
# Out:
# total 7354401
# drwxrwxrwx 1 boba boba       4096 авг  2 10:30 .
# drwxrwxrwx 1 boba boba          0 авг  2 09:59 ..
# drwxrwxrwx 1 boba boba          0 авг  2 10:26 .ipynb_checkpoints
# -rwxrwxrwx 1 boba boba       1862 авг  2 10:30 listTest.npy
# -rwxrwxrwx 1 boba boba       1928 авг  2 10:30 listTrain.npy
# -rwxrwxrwx 1 boba boba        104 авг  2 10:30 meanX.npy
# -rwxrwxrwx 1 boba boba 1019215968 авг  2 10:31 trO.npy
# -rwxrwxrwx 1 boba boba  169869408 авг  2 10:31 trOP.npy
# -rwxrwxrwx 1 boba boba  704643168 авг  2 10:31 trP.npy
# -rwxrwxrwx 1 boba boba 4227858528 авг  2 10:31 trX.npy
# -rwxrwxrwx 1 boba boba 1409286240 авг  2 10:31 trY.npy

# %%
# !ls ../Temp/NewStep/Exp/2 -la
# Out:
# total 7354397
# drwxrwxrwx 1 boba boba        472 авг  2 10:42 .
# drwxrwxrwx 1 boba boba          0 авг  2 09:59 ..
# -rwxrwxrwx 1 boba boba       1862 авг  2 10:41 listTest.npy
# -rwxrwxrwx 1 boba boba       1928 авг  2 10:41 listTrain.npy
# -rwxrwxrwx 1 boba boba        104 авг  2 10:41 meanX.npy
# -rwxrwxrwx 1 boba boba 1019215968 авг  2 10:42 trO.npy
# -rwxrwxrwx 1 boba boba  169869408 авг  2 10:42 trOP.npy
# -rwxrwxrwx 1 boba boba  704643168 авг  2 10:42 trP.npy
# -rwxrwxrwx 1 boba boba 4227858528 авг  2 10:42 trX.npy
# -rwxrwxrwx 1 boba boba 1409286240 авг  2 10:42 trY.npy

# %%
# Сохранение
dirs = '../Temp/NewStep/Exp/2'

np.save(os.path.join(dirs,'meanX.npy'),meanX)
np.save(os.path.join(dirs,'listTrain.npy'),np.array(listTrain))
np.save(os.path.join(dirs,'listTest.npy'), np.array(listTest))

np.save(os.path.join(dirs,'trX.npy'),trX)
np.save(os.path.join(dirs,'trY.npy'),trY)
np.save(os.path.join(dirs,'trP.npy'),trP)
np.save(os.path.join(dirs,'trOP.npy'),trOP)
np.save(os.path.join(dirs,'trO.npy'),trO)

# %%
# Восстановление
meanX     = np.load(os.path.join(dirs,'meanX.npy'))
listTrain = np.load(os.path.join(dirs,'listTrain.npy'))
listTest  = np.load(os.path.join(dirs,'listTest.npy'))

trX = np.load(os.path.join(dirs,'trX.npy'))
trY = np.load(os.path.join(dirs,'trY.npy'))
trP = np.load(os.path.join(dirs,'trP.npy'))
trOP= np.load(os.path.join(dirs,'trOP.npy'))
trO = np.load(os.path.join(dirs,'trO.npy'))
# Out:
# (672, 512, 512, 1)

# %%
#rrr=pd.DataFrame(res,columns=['image_name','tags']); rrr.head(); 
#suffixDT = (datetime.datetime.now()).strftime('%Y-%m-%d-%H-%M-%S'); print(suffixDT)
#rrr.to_csv('../Result/vss'+suffixDT+'.csv',index=False);
